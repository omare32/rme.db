# %%
import os
import oracledb
import requests
from twilio.rest import Client
from requests.packages.urllib3.exceptions import InsecureRequestWarning

# ✅ Disable SSL warnings
requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

# ✅ Database connection details
oracledb.init_oracle_client(lib_dir=r"C:\oracle\instantclient_21_15")
hostname = "10.0.11.59"
port = 1521
service_name = "RMEDB"
username = "RME_DEV"
password = "PASS21RME"

# ✅ Microsoft Teams Webhook
teams_webhook_url = "https://rowadmodern.webhook.office.com/webhookb2/84557fde-c0e1-457d-99d7-152442e5b0ac@7c9607e1-cd01-4c4f-a163-c7f2bb6284a4/IncomingWebhook/2ea28de8d34b417b8ded9774788916fd/24f28753-9c07-40e0-91b2-ea196c200a33/V2f9usIcwbZeFI--I8y4MnuI-SVjXJVlrVqccubKwdsIg1"

# ✅ Twilio WhatsApp Credentials
TWILIO_ACCOUNT_SID = "AC249bd7ddb87e51ebbbec32eaa5805fc2"
TWILIO_AUTH_TOKEN = "36375c546fb0b3953a4dda7ce2e5f6f9"
TWILIO_WHATSAPP_NUMBER = "whatsapp:+14155238886"  # Twilio sandbox number

# ✅ WhatsApp Recipients (Ensure they're registered in Twilio sandbox)
whatsapp_recipients = [
    "whatsapp:+201128484442",
    "whatsapp:+201286177055",
    "whatsapp:+201286868419"
]

# ✅ File paths for storing last transactions
base_dir = r"D:\OneDrive\OneDrive - Rowad Modern Engineering\x004 Data Science\03.rme.db\00.repo\rme.db\13.airflow-spark\07.cash-in-message"
os.makedirs(base_dir, exist_ok=True)
last_cash_in_file = os.path.join(base_dir, "last_cash_in.txt")
last_message_file = os.path.join(base_dir, "last_message.txt")  

# Project mapping dictionary (preloaded from the Excel file)
project_mapping = {
    "0019": "Ismalia Bridge",
    "0030": "Mall Of Egypt",
    "0032": "Sodic Club House",
    "0040": "Al Mostathmreen GIS Substation",
    "0046": "El Amal Bridge",
    "0048": "Wall - New Giza",
    "0051": "Tamey El-amdeed Substation",
    "0052": "Ismailiya East Substation",
    "0053": "Amal Bridge Lock & Load",
    "0059": "New Capital Tunnels",
    "0060": "Ministries Buildings",
    "0061": "Beni Suef Substation R61",
    "0063": "Royal City",
    "0064": "Shubra-Banha lock&load",
    "0065": "El Sewedy Stores Project",
    "0066": "El Mostaqbal lock & load",
    "0068": "Kayan wall lock & Load",
    "0069": "Suez Steel Factory",
    "0070": "Hyper El-Temsah",
    "0071": "EMAAR-PKG117- MARASSI",
    "0072": "Siemens Power Station",
    "0073": "EMAAR-PKG#85-UPTOWN",
    "0074": "Tunnel of Sokhna Road",
    "0075": "Abu Sultan Road Extension",
    "0076": "Mintra New Factory",
    "0077": "King Farouk Resthouse Rest.",
    "0078": "Mohamed Ali Palace Restoration",
    "0079": "New bridge Ismailiya Nefisha",
    "0080": "Fish Market",
    "0081": "AL-JAZI EGYPT",
    "0082": "R5 Mix-Use Complex Project",
    "0083": "TSK Solar Benban",
    "0084": "Alamein",
    "0085": "Elsewedy Univ - Enabling Works",
    "0086": "Lock&Load-30June w Sokhna Rd",
    "0087": "NUCA R05 - Z03",
    "0088": "NUCA R05 - Z02",
    "0089": "AbuSultan Rd Bridge2 Extension",
    "0090": "Tunnel of Sokhna Road (2)",
    "0091": "Middle Tunnel Lock Load",
    "0092": "EDNC Retail & Offices Civil",
    "0093": "EMAAR-PKG# 144, Marassi",
    "0094": "DPW Onshore Port & Terminal",
    "0095": "EMAAR-PKG# 101-UPTOWN",
    "0096": "Substation Elco Steel",
    "0097": "Agric Greenhouses Tunnel",
    "0098": "EMAAR- Pkg 140-ITP-Mivida",
    "0099": "Olympic Multi – Sports Hall",
    "0100": "Emergency Bridge",
    "0101": "Pyramid tunnel",
    "0102": "ELCO STEEL-EGAT",
    "0103": "Abu Ghazala Lock & Load",
    "0104": "Mohamed Aly Fahmy Lock&Load",
    "0105": "El Moshier ( Abu Zaid Khedr)",
    "0106": "ORA Zed Park LOCK&LOAD",
    "0107": "DoubleTree Mangroovy ElGouna",
    "0108": "Baron Fence",
    "0109": "Safeer Square Bridge",
    "0110": "Suez Road Tunnel RES",
    "0111": "HyperOne Zayed Extension",
    "0112": "IKEA Extension MoA",
    "0113": "CFC Podium 2",
    "0114": "Mostafa Kamel Bridge L&L",
    "0115": "Joseph Tito Bridge L&L",
    "0116": "ESPIKO Bridge L&L",
    "0117": "ElGabal AlAsfar Tunnel L&L",
    "0118": "MR3 Bridge L&L",
    "0119": "ESU Ph2-Enabling & Struc",
    "0120": "Mehwar elsalam Lock & Load",
    "0121": "EL-Hegaz Square Bridge",
    "0122": "RING ROAD MARYOTIA EXPANSION",
    "0123": "EMAAR-Pkg#162/163- Marassi",
    "0124": "Sultana Malak Restoration",
    "0125": "Lekela 250MW Wind Farm",
    "0126": "New Giza Teaching Hospital",
    "0127": "Kayan Landscape",
    "0128": "BridgeNasr Rd w Abbas El-Akkad",
    "0129": "Asher Mn Ramadan Bridge No2",
    "0130": "Kafr Shokr Bridge",
    "0131": "Shorouk Bridge-LRT",
    "0132": "RING ROAD BRIDGE - El MARG",
    "0133": "GOV2 - Infra",
    "0134": "Cairo-Alex Railway",
    "0135": "Hassan El Mamoun Bridge",
    "0136": "Sherouk Bridge- LOCK&LOAD",
    "0137": "ORA ZED - Ph 01B - Pkgs A&D",
    "0138": "Kattameya Creeks",
    "0139": "Faculty of Medicine",
    "0140": "Diplomatic District - Infra",
    "0141": "ElSewedy HQ Internal Finishing",
    "0142": "BKG#178-Lagoon Discharge",
    "0143": "El Khatatba Bridge",
    "0144": "EGAT Pelletizing Plant",
    "0145": "Sokhna Port Expansion",
    "0146": "Waldorf Astoria Mock-up Room",
    "0147": "MDF Factory",
    "0148": "Olympic City Lock&Load",
    "0149": "Kemet Building",
    "0150": "Air Defense College",
    "0151": "ORA ZED-Ph 2-Pkgs A&D",
    "0152": "HST Bridges-Sokhna & Mahager",
    "0153": "October Dry Port Railway",
    "0154": "Alfa New Central Labs",
    "0155": "R06 Loack & Load",
    "0156": "Waslet Om Amar Bridge",
    "0157": "Abou Ghaleb Bridge",
    "0158": "Egyptian Exchange Building",
    "0159": "Port Said Port Silos",
    "0160": "The Open Channel Project",
    "0161": "Ras El Teen Hangar",
    "0162": "Asmarat Roads L&L",
    "0163": "El Shohadaa Mosque No.006",
    "0164": "Waldorf Astoria Cairo",
    "0165": "King Mariout  Bridge",
    "0166": "Alamein Coastal Road Bridge",
    "0167": "Wady El Natroon Bridge",
    "0168": "HST El Mahager Bridge",
    "0169": "HST Culverts",
    "0170": "Mivida BP#189",
    "0171": "EDNC Hardscape Package",
    "0172": "Egat Rolling Mill no.4",
    "0173": "EGAT Lock & Load",
    "0174": "Qani bay Al rammah Mosque",
    "0175": "October Under-Railway Tunnel",
    "0176": "Radamis City",
    "0177": "SODIC Allegria Villa f100",
    "0178": "El- Hussein Mosque",
    "0179": "Jawhar Al-Lala Mosque",
    "0180": "Endowments Building",
    "0181": "Beymen Fit Out",
    "0182": "Astoria Sharm elSheikh",
    "0183": "Wadi Halfa Port",
    "0184": "SSC Suez Steel Company Project"
}

# ✅ Read/Write helper functions
def read_file(file_path):
    if os.path.exists(file_path):
        with open(file_path, "r", encoding="utf-8") as file:
            return file.read().strip()
    return ""

def write_file(file_path, content):
    with open(file_path, "w", encoding="utf-8") as file:
        file.write(content)

try:
    print("Connecting to the database...")
    dsn = oracledb.makedsn(hostname, port, service_name=service_name)
    connection = oracledb.connect(user=username, password=password, dsn=dsn)
    print("Connected to the database!")

    cursor = connection.cursor()

    # ✅ Read last recorded cash receipt ID
    last_cash_in_data = read_file(last_cash_in_file)
    last_cash_receipt_id = int(last_cash_in_data.split("|")[0]) if last_cash_in_data else 0

    # ✅ Fetch all new transactions since the last recorded one
    query_new_transactions = """
    SELECT acr.CASH_RECEIPT_ID,
           TO_CHAR(acr.RECEIPT_DATE, 'YYYY-MM-DD') AS receipt_date,
           TRUNC(acr.amount * NVL(acr.exchange_rate, 1)) AS Recipt_amount_EGP,
           acr.comments,
           acr.ATTRIBUTE1  -- Project number
    FROM AR_CASH_RECEIPTS_ALL acr
    WHERE acr.ATTRIBUTE_CATEGORY = '83'
      AND acr.ATTRIBUTE1 IS NOT NULL
      AND acr.ATTRIBUTE2 != 'Manual/Netting'
      AND acr.CASH_RECEIPT_ID > :last_cash_receipt_id  -- ✅ Fetch all new transactions
    ORDER BY acr.CASH_RECEIPT_ID ASC  -- ✅ Ensure older transactions come first
    """
    cursor.execute(query_new_transactions, last_cash_receipt_id=last_cash_receipt_id)
    results = cursor.fetchall()  # ✅ Fetch multiple rows

    if results:
        # ✅ Fetch total cash-in for the current month (excluding reversed transactions)
        query_total_month = """
        SELECT SUM(TRUNC(acr.amount * NVL(acr.exchange_rate, 1))) AS total_month
        FROM AR_CASH_RECEIPTS_ALL acr
        WHERE acr.ATTRIBUTE_CATEGORY = '83'
          AND acr.ATTRIBUTE1 IS NOT NULL
          AND acr.ATTRIBUTE2 != 'Manual/Netting'
          AND acr.REVERSAL_REASON_CODE IS NULL  -- ✅ Ignore reversed transactions
          AND TO_CHAR(acr.RECEIPT_DATE, 'YYYY-MM') = TO_CHAR(SYSDATE, 'YYYY-MM')
        """
        cursor.execute(query_total_month)
        total_month_result = cursor.fetchone()
        total_month = total_month_result[0] if total_month_result[0] else 0

        # ✅ Process each new transaction
        for result in results:
            cash_receipt_id, receipt_date, amount_egp, comment, project_number = result
            project_name = project_mapping.get(project_number, None)  # Fetch project name

            # ✅ Construct the message
            message = "New Cash-In Transaction:\n"
            if project_name:
                message += f"🏗️ Project: {project_name}\n"
            message += (
                f"📅 Date: {receipt_date}\n"
                f"💰 Amount: {amount_egp:,} EGP\n"
                f"📝 Comment: {comment if comment else 'No comment provided'}\n"
                f"🇪🇬 Total Cash-In for {receipt_date[:7]}: {total_month:,.2f} EGP"
            )

            # ✅ Send message to Microsoft Teams
            payload = {"text": message}
            response = requests.post(teams_webhook_url, json=payload, verify=False)
            if response.status_code == 200:
                print(f"✅ Message sent to Teams for {cash_receipt_id}")
            else:
                print(f"❌ Failed to send message to Teams: {response.status_code}, {response.text}")

            # ✅ Send message via WhatsApp
            from twilio.http.http_client import TwilioHttpClient
            http_client = TwilioHttpClient()
            http_client.session.verify = False  # Bypass SSL Verification

            client = Client(TWILIO_ACCOUNT_SID, TWILIO_AUTH_TOKEN, http_client=http_client)

            for recipient in whatsapp_recipients:
                try:
                    msg = client.messages.create(
                        from_=TWILIO_WHATSAPP_NUMBER,
                        body=message,
                        to=recipient
                    )
                    print(f"✅ WhatsApp message sent to {recipient}: SID {msg.sid}")
                except Exception as e:
                    print(f"❌ Error sending WhatsApp message to {recipient}: {e}")

            # ✅ Update the last recorded transaction
            write_file(last_cash_in_file, f"{cash_receipt_id}|{receipt_date}|{amount_egp}|{(comment or '').strip()}")

    else:
        print("No new cash-in transactions found.")

except oracledb.Error as error:
    print(f"❌ Error connecting to database: {error}")

finally:
    try:
        if 'cursor' in locals() and cursor is not None:
            cursor.close()
    except oracledb.Error as error:
        print(f"❌ Error closing cursor: {error}")

    try:
        if 'connection' in locals() and connection is not None:
            connection.close()
    except oracledb.Error as error:
        print(f"❌ Error closing connection: {error}")
# Out:
# Connecting to the database...
# Connected to the database!
# ✅ Message sent to Teams for 2176287
# ✅ WhatsApp message sent to whatsapp:+201128484442: SID SM1ff3235de306f83b1b173f1b8d2f8589
# ✅ WhatsApp message sent to whatsapp:+201286177055: SID SM71a9df7afaa76a420fd703cdf319ec99
# ✅ WhatsApp message sent to whatsapp:+201286868419: SID SM8cb3ada1f59c5f731a5bcace449350ef
# ✅ Message sent to Teams for 2176288
# ✅ WhatsApp message sent to whatsapp:+201128484442: SID SMd97b1bd3a8a293b1b6afd03a75a70e50
# ✅ WhatsApp message sent to whatsapp:+201286177055: SID SM650988efc75b6415f7a3459bd887baed
# ✅ WhatsApp message sent to whatsapp:+201286868419: SID SMca3e9660b8f427d0487cebfd9299dd73
# ✅ Message sent to Teams for 2176289
# ✅ WhatsApp message sent to whatsapp:+201128484442: SID SM48317c69819c703257303aac204b85d7
# ✅ WhatsApp message sent to whatsapp:+201286177055: SID SM776029f385555cb11b0a0d2981bc9761
# ✅ WhatsApp message sent to whatsapp:+201286868419: SID SM4bfce3077ba1727427ee0d82f01c6486
# ✅ Message sent to Teams for 2176290
# ✅ WhatsApp message sent to whatsapp:+201128484442: SID SM640604e4eb172866b4c72fe11c8021af
# ✅ WhatsApp message sent to whatsapp:+201286177055: SID SM2e630e85964f7671a92affe4d9abc4cf
# ✅ WhatsApp message sent to whatsapp:+201286868419: SID SM4c87819ea5c7aac0a540a171b840c9f7
# ✅ Message sent to Teams for 2177287
# ✅ WhatsApp message sent to whatsapp:+201128484442: SID SM29138ef116efea6d08ec78350d24ccbe
# ✅ WhatsApp message sent to whatsapp:+201286177055: SID SMd7892c4dadfa5e74e2ba23a4db32a7ca
# ❌ Error sending WhatsApp message to whatsapp:+201286868419: HTTP 429 error: Unable to create record: Account AC249bd7ddb87e51ebbbec32eaa5805fc2 exceeded the 1 rps rate limit
# ✅ Message sent to Teams for 2179288
# ✅ WhatsApp message sent to whatsapp:+201128484442: SID SM85987d1dc523007f98c342882c1e5c92
# ✅ WhatsApp message sent to whatsapp:+201286177055: SID SM5e2b216359efc8a82390c0b8f42d0e43
# ❌ Error sending WhatsApp message to whatsapp:+201286868419: HTTP 429 error: Unable to create record: Account AC249bd7ddb87e51ebbbec32eaa5805fc2 exceeded the 1 rps rate limit
# ✅ Message sent to Teams for 2179289
# ✅ WhatsApp message sent to whatsapp:+201128484442: SID SMaa5ddcff98eb4dcae64cd6f013c18fc4
# ❌ Error sending WhatsApp message to whatsapp:+201286177055: HTTP 429 error: Unable to create record: Account AC249bd7ddb87e51ebbbec32eaa5805fc2 exceeded the 1 rps rate limit
# ❌ Error sending WhatsApp message to whatsapp:+201286868419: HTTP 429 error: Unable to create record: Account AC249bd7ddb87e51ebbbec32eaa5805fc2 exceeded the 1 rps rate limit
# ✅ Message sent to Teams for 2180288
# ✅ WhatsApp message sent to whatsapp:+201128484442: SID SM2efb42513928ced7c05e424337933304
# ✅ WhatsApp message sent to whatsapp:+201286177055: SID SMd4f8877a6af24ba52554aa243d4dfdaf
# ✅ WhatsApp message sent to whatsapp:+201286868419: SID SM2cb36081562adb1dc3f426ba17e61c91
# ✅ Message sent to Teams for 2180289
# ✅ WhatsApp message sent to whatsapp:+201128484442: SID SM8950e4a58a69473fd7d2d3ab8693c6c8
# ✅ WhatsApp message sent to whatsapp:+201286177055: SID SMc12b52f08ef50c5081aa8c0071d425f4
# ❌ Error sending WhatsApp message to whatsapp:+201286868419: HTTP 429 error: Unable to create record: Account AC249bd7ddb87e51ebbbec32eaa5805fc2 exceeded the null daily messages limit
# ✅ Message sent to Teams for 2180293
# ✅ WhatsApp message sent to whatsapp:+201128484442: SID SM7b859350ef9bef937cd30076d5977a48
# ✅ WhatsApp message sent to whatsapp:+201286177055: SID SM5c8c5d4f57ab9859206a99c345bcec68
# ❌ Error sending WhatsApp message to whatsapp:+201286868419: HTTP 429 error: Unable to create record: Account AC249bd7ddb87e51ebbbec32eaa5805fc2 exceeded the 1 rps rate limit
# ✅ Message sent to Teams for 2180297
# ✅ WhatsApp message sent to whatsapp:+201128484442: SID SM3be1746e95dfd332fdc82762d05c7354
# ❌ Error sending WhatsApp message to whatsapp:+201286177055: HTTP 429 error: Unable to create record: Account AC249bd7ddb87e51ebbbec32eaa5805fc2 exceeded the null daily messages limit
# ❌ Error sending WhatsApp message to whatsapp:+201286868419: HTTP 429 error: Unable to create record: Account AC249bd7ddb87e51ebbbec32eaa5805fc2 exceeded the null daily messages limit
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 274
#     271                 print(f"❌ Error sending WhatsApp message to {recipient}: {e}")
#     273         # ✅ Update the last recorded transaction
# --> 274         write_file(last_cash_in_file, f"{cash_receipt_id}|{receipt_date}|{amount_egp}|{comment.strip()}")
#     276 else:
#     277     print("No new cash-in transactions found.")
#
# AttributeError: 'NoneType' object has no attribute 'strip'
