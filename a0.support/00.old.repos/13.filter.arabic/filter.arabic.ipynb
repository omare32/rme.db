# %%
import pandas as pd

# %%
df=pd.read_csv('RME_Material_Movement_with_cos_090623.csv',encoding='utf-8-sig')
df
# Out:
#           Item Code                            Item Desc  Uom  \
# 0     ZC03001372                       بريزة خارج الحائط  ECH
# 1     ZC03001366                 لاكور ماسورة 1 بوصة EMT  ECH
# 2     ZC01003004            كارت فحص دورى لطفايات الحريق  ECH
# 3     ZC03001365     لاكور ماسورة على فلكسبيل 1 بوصة EMT  ECH
# 4     ZC01003003                               مثلث عاكس  ECH
# ...             ...                                  ...  ...
# 5082            NaN                                  NaN  NaN
# 5083            NaN                                  NaN  NaN
# 5084            NaN                                  NaN  NaN
# 5085            NaN                                  NaN  NaN
# 5086    Page 1 of 1                                  NaN  NaN
#
#                          From   To             Project  Project Num  \
# 0     El Khatatba Bridge-0143  NaN  El Khatatba Bridge        143.0
# 1     El Khatatba Bridge-0143  NaN  El Khatatba Bridge        143.0
# ...

# %%
df[df['Item Desc'].str.contains('حامل كارت ')==True]
# Out:
#         Item Code        Item Desc  Uom                     From   To  \
# 7   ZC01003005     حامل كارت سقالة  ECH  El Khatatba Bridge-0143  NaN
# 8   ZC01003005     حامل كارت سقالة  ECH  El Khatatba Bridge-0143  NaN
# 13  ZC01003005     حامل كارت سقالة  ECH  El Khatatba Bridge-0143  NaN
#
#                Project  Project Num      Trx Id Exp id Task Num  ...  \
# 7   El Khatatba Bridge        143.0  55172133.0    NaN    SE-19  ...
# 8   El Khatatba Bridge        143.0  56542380.0    NaN    SE-19  ...
# 13  El Khatatba Bridge        143.0  51447493.0    NaN    SE-19  ...
#
#                        Trx Type Move Order Num       Date  Unit Cost  \
# 7   Move Order Issue on Project      RE3-58     21-Aug-22          0
# 8   Move Order Issue on Project      RE3-68     09-Oct-22          0
# 13  Move Order Issue on Project      RE3-40     31-Mar-22          0
#
#    Quantities Po Num Total Amount Project Area  Issued Type  Comment
# ...

# %%
df['Item Desc'].str.contains('حامل كارت ')!=True
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 5082    True
# 5083    True
# 5084    True
# 5085    True
# 5086    True
# Name: Item Desc, Length: 5087, dtype: bool
