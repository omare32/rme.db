# %%
import pandas as pd

# %%
df=pd.read_csv('RME_Material_Movement_with_cos_090623.csv',encoding='utf-8-sig')
df
# Out:
#           Item Code                            Item Desc  Uom  \
# 0     ZC03001372                       بريزة خارج الحائط  ECH
# 1     ZC03001366                 لاكور ماسورة 1 بوصة EMT  ECH
# 2     ZC01003004            كارت فحص دورى لطفايات الحريق  ECH
# 3     ZC03001365     لاكور ماسورة على فلكسبيل 1 بوصة EMT  ECH
# 4     ZC01003003                               مثلث عاكس  ECH
# ...             ...                                  ...  ...
# 5082            NaN                                  NaN  NaN
# 5083            NaN                                  NaN  NaN
# 5084            NaN                                  NaN  NaN
# 5085            NaN                                  NaN  NaN
# 5086    Page 1 of 1                                  NaN  NaN
#
#                          From   To             Project  Project Num  \
# 0     El Khatatba Bridge-0143  NaN  El Khatatba Bridge        143.0
# 1     El Khatatba Bridge-0143  NaN  El Khatatba Bridge        143.0
# 2     El Khatatba Bridge-0143  NaN  El Khatatba Bridge        143.0
# 3     El Khatatba Bridge-0143  NaN  El Khatatba Bridge        143.0
# 4     El Khatatba Bridge-0143  NaN  El Khatatba Bridge        143.0
# ...                       ...  ...                 ...          ...
# 5082                      NaN  NaN                 NaN          NaN
# 5083                      NaN  NaN                 NaN          NaN
# 5084                      NaN  NaN                 NaN          NaN
# 5085                      NaN  NaN                 NaN          NaN
# 5086                      NaN  NaN                 NaN          NaN
#
#           Trx Id Exp id Task Num  ...                     Trx Type  \
# 0     47336739.0    NaN    SE-19  ...  Move Order Issue on Project
# 1     50612566.0    NaN    SE-19  ...  Move Order Issue on Project
# 2     58920590.0    NaN    SE-19  ...  Move Order Issue on Project
# 3     50612565.0    NaN    SE-19  ...  Move Order Issue on Project
# 4     61735684.0    NaN    SE-19  ...  Move Order Issue on Project
# ...          ...    ...      ...  ...                          ...
# 5082         NaN    NaN      NaN  ...                          NaN
# 5083         NaN    NaN      NaN  ...                          NaN
# 5084         NaN    NaN      NaN  ...                          NaN
# 5085         NaN    NaN      NaN  ...                          NaN
# 5086         NaN    NaN      NaN  ...                          NaN
#
#      Move Order Num       Date  Unit Cost Quantities Po Num Total Amount  \
# 0         RE3-23     28-Dec-21          0       -3.0    NaN            0
# 1         RE3-33     28-Feb-22          0       -5.0    NaN            0
# 2         RE3-81     25-Dec-22          0       -5.0    NaN            0
# 3         RE3-33     28-Feb-22          0      -10.0    NaN            0
# 4        RE3-100     08-May-23          0       -1.0    NaN            0
# ...             ...        ...        ...        ...    ...          ...
# 5082            NaN        NaN        NaN        NaN    NaN          NaN
# 5083            NaN        NaN        NaN        NaN    NaN          NaN
# 5084            NaN        NaN        NaN        NaN    NaN          NaN
# 5085            NaN        NaN        NaN        NaN    NaN          NaN
# 5086            NaN        NaN        NaN        NaN    NaN          NaN
#
#      Project Area  Issued Type  Comment
# 0             NaN     supplier      NaN
# 1             NaN     supplier      NaN
# 2             NaN          NaN      NaN
# 3             NaN     supplier      NaN
# 4             NaN          NaN      NaN
# ...           ...          ...      ...
# 5082          NaN          NaN      NaN
# 5083          NaN          NaN      NaN
# 5084          NaN          NaN      NaN
# 5085          NaN          NaN      NaN
# 5086          NaN          NaN      NaN
#
# [5087 rows x 24 columns]

# %%
df = df[df['Item Desc'].str.contains('حديد تسليح')==True]
df
# Out:
#             Item Code                                  Item Desc  Uom  \
# 56    150010000008                          حديد تسليح قطر 25 مم  TON
# 57    150010000007                          حديد تسليح قطر 22 مم  TON
# 58    150010000004                          حديد تسليح قطر 16 مم  TON
# 59    150010000001                           حديد تسليح قطر 10مم  TON
# 83    150010000001                           حديد تسليح قطر 10مم  TON
# ...               ...                                        ...  ...
# 4995  150010000002                          حديد تسليح قطر 12 مم  TON
# 5006  150010000004                          حديد تسليح قطر 16 مم  TON
# 5007  150010000002                          حديد تسليح قطر 12 مم  TON
# 5036  150080000071     حديد تسليح قطر 22 مم طول 1.5 متر  Cut Off  TON
# 5067  150010000001                           حديد تسليح قطر 10مم  TON
#
#                          From                       To             Project  \
# 56    El Khatatba Bridge-0143                      NaN  El Khatatba Bridge
# 57    El Khatatba Bridge-0143                      NaN  El Khatatba Bridge
# 58    El Khatatba Bridge-0143                      NaN  El Khatatba Bridge
# 59    El Khatatba Bridge-0143                      NaN  El Khatatba Bridge
# 83    El Khatatba Bridge-0143                      NaN  El Khatatba Bridge
# ...                       ...                      ...                 ...
# 4995  El Khatatba Bridge-0143    RING ROAD BRIDGE-0122  El Khatatba Bridge
# 5006  El Khatatba Bridge-0143  Abou Ghaleb Bridge-0157  El Khatatba Bridge
# 5007  El Khatatba Bridge-0143  Abou Ghaleb Bridge-0157  El Khatatba Bridge
# 5036  El Khatatba Bridge-0143    The Open Channel-0160  El Khatatba Bridge
# 5067                      NaN                      NaN                 NaN
#
#       Project Num      Trx Id   Exp id Task Num  ...            Trx Type  \
# 56          143.0  41117286.0      NaN      302  ...          PO Receipt
# 57          143.0  41117290.0      NaN      302  ...          PO Receipt
# 58          143.0  41117294.0      NaN      302  ...          PO Receipt
# 59          143.0  41117298.0      NaN      302  ...          PO Receipt
# 83          143.0  42729027.0      NaN      302  ...          PO Receipt
# ...           ...         ...      ...      ...  ...                 ...
# 4995        143.0  45409900.0      NaN      NaN  ...  Intransit Shipment
# 5006        143.0  51816334.0      NaN      NaN  ...  Intransit Shipment
# 5007        143.0  51913690.0      NaN      NaN  ...  Intransit Shipment
# 5036        143.0  57616201.0      NaN      NaN  ...  Intransit Shipment
# 5067          NaN  46180017.0  2112866      NaN  ...     RME Site Return
#
#      Move Order Num       Date  Unit Cost Quantities   Po Num Total Amount  \
# 56                   29-Jun-21  14,500.00     67.360  51791.0      976,720
# 57                   29-Jun-21  14,500.00     50.640  51791.0      734,280
# 58                   29-Jun-21  14,500.00      5.860  51791.0       84,970
# 59                   29-Jun-21  14,500.00     15.460  51791.0      224,170
# 83                   21-Aug-21  14,500.00     10.660  51791.0      154,570
# ...             ...        ...        ...        ...      ...          ...
# 4995                 17-Nov-21  14,698.76    -20.000      NaN     -293,975
# 5006                 20-Apr-22  19,630.17     -8.000      NaN     -157,041
# 5007                 24-Apr-22  17,973.58    -12.000      NaN     -215,683
# 5036                 15-Nov-22  18,070.00     -0.737      NaN      -13,318
# 5067                 09-Dec-21  14,500.00      2.500      NaN       36,250
#
#      Project Area  Issued Type  Comment
# 56            NaN          NaN      NaN
# 57            NaN          NaN      NaN
# 58            NaN          NaN      NaN
# 59            NaN          NaN      NaN
# 83            NaN          NaN      NaN
# ...           ...          ...      ...
# 4995          NaN          NaN      NaN
# 5006          NaN          NaN      NaN
# 5007          NaN          NaN      NaN
# 5036          NaN          NaN      NaN
# 5067          NaN          NaN      NaN
#
# [474 rows x 24 columns]
