# %%
import pandas as pd
import numpy as np

data=np.random.randn(4,5)
df=pd.DataFrame(data,columns=['col1','col2','col3','col4','col5'])
df
# Out:
#        col1      col2      col3      col4      col5
# 0 -0.427612 -0.004456  2.182775  1.800414  0.784889
# 1 -0.957508  2.261697  0.154416 -0.250035  0.332984
# 2  0.868438  1.011414  0.094211 -0.098065  1.737322
# 3  1.026685  0.441932  0.992208  0.190548  1.259778

# %%
data
# Out:
# array([[-0.42761205, -0.00445578,  2.18277497,  1.80041406,  0.78488906],
#        [-0.95750833,  2.26169659,  0.15441616, -0.25003527,  0.33298421],
#        [ 0.86843823,  1.0114145 ,  0.09421098, -0.09806487,  1.73732194],
#        [ 1.02668524,  0.44193226,  0.99220836,  0.19054778,  1.259778  ]])

# %%
df[['col1']]
# Out:
#        col1
# 0 -0.427612
# 1 -0.957508
# 2  0.868438
# 3  1.026685

# %%
df['col1']
# Out:
# 0   -0.427612
# 1   -0.957508
# 2    0.868438
# 3    1.026685
# Name: col1, dtype: float64

# %%
type(df['col1'])
# Out:
# pandas.core.series.Series

# %%
df[['col1','col4']]
# Out:
#        col1      col4
# 0 -0.427612  1.800414
# 1 -0.957508 -0.250035
# 2  0.868438 -0.098065
# 3  1.026685  0.190548

# %%
df['col6']=[12,33,5,22]

# %%
df
# Out:
#        col1      col2      col3      col4      col5  col6
# 0 -0.427612 -0.004456  2.182775  1.800414  0.784889    12
# 1 -0.957508  2.261697  0.154416 -0.250035  0.332984    33
# 2  0.868438  1.011414  0.094211 -0.098065  1.737322     5
# 3  1.026685  0.441932  0.992208  0.190548  1.259778    22

# %%
df['col7']=df['col6']+5
df
# Out:
#        col1      col2      col3      col4      col5  col6  col7
# 0 -0.427612 -0.004456  2.182775  1.800414  0.784889    12    17
# 1 -0.957508  2.261697  0.154416 -0.250035  0.332984    33    38
# 2  0.868438  1.011414  0.094211 -0.098065  1.737322     5    10
# 3  1.026685  0.441932  0.992208  0.190548  1.259778    22    27

# %%
df['col7']=df['col1']+df['col2']

# %%
df
# Out:
#        col1      col2      col3      col4      col5  col6      col7
# 0 -0.427612 -0.004456  2.182775  1.800414  0.784889    12 -0.432068
# 1 -0.957508  2.261697  0.154416 -0.250035  0.332984    33  1.304188
# 2  0.868438  1.011414  0.094211 -0.098065  1.737322     5  1.879853
# 3  1.026685  0.441932  0.992208  0.190548  1.259778    22  1.468617

# %%
df.drop('col2',axis=1,inplace=True)

# %%
df
# Out:
#        col1      col3      col4      col5  col6      col7
# 0 -0.427612  2.182775  1.800414  0.784889    12 -0.432068
# 1 -0.957508  0.154416 -0.250035  0.332984    33  1.304188
# 2  0.868438  0.094211 -0.098065  1.737322     5  1.879853
# 3  1.026685  0.992208  0.190548  1.259778    22  1.468617

# %%
df.drop(['col1','col7'],axis=1)
# Out:
#        col3      col4      col5  col6
# 0  2.182775  1.800414  0.784889    12
# 1  0.154416 -0.250035  0.332984    33
# 2  0.094211 -0.098065  1.737322     5
# 3  0.992208  0.190548  1.259778    22

# %%
df
# Out:
#        col1      col3      col4      col5  col6      col7
# 0 -0.427612  2.182775  1.800414  0.784889    12 -0.432068
# 1 -0.957508  0.154416 -0.250035  0.332984    33  1.304188
# 2  0.868438  0.094211 -0.098065  1.737322     5  1.879853
# 3  1.026685  0.992208  0.190548  1.259778    22  1.468617

# %%
df.corr()
# Out:
#           col1      col3      col4      col5      col6      col7
# col1  1.000000 -0.146548 -0.228251  0.918213 -0.533021  0.516073
# col3 -0.146548  1.000000  0.964909 -0.194169 -0.225350 -0.911161
# col4 -0.228251  0.964909  1.000000 -0.169444 -0.362344 -0.948341
# col5  0.918213 -0.194169 -0.169444  1.000000 -0.779632  0.469075
# col6 -0.533021 -0.225350 -0.362344 -0.779632  1.000000  0.096206
# col7  0.516073 -0.911161 -0.948341  0.469075  0.096206  1.000000

# %%
df
# Out:
#        col1      col3      col4      col5  col6      col7
# 0 -0.427612  2.182775  1.800414  0.784889    12 -0.432068
# 1 -0.957508  0.154416 -0.250035  0.332984    33  1.304188
# 2  0.868438  0.094211 -0.098065  1.737322     5  1.879853
# 3  1.026685  0.992208  0.190548  1.259778    22  1.468617

# %%
df['col3']
# Out:
# 0    2.182775
# 1    0.154416
# 2    0.094211
# 3    0.992208
# Name: col3, dtype: float64

# %%
df.loc[2]
# Out:
# col1    0.868438
# col3    0.094211
# col4   -0.098065
# col5    1.737322
# col6    5.000000
# col7    1.879853
# Name: 2, dtype: float64

# %%
df.loc[[2]]
# Out:
#        col1      col3      col4      col5  col6      col7
# 2  0.868438  0.094211 -0.098065  1.737322     5  1.879853

# %%
df.loc[[1,3]]
# Out:
#        col1      col3      col4      col5  col6      col7
# 1 -0.957508  0.154416 -0.250035  0.332984    33  1.304188
# 3  1.026685  0.992208  0.190548  1.259778    22  1.468617

# %%
df.loc[1:3]
# Out:
#        col1      col3      col4      col5  col6      col7
# 1 -0.957508  0.154416 -0.250035  0.332984    33  1.304188
# 2  0.868438  0.094211 -0.098065  1.737322     5  1.879853
# 3  1.026685  0.992208  0.190548  1.259778    22  1.468617

# %%
df.loc[1]
# Out:
# col1    -0.957508
# col3     0.154416
# col4    -0.250035
# col5     0.332984
# col6    33.000000
# col7     1.304188
# Name: 1, dtype: float64

# %%
df.loc[2,'col3']
# Out:
# 0.09421098403928549

# %%
df.loc[[1,3]]
# Out:
#        col1      col3      col4      col5  col6      col7
# 1 -0.957508  0.154416 -0.250035  0.332984    33  1.304188
# 3  1.026685  0.992208  0.190548  1.259778    22  1.468617

# %%
df.loc[[1,3],'col3']
# Out:
# 1    0.154416
# 3    0.992208
# Name: col3, dtype: float64

# %%
df.loc[1:3,['col3','col7']]
# Out:
#        col3      col7
# 1  0.154416  1.304188
# 2  0.094211  1.879853
# 3  0.992208  1.468617

# %%
df.loc[[1,3],['col3','col7']]
# Out:
#        col3      col7
# 1  0.154416  1.304188
# 3  0.992208  1.468617

# %%
df=pd.DataFrame(data,columns=['col1','col2','col3','col4','col5'],index=['a','b','c','d'])
df
# Out:
#        col1      col2      col3      col4      col5
# a -0.427612 -0.004456  2.182775  1.800414  0.784889
# b -0.957508  2.261697  0.154416 -0.250035  0.332984
# c  0.868438  1.011414  0.094211 -0.098065  1.737322
# d  1.026685  0.441932  0.992208  0.190548  1.259778

# %%
df.loc['b']
# Out:
# col1   -0.957508
# col2    2.261697
# col3    0.154416
# col4   -0.250035
# col5    0.332984
# Name: b, dtype: float64

# %%
df.iloc[1]
# Out:
# col1   -0.957508
# col2    2.261697
# col3    0.154416
# col4   -0.250035
# col5    0.332984
# Name: b, dtype: float64

# %%
df.loc['d']=[12,4,2,7,99]
df
# Out:
#         col1      col2      col3      col4       col5
# a  -0.427612 -0.004456  2.182775  1.800414   0.784889
# b  -0.957508  2.261697  0.154416 -0.250035   0.332984
# c   0.868438  1.011414  0.094211 -0.098065   1.737322
# d  12.000000  4.000000  2.000000  7.000000  99.000000

# %%
df.loc['e']=df.loc['a']*2
df
# Out:
#         col1      col2      col3      col4       col5
# a  -0.427612 -0.004456  2.182775  1.800414   0.784889
# b  -0.957508  2.261697  0.154416 -0.250035   0.332984
# c   0.868438  1.011414  0.094211 -0.098065   1.737322
# d  12.000000  4.000000  2.000000  7.000000  99.000000
# e  -0.855224 -0.008912  4.365550  3.600828   1.569778

# %%
df.drop('c',axis=0,inplace=True)

# %%
df
# Out:
#         col1      col2      col3      col4       col5
# a  -0.427612 -0.004456  2.182775  1.800414   0.784889
# b  -0.957508  2.261697  0.154416 -0.250035   0.332984
# d  12.000000  4.000000  2.000000  7.000000  99.000000
# e  -0.855224 -0.008912  4.365550  3.600828   1.569778

# %%
df[df>0]
# Out:
#    col1      col2      col3      col4       col5
# a   NaN       NaN  2.182775  1.800414   0.784889
# b   NaN  2.261697  0.154416       NaN   0.332984
# d  12.0  4.000000  2.000000  7.000000  99.000000
# e   NaN       NaN  4.365550  3.600828   1.569778

# %%
df[df['col1']>0]
# Out:
#    col1  col2  col3  col4  col5
# d  12.0   4.0   2.0   7.0  99.0

# %%
df[df['col2']<0]
# Out:
#        col1      col2      col3      col4      col5
# a -0.427612 -0.004456  2.182775  1.800414  0.784889
# e -0.855224 -0.008912  4.365550  3.600828  1.569778

# %%
df[(df['col1']<0 ) & (df['col2']>0)]
# Out:
#        col1      col2      col3      col4      col5
# b -0.957508  2.261697  0.154416 -0.250035  0.332984

# %%
df[(df['col1']<0 ) | (df['col2']>0)]
# Out:
#         col1      col2      col3      col4       col5
# a  -0.427612 -0.004456  2.182775  1.800414   0.784889
# b  -0.957508  2.261697  0.154416 -0.250035   0.332984
# d  12.000000  4.000000  2.000000  7.000000  99.000000
# e  -0.855224 -0.008912  4.365550  3.600828   1.569778

# %%
df[ ~(df['col2']>0)]
# Out:
#        col1      col2      col3      col4      col5
# a -0.427612 -0.004456  2.182775  1.800414  0.784889
# e -0.855224 -0.008912  4.365550  3.600828  1.569778

# %%
df[~((df['col1']<0 ) & (df['col2']>0))]
# Out:
#         col1      col2      col3      col4       col5
# a  -0.427612 -0.004456  2.182775  1.800414   0.784889
# d  12.000000  4.000000  2.000000  7.000000  99.000000
# e  -0.855224 -0.008912  4.365550  3.600828   1.569778

# %%
df=pd.read_csv('C:/Users/Administrator/Downloads/Epsilon/Rowad/Session 22/data/Ecommerce Purchases.csv')
df
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
df.head(10)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5  7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 6     93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 7  260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 8            2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# 9    3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# ...

# %%
df.tail(10)
# Out:
#                                                 Address    Lot AM or PM  \
# 9990  75731 Molly Springs\nWest Danielle, VT 96934-5102  93 ty       PM
# 9991              PSC 8165, Box 8498\nAPO AP 60327-0346  50 dA       AM
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH       PM
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  72 jg       PM
# 9994       6276 Rojas Hollow\nLake Louis, WY 56410-7837  93 Ex       PM
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# 9990  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_4;...
# 9991  Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...
# ...

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
df.isnull().sum()
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
df.columns=df.columns.str.lower().str.replace(' ','_')
df
# Out:
#                                                 address    lot am_or_pm  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            browser_info  \
# ...

# %%
df.columns
# Out:
# Index(['address', 'lot', 'am_or_pm', 'browser_info', 'company', 'credit_card',
#        'cc_exp_date', 'cc_security_code', 'cc_provider', 'email', 'job',
#        'ip_address', 'language', 'purchase_price'],
#       dtype='object')

# %%
df['purchase_price']
# Out:
# 0       98.14
# 1       70.73
# 2        0.95
# 3       78.04
# 4       77.82
#         ...
# 9995    82.21
# 9996    25.63
# 9997    83.98
# 9998    38.84
# 9999    67.59
# Name: purchase_price, Length: 10000, dtype: float64

# %%
df.describe()
# Out:
#         credit_card  cc_security_code  purchase_price
# count  1.000000e+04      10000.000000    10000.000000
# mean   2.341374e+15        907.217800       50.347302
# std    2.256103e+15       1589.693035       29.015836
# min    6.040186e+10          0.000000        0.000000
# 25%    3.056322e+13        280.000000       25.150000
# 50%    8.699942e+14        548.000000       50.505000
# 75%    4.492298e+15        816.000000       75.770000
# max    6.012000e+15       9993.000000       99.990000

# %%
df['purchase_price'].mean()
# Out:
# 50.347302

# %%
df['purchase_price'].std()
# Out:
# 29.015836309789048

# %%
df['purchase_price'].max()
# Out:
# 99.99

# %%
df['purchase_price'].median()
# Out:
# 50.504999999999995

# %%
df['job'].unique()
# Out:
# array(['Scientist, product/process development', 'Drilling engineer',
#        'Customer service manager', 'Fine artist', 'Fish farm manager',
#        'Dancer', 'Event organiser', 'Financial manager',
#        'Forensic scientist', 'Development worker, community',
#        'Diagnostic radiographer', 'Surveyor, quantity',
#        'Accountant, chartered public finance', 'Acupuncturist',
#        'Retail manager', 'Therapist, art', 'Designer, jewellery',
#        'Photographer', 'Designer, interior/spatial',
#        'Public relations officer', 'Presenter, broadcasting',
#        'Field seismologist', 'Musician',
#        'Training and development officer', "Barrister's clerk",
#        'Careers adviser', 'Scientist, research (life sciences)',
#        'Recycling officer', 'Fisheries officer', 'Sales executive',
#        'Civil Service fast streamer', 'Theatre stage manager',
#        'Therapist, music', 'Lecturer, further education',
# ...

# %%
df.job.nunique()
# Out:
# 623

# %%
df.job.value_counts()
# Out:
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Purchasing manager               27
# Designer, jewellery              27
#                                  ..
# Prison officer                    7
# Editor, film/video                6
# Actuary                           6
# Information systems manager       5
# Investment analyst                5
# Name: job, Length: 623, dtype: int64

# %%
df.job.value_counts().head(10)
# Out:
# Interior and spatial designer        31
# Lawyer                               30
# Social researcher                    28
# Purchasing manager                   27
# Designer, jewellery                  27
# Research officer, political party    27
# Charity fundraiser                   26
# Designer, fashion/clothing           26
# Social worker                        26
# Dietitian                            26
# Name: job, dtype: int64

# %%
dt_un=df.job.value_counts().reset_index()
dt_un
# Out:
#                              index  job
# 0    Interior and spatial designer   31
# 1                           Lawyer   30
# 2                Social researcher   28
# 3               Purchasing manager   27
# 4              Designer, jewellery   27
# ..                             ...  ...
# 618                 Prison officer    7
# 619             Editor, film/video    6
# 620                        Actuary    6
# 621    Information systems manager    5
# 622             Investment analyst    5
#
# [623 rows x 2 columns]

# %%
dt_un.to_csv('job_freq.csv')

# %%
df[['job','purchase_price']].sort_values('purchase_price',ascending=False)
# Out:
#                                         job  purchase_price
# 2092                 Surveyor, hydrographic           99.99
# 7807                    Surveyor, insurance           99.99
# 9856                          Site engineer           99.97
# 7604                Teacher, primary school           99.95
# 3844             Television camera operator           99.93
# ...                                     ...             ...
# 2783                             IT trainer            0.02
# 8656  Product/process development scientist            0.02
# 6863             Television camera operator            0.01
# 2876                   Biomedical scientist            0.00
# 5487                          Stage manager            0.00
#
# [10000 rows x 2 columns]

# %%
df.groupby('job').purchase_price.sum()
# Out:
# job
# Academic librarian                   527.47
# Accommodation manager                629.65
# Accountant, chartered               1051.31
# Accountant, chartered certified     1043.01
# Accountant, chartered management    1036.24
#                                      ...
# Water quality scientist              837.47
# Web designer                        1195.29
# Wellsite geologist                  1231.42
# Writer                               448.63
# Youth worker                         729.24
# Name: purchase_price, Length: 623, dtype: float64

# %%
df_jobs_agg=df.groupby('job').purchase_price.sum().reset_index()
df_jobs_agg
# Out:
#                                   job  purchase_price
# 0                  Academic librarian          527.47
# 1               Accommodation manager          629.65
# 2               Accountant, chartered         1051.31
# 3     Accountant, chartered certified         1043.01
# 4    Accountant, chartered management         1036.24
# ..                                ...             ...
# 618           Water quality scientist          837.47
# 619                      Web designer         1195.29
# 620                Wellsite geologist         1231.42
# 621                            Writer          448.63
# 622                      Youth worker          729.24
#
# [623 rows x 2 columns]

# %%
df_jobs_agg.sort_values('purchase_price',ascending=False).reset_index().drop('index',axis=1)
# Out:
#                              job  purchase_price
# 0                      Dietitian         1605.30
# 1                         Lawyer         1603.85
# 2             Purchasing manager         1577.97
# 3                 Therapist, art         1526.31
# 4        Clinical cytogeneticist         1495.92
# ..                           ...             ...
# 618              Music therapist          327.50
# 619                      Actuary          262.72
# 620  Information systems manager          241.42
# 621          Marketing executive          234.08
# 622          Art gallery manager          219.05
#
# [623 rows x 2 columns]

# %%
df_jobs_agg=df_jobs_agg.sort_values('purchase_price',ascending=False).reset_index().drop('index',axis=1)

# %%
df_jobs_agg
# Out:
#                              job  purchase_price
# 0                      Dietitian         1605.30
# 1                         Lawyer         1603.85
# 2             Purchasing manager         1577.97
# 3                 Therapist, art         1526.31
# 4        Clinical cytogeneticist         1495.92
# ..                           ...             ...
# 618              Music therapist          327.50
# 619                      Actuary          262.72
# 620  Information systems manager          241.42
# 621          Marketing executive          234.08
# 622          Art gallery manager          219.05
#
# [623 rows x 2 columns]

# %%
df
# Out:
#                                                 address    lot am_or_pm  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            browser_info  \
# ...

# %%
df.purchase_price.mean()
# Out:
# 50.347302

# %%
df.purchase_price.min(),df.purchase_price.max()
# Out:
# (0.0, 99.99)

# %%
df.language.value_counts()['en']
# Out:
# 1098

# %%
len(df[df['job']=='Lawyer'])
# Out:
# 30

# %%
df.am_or_pm.value_counts()['PM'],df.am_or_pm.value_counts()['AM']
# Out:
# (5068, 4932)

# %%
list(df.am_or_pm.value_counts().values)
# Out:
# [5068, 4932]

# %%
list(df.job.value_counts().head(5).index)
# Out:
# ['Interior and spatial designer',
#  'Lawyer',
#  'Social researcher',
#  'Purchasing manager',
#  'Designer, jewellery']

# %%
df[df['lot']=='90 WT'].purchase_price.values[0]
# Out:
# 75.1

# %%
df[df['credit_card']==4926535242672853].email.values[0]
# Out:
# 'bondellen@williams-garza.com'

# %%
df['credit_card']=df['credit_card'].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   address           10000 non-null  object
#  1   lot               10000 non-null  object
#  2   am_or_pm          10000 non-null  object
#  3   browser_info      10000 non-null  object
#  4   company           10000 non-null  object
#  5   credit_card       10000 non-null  int64
#  6   cc_exp_date       10000 non-null  object
#  7   cc_security_code  10000 non-null  int64
#  8   cc_provider       10000 non-null  object
#  9   email             10000 non-null  object
#  10  job               10000 non-null  object
#  11  ip_address        10000 non-null  object
#  12  language          10000 non-null  object
#  13  purchase_price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
df.cc_provider
# Out:
# 0                      JCB 16 digit
# 1                        Mastercard
# 2                      JCB 16 digit
# 3                          Discover
# 4       Diners Club / Carte Blanche
#                    ...
# 9995                   JCB 15 digit
# 9996                   JCB 16 digit
# 9997                  VISA 16 digit
# 9998               American Express
# 9999                   JCB 15 digit
# Name: cc_provider, Length: 10000, dtype: object

# %%
len(df[(df['cc_provider']=='American Express')&(df.purchase_price > 95)])
# Out:
# 39

# %%
df.cc_exp_date
# Out:
# 0       02/20
# 1       11/18
# 2       08/19
# 3       02/24
# 4       10/25
#         ...
# 9995    03/22
# 9996    07/25
# 9997    05/21
# 9998    11/17
# 9999    02/19
# Name: cc_exp_date, Length: 10000, dtype: object

# %%
df2=pd.read_csv('bikes.csv')
df2
# Out:
#                   datetime  season  holiday  workingday weather   temp  \
# 0      2011-01-01 00:00:00  Spring      0.0         0.0   Clear   9.84
# 1      2011-01-01 01:00:00  Spring      0.0         0.0     NaN   9.02
# 2      2011-01-01 02:00:00  Spring      0.0         0.0   Clear   9.02
# 3      2011-01-01 03:00:00  Spring      0.0         0.0   Clear   9.84
# 4      2011-01-01 04:00:00     NaN      0.0         0.0   Clear    NaN
# ...                    ...     ...      ...         ...     ...    ...
# 10881  2012-12-19 19:00:00  Winter      0.0         1.0   Clear  15.58
# 10882  2012-12-19 20:00:00  Winter      0.0         1.0     NaN  14.76
# 10883  2012-12-19 21:00:00     NaN      0.0         1.0   Clear  13.94
# 10884  2012-12-19 22:00:00  Winter      NaN         1.0   Clear  13.94
# 10885  2012-12-19 23:00:00  Winter      0.0         1.0   Clear  13.12
#
#        humidity  windspeed  casual  registered  rented_bikes_count
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   datetime            10886 non-null  object
#  1   season              10672 non-null  object
#  2   holiday             10030 non-null  float64
#  3   workingday          9388 non-null   float64
#  4   weather             8746 non-null   object
#  5   temp                8104 non-null   float64
#  6   humidity            7462 non-null   float64
#  7   windspeed           6820 non-null   float64
#  8   casual              10886 non-null  int64
#  9   registered          10886 non-null  int64
#  10  rented_bikes_count  10886 non-null  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 935.6+ KB

# %%
df2['datetime']=pd.to_datetime(df2['datetime'])

# %%
df2['datetime'].dt.day_name()
# Out:
# 0         Saturday
# 1         Saturday
# 2         Saturday
# 3         Saturday
# 4         Saturday
#            ...
# 10881    Wednesday
# 10882    Wednesday
# 10883    Wednesday
# 10884    Wednesday
# 10885    Wednesday
# Name: datetime, Length: 10886, dtype: object

# %%
df['cc_exp_date'].apply(lambda x: x.split('/')[1]=='25').sum()
# Out:
# 1033

# %%
df['cc_dd']=pd.to_datetime(df['cc_exp_date'],format='%m/%y')

# %%
df[['cc_exp_date','cc_dd']]
# Out:
#      cc_exp_date      cc_dd
# 0          02/20 2020-02-01
# 1          11/18 2018-11-01
# 2          08/19 2019-08-01
# 3          02/24 2024-02-01
# 4          10/25 2025-10-01
# ...          ...        ...
# 9995       03/22 2022-03-01
# 9996       07/25 2025-07-01
# 9997       05/21 2021-05-01
# 9998       11/17 2017-11-01
# 9999       02/19 2019-02-01
#
# [10000 rows x 2 columns]

# %%
len(df[df['cc_dd'].dt.year==2025])
# Out:
# 1033

# %%
list(df.email.apply(lambda x: x.split('@')[1]).value_counts().head(5).index)
# Out:
# ['hotmail.com', 'yahoo.com', 'gmail.com', 'smith.com', 'williams.com']

# %%
df['email_provider']=df['email'].apply(lambda x: x.split('@')[1])
df[['email','email_provider']]
# Out:
#                                email        email_provider
# 0                  pdunlap@yahoo.com             yahoo.com
# 1                 anthony41@reed.com              reed.com
# 2     amymiller@morales-harrison.com  morales-harrison.com
# 3        brent16@olson-robinson.info   olson-robinson.info
# 4        christopherwright@gmail.com             gmail.com
# ...                              ...                   ...
# 9995          iscott@wade-garner.com       wade-garner.com
# 9996              mary85@hotmail.com           hotmail.com
# 9997               tyler16@gmail.com             gmail.com
# 9998         elizabethmoore@reid.net              reid.net
# 9999           rachelford@vaughn.com            vaughn.com
#
# [10000 rows x 2 columns]

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3'],
                        'C': ['C0', 'C1', 'C2', 'C3'],
                        'D': ['D0', 'D1', 'D2', 'D3']},
                        index=[0, 1, 2, 3])

df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                        'B': ['B4', 'B5', 'B6', 'B7'],
                        'C': ['C4', 'C5', 'C6', 'C7'],
                        'D': ['D4', 'D5', 'D6', 'D7']},
                         index=[4, 5, 6, 7]) 

df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                        'B': ['B8', 'B9', 'B10', 'B11'],
                        'C': ['C8', 'C9', 'C10', 'C11'],
                        'D': ['D8', 'D9', 'D10', 'D11']},
                        index=[8, 9, 10, 11])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
new_df = pd.concat([df1,df2,df3], axis=0)
new_df
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
left = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})
   
right = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                          'C': ['C0', 'C1', 'C2', 'C3'],
                          'D': ['D0', 'D1', 'D2', 'D3']})  

left
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
right
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %%
pd.merge(left, right, how='left', on='key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
left = pd.DataFrame({'key1': ['K0', 'K0', 'K1', 'K2'],
                     'key2': ['K0', 'K1', 'K0', 'K1'],
                        'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3']})
    
right = pd.DataFrame({'key1': ['K0', 'K1', 'K1', 'K2'],
                               'key2': ['K0', 'K0', 'K0', 'K0'],
                                  'C': ['C0', 'C1', 'C2', 'C3'],
                                  'D': ['D0', 'D1', 'D2', 'D3']})

pd.merge(left, right, how='left', on=['key1', 'key2'])
# Out:
#   key1 key2   A   B    C    D
# 0   K0   K0  A0  B0   C0   D0
# 1   K0   K1  A1  B1  NaN  NaN
# 2   K1   K0  A2  B2   C1   D1
# 3   K1   K0  A2  B2   C2   D2
# 4   K2   K1  A3  B3  NaN  NaN

# %%
left = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                     'B': ['B0', 'B1', 'B2']},
                      index=['K0', 'K1', 'K2']) 

right = pd.DataFrame({'C': ['C0', 'C2', 'C3'],
                    'D': ['D0', 'D2', 'D3']},
                      index=['K0', 'K2', 'K3'])

left.join(right, how='left')
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C2   D2

# %%
left
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2

# %%
right
# Out:
#      C   D
# K0  C0  D0
# K2  C2  D2
# K3  C3  D3
