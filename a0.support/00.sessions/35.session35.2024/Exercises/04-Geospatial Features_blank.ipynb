# %% [markdown]
# # Geospatial Features
# In this notebook we will learn about geographic data and how to work with them

# %%
# import libraries
import numpy as np 
import pandas as pd

# %% [markdown]
# ### 1) Work with Lat and Long
#
# we will use this library: https://pypi.org/project/geopy/

# %% [markdown]
# **1) Measuring Distance**

# %%
# import great_circle from geopy.distance


# create 2 vars for home and cafe with lats and longs of (30.109919, 31.308797) & (30.120982, 31.322026)


# calcaulate the distance
# Out:
# 1.7698508016026915

# %% [markdown]
# ***So Lets use it with Our data***

# %%
# read sendy_logistics dataset
df = pd.read_csv('../dastasets/sendy_logistics.csv')
df.head()
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0   Order_No_4211   User_Id_633         Bike              3
# 1  Order_No_25375  User_Id_2285         Bike              3
# 2   Order_No_1899   User_Id_265         Bike              3
# 3   Order_No_9336  User_Id_1402         Bike              3
# 4  Order_No_27883  User_Id_1737         Bike              1
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                         9
# 1             Personal                        12
# 2             Business                        30
# 3             Business                        15
# 4             Personal                        13
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             5       9:35:46 AM                            9
# 1                             5      11:16:16 AM                           12
# ...

# %%
# create a fn to extract the distance from lat & long in each row

# apply the fn to df and create new column for distance
# Out:
#                                                        0               1  \
# Order No                                   Order_No_4211  Order_No_25375
# User Id                                      User_Id_633    User_Id_2285
# Vehicle Type                                        Bike            Bike
# Platform Type                                          3               3
# Personal or Business                            Business        Personal
# Placement - Day of Month                               9              12
# Placement - Weekday (Mo = 1)                           5               5
# Placement - Time                              9:35:46 AM     11:16:16 AM
# Confirmation - Day of Month                            9              12
# Confirmation - Weekday (Mo = 1)                        5               5
# Confirmation - Time                           9:40:10 AM     11:23:21 AM
# Arrival at Pickup - Day of Month                       9              12
# ...

# %% [markdown]
# ### 2) Geocoding features to get the address from lat, long or reverse.
#
# we will use this library: https://pypi.org/project/geopy/

# %%
# import Nominatim from geopy.geocoders


# create an object from Nominatim with user_agent = Epsilon

# %%
# give a location to the object using .geocode method


# show the location information data using .raw method
# Out:
# {'place_id': 43010744,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#  'osm_type': 'way',
#  'osm_id': 26753320,
#  'lat': '30.026992800000002',
#  'lon': '31.40906325945414',
#  'class': 'place',
#  'type': 'neighbourhood',
#  'place_rank': 20,
#  'importance': 0.25000999999999995,
#  'addresstype': 'neighbourhood',
#  'name': 'كايرو فستيفال سيتى',
#  'display_name': 'كايرو فستيفال سيتى, القاهرة, مصر',
#  'boundingbox': ['30.0164179', '30.0374523', '31.4019316', '31.4220303']}

# %%
# show lat & long
# Out:
# ('30.026992800000002', '31.40906325945414')

# %%
# show the location information using .reverse with lat & long
# Out:
# {'place_id': 372290306,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#  'osm_type': 'way',
#  'osm_id': 253593226,
#  'lat': '30.0281356',
#  'lon': '31.407670569933664',
#  'class': 'shop',
#  'type': 'mall',
#  'place_rank': 30,
#  'importance': 9.99999999995449e-06,
#  'addresstype': 'shop',
#  'name': 'كايرو فستيفال سيتى مول',
#  'display_name': 'كايرو فستيفال سيتى مول, محور العروبة الجانبى, كايرو فستيفال سيتى, القاهرة, 11528, مصر',
#  'address': {'shop': 'كايرو فستيفال سيتى مول',
#   'road': 'محور العروبة الجانبى',
#   'village': 'كايرو فستيفال سيتى',
#   'city': 'القاهرة',
#   'state': 'القاهرة',
#   'ISO3166-2-lvl4': 'EG-C',
#   'postcode': '11528',
#   'country': 'مصر',
#   'country_code': 'eg'},
#  'boundingbox': ['30.0257898', '30.0304728', '31.4065217', '31.4097109']}

# %%
# show country name from location information
# Out:
# 'مصر'

# %%
# show city name from location information
# Out:
# 'القاهرة'

# %% [markdown]
# ***So Lets use it with Our data***

# %%
# take a sample of size 200 from sendy_logistics dataset
df = pd.read_csv('../dastasets/sendy_logistics.csv').sample(200)
df.head()
# Out:
#              Order No       User Id Vehicle Type  Platform Type  \
# 14712  Order_No_26350  User_Id_3560         Bike              3
# 19958   Order_No_9863   User_Id_402         Bike              3
# 17148   Order_No_7782  User_Id_2653         Bike              1
# 1770   Order_No_22189  User_Id_2330         Bike              3
# 6295   Order_No_18756  User_Id_3669         Bike              3
#
#       Personal or Business  Placement - Day of Month  \
# 14712             Business                        22
# 19958             Business                        21
# 17148             Personal                        26
# 1770              Business                        20
# 6295              Business                        30
#
#        Placement - Weekday (Mo = 1) Placement - Time  \
# 14712                             3       2:05:34 PM
# 19958                             2       6:21:37 PM
# 17148                             3      12:04:31 PM
# ...

# %%
# def filter_lat(x):
#     if -90 <= x <= 90:
#         return x
#     else: 
#         return np.nan

# def filter_long(x):
#     if -180 <= x <= 180:
#         return x
#     else: 
#         return np.nan    

# df['Pickup Lat'] = df['Pickup Lat'].apply(filter_lat)
# df['Pickup Long'] = df['Pickup Long'].apply(filter_long)

# %%
# create a fn to extract the city name from the data
    

# create a new column called city
# Out:
#              Order No       User Id Vehicle Type  Platform Type  \
# 14712  Order_No_26350  User_Id_3560         Bike              3
# 19958   Order_No_9863   User_Id_402         Bike              3
# 17148   Order_No_7782  User_Id_2653         Bike              1
# 1770   Order_No_22189  User_Id_2330         Bike              3
# 6295   Order_No_18756  User_Id_3669         Bike              3
#
#       Personal or Business  Placement - Day of Month  \
# 14712             Business                        22
# 19958             Business                        21
# 17148             Personal                        26
# 1770              Business                        20
# 6295              Business                        30
#
#        Placement - Weekday (Mo = 1) Placement - Time  \
# 14712                             3       2:05:34 PM
# 19958                             2       6:21:37 PM
# 17148                             3      12:04:31 PM
# ...

# %%
# show value counts
# Out:
# city
# Nairobi                    195
# Syokimau-Mulolongo ward      2
# Kahawa ward                  1
# Nkaimurunya ward             1
# Matathani ward               1
# Name: count, dtype: int64

# %% [markdown]
# # Great Work!
