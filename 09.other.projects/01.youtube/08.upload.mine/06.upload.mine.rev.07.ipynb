# %%
import os
import pickle
import tkinter as tk
from tkinter import filedialog
import subprocess
import shlex
import json
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload
from google.auth.transport.requests import Request

SCOPES = ['https://www.googleapis.com/auth/youtube.upload']
CLIENT_SECRETS_FILE = 'client_secret.emc.json'
VIDEO_EXTENSIONS = ['.mp4', '.mov', '.avi', '.mkv', '.flv', '.wmv']
MERGED_OUTPUT_DIR = 'D:/merged'
PROCESSED_JSON = os.path.join(MERGED_OUTPUT_DIR, 'processed_folders.json')

os.makedirs(MERGED_OUTPUT_DIR, exist_ok=True)

def get_parent_directory():
    root = tk.Tk()
    root.withdraw()
    directory = filedialog.askdirectory(title="Select Parent Directory to Scan for Video Folders")
    root.destroy()
    return directory

def find_video_folders(parent_dir):
    video_folders = []
    for root, dirs, files in os.walk(parent_dir):
        if any(file.lower().endswith(tuple(VIDEO_EXTENSIONS)) for file in files):
            video_folders.append(root)
    return video_folders

def find_videos(directory):
    video_files = []
    for root, _, files in os.walk(directory):
        for file in files:
            if any(file.lower().endswith(ext) for ext in VIDEO_EXTENSIONS):
                video_files.append(os.path.join(root, file))
    return sorted(video_files)

def merge_videos_ffmpeg(video_files, output_path):
    filelist_path = 'ffmpeg_filelist.txt'
    with open(filelist_path, 'w', encoding='utf-8') as f:
        for vf in video_files:
            f.write(f"file '{vf.replace('\\', '/').replace("'", "'\\''")}'\n")
    cmd = f"ffmpeg -f concat -safe 0 -i {filelist_path} -c copy \"{output_path}\""
    print(f"Running: {cmd}")
    result = subprocess.run(shlex.split(cmd), capture_output=True, text=True)
    if result.returncode != 0:
        print('ffmpeg error:', result.stderr)
        raise RuntimeError('ffmpeg merge failed')
    os.remove(filelist_path)

def authenticate_youtube():
    creds = None
    if os.path.exists('token.pickle'):
        with open('token.pickle', 'rb') as token:
            creds = pickle.load(token)
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(CLIENT_SECRETS_FILE, SCOPES)
            creds = flow.run_local_server(port=0)
        with open('token.pickle', 'wb') as token:
            pickle.dump(creds, token)
    return build('youtube', 'v3', credentials=creds)

def get_last_4_folders(path):
    parts = os.path.normpath(path).split(os.sep)
    return ' - '.join(parts[-4:]) if len(parts) >= 4 else os.path.basename(path)

def upload_video(youtube, file_path, title):
    body = {
        'snippet': {
            'title': title,
            'description': 'Merged video uploaded by automated script',
            'tags': [],
            'categoryId': '22'
        },
        'status': {
            'privacyStatus': 'private'
        }
    }
    media = MediaFileUpload(file_path, resumable=True)
    request = youtube.videos().insert(
        part=','.join(body.keys()),
        body=body,
        media_body=media
    )
    response = None
    try:
        while response is None:
            status, response = request.next_chunk()
            if status:
                print(f"Uploading {file_path}: {int(status.progress() * 100)}% done.")
        print(f"Upload Complete: {file_path}")
        # Compose YouTube link if upload succeeded
        video_id = response.get('id') if response else None
        youtube_url = f'https://youtu.be/{video_id}' if video_id else None
        return response, youtube_url, None
    except Exception as e:
        # Check for quota errors in the error message
        error_msg = str(e)
        if 'quota' in error_msg.lower() or 'quotaexceeded' in error_msg.lower():
            return None, None, 'quota'
        return None, None, error_msg

def load_processed():
    if os.path.exists(PROCESSED_JSON):
        with open(PROCESSED_JSON, 'r', encoding='utf-8') as f:
            return json.load(f)
    return {}

def save_processed(processed):
    with open(PROCESSED_JSON, 'w', encoding='utf-8') as f:
        json.dump(processed, f, indent=2, ensure_ascii=False)

def main():
    parent_dir = get_parent_directory()
    if not parent_dir:
        print("No parent directory selected. Exiting.")
        return
    video_folders = find_video_folders(parent_dir)
    if not video_folders:
        print("No folders with videos found.")
        return
    processed = load_processed()
    youtube = authenticate_youtube()
    total_folders = len(video_folders)
    quota_reached = False
    for idx, folder in enumerate(video_folders, 1):
        if folder in processed:
            print(f"[{idx}/{total_folders}] Skipping already processed folder: {folder}")
            continue
        videos = find_videos(folder)
        if not videos:
            processed[folder] = {'status': 'no_videos', 'title': None}
            save_processed(processed)
            continue
        merged_title = get_last_4_folders(folder)
        merged_path = os.path.join(MERGED_OUTPUT_DIR, merged_title + '.mp4')
        print(f"[{idx}/{total_folders}] Merging {len(videos)} videos in: {folder}")
        try:
            merge_videos_ffmpeg(videos, merged_path)
            print(f"[{idx}/{total_folders}] Merged video saved to: {merged_path}")
            print(f"[{idx}/{total_folders}] Uploading video to YouTube: {merged_title}")
            response, youtube_url, upload_status = upload_video(youtube, merged_path, merged_title)
            if upload_status == 'quota':
                print(f"[{idx}/{total_folders}] Quota exceeded. Stopping further uploads.")
                processed[folder] = {'status': 'quota', 'title': merged_title}
                quota_reached = True
                save_processed(processed)
                break
            elif youtube_url:
                print(f"[{idx}/{total_folders}] Upload complete: {merged_title}")
                processed[folder] = {'status': 'uploaded', 'title': merged_title, 'youtube_url': youtube_url}
            else:
                print(f"[{idx}/{total_folders}] Upload failed: {merged_title} ({upload_status})")
                processed[folder] = {'status': 'failed', 'title': merged_title, 'error': upload_status}
        except Exception as e:
            print(f"[{idx}/{total_folders}] Failed to process {folder}: {e}")
            processed[folder] = {'status': 'failed', 'title': merged_title, 'error': str(e)}
            youtube_url = None
        save_processed(processed)
        # Only cleanup and create .txt file if upload succeeded and link is available
        if processed[folder].get('status') == 'uploaded' and os.path.exists(merged_path):
            os.remove(merged_path)
            print(f"[{idx}/{total_folders}] Deleted merged video: {merged_path}")
            txt_path = os.path.splitext(merged_path)[0] + ".txt"
            with open(txt_path, 'w', encoding='utf-8') as f:
                f.write(f"YouTube Link: {processed[folder]['youtube_url']}\n")
            print(f"[{idx}/{total_folders}] Wrote YouTube link to: {txt_path}")
    print("Processing complete. See processed_folders.json for details.")

if __name__ == '__main__':
    main()
# Out:
# [1/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00fail\2017
# [2/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00fail\2018
# [3/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00fail\2016
# [4/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00fail\2019
# [5/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00fail\2020
# [6/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00fail\2021
# [7/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00fail\2022
# [8/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00family\2017
# [9/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00family\2016
# [10/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00family\2015
# [11/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00family\2018
# [12/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00family\2019
# [13/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00family\2023
# [14/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00family\1995
# [15/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00family\2024
# [16/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00car\2025
# [17/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00car\2024
# [18/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00cats\2025
# [19/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00cats\2024
# [20/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00cats\2021
# [21/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00cats\2016
# [22/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00cats\2019
# [23/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00cats\2023
# [24/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00cats\2022
# [25/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00cats\2018
# [26/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00cats\2020
# [27/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00concert\2024
# [28/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00concert\2023
# [29/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00dogs\2025
# [30/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00dogs\2020
# [31/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00dogs\2019
# [32/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00dogs\2017
# [33/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00dogs\2016
# [34/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00dogs\2023
# [35/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00dogs\2021
# [36/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00dogs\2018
# [37/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00dogs\2022
# [38/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00dogs\2015
# [39/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00dogs\2024
# [40/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00me\2025
# [41/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00me\2021
# [42/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00me\2017
# [43/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00me\2022
# [44/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00me\2020
# [45/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00me\2015
# [46/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00me\2016
# [47/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00me\2023
# [48/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00me\2019
# [49/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00me\2018
# [50/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00me\2024
# [51/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00medical\2020
# [52/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00medical\2021
# [53/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00medical\2023
# [54/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00medical\2018
# [55/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00medical\2022
# [56/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00medical\2019
# [57/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00medical\2024
# [58/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00qvr\2025
# [59/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00qvr\2023
# [60/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00qvr\2024
# [61/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00screen\2025
# [62/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00screen\2023
# [63/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00screen\2014
# [64/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00screen\2016
# [65/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00screen\2021
# [66/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00screen\2019
# [67/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00screen\2024
# [68/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00screen\2017
# [69/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00screen\2020
# [70/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00screen\2015
# [71/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00screen\2022
# [72/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00screen\2018
# [73/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00work\2025
# [74/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00work\2015
# [75/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00work\2022
# [76/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00work\2017
# [77/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00work\2016
# [78/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00work\2020
# [79/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00work\2021
# [80/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00work\2023
# [81/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00work\2024
# [82/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00work\2019
# [83/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00work\2018
# [84/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00street\2025
# [85/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00street\2019
# [86/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00street\2023
# [87/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00street\2020
# [88/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00street\2016
# [89/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00street\2021
# [90/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00street\2017
# [91/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00street\2024
# [92/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00street\2015
# [93/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00street\2018
# [94/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00street\2022
# [95/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00transport\2017
# [96/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00transport\2021
# [97/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00transport\2020
# [98/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00transport\2022
# [99/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00transport\2024
# [100/123] Skipping already processed folder: G:/My Drive/P-sync/04OmarCameraAdd\Video\00transport\2018
# [101/123] Merging 31 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00transport\2023
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00transport - 2023.mp4"
