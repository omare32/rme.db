# %%
import os
import pickle
import tkinter as tk
from tkinter import filedialog
import subprocess
import shlex
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload
from google.auth.transport.requests import Request

SCOPES = ['https://www.googleapis.com/auth/youtube.upload']
CLIENT_SECRETS_FILE = 'client_secret.emc.json'
VIDEO_EXTENSIONS = ['.mp4', '.mov', '.avi', '.mkv', '.flv', '.wmv']
MERGED_OUTPUT_DIR = 'D:/merged'

os.makedirs(MERGED_OUTPUT_DIR, exist_ok=True)

def get_parent_directory():
    root = tk.Tk()
    root.withdraw()
    directory = filedialog.askdirectory(title="Select Parent Directory to Scan for Video Folders")
    root.destroy()
    return directory

def find_video_folders(parent_dir):
    video_folders = []
    for root, dirs, files in os.walk(parent_dir):
        if any(file.lower().endswith(tuple(VIDEO_EXTENSIONS)) for file in files):
            video_folders.append(root)
    return video_folders

def find_videos(directory):
    video_files = []
    for root, _, files in os.walk(directory):
        for file in files:
            if any(file.lower().endswith(ext) for ext in VIDEO_EXTENSIONS):
                video_files.append(os.path.join(root, file))
    return sorted(video_files)

def merge_videos_ffmpeg(video_files, output_path):
    filelist_path = 'ffmpeg_filelist.txt'
    with open(filelist_path, 'w', encoding='utf-8') as f:
        for vf in video_files:
            f.write(f"file '{vf.replace('\\', '/').replace("'", "'\\''")}'\n")
    cmd = f"ffmpeg -f concat -safe 0 -i {filelist_path} -c copy \"{output_path}\""
    print(f"Running: {cmd}")
    result = subprocess.run(shlex.split(cmd), capture_output=True, text=True)
    if result.returncode != 0:
        print('ffmpeg error:', result.stderr)
        raise RuntimeError('ffmpeg merge failed')
    os.remove(filelist_path)

def authenticate_youtube():
    creds = None
    if os.path.exists('token.pickle'):
        with open('token.pickle', 'rb') as token:
            creds = pickle.load(token)
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(CLIENT_SECRETS_FILE, SCOPES)
            creds = flow.run_local_server(port=0)
        with open('token.pickle', 'wb') as token:
            pickle.dump(creds, token)
    return build('youtube', 'v3', credentials=creds)

def get_last_4_folders(path):
    parts = os.path.normpath(path).split(os.sep)
    return ' - '.join(parts[-4:]) if len(parts) >= 4 else os.path.basename(path)

def upload_video(youtube, file_path, title):
    body = {
        'snippet': {
            'title': title,
            'description': 'Merged video uploaded by automated script',
            'tags': [],
            'categoryId': '22'
        },
        'status': {
            'privacyStatus': 'private'
        }
    }
    media = MediaFileUpload(file_path, resumable=True)
    request = youtube.videos().insert(
        part=','.join(body.keys()),
        body=body,
        media_body=media
    )
    response = None
    while response is None:
        status, response = request.next_chunk()
        if status:
            print(f"Uploading {file_path}: {int(status.progress() * 100)}% done.")
    print(f"Upload Complete: {file_path}")
    # Compose YouTube link if upload succeeded
    video_id = response.get('id') if response else None
    youtube_url = f'https://youtu.be/{video_id}' if video_id else None
    return response, youtube_url

def main():
    parent_dir = get_parent_directory()
    if not parent_dir:
        print("No parent directory selected. Exiting.")
        return
    video_folders = find_video_folders(parent_dir)
    if not video_folders:
        print("No folders with videos found.")
        return
    youtube = authenticate_youtube()
    total_folders = len(video_folders)
    for idx, folder in enumerate(video_folders, 1):
        videos = find_videos(folder)
        if not videos:
            continue
        merged_title = get_last_4_folders(folder)
        merged_path = os.path.join(MERGED_OUTPUT_DIR, merged_title + '.mp4')
        print(f"[{idx}/{total_folders}] Merging {len(videos)} videos in: {folder}")
        try:
            merge_videos_ffmpeg(videos, merged_path)
            print(f"[{idx}/{total_folders}] Merged video saved to: {merged_path}")
            print(f"[{idx}/{total_folders}] Uploading video to YouTube: {merged_title}")
            response, youtube_url = upload_video(youtube, merged_path, merged_title)
            print(f"[{idx}/{total_folders}] Upload complete: {merged_title}")
        except Exception as e:
            print(f"[{idx}/{total_folders}] Failed to process {folder}: {e}")
            youtube_url = None
        # Only cleanup and create .txt file if upload succeeded and link is available
        if youtube_url and os.path.exists(merged_path):
            os.remove(merged_path)
            print(f"[{idx}/{total_folders}] Deleted merged video: {merged_path}")
            txt_path = os.path.splitext(merged_path)[0] + ".txt"
            with open(txt_path, 'w', encoding='utf-8') as f:
                f.write(f"YouTube Link: {youtube_url}\n")
            print(f"[{idx}/{total_folders}] Wrote YouTube link to: {txt_path}")

if __name__ == '__main__':
    main()
# Out:
# [1/123] Merging 1 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00fail\2017
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00fail - 2017.mp4"
# [1/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00fail - 2017.mp4
# [1/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00fail - 2017
# Upload Complete: D:/merged\04OmarCameraAdd - Video - 00fail - 2017.mp4
# [1/123] Upload complete: 04OmarCameraAdd - Video - 00fail - 2017
# [1/123] Deleted merged video: D:/merged\04OmarCameraAdd - Video - 00fail - 2017.mp4
# [1/123] Wrote YouTube link to: D:/merged\04OmarCameraAdd - Video - 00fail - 2017.txt
# [2/123] Merging 4 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00fail\2018
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00fail - 2018.mp4"
# [2/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00fail - 2018.mp4
# [2/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00fail - 2018
# Upload Complete: D:/merged\04OmarCameraAdd - Video - 00fail - 2018.mp4
# [2/123] Upload complete: 04OmarCameraAdd - Video - 00fail - 2018
# [2/123] Deleted merged video: D:/merged\04OmarCameraAdd - Video - 00fail - 2018.mp4
# [2/123] Wrote YouTube link to: D:/merged\04OmarCameraAdd - Video - 00fail - 2018.txt
# [3/123] Merging 14 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00fail\2016
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00fail - 2016.mp4"
# [3/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00fail - 2016.mp4
# [3/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00fail - 2016
# Upload Complete: D:/merged\04OmarCameraAdd - Video - 00fail - 2016.mp4
# [3/123] Upload complete: 04OmarCameraAdd - Video - 00fail - 2016
# [3/123] Deleted merged video: D:/merged\04OmarCameraAdd - Video - 00fail - 2016.mp4
# [3/123] Wrote YouTube link to: D:/merged\04OmarCameraAdd - Video - 00fail - 2016.txt
# [4/123] Merging 22 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00fail\2019
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00fail - 2019.mp4"
# [4/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00fail - 2019.mp4
# [4/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00fail - 2019
# Upload Complete: D:/merged\04OmarCameraAdd - Video - 00fail - 2019.mp4
# [4/123] Upload complete: 04OmarCameraAdd - Video - 00fail - 2019
# [4/123] Deleted merged video: D:/merged\04OmarCameraAdd - Video - 00fail - 2019.mp4
# [4/123] Wrote YouTube link to: D:/merged\04OmarCameraAdd - Video - 00fail - 2019.txt
# [5/123] Merging 8 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00fail\2020
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00fail - 2020.mp4"
# [5/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00fail - 2020.mp4
# [5/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00fail - 2020
# Upload Complete: D:/merged\04OmarCameraAdd - Video - 00fail - 2020.mp4
# [5/123] Upload complete: 04OmarCameraAdd - Video - 00fail - 2020
# [5/123] Deleted merged video: D:/merged\04OmarCameraAdd - Video - 00fail - 2020.mp4
# [5/123] Wrote YouTube link to: D:/merged\04OmarCameraAdd - Video - 00fail - 2020.txt
# [6/123] Merging 3 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00fail\2021
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00fail - 2021.mp4"
# [6/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00fail - 2021.mp4
# [6/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00fail - 2021
# Upload Complete: D:/merged\04OmarCameraAdd - Video - 00fail - 2021.mp4
# [6/123] Upload complete: 04OmarCameraAdd - Video - 00fail - 2021
# [6/123] Deleted merged video: D:/merged\04OmarCameraAdd - Video - 00fail - 2021.mp4
# [6/123] Wrote YouTube link to: D:/merged\04OmarCameraAdd - Video - 00fail - 2021.txt
# [7/123] Merging 5 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00fail\2022
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00fail - 2022.mp4"
# [7/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00fail - 2022.mp4
# [7/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00fail - 2022
# Upload Complete: D:/merged\04OmarCameraAdd - Video - 00fail - 2022.mp4
# [7/123] Upload complete: 04OmarCameraAdd - Video - 00fail - 2022
# [7/123] Deleted merged video: D:/merged\04OmarCameraAdd - Video - 00fail - 2022.mp4
# [7/123] Wrote YouTube link to: D:/merged\04OmarCameraAdd - Video - 00fail - 2022.txt
# [8/123] Merging 5 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00family\2017
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00family - 2017.mp4"
# [8/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00family - 2017.mp4
# [8/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00family - 2017
# Upload Complete: D:/merged\04OmarCameraAdd - Video - 00family - 2017.mp4
# [8/123] Upload complete: 04OmarCameraAdd - Video - 00family - 2017
# [8/123] Deleted merged video: D:/merged\04OmarCameraAdd - Video - 00family - 2017.mp4
# [8/123] Wrote YouTube link to: D:/merged\04OmarCameraAdd - Video - 00family - 2017.txt
# [9/123] Merging 3 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00family\2016
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00family - 2016.mp4"
# [9/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00family - 2016.mp4
# [9/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00family - 2016
# Upload Complete: D:/merged\04OmarCameraAdd - Video - 00family - 2016.mp4
# [9/123] Upload complete: 04OmarCameraAdd - Video - 00family - 2016
# [9/123] Deleted merged video: D:/merged\04OmarCameraAdd - Video - 00family - 2016.mp4
# [9/123] Wrote YouTube link to: D:/merged\04OmarCameraAdd - Video - 00family - 2016.txt
# [10/123] Merging 3 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00family\2015
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00family - 2015.mp4"
# [10/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00family - 2015.mp4
# [10/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00family - 2015
# Upload Complete: D:/merged\04OmarCameraAdd - Video - 00family - 2015.mp4
# [10/123] Upload complete: 04OmarCameraAdd - Video - 00family - 2015
# [10/123] Deleted merged video: D:/merged\04OmarCameraAdd - Video - 00family - 2015.mp4
# [10/123] Wrote YouTube link to: D:/merged\04OmarCameraAdd - Video - 00family - 2015.txt
# [11/123] Merging 17 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00family\2018
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00family - 2018.mp4"
# [11/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00family - 2018.mp4
# [11/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00family - 2018
# Uploading D:/merged\04OmarCameraAdd - Video - 00family - 2018.mp4: 10% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00family - 2018.mp4: 21% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00family - 2018.mp4: 31% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00family - 2018.mp4: 42% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00family - 2018.mp4: 52% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00family - 2018.mp4: 63% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00family - 2018.mp4: 74% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00family - 2018.mp4: 84% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00family - 2018.mp4: 95% done.
# Upload Complete: D:/merged\04OmarCameraAdd - Video - 00family - 2018.mp4
# [11/123] Upload complete: 04OmarCameraAdd - Video - 00family - 2018
# [11/123] Deleted merged video: D:/merged\04OmarCameraAdd - Video - 00family - 2018.mp4
# [11/123] Wrote YouTube link to: D:/merged\04OmarCameraAdd - Video - 00family - 2018.txt
# [12/123] Merging 6 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00family\2019
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00family - 2019.mp4"
# [12/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00family - 2019.mp4
# [12/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00family - 2019
# Upload Complete: D:/merged\04OmarCameraAdd - Video - 00family - 2019.mp4
# [12/123] Upload complete: 04OmarCameraAdd - Video - 00family - 2019
# [12/123] Deleted merged video: D:/merged\04OmarCameraAdd - Video - 00family - 2019.mp4
# [12/123] Wrote YouTube link to: D:/merged\04OmarCameraAdd - Video - 00family - 2019.txt
# [13/123] Merging 1 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00family\2023
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00family - 2023.mp4"
# [13/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00family - 2023.mp4
# [13/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00family - 2023
# Upload Complete: D:/merged\04OmarCameraAdd - Video - 00family - 2023.mp4
# [13/123] Upload complete: 04OmarCameraAdd - Video - 00family - 2023
# [13/123] Deleted merged video: D:/merged\04OmarCameraAdd - Video - 00family - 2023.mp4
# [13/123] Wrote YouTube link to: D:/merged\04OmarCameraAdd - Video - 00family - 2023.txt
# [14/123] Merging 1 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00family\1995
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00family - 1995.mp4"
# [14/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00family - 1995.mp4
# [14/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00family - 1995
# Uploading D:/merged\04OmarCameraAdd - Video - 00family - 1995.mp4: 95% done.
# Upload Complete: D:/merged\04OmarCameraAdd - Video - 00family - 1995.mp4
# [14/123] Upload complete: 04OmarCameraAdd - Video - 00family - 1995
# [14/123] Deleted merged video: D:/merged\04OmarCameraAdd - Video - 00family - 1995.mp4
# [14/123] Wrote YouTube link to: D:/merged\04OmarCameraAdd - Video - 00family - 1995.txt
# [15/123] Merging 4 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00family\2024
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00family - 2024.mp4"
# [15/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00family - 2024.mp4
# [15/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00family - 2024
# Upload Complete: D:/merged\04OmarCameraAdd - Video - 00family - 2024.mp4
# [15/123] Upload complete: 04OmarCameraAdd - Video - 00family - 2024
# [15/123] Deleted merged video: D:/merged\04OmarCameraAdd - Video - 00family - 2024.mp4
# [15/123] Wrote YouTube link to: D:/merged\04OmarCameraAdd - Video - 00family - 2024.txt
# [16/123] Merging 1 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00car\2025
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00car - 2025.mp4"
# [16/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00car - 2025.mp4
# [16/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00car - 2025
# Upload Complete: D:/merged\04OmarCameraAdd - Video - 00car - 2025.mp4
# [16/123] Upload complete: 04OmarCameraAdd - Video - 00car - 2025
# [16/123] Deleted merged video: D:/merged\04OmarCameraAdd - Video - 00car - 2025.mp4
# [16/123] Wrote YouTube link to: D:/merged\04OmarCameraAdd - Video - 00car - 2025.txt
# [17/123] Merging 33 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00car\2024
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00car - 2024.mp4"
# [17/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00car - 2024.mp4
# [17/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00car - 2024
# Uploading D:/merged\04OmarCameraAdd - Video - 00car - 2024.mp4: 20% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00car - 2024.mp4: 40% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00car - 2024.mp4: 60% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00car - 2024.mp4: 80% done.
# Upload Complete: D:/merged\04OmarCameraAdd - Video - 00car - 2024.mp4
# [17/123] Upload complete: 04OmarCameraAdd - Video - 00car - 2024
# [17/123] Deleted merged video: D:/merged\04OmarCameraAdd - Video - 00car - 2024.mp4
# [17/123] Wrote YouTube link to: D:/merged\04OmarCameraAdd - Video - 00car - 2024.txt
# [18/123] Merging 2 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00cats\2025
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00cats - 2025.mp4"
# [18/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00cats - 2025.mp4
# [18/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00cats - 2025
# Upload Complete: D:/merged\04OmarCameraAdd - Video - 00cats - 2025.mp4
# [18/123] Upload complete: 04OmarCameraAdd - Video - 00cats - 2025
# [18/123] Deleted merged video: D:/merged\04OmarCameraAdd - Video - 00cats - 2025.mp4
# [18/123] Wrote YouTube link to: D:/merged\04OmarCameraAdd - Video - 00cats - 2025.txt
# [19/123] Merging 142 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00cats\2024
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00cats - 2024.mp4"
# [19/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00cats - 2024.mp4
# [19/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00cats - 2024
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2024.mp4: 3% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2024.mp4: 7% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2024.mp4: 10% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2024.mp4: 14% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2024.mp4: 17% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2024.mp4: 21% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2024.mp4: 25% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2024.mp4: 28% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2024.mp4: 32% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2024.mp4: 35% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2024.mp4: 39% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2024.mp4: 42% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2024.mp4: 46% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2024.mp4: 50% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2024.mp4: 53% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2024.mp4: 57% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2024.mp4: 60% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2024.mp4: 64% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2024.mp4: 68% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2024.mp4: 71% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2024.mp4: 75% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2024.mp4: 78% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2024.mp4: 82% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2024.mp4: 85% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2024.mp4: 89% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2024.mp4: 93% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2024.mp4: 96% done.
# Upload Complete: D:/merged\04OmarCameraAdd - Video - 00cats - 2024.mp4
# [19/123] Upload complete: 04OmarCameraAdd - Video - 00cats - 2024
# [19/123] Deleted merged video: D:/merged\04OmarCameraAdd - Video - 00cats - 2024.mp4
# [19/123] Wrote YouTube link to: D:/merged\04OmarCameraAdd - Video - 00cats - 2024.txt
# [20/123] Merging 390 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00cats\2021
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4"
# [20/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4
# [20/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00cats - 2021
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 1% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 2% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 4% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 5% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 7% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 8% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 9% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 11% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 12% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 14% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 15% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 17% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 18% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 19% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 21% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 22% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 24% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 25% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 27% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 28% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 29% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 31% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 32% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 34% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 35% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 37% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 38% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 39% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 41% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 42% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 44% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 45% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 47% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 48% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 49% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 51% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 52% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 54% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 55% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 57% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 58% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 59% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 61% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 62% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 64% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 65% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 67% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 68% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 69% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 71% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 72% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 74% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 75% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 77% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 78% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 79% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 81% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 82% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 84% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 85% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 87% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 88% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 89% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 91% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 92% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 94% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 95% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 96% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 98% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4: 99% done.
# Upload Complete: D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4
# [20/123] Upload complete: 04OmarCameraAdd - Video - 00cats - 2021
# [20/123] Deleted merged video: D:/merged\04OmarCameraAdd - Video - 00cats - 2021.mp4
# [20/123] Wrote YouTube link to: D:/merged\04OmarCameraAdd - Video - 00cats - 2021.txt
# [21/123] Merging 4 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00cats\2016
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00cats - 2016.mp4"
# [21/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00cats - 2016.mp4
# [21/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00cats - 2016
# Upload Complete: D:/merged\04OmarCameraAdd - Video - 00cats - 2016.mp4
# [21/123] Upload complete: 04OmarCameraAdd - Video - 00cats - 2016
# [21/123] Deleted merged video: D:/merged\04OmarCameraAdd - Video - 00cats - 2016.mp4
# [21/123] Wrote YouTube link to: D:/merged\04OmarCameraAdd - Video - 00cats - 2016.txt
# [22/123] Merging 603 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00cats\2019
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4"
# [22/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4
# [22/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00cats - 2019
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 0% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 1% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 2% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 3% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 4% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 5% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 6% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 7% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 8% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 9% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 10% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 11% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 12% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 13% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 14% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 15% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 16% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 17% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 18% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 19% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 20% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 21% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 22% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 23% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 23% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 24% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 25% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 26% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 27% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 28% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 29% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 30% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 31% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 32% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 33% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 34% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 35% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 36% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 37% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 38% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 39% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 40% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 41% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 42% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 43% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 44% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 45% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 46% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 46% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 47% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 48% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 49% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 50% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 51% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 52% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 53% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 54% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 55% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 56% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 57% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 58% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 59% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 60% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 61% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 62% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 63% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 64% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 65% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 66% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 67% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 68% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 69% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 70% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 70% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 71% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 72% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 73% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 74% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 75% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 76% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 77% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 78% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 79% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 80% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 81% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 82% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 83% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 84% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 85% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 86% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 87% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 88% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 89% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 90% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 91% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 92% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 93% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 93% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 94% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 95% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 96% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 97% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 98% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4: 99% done.
# Upload Complete: D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4
# [22/123] Upload complete: 04OmarCameraAdd - Video - 00cats - 2019
# [22/123] Deleted merged video: D:/merged\04OmarCameraAdd - Video - 00cats - 2019.mp4
# [22/123] Wrote YouTube link to: D:/merged\04OmarCameraAdd - Video - 00cats - 2019.txt
# [23/123] Merging 68 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00cats\2023
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00cats - 2023.mp4"
# [23/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00cats - 2023.mp4
# [23/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00cats - 2023
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2023.mp4: 9% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2023.mp4: 18% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2023.mp4: 27% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2023.mp4: 36% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2023.mp4: 45% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2023.mp4: 54% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2023.mp4: 63% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2023.mp4: 72% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2023.mp4: 81% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2023.mp4: 90% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2023.mp4: 99% done.
# Upload Complete: D:/merged\04OmarCameraAdd - Video - 00cats - 2023.mp4
# [23/123] Upload complete: 04OmarCameraAdd - Video - 00cats - 2023
# [23/123] Deleted merged video: D:/merged\04OmarCameraAdd - Video - 00cats - 2023.mp4
# [23/123] Wrote YouTube link to: D:/merged\04OmarCameraAdd - Video - 00cats - 2023.txt
# [24/123] Merging 244 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00cats\2022
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4"
# [24/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4
# [24/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00cats - 2022
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 2% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 4% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 7% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 9% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 11% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 14% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 16% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 19% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 21% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 23% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 26% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 28% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 31% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 33% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 35% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 38% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 40% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 43% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 45% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 47% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 50% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 52% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 54% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 57% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 59% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 62% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 64% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 66% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 69% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 71% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 74% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 76% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 78% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 81% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 83% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 86% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 88% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 90% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 93% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 95% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4: 98% done.
# Upload Complete: D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4
# [24/123] Upload complete: 04OmarCameraAdd - Video - 00cats - 2022
# [24/123] Deleted merged video: D:/merged\04OmarCameraAdd - Video - 00cats - 2022.mp4
# [24/123] Wrote YouTube link to: D:/merged\04OmarCameraAdd - Video - 00cats - 2022.txt
# [25/123] Merging 670 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00cats\2018
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4"
# [25/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4
# [25/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00cats - 2018
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 0% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 1% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 2% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 3% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 4% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 5% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 6% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 6% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 7% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 8% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 9% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 10% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 11% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 12% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 12% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 13% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 14% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 15% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 16% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 17% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 18% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 18% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 19% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 20% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 21% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 22% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 23% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 24% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 24% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 25% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 26% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 27% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 28% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 29% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 30% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 31% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 31% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 32% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 33% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 34% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 35% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 36% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 37% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 37% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 38% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 39% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 40% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 41% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 42% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 43% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 43% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 44% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 45% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 46% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 47% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 48% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 49% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 49% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 50% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 51% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 52% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 53% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 54% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 55% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 55% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 56% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 57% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 58% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 59% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 60% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 61% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 62% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 62% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 63% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 64% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 65% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 66% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 67% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 68% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 68% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 69% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 70% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 71% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 72% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 73% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 74% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 74% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 75% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 76% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 77% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 78% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 79% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 80% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 80% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 81% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 82% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 83% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 84% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 85% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 86% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 86% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 87% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 88% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 89% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 90% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 91% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 92% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 93% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 93% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 94% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 95% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 96% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 97% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 98% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 99% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4: 99% done.
# Upload Complete: D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4
# [25/123] Upload complete: 04OmarCameraAdd - Video - 00cats - 2018
# [25/123] Deleted merged video: D:/merged\04OmarCameraAdd - Video - 00cats - 2018.mp4
# [25/123] Wrote YouTube link to: D:/merged\04OmarCameraAdd - Video - 00cats - 2018.txt
# [26/123] Merging 292 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00cats\2020
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00cats - 2020.mp4"
# [26/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00cats - 2020.mp4
# [26/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00cats - 2020
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2020.mp4: 2% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2020.mp4: 4% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2020.mp4: 6% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2020.mp4: 8% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2020.mp4: 10% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2020.mp4: 12% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2020.mp4: 15% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2020.mp4: 17% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2020.mp4: 19% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2020.mp4: 21% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2020.mp4: 23% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2020.mp4: 25% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2020.mp4: 28% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2020.mp4: 30% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2020.mp4: 32% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2020.mp4: 34% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2020.mp4: 36% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2020.mp4: 38% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2020.mp4: 41% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2020.mp4: 43% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2020.mp4: 45% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2020.mp4: 47% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2020.mp4: 49% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2020.mp4: 51% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2020.mp4: 53% done.
# Uploading D:/merged\04OmarCameraAdd - Video - 00cats - 2020.mp4: 56% done.
# ...
# [105/123] Merging 3 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00trip\2013
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00trip - 2013.mp4"
# [105/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00trip - 2013.mp4
# [105/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00trip - 2013
# [105/123] Failed to process G:/My Drive/P-sync/04OmarCameraAdd\Video\00trip\2013: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# [106/123] Merging 20 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00trip\2020
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00trip - 2020.mp4"
# [106/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00trip - 2020.mp4
# [106/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00trip - 2020
# [106/123] Failed to process G:/My Drive/P-sync/04OmarCameraAdd\Video\00trip\2020: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# [107/123] Merging 36 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00trip\2021
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00trip - 2021.mp4"
# [107/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00trip - 2021.mp4
# [107/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00trip - 2021
# [107/123] Failed to process G:/My Drive/P-sync/04OmarCameraAdd\Video\00trip\2021: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# [108/123] Merging 32 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00trip\2017
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00trip - 2017.mp4"
# [108/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00trip - 2017.mp4
# [108/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00trip - 2017
# [108/123] Failed to process G:/My Drive/P-sync/04OmarCameraAdd\Video\00trip\2017: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# [109/123] Merging 1 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00trip\2019
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00trip - 2019.mp4"
# [109/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00trip - 2019.mp4
# [109/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00trip - 2019
# [109/123] Failed to process G:/My Drive/P-sync/04OmarCameraAdd\Video\00trip\2019: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# [110/123] Merging 16 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00trip\2024
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00trip - 2024.mp4"
# [110/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00trip - 2024.mp4
# [110/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00trip - 2024
# [110/123] Failed to process G:/My Drive/P-sync/04OmarCameraAdd\Video\00trip\2024: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# [111/123] Merging 36 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00trip\2022
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00trip - 2022.mp4"
# [111/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00trip - 2022.mp4
# [111/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00trip - 2022
# [111/123] Failed to process G:/My Drive/P-sync/04OmarCameraAdd\Video\00trip\2022: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# [112/123] Merging 3 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00trip\2023
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00trip - 2023.mp4"
# [112/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00trip - 2023.mp4
# [112/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00trip - 2023
# [112/123] Failed to process G:/My Drive/P-sync/04OmarCameraAdd\Video\00trip\2023: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# [113/123] Merging 2 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00trip\2015
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00trip - 2015.mp4"
# [113/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00trip - 2015.mp4
# [113/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00trip - 2015
# [113/123] Failed to process G:/My Drive/P-sync/04OmarCameraAdd\Video\00trip\2015: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# [114/123] Merging 7 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00trip\2018
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00trip - 2018.mp4"
# [114/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00trip - 2018.mp4
# [114/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00trip - 2018
# [114/123] Failed to process G:/My Drive/P-sync/04OmarCameraAdd\Video\00trip\2018: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# [115/123] Merging 28 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00sha2a\2016
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00sha2a - 2016.mp4"
# [115/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00sha2a - 2016.mp4
# [115/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00sha2a - 2016
# [115/123] Failed to process G:/My Drive/P-sync/04OmarCameraAdd\Video\00sha2a\2016: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# [116/123] Merging 94 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00sha2a\2018
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00sha2a - 2018.mp4"
# [116/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00sha2a - 2018.mp4
# [116/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00sha2a - 2018
# [116/123] Failed to process G:/My Drive/P-sync/04OmarCameraAdd\Video\00sha2a\2018: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# [117/123] Merging 11 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00sha2a\2021
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00sha2a - 2021.mp4"
# [117/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00sha2a - 2021.mp4
# [117/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00sha2a - 2021
# [117/123] Failed to process G:/My Drive/P-sync/04OmarCameraAdd\Video\00sha2a\2021: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# [118/123] Merging 36 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00sha2a\2019
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00sha2a - 2019.mp4"
# [118/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00sha2a - 2019.mp4
# [118/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00sha2a - 2019
# [118/123] Failed to process G:/My Drive/P-sync/04OmarCameraAdd\Video\00sha2a\2019: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# [119/123] Merging 25 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00sha2a\2024
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00sha2a - 2024.mp4"
# [119/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00sha2a - 2024.mp4
# [119/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00sha2a - 2024
# [119/123] Failed to process G:/My Drive/P-sync/04OmarCameraAdd\Video\00sha2a\2024: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# [120/123] Merging 9 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00sha2a\2017
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00sha2a - 2017.mp4"
# [120/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00sha2a - 2017.mp4
# [120/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00sha2a - 2017
# [120/123] Failed to process G:/My Drive/P-sync/04OmarCameraAdd\Video\00sha2a\2017: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# [121/123] Merging 9 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00sha2a\2023
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00sha2a - 2023.mp4"
# [121/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00sha2a - 2023.mp4
# [121/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00sha2a - 2023
# [121/123] Failed to process G:/My Drive/P-sync/04OmarCameraAdd\Video\00sha2a\2023: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# [122/123] Merging 26 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00sha2a\2020
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00sha2a - 2020.mp4"
# [122/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00sha2a - 2020.mp4
# [122/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00sha2a - 2020
# [122/123] Failed to process G:/My Drive/P-sync/04OmarCameraAdd\Video\00sha2a\2020: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# [123/123] Merging 12 videos in: G:/My Drive/P-sync/04OmarCameraAdd\Video\00sha2a\2022
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\04OmarCameraAdd - Video - 00sha2a - 2022.mp4"
# [123/123] Merged video saved to: D:/merged\04OmarCameraAdd - Video - 00sha2a - 2022.mp4
# [123/123] Uploading video to YouTube: 04OmarCameraAdd - Video - 00sha2a - 2022
# [123/123] Failed to process G:/My Drive/P-sync/04OmarCameraAdd\Video\00sha2a\2022: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
