# %%
import os
import pickle
import tkinter as tk
from tkinter import filedialog
import subprocess
import shlex
import json
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload
from google.auth.transport.requests import Request

SCOPES = ['https://www.googleapis.com/auth/youtube.upload']
CLIENT_SECRETS_FILE = 'client_secret.emc.json'
VIDEO_EXTENSIONS = ['.mp4', '.mov', '.avi', '.mkv', '.flv', '.wmv']
MERGED_OUTPUT_DIR = 'D:/merged'
PROCESSED_JSON = os.path.join(MERGED_OUTPUT_DIR, 'processed_folders.json')

os.makedirs(MERGED_OUTPUT_DIR, exist_ok=True)

def get_parent_directory():
    root = tk.Tk()
    root.withdraw()
    directory = filedialog.askdirectory(title="Select Parent Directory to Scan for Video Folders")
    root.destroy()
    return directory

def find_video_folders(parent_dir):
    video_folders = []
    for root, dirs, files in os.walk(parent_dir):
        if any(file.lower().endswith(tuple(VIDEO_EXTENSIONS)) for file in files):
            video_folders.append(root)
    return video_folders

def find_videos_by_resolution(directory):
    video_files = []
    for root, _, files in os.walk(directory):
        for file in files:
            if any(file.lower().endswith(ext) for ext in VIDEO_EXTENSIONS):
                video_files.append(os.path.join(root, file))
    # Group by resolution
    resolution_groups = {}
    for vf in video_files:
        try:
            result = subprocess.run([
                'python', os.path.join(os.path.dirname(__file__), 'ffprobe_resolution.py'), vf
            ], capture_output=True, text=True)
            if result.returncode == 0:
                res = result.stdout.strip()
                print(f"[RESOLUTION] {vf} -> {res}")
            else:
                res = 'unknown'
                print(f"[RESOLUTION-ERROR] {vf} -> unknown (ffprobe error: {result.stderr.strip()})")
        except Exception as e:
            res = 'unknown'
            print(f"[RESOLUTION-EXCEPTION] {vf} -> unknown (Exception: {e})")
        if res not in resolution_groups:
            resolution_groups[res] = []
        resolution_groups[res].append(vf)
    return resolution_groups

def merge_videos_ffmpeg(video_files, output_path):
    filelist_path = 'ffmpeg_filelist.txt'
    with open(filelist_path, 'w', encoding='utf-8') as f:
        for vf in video_files:
            f.write(f"file '{vf.replace('\\', '/').replace("'", "'\\''")}'\n")
    cmd = f"ffmpeg -f concat -safe 0 -i {filelist_path} -c copy \"{output_path}\""
    print(f"Running: {cmd}")
    result = subprocess.run(shlex.split(cmd), capture_output=True, text=True)
    if result.returncode != 0:
        print('ffmpeg error:', result.stderr)
        raise RuntimeError('ffmpeg merge failed')
    os.remove(filelist_path)

def authenticate_youtube():
    creds = None
    if os.path.exists('token.pickle'):
        with open('token.pickle', 'rb') as token:
            creds = pickle.load(token)
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(CLIENT_SECRETS_FILE, SCOPES)
            creds = flow.run_local_server(port=0)
        with open('token.pickle', 'wb') as token:
            pickle.dump(creds, token)
    return build('youtube', 'v3', credentials=creds)

def get_last_4_folders(path):
    parts = os.path.normpath(path).split(os.sep)
    return ' - '.join(parts[-4:]) if len(parts) >= 4 else os.path.basename(path)

def upload_video(youtube, file_path, title):
    body = {
        'snippet': {
            'title': title,
            'description': 'Merged video uploaded by automated script',
            'tags': [],
            'categoryId': '22'
        },
        'status': {
            'privacyStatus': 'private'
        }
    }
    media = MediaFileUpload(file_path, resumable=True)
    request = youtube.videos().insert(
        part=','.join(body.keys()),
        body=body,
        media_body=media
    )
    response = None
    try:
        while response is None:
            status, response = request.next_chunk()
            if status:
                print(f"Uploading {file_path}: {int(status.progress() * 100)}% done.")
        print(f"Upload Complete: {file_path}")
        # Compose YouTube link if upload succeeded
        video_id = response.get('id') if response else None
        youtube_url = f'https://youtu.be/{video_id}' if video_id else None
        return response, youtube_url, None
    except Exception as e:
        # Check for quota errors in the error message
        error_msg = str(e)
        if 'quota' in error_msg.lower() or 'quotaexceeded' in error_msg.lower():
            return None, None, 'quota'
        return None, None, error_msg

def load_processed():
    if os.path.exists(PROCESSED_JSON):
        with open(PROCESSED_JSON, 'r', encoding='utf-8') as f:
            return json.load(f)
    return {}

def save_processed(processed):
    with open(PROCESSED_JSON, 'w', encoding='utf-8') as f:
        json.dump(processed, f, indent=2, ensure_ascii=False)

def main():
    parent_dir = get_parent_directory()
    if not parent_dir:
        print("No parent directory selected. Exiting.")
        return
    video_folders = find_video_folders(parent_dir)
    if not video_folders:
        print("No folders with videos found.")
        return
    processed = load_processed()
    youtube = authenticate_youtube()
    total_folders = len(video_folders)
    quota_reached = False
    for idx, folder in enumerate(video_folders, 1):
        # Support both old (flat) and new (parts) processed structures
        skip_folder = False
        if folder in processed:
            entry = processed[folder]
            if isinstance(entry, dict):
                # Old style: flat dict with 'status'
                if 'status' in entry and entry['status'] == 'uploaded':
                    skip_folder = True
                # New style: dict of parts
                elif all(isinstance(v, dict) and v.get('status') == 'uploaded' for v in entry.values()):
                    skip_folder = True
        if skip_folder:
            print(f"[{idx}/{total_folders}] Skipping already processed folder: {folder}")
            continue
        res_groups = find_videos_by_resolution(folder)
        if not res_groups or all(len(vs) == 0 for vs in res_groups.values()):
            processed[folder] = {'status': 'no_videos', 'title': None}
            save_processed(processed)
            continue
        processed[folder] = processed.get(folder, {})
        part_number = 1
        for res, videos in res_groups.items():
            if not videos:
                continue
            part_key = f"part_{part_number:02d}_{res}"
            if part_key in processed[folder] and processed[folder][part_key].get('status') == 'uploaded':
                print(f"[{idx}/{total_folders}] Skipping already processed part: {part_key} in {folder}")
                part_number += 1
                continue
            # Only include resolution in title if not 'unknown'
            if res == 'unknown':
                merged_title = get_last_4_folders(folder) + f" - Part {part_number:02d}"
            else:
                merged_title = get_last_4_folders(folder) + f" - Part {part_number:02d} ({res})"
            merged_path = os.path.join(MERGED_OUTPUT_DIR, merged_title + '.mp4')
            print(f"[{idx}/{total_folders}] Merging {len(videos)} videos in: {folder} (Resolution: {res})")
            try:
                merge_videos_ffmpeg(videos, merged_path)
                print(f"[{idx}/{total_folders}] Merged video saved to: {merged_path}")
                print(f"[{idx}/{total_folders}] Uploading video to YouTube: {merged_title}")
                response, youtube_url, upload_status = upload_video(youtube, merged_path, merged_title)
                if upload_status == 'quota':
                    print(f"[{idx}/{total_folders}] Quota exceeded. Stopping further uploads.")
                    processed[folder][part_key] = {'status': 'quota', 'title': merged_title}
                    quota_reached = True
                    save_processed(processed)
                    break
                elif youtube_url:
                    print(f"[{idx}/{total_folders}] Upload complete: {merged_title}")
                    processed[folder][part_key] = {'status': 'uploaded', 'title': merged_title, 'youtube_url': youtube_url}
                else:
                    print(f"[{idx}/{total_folders}] Upload failed: {merged_title} ({upload_status})")
                    processed[folder][part_key] = {'status': 'failed', 'title': merged_title, 'error': upload_status}
            except Exception as e:
                print(f"[{idx}/{total_folders}] Failed to process {folder} part {part_number}: {e}")
                processed[folder][part_key] = {'status': 'failed', 'title': merged_title, 'error': str(e)}
                youtube_url = None
            save_processed(processed)
            # Only cleanup and create .txt file if upload succeeded and link is available
            if processed[folder][part_key].get('status') == 'uploaded' and os.path.exists(merged_path):
                os.remove(merged_path)
                print(f"[{idx}/{total_folders}] Deleted merged video: {merged_path}")
                txt_path = os.path.splitext(merged_path)[0] + ".txt"
                with open(txt_path, 'w', encoding='utf-8') as f:
                    f.write(f"YouTube Link: {processed[folder][part_key]['youtube_url']}\n")
                print(f"[{idx}/{total_folders}] Wrote YouTube link to: {txt_path}")
            part_number += 1
        save_processed(processed)
        if quota_reached:
            break
    print("Processing complete. See processed_folders.json for details.")

if __name__ == '__main__':
    main()
# Out:
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\031 (1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180522-WA0032.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\029 (2).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\Halafawi BDSM.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180519-WA0233.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\Matsebo Latelweh.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180525-WA0030.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\026.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\020 (1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20171122-WA0019.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\0022.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180520-WA0054.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\012 (1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\microbus attack combined.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\00000.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20170530-WA0016.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\025 (1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\Heathen Pride (1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\08 - Korneesha 540p.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180520-WA0060.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\021.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180519-WA0205.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20161031-WA0003.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180519-WA0226.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\Dahab Video 1080p.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\021 (1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180519-WA0131.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\DSCN5579.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\009 (1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\027 (1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\003 (2).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\07 - W Dalia.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\02.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180519-WA0278.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\031.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20150806-WA0001.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\07 - Finsterforst - Von Glorreichem Schmerz.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\009 (2).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180519-WA0182.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180520-WA0057.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\MOV00527(1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180623-WA0129.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID_45960215_101032_668.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\017.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\1.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180514-WA0040.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180424-WA0021.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180520-WA0040.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\mmm.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180519-WA0213.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\media_upload1497422782630.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20150321-WA0001.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20170104-WA0013.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\116.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180518-WA0016.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\007 (3).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180519-WA0231.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\087.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\01.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\003 (1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20161111-WA0001.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\01 - Fel Microbus.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180506-WA0032.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\1_chunk_1.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\01 - safy.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180516-WA0036.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\Sinister Realm The Hash is Burning_0001.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\MOV00525(1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180516-WA0038.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\011 (2).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180520-WA0055.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180717-WA0020.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20170124-WA0018.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\008 (3).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\media_upload1497421364895.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20161103-WA0002.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VHS 20 mins.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\002.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\117.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\015 (2).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180505-WA0038.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180519-WA0162.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180519-WA0196.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180519-WA0137.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID_21281011_170730_093.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\2015.07 - Women's Bathroom.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180225-WA0021.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\019 (1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180519-WA0148.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180427-WA0056.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180520-WA0064.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID_29520327_073903_915.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180519-WA0206.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\20151227-000026.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\Sinister Realm The Hash is Burning.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180420-WA0075.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\received_1538570289526401.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\2011.01.15 00-00-00.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\047.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180519-WA0166.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180519-WA0143.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\MOV00522.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\103.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\122.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20161103-WA0004.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\0008.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\08 - Korneesh 1080p.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\video-1448317778.mp4.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\00 - LHC Remix.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\Sisi Satanic Metal.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20150702-WA0002.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\MOV00522(1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180520-WA0059.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180519-WA0128.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\071.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20170428-WA0012.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\03 - asma.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180519-WA0195.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\022 (2).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180420-WA0018.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID_20670706_070342_832.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\2010.11.20 02-45-101.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\for son.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\MOV00527.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180521-WA0044.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\teslam el 2ayady.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\037.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180519-WA0201.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\001 (5).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\014 (2).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\011 (1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\016 (2).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20161109-WA0005.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\002 (2).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\Me Pen.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20161103-WA0005.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\Untitled.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180519-WA0133.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\ShoSho Tunnel.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20150320-WA0001.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\02 - Small One.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20150420-WA0001.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\01 - My DVDs 01.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\06 - Ensiferum - Token of Time (Overlay).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\hgfhgfhgfhg.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\final.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20150812-WA0002.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\03 - Fel Mostashfa Part 01.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\03 - Fel Mostashfa Part 02.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\04 - W Amon.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\05 - W Ali.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\EL ReMix.avi -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\06 - Ensiferum - Token of Time.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\Dahab Video 720p.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\01 - Snake Eater.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\04 - Time Only Knows.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\02 - Akuda Bar.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\el zeb.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\6666.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\all.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\001 (1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\003.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\004 (1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\005 (2).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\006 (2).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\007.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\009 (3).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\010 (3).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\013 (1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\01 - Selem.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\02 - More Selem.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\03 - Mom Talkin.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\001.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\002 (1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\003 (3).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\004 (3).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\005 (3).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\006 (3).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\007 (1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\008 (2).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\010 (2).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\012 (2).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\013.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\014 (3).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\015 (1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\018.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\019.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\022.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\023 (2).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\004 (2).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\005 (1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\006.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\008.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\010 (1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\011 (3).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\012.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\013 (2).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\015.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\014 (1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\016 (1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\017 (2).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\018 (1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\019 (2).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\020 (2).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\021 (2).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\023 (1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\024 (1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\028 (1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\029.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\030.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\001 (3).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\001 (2).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\004.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\005.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\006 (1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\007 (2).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\008 (1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\009.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\010.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\011.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\012 (3).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\013 (3).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\014.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\016.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\017 (1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\018 (2).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\020.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\022 (1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\023.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\024.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\025.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\027.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\028.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\029 (1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\0000000001.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\001 2ay sa3a b 13.5.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\014 (4).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\028 (2).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\036.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\039.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\041.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\043.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\048.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\050.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\051.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\052.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\053.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\056.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\057.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\058.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\061.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\062.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\063.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\072.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\073.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\074.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\075.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\086.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\088.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\091.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\ALI.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\114.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\118.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\119.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\120.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\121.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\2014.11.07_054655.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20150418-WA0000.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\mp4.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\mp4 (1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\dfgdfgdfg.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\003 (4).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\001 (4).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\00002222.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\00003333.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\444444444.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\2016.04.23_000332.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\0222222.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\The.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\09.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\No Child's Behind Is Left 2.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\02 - sherif.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\received_1244079818975451.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\iced2.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\take my wife.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\dupingrandom2.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\for son2.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\googlephotos-f7ea52d40020ac5e1aae5765855f716ce111e216.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\received_420827474750213.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\received_10154585515562162.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\rubs the lotion on it's skin.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\this song is about you.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\06 - final.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\emzy emz.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20151002-WA0014.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\20151227-000042.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\20160105-000008.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\20160501-000006.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\20160502-000037.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\videoplayback.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\162.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\0111.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\042.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\2010.11.20 02-45-08.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\2010.11.20 02-45-07.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\2010.11.20 02-45-09.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\2010.11.20 02-45-10.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\2010.11.20 02-45-071.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\2010.11.20 02-45-081.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\2010.11.20 02-45-072.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\2010.11.20 02-45-091.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\2010.11.20 02-45-092.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\2011.01.30 00-00-00.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\2011.02.02 00-00-00.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\2011.03.27 00-00-00.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\DSCN6496.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\MOV00521.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\MOV00524(1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\MOV00525.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\MOV00526.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\MOV00526(1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\MOV01282.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\Untitled (3).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\WhatsApp Video 2017-04-06 at 10.26.56 PM.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\WhatsApp Video 2017-04-06 at 10.26.56 PM (1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\123.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20170416-WA0000.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\received_1559573094092787.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20170501-WA0001.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID_23360710_025532_295.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID_40010302_210319_775.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\06 - Friday Tuqa.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\163.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\165.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID_22880216_062434_084.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID_130880318_021410_833.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID_31441125_075644_379.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\166.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\I dont like the jews.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\omaressamlhc - BTZFfUbAvxP.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID_29180611_232709_133.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20171129-WA0002.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID_33350201_205539_938.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID_53050705_060732_907.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID_22231212_013429_572.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID_32341211_150021_755.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\001 - Seks.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180416-WA0086.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180427-WA0160.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180427-WA0156.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180427-WA0157.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180425-WA0015.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180425-WA0016.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180425-WA0014.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180424-WA0052.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180424-WA0027.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180424-WA0022.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180424-WA0020.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180423-WA0039.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180422-WA0045.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180420-WA0006.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\06OmarCore1\Video\VID-20180419-WA0094.mp4 -> unknown (Exception: name '__file__' is not defined)
# ...
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\09NadaCore1\Video\VID_20200315_220719.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\09NadaCore1\Video\VID_20200315_221148.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\09NadaCore1\Video\VID_20200315_221347.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\09NadaCore1\Video\VID_20200315_221630.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\09NadaCore1\Video\VID_20200703_082735.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\09NadaCore1\Video\VID_20200709_153814.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\09NadaCore1\Video\VID_20200716_134147.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\09NadaCore1\Video\VID_20201101_000917.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\09NadaCore1\Video\VID_20201101_000959.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\09NadaCore1\Video\VID_44280204_000350_393.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\09NadaCore1\Video\VID_44611205_143632_137.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\09NadaCore1\Video\VID_51430520_050847_948.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\09NadaCore1\Video\YouCut_20200321_222745900.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\09NadaCore1\Video\YouCut_20200321_223537834.mp4 -> unknown (Exception: name '__file__' is not defined)
# [39/42] Merging 720 videos in: G:/My Drive/P-core\09NadaCore1\Video (Resolution: unknown)
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4"
# [39/42] Merged video saved to: D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4
# [39/42] Uploading video to YouTube: My Drive - P-core - 09NadaCore1 - Video - Part 01
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 1% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 2% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 3% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 4% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 6% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 7% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 8% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 9% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 11% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 12% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 13% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 14% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 16% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 17% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 18% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 19% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 20% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 22% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 23% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 24% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 25% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 27% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 28% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 29% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 30% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 32% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 33% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 34% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 35% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 36% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 38% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 39% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 40% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 41% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 43% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 44% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 45% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 46% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 48% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 49% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 50% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 51% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 53% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 54% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 55% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 56% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 57% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 59% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 60% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 61% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 62% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 64% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 65% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 66% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 67% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 69% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 70% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 71% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 72% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 73% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 75% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 76% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 77% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 78% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 80% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 81% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 82% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 83% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 85% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 86% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 87% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 88% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 89% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 91% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 92% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 93% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 94% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 96% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 97% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 98% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4: 99% done.
# Upload Complete: D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4
# [39/42] Upload complete: My Drive - P-core - 09NadaCore1 - Video - Part 01
# [39/42] Deleted merged video: D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.mp4
# [39/42] Wrote YouTube link to: D:/merged\My Drive - P-core - 09NadaCore1 - Video - Part 01.txt
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\09NadaCore1\VideoNew\20240429_173123.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\09NadaCore1\VideoNew\20240606_063603.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\09NadaCore1\VideoNew\Screen_Recording_20240609_210336_Pinterest.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\09NadaCore1\VideoNew\Screen_Recording_20240614_160915.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\09NadaCore1\VideoNew\VID20240713204930.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\09NadaCore1\VideoNew\VID20240713205642.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\09NadaCore1\VideoNew\VID_44280204_000350_393 (1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\09NadaCore1\VideoNew\VID_44280204_000350_393.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\09NadaCore1\VideoNew\YouCut_20240319_202038110.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\09NadaCore1\VideoNew\YouCut_20240404_232123224.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\09NadaCore1\VideoNew\YouCut_20240407_140946451.mp4 -> unknown (Exception: name '__file__' is not defined)
# [40/42] Merging 11 videos in: G:/My Drive/P-core\09NadaCore1\VideoNew (Resolution: unknown)
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\My Drive - P-core - 09NadaCore1 - VideoNew - Part 01.mp4"
# [40/42] Merged video saved to: D:/merged\My Drive - P-core - 09NadaCore1 - VideoNew - Part 01.mp4
# [40/42] Uploading video to YouTube: My Drive - P-core - 09NadaCore1 - VideoNew - Part 01
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - VideoNew - Part 01.mp4: 29% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - VideoNew - Part 01.mp4: 59% done.
# Uploading D:/merged\My Drive - P-core - 09NadaCore1 - VideoNew - Part 01.mp4: 89% done.
# Upload Complete: D:/merged\My Drive - P-core - 09NadaCore1 - VideoNew - Part 01.mp4
# [40/42] Upload complete: My Drive - P-core - 09NadaCore1 - VideoNew - Part 01
# [40/42] Deleted merged video: D:/merged\My Drive - P-core - 09NadaCore1 - VideoNew - Part 01.mp4
# [40/42] Wrote YouTube link to: D:/merged\My Drive - P-core - 09NadaCore1 - VideoNew - Part 01.txt
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\09NadaNotCamera\Image\00screenshots\SVID_20210118_115103_1.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\09NadaNotCamera\Image\00screenshots\SVID_20210121_185613_1.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\09NadaNotCamera\Image\00screenshots\SVID_20210303_224510_1.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\09NadaNotCamera\Image\00screenshots\SVID_20210303_224608_1.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\09NadaNotCamera\Image\00screenshots\SVID_20210324_133600_1.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\09NadaNotCamera\Image\00screenshots\SVID_20210330_180629_1.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\09NadaNotCamera\Image\00screenshots\SVID_20210630_002200_1.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\09NadaNotCamera\Image\00screenshots\SVID_20210708_160505_1.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\09NadaNotCamera\Image\00screenshots\SVID_20210731_004059_1.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\09NadaNotCamera\Image\00screenshots\SVID_20210731_180309_1.mp4 -> unknown (Exception: name '__file__' is not defined)
# [41/42] Merging 10 videos in: G:/My Drive/P-core\09NadaNotCamera\Image\00screenshots (Resolution: unknown)
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\P-core - 09NadaNotCamera - Image - 00screenshots - Part 01.mp4"
# [41/42] Merged video saved to: D:/merged\P-core - 09NadaNotCamera - Image - 00screenshots - Part 01.mp4
# [41/42] Uploading video to YouTube: P-core - 09NadaNotCamera - Image - 00screenshots - Part 01
# Uploading D:/merged\P-core - 09NadaNotCamera - Image - 00screenshots - Part 01.mp4: 44% done.
# Uploading D:/merged\P-core - 09NadaNotCamera - Image - 00screenshots - Part 01.mp4: 89% done.
# Upload Complete: D:/merged\P-core - 09NadaNotCamera - Image - 00screenshots - Part 01.mp4
# [41/42] Upload complete: P-core - 09NadaNotCamera - Image - 00screenshots - Part 01
# [41/42] Deleted merged video: D:/merged\P-core - 09NadaNotCamera - Image - 00screenshots - Part 01.mp4
# [41/42] Wrote YouTube link to: D:/merged\P-core - 09NadaNotCamera - Image - 00screenshots - Part 01.txt
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\09NadaNotCamera\Video\MOVIE.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/P-core\09NadaNotCamera\Video\VID-20190727-WA0000.mp4 -> unknown (Exception: name '__file__' is not defined)
# [42/42] Merging 2 videos in: G:/My Drive/P-core\09NadaNotCamera\Video (Resolution: unknown)
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\My Drive - P-core - 09NadaNotCamera - Video - Part 01.mp4"
# [42/42] Merged video saved to: D:/merged\My Drive - P-core - 09NadaNotCamera - Video - Part 01.mp4
# [42/42] Uploading video to YouTube: My Drive - P-core - 09NadaNotCamera - Video - Part 01
# Upload Complete: D:/merged\My Drive - P-core - 09NadaNotCamera - Video - Part 01.mp4
# [42/42] Upload complete: My Drive - P-core - 09NadaNotCamera - Video - Part 01
# [42/42] Deleted merged video: D:/merged\My Drive - P-core - 09NadaNotCamera - Video - Part 01.mp4
# [42/42] Wrote YouTube link to: D:/merged\My Drive - P-core - 09NadaNotCamera - Video - Part 01.txt
# Processing complete. See processed_folders.json for details.
