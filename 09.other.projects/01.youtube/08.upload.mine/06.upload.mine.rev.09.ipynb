# %%
import os
import pickle
import tkinter as tk
from tkinter import filedialog
import subprocess
import shlex
import json
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload
from google.auth.transport.requests import Request

SCOPES = ['https://www.googleapis.com/auth/youtube.upload']
CLIENT_SECRETS_FILE = 'client_secret.emc.json'
VIDEO_EXTENSIONS = ['.mp4', '.mov', '.avi', '.mkv', '.flv', '.wmv']
MERGED_OUTPUT_DIR = 'D:/merged'
PROCESSED_JSON = os.path.join(MERGED_OUTPUT_DIR, 'processed_folders.json')

os.makedirs(MERGED_OUTPUT_DIR, exist_ok=True)

def get_parent_directory():
    root = tk.Tk()
    root.withdraw()
    directory = filedialog.askdirectory(title="Select Parent Directory to Scan for Video Folders")
    root.destroy()
    return directory

def find_video_folders(parent_dir):
    video_folders = []
    for root, dirs, files in os.walk(parent_dir):
        if any(file.lower().endswith(tuple(VIDEO_EXTENSIONS)) for file in files):
            video_folders.append(root)
    return video_folders

def find_videos_by_resolution(directory):
    video_files = []
    for root, _, files in os.walk(directory):
        for file in files:
            if any(file.lower().endswith(ext) for ext in VIDEO_EXTENSIONS):
                video_files.append(os.path.join(root, file))
    # Group by resolution
    resolution_groups = {}
    for vf in video_files:
        try:
            result = subprocess.run([
                'python', os.path.join(os.path.dirname(__file__), 'ffprobe_resolution.py'), vf
            ], capture_output=True, text=True)
            if result.returncode == 0:
                res = result.stdout.strip()
                print(f"[RESOLUTION] {vf} -> {res}")
            else:
                res = 'unknown'
                print(f"[RESOLUTION-ERROR] {vf} -> unknown (ffprobe error: {result.stderr.strip()})")
        except Exception as e:
            res = 'unknown'
            print(f"[RESOLUTION-EXCEPTION] {vf} -> unknown (Exception: {e})")
        if res not in resolution_groups:
            resolution_groups[res] = []
        resolution_groups[res].append(vf)
    return resolution_groups

def merge_videos_ffmpeg(video_files, output_path):
    filelist_path = 'ffmpeg_filelist.txt'
    with open(filelist_path, 'w', encoding='utf-8') as f:
        for vf in video_files:
            f.write(f"file '{vf.replace('\\', '/').replace("'", "'\\''")}'\n")
    cmd = f"ffmpeg -f concat -safe 0 -i {filelist_path} -c copy \"{output_path}\""
    print(f"Running: {cmd}")
    result = subprocess.run(shlex.split(cmd), capture_output=True, text=True)
    if result.returncode != 0:
        print('ffmpeg error:', result.stderr)
        raise RuntimeError('ffmpeg merge failed')
    os.remove(filelist_path)

def authenticate_youtube():
    creds = None
    if os.path.exists('token.pickle'):
        with open('token.pickle', 'rb') as token:
            creds = pickle.load(token)
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(CLIENT_SECRETS_FILE, SCOPES)
            creds = flow.run_local_server(port=0)
        with open('token.pickle', 'wb') as token:
            pickle.dump(creds, token)
    return build('youtube', 'v3', credentials=creds)

def get_last_4_folders(path):
    parts = os.path.normpath(path).split(os.sep)
    return ' - '.join(parts[-4:]) if len(parts) >= 4 else os.path.basename(path)

def upload_video(youtube, file_path, title):
    body = {
        'snippet': {
            'title': title,
            'description': 'Merged video uploaded by automated script',
            'tags': [],
            'categoryId': '22'
        },
        'status': {
            'privacyStatus': 'private'
        }
    }
    media = MediaFileUpload(file_path, resumable=True)
    request = youtube.videos().insert(
        part=','.join(body.keys()),
        body=body,
        media_body=media
    )
    response = None
    try:
        while response is None:
            status, response = request.next_chunk()
            if status:
                print(f"Uploading {file_path}: {int(status.progress() * 100)}% done.")
        print(f"Upload Complete: {file_path}")
        # Compose YouTube link if upload succeeded
        video_id = response.get('id') if response else None
        youtube_url = f'https://youtu.be/{video_id}' if video_id else None
        return response, youtube_url, None
    except Exception as e:
        # Check for quota errors in the error message
        error_msg = str(e)
        if 'quota' in error_msg.lower() or 'quotaexceeded' in error_msg.lower():
            return None, None, 'quota'
        return None, None, error_msg

def load_processed():
    if os.path.exists(PROCESSED_JSON):
        with open(PROCESSED_JSON, 'r', encoding='utf-8') as f:
            return json.load(f)
    return {}

def save_processed(processed):
    with open(PROCESSED_JSON, 'w', encoding='utf-8') as f:
        json.dump(processed, f, indent=2, ensure_ascii=False)

def main():
    parent_dir = get_parent_directory()
    if not parent_dir:
        print("No parent directory selected. Exiting.")
        return
    video_folders = find_video_folders(parent_dir)
    if not video_folders:
        print("No folders with videos found.")
        return
    processed = load_processed()
    youtube = authenticate_youtube()
    total_folders = len(video_folders)
    quota_reached = False
    for idx, folder in enumerate(video_folders, 1):
        # Support both old (flat) and new (parts) processed structures
        skip_folder = False
        if folder in processed:
            entry = processed[folder]
            if isinstance(entry, dict):
                # Old style: flat dict with 'status'
                if 'status' in entry and entry['status'] == 'uploaded':
                    skip_folder = True
                # New style: dict of parts
                elif all(isinstance(v, dict) and v.get('status') == 'uploaded' for v in entry.values()):
                    skip_folder = True
        if skip_folder:
            print(f"[{idx}/{total_folders}] Skipping already processed folder: {folder}")
            continue
        res_groups = find_videos_by_resolution(folder)
        if not res_groups or all(len(vs) == 0 for vs in res_groups.values()):
            processed[folder] = {'status': 'no_videos', 'title': None}
            save_processed(processed)
            continue
        processed[folder] = processed.get(folder, {})
        num_res_groups = len([v for v in res_groups.values() if v])
        part_number = 1
        for res, videos in res_groups.items():
            if not videos:
                continue
            # Determine if we need to use "Part xx" in the title
            use_part = num_res_groups > 1
            part_key_base = f"{res}" if not use_part else f"part_{part_number:02d}_{res}"
            if part_key_base in processed[folder] and processed[folder][part_key_base].get('status') == 'uploaded':
                print(f"[{idx}/{total_folders}] Skipping already processed part: {part_key_base} in {folder}")
                part_number += 1
                continue
            # Title logic
            base_title = get_last_4_folders(folder)
            if res != 'unknown':
                base_title += f" ({res})"
            merged_title = base_title
            if use_part:
                merged_title = f"{base_title} - Part {part_number:02d}"
            merged_path = os.path.join(MERGED_OUTPUT_DIR, merged_title + '.mp4')
            print(f"[{idx}/{total_folders}] Merging {len(videos)} videos in: {folder} (Resolution: {res})")
            try:
                merge_videos_ffmpeg(videos, merged_path)
                print(f"[{idx}/{total_folders}] Merged video saved to: {merged_path}")
                # Check duration and split if needed
                split_proc = subprocess.run([
                    'python', os.path.join(os.path.dirname(__file__), 'split_video_ffmpeg.py'), merged_path, '43200'
                ], capture_output=True, text=True)
                split_files = [merged_path]
                if split_proc.returncode == 0:
                    split_files = [line.strip() for line in split_proc.stdout.splitlines() if line.strip()]
                part_suffix = 'a'
                for split_idx, split_file in enumerate(split_files):
                    this_title = merged_title if len(split_files) == 1 else f"{merged_title}{chr(97+split_idx)}"
                    print(f"[{idx}/{total_folders}] Uploading video to YouTube: {this_title}")
                    response, youtube_url, upload_status = upload_video(youtube, split_file, this_title)
                    split_key = part_key if len(split_files) == 1 else f"{part_key}{chr(97+split_idx)}"
                    if upload_status == 'quota':
                        print(f"[{idx}/{total_folders}] Quota exceeded. Stopping further uploads.")
                        processed[folder][split_key] = {'status': 'quota', 'title': this_title}
                        quota_reached = True
                        save_processed(processed)
                        break
                    elif youtube_url:
                        print(f"[{idx}/{total_folders}] Upload complete: {this_title}")
                        processed[folder][split_key] = {'status': 'uploaded', 'title': this_title, 'youtube_url': youtube_url}
                    else:
                        print(f"[{idx}/{total_folders}] Upload failed: {this_title} ({upload_status})")
                        processed[folder][split_key] = {'status': 'failed', 'title': this_title, 'error': upload_status}
                    save_processed(processed)
                    # Only cleanup and create .txt file if upload succeeded and link is available
                    if processed[folder][split_key].get('status') == 'uploaded' and os.path.exists(split_file):
                        os.remove(split_file)
                        print(f"[{idx}/{total_folders}] Deleted merged video: {split_file}")
                        txt_path = os.path.splitext(split_file)[0] + ".txt"
                        with open(txt_path, 'w', encoding='utf-8') as f:
                            f.write(f"YouTube Link: {processed[folder][split_key]['youtube_url']}\n")
                        print(f"[{idx}/{total_folders}] Wrote YouTube link to: {txt_path}")
                    if quota_reached:
                        break
                if quota_reached:
                    break
            except Exception as e:
                print(f"[{idx}/{total_folders}] Failed to process {folder} part {part_number}: {e}")
                processed[folder][part_key] = {'status': 'failed', 'title': merged_title, 'error': str(e)}
                youtube_url = None
            save_processed(processed)
            part_number += 1
        save_processed(processed)
        if quota_reached:
            break
    print("Processing complete. See processed_folders.json for details.")

if __name__ == '__main__':
    main()
# Out:
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\4.0 - Screenshots\xorganize3\Screen_Recording_20240507_205954_Facebook.mp4 -> unknown (Exception: name '__file__' is not defined)
# [1/132] Merging 1 videos in: G:/My Drive/Mega\4.0 - Screenshots\xorganize3 (Resolution: unknown)
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\My Drive - Mega - 4.0 - Screenshots - xorganize3 - Part 01.mp4"
# [1/132] Merged video saved to: D:/merged\My Drive - Mega - 4.0 - Screenshots - xorganize3 - Part 01.mp4
# [1/132] Failed to process G:/My Drive/Mega\4.0 - Screenshots\xorganize3 part 1: name '__file__' is not defined
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\07OmarNotCamera\Video\ScreenRecord\20180224_202841.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\07OmarNotCamera\Video\ScreenRecord\20180224_203022.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\07OmarNotCamera\Video\ScreenRecord\20180224_203140.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\07OmarNotCamera\Video\ScreenRecord\20180224_203256.mp4 -> unknown (Exception: name '__file__' is not defined)
# [2/132] Merging 4 videos in: G:/My Drive/Mega\07OmarNotCamera\Video\ScreenRecord (Resolution: unknown)
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\Mega - 07OmarNotCamera - Video - ScreenRecord - Part 01.mp4"
# [2/132] Merged video saved to: D:/merged\Mega - 07OmarNotCamera - Video - ScreenRecord - Part 01.mp4
# [2/132] Failed to process G:/My Drive/Mega\07OmarNotCamera\Video\ScreenRecord part 1: name '__file__' is not defined
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\omarvideo\VID-20180408-WA0059.mp4 -> unknown (Exception: name '__file__' is not defined)
# [3/132] Merging 1 videos in: G:/My Drive/Mega\C\omarvideo (Resolution: unknown)
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\My Drive - Mega - C - omarvideo - Part 01.mp4"
# [3/132] Merged video saved to: D:/merged\My Drive - Mega - C - omarvideo - Part 01.mp4
# [3/132] Failed to process G:/My Drive/Mega\C\omarvideo part 1: name '__file__' is not defined
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\09\xorganize01\Avikah Kano - 1001158004973467(540p).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\09\xorganize01\Facebook 1672059330265326(HD).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\09\xorganize01\Facebook 964165352117007(HD).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\09\xorganize01\Facebook 7523612031038742(HD).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\09\xorganize01\Ecosystem Gossips - 813838080304865(720p).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\09\xorganize01\Facebook PraiseTheFrom(720p).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\09\xorganize01\Facebook 256070236595923(HD).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\09\xorganize01\Facebook 1371170016259628(720p).mp4 -> unknown (Exception: name '__file__' is not defined)
# [4/132] Merging 8 videos in: G:/My Drive/Mega\C\09\xorganize01 (Resolution: unknown)
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\Mega - C - 09 - xorganize01 - Part 01.mp4"
# [4/132] Merged video saved to: D:/merged\Mega - C - 09 - xorganize01 - Part 01.mp4
# [4/132] Failed to process G:/My Drive/Mega\C\09\xorganize01 part 1: name '__file__' is not defined
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\09\xorganize04\Shehap EldIn A Mohammedd - 😂😂😂😂😂😂😂😂😂😂😂😂 - 1301784694111186(HD).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\09\xorganize04\السنبلاوين اون لاين - ‏الف مبروووك بس ماله الزيت __ - 1151324152852086(720p).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\09\xorganize04\VID-20240217-WA0000.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\09\xorganize04\VID-20240216-WA0001.mp4 -> unknown (Exception: name '__file__' is not defined)
# [5/132] Merging 4 videos in: G:/My Drive/Mega\C\09\xorganize04 (Resolution: unknown)
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\Mega - C - 09 - xorganize04 - Part 01.mp4"
# [5/132] Merged video saved to: D:/merged\Mega - C - 09 - xorganize04 - Part 01.mp4
# [5/132] Failed to process G:/My Drive/Mega\C\09\xorganize04 part 1: name '__file__' is not defined
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\11.2025\Beautiful cabin crew ��� Scarlett Johansson�� _Art _Artist _ArtGallery... _Painting _Imagination _BOOMchallange _MeganFox _CabinCrewTraining(HD).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\11.2025\VID-20250403-WA0000.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\11.2025\VID-20250416-WA0000.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\11.2025\VID-20250419-WA0003.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\11.2025\VID-20250501-WA0000.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\11.2025\VID-20250419-WA0027.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\11.2025\VID-20250506-WA0000.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\11.2025\Screen_Recording_20250410_152014_Teams.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\11.2025\VID-20250419-WA0029.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\11.2025\VID-20250419-WA0015.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\11.2025\VID-20250516-WA0005.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\11.2025\VID-20250411-WA0004.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\11.2025\VID-20250501-WA0007.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\11.2025\Ziad Elgendy(360p).MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\11.2025\VID-20250306-WA0004.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\11.2025\VID-20250407-WA0015.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\11.2025\VID-20250407-WA0005.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\11.2025\Unconfirmed_download_https___www.facebook.com_share_r_18oBB5CoBn_(HD).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\11.2025\VID-20250419-WA0032.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\11.2025\VID-20250429-WA0007.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\11.2025\VID-20250330-WA0000.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\11.2025\VID-20250419-WA0002.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\11.2025\VID-20250328-WA0001.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\11.2025\Screen_Recording_20250326_113320_YouTube.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\11.2025\VID20250306121928.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\11.2025\VID-20250427-WA0011.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\11.2025\VID20241217171901.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\11.2025\VID-20250516-WA0006.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\11.2025\VID20241217172001.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\11.2025\VID20241217171753.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\11.2025\دكتور محمود صلاح(720P_HD).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\11.2025\VID20241217171935.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\11.2025\VID20250227161502.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\C\11.2025\VID20241217172202.mp4 -> unknown (Exception: name '__file__' is not defined)
# [6/132] Merging 34 videos in: G:/My Drive/Mega\C\11.2025 (Resolution: unknown)
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\My Drive - Mega - C - 11.2025 - Part 01.mp4"
# [6/132] Merged video saved to: D:/merged\My Drive - Mega - C - 11.2025 - Part 01.mp4
# [6/132] Failed to process G:/My Drive/Mega\C\11.2025 part 1: name '__file__' is not defined
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\1.0 - Image\05.D-Albums\Me\The.avi -> unknown (Exception: name '__file__' is not defined)
# [7/132] Merging 1 videos in: G:/My Drive/Mega\1.0 - Image\05.D-Albums\Me (Resolution: unknown)
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\Mega - 1.0 - Image - 05.D-Albums - Me - Part 01.mp4"
# [7/132] Merged video saved to: D:/merged\Mega - 1.0 - Image - 05.D-Albums - Me - Part 01.mp4
# [7/132] Failed to process G:/My Drive/Mega\1.0 - Image\05.D-Albums\Me part 1: name '__file__' is not defined
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\America\009.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\America\016.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\America\025.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\America\blacks for trump.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\America\Brian Williams is ‘guided by the beauty of our weapons’ in Syria strikes.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\America\Bush Fool Me Once.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\America\Colbert racial insensitivity.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\America\hilary snl.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\America\MetalTrump - Holy Wars - YouTube.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\America\Nick Breckon (@nickbreckon) - Twitter.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\America\the american south.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\America\The Great Meme War of 2016.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\America\Trump Russia Possible Collusion (REMIX).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\America\US Acting Assistant Secretary of State Stuart Jones fails to respond about democracy in Saudi Arabia.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\America\Watch Obama dig into Trump at the 2011 White House Corres... - YouTube.mp4 -> unknown (Exception: name '__file__' is not defined)
# [8/132] Merging 15 videos in: G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\America (Resolution: unknown)
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\2.0 - Video - 2.01 - M-Albums - 2.01 - Politics And War - America - Part 01.mp4"
# [8/132] Merged video saved to: D:/merged\2.0 - Video - 2.01 - M-Albums - 2.01 - Politics And War - America - Part 01.mp4
# [8/132] Failed to process G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\America part 1: name '__file__' is not defined
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\Canada\people kind.mp4 -> unknown (Exception: name '__file__' is not defined)
# [9/132] Merging 1 videos in: G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\Canada (Resolution: unknown)
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\2.0 - Video - 2.01 - M-Albums - 2.01 - Politics And War - Canada - Part 01.mp4"
# [9/132] Merged video saved to: D:/merged\2.0 - Video - 2.01 - M-Albums - 2.01 - Politics And War - Canada - Part 01.mp4
# [9/132] Failed to process G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\Canada part 1: name '__file__' is not defined
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\Communists\23683411_307971053054886_1434424527453945856_n.mp4 -> unknown (Exception: name '__file__' is not defined)
# [10/132] Merging 1 videos in: G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\Communists (Resolution: unknown)
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\2.0 - Video - 2.01 - M-Albums - 2.01 - Politics And War - Communists - Part 01.mp4"
# [10/132] Merged video saved to: D:/merged\2.0 - Video - 2.01 - M-Albums - 2.01 - Politics And War - Communists - Part 01.mp4
# [10/132] Failed to process G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\Communists part 1: name '__file__' is not defined
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\Hippies\Grace Slick Interview @ Kralingen Music Festival June 1970-converted.mp4 -> unknown (Exception: name '__file__' is not defined)
# [11/132] Merging 1 videos in: G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\Hippies (Resolution: unknown)
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\2.0 - Video - 2.01 - M-Albums - 2.01 - Politics And War - Hippies - Part 01.mp4"
# [11/132] Merged video saved to: D:/merged\2.0 - Video - 2.01 - M-Albums - 2.01 - Politics And War - Hippies - Part 01.mp4
# [11/132] Failed to process G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\Hippies part 1: name '__file__' is not defined
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\Isreal\008.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\Isreal\174.mp4 -> unknown (Exception: name '__file__' is not defined)
# [12/132] Merging 2 videos in: G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\Isreal (Resolution: unknown)
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\2.0 - Video - 2.01 - M-Albums - 2.01 - Politics And War - Isreal - Part 01.mp4"
# [12/132] Merged video saved to: D:/merged\2.0 - Video - 2.01 - M-Albums - 2.01 - Politics And War - Isreal - Part 01.mp4
# [12/132] Failed to process G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\Isreal part 1: name '__file__' is not defined
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\Nazis\167.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\Nazis\Holding Back The Night.mp4 -> unknown (Exception: name '__file__' is not defined)
# [13/132] Merging 2 videos in: G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\Nazis (Resolution: unknown)
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\2.0 - Video - 2.01 - M-Albums - 2.01 - Politics And War - Nazis - Part 01.mp4"
# [13/132] Merged video saved to: D:/merged\2.0 - Video - 2.01 - M-Albums - 2.01 - Politics And War - Nazis - Part 01.mp4
# [13/132] Failed to process G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\Nazis part 1: name '__file__' is not defined
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\Russia\144.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\Russia\147.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\Russia\177.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\Russia\music of the world.mp4 -> unknown (Exception: name '__file__' is not defined)
# [14/132] Merging 4 videos in: G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\Russia (Resolution: unknown)
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\2.0 - Video - 2.01 - M-Albums - 2.01 - Politics And War - Russia - Part 01.mp4"
# [14/132] Merged video saved to: D:/merged\2.0 - Video - 2.01 - M-Albums - 2.01 - Politics And War - Russia - Part 01.mp4
# [14/132] Failed to process G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\Russia part 1: name '__file__' is not defined
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\Syria\fake syria in port said.mp4 -> unknown (Exception: name '__file__' is not defined)
# [15/132] Merging 1 videos in: G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\Syria (Resolution: unknown)
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\2.0 - Video - 2.01 - M-Albums - 2.01 - Politics And War - Syria - Part 01.mp4"
# [15/132] Merged video saved to: D:/merged\2.0 - Video - 2.01 - M-Albums - 2.01 - Politics And War - Syria - Part 01.mp4
# [15/132] Failed to process G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\Syria part 1: name '__file__' is not defined
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\Terrorism\Terrorists are building drones. France is destroying them with eagles. - The Washington Post.mp4 -> unknown (Exception: name '__file__' is not defined)
# [16/132] Merging 1 videos in: G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\Terrorism (Resolution: unknown)
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\2.0 - Video - 2.01 - M-Albums - 2.01 - Politics And War - Terrorism - Part 01.mp4"
# [16/132] Merged video saved to: D:/merged\2.0 - Video - 2.01 - M-Albums - 2.01 - Politics And War - Terrorism - Part 01.mp4
# [16/132] Failed to process G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\Terrorism part 1: name '__file__' is not defined
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\WWII\tom germany jerry soviet union.mp4 -> unknown (Exception: name '__file__' is not defined)
# [17/132] Merging 1 videos in: G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\WWII (Resolution: unknown)
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\2.0 - Video - 2.01 - M-Albums - 2.01 - Politics And War - WWII - Part 01.mp4"
# [17/132] Merged video saved to: D:/merged\2.0 - Video - 2.01 - M-Albums - 2.01 - Politics And War - WWII - Part 01.mp4
# [17/132] Failed to process G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.01 - Politics And War\WWII part 1: name '__file__' is not defined
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\7'ara\047.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\7'ara\17720578_1316617085080942_4778484389082300416_n.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\7'ara\181.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\7'ara\Islam Aysha.mp4 -> unknown (Exception: name '__file__' is not defined)
# [18/132] Merging 4 videos in: G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\7'ara (Resolution: unknown)
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\2.0 - Video - 2.01 - M-Albums - 2.02 - Progressives And Islam - 7'ara - Part 01.mp4"
# [18/132] Merged video saved to: D:/merged\2.0 - Video - 2.01 - M-Albums - 2.02 - Progressives And Islam - 7'ara - Part 01.mp4
# [18/132] Failed to process G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\7'ara part 1: name '__file__' is not defined
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Allah Akbar ISIS\017.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Allah Akbar ISIS\019.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Allah Akbar ISIS\036.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Allah Akbar ISIS\046.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Allah Akbar ISIS\allah akbar compilation.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Allah Akbar ISIS\Brick in Washing Machine.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Allah Akbar ISIS\HeadBang From Muslims.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Allah Akbar ISIS\Saleel El Sawarem Ra2asa.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Allah Akbar ISIS\Skrillex - Allahu Akbar - YouTube-converted.mp4 -> unknown (Exception: name '__file__' is not defined)
# [19/132] Merging 9 videos in: G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Allah Akbar ISIS (Resolution: unknown)
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\2.0 - Video - 2.01 - M-Albums - 2.02 - Progressives And Islam - Allah Akbar ISIS - Part 01.mp4"
# [19/132] Merged video saved to: D:/merged\2.0 - Video - 2.01 - M-Albums - 2.02 - Progressives And Islam - Allah Akbar ISIS - Part 01.mp4
# [19/132] Failed to process G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Allah Akbar ISIS part 1: name '__file__' is not defined
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Atheism\008.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Atheism\032.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Atheism\Esmaha Tabe3ah!.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Atheism\god is dead.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Atheism\Jowan Safadi with Pics.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Atheism\Jowan Safadi.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Atheism\masry mol7ed 7'awater.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Atheism\sagan allah allah.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Atheism\Soret El Nudes.mp4 -> unknown (Exception: name '__file__' is not defined)
# [20/132] Merging 9 videos in: G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Atheism (Resolution: unknown)
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\2.0 - Video - 2.01 - M-Albums - 2.02 - Progressives And Islam - Atheism - Part 01.mp4"
# [20/132] Merged video saved to: D:/merged\2.0 - Video - 2.01 - M-Albums - 2.02 - Progressives And Islam - Atheism - Part 01.mp4
# [20/132] Failed to process G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Atheism part 1: name '__file__' is not defined
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\De7k\02.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\De7k\03.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\De7k\05.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\De7k\111.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\De7k\2.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\De7k\5.mp4 -> unknown (Exception: name '__file__' is not defined)
# [21/132] Merging 6 videos in: G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\De7k (Resolution: unknown)
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\2.0 - Video - 2.01 - M-Albums - 2.02 - Progressives And Islam - De7k - Part 01.mp4"
# [21/132] Merged video saved to: D:/merged\2.0 - Video - 2.01 - M-Albums - 2.02 - Progressives And Islam - De7k - Part 01.mp4
# [21/132] Failed to process G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\De7k part 1: name '__file__' is not defined
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Jesus\17605867_285980398496212_1043222924560957440_n.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Jesus\55555 Kenesah.mp4 -> unknown (Exception: name '__file__' is not defined)
# [22/132] Merging 2 videos in: G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Jesus (Resolution: unknown)
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\2.0 - Video - 2.01 - M-Albums - 2.02 - Progressives And Islam - Jesus - Part 01.mp4"
# [22/132] Merged video saved to: D:/merged\2.0 - Video - 2.01 - M-Albums - 2.02 - Progressives And Islam - Jesus - Part 01.mp4
# [22/132] Failed to process G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Jesus part 1: name '__file__' is not defined
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Liberal Islam\03.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Liberal Islam\176.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Liberal Islam\Brooklyn.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Liberal Islam\Gays Liberal Islam.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Liberal Islam\Linda Prophet Complete.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Liberal Islam\Linda Prophet Ten Ten.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Liberal Islam\New York.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Liberal Islam\oMv4agnSuHM1uBbb.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Liberal Islam\the liberal 2edrabhn.mp4 -> unknown (Exception: name '__file__' is not defined)
# [23/132] Merging 9 videos in: G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Liberal Islam (Resolution: unknown)
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\2.0 - Video - 2.01 - M-Albums - 2.02 - Progressives And Islam - Liberal Islam - Part 01.mp4"
# [23/132] Merged video saved to: D:/merged\2.0 - Video - 2.01 - M-Albums - 2.02 - Progressives And Islam - Liberal Islam - Part 01.mp4
# [23/132] Failed to process G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Liberal Islam part 1: name '__file__' is not defined
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Memri\Memri TV compilation debates - YouTube.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Memri\VID-20170408-WA0002.mp4 -> unknown (Exception: name '__file__' is not defined)
# [24/132] Merging 2 videos in: G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Memri (Resolution: unknown)
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\2.0 - Video - 2.01 - M-Albums - 2.02 - Progressives And Islam - Memri - Part 01.mp4"
# [24/132] Merged video saved to: D:/merged\2.0 - Video - 2.01 - M-Albums - 2.02 - Progressives And Islam - Memri - Part 01.mp4
# [24/132] Failed to process G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Memri part 1: name '__file__' is not defined
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Sheyoo7'\116.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Sheyoo7'\148.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Sheyoo7'\17498184_225599071250553_3837248714255106048_n.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Sheyoo7'\ali w mo3aywa fight.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Sheyoo7'\amr khaled meets qatari.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Sheyoo7'\amr khaled walahi bashta3'al.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Sheyoo7'\bla bla bla.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Sheyoo7'\h7FCnhtoi1oIEKit.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Sheyoo7'\psychedelic trippy islam.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Sheyoo7'\regl edit.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Sheyoo7'\regl full.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Sheyoo7'\saudi ofti talkin nonsense.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Sheyoo7'\shiaa.mp4 -> unknown (Exception: name '__file__' is not defined)
# [25/132] Merging 13 videos in: G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Sheyoo7' (Resolution: unknown)
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\2.0 - Video - 2.01 - M-Albums - 2.02 - Progressives And Islam - Sheyoo7' - Part 01.mp4"
# [25/132] Merged video saved to: D:/merged\2.0 - Video - 2.01 - M-Albums - 2.02 - Progressives And Islam - Sheyoo7' - Part 01.mp4
# [25/132] Failed to process G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\Sheyoo7' part 1: name '__file__' is not defined
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\UK\Prophet Robinson predicted the future again - YouTube.mp4 -> unknown (Exception: name '__file__' is not defined)
# [26/132] Merging 1 videos in: G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\UK (Resolution: unknown)
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\2.0 - Video - 2.01 - M-Albums - 2.02 - Progressives And Islam - UK - Part 01.mp4"
# [26/132] Merged video saved to: D:/merged\2.0 - Video - 2.01 - M-Albums - 2.02 - Progressives And Islam - UK - Part 01.mp4
# [26/132] Failed to process G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.02 - Progressives And Islam\UK part 1: name '__file__' is not defined
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Arabs\050.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Arabs\055.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Arabs\128.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Arabs\3alamat al tarkeem.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Arabs\arabs global warming.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Arabs\Arabs running funny - YouTube.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Arabs\Mickey Ra2s Multiculture.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Arabs\qadafy toktok.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Arabs\qadafy.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Arabs\the perfect murder.mp4 -> unknown (Exception: name '__file__' is not defined)
# [27/132] Merging 10 videos in: G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Arabs (Resolution: unknown)
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\2.0 - Video - 2.01 - M-Albums - 2.03 - Masr And Middle East - Arabs - Part 01.mp4"
# [27/132] Merged video saved to: D:/merged\2.0 - Video - 2.01 - M-Albums - 2.03 - Masr And Middle East - Arabs - Part 01.mp4
# [27/132] Failed to process G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Arabs part 1: name '__file__' is not defined
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Audio\me3'za yrbotha.mp4 -> unknown (Exception: name '__file__' is not defined)
# [28/132] Merging 1 videos in: G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Audio (Resolution: unknown)
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\2.0 - Video - 2.01 - M-Albums - 2.03 - Masr And Middle East - Audio - Part 01.mp4"
# [28/132] Merged video saved to: D:/merged\2.0 - Video - 2.01 - M-Albums - 2.03 - Masr And Middle East - Audio - Part 01.mp4
# [28/132] Failed to process G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Audio part 1: name '__file__' is not defined
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Magragan\15679030_751133938371070_2126346189791035392_n.mp4 -> unknown (Exception: name '__file__' is not defined)
# [29/132] Merging 1 videos in: G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Magragan (Resolution: unknown)
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\2.0 - Video - 2.01 - M-Albums - 2.03 - Masr And Middle East - Magragan - Part 01.mp4"
# [29/132] Merged video saved to: D:/merged\2.0 - Video - 2.01 - M-Albums - 2.03 - Masr And Middle East - Magragan - Part 01.mp4
# [29/132] Failed to process G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Magragan part 1: name '__file__' is not defined
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Masr Assholes\007.mp4 -> unknown (Exception: name '__file__' is not defined)
# [30/132] Merging 1 videos in: G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Masr Assholes (Resolution: unknown)
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\2.0 - Video - 2.01 - M-Albums - 2.03 - Masr And Middle East - Masr Assholes - Part 01.mp4"
# [30/132] Merged video saved to: D:/merged\2.0 - Video - 2.01 - M-Albums - 2.03 - Masr And Middle East - Masr Assholes - Part 01.mp4
# [30/132] Failed to process G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Masr Assholes part 1: name '__file__' is not defined
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Masr Charecters\AlZobaba Almal3onah.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Masr Charecters\El Laho El 7'afy\2nd complete.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Masr Charecters\El Laho El 7'afy\2nd spli.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Masr Charecters\Obama Masry\135.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Masr Charecters\Obama Masry\7'abar eh.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Masr Charecters\Obama Masry\car 1.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Masr Charecters\Obama Masry\gohanam.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Masr Charecters\Obama Masry\Made Combined Car.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Masr Charecters\Obama Masry\Obama El Masry gettin personal.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Masr Charecters\Obama Masry\sobhan allah.mp4 -> unknown (Exception: name '__file__' is not defined)
# [31/132] Merging 10 videos in: G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Masr Charecters (Resolution: unknown)
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\2.0 - Video - 2.01 - M-Albums - 2.03 - Masr And Middle East - Masr Charecters - Part 01.mp4"
# [31/132] Merged video saved to: D:/merged\2.0 - Video - 2.01 - M-Albums - 2.03 - Masr And Middle East - Masr Charecters - Part 01.mp4
# [31/132] Failed to process G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Masr Charecters part 1: name '__file__' is not defined
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Masr Charecters\El Laho El 7'afy\2nd complete.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Masr Charecters\El Laho El 7'afy\2nd spli.mp4 -> unknown (Exception: name '__file__' is not defined)
# [32/132] Merging 2 videos in: G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Masr Charecters\El Laho El 7'afy (Resolution: unknown)
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\2.01 - M-Albums - 2.03 - Masr And Middle East - Masr Charecters - El Laho El 7'afy - Part 01.mp4"
# [32/132] Merged video saved to: D:/merged\2.01 - M-Albums - 2.03 - Masr And Middle East - Masr Charecters - El Laho El 7'afy - Part 01.mp4
# [32/132] Failed to process G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Masr Charecters\El Laho El 7'afy part 1: name '__file__' is not defined
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Masr Charecters\Obama Masry\135.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Masr Charecters\Obama Masry\7'abar eh.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Masr Charecters\Obama Masry\car 1.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Masr Charecters\Obama Masry\gohanam.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Masr Charecters\Obama Masry\Made Combined Car.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Masr Charecters\Obama Masry\Obama El Masry gettin personal.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Masr Charecters\Obama Masry\sobhan allah.mp4 -> unknown (Exception: name '__file__' is not defined)
# [33/132] Merging 7 videos in: G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Masr Charecters\Obama Masry (Resolution: unknown)
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\2.01 - M-Albums - 2.03 - Masr And Middle East - Masr Charecters - Obama Masry - Part 01.mp4"
# [33/132] Merged video saved to: D:/merged\2.01 - M-Albums - 2.03 - Masr And Middle East - Masr Charecters - Obama Masry - Part 01.mp4
# [33/132] Failed to process G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Masr Charecters\Obama Masry part 1: name '__file__' is not defined
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Masr Fadaye7\003.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Masr Fadaye7\015.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Masr Fadaye7\021.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Masr Fadaye7\145.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Masr Fadaye7\da7'let 7'na2a.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Masr Fadaye7\eh 2007.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\2.0 - Video\2.01 - M-Albums\2.03 - Masr And Middle East\Masr Fadaye7\la elah 2ela allah a7a.mp4 -> unknown (Exception: name '__file__' is not defined)
# ...
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\ليالي وعجباني ومدلعة الرجالة حواليها - YouTube.MKV -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\مجموعة قهوة عصمان بيك.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\هتلر يتعلم من الشيخ ديدات كيفية إفحام المخالفين..mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\هواة تربية القطط 🐱🐱 (1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\هواة تربية القطط 🐱🐱.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\يلعن كسم الانسان وائل الابراشي(240P).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\ဂစ္တာတီးနည္း သီခ်င္းစာအုပ္ေလးမ်ားမ်ွေဝၾကမယ္.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\‫Admin AM في كأس العالم النشيد الوطني الالماني... - حملة حماية المايوه المصري من الإخوان‬.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\‫Ali El Morabit - حشومة عليكوم يا كفرة‬.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\‫BlueWorld - تزوجي من ترقصين معه وليس من يطلب منك الرقص له! 😍‬.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\‫Dz Trends - شوف وماتندمش .. تشبع ضحك 😂😂😂 - Facebook‬.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\‫Fares Herz - ويل سميث يا جماعة kiki do you love 😍😍😍😍😍‬.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\‫Lamar tube لمار تيوب - wowq - Facebook‬.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\‫Look.Me - المشجعين المصريين مولعينها هتافات في شوارع روسيا - Facebook‬.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\‫Look.Me - مشجع روسي يجر شكل المذيعه داليا اشرف 😂 شوف رد فعلها 💪😂 - Facebook‬.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\‫MoDy Photography - #جوهره انا لو لو لو - Facebook‬.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\‫Mohamed Hussien - لكل اللي بيكرهوني 😎😂‬.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\‫Mohamed Mamdouh - في شرع مين ده 😡😡 مكنش ينفع حاجه زي ديه تحصل و...‬.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\‫Mohamed Nasser - رقصة #كيكي -تهدد- الأمن القومى ويستغلها أهل...‬.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\‫Nada Abo Treka - راجل بيهتف -مش عايزينك يا سيسي- و-يسقط حكم...‬.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\‫Nostalgia - لما الكراش ينزل صورة جديدة‬.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\‫Omar Sharky - لما تبقى عايز تلحق التريند.. #kikichallenge #kiki‬.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\‫OTFeed - الشاب ده هو وقطته حاولو يمسكو فار .. هموت من الضحك 😂😂‬.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\‫SEVDA - لمَّا ابقي أنا واُختي فِـ البيت ونتكلم Messenger Call 😂..‬.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\‫SpeciaL ツ - حد يموت البت دي😂😂😂😂😂‬.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\‫TILO - ماكبث.....الصف الثاني الثانوي......بمسرح المدرسة ومشاركة...‬.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\‫Trend Egypt - انتوا ازاي تتهجموا عالناس في بيوت الدعارة - Facebook‬.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\‫أحقر مشهد في تاريخ الدراما المصرية - Abdul rahman Yusuf‬.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\‫إيه يابنتى العسل ده😍😍 عندما تجتمع المياصة والرقص... - Dance to the end‬.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\‫الفيديو ده خطير - Dark Memes Page With Long Name‬.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\‫الكون - سحر الفيزياء... كُرات البولي أكريلاميد بوليمر هذه لها نفس...‬.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\‫بالصدفة بقلب فى القنوات لقيت المطرب العالمى دة 😢😢💔💔💔 - Egypt comedy crushes‬.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\‫سما المصرى Sama Elmasry - سما المصرى ورقصه الكيكى البلدى - Facebook‬.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\‫فلوتين - قلبي وقف 😳😱😵‬.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\‫قد لمعت عيناه ❤️ - Abdulrahman Attia‬.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\‫كريم عاشور - لما تسال سيساوي عن اللي بيقصده السيسي من خطاباته و...‬.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\‫كوميديا اخلاقية - شوف هدا بزربة ورد بالك لا يديروها بيك‬.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\‫لم أتخيل في حياتي أن اعشق اغنية ألمانية لكن هذه... - ماريانا السليمان‬.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\‫متصلة تبكي ل الابراشى- ديه آخرتها يا سيسى انا... - ام ترتر Om Tartar‬.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\‫متصلة تبكي ل الابراشى- ديه آخرتها يا سيسى انا... - ام ترتر Om Tartar‬_2.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\‫مدرسة جرافيك مان - تحدي كيكي - Facebook‬.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\‫ميمو كافيه - سما المصرى بتسأل ..هو لسه فى كبت جنسى و احنا فى 2017‬.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\‫وَهــم ، - By - @mohamed mansour‬.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\⛵Dr. Jordan B. Peterson's Mythopoeic PARTY BOAT⛵ ⛵ ⛵.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\搞笑行动（私人）无限公司.MP4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\07\Ｓａｄｆｏｒｅｖｅｒ - The best feelings.MP4 -> unknown (Exception: name '__file__' is not defined)
# [131/132] Merging 532 videos in: G:/My Drive/Mega\megaold\07 (Resolution: unknown)
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\My Drive - Mega - megaold - 07 - Part 01.mp4"
# [131/132] Merged video saved to: D:/merged\My Drive - Mega - megaold - 07 - Part 01.mp4
# [131/132] Failed to process G:/My Drive/Mega\megaold\07 part 1: name '__file__' is not defined
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\1.16694648289053901E18.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\1.18635690241188659E18.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\10000000_2396477593778144_6694422043016298482_n.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\10000000_504180183714699_3222292326715148432_n.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\20190727_152017149670.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\20190727_16592157783.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\20190731_20390028585.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\2189822359086008123.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\70941194_520204291878935_1726279261198930215_n.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\78698578_440404706676115_3031248545828044800_n.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\78851495_539793946577787_87359381397569536_n.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\79071336_761345447626611_5399944823710941184_n.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\79418118_2315514198740746_586288414865752064_n.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\79819764_455397058710477_8925326367646547968_n(1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\80064687_477077606500752_2138875339537907712_n.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\80257949_1385814901593027_556164085482258432_n.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\80448801_2572031406362007_1544795823932440576_n.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\danielleyayalaa_73291351_986237015060894_7443250906334277646_n.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\Don Michael Jr..mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\ff.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\front6689.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\getfvid_14616181_267539763640948_1101880396729024512_n.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\getfvid_70116327_507546993345306_8774015370404239425_n.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\getfvid_70230647_657888114703474_8163505659980915163_n.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\getfvid_70364506_364755291137924_7096966374651592704_n.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\getfvid_70621272_355860321968386_3404935126059057152_n.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\getfvid_71738614_191294045223865_7810721245856555587_n.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\getfvid_71835987_2412728128996090_6645407038002167808_n.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\getfvid_72297444_537264910352757_931829468815687680_n.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\getfvid_72825956_3030747403622596_2380510143776292864_n.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\getfvid_78752518_833487480442144_8125420817942052864_n.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\giphy (1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\giphy (2).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\giphy (3).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\giphy-1.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\giphy.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\i will not look at any single boob and i will not look at any single butt in this video.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\nLjZ6A1.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\received_1323657441136868.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\Red Letter Media Loves Rogue One! (1).mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\Red Letter Media Loves Rogue One!.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\Rick.and.Morty.S04E04.Claw.and.Hoarder.Special.Ricktims.Morty.480p.x264-mSD.mkv -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\tiktokposting.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\tumblr_pgg9izVknU1r0uzl6_720.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\tumblr_pra3sa1ttt1udwv5b.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\tumblr_pv0rrrAszp1vmobp0.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\tumblr_pyxroafCku1ynqt5u.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\video-1570167706.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\video11841365_0.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\Watch_ Jeff Goldblum Didn't Know About the Spider-Man Split.mp4 -> unknown (Exception: name '__file__' is not defined)
# [RESOLUTION-EXCEPTION] G:/My Drive/Mega\megaold\08\y2mate.com - priceless_reaction_to_finding_out_who_darth_vader_really_is_KMLmGi6AK-c_360p.mp4 -> unknown (Exception: name '__file__' is not defined)
# [132/132] Merging 51 videos in: G:/My Drive/Mega\megaold\08 (Resolution: unknown)
# Running: ffmpeg -f concat -safe 0 -i ffmpeg_filelist.txt -c copy "D:/merged\My Drive - Mega - megaold - 08 - Part 01.mp4"
# [132/132] Merged video saved to: D:/merged\My Drive - Mega - megaold - 08 - Part 01.mp4
# [132/132] Failed to process G:/My Drive/Mega\megaold\08 part 1: name '__file__' is not defined
# Processing complete. See processed_folders.json for details.
