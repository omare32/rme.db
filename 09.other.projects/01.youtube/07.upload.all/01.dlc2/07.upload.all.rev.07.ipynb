# %%
import os
import sys
import glob
import logging
from datetime import datetime
from pathlib import Path
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import tkinter as tk
from tkinter import filedialog
from google_auth_oauthlib.flow import InstalledAppFlow
from google.oauth2.credentials import Credentials
from google.auth.transport.requests import Request
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload
import time

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(message)s',
    datefmt='%H:%M:%S',
    handlers=[
        logging.FileHandler('upload_all.log', encoding='utf-8'),
        logging.StreamHandler()
    ]
)

TOKEN_FILE = "token.json"
SCOPES = ["https://www.googleapis.com/auth/youtube.upload"]

os.environ['OAUTHLIB_INSECURE_TRANSPORT'] = '1'
os.environ['PYTHONHTTPSVERIFY'] = '0'

def get_authenticated_service(client_secrets_file: str):
    creds = None
    if os.path.exists(TOKEN_FILE):
        creds = Credentials.from_authorized_user_file(TOKEN_FILE, SCOPES)
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(client_secrets_file, SCOPES)
            creds = flow.run_local_server(port=0)
        with open(TOKEN_FILE, 'w') as token:
            token.write(creds.to_json())
    return build('youtube', 'v3', credentials=creds)

def upload_to_youtube(youtube, video_path: str, title: str, description: str = "Uploaded by script"):
    MAX_RETRIES = 3
    RETRY_DELAY_SECONDS = 180  # 3 minutes
    for attempt in range(1, MAX_RETRIES + 1):
        try:
            body = {
                'snippet': {
                    'title': title,
                    'description': description,
                    'tags': ['tutorial', 'education']
                },
                'status': {
                    'privacyStatus': 'unlisted',
                    'selfDeclaredMadeForKids': False
                }
            }
            insert_request = youtube.videos().insert(
                part=','.join(body.keys()),
                body=body,
                media_body=MediaFileUpload(video_path, chunksize=-1, resumable=True)
            )
            response = None
            while response is None:
                status, response = insert_request.next_chunk()
                if status:
                    logging.info(f"Upload {int(status.progress() * 100)}% complete for {video_path}")
            return response['id']
        except Exception as e:
            logging.error(f"Error uploading {video_path} to YouTube (attempt {attempt}): {str(e)}")
            if attempt < MAX_RETRIES:
                logging.info(f"Retrying upload for {video_path} in {RETRY_DELAY_SECONDS // 60} minutes...")
                time.sleep(RETRY_DELAY_SECONDS)
            else:
                logging.error(f"Upload failed for {video_path} after {MAX_RETRIES} attempts.")
                return None

def select_folder_dialog(title="Select folder"):
    """Open a folder selection dialog and return the selected path."""
    try:
        root = tk.Tk()
        root.withdraw()
        root.update_idletasks()
        width = root.winfo_screenwidth()
        height = root.winfo_screenheight()
        x = (width - 400) // 2
        y = (height - 300) // 2
        root.geometry(f'400x300+{x}+{y}')
        folder_path = filedialog.askdirectory(
            title=title,
            mustexist=True
        )
        root.destroy()
        return folder_path
    except Exception as e:
        logging.error(f"Error in folder selection: {str(e)}")
        return None

def main():
    # Select parent folder
    parent_folder = select_folder_dialog(title="Select parent folder containing videos to upload recursively")
    if not parent_folder or not os.path.exists(parent_folder):
        logging.error("No folder selected or folder does not exist")
        return
    cwd = os.getcwd()
    client_secrets_file = os.path.join(cwd, "client_secret.dlc.json")
    if not os.path.exists(client_secrets_file):
        logging.error(f"Client secrets file not found at: {client_secrets_file}")
        return
    youtube = get_authenticated_service(client_secrets_file)
    logging.info("YouTube authentication complete.")
    VIDEO_EXTENSIONS = ('.mp4', '.mkv', '.avi', '.mov', '.wmv', '.flv', '.webm', '.3gp')
    for root, _, files in os.walk(parent_folder):
        for file in files:
            if file.lower().endswith(VIDEO_EXTENSIONS) and not file.endswith('.txt'):
                video_path = os.path.join(root, file)
                video_name = os.path.splitext(file)[0]
                link_file = os.path.join(root, f"{video_name}.txt")
                if not os.path.exists(link_file):
                    folder_name = os.path.basename(root)
                    MAX_TITLE_LENGTH = 100
                    title = f"{folder_name} - {video_name}"
                    if len(title) > MAX_TITLE_LENGTH:
                        title = title[:MAX_TITLE_LENGTH]
                    logging.info(f"Uploading: {video_path} with title: {title}")
                    video_id = upload_to_youtube(youtube, video_path, title)
                    if video_id:
                        with open(link_file, 'w') as f:
                            f.write(f"https://www.youtube.com/watch?v={video_id}\n")
                        try:
                            os.remove(video_path)
                        except Exception as e:
                            logging.error(f"Failed to delete uploaded video file: {video_path}: {str(e)}")
                        logging.info(f"Upload successful! Video ID: {video_id}")
                    else:
                        logging.error(f"Upload failed for {video_path}")
                else:
                    logging.info(f"Link file already exists for {video_path}. Skipping upload.")
    logging.info("All specified folders and subfolders processed.")

if __name__ == "__main__":
    main()
# Out:
# 09:52:17 - file_cache is only supported with oauth2client<4.0.0
# 09:52:17 - YouTube authentication complete.
# 09:52:18 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_100.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_100
# 09:53:21 - Upload successful! Video ID: R-hiCXSEtUQ
# 09:53:21 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_101.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_101
# 09:54:02 - Upload successful! Video ID: UvFnKIO_fog
# 09:54:02 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_103.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_103
# 09:54:43 - Upload successful! Video ID: Rum6d8bAUmg
# 09:54:43 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_104.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_104
# 09:55:23 - Upload successful! Video ID: xxgD10ob3Sw
# 09:55:23 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_105.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_105
# 09:56:03 - Upload successful! Video ID: DmVTLJxaTNw
# 09:56:03 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_106.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_106
# 09:56:43 - Upload successful! Video ID: Jr9ppkVFwYA
# 09:56:43 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_107.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_107
# 09:57:22 - Upload successful! Video ID: ozBuAN9ZGKM
# 09:57:22 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_108.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_108
# 09:58:02 - Upload successful! Video ID: 2tj9wshkPvY
# 09:58:02 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_109.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_109
# 09:58:42 - Upload successful! Video ID: oVXuYFM6Pyw
# 09:58:42 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_110.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_110
# 09:59:21 - Upload successful! Video ID: 8-W_VamrQwk
# 09:59:21 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_111.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_111
# 10:00:01 - Upload successful! Video ID: YzASo4Y2les
# 10:00:01 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_112.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_112
# 10:00:41 - Upload successful! Video ID: BUyreTTdsV0
# 10:00:41 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_113.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_113
# 10:01:21 - Upload successful! Video ID: XdDDyyY3DW4
# 10:01:21 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_114.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_114
# 10:02:02 - Upload successful! Video ID: YW8REBqz7AI
# 10:02:02 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_115.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_115
# 10:02:43 - Upload successful! Video ID: LVhHmcQSRlU
# 10:02:43 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_116.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_116
# 10:04:33 - Upload successful! Video ID: CjtrUhw9UNI
# 10:04:33 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_117.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_117
# 10:04:58 - Upload successful! Video ID: 7aL3St1jTVU
# 10:04:58 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_118.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_118
# 10:05:36 - Upload successful! Video ID: ee7XjlmjyAU
# 10:05:36 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_119.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_119
# 10:06:13 - Upload successful! Video ID: CAgUWYNeSgI
# 10:06:13 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_120.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_120
# 10:06:51 - Upload successful! Video ID: U4aRChCvm9A
# 10:06:51 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_121.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_121
# 10:07:29 - Upload successful! Video ID: IJK72BFpQ7o
# 10:07:29 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_122.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_122
# 10:08:08 - Upload successful! Video ID: qu_Px8WPkgE
# 10:08:08 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_123.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_123
# 10:08:46 - Upload successful! Video ID: -ofL52Ec8K0
# 10:08:46 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_124.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_124
# 10:09:25 - Upload successful! Video ID: 68xxBan1X2g
# 10:09:25 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_125.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_125
# 10:10:03 - Upload successful! Video ID: iLQVI8Wxw68
# 10:10:03 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_126.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_126
# 10:10:40 - Upload successful! Video ID: w8uVLuMuNyQ
# 10:10:40 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_127.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_127
# 10:11:18 - Upload successful! Video ID: IK-CO9MzTqo
# 10:11:18 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_128.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_128
# 10:11:56 - Upload successful! Video ID: _tONGXPNjyE
# 10:11:56 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_129.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_129
# 10:12:34 - Upload successful! Video ID: NXV0iYGyREc
# 10:12:34 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_131.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_131
# 10:13:12 - Upload successful! Video ID: uu24-Wk11Ig
# 10:13:12 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_132.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_132
# 10:13:51 - Upload successful! Video ID: FESr1gt0sLA
# 10:13:51 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_133.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_133
# 10:14:30 - Upload successful! Video ID: 2b51bBZ96xI
# 10:14:30 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_134.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_134
# 10:15:08 - Upload successful! Video ID: FPgG_8A3UmY
# 10:15:08 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_135.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_135
# 10:15:47 - Upload successful! Video ID: Zd8utf50UOE
# 10:15:47 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_136.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_136
# 10:16:25 - Upload successful! Video ID: xqdRJcyxQAk
# 10:16:25 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_137.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_137
# 10:17:02 - Upload successful! Video ID: 9iP0RCDFlFg
# 10:17:02 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_138.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_138
# 10:17:40 - Upload successful! Video ID: F6n6CUlRm4Q
# 10:17:40 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_139.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_139
# 10:18:18 - Upload successful! Video ID: -J9w-YZ9-0g
# 10:18:18 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_140.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_140
# 10:18:57 - Upload successful! Video ID: 8yJAZkb8ElE
# 10:18:57 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_141.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_141
# 10:19:35 - Upload successful! Video ID: CjJ8JpaFG2o
# 10:19:35 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_142.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_142
# 10:20:15 - Upload successful! Video ID: 4_BYtdWUU8s
# 10:20:15 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_143.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_143
# 10:20:53 - Upload successful! Video ID: LbAHMIVg2OY
# 10:20:53 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_144.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_144
# 10:21:31 - Upload successful! Video ID: QaNdH7jAOPw
# 10:21:31 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_146.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_146
# 10:22:08 - Upload successful! Video ID: m7vYig_VUd4
# 10:22:08 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_99.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_99
# 10:22:48 - Upload successful! Video ID: Isf_3dR5fwI
# 10:22:48 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\165 هكذا تكلم مرسي.mp4 with title: MasryMol7ed - 165 هكذا تكلم مرسي
# 10:23:34 - Upload successful! Video ID: Ei_EVpzrQ2Y
# 10:23:34 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\166 دقت ساعة العمل الثوري.mp4 with title: MasryMol7ed - 166 دقت ساعة العمل الثوري
# 10:24:26 - Upload successful! Video ID: 6wqVQU88_PI
# 10:24:26 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\167 إيزيس تسحق أبا جهل.mp4 with title: MasryMol7ed - 167 إيزيس تسحق أبا جهل
# 10:24:53 - Upload successful! Video ID: FRvZEGz7SGk
# 10:24:53 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\168 حسبى الله ونعم الوكيل فيك يا مرسي.mp4 with title: MasryMol7ed - 168 حسبى الله ونعم الوكيل فيك يا مرسي
# 10:25:19 - Upload successful! Video ID: RTWYdKjBg2w
# 10:25:19 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\169 عبقرية مرسي.mp4 with title: MasryMol7ed - 169 عبقرية مرسي
# 10:25:53 - Upload successful! Video ID: BFGOeyjBi9I
# 10:25:53 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\170 حصاد الأسبوع.mp4 with title: MasryMol7ed - 170 حصاد الأسبوع
# 10:26:23 - Upload successful! Video ID: C3scMzW_3NE
# 10:26:23 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\171 حصاد العام.mp4 with title: MasryMol7ed - 171 حصاد العام
# 10:26:53 - Upload successful! Video ID: vtupj1bzF5Y
# 10:26:53 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\172 مرسي.mp4 with title: MasryMol7ed - 172 مرسي
# 10:27:27 - Upload successful! Video ID: S3i241nsCOw
# 10:27:27 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\173 قناة أم عصام الفضائية قناة العام.mp4 with title: MasryMol7ed - 173 قناة أم عصام الفضائية قناة العام
# 10:28:06 - Upload successful! Video ID: 0RiDvwMDoAU
# 10:28:06 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\174 بيوت لله أم أوكار للشيطان.mp4 with title: MasryMol7ed - 174 بيوت لله أم أوكار للشيطان
# 10:28:38 - Upload successful! Video ID: ULsu1lQmhmE
# 10:28:38 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\175 حول القضية الفلسطينية.mp4 with title: MasryMol7ed - 175 حول القضية الفلسطينية
# 10:29:13 - Upload successful! Video ID: EiPWSfNA6p4
# 10:29:13 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\176 حول القضية الإماراتية 1.mp4 with title: MasryMol7ed - 176 حول القضية الإماراتية 1
# 10:29:38 - Upload successful! Video ID: G-1n61l4vXA
# 10:29:38 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\177 حول القضية الإماراتية 2.mp4 with title: MasryMol7ed - 177 حول القضية الإماراتية 2
# 10:30:01 - Upload successful! Video ID: LRW0YHJJ1mc
# 10:30:01 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\178 مرسى فى المصيدة.mp4 with title: MasryMol7ed - 178 مرسى فى المصيدة
# 10:30:26 - Upload successful! Video ID: CVh3xsqhtx8
# 10:30:26 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\179 حانت لحظة الحقيقة.mp4 with title: MasryMol7ed - 179 حانت لحظة الحقيقة
# 10:30:54 - Upload successful! Video ID: wJrDW8nxZcM
# 10:30:54 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\180 الإسلام والكس 1.mp4 with title: MasryMol7ed - 180 الإسلام والكس 1
# 10:31:25 - Upload successful! Video ID: B-akqBO1sz4
# 10:31:25 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\181 الإسلام والكس 2.mp4 with title: MasryMol7ed - 181 الإسلام والكس 2
# 10:31:58 - Upload successful! Video ID: VjRsxY44hvA
# 10:31:58 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\182 الإسلام والكس 3.mp4 with title: MasryMol7ed - 182 الإسلام والكس 3
# 10:32:27 - Upload successful! Video ID: heR9TUml5BU
# 10:32:27 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\183 الإسلام والكس 4.mp4 with title: MasryMol7ed - 183 الإسلام والكس 4
# 10:32:58 - Upload successful! Video ID: mZOdharxoGQ
# 10:32:58 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\184 الإسلام والكس 5.mp4 with title: MasryMol7ed - 184 الإسلام والكس 5
# 10:33:17 - Upload successful! Video ID: PMXd31r6PXQ
# 10:33:17 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\185 الإسلام والكس 6.mp4 with title: MasryMol7ed - 185 الإسلام والكس 6
# 10:33:52 - Upload successful! Video ID: EcW-OgW2rz8
# 10:33:52 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\186 مظلومية الإخوان المزعومة 1.mp4 with title: MasryMol7ed - 186 مظلومية الإخوان المزعومة 1
# 10:34:24 - Upload successful! Video ID: QycLaGTE5yc
# 10:34:24 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\188 عاصم عبد الماجد رئيسا لمصر.mp4 with title: MasryMol7ed - 188 عاصم عبد الماجد رئيسا لمصر
# 10:34:36 - Upload successful! Video ID: 2vih6hBIxQU
# 10:34:36 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\189 ثورة المعارك الخاسرة.mp4 with title: MasryMol7ed - 189 ثورة المعارك الخاسرة
# 10:35:15 - Upload successful! Video ID: 5_zneMTFFDk
# 10:35:15 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\190 تعليقا على الأحداث 25 03 2013.mp4 with title: MasryMol7ed - 190 تعليقا على الأحداث 25 03 2013
# 10:36:00 - Upload successful! Video ID: 071eEa_uuL4
# 10:36:00 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\191 حول الدور الأمريكي.mp4 with title: MasryMol7ed - 191 حول الدور الأمريكي
# 10:36:44 - Upload successful! Video ID: 8PwlDLk28Zk
# 10:36:44 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\192 تأملات شخصية فى أورجي البلهاء بالمقطم.mp4 with title: MasryMol7ed - 192 تأملات شخصية فى أورجي البلهاء بالمقطم
# 10:37:29 - Upload successful! Video ID: rCKBVIudkSQ
# 10:37:29 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\193 فلاش باك.mp4 with title: MasryMol7ed - 193 فلاش باك
# 10:38:05 - Upload successful! Video ID: 1yXvgi48twk
# 10:38:05 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\194 كبيرهم الذى علمهم السحر عبد الحميد كشك.mp4 with title: MasryMol7ed - 194 كبيرهم الذى علمهم السحر عبد الحميد كشك
# 10:38:41 - Upload successful! Video ID: s2wXtiZgfco
# 10:38:41 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\195 أباطيل وأسمار إخوانية.mp4 with title: MasryMol7ed - 195 أباطيل وأسمار إخوانية
# 10:39:01 - Upload successful! Video ID: OO9cXGFklww
# 10:39:01 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\196 محاكم التفتيش الإسلامية.mp4 with title: MasryMol7ed - 196 محاكم التفتيش الإسلامية
# 10:39:45 - Upload successful! Video ID: xMjusOBJUkI
# 10:39:45 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\197 الرد الأريب على المغفل عمرو أديب.mp4 with title: MasryMol7ed - 197 الرد الأريب على المغفل عمرو أديب
# 10:40:22 - Upload successful! Video ID: 8HVfpz5xN10
# 10:40:22 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\198 عودة قبيلة الحربات.mp4 with title: MasryMol7ed - 198 عودة قبيلة الحربات
# 10:41:08 - Upload successful! Video ID: 8_pMnU2EnUc
# 10:41:08 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\199 زيارة السيدة العجوز.mp4 with title: MasryMol7ed - 199 زيارة السيدة العجوز
# 10:41:50 - Upload successful! Video ID: 43d5zKd6h9Q
# 10:41:50 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\200 وداعا مرسي.mp4 with title: MasryMol7ed - 200 وداعا مرسي
# 10:42:20 - Upload successful! Video ID: iDSQX0SVPfY
# 10:42:20 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\201 فلتكن الريح فى الأرض تكنس هذا العفن.mp4 with title: MasryMol7ed - 201 فلتكن الريح فى الأرض تكنس هذا العفن
# 10:42:32 - Upload successful! Video ID: 3VdOqtVkIIQ
# 10:42:32 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\202 الآن الآن وليس غدا.mp4 with title: MasryMol7ed - 202 الآن الآن وليس غدا
# 10:42:59 - Upload successful! Video ID: QZqH42DKIaY
# 10:42:59 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\203 جماعة تبحث عن مؤلف.mp4 with title: MasryMol7ed - 203 جماعة تبحث عن مؤلف
# 10:43:51 - Upload successful! Video ID: L_xS7MFaQTE
# 10:43:51 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\204 من وحى باليه بحيرة البهايم برابعة.mp4 with title: MasryMol7ed - 204 من وحى باليه بحيرة البهايم برابعة
# 10:44:42 - Upload successful! Video ID: Im6LwTANcRg
# 10:44:42 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\205 تنتون الإخوانى وتنتن الأمريكانى .mp4 with title: MasryMol7ed - 205 تنتون الإخوانى وتنتن الأمريكانى
# 10:45:28 - Upload successful! Video ID: gfkpRKkFYdg
# 10:45:28 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\206 تنتون الإخوانى وتنتن الأمريكانى 2.mp4 with title: MasryMol7ed - 206 تنتون الإخوانى وتنتن الأمريكانى 2
# 10:46:09 - Upload successful! Video ID: j9yexkJfTVI
# 10:46:09 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\207 وجوب طاعة الإمام المتغلب الفريق السيسي حفظه الله.mp4 with title: MasryMol7ed - 207 وجوب طاعة الإمام المتغلب الفريق السيسي حفظه الله
# 10:46:34 - Upload successful! Video ID: sImPrN64cHM
# 10:46:34 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\208 أبانا الذى فى اليوتيوب.mp4 with title: MasryMol7ed - 208 أبانا الذى فى اليوتيوب
# 10:46:43 - Upload successful! Video ID: Ja_kGZ3PBFE
# 10:46:43 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\209 جزيرة الشاويش عطية.mp4 with title: MasryMol7ed - 209 جزيرة الشاويش عطية
# 10:46:58 - Upload successful! Video ID: OIOXtdRKyv4
# 10:46:58 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\210 جزيرة الشاويش عطية 2.mp4 with title: MasryMol7ed - 210 جزيرة الشاويش عطية 2
# 10:47:13 - Upload successful! Video ID: EtR3zgUsihg
# 10:47:13 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\211 جزيرة الشاويش عطية 3.mp4 with title: MasryMol7ed - 211 جزيرة الشاويش عطية 3
# 10:47:27 - Upload successful! Video ID: JbBbW8pQTgY
# 10:47:27 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\212 بدأ الحساب.mp4 with title: MasryMol7ed - 212 بدأ الحساب
# 10:47:42 - Upload successful! Video ID: PJotGF1FxTs
# 10:47:42 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\213 مرسى الفكرة.mp4 with title: MasryMol7ed - 213 مرسى الفكرة
# 10:47:56 - Upload successful! Video ID: GmoC48-W2UY
# 10:47:56 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\214 سم هويدى المغشوش.mp4 with title: MasryMol7ed - 214 سم هويدى المغشوش
# 10:48:06 - Upload successful! Video ID: 0bZF6eMhyrA
# 10:48:06 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\215 رابعة العدوية تعود إلى عهرها القديم.mp4 with title: MasryMol7ed - 215 رابعة العدوية تعود إلى عهرها القديم
# 10:48:21 - Upload successful! Video ID: SSAx6Mc-Ez0
# 10:48:21 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\216 رابعة الحيوان.mp4 with title: MasryMol7ed - 216 رابعة الحيوان
# 10:49:05 - Upload successful! Video ID: KqSYM15nFYQ
# 10:49:05 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\217 وقفات مع الأزهر.mp4 with title: MasryMol7ed - 217 وقفات مع الأزهر
# 10:49:42 - Upload successful! Video ID: hy8qCMamUxc
# 10:49:42 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\218 حرب الأغاني.mp4 with title: MasryMol7ed - 218 حرب الأغاني
# 10:50:33 - Upload successful! Video ID: ijmlWSieVFY
# 10:50:33 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\219 الحب من طرف واحد بين اليسار وأم أيمن.mp4 with title: MasryMol7ed - 219 الحب من طرف واحد بين اليسار وأم أيمن
# 10:51:09 - Upload successful! Video ID: AMqVPjU7HVU
# 10:51:09 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\220 حول ترشح السيسي.mp4 with title: MasryMol7ed - 220 حول ترشح السيسي
# 10:51:57 - Upload successful! Video ID: ouRKIXhGSq8
# 10:51:57 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\221 ثورة دى ولا انقلاب.mp4 with title: MasryMol7ed - 221 ثورة دى ولا انقلاب
# 10:52:28 - Upload successful! Video ID: XiEiFAs1rOI
# 10:52:28 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\25 - 2a2emet elgahl wa alta7'alof - 01.flv with title: Old - 25 - 2a2emet elgahl wa alta7'alof - 01
# 10:52:44 - Upload successful! Video ID: ObVbspwPL8E
# 10:52:44 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\26 - 2a2emet elgahl wa alta7'alof - 02.flv with title: Old - 26 - 2a2emet elgahl wa alta7'alof - 02
# 10:52:44 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\26 - 2a2emet elgahl wa alta7'alof - 02.flv to YouTube (attempt 1): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 10:52:44 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\26 - 2a2emet elgahl wa alta7'alof - 02.flv in 3 minutes...
# 10:55:44 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\26 - 2a2emet elgahl wa alta7'alof - 02.flv to YouTube (attempt 2): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 10:55:44 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\26 - 2a2emet elgahl wa alta7'alof - 02.flv in 3 minutes...
# 10:58:45 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\26 - 2a2emet elgahl wa alta7'alof - 02.flv to YouTube (attempt 3): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 10:58:45 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\26 - 2a2emet elgahl wa alta7'alof - 02.flv after 3 attempts.
# 10:58:45 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\26 - 2a2emet elgahl wa alta7'alof - 02.flv
# 10:58:45 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\27 - 2a2emet elgahl wa alta7'alof - 03.flv with title: Old - 27 - 2a2emet elgahl wa alta7'alof - 03
# 10:58:45 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\27 - 2a2emet elgahl wa alta7'alof - 03.flv to YouTube (attempt 1): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 10:58:45 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\27 - 2a2emet elgahl wa alta7'alof - 03.flv in 3 minutes...
# 11:01:46 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\27 - 2a2emet elgahl wa alta7'alof - 03.flv to YouTube (attempt 2): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 11:01:46 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\27 - 2a2emet elgahl wa alta7'alof - 03.flv in 3 minutes...
# 11:04:46 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\27 - 2a2emet elgahl wa alta7'alof - 03.flv to YouTube (attempt 3): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 11:04:46 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\27 - 2a2emet elgahl wa alta7'alof - 03.flv after 3 attempts.
# 11:04:46 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\27 - 2a2emet elgahl wa alta7'alof - 03.flv
# 11:04:46 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\28 - 2a2emet elgahl wa alta7'alof - 04.flv with title: Old - 28 - 2a2emet elgahl wa alta7'alof - 04
# 11:04:46 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\28 - 2a2emet elgahl wa alta7'alof - 04.flv to YouTube (attempt 1): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 11:04:46 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\28 - 2a2emet elgahl wa alta7'alof - 04.flv in 3 minutes...
# 11:07:47 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\28 - 2a2emet elgahl wa alta7'alof - 04.flv to YouTube (attempt 2): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 11:07:47 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\28 - 2a2emet elgahl wa alta7'alof - 04.flv in 3 minutes...
# 11:10:47 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\28 - 2a2emet elgahl wa alta7'alof - 04.flv to YouTube (attempt 3): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 11:10:47 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\28 - 2a2emet elgahl wa alta7'alof - 04.flv after 3 attempts.
# 11:10:47 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\28 - 2a2emet elgahl wa alta7'alof - 04.flv
# 11:10:47 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\29 - 2a2emet elgahl wa alta7'alof - 05.flv with title: Old - 29 - 2a2emet elgahl wa alta7'alof - 05
# 11:10:47 - Encountered 403 Forbidden with reason "quotaExceeded"
# 11:10:47 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\29 - 2a2emet elgahl wa alta7'alof - 05.flv to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 11:10:47 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\29 - 2a2emet elgahl wa alta7'alof - 05.flv in 3 minutes...
# 11:13:48 - Encountered 403 Forbidden with reason "quotaExceeded"
# 11:13:48 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\29 - 2a2emet elgahl wa alta7'alof - 05.flv to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 11:13:48 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\29 - 2a2emet elgahl wa alta7'alof - 05.flv in 3 minutes...
# 11:16:48 - Encountered 403 Forbidden with reason "quotaExceeded"
# 11:16:48 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\29 - 2a2emet elgahl wa alta7'alof - 05.flv to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 11:16:48 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\29 - 2a2emet elgahl wa alta7'alof - 05.flv after 3 attempts.
# 11:16:48 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\29 - 2a2emet elgahl wa alta7'alof - 05.flv
# 11:16:48 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\‫أتلم تنتون على تنتن صبحوا الإتنين أنتن وأنتن‬ - YouTube - 107.flv with title: Old - ‫أتلم تنتون على تنتن صبحوا الإتنين أنتن وأنتن‬ - YouTube - 107
# 11:16:48 - Encountered 403 Forbidden with reason "quotaExceeded"
# 11:16:48 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\‫أتلم تنتون على تنتن صبحوا الإتنين أنتن وأنتن‬ - YouTube - 107.flv to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 11:16:48 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\‫أتلم تنتون على تنتن صبحوا الإتنين أنتن وأنتن‬ - YouTube - 107.flv in 3 minutes...
# 11:19:48 - Encountered 403 Forbidden with reason "quotaExceeded"
# 11:19:48 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\‫أتلم تنتون على تنتن صبحوا الإتنين أنتن وأنتن‬ - YouTube - 107.flv to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 11:19:48 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\‫أتلم تنتون على تنتن صبحوا الإتنين أنتن وأنتن‬ - YouTube - 107.flv in 3 minutes...
# 11:22:48 - Encountered 403 Forbidden with reason "quotaExceeded"
# 11:22:48 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\‫أتلم تنتون على تنتن صبحوا الإتنين أنتن وأنتن‬ - YouTube - 107.flv to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 11:22:48 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\‫أتلم تنتون على تنتن صبحوا الإتنين أنتن وأنتن‬ - YouTube - 107.flv after 3 attempts.
# 11:22:48 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\‫أتلم تنتون على تنتن صبحوا الإتنين أنتن وأنتن‬ - YouTube - 107.flv
# 11:22:48 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\‫أفق يا رجل‬ - YouTube - 106.flv with title: Old - ‫أفق يا رجل‬ - YouTube - 106
# 11:22:48 - Encountered 403 Forbidden with reason "quotaExceeded"
# 11:22:48 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\‫أفق يا رجل‬ - YouTube - 106.flv to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 11:22:48 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\‫أفق يا رجل‬ - YouTube - 106.flv in 3 minutes...
# 11:25:48 - Encountered 403 Forbidden with reason "quotaExceeded"
# 11:25:48 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\‫أفق يا رجل‬ - YouTube - 106.flv to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 11:25:48 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\‫أفق يا رجل‬ - YouTube - 106.flv in 3 minutes...
# 11:28:48 - Encountered 403 Forbidden with reason "quotaExceeded"
# 11:28:48 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\‫أفق يا رجل‬ - YouTube - 106.flv to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 11:28:48 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\‫أفق يا رجل‬ - YouTube - 106.flv after 3 attempts.
# 11:28:48 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\‫أفق يا رجل‬ - YouTube - 106.flv
# 11:28:48 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\‫أنا أسف ياريس‬ - YouTube - 105.flv with title: Old - ‫أنا أسف ياريس‬ - YouTube - 105
# 11:28:49 - Encountered 403 Forbidden with reason "quotaExceeded"
# 11:28:49 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\‫أنا أسف ياريس‬ - YouTube - 105.flv to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 11:28:49 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\‫أنا أسف ياريس‬ - YouTube - 105.flv in 3 minutes...
# 11:31:49 - Encountered 403 Forbidden with reason "quotaExceeded"
# 11:31:49 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\‫أنا أسف ياريس‬ - YouTube - 105.flv to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 11:31:49 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\MasryMol7ed\Old\‫أنا أسف ياريس‬ - YouTube - 105.flv in 3 minutes...
