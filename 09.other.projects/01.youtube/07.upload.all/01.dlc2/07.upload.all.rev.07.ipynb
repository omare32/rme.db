# %%
import os
import sys
import glob
import logging
from datetime import datetime
from pathlib import Path
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import tkinter as tk
from tkinter import filedialog
from google_auth_oauthlib.flow import InstalledAppFlow
from google.oauth2.credentials import Credentials
from google.auth.transport.requests import Request
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload
import time

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(message)s',
    datefmt='%H:%M:%S',
    handlers=[
        logging.FileHandler('upload_all.log', encoding='utf-8'),
        logging.StreamHandler()
    ]
)

TOKEN_FILE = "token.json"
SCOPES = ["https://www.googleapis.com/auth/youtube.upload"]

os.environ['OAUTHLIB_INSECURE_TRANSPORT'] = '1'
os.environ['PYTHONHTTPSVERIFY'] = '0'

def get_authenticated_service(client_secrets_file: str):
    creds = None
    if os.path.exists(TOKEN_FILE):
        creds = Credentials.from_authorized_user_file(TOKEN_FILE, SCOPES)
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(client_secrets_file, SCOPES)
            creds = flow.run_local_server(port=0)
        with open(TOKEN_FILE, 'w') as token:
            token.write(creds.to_json())
    return build('youtube', 'v3', credentials=creds)

def upload_to_youtube(youtube, video_path: str, title: str, description: str = "Uploaded by script"):
    MAX_RETRIES = 3
    RETRY_DELAY_SECONDS = 180  # 3 minutes
    for attempt in range(1, MAX_RETRIES + 1):
        try:
            body = {
                'snippet': {
                    'title': title,
                    'description': description,
                    'tags': ['tutorial', 'education']
                },
                'status': {
                    'privacyStatus': 'unlisted',
                    'selfDeclaredMadeForKids': False
                }
            }
            insert_request = youtube.videos().insert(
                part=','.join(body.keys()),
                body=body,
                media_body=MediaFileUpload(video_path, chunksize=-1, resumable=True)
            )
            response = None
            while response is None:
                status, response = insert_request.next_chunk()
                if status:
                    logging.info(f"Upload {int(status.progress() * 100)}% complete for {video_path}")
            return response['id']
        except Exception as e:
            logging.error(f"Error uploading {video_path} to YouTube (attempt {attempt}): {str(e)}")
            if attempt < MAX_RETRIES:
                logging.info(f"Retrying upload for {video_path} in {RETRY_DELAY_SECONDS // 60} minutes...")
                time.sleep(RETRY_DELAY_SECONDS)
            else:
                logging.error(f"Upload failed for {video_path} after {MAX_RETRIES} attempts.")
                return None

def select_folder_dialog(title="Select folder"):
    """Open a folder selection dialog and return the selected path."""
    try:
        root = tk.Tk()
        root.withdraw()
        root.update_idletasks()
        width = root.winfo_screenwidth()
        height = root.winfo_screenheight()
        x = (width - 400) // 2
        y = (height - 300) // 2
        root.geometry(f'400x300+{x}+{y}')
        folder_path = filedialog.askdirectory(
            title=title,
            mustexist=True
        )
        root.destroy()
        return folder_path
    except Exception as e:
        logging.error(f"Error in folder selection: {str(e)}")
        return None

def main():
    # Select parent folder
    parent_folder = select_folder_dialog(title="Select parent folder containing videos to upload recursively")
    if not parent_folder or not os.path.exists(parent_folder):
        logging.error("No folder selected or folder does not exist")
        return
    cwd = os.getcwd()
    client_secrets_file = os.path.join(cwd, "client_secret.dlc.json")
    if not os.path.exists(client_secrets_file):
        logging.error(f"Client secrets file not found at: {client_secrets_file}")
        return
    youtube = get_authenticated_service(client_secrets_file)
    logging.info("YouTube authentication complete.")
    VIDEO_EXTENSIONS = ('.mp4', '.mkv', '.avi', '.mov', '.wmv', '.flv', '.webm')
    for root, _, files in os.walk(parent_folder):
        for file in files:
            if file.lower().endswith(VIDEO_EXTENSIONS) and not file.endswith('.txt'):
                video_path = os.path.join(root, file)
                video_name = os.path.splitext(file)[0]
                link_file = os.path.join(root, f"{video_name}.txt")
                if not os.path.exists(link_file):
                    folder_name = os.path.basename(root)
                    MAX_TITLE_LENGTH = 100
                    title = f"{folder_name} - {video_name}"
                    if len(title) > MAX_TITLE_LENGTH:
                        title = title[:MAX_TITLE_LENGTH]
                    logging.info(f"Uploading: {video_path} with title: {title}")
                    video_id = upload_to_youtube(youtube, video_path, title)
                    if video_id:
                        with open(link_file, 'w') as f:
                            f.write(f"https://www.youtube.com/watch?v={video_id}\n")
                        try:
                            os.remove(video_path)
                        except Exception as e:
                            logging.error(f"Failed to delete uploaded video file: {video_path}: {str(e)}")
                        logging.info(f"Upload successful! Video ID: {video_id}")
                    else:
                        logging.error(f"Upload failed for {video_path}")
                else:
                    logging.info(f"Link file already exists for {video_path}. Skipping upload.")
    logging.info("All specified folders and subfolders processed.")

if __name__ == "__main__":
    main()
# Out:
# 14:39:06 - file_cache is only supported with oauth2client<4.0.0
# 14:39:06 - YouTube authentication complete.
# 14:39:06 - Link file already exists for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin\The.Genius.of.Charles.Darwin.1of3.Life.Darwin.and.Everything.XviD.AC3.MVGroup.org.avi. Skipping upload.
# 14:39:06 - Link file already exists for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin\The.Genius.of.Charles.Darwin.2of3.The.Fifth.Ape.XviD.AC3.MVGroup.org.avi. Skipping upload.
# 14:39:06 - Link file already exists for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin\The.Genius.of.Charles.Darwin.3of3.God.Strikes.Back.XviD.AC3.MVGroup.org.avi. Skipping upload.
# 14:39:06 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychologists\Steven Pinker\Steven Pinker, -The Sense of Style- - YouTube.mp4 with title: Steven Pinker - Steven Pinker, -The Sense of Style- - YouTube
# 14:40:05 - Upload successful! Video ID: VMc8Ut6znls
# 14:40:05 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychologists\Steven Pinker\Steven Pinker- Linguistics as a Window to Understanding the Brain - YouTube.mp4 with title: Steven Pinker - Steven Pinker- Linguistics as a Window to Understanding the Brain - YouTube
# 14:40:52 - Upload successful! Video ID: xdLRFGTrmuY
# 14:40:52 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychologists\Steven Pinker\Understanding Human Nature with Steven Pinker - Conversations with History - YouTube.mp4 with title: Steven Pinker - Understanding Human Nature with Steven Pinker - Conversations with History - YouTube
# 14:41:46 - Upload successful! Video ID: 8FBabYvmg3o
# 14:41:46 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 1.mkv with title: New Folder - Psych 1 - General Psychology - Lecture 1
# 14:42:12 - Upload successful! Video ID: fOVBL7v4Sow
# 14:42:12 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 10.mkv with title: New Folder - Psych 1 - General Psychology - Lecture 10
# 14:42:36 - Upload successful! Video ID: QmI0EkciPWs
# 14:42:36 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 11.mkv with title: New Folder - Psych 1 - General Psychology - Lecture 11
# 14:43:01 - Upload successful! Video ID: lz9LQkkP1ck
# 14:43:01 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 12.mkv with title: New Folder - Psych 1 - General Psychology - Lecture 12
# 14:43:28 - Upload successful! Video ID: ZCQUWab1ah8
# 14:43:28 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 13.mkv with title: New Folder - Psych 1 - General Psychology - Lecture 13
# 14:43:53 - Upload successful! Video ID: x3tIPS5kwjg
# 14:43:53 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 14.mkv with title: New Folder - Psych 1 - General Psychology - Lecture 14
# 14:44:18 - Upload successful! Video ID: vMH37fUJC_g
# 14:44:18 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 15.mkv with title: New Folder - Psych 1 - General Psychology - Lecture 15
# 14:44:46 - Upload successful! Video ID: zTn_rQuU-8Y
# 14:44:46 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 16.mkv with title: New Folder - Psych 1 - General Psychology - Lecture 16
# 14:45:10 - Upload successful! Video ID: ZHG18x_b9Zk
# 14:45:10 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 17.mkv with title: New Folder - Psych 1 - General Psychology - Lecture 17
# 14:45:35 - Upload successful! Video ID: LE-cYwNtWq4
# 14:45:35 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 18.mkv with title: New Folder - Psych 1 - General Psychology - Lecture 18
# 14:45:53 - Upload successful! Video ID: rRiBJ_OEjx8
# 14:45:53 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 2.mkv with title: New Folder - Psych 1 - General Psychology - Lecture 2
# 14:46:12 - Upload successful! Video ID: Nm-Ws3iVtE0
# 14:46:12 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 20.mkv with title: New Folder - Psych 1 - General Psychology - Lecture 20
# 14:46:39 - Upload successful! Video ID: R4Ew7TIdWpQ
# 14:46:39 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 21.mkv with title: New Folder - Psych 1 - General Psychology - Lecture 21
# 14:47:05 - Upload successful! Video ID: ctzX1eoJGKQ
# 14:47:05 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 22.mkv with title: New Folder - Psych 1 - General Psychology - Lecture 22
# 14:47:31 - Upload successful! Video ID: mksJTetkwQg
# 14:47:31 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 23.mkv with title: New Folder - Psych 1 - General Psychology - Lecture 23
# 14:48:00 - Upload successful! Video ID: njlM2ttNaNQ
# 14:48:00 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 24.mkv with title: New Folder - Psych 1 - General Psychology - Lecture 24
# 14:48:26 - Upload successful! Video ID: sPC9o9h8hFo
# 14:48:26 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 25.mkv with title: New Folder - Psych 1 - General Psychology - Lecture 25
# 14:48:40 - Upload successful! Video ID: 2P4agftnZpE
# 14:48:40 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 3.mkv with title: New Folder - Psych 1 - General Psychology - Lecture 3
# 14:49:05 - Upload successful! Video ID: Zm3rlQbxFNE
# 14:49:05 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 4.mkv with title: New Folder - Psych 1 - General Psychology - Lecture 4
# 14:49:32 - Upload successful! Video ID: 7UW8lLBs7EA
# 14:49:32 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 5.mkv with title: New Folder - Psych 1 - General Psychology - Lecture 5
# 14:49:58 - Upload successful! Video ID: 7kGPzV-va0U
# 14:49:58 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 6.mkv with title: New Folder - Psych 1 - General Psychology - Lecture 6
# 14:50:25 - Upload successful! Video ID: 9aaTL-KuXJU
# 14:50:25 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 7.mkv with title: New Folder - Psych 1 - General Psychology - Lecture 7
# 14:50:53 - Upload successful! Video ID: ybjbWsEO8Pg
# 14:50:53 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 8.mkv with title: New Folder - Psych 1 - General Psychology - Lecture 8
# 14:51:18 - Upload successful! Video ID: YvcrxS1B5Wc
# 14:51:18 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 9.mkv with title: New Folder - Psych 1 - General Psychology - Lecture 9
# 14:51:43 - Upload successful! Video ID: G0-2GiCG0cI
# 14:51:43 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\01. The Agricultural Revolution  Crash Course World History #1.mp4 with title: World History - 01. The Agricultural Revolution  Crash Course World History #1
# 14:52:07 - Upload successful! Video ID: APcRCu8PIfM
# 14:52:07 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\02. Indus Valley Civilization  Crash Course World History #2.mp4 with title: World History - 02. Indus Valley Civilization  Crash Course World History #2
# 14:52:26 - Upload successful! Video ID: 7beaOqMJAM4
# 14:52:26 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\03. Mesopotamia  Crash Course World History #3.mp4 with title: World History - 03. Mesopotamia  Crash Course World History #3
# 14:52:52 - Upload successful! Video ID: uj7CLzBnzQ8
# 14:52:52 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\04. Ancient Egypt  Crash Course World History #4.mp4 with title: World History - 04. Ancient Egypt  Crash Course World History #4
# 14:53:16 - Upload successful! Video ID: jMHgXZnyZEo
# 14:53:16 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\05. The Persians & Greeks  Crash Course World History #5.mp4 with title: World History - 05. The Persians & Greeks  Crash Course World History #5
# 14:53:38 - Upload successful! Video ID: BPoM0YRMo-U
# 14:53:38 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\06. Buddha and Ashoka  Crash Course World History #6.mp4 with title: World History - 06. Buddha and Ashoka  Crash Course World History #6
# 14:54:01 - Upload successful! Video ID: -5iCu8OHqKQ
# 14:54:01 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\07. ‎2,000 Years of Chinese History! The Mandate of Heaven and Confucius  World History #7.mp4 with title: World History - 07. ‎2,000 Years of Chinese History! The Mandate of Heaven and Confucius  World Hist
# 14:54:28 - Upload successful! Video ID: Vw_i-wb9X_g
# 14:54:28 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\08. Alexander the Great and the Situation ... the Great Crash Course World History #8.mp4 with title: World History - 08. Alexander the Great and the Situation ... the Great Crash Course World History #
# 14:54:49 - Upload successful! Video ID: KvdiuY-TFTo
# 14:54:49 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\09. The Silk Road and Ancient Trade  Crash Course World History #9.mp4 with title: World History - 09. The Silk Road and Ancient Trade  Crash Course World History #9
# 14:55:11 - Upload successful! Video ID: iefLDyZMJds
# 14:55:11 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\10. The Roman Empire. Or Republic. Or...Which Was It  Crash Course World History #10.mp4 with title: World History - 10. The Roman Empire. Or Republic. Or...Which Was It  Crash Course World History #10
# 14:55:34 - Upload successful! Video ID: dbBNfgvD2v4
# 14:55:34 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\11. Christianity from Judaism to Constantine  Crash Course World History #11.mp4 with title: World History - 11. Christianity from Judaism to Constantine  Crash Course World History #11
# 14:55:59 - Upload successful! Video ID: cbQMR6nBUiY
# 14:55:59 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\12. Fall of The Roman Empire...in the 15th Century  Crash Course World History #12.mp4 with title: World History - 12. Fall of The Roman Empire...in the 15th Century  Crash Course World History #12
# 14:56:24 - Upload successful! Video ID: yRUOCKd8Ffc
# 14:56:24 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\13. Islam, the Quran, and the Five Pillars All Without a Flamewar  Crash Course World History #13.mp4 with title: World History - 13. Islam, the Quran, and the Five Pillars All Without a Flamewar  Crash Course Worl
# 14:56:48 - Upload successful! Video ID: T-bepyuxIy4
# 14:56:48 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\14. The Dark Ages...How Dark Were They, Really  Crash Course World History #14.mp4 with title: World History - 14. The Dark Ages...How Dark Were They, Really  Crash Course World History #14
# 14:57:11 - Upload successful! Video ID: 2u4EqPclq0A
# 14:57:11 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\15. The Crusades - Pilgrimage or Holy War  Crash Course World History #15.mp4 with title: World History - 15. The Crusades - Pilgrimage or Holy War  Crash Course World History #15
# 14:57:35 - Upload successful! Video ID: BxnB__1fUxI
# 14:57:35 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\16. Mansa Musa and Islam in Africa  Crash Course World History #16.mp4 with title: World History - 16. Mansa Musa and Islam in Africa  Crash Course World History #16
# 14:57:57 - Upload successful! Video ID: pu1Jh_-HSak
# 14:57:57 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\17. Wait For It...The Mongols!  Crash Course World History #17.mp4 with title: World History - 17. Wait For It...The Mongols!  Crash Course World History #17
# 14:58:21 - Upload successful! Video ID: 8sqDbaCYOqA
# 14:58:21 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\18. Int l Commerce, Snorkeling Camels, and The Indian Ocean Trade  Crash Course World History #18.mp4 with title: World History - 18. Int l Commerce, Snorkeling Camels, and The Indian Ocean Trade  Crash Course Worl
# 14:58:41 - Upload successful! Video ID: lcg0ykq3tmA
# 14:58:41 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\19. Venice and the Ottoman Empire  Crash Course World History #19.mp4 with title: World History - 19. Venice and the Ottoman Empire  Crash Course World History #19
# 14:59:01 - Upload successful! Video ID: UGEdIBqK62M
# 14:59:01 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\20. Russia, the Kievan Rus, and the Mongols  Crash Course World History #20.mp4 with title: World History - 20. Russia, the Kievan Rus, and the Mongols  Crash Course World History #20
# 14:59:23 - Upload successful! Video ID: 3zKnLwd-kSg
# 14:59:23 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\21. Columbus, de Gama, and Zheng He! 15th Century Mariners. Crash Course  World History #21.mp4 with title: World History - 21. Columbus, de Gama, and Zheng He! 15th Century Mariners. Crash Course  World Hist
# 14:59:44 - Upload successful! Video ID: dN_aroR7AbM
# 14:59:44 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\22. The Renaissance  Was it a Thing - Crash Course World History #22.mp4 with title: World History - 22. The Renaissance  Was it a Thing - Crash Course World History #22
# 15:00:06 - Upload successful! Video ID: -BPJqWSVIFE
# 15:00:06 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\23. The Columbian Exchange  Crash Course World History #23.mp4 with title: World History - 23. The Columbian Exchange  Crash Course World History #23
# 15:00:31 - Upload successful! Video ID: VtDF38COHCc
# 15:00:31 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\24. The Atlantic Slave Trade  Crash Course World History #24.mp4 with title: World History - 24. The Atlantic Slave Trade  Crash Course World History #24
# 15:00:54 - Upload successful! Video ID: -1H1sp-vYHU
# 15:00:54 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\25. The Spanish Empire, Silver, & Runaway Inflation  Crash Course World History #25.mp4 with title: World History - 25. The Spanish Empire, Silver, & Runaway Inflation  Crash Course World History #25
# 15:01:16 - Upload successful! Video ID: 4SPR0ETePSQ
# 15:01:16 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\26. The Seven Years War  Crash Course World History #26.mp4 with title: World History - 26. The Seven Years War  Crash Course World History #26
# 15:01:41 - Upload successful! Video ID: TpQQomIURN8
# 15:01:41 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\27. The Amazing Life and Strange Death of Captain Cook  Crash Course World History #27.mp4 with title: World History - 27. The Amazing Life and Strange Death of Captain Cook  Crash Course World History #
# 15:02:02 - Upload successful! Video ID: qGCrCXkaFz4
# 15:02:02 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\28. Tea, Taxes, and The American Revolution  Crash Course World History #28.mp4 with title: World History - 28. Tea, Taxes, and The American Revolution  Crash Course World History #28
# 15:02:24 - Upload successful! Video ID: HSAcHCzp5PQ
# 15:02:24 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\29. The French Revolution  Crash Course World History #29.mp4 with title: World History - 29. The French Revolution  Crash Course World History #29
# 15:02:50 - Upload successful! Video ID: yhbCX_CMcBg
# 15:02:50 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\30. Haitian Revolutions  Crash Course World History #30.mp4 with title: World History - 30. Haitian Revolutions  Crash Course World History #30
# 15:03:16 - Upload successful! Video ID: wJ0wIuQcRqc
# 15:03:16 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\31. Latin American Revolutions  Crash Course World History #31.mp4 with title: World History - 31. Latin American Revolutions  Crash Course World History #31
# 15:03:43 - Upload successful! Video ID: fVBKukFDRYk
# 15:03:43 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\32. Coal, Steam, and The Industrial Revolution  Crash Course World History #32.mp4 with title: World History - 32. Coal, Steam, and The Industrial Revolution  Crash Course World History #32
# 15:04:05 - Upload successful! Video ID: ZFCMdjCn0tY
# 15:04:05 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\33. Capitalism and Socialism  Crash Course World History #33.mp4 with title: World History - 33. Capitalism and Socialism  Crash Course World History #33
# 15:04:33 - Upload successful! Video ID: HkWgvIYaVek
# 15:04:33 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\34. Samurai, Daimyo, Matthew Perry, and Nationalism  Crash Course World History #34.mp4 with title: World History - 34. Samurai, Daimyo, Matthew Perry, and Nationalism  Crash Course World History #34
# 15:04:57 - Upload successful! Video ID: QIgD0enaSG0
# 15:04:57 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\35. Imperialism  Crash Course World History #35.mp4 with title: World History - 35. Imperialism  Crash Course World History #35
# 15:05:24 - Upload successful! Video ID: gKT0imDq92s
# 15:05:24 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\36. Archdukes, Cynicism, and World War I  Crash Course World History #36.mp4 with title: World History - 36. Archdukes, Cynicism, and World War I  Crash Course World History #36
# 15:05:51 - Upload successful! Video ID: 8V5XI9JvkOA
# 15:05:51 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\37. Communists, Nationalists, and China s Revolutions  Crash Course World History #37.mp4 with title: World History - 37. Communists, Nationalists, and China s Revolutions  Crash Course World History #3
# 15:06:19 - Upload successful! Video ID: 1XO1EQG9DuU
# 15:06:19 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\38. World War II  Crash Course World History #38.mp4 with title: World History - 38. World War II  Crash Course World History #38
# 15:06:48 - Upload successful! Video ID: o1dJYUWNKBA
# 15:06:48 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\39. USA vs USSR Fight! The Cold War  Crash Course World History #39.mp4 with title: World History - 39. USA vs USSR Fight! The Cold War  Crash Course World History #39
# 15:07:13 - Upload successful! Video ID: A0VXULl4cEo
# 15:07:13 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\40. Decolonization and Nationalism Triumphant  Crash Course World History #40.mp4 with title: World History - 40. Decolonization and Nationalism Triumphant  Crash Course World History #40
# 15:07:40 - Upload successful! Video ID: RFvgNK6CTjE
# 15:07:40 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\41. Globalization I - The Upside  Crash Course World History #41.mp4 with title: World History - 41. Globalization I - The Upside  Crash Course World History #41
# 15:08:02 - Upload successful! Video ID: LPeIDHkhhDE
# 15:08:02 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History\42. Globalization II - Good or Bad  Crash Course World History #42.mp4 with title: World History - 42. Globalization II - Good or Bad  Crash Course World History #42
# 15:08:29 - Upload successful! Video ID: KX3IjAsTncI
# 15:08:29 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History 2\01. Rethinking Civilization - Crash Course World History 201.mp4 with title: World History 2 - 01. Rethinking Civilization - Crash Course World History 201
# 15:08:56 - Upload successful! Video ID: z5wLFjsL43g
# 15:08:56 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History 2\02. Money & Debt  Crash Course World History 202.mp4 with title: World History 2 - 02. Money & Debt  Crash Course World History 202
# 15:09:24 - Upload successful! Video ID: J2zaDGPODbk
# 15:09:24 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History 2\03. Disease! Crash Course World History 203.mp4 with title: World History 2 - 03. Disease! Crash Course World History 203
# 15:09:47 - Upload successful! Video ID: JYgTGurWimY
# 15:09:47 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History 2\04. War & Human Nature  Crash Course World History 204.mp4 with title: World History 2 - 04. War & Human Nature  Crash Course World History 204
# 15:10:07 - Upload successful! Video ID: jBt2AesfCdM
# 15:10:07 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History 2\05. War and Civilization  Crash Course World History 205.mp4 with title: World History 2 - 05. War and Civilization  Crash Course World History 205
# 15:10:34 - Upload successful! Video ID: 15iIqgbTk7I
# 15:10:34 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History 2\06. Climate Change, Chaos, and The Little Ice Age - Crash Course World History 206.mp4 with title: World History 2 - 06. Climate Change, Chaos, and The Little Ice Age - Crash Course World History 206
# 15:10:56 - Upload successful! Video ID: 8UQxgqds9V0
# 15:10:56 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History 2\07. Humans and Energy  Crash Course World History 207.mp4 with title: World History 2 - 07. Humans and Energy  Crash Course World History 207
# 15:11:11 - Upload successful! Video ID: 5IG5hkoomnw
# 15:11:11 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History 2\08. Drought and Famine  Crash Course World History #208.mp4 with title: World History 2 - 08. Drought and Famine  Crash Course World History #208
# 15:11:34 - Upload successful! Video ID: OkjLU-k4tdM
# 15:11:34 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History 2\09. HOW World War I Started  Crash Course World History 209.mp4 with title: World History 2 - 09. HOW World War I Started  Crash Course World History 209
# 15:11:54 - Upload successful! Video ID: 3ylo_XcEecE
# 15:11:54 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History 2\10. Who Started World War I  Crash Course World History 210.mp4 with title: World History 2 - 10. Who Started World War I  Crash Course World History 210
# 15:12:18 - Upload successful! Video ID: jOnXuTxwPIE
# 15:12:18 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History 2\11. The End of Civilization (In the Bronze Age)  Crash Course World History 211.mp4 with title: World History 2 - 11. The End of Civilization (In the Bronze Age)  Crash Course World History 211
# 15:12:44 - Upload successful! Video ID: ZUMEDaYKPUU
# 15:12:44 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History 2\12. The Rise of the West and Historical Methodology  Crash Course World History #212.mp4 with title: World History 2 - 12. The Rise of the West and Historical Methodology  Crash Course World History #2
# 15:13:07 - Upload successful! Video ID: sGhm4SOQx5Q
# 15:13:07 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History 2\13. Asian Responses to Imperialism  Crash Course World History #213.mp4 with title: World History 2 - 13. Asian Responses to Imperialism  Crash Course World History #213
# 15:13:32 - Upload successful! Video ID: MI6KxhJBip0
# 15:13:32 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History 2\14. The Railroad Journey and the Industrial Revolution  Crash Course World History 214.mp4 with title: World History 2 - 14. The Railroad Journey and the Industrial Revolution  Crash Course World History
# 15:13:57 - Upload successful! Video ID: NbUYIrQQb08
# 15:13:57 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History 2\15. Population, Sustainability, and Malthus  Crash Course World History 215.mp4 with title: World History 2 - 15. Population, Sustainability, and Malthus  Crash Course World History 215
# 15:14:25 - Upload successful! Video ID: o2QeCp7jO68
# 15:14:25 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History 2\16. Islam and Politics  Crash Course World History 216.mp4 with title: World History 2 - 16. Islam and Politics  Crash Course World History 216
# 15:14:51 - Upload successful! Video ID: oXMmaOMx0-o
# 15:14:51 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History 2\17. The Mughal Empire and Historical Reputation  Crash Course World History #217.mp4 with title: World History 2 - 17. The Mughal Empire and Historical Reputation  Crash Course World History #217
# 15:15:14 - Upload successful! Video ID: 2znFvxIw4dM
# 15:15:14 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History 2\18. Luther and the Protestant Reformation  Crash Course World History #218.mp4 with title: World History 2 - 18. Luther and the Protestant Reformation  Crash Course World History #218
# 15:15:46 - Upload successful! Video ID: OFY6p0ybHQ4
# 15:15:46 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History 2\19. Charles V and the Holy Roman Empire  Crash Course World History #219.mp4 with title: World History 2 - 19. Charles V and the Holy Roman Empire  Crash Course World History #219
# 15:16:12 - Upload successful! Video ID: QX8uLJYIeAk
# 15:16:12 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History 2\20. World War II, A War for Resources  Crash Course World History #220.mp4 with title: World History 2 - 20. World War II, A War for Resources  Crash Course World History #220
# 15:16:35 - Upload successful! Video ID: qFdewNdKEs4
# 15:16:35 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History 2\21. Congo and Africa s World War  Crash Course World History 221.mp4 with title: World History 2 - 21. Congo and Africa s World War  Crash Course World History 221
# 15:16:59 - Upload successful! Video ID: ITB2XVhOxt0
# 15:16:59 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History 2\22. Water and Classical Civilizations  Crash Course World History 222.mp4 with title: World History 2 - 22. Water and Classical Civilizations  Crash Course World History 222
# 15:17:23 - Upload successful! Video ID: 1GrkHcVTZRE
# 15:17:23 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History 2\23. Conflict in Israel and Palestine  Crash Course World History 223.mp4 with title: World History 2 - 23. Conflict in Israel and Palestine  Crash Course World History 223
# 15:17:49 - Upload successful! Video ID: L1-5Fuo9D9I
# 15:17:49 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History 2\24. The Vikings! - Crash Course World History 224.mp4 with title: World History 2 - 24. The Vikings! - Crash Course World History 224
# 15:18:13 - Upload successful! Video ID: rYaESE9pj0M
# 15:18:13 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History 2\25. War and Nation Building in Latin America  Crash Course World History 225.mp4 with title: World History 2 - 25. War and Nation Building in Latin America  Crash Course World History 225
# 15:18:37 - Upload successful! Video ID: ms3ME9rJQHA
# 15:18:37 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History 2\26. Iran s Revolutions  Crash Course World History 226.mp4 with title: World History 2 - 26. Iran s Revolutions  Crash Course World History 226
# 15:19:05 - Upload successful! Video ID: e4xeFSZzJfE
# 15:19:05 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History 2\27. Japan in the Heian Period and Cultural History  Crash Course World History 227.mp4 with title: World History 2 - 27. Japan in the Heian Period and Cultural History  Crash Course World History 227
# 15:19:35 - Upload successful! Video ID: Mnl5HZwVrtU
# 15:19:35 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History 2\28. Nonviolence and Peace Movements  Crash Course World History 228.mp4 with title: World History 2 - 28. Nonviolence and Peace Movements  Crash Course World History 228
# 15:20:01 - Upload successful! Video ID: gvVq8e-UFqY
# 15:20:01 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History 2\29. Capitalism and the Dutch East India Company  Crash Course World History 229.mp4 with title: World History 2 - 29. Capitalism and the Dutch East India Company  Crash Course World History 229
# 15:20:32 - Upload successful! Video ID: VZ-STX63BlI
# 15:20:32 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Literature And History\World History\World History 2\30. Democracy, Authoritarian Capitalism, and China  Crash Course World History 230.mp4 with title: World History 2 - 30. Democracy, Authoritarian Capitalism, and China  Crash Course World History 230
# 15:21:03 - Upload successful! Video ID: bTRefXz1xwg
# 15:21:03 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\03-Philosophers (1700-2000)\Immanuel Kant\Oxford Lectures\01 - Just what is Kant's Project.mp4 with title: Oxford Lectures - 01 - Just what is Kant's Project
# 15:22:57 - Upload successful! Video ID: GHOB-zijPss
# 15:22:57 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\03-Philosophers (1700-2000)\Immanuel Kant\Oxford Lectures\02 - The broader philosophical context.mp4 with title: Oxford Lectures - 02 - The broader philosophical context
# 15:22:57 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:22:57 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\03-Philosophers (1700-2000)\Immanuel Kant\Oxford Lectures\02 - The broader philosophical context.mp4 to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:22:57 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\03-Philosophers (1700-2000)\Immanuel Kant\Oxford Lectures\02 - The broader philosophical context.mp4 in 3 minutes...
# 15:25:58 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:25:58 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\03-Philosophers (1700-2000)\Immanuel Kant\Oxford Lectures\02 - The broader philosophical context.mp4 to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:25:58 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\03-Philosophers (1700-2000)\Immanuel Kant\Oxford Lectures\02 - The broader philosophical context.mp4 in 3 minutes...
# 15:28:58 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:28:58 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\03-Philosophers (1700-2000)\Immanuel Kant\Oxford Lectures\02 - The broader philosophical context.mp4 to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:28:58 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\03-Philosophers (1700-2000)\Immanuel Kant\Oxford Lectures\02 - The broader philosophical context.mp4 after 3 attempts.
# 15:28:58 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\03-Philosophers (1700-2000)\Immanuel Kant\Oxford Lectures\02 - The broader philosophical context.mp4
# 15:28:58 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\03-Philosophers (1700-2000)\Immanuel Kant\Oxford Lectures\03 - Space, time and the Analogies of Experiences.mp4 with title: Oxford Lectures - 03 - Space, time and the Analogies of Experiences
# 15:28:58 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:28:58 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\03-Philosophers (1700-2000)\Immanuel Kant\Oxford Lectures\03 - Space, time and the Analogies of Experiences.mp4 to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:28:58 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\03-Philosophers (1700-2000)\Immanuel Kant\Oxford Lectures\03 - Space, time and the Analogies of Experiences.mp4 in 3 minutes...
# 15:31:58 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:31:58 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\03-Philosophers (1700-2000)\Immanuel Kant\Oxford Lectures\03 - Space, time and the Analogies of Experiences.mp4 to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:31:58 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\03-Philosophers (1700-2000)\Immanuel Kant\Oxford Lectures\03 - Space, time and the Analogies of Experiences.mp4 in 3 minutes...
# 15:34:58 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:34:58 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\03-Philosophers (1700-2000)\Immanuel Kant\Oxford Lectures\03 - Space, time and the Analogies of Experiences.mp4 to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:34:58 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\03-Philosophers (1700-2000)\Immanuel Kant\Oxford Lectures\03 - Space, time and the Analogies of Experiences.mp4 after 3 attempts.
# 15:34:58 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\03-Philosophers (1700-2000)\Immanuel Kant\Oxford Lectures\03 - Space, time and the Analogies of Experiences.mp4
# 15:34:58 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\03-Philosophers (1700-2000)\Immanuel Kant\Oxford Lectures\04 - How are a priori synthetic judgements possible.mp4 with title: Oxford Lectures - 04 - How are a priori synthetic judgements possible
# 15:34:58 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:34:58 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\03-Philosophers (1700-2000)\Immanuel Kant\Oxford Lectures\04 - How are a priori synthetic judgements possible.mp4 to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:34:58 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\03-Philosophers (1700-2000)\Immanuel Kant\Oxford Lectures\04 - How are a priori synthetic judgements possible.mp4 in 3 minutes...
# 15:37:59 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:37:59 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\03-Philosophers (1700-2000)\Immanuel Kant\Oxford Lectures\04 - How are a priori synthetic judgements possible.mp4 to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:37:59 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\03-Philosophers (1700-2000)\Immanuel Kant\Oxford Lectures\04 - How are a priori synthetic judgements possible.mp4 in 3 minutes...
# 15:40:59 - Encountered 403 Forbidden with reason "quotaExceeded"
# ...
# 12:51:05 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_116.wmv in 3 minutes...
# 12:54:06 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_116.wmv to YouTube (attempt 2): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 12:54:06 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_116.wmv in 3 minutes...
# 12:57:06 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_116.wmv to YouTube (attempt 3): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 12:57:06 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_116.wmv after 3 attempts.
# 12:57:06 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_116.wmv
# 12:57:06 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_117.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_117
# 12:57:07 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_117.wmv to YouTube (attempt 1): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 12:57:07 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_117.wmv in 3 minutes...
# 13:00:08 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_117.wmv to YouTube (attempt 2): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 13:00:08 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_117.wmv in 3 minutes...
# 13:03:08 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_117.wmv to YouTube (attempt 3): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 13:03:08 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_117.wmv after 3 attempts.
# 13:03:08 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_117.wmv
# 13:03:08 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_118.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_118
# 13:03:08 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_118.wmv to YouTube (attempt 1): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 13:03:08 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_118.wmv in 3 minutes...
# 13:06:09 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_118.wmv to YouTube (attempt 2): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 13:06:09 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_118.wmv in 3 minutes...
# 13:09:09 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_118.wmv to YouTube (attempt 3): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 13:09:09 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_118.wmv after 3 attempts.
# 13:09:09 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_118.wmv
# 13:09:09 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_119.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_119
# 13:09:10 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_119.wmv to YouTube (attempt 1): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 13:09:10 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_119.wmv in 3 minutes...
# 13:12:10 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_119.wmv to YouTube (attempt 2): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 13:12:10 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_119.wmv in 3 minutes...
# 13:15:11 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_119.wmv to YouTube (attempt 3): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 13:15:11 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_119.wmv after 3 attempts.
# 13:15:11 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_119.wmv
# 13:15:11 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_120.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_120
# 13:15:11 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_120.wmv to YouTube (attempt 1): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 13:15:11 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_120.wmv in 3 minutes...
# 13:18:12 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_120.wmv to YouTube (attempt 2): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 13:18:12 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_120.wmv in 3 minutes...
# 13:21:12 - Encountered 403 Forbidden with reason "quotaExceeded"
# 13:21:12 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_120.wmv to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 13:21:12 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_120.wmv after 3 attempts.
# 13:21:12 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_120.wmv
# 13:21:12 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_121.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_121
# 13:21:12 - Encountered 403 Forbidden with reason "quotaExceeded"
# 13:21:12 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_121.wmv to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 13:21:12 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_121.wmv in 3 minutes...
# 13:24:12 - Encountered 403 Forbidden with reason "quotaExceeded"
# 13:24:12 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_121.wmv to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 13:24:12 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_121.wmv in 3 minutes...
# 13:27:13 - Encountered 403 Forbidden with reason "quotaExceeded"
# 13:27:13 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_121.wmv to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 13:27:13 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_121.wmv after 3 attempts.
# 13:27:13 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_121.wmv
# 13:27:13 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_122.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_122
# 13:27:13 - Encountered 403 Forbidden with reason "quotaExceeded"
# 13:27:13 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_122.wmv to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 13:27:13 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_122.wmv in 3 minutes...
