# %%
import os
import sys
import glob
import logging
from datetime import datetime
from pathlib import Path
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import tkinter as tk
from tkinter import filedialog
from google_auth_oauthlib.flow import InstalledAppFlow
from google.oauth2.credentials import Credentials
from google.auth.transport.requests import Request
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload
import time

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(message)s',
    datefmt='%H:%M:%S',
    handlers=[
        logging.FileHandler('upload_all.log', encoding='utf-8'),
        logging.StreamHandler()
    ]
)

TOKEN_FILE = "token.json"
SCOPES = ["https://www.googleapis.com/auth/youtube.upload"]

os.environ['OAUTHLIB_INSECURE_TRANSPORT'] = '1'
os.environ['PYTHONHTTPSVERIFY'] = '0'

def get_authenticated_service(client_secrets_file: str):
    creds = None
    if os.path.exists(TOKEN_FILE):
        creds = Credentials.from_authorized_user_file(TOKEN_FILE, SCOPES)
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(client_secrets_file, SCOPES)
            creds = flow.run_local_server(port=0)
        with open(TOKEN_FILE, 'w') as token:
            token.write(creds.to_json())
    return build('youtube', 'v3', credentials=creds)

def upload_to_youtube(youtube, video_path: str, title: str, description: str = "Uploaded by script"):
    MAX_RETRIES = 3
    RETRY_DELAY_SECONDS = 180  # 3 minutes
    for attempt in range(1, MAX_RETRIES + 1):
        try:
            body = {
                'snippet': {
                    'title': title,
                    'description': description,
                    'tags': ['tutorial', 'education']
                },
                'status': {
                    'privacyStatus': 'unlisted',
                    'selfDeclaredMadeForKids': False
                }
            }
            insert_request = youtube.videos().insert(
                part=','.join(body.keys()),
                body=body,
                media_body=MediaFileUpload(video_path, chunksize=-1, resumable=True)
            )
            response = None
            while response is None:
                status, response = insert_request.next_chunk()
                if status:
                    logging.info(f"Upload {int(status.progress() * 100)}% complete for {video_path}")
            return response['id']
        except Exception as e:
            logging.error(f"Error uploading {video_path} to YouTube (attempt {attempt}): {str(e)}")
            if attempt < MAX_RETRIES:
                logging.info(f"Retrying upload for {video_path} in {RETRY_DELAY_SECONDS // 60} minutes...")
                time.sleep(RETRY_DELAY_SECONDS)
            else:
                logging.error(f"Upload failed for {video_path} after {MAX_RETRIES} attempts.")
                return None

def select_folder_dialog(title="Select folder"):
    """Open a folder selection dialog and return the selected path."""
    try:
        root = tk.Tk()
        root.withdraw()
        root.update_idletasks()
        width = root.winfo_screenwidth()
        height = root.winfo_screenheight()
        x = (width - 400) // 2
        y = (height - 300) // 2
        root.geometry(f'400x300+{x}+{y}')
        folder_path = filedialog.askdirectory(
            title=title,
            mustexist=True
        )
        root.destroy()
        return folder_path
    except Exception as e:
        logging.error(f"Error in folder selection: {str(e)}")
        return None

def main():
    # Select parent folder
    parent_folder = select_folder_dialog(title="Select parent folder containing videos to upload recursively")
    if not parent_folder or not os.path.exists(parent_folder):
        logging.error("No folder selected or folder does not exist")
        return
    cwd = os.getcwd()
    client_secrets_file = os.path.join(cwd, "client_secret.dlc.json")
    if not os.path.exists(client_secrets_file):
        logging.error(f"Client secrets file not found at: {client_secrets_file}")
        return
    youtube = get_authenticated_service(client_secrets_file)
    logging.info("YouTube authentication complete.")
    VIDEO_EXTENSIONS = ('.mp4', '.mkv', '.avi', '.mov', '.wmv', '.flv', '.webm', '.3gp')
    for root, _, files in os.walk(parent_folder):
        for file in files:
            if file.lower().endswith(VIDEO_EXTENSIONS) and not file.endswith('.txt'):
                video_path = os.path.join(root, file)
                video_name = os.path.splitext(file)[0]
                link_file = os.path.join(root, f"{video_name}.txt")
                if not os.path.exists(link_file):
                    folder_name = os.path.basename(root)
                    MAX_TITLE_LENGTH = 100
                    title = f"{folder_name} - {video_name}"
                    if len(title) > MAX_TITLE_LENGTH:
                        title = title[:MAX_TITLE_LENGTH]
                    logging.info(f"Uploading: {video_path} with title: {title}")
                    video_id = upload_to_youtube(youtube, video_path, title)
                    if video_id:
                        with open(link_file, 'w') as f:
                            f.write(f"https://www.youtube.com/watch?v={video_id}\n")
                        try:
                            os.remove(video_path)
                        except Exception as e:
                            logging.error(f"Failed to delete uploaded video file: {video_path}: {str(e)}")
                        logging.info(f"Upload successful! Video ID: {video_id}")
                    else:
                        logging.error(f"Upload failed for {video_path}")
                else:
                    logging.info(f"Link file already exists for {video_path}. Skipping upload.")
    logging.info("All specified folders and subfolders processed.")

if __name__ == "__main__":
    main()
# Out:
# 23:44:09 - file_cache is only supported with oauth2client<4.0.0
# 23:44:09 - YouTube authentication complete.
# 23:44:09 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Godless Saudi\نيل ديغراس تايسون  إله الفجوات. مترجم.mp4 with title: Godless Saudi - نيل ديغراس تايسون  إله الفجوات. مترجم
# 23:44:15 - Upload successful! Video ID: eOmMVhFh5Gg
# 23:44:15 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Godless Saudi\هارون يحيى يرقص غانغنم ستايل Gangnam Style.mp4 with title: Godless Saudi - هارون يحيى يرقص غانغنم ستايل Gangnam Style
# 23:44:23 - Upload successful! Video ID: QigxaH90GR8
# 23:44:23 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Heba Dakak\أوضاع اللاجئين في أوروبا مع هبة دقاق - برنامج البط الأسود ٢٥١.mp4 with title: Heba Dakak - أوضاع اللاجئين في أوروبا مع هبة دقاق - برنامج البط الأسود ٢٥١
# 23:46:28 - Upload successful! Video ID: AF9LkMIs1b8
# 23:46:28 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Heba Dakak\وجهة نظر في الأحداث السورية مع هبة دقاق - برنامج البط الأسود ٢٥٣.mp4 with title: Heba Dakak - وجهة نظر في الأحداث السورية مع هبة دقاق - برنامج البط الأسود ٢٥٣
# 23:48:12 - Upload successful! Video ID: 81_-p8lTd80
# 23:48:12 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Just X\Just X 01.3gp with title: Just X - Just X 01
# 23:48:17 - Upload successful! Video ID: 2bt-fdOcOeg
# 23:48:17 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Just X\Just X 02.3gp with title: Just X - Just X 02
# 23:48:25 - Upload successful! Video ID: G-7KnSHXyRk
# 23:48:25 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Just X\Just X 03.3gp with title: Just X - Just X 03
# 23:48:37 - Upload successful! Video ID: oyd_s6i7RPU
# 23:48:37 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Just X\Just X 04.3gp with title: Just X - Just X 04
# 23:48:46 - Upload successful! Video ID: bKTHQVpoKxk
# 23:48:46 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Just X\Just X 05.3gp with title: Just X - Just X 05
# 23:48:50 - Upload successful! Video ID: druEil8f4xk
# 23:48:50 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Just X\Just X 06 Monazra.3gp with title: Just X - Just X 06 Monazra
# 23:48:59 - Upload successful! Video ID: OwrGzNi09FY
# 23:48:59 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Just X\Just X 07 Logical Fallacies.3gp with title: Just X - Just X 07 Logical Fallacies
# 23:49:05 - Upload successful! Video ID: GUrl6rif8zE
# 23:49:05 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Just X\Just X 08 Embryo.3gp with title: Just X - Just X 08 Embryo
# 23:49:11 - Upload successful! Video ID: Thlaz4kdlgE
# 23:49:11 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Just X\Just X 09.3gp with title: Just X - Just X 09
# 23:49:15 - Upload successful! Video ID: 9CuAR_vfWiM
# 23:49:15 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Just X\Just X 10.3gp with title: Just X - Just X 10
# 23:49:23 - Upload successful! Video ID: UYCSNma6BaU
# 23:49:23 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Khelood\الإستغباء الممنهج   الحلقة 1.mp4 with title: Khelood - الإستغباء الممنهج   الحلقة 1
# 23:49:35 - Upload successful! Video ID: NVUy2VffKx4
# 23:49:35 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Khelood\التطرف الكوميدى (هيئة الأمر بالمعروف و النهى عن المنكر) الجزء الأول.mp4 with title: Khelood - التطرف الكوميدى (هيئة الأمر بالمعروف و النهى عن المنكر) الجزء الأول
# 23:50:00 - Upload successful! Video ID: QMqLOpjA_BI
# 23:50:00 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Khelood\التطرف الكوميدى (هيئة الأمر بالمعروف و النهى عن المنكر) الجزء الأول‬.mp4 with title: Khelood - التطرف الكوميدى (هيئة الأمر بالمعروف و النهى عن المنكر) الجزء الأول‬
# 23:50:23 - Upload successful! Video ID: hBwW6W5Db64
# 23:50:23 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Khelood\التطرف الكوميدى (هيئة الأمر بالمعروف و النهى عن المنكر) الجزء الثالث.mp4 with title: Khelood - التطرف الكوميدى (هيئة الأمر بالمعروف و النهى عن المنكر) الجزء الثالث
# 23:50:44 - Upload successful! Video ID: 6_mtEnznShE
# 23:50:44 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Khelood\التطرف الكوميدى (هيئة الأمر بالمعروف و النهى عن المنكر) الجزء الثانى.mp4 with title: Khelood - التطرف الكوميدى (هيئة الأمر بالمعروف و النهى عن المنكر) الجزء الثانى
# 23:51:12 - Upload successful! Video ID: FiZmoVIDmFM
# 23:51:12 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Khelood\التطرف الكوميدى (هيئة الأمر بالمعروف و النهى عن المنكر) الجزء الثانى‬ .mp4 with title: Khelood - التطرف الكوميدى (هيئة الأمر بالمعروف و النهى عن المنكر) الجزء الثانى‬
# 23:51:39 - Upload successful! Video ID: XJ8qVy1CKOg
# 23:51:39 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\masrymolhed\001 الحويني هل هو المرض أم عرض له.mp4 with title: masrymolhed - 001 الحويني هل هو المرض أم عرض له
# 23:51:50 - Upload successful! Video ID: 3OjiBEfhjRw
# 23:51:50 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\masrymolhed\002 لماذا أنا ملحد 1.mp4 with title: masrymolhed - 002 لماذا أنا ملحد 1
# 23:51:59 - Upload successful! Video ID: 1Nz60s2LfH8
# 23:51:59 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\masrymolhed\003 لماذا أنا ملحد 2.mp4 with title: masrymolhed - 003 لماذا أنا ملحد 2
# 23:52:09 - Upload successful! Video ID: hzE2wipNHDs
# 23:52:09 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\masrymolhed\004 لماذا أنا ملحد 3.mp4 with title: masrymolhed - 004 لماذا أنا ملحد 3
# 23:52:19 - Upload successful! Video ID: 7DYpwkDKuhQ
# 23:52:19 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\masrymolhed\005 لماذا أنا ملحد 4.mp4 with title: masrymolhed - 005 لماذا أنا ملحد 4
# 23:52:30 - Upload successful! Video ID: 3E0poOZtYZA
# 23:52:30 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\masrymolhed\007 لماذا أنا ملحد 6.mp4 with title: masrymolhed - 007 لماذا أنا ملحد 6
# 23:52:41 - Upload successful! Video ID: 01Ur11J9dtg
# 23:52:41 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\masrymolhed\008 لماذا أنا ملحد 7.mp4 with title: masrymolhed - 008 لماذا أنا ملحد 7
# 23:52:52 - Upload successful! Video ID: NcP8w80soAU
# 23:52:52 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\masrymolhed\009 لماذا أنا ملحد 8.mp4 with title: masrymolhed - 009 لماذا أنا ملحد 8
# 23:53:03 - Upload successful! Video ID: EcbpA31EoKw
# 23:53:03 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\masrymolhed\010 لماذا أنا ملحد 9.mp4 with title: masrymolhed - 010 لماذا أنا ملحد 9
# 23:53:17 - Upload successful! Video ID: YJ5dsnoe5w4
# 23:53:17 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\masrymolhed\011 لماذا أنا ملحد 10.mp4 with title: masrymolhed - 011 لماذا أنا ملحد 10
# 23:53:31 - Upload successful! Video ID: 4e9Z0DNdd-Q
# 23:53:31 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\masrymolhed\012 لماذا أنا ملحد 11.mp4 with title: masrymolhed - 012 لماذا أنا ملحد 11
# 23:53:45 - Upload successful! Video ID: 67JKVsSSo-o
# 23:53:45 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\masrymolhed\013 لماذا أنا ملحد 12.mp4 with title: masrymolhed - 013 لماذا أنا ملحد 12
# 23:53:58 - Upload successful! Video ID: L0ofZRGJsKs
# 23:53:58 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\masrymolhed\014 لماذا أنا ملحد 13.mp4 with title: masrymolhed - 014 لماذا أنا ملحد 13
# 23:54:13 - Upload successful! Video ID: TuImHwJka2A
# 23:54:13 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\masrymolhed\015 لماذا أنا ملحد 14.mp4 with title: masrymolhed - 015 لماذا أنا ملحد 14
# 23:54:25 - Upload successful! Video ID: X98LD9up1EU
# 23:54:25 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\masrymolhed\016 لماذا أنا ملحد 15.mp4 with title: masrymolhed - 016 لماذا أنا ملحد 15
# 23:54:40 - Upload successful! Video ID: yI3mbd8z6kw
# 23:54:40 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\masrymolhed\017 لماذا أنا ملحد 16.mp4 with title: masrymolhed - 017 لماذا أنا ملحد 16
# 23:54:54 - Upload successful! Video ID: FErMsloDZmk
# 23:54:54 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\masrymolhed\018 لماذا أنا ملحد 17.mp4 with title: masrymolhed - 018 لماذا أنا ملحد 17
# 23:55:08 - Upload successful! Video ID: lhXA3_5cLuo
# 23:55:08 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\masrymolhed\019 لماذا أنا ملحد 18.mp4 with title: masrymolhed - 019 لماذا أنا ملحد 18
# 23:55:24 - Upload successful! Video ID: OgCU5oufZd8
# 23:55:24 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\masrymolhed\020 لماذا أنا ملحد 19.mp4 with title: masrymolhed - 020 لماذا أنا ملحد 19
# 23:55:37 - Upload successful! Video ID: Rjobx8SRcwU
# 23:55:37 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\masrymolhed\021 لماذا أنا ملحد 20.mp4 with title: masrymolhed - 021 لماذا أنا ملحد 20
# 23:55:54 - Upload successful! Video ID: b1247Ncbwxs
# 23:55:54 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\masrymolhed\022 لماذا أنا ملحد 21.mp4 with title: masrymolhed - 022 لماذا أنا ملحد 21
# 23:56:07 - Upload successful! Video ID: 0stBacHRbNY
# 23:56:07 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\masrymolhed\023 رسالة مفتوحة إلى سيادة المشير.mp4 with title: masrymolhed - 023 رسالة مفتوحة إلى سيادة المشير
# 23:56:14 - Upload successful! Video ID: 8gx87wnAv5Q
# 23:56:14 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\masrymolhed\024 حول إهانة المقدسات.mp4 with title: masrymolhed - 024 حول إهانة المقدسات
# 23:56:30 - Upload successful! Video ID: OTPflVnmK7g
# 23:56:30 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\masrymolhed\أتينا لنخرج العباد من عبادة العباد إلى عبادة البتنجان الإسود MasryMolhed.mp4 with title: masrymolhed - أتينا لنخرج العباد من عبادة العباد إلى عبادة البتنجان الإسود MasryMolhed
# 23:56:47 - Upload successful! Video ID: gQFGRaFYa9E
# 23:56:47 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\masrymolhed\الحريه في الإسلام MasryMolhed.mp4 with title: masrymolhed - الحريه في الإسلام MasryMolhed
# 23:57:02 - Upload successful! Video ID: z-_EWJwf5Gk
# 23:57:02 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\masrymolhed\حد الردة MasryMolhed.mp4 with title: masrymolhed - حد الردة MasryMolhed
# 23:57:15 - Upload successful! Video ID: wV0zEFIVKoc
# 23:57:15 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\masrymolhed\دياثة رسول الله عديم الشرف MasryMolhed.mp4 with title: masrymolhed - دياثة رسول الله عديم الشرف MasryMolhed
# 23:57:22 - Upload successful! Video ID: zKgheIuJjWA
# 23:57:22 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\masrymolhed\سبب الخلاف بين عائشه وعلي MasryMolhed.mp4 with title: masrymolhed - سبب الخلاف بين عائشه وعلي MasryMolhed
# 23:57:29 - Upload successful! Video ID: cQl7azsEhDs
# 23:57:29 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\masrymolhed\سيمفونية العلم  - متعة الاكتشاف [مترجم] (بيل ناي)   كلمات من مناظرة بيل نايل وكين هام.mp4 with title: masrymolhed - سيمفونية العلم  - متعة الاكتشاف [مترجم] (بيل ناي)   كلمات من مناظرة بيل نايل وكين هام
# 23:57:32 - Upload successful! Video ID: TFygxwqP6Ak
# 23:57:32 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\masrymolhed\قذارة صلعم MasryMolhed.mp4 with title: masrymolhed - قذارة صلعم MasryMolhed
# 23:57:41 - Upload successful! Video ID: OG1bgaJAk-U
# 23:57:41 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\masrymolhed\ماذا لو بعث رسول الله في هذا الزمن؟ MasryMolhed.mp4 with title: masrymolhed - ماذا لو بعث رسول الله في هذا الزمن؟ MasryMolhed
# 23:57:45 - Upload successful! Video ID: qBziFIE7_uY
# 23:57:45 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\masrymolhed\مصري ملحد يعلن توبته ويتلو أيات من الذكر الحكيم MasryMolhed.mp4 with title: masrymolhed - مصري ملحد يعلن توبته ويتلو أيات من الذكر الحكيم MasryMolhed
# 23:57:52 - Upload successful! Video ID: pwR1yhnNhk8
# 23:57:52 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\masrymolhed\هل ترك رسول الله إمرأه لم ينكحها في الجزيره العربيه؟ MasryMolhed.mp4 with title: masrymolhed - هل ترك رسول الله إمرأه لم ينكحها في الجزيره العربيه؟ MasryMolhed
# 23:58:08 - Upload successful! Video ID: o08Yo0Xe4Mg
# 23:58:08 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\masrymolhed\هل وضع محمد أسس لنظام الحكم و تداول السلطه بعد هلاكه؟ MasryMolhed.mp4 with title: masrymolhed - هل وضع محمد أسس لنظام الحكم و تداول السلطه بعد هلاكه؟ MasryMolhed
# 23:58:13 - Upload successful! Video ID: uOSkEh62fAw
# 23:58:13 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\MasryMolhed 2nd\أبانا الذى فى اليوتيوب.mp4 with title: MasryMolhed 2nd - أبانا الذى فى اليوتيوب
# 23:58:22 - Upload successful! Video ID: NfbHbcNECrA
# 23:58:22 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\MasryMolhed 2nd\الأزهر الجريمة والعقاب.mp4 with title: MasryMolhed 2nd - الأزهر الجريمة والعقاب
# 23:58:54 - Upload successful! Video ID: 1MREJlSW33I
# 23:58:54 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\MasryMolhed 2nd\الحب من طرف واحد بين اليسار وأم أيمن.mp4 with title: MasryMolhed 2nd - الحب من طرف واحد بين اليسار وأم أيمن
# 23:59:34 - Upload successful! Video ID: Hql4zxODPCI
# 23:59:34 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\MasryMolhed 2nd\النظرية العلفية لتفسير سلوك خولات البنا وبهايم السلفية.mp4 with title: MasryMolhed 2nd - النظرية العلفية لتفسير سلوك خولات البنا وبهايم السلفية
# 00:00:23 - Upload successful! Video ID: vsDuAyboOjM
# 00:00:23 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\MasryMolhed 2nd\بدأ الحساب.mp4 with title: MasryMolhed 2nd - بدأ الحساب
# 00:00:39 - Upload successful! Video ID: K8D1kgJg9ic
# 00:00:39 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\MasryMolhed 2nd\بين ماخور القذافى وماخور موزة.mp4 with title: MasryMolhed 2nd - بين ماخور القذافى وماخور موزة
# 00:01:26 - Upload successful! Video ID: yCVtD0F5nfI
# 00:01:26 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\MasryMolhed 2nd\تحسبهم جميعا وقلوبهم شتى.mp4 with title: MasryMolhed 2nd - تحسبهم جميعا وقلوبهم شتى
# 00:02:05 - Upload successful! Video ID: aBfCspeVfvo
# 00:02:05 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\MasryMolhed 2nd\ثورة دى ولا إنقلاب.mp4 with title: MasryMolhed 2nd - ثورة دى ولا إنقلاب
# 00:02:38 - Upload successful! Video ID: UBE2IfoKvkE
# 00:02:38 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\MasryMolhed 2nd\جزيرة الشاويش عطية 2.mp4 with title: MasryMolhed 2nd - جزيرة الشاويش عطية 2
# 00:02:53 - Upload successful! Video ID: P7UPvLhxdcI
# 00:02:53 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\MasryMolhed 2nd\جزيرة الشاويش عطية 3.mp4 with title: MasryMolhed 2nd - جزيرة الشاويش عطية 3
# 00:03:08 - Upload successful! Video ID: urnfPig18_I
# 00:03:08 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\MasryMolhed 2nd\جزيرة الشاويش عطية.mp4 with title: MasryMolhed 2nd - جزيرة الشاويش عطية
# 00:03:24 - Upload successful! Video ID: CpwNo63wBC8
# 00:03:24 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\MasryMolhed 2nd\حرب الأغانى.mp4 with title: MasryMolhed 2nd - حرب الأغانى
# 00:04:18 - Upload successful! Video ID: BSJ0BugjluA
# 00:04:18 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\MasryMolhed 2nd\حول ترشح السيسي.mp4 with title: MasryMolhed 2nd - حول ترشح السيسي
# 00:05:09 - Upload successful! Video ID: 9YCDugemzYs
# 00:05:09 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\MasryMolhed 2nd\حول ثورة خولات البنا.mp4 with title: MasryMolhed 2nd - حول ثورة خولات البنا
# 00:05:46 - Upload successful! Video ID: Mnk2lfDvH4o
# 00:05:46 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\MasryMolhed 2nd\رابعة الحيوان.mp4 with title: MasryMolhed 2nd - رابعة الحيوان
# 00:06:33 - Upload successful! Video ID: 8mmLuKxj7Y4
# 00:06:33 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\MasryMolhed 2nd\رابعة العدوية تعود إلى عهرها القديم.mp4 with title: MasryMolhed 2nd - رابعة العدوية تعود إلى عهرها القديم
# 00:06:47 - Upload successful! Video ID: TWb9AC5O8eI
# 00:06:47 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\MasryMolhed 2nd\سم هويدى المغشوش.mp4 with title: MasryMolhed 2nd - سم هويدى المغشوش
# 00:06:58 - Upload successful! Video ID: Pcg3D8vp7w8
# 00:06:58 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\MasryMolhed 2nd\صندوق الشرور يبتلع شمامى الكلة.mp4 with title: MasryMolhed 2nd - صندوق الشرور يبتلع شمامى الكلة
# 00:07:33 - Upload successful! Video ID: yYbR0KQcpkk
# 00:07:33 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\MasryMolhed 2nd\عزاء واجب لخولات البنا.mp4 with title: MasryMolhed 2nd - عزاء واجب لخولات البنا
# 00:08:01 - Upload successful! Video ID: B3_AyOlQzQQ
# 00:08:01 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\MasryMolhed 2nd\فأجاب جميع الشعب وقالوا دمهم علينا وعلى أولادنا.mp4 with title: MasryMolhed 2nd - فأجاب جميع الشعب وقالوا دمهم علينا وعلى أولادنا
# 00:08:47 - Upload successful! Video ID: QhXctlnbzaM
# 00:08:47 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\MasryMolhed 2nd\فى البدء كانت الكلة.mp4 with title: MasryMolhed 2nd - فى البدء كانت الكلة
# 00:09:15 - Upload successful! Video ID: viBELjSDzuY
# 00:09:15 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\MasryMolhed 2nd\محمد مات خلف بنات.mp4 with title: MasryMolhed 2nd - محمد مات خلف بنات
# 00:09:27 - Upload successful! Video ID: elr46YgCtrc
# 00:09:27 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\MasryMolhed 2nd\مرسى الفكرة.mp4 with title: MasryMolhed 2nd - مرسى الفكرة
# 00:09:42 - Upload successful! Video ID: -RvJNUwCEIM
# 00:09:42 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\MasryMolhed 2nd\وداعا بديع.mp4 with title: MasryMolhed 2nd - وداعا بديع
# 00:09:59 - Upload successful! Video ID: ioLVM0mdoTk
# 00:09:59 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\MasryMolhed 2nd\وقفات مع الأزهر.mp4 with title: MasryMolhed 2nd - وقفات مع الأزهر
# 00:10:38 - Upload successful! Video ID: 4eyIOSNVeHs
# 00:10:38 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Masrymolhed 480p\روائع مولانا الجزء الاول‬ - YouTube.mp4 with title: Masrymolhed 480p - روائع مولانا الجزء الاول‬ - YouTube
# 00:20:56 - Encountered 403 Forbidden with reason "authenticatedUserAccountSuspended"
# 00:20:56 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Masrymolhed 480p\روائع مولانا الجزء الاول‬ - YouTube.mp4 to YouTube (attempt 1): <HttpError 403 when requesting https://youtube.googleapis.com/upload/youtube/v3/videos?part=snippet%2Cstatus&alt=json&uploadType=resumable returned "The YouTube account of the authenticated user is suspended. In case the authenticated user is acting on behalf of another Google account, then this error refers to the latter.". Details: "[{'message': 'The YouTube account of the authenticated user is suspended. In case the authenticated user is acting on behalf of another Google account, then this error refers to the latter.', 'domain': 'youtube.common', 'reason': 'authenticatedUserAccountSuspended'}]">
# 00:20:56 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Masrymolhed 480p\روائع مولانا الجزء الاول‬ - YouTube.mp4 in 3 minutes...
# 00:23:56 - Encountered 403 Forbidden with reason "authenticatedUserAccountSuspended"
# 00:23:56 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Masrymolhed 480p\روائع مولانا الجزء الاول‬ - YouTube.mp4 to YouTube (attempt 2): <HttpError 403 when requesting None returned "The YouTube account of the authenticated user is suspended. In case the authenticated user is acting on behalf of another Google account, then this error refers to the latter.". Details: "[{'message': 'The YouTube account of the authenticated user is suspended. In case the authenticated user is acting on behalf of another Google account, then this error refers to the latter.', 'domain': 'youtube.common', 'reason': 'authenticatedUserAccountSuspended'}]">
# 00:23:56 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Masrymolhed 480p\روائع مولانا الجزء الاول‬ - YouTube.mp4 in 3 minutes...
# 00:26:56 - Encountered 403 Forbidden with reason "authenticatedUserAccountSuspended"
# 00:26:56 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Masrymolhed 480p\روائع مولانا الجزء الاول‬ - YouTube.mp4 to YouTube (attempt 3): <HttpError 403 when requesting None returned "The YouTube account of the authenticated user is suspended. In case the authenticated user is acting on behalf of another Google account, then this error refers to the latter.". Details: "[{'message': 'The YouTube account of the authenticated user is suspended. In case the authenticated user is acting on behalf of another Google account, then this error refers to the latter.', 'domain': 'youtube.common', 'reason': 'authenticatedUserAccountSuspended'}]">
# 00:26:56 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Masrymolhed 480p\روائع مولانا الجزء الاول‬ - YouTube.mp4 after 3 attempts.
# 00:26:56 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Masrymolhed 480p\روائع مولانا الجزء الاول‬ - YouTube.mp4
# 00:26:56 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Masrymolhed 480p\روائع مولانا الجزء الثالث‬ - YouTube.mp4 with title: Masrymolhed 480p - روائع مولانا الجزء الثالث‬ - YouTube
# 00:26:56 - Encountered 403 Forbidden with reason "authenticatedUserAccountSuspended"
# 00:26:56 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Masrymolhed 480p\روائع مولانا الجزء الثالث‬ - YouTube.mp4 to YouTube (attempt 1): <HttpError 403 when requesting None returned "The YouTube account of the authenticated user is suspended. In case the authenticated user is acting on behalf of another Google account, then this error refers to the latter.". Details: "[{'message': 'The YouTube account of the authenticated user is suspended. In case the authenticated user is acting on behalf of another Google account, then this error refers to the latter.', 'domain': 'youtube.common', 'reason': 'authenticatedUserAccountSuspended'}]">
# 00:26:56 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Masrymolhed 480p\روائع مولانا الجزء الثالث‬ - YouTube.mp4 in 3 minutes...
# 00:29:57 - Encountered 403 Forbidden with reason "authenticatedUserAccountSuspended"
# 00:29:57 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Masrymolhed 480p\روائع مولانا الجزء الثالث‬ - YouTube.mp4 to YouTube (attempt 2): <HttpError 403 when requesting None returned "The YouTube account of the authenticated user is suspended. In case the authenticated user is acting on behalf of another Google account, then this error refers to the latter.". Details: "[{'message': 'The YouTube account of the authenticated user is suspended. In case the authenticated user is acting on behalf of another Google account, then this error refers to the latter.', 'domain': 'youtube.common', 'reason': 'authenticatedUserAccountSuspended'}]">
# 00:29:57 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Masrymolhed 480p\روائع مولانا الجزء الثالث‬ - YouTube.mp4 in 3 minutes...
# 00:32:57 - Encountered 403 Forbidden with reason "authenticatedUserAccountSuspended"
# 00:32:57 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Masrymolhed 480p\روائع مولانا الجزء الثالث‬ - YouTube.mp4 to YouTube (attempt 3): <HttpError 403 when requesting None returned "The YouTube account of the authenticated user is suspended. In case the authenticated user is acting on behalf of another Google account, then this error refers to the latter.". Details: "[{'message': 'The YouTube account of the authenticated user is suspended. In case the authenticated user is acting on behalf of another Google account, then this error refers to the latter.', 'domain': 'youtube.common', 'reason': 'authenticatedUserAccountSuspended'}]">
# 00:32:57 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Masrymolhed 480p\روائع مولانا الجزء الثالث‬ - YouTube.mp4 after 3 attempts.
# 00:32:57 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Masrymolhed 480p\روائع مولانا الجزء الثالث‬ - YouTube.mp4
# 00:32:57 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Masrymolhed 480p\روائع مولانا الجزء الثاني‬ - YouTube.mp4 with title: Masrymolhed 480p - روائع مولانا الجزء الثاني‬ - YouTube
# 00:32:57 - Encountered 403 Forbidden with reason "authenticatedUserAccountSuspended"
# 00:32:57 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Masrymolhed 480p\روائع مولانا الجزء الثاني‬ - YouTube.mp4 to YouTube (attempt 1): <HttpError 403 when requesting None returned "The YouTube account of the authenticated user is suspended. In case the authenticated user is acting on behalf of another Google account, then this error refers to the latter.". Details: "[{'message': 'The YouTube account of the authenticated user is suspended. In case the authenticated user is acting on behalf of another Google account, then this error refers to the latter.', 'domain': 'youtube.common', 'reason': 'authenticatedUserAccountSuspended'}]">
# 00:32:57 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Masrymolhed 480p\روائع مولانا الجزء الثاني‬ - YouTube.mp4 in 3 minutes...
# 00:35:57 - Encountered 403 Forbidden with reason "authenticatedUserAccountSuspended"
# 00:35:57 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Masrymolhed 480p\روائع مولانا الجزء الثاني‬ - YouTube.mp4 to YouTube (attempt 2): <HttpError 403 when requesting None returned "The YouTube account of the authenticated user is suspended. In case the authenticated user is acting on behalf of another Google account, then this error refers to the latter.". Details: "[{'message': 'The YouTube account of the authenticated user is suspended. In case the authenticated user is acting on behalf of another Google account, then this error refers to the latter.', 'domain': 'youtube.common', 'reason': 'authenticatedUserAccountSuspended'}]">
# 00:35:57 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Masrymolhed 480p\روائع مولانا الجزء الثاني‬ - YouTube.mp4 in 3 minutes...
# 00:38:58 - Encountered 403 Forbidden with reason "authenticatedUserAccountSuspended"
# 00:38:58 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Masrymolhed 480p\روائع مولانا الجزء الثاني‬ - YouTube.mp4 to YouTube (attempt 3): <HttpError 403 when requesting None returned "The YouTube account of the authenticated user is suspended. In case the authenticated user is acting on behalf of another Google account, then this error refers to the latter.". Details: "[{'message': 'The YouTube account of the authenticated user is suspended. In case the authenticated user is acting on behalf of another Google account, then this error refers to the latter.', 'domain': 'youtube.common', 'reason': 'authenticatedUserAccountSuspended'}]">
# 00:38:58 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Masrymolhed 480p\روائع مولانا الجزء الثاني‬ - YouTube.mp4 after 3 attempts.
# 00:38:58 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Masrymolhed 480p\روائع مولانا الجزء الثاني‬ - YouTube.mp4
# 00:38:58 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Masrymolhed 480p\روائع مولانا الجزء الرابع‬ - YouTube.mp4 with title: Masrymolhed 480p - روائع مولانا الجزء الرابع‬ - YouTube
# 00:38:58 - Encountered 403 Forbidden with reason "quotaExceeded"
# 00:38:58 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Masrymolhed 480p\روائع مولانا الجزء الرابع‬ - YouTube.mp4 to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 00:38:58 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Masrymolhed 480p\روائع مولانا الجزء الرابع‬ - YouTube.mp4 in 3 minutes...
# 00:41:59 - Encountered 403 Forbidden with reason "quotaExceeded"
# 00:41:59 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Masrymolhed 480p\روائع مولانا الجزء الرابع‬ - YouTube.mp4 to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 00:41:59 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Masrymolhed 480p\روائع مولانا الجزء الرابع‬ - YouTube.mp4 in 3 minutes...
# 00:44:59 - Encountered 403 Forbidden with reason "quotaExceeded"
# 00:44:59 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Masrymolhed 480p\روائع مولانا الجزء الرابع‬ - YouTube.mp4 to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 00:44:59 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Masrymolhed 480p\روائع مولانا الجزء الرابع‬ - YouTube.mp4 after 3 attempts.
# 00:44:59 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Masrymolhed 480p\روائع مولانا الجزء الرابع‬ - YouTube.mp4
# 00:44:59 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\mawlanaomar\انت تسأل ورسول الله يجيب - مولانا عمر.mp4 with title: mawlanaomar - انت تسأل ورسول الله يجيب - مولانا عمر
# 00:44:59 - Encountered 403 Forbidden with reason "quotaExceeded"
# 00:44:59 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\mawlanaomar\انت تسأل ورسول الله يجيب - مولانا عمر.mp4 to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 00:44:59 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\mawlanaomar\انت تسأل ورسول الله يجيب - مولانا عمر.mp4 in 3 minutes...
# 00:47:59 - Encountered 403 Forbidden with reason "quotaExceeded"
# 00:48:00 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\mawlanaomar\انت تسأل ورسول الله يجيب - مولانا عمر.mp4 to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 00:48:00 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\mawlanaomar\انت تسأل ورسول الله يجيب - مولانا عمر.mp4 in 3 minutes...
# 00:51:00 - Encountered 403 Forbidden with reason "quotaExceeded"
# 00:51:00 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\mawlanaomar\انت تسأل ورسول الله يجيب - مولانا عمر.mp4 to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 00:51:00 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\mawlanaomar\انت تسأل ورسول الله يجيب - مولانا عمر.mp4 after 3 attempts.
# 00:51:00 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\mawlanaomar\انت تسأل ورسول الله يجيب - مولانا عمر.mp4
# 00:51:00 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\mawlanaomar\جنة الفردوس - مولانا عمر.mp4 with title: mawlanaomar - جنة الفردوس - مولانا عمر
# 00:51:00 - Encountered 403 Forbidden with reason "quotaExceeded"
# 00:51:00 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\mawlanaomar\جنة الفردوس - مولانا عمر.mp4 to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 00:51:00 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\mawlanaomar\جنة الفردوس - مولانا عمر.mp4 in 3 minutes...
# 00:54:00 - Encountered 403 Forbidden with reason "quotaExceeded"
# 00:54:00 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\mawlanaomar\جنة الفردوس - مولانا عمر.mp4 to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 00:54:00 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\mawlanaomar\جنة الفردوس - مولانا عمر.mp4 in 3 minutes...
# 00:57:00 - Encountered 403 Forbidden with reason "quotaExceeded"
# 00:57:00 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\mawlanaomar\جنة الفردوس - مولانا عمر.mp4 to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 00:57:00 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\mawlanaomar\جنة الفردوس - مولانا عمر.mp4 after 3 attempts.
# 00:57:00 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\mawlanaomar\جنة الفردوس - مولانا عمر.mp4
# 00:57:00 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\mawlanaomar\حديث الاسراء والمعراج - مولانا عمر.mp4 with title: mawlanaomar - حديث الاسراء والمعراج - مولانا عمر
# 00:57:00 - Encountered 403 Forbidden with reason "quotaExceeded"
# 00:57:00 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\mawlanaomar\حديث الاسراء والمعراج - مولانا عمر.mp4 to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 00:57:00 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\mawlanaomar\حديث الاسراء والمعراج - مولانا عمر.mp4 in 3 minutes...
# 01:00:00 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:00:00 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\mawlanaomar\حديث الاسراء والمعراج - مولانا عمر.mp4 to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:00:00 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\mawlanaomar\حديث الاسراء والمعراج - مولانا عمر.mp4 in 3 minutes...
# 01:03:00 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:03:00 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\mawlanaomar\حديث الاسراء والمعراج - مولانا عمر.mp4 to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:03:00 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\mawlanaomar\حديث الاسراء والمعراج - مولانا عمر.mp4 after 3 attempts.
# 01:03:00 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\mawlanaomar\حديث الاسراء والمعراج - مولانا عمر.mp4
# 01:03:00 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\mawlanaomar\حديث الجزمة البلاستيك - مولانا عمر.mp4 with title: mawlanaomar - حديث الجزمة البلاستيك - مولانا عمر
# ...
# 06:33:25 - Encountered 403 Forbidden with reason "quotaExceeded"
# 06:33:25 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\إعلان إعادة أنتاج مسلسل الكون (2014) [مترجم] - نايل ديغارسي تايسون - قناة فوكس.mp4 to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 06:33:25 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\إعلان إعادة أنتاج مسلسل الكون (2014) [مترجم] - نايل ديغارسي تايسون - قناة فوكس.mp4 after 3 attempts.
# 06:33:25 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\إعلان إعادة أنتاج مسلسل الكون (2014) [مترجم] - نايل ديغارسي تايسون - قناة فوكس.mp4
# 06:33:25 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\الايدولوجية والمعتقدات، اللعبة المستحيلة.mp4 with title: Targama Daniel - الايدولوجية والمعتقدات، اللعبة المستحيلة
# 06:33:26 - Encountered 403 Forbidden with reason "quotaExceeded"
# 06:33:26 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\الايدولوجية والمعتقدات، اللعبة المستحيلة.mp4 to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 06:33:26 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\الايدولوجية والمعتقدات، اللعبة المستحيلة.mp4 in 3 minutes...
# 06:36:26 - Encountered 403 Forbidden with reason "quotaExceeded"
# 06:36:26 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\الايدولوجية والمعتقدات، اللعبة المستحيلة.mp4 to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 06:36:26 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\الايدولوجية والمعتقدات، اللعبة المستحيلة.mp4 in 3 minutes...
# 06:39:26 - Encountered 403 Forbidden with reason "quotaExceeded"
# 06:39:26 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\الايدولوجية والمعتقدات، اللعبة المستحيلة.mp4 to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 06:39:26 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\الايدولوجية والمعتقدات، اللعبة المستحيلة.mp4 after 3 attempts.
# 06:39:26 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\الايدولوجية والمعتقدات، اللعبة المستحيلة.mp4
# 06:39:26 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\التطور في 5 دقائق.mp4 with title: Targama Daniel - التطور في 5 دقائق
# 06:39:26 - Encountered 403 Forbidden with reason "quotaExceeded"
# 06:39:26 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\التطور في 5 دقائق.mp4 to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 06:39:26 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\التطور في 5 دقائق.mp4 in 3 minutes...
# 06:42:26 - Encountered 403 Forbidden with reason "quotaExceeded"
# 06:42:26 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\التطور في 5 دقائق.mp4 to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 06:42:26 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\التطور في 5 دقائق.mp4 in 3 minutes...
# 06:45:26 - Encountered 403 Forbidden with reason "quotaExceeded"
# 06:45:26 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\التطور في 5 دقائق.mp4 to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 06:45:26 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\التطور في 5 دقائق.mp4 after 3 attempts.
# 06:45:26 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\التطور في 5 دقائق.mp4
# 06:45:26 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\العلم أجرني من ظلمات الجهل.mp4 with title: Targama Daniel - العلم أجرني من ظلمات الجهل
# 06:45:27 - Encountered 403 Forbidden with reason "quotaExceeded"
# 06:45:27 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\العلم أجرني من ظلمات الجهل.mp4 to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 06:45:27 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\العلم أجرني من ظلمات الجهل.mp4 in 3 minutes...
# 06:48:27 - Encountered 403 Forbidden with reason "quotaExceeded"
# 06:48:27 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\العلم أجرني من ظلمات الجهل.mp4 to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 06:48:27 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\العلم أجرني من ظلمات الجهل.mp4 in 3 minutes...
# 06:51:27 - Encountered 403 Forbidden with reason "quotaExceeded"
# 06:51:27 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\العلم أجرني من ظلمات الجهل.mp4 to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 06:51:27 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\العلم أجرني من ظلمات الجهل.mp4 after 3 attempts.
# 06:51:27 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\العلم أجرني من ظلمات الجهل.mp4
# 06:51:27 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\الفيلم القصير  المتجولون في الفضاء [مترجم].mp4 with title: Targama Daniel - الفيلم القصير  المتجولون في الفضاء [مترجم]
# 06:51:27 - Encountered 403 Forbidden with reason "quotaExceeded"
# 06:51:27 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\الفيلم القصير  المتجولون في الفضاء [مترجم].mp4 to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 06:51:27 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\الفيلم القصير  المتجولون في الفضاء [مترجم].mp4 in 3 minutes...
# 06:54:27 - Encountered 403 Forbidden with reason "quotaExceeded"
# 06:54:27 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\الفيلم القصير  المتجولون في الفضاء [مترجم].mp4 to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 06:54:27 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\الفيلم القصير  المتجولون في الفضاء [مترجم].mp4 in 3 minutes...
# 06:57:27 - Encountered 403 Forbidden with reason "quotaExceeded"
# 06:57:27 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\الفيلم القصير  المتجولون في الفضاء [مترجم].mp4 to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 06:57:27 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\الفيلم القصير  المتجولون في الفضاء [مترجم].mp4 after 3 attempts.
# 06:57:27 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\الفيلم القصير  المتجولون في الفضاء [مترجم].mp4
# 06:57:27 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\الفيلم القصير  الهائمون (كارل ساجان) [مترجم].mp4 with title: Targama Daniel - الفيلم القصير  الهائمون (كارل ساجان) [مترجم]
# 06:57:27 - Encountered 403 Forbidden with reason "quotaExceeded"
# 06:57:27 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\الفيلم القصير  الهائمون (كارل ساجان) [مترجم].mp4 to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 06:57:27 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\الفيلم القصير  الهائمون (كارل ساجان) [مترجم].mp4 in 3 minutes...
# 07:00:27 - Encountered 403 Forbidden with reason "quotaExceeded"
# 07:00:27 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\الفيلم القصير  الهائمون (كارل ساجان) [مترجم].mp4 to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 07:00:27 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism\Arabs\Youtubers\Targama Daniel\الفيلم القصير  الهائمون (كارل ساجان) [مترجم].mp4 in 3 minutes...
