# %%
import os
import sys
import glob
import logging
from datetime import datetime
from pathlib import Path
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import tkinter as tk
from tkinter import filedialog
from google_auth_oauthlib.flow import InstalledAppFlow
from google.oauth2.credentials import Credentials
from google.auth.transport.requests import Request
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload
import time

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(message)s',
    datefmt='%H:%M:%S',
    handlers=[
        logging.FileHandler('upload_all.log', encoding='utf-8'),
        logging.StreamHandler()
    ]
)

TOKEN_FILE = "token.json"
SCOPES = ["https://www.googleapis.com/auth/youtube.upload"]

os.environ['OAUTHLIB_INSECURE_TRANSPORT'] = '1'
os.environ['PYTHONHTTPSVERIFY'] = '0'

def get_authenticated_service(client_secrets_file: str):
    creds = None
    if os.path.exists(TOKEN_FILE):
        creds = Credentials.from_authorized_user_file(TOKEN_FILE, SCOPES)
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(client_secrets_file, SCOPES)
            creds = flow.run_local_server(port=0)
        with open(TOKEN_FILE, 'w') as token:
            token.write(creds.to_json())
    return build('youtube', 'v3', credentials=creds)

def upload_to_youtube(youtube, video_path: str, title: str, description: str = "Uploaded by script"):
    MAX_RETRIES = 3
    RETRY_DELAY_SECONDS = 180  # 3 minutes
    for attempt in range(1, MAX_RETRIES + 1):
        try:
            body = {
                'snippet': {
                    'title': title,
                    'description': description,
                    'tags': ['tutorial', 'education']
                },
                'status': {
                    'privacyStatus': 'unlisted',
                    'selfDeclaredMadeForKids': False
                }
            }
            insert_request = youtube.videos().insert(
                part=','.join(body.keys()),
                body=body,
                media_body=MediaFileUpload(video_path, chunksize=-1, resumable=True)
            )
            response = None
            while response is None:
                status, response = insert_request.next_chunk()
                if status:
                    logging.info(f"Upload {int(status.progress() * 100)}% complete for {video_path}")
            return response['id']
        except Exception as e:
            logging.error(f"Error uploading {video_path} to YouTube (attempt {attempt}): {str(e)}")
            if attempt < MAX_RETRIES:
                logging.info(f"Retrying upload for {video_path} in {RETRY_DELAY_SECONDS // 60} minutes...")
                time.sleep(RETRY_DELAY_SECONDS)
            else:
                logging.error(f"Upload failed for {video_path} after {MAX_RETRIES} attempts.")
                return None

def select_folder_dialog(title="Select folder"):
    """Open a folder selection dialog and return the selected path."""
    try:
        root = tk.Tk()
        root.withdraw()
        root.update_idletasks()
        width = root.winfo_screenwidth()
        height = root.winfo_screenheight()
        x = (width - 400) // 2
        y = (height - 300) // 2
        root.geometry(f'400x300+{x}+{y}')
        folder_path = filedialog.askdirectory(
            title=title,
            mustexist=True
        )
        root.destroy()
        return folder_path
    except Exception as e:
        logging.error(f"Error in folder selection: {str(e)}")
        return None

def main():
    # Select parent folder
    parent_folder = select_folder_dialog(title="Select parent folder containing videos to upload recursively")
    if not parent_folder or not os.path.exists(parent_folder):
        logging.error("No folder selected or folder does not exist")
        return
    cwd = os.getcwd()
    client_secrets_file = os.path.join(cwd, "client_secret.dlc.json")
    if not os.path.exists(client_secrets_file):
        logging.error(f"Client secrets file not found at: {client_secrets_file}")
        return
    youtube = get_authenticated_service(client_secrets_file)
    logging.info("YouTube authentication complete.")
    VIDEO_EXTENSIONS = ('.mp4', '.mkv', '.avi', '.mov', '.wmv', '.flv', '.webm')
    for root, _, files in os.walk(parent_folder):
        for file in files:
            if file.lower().endswith(VIDEO_EXTENSIONS) and not file.endswith('.txt'):
                video_path = os.path.join(root, file)
                video_name = os.path.splitext(file)[0]
                link_file = os.path.join(root, f"{video_name}.txt")
                if not os.path.exists(link_file):
                    folder_name = os.path.basename(root)
                    MAX_TITLE_LENGTH = 100
                    title = f"{folder_name} - {video_name}"
                    if len(title) > MAX_TITLE_LENGTH:
                        title = title[:MAX_TITLE_LENGTH]
                    logging.info(f"Uploading: {video_path} with title: {title}")
                    video_id = upload_to_youtube(youtube, video_path, title)
                    if video_id:
                        with open(link_file, 'w') as f:
                            f.write(f"https://www.youtube.com/watch?v={video_id}\n")
                        try:
                            os.remove(video_path)
                        except Exception as e:
                            logging.error(f"Failed to delete uploaded video file: {video_path}: {str(e)}")
                        logging.info(f"Upload successful! Video ID: {video_id}")
                    else:
                        logging.error(f"Upload failed for {video_path}")
                else:
                    logging.info(f"Link file already exists for {video_path}. Skipping upload.")
    logging.info("All specified folders and subfolders processed.")

if __name__ == "__main__":
    main()
# Out:
# 08:45:50 - file_cache is only supported with oauth2client<4.0.0
# 08:45:50 - YouTube authentication complete.
# 08:45:51 - Link file already exists for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin\The.Genius.of.Charles.Darwin.1of3.Life.Darwin.and.Everything.XviD.AC3.MVGroup.org.avi. Skipping upload.
# 08:45:51 - Link file already exists for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin\The.Genius.of.Charles.Darwin.2of3.The.Fifth.Ape.XviD.AC3.MVGroup.org.avi. Skipping upload.
# 08:45:51 - Link file already exists for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin\The.Genius.of.Charles.Darwin.3of3.God.Strikes.Back.XviD.AC3.MVGroup.org.avi. Skipping upload.
# 08:45:51 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\03-Philosophers (1700-2000)\Immanuel Kant\Oxford Lectures\02 - The broader philosophical context.mp4 with title: Oxford Lectures - 02 - The broader philosophical context
# 08:47:37 - Upload successful! Video ID: 4UHaAUjP-7U
# 08:47:37 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\03-Philosophers (1700-2000)\Immanuel Kant\Oxford Lectures\03 - Space, time and the Analogies of Experiences.mp4 with title: Oxford Lectures - 03 - Space, time and the Analogies of Experiences
# 08:49:32 - Upload successful! Video ID: ULTxNkqkfK8
# 08:49:32 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\03-Philosophers (1700-2000)\Immanuel Kant\Oxford Lectures\04 - How are a priori synthetic judgements possible.mp4 with title: Oxford Lectures - 04 - How are a priori synthetic judgements possible
# 08:51:08 - Upload successful! Video ID: o9Dif5xF4Ck
# 08:51:08 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\03-Philosophers (1700-2000)\Immanuel Kant\Oxford Lectures\05 - Idealisms and their refutations.mp4 with title: Oxford Lectures - 05 - Idealisms and their refutations
# 08:52:50 - Upload successful! Video ID: y40PAAOTf2A
# 08:52:50 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\03-Philosophers (1700-2000)\Immanuel Kant\Oxford Lectures\06 - Concepts, judgement and the Transcendental Deduction of the Categories.mp4 with title: Oxford Lectures - 06 - Concepts, judgement and the Transcendental Deduction of the Categories
# 08:54:27 - Upload successful! Video ID: NAnrkwWrU_I
# 08:54:27 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\03-Philosophers (1700-2000)\Immanuel Kant\Oxford Lectures\07 - The Self and the Synthetic Unity of Apperception.mp4 with title: Oxford Lectures - 07 - The Self and the Synthetic Unity of Apperception
# 08:55:59 - Upload successful! Video ID: zCUYGZCugI4
# 08:55:59 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\03-Philosophers (1700-2000)\Immanuel Kant\Oxford Lectures\08 - The discipline of reason The paralogisms and Antinomies of Pure Reason..mp4 with title: Oxford Lectures - 08 - The discipline of reason The paralogisms and Antinomies of Pure Reason.
# 08:57:32 - Upload successful! Video ID: lwuBqzs1eA8
# 08:57:32 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\04-Philosophers (2000-2015)\Colin McGinn\Colin McGinn - Mysterianism and the Mind of God - YouTube_2.mp4 with title: Colin McGinn - Colin McGinn - Mysterianism and the Mind of God - YouTube_2
# 09:00:05 - Upload successful! Video ID: KZuNn64Z-pQ
# 09:00:05 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\04-Philosophers (2000-2015)\Colin McGinn\The science of philosophy- talk by Professor Colin McGinn - YouTube_2.mp4 with title: Colin McGinn - The science of philosophy- talk by Professor Colin McGinn - YouTube_2
# 09:02:33 - Upload successful! Video ID: qrtXo8WIjDM
# 09:02:33 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\aristotle to hawking\YouTube - Part 1-1 تاريخ الفلسفة من ارسطو حتى هوكينج.flv with title: aristotle to hawking - YouTube - Part 1-1 تاريخ الفلسفة من ارسطو حتى هوكينج
# 09:02:48 - Upload successful! Video ID: -kLSqmfI4SI
# 09:02:48 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\aristotle to hawking\YouTube - Part 1-2 تاريخ الفلسفة من ارسطو حتى هوكينج.flv with title: aristotle to hawking - YouTube - Part 1-2 تاريخ الفلسفة من ارسطو حتى هوكينج
# 09:03:01 - Upload successful! Video ID: 10MgX36wz68
# 09:03:01 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\aristotle to hawking\YouTube - Part 1-3 تاريخ الفلسفة من ارسطو حتى هوكينج.flv with title: aristotle to hawking - YouTube - Part 1-3 تاريخ الفلسفة من ارسطو حتى هوكينج
# 09:03:12 - Upload successful! Video ID: 8gxtz-gDtv0
# 09:03:12 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\aristotle to hawking\YouTube - Part 4-1 تاريخ الفلسفة من ارسطو حتى هوكينج.flv with title: aristotle to hawking - YouTube - Part 4-1 تاريخ الفلسفة من ارسطو حتى هوكينج
# 09:03:26 - Upload successful! Video ID: 4qZCtsXx2IE
# 09:03:26 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\aristotle to hawking\YouTube - Part 5-1 تاريخ الفلسفة من ارسطو حتى هوكينج.flv with title: aristotle to hawking - YouTube - Part 5-1 تاريخ الفلسفة من ارسطو حتى هوكينج
# 09:03:39 - Upload successful! Video ID: zMmTpWwACcM
# 09:03:39 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\aristotle to hawking\YouTube - Part 6-1 تاريخ الفلسفة من ارسطو حتى هوكينج.flv with title: aristotle to hawking - YouTube - Part 6-1 تاريخ الفلسفة من ارسطو حتى هوكينج
# 09:03:52 - Upload successful! Video ID: aFtHq_sYZ8w
# 09:03:52 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\aristotle to hawking\YouTube - Part 6-2 تاريخ الفلسفة من ارسطو حتى هوكينج.flv with title: aristotle to hawking - YouTube - Part 6-2 تاريخ الفلسفة من ارسطو حتى هوكينج
# 09:04:06 - Upload successful! Video ID: pCc0rCQ_l5g
# 09:04:06 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\aristotle to hawking\YouTube - Part 6-3 تاريخ الفلسفة من ارسطو حتى هوكينج.flv with title: aristotle to hawking - YouTube - Part 6-3 تاريخ الفلسفة من ارسطو حتى هوكينج
# 09:04:22 - Upload successful! Video ID: _g69Ny-FLLA
# 09:04:22 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\aristotle to hawking\YouTube - تاريخ الفلسفة من ارسطو حتى هوكينج - مقدمة وتعريف.flv with title: aristotle to hawking - YouTube - تاريخ الفلسفة من ارسطو حتى هوكينج - مقدمة وتعريف
# 09:04:29 - Upload successful! Video ID: zq8J-_Ue-qY
# 09:04:29 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\Free Will\Consciousness and the limits of Science - Boundaries of the Knowable (1 10).mkv with title: Free Will - Consciousness and the limits of Science - Boundaries of the Knowable (1 10)
# 09:04:53 - Upload successful! Video ID: qKBMg1MxpOs
# 09:04:53 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\Free Will\Cosmology - Boundaries of the Knowable (3 10).mkv with title: Free Will - Cosmology - Boundaries of the Knowable (3 10)
# 09:05:10 - Upload successful! Video ID: NBM0HNQsVdI
# 09:05:10 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\Free Will\ET, Life and the Universe - Boundaries of the Knowable (4 10).mkv with title: Free Will - ET, Life and the Universe - Boundaries of the Knowable (4 10)
# 09:05:32 - Upload successful! Video ID: MidMr83iXPE
# 09:05:32 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\Free Will\Free will and determinism - Boundaries of the Knowable (2 10).mkv with title: Free Will - Free will and determinism - Boundaries of the Knowable (2 10)
# 09:05:48 - Upload successful! Video ID: f9EMt7sbKGU
# 09:05:48 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\Free Will\Superstrings - Boundaries of the Knowable (10 10).mkv with title: Free Will - Superstrings - Boundaries of the Knowable (10 10)
# 09:06:14 - Upload successful! Video ID: Eo4_9gN10hM
# 09:06:14 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\Free Will\The nature of matter - Boundaries of the Knowable (8 10).mkv with title: Free Will - The nature of matter - Boundaries of the Knowable (8 10)
# 09:06:40 - Upload successful! Video ID: xC7zZ2GmCGM
# 09:06:40 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\Free Will\The nature of Space - Boundaries of the Knowable (6 10).mkv with title: Free Will - The nature of Space - Boundaries of the Knowable (6 10)
# 09:06:58 - Upload successful! Video ID: w7yyEfYwXyQ
# 09:06:58 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\Free Will\The nature of time - Boundaries of the Knowable (7 10).mkv with title: Free Will - The nature of time - Boundaries of the Knowable (7 10)
# 09:07:25 - Upload successful! Video ID: -864fzuTxxc
# 09:07:25 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\Free Will\The size of Universe - Boundaries of the Knowable (5 10).mkv with title: Free Will - The size of Universe - Boundaries of the Knowable (5 10)
# 09:07:44 - Upload successful! Video ID: PFGXlUIXxmg
# 09:07:44 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Philosophy And Epistemology\Free Will\The wave particle paradox - Boundaries of the Knowable (9 10).mkv with title: Free Will - The wave particle paradox - Boundaries of the Knowable (9 10)
# 09:08:00 - Upload successful! Video ID: TpCG-99bH_8
# 09:08:00 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\Authors\Carl Sagan\Life Beyond Earth and the Mind of Man - 1975.mp4 with title: Carl Sagan - Life Beyond Earth and the Mind of Man - 1975
# 09:08:55 - Upload successful! Video ID: q5k3ksHPvpU
# 09:08:55 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\Authors\Lawrence Krauss\A Universe From Nothing' by Lawrence Krauss, AAI 2009 (720p).mp4 with title: Lawrence Krauss - A Universe From Nothing' by Lawrence Krauss, AAI 2009 (720p)
# 09:12:20 - Upload successful! Video ID: BEXvBqXcbKE
# 09:12:20 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\Authors\Lawrence Krauss\Lawrence Krauss - A Journey to the Beginning of Time - December 6, 2014 - YouTube.mp4 with title: Lawrence Krauss - Lawrence Krauss - A Journey to the Beginning of Time - December 6, 2014 - YouTube
# 09:14:04 - Upload successful! Video ID: paWmCQcSsHE
# 09:14:04 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\Authors\Lawrence Krauss\Lawrence Krauss - Q&A - December 9, 2014 - YouTube.mp4 with title: Lawrence Krauss - Lawrence Krauss - Q&A - December 9, 2014 - YouTube
# 09:15:01 - Upload successful! Video ID: fLOMzZE-cqs
# 09:15:01 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\Authors\Lawrence Krauss\Lawrence Krauss -Tribute To Christopher Hitchens- (MUST WATCH!!) - YouTube.mp4 with title: Lawrence Krauss - Lawrence Krauss -Tribute To Christopher Hitchens- (MUST WATCH!!) - YouTube
# 09:15:16 - Upload successful! Video ID: zq2Leb6gHV8
# 09:15:16 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\Authors\Lawrence Krauss\NonCon 2015 - Lawrence Krauss Keynote Address - YouTube.MP4 with title: Lawrence Krauss - NonCon 2015 - Lawrence Krauss Keynote Address - YouTube
# 09:16:15 - Upload successful! Video ID: zX0SqTGPsuA
# 09:16:15 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\Authors\Lawrence Krauss\Videos\Lawrence Krauss - A Universe from Nothing- Why There Is Something Rather Than Nothing - YouTube_2.flv with title: Videos - Lawrence Krauss - A Universe from Nothing- Why There Is Something Rather Than Nothing - You
# 09:17:40 - Upload successful! Video ID: XM-Lc1CLgeM
# 09:17:40 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\Authors\Lawrence Krauss\Videos\Lawrence Krauss on Q&A - Science vs Religion - 18 Feb 2013 - YouTube.flv with title: Videos - Lawrence Krauss on Q&A - Science vs Religion - 18 Feb 2013 - YouTube
# 09:18:33 - Upload successful! Video ID: vhpLFvIomAE
# 09:18:33 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\Authors\Lawrence Krauss\Videos\Nobel Conference Discussion Lawrence Krauss Nobel - YouTube.mp4 with title: Videos - Nobel Conference Discussion Lawrence Krauss Nobel - YouTube
# 09:20:53 - Upload successful! Video ID: wAVglyWze7g
# 09:20:53 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\Authors\Lawrence Krauss\Videos\The Big Debates- Islam or Atheism - Which Makes More Sense- Lawrence Krauss & Hamza Tzortzis.mp4 with title: Videos - The Big Debates- Islam or Atheism - Which Makes More Sense- Lawrence Krauss & Hamza Tzortzi
# 09:23:18 - Upload successful! Video ID: Oj0YFqijMbg
# 09:23:18 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\Authors\Neil deGrasse Tyson\Cosmic Quandaries with Dr. Neil deGrasse Tyson‬‏.flv with title: Neil deGrasse Tyson - Cosmic Quandaries with Dr. Neil deGrasse Tyson‬‏
# 09:24:21 - Upload successful! Video ID: EblFrx5lHE0
# 09:24:21 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\Authors\Neil deGrasse Tyson\Neil deGrasse Tyson  Lecture at UW  May, 2014.mp4 with title: Neil deGrasse Tyson - Neil deGrasse Tyson  Lecture at UW  May, 2014
# 09:26:32 - Upload successful! Video ID: SuukYgEieA8
# 09:26:32 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\Authors\Neil deGrasse Tyson\Vid\A Conversation with Dr. Neil deGrasse Tyson - SXSW Interactive 2014 (Full Session) - YouTube.mp4 with title: Vid - A Conversation with Dr. Neil deGrasse Tyson - SXSW Interactive 2014 (Full Session) - YouTube
# 09:27:58 - Upload successful! Video ID: gBA3Lw-nXns
# 09:27:58 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\Authors\Neil deGrasse Tyson\Vid\Cosmic Quandaries With Dr. Neil deGrasse Tyson.flv with title: Vid - Cosmic Quandaries With Dr. Neil deGrasse Tyson
# 09:29:01 - Upload successful! Video ID: B6WtpfxPxck
# 09:29:01 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\Authors\Neil deGrasse Tyson\Vid\Cosmos Panel QA Featuring Seth MacFarlane, Neil Degrasse Tyson, Ann Druyan - DevoutNone - YouTube.mp4 with title: Vid - Cosmos Panel QA Featuring Seth MacFarlane, Neil Degrasse Tyson, Ann Druyan - DevoutNone - YouT
# 09:30:06 - Upload successful! Video ID: Eiu-MmqxS-o
# 09:30:06 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\Authors\Neil deGrasse Tyson\Vid\Neil deGrasse Tyson University of Washington 2011 - YouTube.mp4 with title: Vid - Neil deGrasse Tyson University of Washington 2011 - YouTube
# 09:32:21 - Upload successful! Video ID: _5DGe_khk20
# 09:32:21 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\Authors\Neil deGrasse Tyson\Vid\Neil Degrasse Tyson- -If you_re scientifically literate the world looks very different to you-.flv with title: Vid - Neil Degrasse Tyson- -If you_re scientifically literate the world looks very different to you-
# 09:32:26 - Upload successful! Video ID: GzzA8ya_U9k
# 09:32:26 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\Authors\Neil deGrasse Tyson\Vid\Neil deGrasse Tyson-creationism.flv with title: Vid - Neil deGrasse Tyson-creationism
# 09:32:33 - Upload successful! Video ID: NyIT66KKGgI
# 09:32:33 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\Authors\Neil deGrasse Tyson\Vid\Stephen Colbert Interviews Neil deGrasse Tyson at Montclair Kimberley Academy - January 29th 2010 - YouTube.flv with title: Vid - Stephen Colbert Interviews Neil deGrasse Tyson at Montclair Kimberley Academy - January 29th 2
# 09:34:09 - Upload successful! Video ID: pXr6uwweZNU
# 09:34:09 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\Authors\Neil deGrasse Tyson\Vid\The Moon_ the Tides and why Neil DeGrasse Tyson is Colbert_s God - YouTube.flv with title: Vid - The Moon_ the Tides and why Neil DeGrasse Tyson is Colbert_s God - YouTube
# 09:35:27 - Upload successful! Video ID: Q4DcfPxYkRk
# 09:35:27 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\Particle Physics\Lectures\Higgs Boson and the Fundamental Nature of Reality - Sean Carroll - Skepticon 5.mp4 with title: Lectures - Higgs Boson and the Fundamental Nature of Reality - Sean Carroll - Skepticon 5
# 09:37:54 - Upload successful! Video ID: k_622SmPx8w
# 09:37:54 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Modern physics for non-scientists - Richard Wolfson - 01 - Time travel - Tunneling - Tennis.avi with title: TTC - TTC - Modern physics for non-scientists - Richard Wolfson - 01 - Time travel - Tunneling - Ten
# 09:38:55 - Upload successful! Video ID: OZOi_X0KIDo
# 09:38:55 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Modern physics for non-scientists - Richard Wolfson - 08 - Uncommon sense - Stretching time.avi with title: TTC - TTC - Modern physics for non-scientists - Richard Wolfson - 08 - Uncommon sense - Stretching t
# 09:40:01 - Upload successful! Video ID: 5_L4fcZz0iU
# 09:40:01 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Physics In Your Life - 16. Making Electricity.avi with title: TTC - TTC - Physics In Your Life - 16. Making Electricity
# 09:40:55 - Upload successful! Video ID: 3PSXkygwaG4
# 09:40:55 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Physics In Your Life - 20 The 20Th Century's Greatest Invention.avi with title: TTC - TTC - Physics In Your Life - 20 The 20Th Century's Greatest Invention
# 09:41:50 - Upload successful! Video ID: PLMXPIrhfdQ
# 09:41:50 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\Mechanical Universe\Mechanical_Universe_01 Introduction.wmv with title: Mechanical Universe - Mechanical_Universe_01 Introduction
# 09:42:32 - Upload successful! Video ID: xrLn8_r8sRg
# 09:42:32 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\Mechanical Universe\Mechanical_Universe_02 The Law of Falling Bodies.wmv with title: Mechanical Universe - Mechanical_Universe_02 The Law of Falling Bodies
# 09:43:13 - Upload successful! Video ID: bVr2b6FvKRg
# 09:43:13 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\Mechanical Universe\Mechanical_Universe_03 Derivatives.wmv with title: Mechanical Universe - Mechanical_Universe_03 Derivatives
# 09:43:54 - Upload successful! Video ID: FUh1L7kehpw
# 09:43:54 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\Mechanical Universe\Mechanical_Universe_04._Inertia.wmv with title: Mechanical Universe - Mechanical_Universe_04._Inertia
# 09:44:17 - Upload successful! Video ID: QBzCOj3Cq6Q
# 09:44:17 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\Mechanical Universe\Mechanical_Universe_05._Vectors.wmv with title: Mechanical Universe - Mechanical_Universe_05._Vectors
# 09:44:57 - Upload successful! Video ID: rk7aBr2mwJU
# 09:44:57 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\Mechanical Universe\Mechanical_Universe_06 Newtons Law.wmv with title: Mechanical Universe - Mechanical_Universe_06 Newtons Law
# 09:45:38 - Upload successful! Video ID: Z-eNcB4Gtp0
# 09:45:38 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\Mechanical Universe\Mechanical_Universe_07 Integration.wmv with title: Mechanical Universe - Mechanical_Universe_07 Integration
# 09:46:19 - Upload successful! Video ID: ctDp8PJslAo
# 09:46:19 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\Mechanical Universe\Mechanical_Universe_08 The Apple and the Moon.wmv with title: Mechanical Universe - Mechanical_Universe_08 The Apple and the Moon
# 09:47:00 - Upload successful! Video ID: pq5_d8ZAiHY
# 09:47:00 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\Mechanical Universe\Mechanical_Universe_09 Moving in Circles.wmv with title: Mechanical Universe - Mechanical_Universe_09 Moving in Circles
# 09:47:41 - Upload successful! Video ID: XaXkgu1alAc
# 09:47:41 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\Mechanical Universe\Mechanical_Universe_10 Fundamental Forces.wmv with title: Mechanical Universe - Mechanical_Universe_10 Fundamental Forces
# 09:48:22 - Upload successful! Video ID: vI78iMpzU9c
# 09:48:22 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\Mechanical Universe\Mechanical_Universe_11._Gravity__Electricity__Magnetism.wmv with title: Mechanical Universe - Mechanical_Universe_11._Gravity__Electricity__Magnetism
# 09:49:03 - Upload successful! Video ID: dJx-B9EQAKs
# 09:49:03 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\Mechanical Universe\Mechanical_Universe_12 The Millikan Experiment.wmv with title: Mechanical Universe - Mechanical_Universe_12 The Millikan Experiment
# 09:49:44 - Upload successful! Video ID: uEB_oa4Dc-4
# 09:49:44 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\Mechanical Universe\Mechanical_Universe_13 Conservation of Energy.wmv with title: Mechanical Universe - Mechanical_Universe_13 Conservation of Energy
# 09:50:25 - Upload successful! Video ID: i61ny3Q-vgk
# 09:50:25 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\Mechanical Universe\Mechanical_Universe_14 Potential Energy.wmv with title: Mechanical Universe - Mechanical_Universe_14 Potential Energy
# 09:51:07 - Upload successful! Video ID: WYmBFM9kdxs
# 09:51:07 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\Mechanical Universe\Mechanical_Universe_15._Conservation_of_Momentum.wmv with title: Mechanical Universe - Mechanical_Universe_15._Conservation_of_Momentum
# 09:51:48 - Upload successful! Video ID: XpBjtriWrjM
# 09:51:48 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\Mechanical Universe\Mechanical_Universe_16 Harmonic Motion.wmv with title: Mechanical Universe - Mechanical_Universe_16 Harmonic Motion
# 09:52:30 - Upload successful! Video ID: lmR9snwdI9I
# 09:52:30 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\Mechanical Universe\Mechanical_Universe_17 Resonance.wmv with title: Mechanical Universe - Mechanical_Universe_17 Resonance
# 09:53:11 - Upload successful! Video ID: lCbqpKZORNQ
# 09:53:11 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\Mechanical Universe\Mechanical_Universe_18 Waves.wmv with title: Mechanical Universe - Mechanical_Universe_18 Waves
# 09:53:52 - Upload successful! Video ID: g0FT_QyiT3I
# 09:53:52 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\Mechanical Universe\Mechanical_Universe_19 Angular Momentum.wmv with title: Mechanical Universe - Mechanical_Universe_19 Angular Momentum
# 09:54:34 - Upload successful! Video ID: eI1-v94BHy4
# 09:54:34 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\Mechanical Universe\Mechanical_Universe_20 Torques and Gyroscopes.wmv with title: Mechanical Universe - Mechanical_Universe_20 Torques and Gyroscopes
# 09:55:15 - Upload successful! Video ID: pJVg0w0uIRM
# 09:55:15 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\Mechanical Universe\Mechanical_Universe_21 Keplers Three Laws.wmv with title: Mechanical Universe - Mechanical_Universe_21 Keplers Three Laws
# 09:55:57 - Upload successful! Video ID: nP-W2XeLeso
# 09:55:57 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\Mechanical Universe\Mechanical_Universe_22 The Kepler Problem.wmv with title: Mechanical Universe - Mechanical_Universe_22 The Kepler Problem
# 09:56:38 - Upload successful! Video ID: WtTMSBZ7G8M
# 09:56:38 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\Mechanical Universe\Mechanical_Universe_23._Energy_and_Eccentricity.wmv with title: Mechanical Universe - Mechanical_Universe_23._Energy_and_Eccentricity
# 09:57:05 - Upload successful! Video ID: cg9BaWmY0z4
# 09:57:05 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\Mechanical Universe\Mechanical_Universe_24 Navigating in Space.wmv with title: Mechanical Universe - Mechanical_Universe_24 Navigating in Space
# 09:57:46 - Upload successful! Video ID: -T3Vfopk7xI
# 09:57:46 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\Mechanical Universe\Mechanical_Universe_25 Kepler to Einstein.wmv with title: Mechanical Universe - Mechanical_Universe_25 Kepler to Einstein
# 09:58:27 - Upload successful! Video ID: oxFF311fYbU
# 09:58:27 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\Mechanical Universe\Mechanical_Universe_26 Harmony of the Spheres.wmv with title: Mechanical Universe - Mechanical_Universe_26 Harmony of the Spheres
# 09:59:09 - Upload successful! Video ID: leBHmae4yvk
# 09:59:09 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\Mechanical Universe\Mechanical_Universe_27._Mechanical_Universe_and_Beyond.wmv with title: Mechanical Universe - Mechanical_Universe_27._Mechanical_Universe_and_Beyond
# 09:59:37 - Upload successful! Video ID: 1vkA7ejW6PA
# 09:59:37 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\Mechanical Universe\Mechanical_Universe_28 Static Electricity.wmv with title: Mechanical Universe - Mechanical_Universe_28 Static Electricity
# 10:00:22 - Upload successful! Video ID: EBbfKP7Ocsg
# 10:00:22 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\Mechanical Universe\Mechanical_Universe_29 The Electric Field.wmv with title: Mechanical Universe - Mechanical_Universe_29 The Electric Field
# 10:01:03 - Upload successful! Video ID: zGDPChV5Aow
# 10:01:03 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\Mechanical Universe\Mechanical_Universe_30 Potential and Capacitance.wmv with title: Mechanical Universe - Mechanical_Universe_30 Potential and Capacitance
# 10:01:44 - Upload successful! Video ID: hsGHnir0kAk
# 10:01:44 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\Mechanical Universe\Mechanical_Universe_31 Voltage Energy and Force.wmv with title: Mechanical Universe - Mechanical_Universe_31 Voltage Energy and Force
# 10:02:25 - Upload successful! Video ID: bLnwf8v_dq8
# 10:02:25 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\Mechanical Universe\Mechanical_Universe_32 The Electric Battery.wmv with title: Mechanical Universe - Mechanical_Universe_32 The Electric Battery
# 10:03:06 - Upload successful! Video ID: haPi74ccWgY
# 10:03:06 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\Mechanical Universe\Mechanical_Universe_33 Electrical Circuits.wmv with title: Mechanical Universe - Mechanical_Universe_33 Electrical Circuits
# 10:03:47 - Upload successful! Video ID: 8QCtpOh1kMA
# 10:03:47 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\Mechanical Universe\Mechanical_Universe_34 Magnetism.wmv with title: Mechanical Universe - Mechanical_Universe_34 Magnetism
# 10:04:28 - Upload successful! Video ID: sbI6_S3wcf4
# 10:04:28 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\Mechanical Universe\Mechanical_Universe_35 Magnetic Field.wmv with title: Mechanical Universe - Mechanical_Universe_35 Magnetic Field
# 10:05:09 - Upload successful! Video ID: PoIwAyt2zMk
# 10:05:09 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\Mechanical Universe\Mechanical_Universe_36 Vector Fields And Hydrodynamics.wmv with title: Mechanical Universe - Mechanical_Universe_36 Vector Fields And Hydrodynamics
# 10:05:50 - Upload successful! Video ID: 8M8vBg-LLZQ
# 10:05:50 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\32. Uranus and Neptune, the Small Giants.avi with title: TTC - Understanding The Universe - 32. Uranus and Neptune, the Small Giants
# 10:06:32 - Upload successful! Video ID: B0nqqTK25QE
# 10:06:32 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\33. Pluto and Its Cousins.avi with title: TTC - Understanding The Universe - 33. Pluto and Its Cousins
# 10:07:15 - Upload successful! Video ID: bwsFjoBUHB0
# 10:07:15 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\34. Asteroids and Dwarf Planets.avi with title: TTC - Understanding The Universe - 34. Asteroids and Dwarf Planets
# 10:07:57 - Upload successful! Video ID: jX5E4kTdhiU
# 10:07:57 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\35. Comets—Gorgeous Primordial Snowballs.avi with title: TTC - Understanding The Universe - 35. Comets—Gorgeous Primordial Snowballs
# 10:08:39 - Upload successful! Video ID: gPCibOktLWM
# 10:08:39 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\36. Catastrophic Collisions.avi with title: TTC - Understanding The Universe - 36. Catastrophic Collisions
# 10:09:21 - Upload successful! Video ID: 8m1k86YWi8I
# 10:09:21 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\37. The Formation of Planetary Systems.avi with title: TTC - Understanding The Universe - 37. The Formation of Planetary Systems
# 10:10:03 - Upload successful! Video ID: hwAyvqlmt2U
# 10:10:03 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\38. The Quest for Other Planetary Systems.avi with title: TTC - Understanding The Universe - 38. The Quest for Other Planetary Systems
# 10:10:45 - Upload successful! Video ID: 4UVKAYUrLL8
# 10:10:45 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\39. Extra-Solar Planets Galore!.avi with title: TTC - Understanding The Universe - 39. Extra-Solar Planets Galore!
# 10:11:27 - Upload successful! Video ID: JqNL3aDDdY8
# 10:11:27 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\40. Life Beyond the Earth.avi with title: TTC - Understanding The Universe - 40. Life Beyond the Earth
# 10:12:09 - Upload successful! Video ID: YASvJsYvM4o
# 10:12:09 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\41. The Search for Extraterrestrials.avi with title: TTC - Understanding The Universe - 41. The Search for Extraterrestrials
# 10:12:51 - Upload successful! Video ID: rPiJaslmqRY
# 10:12:51 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\42. Special Relativity and Interstellar Travel.avi with title: TTC - Understanding The Universe - 42. Special Relativity and Interstellar Travel
# 10:13:33 - Upload successful! Video ID: BLOKbmZ8h3M
# 10:13:33 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\43. Stars—Distant Suns.avi with title: TTC - Understanding The Universe - 43. Stars—Distant Suns
# 10:13:33 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\43. Stars—Distant Suns.avi to YouTube (attempt 1): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 10:13:33 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\43. Stars—Distant Suns.avi in 3 minutes...
# 10:16:34 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\43. Stars—Distant Suns.avi to YouTube (attempt 2): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 10:16:34 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\43. Stars—Distant Suns.avi in 3 minutes...
# 10:19:34 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\43. Stars—Distant Suns.avi to YouTube (attempt 3): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 10:19:34 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\43. Stars—Distant Suns.avi after 3 attempts.
# 10:19:34 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\43. Stars—Distant Suns.avi
# 10:19:34 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\44. The Intrinsic Brightnesses of Stars.avi with title: TTC - Understanding The Universe - 44. The Intrinsic Brightnesses of Stars
# 10:19:34 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\44. The Intrinsic Brightnesses of Stars.avi to YouTube (attempt 1): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 10:19:34 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\44. The Intrinsic Brightnesses of Stars.avi in 3 minutes...
# 10:22:35 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\44. The Intrinsic Brightnesses of Stars.avi to YouTube (attempt 2): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 10:22:35 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\44. The Intrinsic Brightnesses of Stars.avi in 3 minutes...
# 10:25:35 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\44. The Intrinsic Brightnesses of Stars.avi to YouTube (attempt 3): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 10:25:35 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\44. The Intrinsic Brightnesses of Stars.avi after 3 attempts.
# 10:25:35 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\44. The Intrinsic Brightnesses of Stars.avi
# 10:25:35 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\45. The Diverse Sizes of Stars.avi with title: TTC - Understanding The Universe - 45. The Diverse Sizes of Stars
# 10:25:36 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\45. The Diverse Sizes of Stars.avi to YouTube (attempt 1): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 10:25:36 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\45. The Diverse Sizes of Stars.avi in 3 minutes...
# 10:28:36 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\45. The Diverse Sizes of Stars.avi to YouTube (attempt 2): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 10:28:36 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\45. The Diverse Sizes of Stars.avi in 3 minutes...
# 10:31:36 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\45. The Diverse Sizes of Stars.avi to YouTube (attempt 3): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 10:31:36 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\45. The Diverse Sizes of Stars.avi after 3 attempts.
# 10:31:36 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\45. The Diverse Sizes of Stars.avi
# 10:31:36 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\46. Binary Stars and Stellar Masses.avi with title: TTC - Understanding The Universe - 46. Binary Stars and Stellar Masses
# 10:31:37 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\46. Binary Stars and Stellar Masses.avi to YouTube (attempt 1): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 10:31:37 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\46. Binary Stars and Stellar Masses.avi in 3 minutes...
# 10:34:37 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\46. Binary Stars and Stellar Masses.avi to YouTube (attempt 2): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 10:34:37 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\46. Binary Stars and Stellar Masses.avi in 3 minutes...
# 10:37:38 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\46. Binary Stars and Stellar Masses.avi to YouTube (attempt 3): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 10:37:38 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\46. Binary Stars and Stellar Masses.avi after 3 attempts.
# 10:37:38 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\46. Binary Stars and Stellar Masses.avi
# 10:37:38 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\47. Star Clusters, Ages, and Remote Distances.avi with title: TTC - Understanding The Universe - 47. Star Clusters, Ages, and Remote Distances
# ...
# 11:51:18 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\83. Einstein's Biggest Blunder.avi after 3 attempts.
# 11:51:18 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\83. Einstein's Biggest Blunder.avi
# 11:51:18 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\84. The Afterglow of the Big Bang.avi with title: TTC - Understanding The Universe - 84. The Afterglow of the Big Bang
# 11:51:19 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\84. The Afterglow of the Big Bang.avi to YouTube (attempt 1): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 11:51:19 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\84. The Afterglow of the Big Bang.avi in 3 minutes...
# 11:54:19 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\84. The Afterglow of the Big Bang.avi to YouTube (attempt 2): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 11:54:19 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\84. The Afterglow of the Big Bang.avi in 3 minutes...
# 11:57:20 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\84. The Afterglow of the Big Bang.avi to YouTube (attempt 3): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 11:57:20 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\84. The Afterglow of the Big Bang.avi after 3 attempts.
# 11:57:20 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\84. The Afterglow of the Big Bang.avi
# 11:57:20 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\85. Ripples in the Cosmic Background Radiation.avi with title: TTC - Understanding The Universe - 85. Ripples in the Cosmic Background Radiation
# 11:57:20 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\85. Ripples in the Cosmic Background Radiation.avi to YouTube (attempt 1): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 11:57:20 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\85. Ripples in the Cosmic Background Radiation.avi in 3 minutes...
# 12:00:21 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\85. Ripples in the Cosmic Background Radiation.avi to YouTube (attempt 2): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 12:00:21 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\85. Ripples in the Cosmic Background Radiation.avi in 3 minutes...
# 12:03:21 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\85. Ripples in the Cosmic Background Radiation.avi to YouTube (attempt 3): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 12:03:21 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\85. Ripples in the Cosmic Background Radiation.avi after 3 attempts.
# 12:03:21 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\85. Ripples in the Cosmic Background Radiation.avi
# 12:03:21 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\86. The Stuff of the Cosmos.avi with title: TTC - Understanding The Universe - 86. The Stuff of the Cosmos
# 12:03:21 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\86. The Stuff of the Cosmos.avi to YouTube (attempt 1): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 12:03:21 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\86. The Stuff of the Cosmos.avi in 3 minutes...
# 12:06:22 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\86. The Stuff of the Cosmos.avi to YouTube (attempt 2): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 12:06:22 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\86. The Stuff of the Cosmos.avi in 3 minutes...
# 12:09:22 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\86. The Stuff of the Cosmos.avi to YouTube (attempt 3): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 12:09:22 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\86. The Stuff of the Cosmos.avi after 3 attempts.
# 12:09:22 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\86. The Stuff of the Cosmos.avi
# 12:09:22 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\87. Dark Energy—Quantum Fluctuations.avi with title: TTC - Understanding The Universe - 87. Dark Energy—Quantum Fluctuations
# 12:09:23 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\87. Dark Energy—Quantum Fluctuations.avi to YouTube (attempt 1): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 12:09:23 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\87. Dark Energy—Quantum Fluctuations.avi in 3 minutes...
# 12:12:23 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\87. Dark Energy—Quantum Fluctuations.avi to YouTube (attempt 2): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 12:12:23 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\87. Dark Energy—Quantum Fluctuations.avi in 3 minutes...
# 12:15:24 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\87. Dark Energy—Quantum Fluctuations.avi to YouTube (attempt 3): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 12:15:24 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\87. Dark Energy—Quantum Fluctuations.avi after 3 attempts.
# 12:15:24 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\87. Dark Energy—Quantum Fluctuations.avi
# 12:15:24 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\88. Dark Energy—Quintessence.avi with title: TTC - Understanding The Universe - 88. Dark Energy—Quintessence
# 12:15:24 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\88. Dark Energy—Quintessence.avi to YouTube (attempt 1): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 12:15:24 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\88. Dark Energy—Quintessence.avi in 3 minutes...
# 12:18:24 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\88. Dark Energy—Quintessence.avi to YouTube (attempt 2): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 12:18:24 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\88. Dark Energy—Quintessence.avi in 3 minutes...
# 12:21:25 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\88. Dark Energy—Quintessence.avi to YouTube (attempt 3): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 12:21:25 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\88. Dark Energy—Quintessence.avi after 3 attempts.
# 12:21:25 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\88. Dark Energy—Quintessence.avi
# 12:21:25 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\89. Grand Unification & Theories of Everything.avi with title: TTC - Understanding The Universe - 89. Grand Unification & Theories of Everything
# 12:21:25 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\89. Grand Unification & Theories of Everything.avi to YouTube (attempt 1): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 12:21:25 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\89. Grand Unification & Theories of Everything.avi in 3 minutes...
# 12:24:26 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\89. Grand Unification & Theories of Everything.avi to YouTube (attempt 2): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 12:24:26 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\89. Grand Unification & Theories of Everything.avi in 3 minutes...
