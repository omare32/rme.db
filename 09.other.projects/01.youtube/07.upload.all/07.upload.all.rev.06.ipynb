# %%
import os
import sys
import glob
import logging
from datetime import datetime
from pathlib import Path
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import tkinter as tk
from tkinter import filedialog
from google_auth_oauthlib.flow import InstalledAppFlow
from google.oauth2.credentials import Credentials
from google.auth.transport.requests import Request
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload
import time

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(message)s',
    datefmt='%H:%M:%S',
    handlers=[
        logging.FileHandler('upload_all.log', encoding='utf-8'),
        logging.StreamHandler()
    ]
)

TOKEN_FILE = "token.json"
SCOPES = ["https://www.googleapis.com/auth/youtube.upload"]

os.environ['OAUTHLIB_INSECURE_TRANSPORT'] = '1'
os.environ['PYTHONHTTPSVERIFY'] = '0'

def get_authenticated_service(client_secrets_file: str):
    creds = None
    if os.path.exists(TOKEN_FILE):
        creds = Credentials.from_authorized_user_file(TOKEN_FILE, SCOPES)
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(client_secrets_file, SCOPES)
            creds = flow.run_local_server(port=0)
        with open(TOKEN_FILE, 'w') as token:
            token.write(creds.to_json())
    return build('youtube', 'v3', credentials=creds)

def upload_to_youtube(youtube, video_path: str, title: str, description: str = "Uploaded by script"):
    MAX_RETRIES = 3
    RETRY_DELAY_SECONDS = 180  # 3 minutes
    for attempt in range(1, MAX_RETRIES + 1):
        try:
            body = {
                'snippet': {
                    'title': title,
                    'description': description,
                    'tags': ['tutorial', 'education']
                },
                'status': {
                    'privacyStatus': 'unlisted',
                    'selfDeclaredMadeForKids': False
                }
            }
            insert_request = youtube.videos().insert(
                part=','.join(body.keys()),
                body=body,
                media_body=MediaFileUpload(video_path, chunksize=-1, resumable=True)
            )
            response = None
            while response is None:
                status, response = insert_request.next_chunk()
                if status:
                    logging.info(f"Upload {int(status.progress() * 100)}% complete for {video_path}")
            return response['id']
        except Exception as e:
            logging.error(f"Error uploading {video_path} to YouTube (attempt {attempt}): {str(e)}")
            if attempt < MAX_RETRIES:
                logging.info(f"Retrying upload for {video_path} in {RETRY_DELAY_SECONDS // 60} minutes...")
                time.sleep(RETRY_DELAY_SECONDS)
            else:
                logging.error(f"Upload failed for {video_path} after {MAX_RETRIES} attempts.")
                return None

def select_folder_dialog(title="Select folder"):
    """Open a folder selection dialog and return the selected path."""
    try:
        root = tk.Tk()
        root.withdraw()
        root.update_idletasks()
        width = root.winfo_screenwidth()
        height = root.winfo_screenheight()
        x = (width - 400) // 2
        y = (height - 300) // 2
        root.geometry(f'400x300+{x}+{y}')
        folder_path = filedialog.askdirectory(
            title=title,
            mustexist=True
        )
        root.destroy()
        return folder_path
    except Exception as e:
        logging.error(f"Error in folder selection: {str(e)}")
        return None

def process_folder(youtube, input_folder):
    folder_name = os.path.basename(input_folder)
    VIDEO_EXTENSIONS = ('.mp4', '.mkv', '.avi', '.mov', '.wmv', '.flv', '.webm')
    video_files = [os.path.join(input_folder, f) for f in os.listdir(input_folder)
                  if os.path.isfile(os.path.join(input_folder, f))
                  and f.lower().endswith(VIDEO_EXTENSIONS)
                  and not f.endswith('.txt')]
    if not video_files:
        logging.info(f"No files found in the folder: {input_folder}")
        return
    logging.info(f"Found {len(video_files)} files to process in {input_folder}.")
    video_files = [f for f in video_files if not os.path.exists(os.path.splitext(f)[0] + '.txt')]
    for video_path in video_files:
        video_name = os.path.splitext(os.path.basename(video_path))[0]
        MAX_TITLE_LENGTH = 100
        title = f"{folder_name} - {video_name}"
        if len(title) > MAX_TITLE_LENGTH:
            title = title[:MAX_TITLE_LENGTH]
        logging.info(f"Uploading: {video_path} with title: {title}")
        video_id = upload_to_youtube(youtube, video_path, title)
        if video_id:
            link_file = os.path.join(input_folder, f"{video_name}.txt")
            with open(link_file, 'w') as f:
                f.write(f"https://www.youtube.com/watch?v={video_id}\n")
            try:
                os.remove(video_path)
            except Exception as e:
                logging.error(f"Failed to delete uploaded video file: {video_path}: {str(e)}")
            logging.info(f"Upload successful! Video ID: {video_id}")
        else:
            logging.error(f"Upload failed for {video_path}")

def main():
    # Select parent folder
    parent_folder = select_folder_dialog(title="Select parent folder containing subfolders of videos to upload")
    if not parent_folder or not os.path.exists(parent_folder):
        logging.error("No folder selected or folder does not exist")
        return
    cwd = os.getcwd()
    client_secrets_file = os.path.join(cwd, "client_secret.dlc.json")
    if not os.path.exists(client_secrets_file):
        logging.error(f"Client secrets file not found at: {client_secrets_file}")
        return
    youtube = get_authenticated_service(client_secrets_file)
    logging.info("YouTube authentication complete.")
    # Find all immediate subfolders
    subfolders = [os.path.join(parent_folder, d) for d in os.listdir(parent_folder)
                  if os.path.isdir(os.path.join(parent_folder, d))]
    if not subfolders:
        logging.info("No subfolders found in the selected parent folder.")
        return
    for subfolder in subfolders:
        logging.info(f"Processing subfolder: {subfolder}")
        process_folder(youtube, subfolder)
    logging.info("All subfolders processed.")

if __name__ == "__main__":
    main()
# Out:
# 09:53:45 - file_cache is only supported with oauth2client<4.0.0
# 09:53:45 - YouTube authentication complete.
# 09:53:45 - Processing subfolder: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/l\Docs
# 09:53:45 - Found 129 files to process in //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/l\Docs.
# 09:53:45 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/l\Docs\Alaska Pipeline.avi with title: Docs - Alaska Pipeline
# 09:55:48 - Upload successful! Video ID: 3W6LwOVEcDM
# 09:55:48 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/l\Docs\Alien Planet.avi with title: Docs - Alien Planet
# 09:59:54 - Upload successful! Video ID: 9QibTS3O_2A
# 09:59:54 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/l\Docs\amateurporn-xvid-ws.avi with title: Docs - amateurporn-xvid-ws
# 10:02:08 - Upload successful! Video ID: 9_6-iiRVwqQ
# 10:02:08 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/l\Docs\Are We Alone In The Universe.avi with title: Docs - Are We Alone In The Universe
# 10:04:59 - Upload successful! Video ID: y5pZ5Ge_Zng
# 10:04:59 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/l\Docs\Arthur Clarke - Fractals - The Colors Of Infinity.avi with title: Docs - Arthur Clarke - Fractals - The Colors Of Infinity
# 10:07:02 - Upload successful! Video ID: vpvG27nMdEo
# 10:07:02 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/l\Docs\Asteroid - The Doomsday Rock.avi with title: Docs - Asteroid - The Doomsday Rock
# 10:09:05 - Upload successful! Video ID: hBr49pzjKeE
# 10:09:05 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/l\Docs\BangkokGirl.TheLens.avi with title: Docs - BangkokGirl.TheLens
# 10:12:01 - Upload successful! Video ID: KgqzL5Aqdog
# 10:12:01 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/l\Docs\Beautiful.Minds.(Part.1).The.Living.Computer.TVRip.XviD-SPORE.avi with title: Docs - Beautiful.Minds.(Part.1).The.Living.Computer.TVRip.XviD-SPORE
# 10:14:04 - Upload successful! Video ID: e4Y_OLeHnYs
# 10:14:04 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/l\Docs\Beep.A.Documentary.History.of.Game.Sound.2016.480p.Bluray.x264.AAC.MVGroup.org.mp4 with title: Docs - Beep.A.Documentary.History.of.Game.Sound.2016.480p.Bluray.x264.AAC.MVGroup.org
# 10:16:54 - Upload successful! Video ID: cIIZZ8iywmE
# 10:16:54 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/l\Docs\Bermuda.Triangle-The.True.Story-12-03-2007.avi with title: Docs - Bermuda.Triangle-The.True.Story-12-03-2007
# 10:18:57 - Upload successful! Video ID: zE5KZJEIOiU
# 10:18:57 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/l\Docs\Beyond_the_Da_Vinci_Code_-_complete_-_DivX@VBR.avi with title: Docs - Beyond_the_Da_Vinci_Code_-_complete_-_DivX@VBR
# 10:23:03 - Upload successful! Video ID: rwvimwdj7BM
# 10:23:03 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/l\Docs\BigCatCrisis.NationalGeographic.avi with title: Docs - BigCatCrisis.NationalGeographic
# 10:25:58 - Upload successful! Video ID: st4yIpcDQjI
# 10:25:58 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/l\Docs\BIOGRAPHY.Barack.Obama.XviD.AC3.avi with title: Docs - BIOGRAPHY.Barack.Obama.XviD.AC3
# 10:30:03 - Upload successful! Video ID: J15w7Z7uRh8
# 10:30:03 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/l\Docs\Biography.Mark.Twain.His.Amazing.Adventures.avi with title: Docs - Biography.Mark.Twain.His.Amazing.Adventures
# 10:31:50 - Upload successful! Video ID: GQp4ykfO9Cw
# 10:31:50 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/l\Docs\Birth of a Solar System.avi with title: Docs - Birth of a Solar System
# 10:33:53 - Upload successful! Video ID: Xk5JGGw92Dw
# 10:33:53 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/l\Docs\Black Sky - The Race for Space.avi with title: Docs - Black Sky - The Race for Space
# 10:37:59 - Upload successful! Video ID: F8xVbvaj9ao
# 10:37:59 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/l\Docs\Black Sky -1- SpaceshipOne.avi with title: Docs - Black Sky -1- SpaceshipOne
# 10:41:28 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/l\Docs\Black Sky -1- SpaceshipOne.avi to YouTube (attempt 1): [WinError 10054] An existing connection was forcibly closed by the remote host
# 10:41:28 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/l\Docs\Black Sky -1- SpaceshipOne.avi in 3 minutes...
# 10:44:28 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/l\Docs\Black Sky -1- SpaceshipOne.avi to YouTube (attempt 2): [WinError 10054] An existing connection was forcibly closed by the remote host
# 10:44:28 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/l\Docs\Black Sky -1- SpaceshipOne.avi in 3 minutes...
# 10:51:25 - Failed to delete uploaded video file: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/l\Docs\Black Sky -1- SpaceshipOne.avi: [WinError 32] The process cannot access the file because it is being used by another process: '//fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/l\\Docs\\Black Sky -1- SpaceshipOne.avi'
# 10:51:25 - Upload successful! Video ID: L8DML63XQHI
# 10:51:25 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/l\Docs\Black Sky -2- SpaceshipOne.avi with title: Docs - Black Sky -2- SpaceshipOne
# 10:53:42 - Upload successful! Video ID: 32ZVke44Sko
# 10:53:42 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/l\Docs\Bounce.behind.the.velvet.rope.DVDRip.XViD.avi with title: Docs - Bounce.behind.the.velvet.rope.DVDRip.XViD
# 10:57:38 - Upload successful! Video ID: vsp2z4Hl5OA
# 10:57:38 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/l\Docs\Brainsex - Why we fall in love - Documentary.avi with title: Docs - Brainsex - Why we fall in love - Documentary
# 11:01:35 - Upload successful! Video ID: jcLN0YfAXi0
# 11:01:35 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/l\Docs\Breaking.the.Silence.AC3.XviD.www.mvgroup.org.avi with title: Docs - Breaking.the.Silence.AC3.XviD.www.mvgroup.org
# 11:05:45 - Upload successful! Video ID: tJpz_QG7OUk
# 11:05:45 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/l\Docs\Buddha, Bees & the Giant Hornet Queen.avi with title: Docs - Buddha, Bees & the Giant Hornet Queen
# 11:08:34 - Upload successful! Video ID: yRIRfMoQp4s
# 11:08:34 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/l\Docs\Building the Biggest - International Space Station.avi with title: Docs - Building the Biggest - International Space Station
# 11:10:31 - Upload successful! Video ID: THjqNV0kLOc
# 11:10:31 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/l\Docs\Bushs.Brain.LiMiTED.DVDRip.XViD-ALLiANCE.avi with title: Docs - Bushs.Brain.LiMiTED.DVDRip.XViD-ALLiANCE
# 11:14:27 - Upload successful! Video ID: lJjBVgnDFBQ
# 11:14:27 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/l\Docs\Bye Bye Planet Pluto.avi with title: Docs - Bye Bye Planet Pluto
# 11:18:03 - Upload successful! Video ID: y74TLjwApoA
# 11:18:03 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/l\Docs\Cambodia - The Betrayal.avi with title: Docs - Cambodia - The Betrayal
# 11:21:45 - Upload successful! Video ID: tC1bXujP6-g
# 11:21:45 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/l\Docs\Capitalism.A.Love.Story.DOCU.DVDRip.XviD-SAPHiRE.avi with title: Docs - Capitalism.A.Love.Story.DOCU.DVDRip.XviD-SAPHiRE
# 11:29:39 - Upload successful! Video ID: 9u2VlD4uJt4
# 11:29:39 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/l\Docs\Catching The Comet.mp4 with title: Docs - Catching The Comet
# 11:31:25 - Upload successful! Video ID: HOF_OMEFaTU
# 11:31:25 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/l\Docs\CBC.Nuclear.Jihad.XviD.mp3.festering.leper.avi with title: Docs - CBC.Nuclear.Jihad.XviD.mp3.festering.leper
# 11:35:17 - Upload successful! Video ID: pCNaBfJBcJg
# 11:35:17 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/l\Docs\CBC.The.Fifth.Estate.2016.The.Fire.Breather.The.Rise.and.Rage.of.Donald.Trump.1080p.WEB-DL.H.264.AAC.MVGroup.Forum.mkv with title: Docs - CBC.The.Fifth.Estate.2016.The.Fire.Breather.The.Rise.and.Rage.of.Donald.Trump.1080p.WEB-DL.H.
# 11:39:17 - Upload successful! Video ID: y7ncIlytITE
# 11:39:17 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/l\Docs\CBC.The.Fifth.Estate.The.Strange.World.of.Julian.Assange.HDTV.x264.720p.AC3.MVGroup.org.mkv with title: Docs - CBC.The.Fifth.Estate.The.Strange.World.of.Julian.Assange.HDTV.x264.720p.AC3.MVGroup.org
