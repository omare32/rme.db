# %%
import os
import sys
import glob
import logging
from datetime import datetime
from pathlib import Path
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import tkinter as tk
from tkinter import filedialog
from google_auth_oauthlib.flow import InstalledAppFlow
from google.oauth2.credentials import Credentials
from google.auth.transport.requests import Request
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload
import time

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(message)s',
    datefmt='%H:%M:%S',
    handlers=[
        logging.FileHandler('upload_all.log', encoding='utf-8'),
        logging.StreamHandler()
    ]
)

TOKEN_FILE = "token.json"
SCOPES = ["https://www.googleapis.com/auth/youtube.upload"]

os.environ['OAUTHLIB_INSECURE_TRANSPORT'] = '1'
os.environ['PYTHONHTTPSVERIFY'] = '0'

def get_authenticated_service(client_secrets_file: str):
    creds = None
    if os.path.exists(TOKEN_FILE):
        creds = Credentials.from_authorized_user_file(TOKEN_FILE, SCOPES)
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(client_secrets_file, SCOPES)
            creds = flow.run_local_server(port=0)
        with open(TOKEN_FILE, 'w') as token:
            token.write(creds.to_json())
    return build('youtube', 'v3', credentials=creds)

def upload_to_youtube(youtube, video_path: str, title: str, description: str = "Uploaded by script"):
    MAX_RETRIES = 3
    RETRY_DELAY_SECONDS = 180  # 3 minutes
    for attempt in range(1, MAX_RETRIES + 1):
        try:
            body = {
                'snippet': {
                    'title': title,
                    'description': description,
                    'tags': ['tutorial', 'education']
                },
                'status': {
                    'privacyStatus': 'unlisted',
                    'selfDeclaredMadeForKids': False
                }
            }
            insert_request = youtube.videos().insert(
                part=','.join(body.keys()),
                body=body,
                media_body=MediaFileUpload(video_path, chunksize=-1, resumable=True)
            )
            response = None
            while response is None:
                status, response = insert_request.next_chunk()
                if status:
                    logging.info(f"Upload {int(status.progress() * 100)}% complete for {video_path}")
            return response['id']
        except Exception as e:
            logging.error(f"Error uploading {video_path} to YouTube (attempt {attempt}): {str(e)}")
            if attempt < MAX_RETRIES:
                logging.info(f"Retrying upload for {video_path} in {RETRY_DELAY_SECONDS // 60} minutes...")
                time.sleep(RETRY_DELAY_SECONDS)
            else:
                logging.error(f"Upload failed for {video_path} after {MAX_RETRIES} attempts.")
                return None

def select_folder_dialog(title="Select folder"):
    """Open a folder selection dialog and return the selected path."""
    try:
        root = tk.Tk()
        root.withdraw()
        root.update_idletasks()
        width = root.winfo_screenwidth()
        height = root.winfo_screenheight()
        x = (width - 400) // 2
        y = (height - 300) // 2
        root.geometry(f'400x300+{x}+{y}')
        folder_path = filedialog.askdirectory(
            title=title,
            mustexist=True
        )
        root.destroy()
        return folder_path
    except Exception as e:
        logging.error(f"Error in folder selection: {str(e)}")
        return None

def process_folder(youtube, input_folder):
    folder_name = os.path.basename(input_folder)
    VIDEO_EXTENSIONS = ('.mp4', '.mkv', '.avi', '.mov', '.wmv', '.flv', '.webm')
    video_files = [os.path.join(input_folder, f) for f in os.listdir(input_folder)
                  if os.path.isfile(os.path.join(input_folder, f))
                  and f.lower().endswith(VIDEO_EXTENSIONS)
                  and not f.endswith('.txt')]
    if not video_files:
        logging.info(f"No files found in the folder: {input_folder}")
        return
    logging.info(f"Found {len(video_files)} files to process in {input_folder}.")
    video_files = [f for f in video_files if not os.path.exists(os.path.splitext(f)[0] + '.txt')]
    for video_path in video_files:
        video_name = os.path.splitext(os.path.basename(video_path))[0]
        MAX_TITLE_LENGTH = 100
        title = f"{folder_name} - {video_name}"
        if len(title) > MAX_TITLE_LENGTH:
            title = title[:MAX_TITLE_LENGTH]
        logging.info(f"Uploading: {video_path} with title: {title}")
        video_id = upload_to_youtube(youtube, video_path, title)
        if video_id:
            link_file = os.path.join(input_folder, f"{video_name}.txt")
            with open(link_file, 'w') as f:
                f.write(f"https://www.youtube.com/watch?v={video_id}\n")
            try:
                os.remove(video_path)
            except Exception as e:
                logging.error(f"Failed to delete uploaded video file: {video_path}: {str(e)}")
            logging.info(f"Upload successful! Video ID: {video_id}")
        else:
            logging.error(f"Upload failed for {video_path}")

def main():
    # Select parent folder
    parent_folder = select_folder_dialog(title="Select parent folder containing subfolders of videos to upload")
    if not parent_folder or not os.path.exists(parent_folder):
        logging.error("No folder selected or folder does not exist")
        return
    cwd = os.getcwd()
    client_secrets_file = os.path.join(cwd, "client_secret.dlc.json")
    if not os.path.exists(client_secrets_file):
        logging.error(f"Client secrets file not found at: {client_secrets_file}")
        return
    youtube = get_authenticated_service(client_secrets_file)
    logging.info("YouTube authentication complete.")
    # Find all immediate subfolders
    subfolders = [os.path.join(parent_folder, d) for d in os.listdir(parent_folder)
                  if os.path.isdir(os.path.join(parent_folder, d))]
    if not subfolders:
        logging.info("No subfolders found in the selected parent folder.")
        return
    for subfolder in subfolders:
        logging.info(f"Processing subfolder: {subfolder}")
        process_folder(youtube, subfolder)
    logging.info("All subfolders processed.")

if __name__ == "__main__":
    main()
# Out:
# 20:22:18 - file_cache is only supported with oauth2client<4.0.0
# 20:22:18 - YouTube authentication complete.
# 20:22:18 - Processing subfolder: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\1980-2000
# 20:22:18 - Found 8 files to process in //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\1980-2000.
# 20:22:18 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\1980-2000\Frontline.S1995E15.Waco.The.Inside.Story.PBS.WEB-DL.AAC2.0.H.264.mp4 with title: 1980-2000 - Frontline.S1995E15.Waco.The.Inside.Story.PBS.WEB-DL.AAC2.0.H.264
# 20:25:26 - Upload successful! Video ID: YzUQLQcOGXs
# 20:25:26 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\1980-2000\PBS.Frontline.1985.Memory.of.the.Camps.720p.HDTV.x264.AAC.MVGroup.org.mp4 with title: 1980-2000 - PBS.Frontline.1985.Memory.of.the.Camps.720p.HDTV.x264.AAC.MVGroup.org
# 20:31:04 - Upload successful! Video ID: ohRPcfQMAo0
# 20:31:04 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\1980-2000\PBS.Frontline.1990.The.Spirit.of.Crazy.Horse.VHSRip.x264.AAC.MVGroup.org.mp4 with title: 1980-2000 - PBS.Frontline.1990.The.Spirit.of.Crazy.Horse.VHSRip.x264.AAC.MVGroup.org
# 20:35:56 - Upload successful! Video ID: 46fqHPFACwA
# 20:35:56 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\1980-2000\PBS.Frontline.1996.The.Gulf.War.1of2.VHSRip.x264.AAC.MVGroup.org.mp4 with title: 1980-2000 - PBS.Frontline.1996.The.Gulf.War.1of2.VHSRip.x264.AAC.MVGroup.org
# 20:42:33 - Upload successful! Video ID: V4iRczHS9hc
# 20:42:33 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\1980-2000\PBS.Frontline.1996.The.Gulf.War.2of2.VHSRip.x264.AAC.MVGroup.org.mp4 with title: 1980-2000 - PBS.Frontline.1996.The.Gulf.War.2of2.VHSRip.x264.AAC.MVGroup.org
# 20:49:35 - Upload successful! Video ID: ZYKTbD_Mp3w
# 20:49:35 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\1980-2000\PBS.Frontline.1998.From.Jesus.to.Christ.The.First.Christians.1of2.720p.HDTV.x264.AAC.MVGroup.org.mp4 with title: 1980-2000 - PBS.Frontline.1998.From.Jesus.to.Christ.The.First.Christians.1of2.720p.HDTV.x264.AAC.MVG
# 21:02:24 - Upload successful! Video ID: 37w3M_C0XIs
# 21:02:24 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\1980-2000\PBS.Frontline.1998.From.Jesus.to.Christ.The.First.Christians.2of2.720p.HDTV.x264.AAC.MVGroup.org.mp4 with title: 1980-2000 - PBS.Frontline.1998.From.Jesus.to.Christ.The.First.Christians.2of2.720p.HDTV.x264.AAC.MVG
# 21:13:56 - Upload successful! Video ID: r3KH4qX9jUY
# 21:13:56 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\1980-2000\PBS.Frontline.1999.The.Long.Walk.of.Nelson.Mandela.720p.x264.AAC.MVGroup.org.mp4 with title: 1980-2000 - PBS.Frontline.1999.The.Long.Walk.of.Nelson.Mandela.720p.x264.AAC.MVGroup.org
# 21:26:58 - Upload successful! Video ID: FUpA7gbDUnQ
# 21:26:58 - Processing subfolder: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2001-2011
# 21:26:58 - Found 36 files to process in //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2001-2011.
# 21:26:58 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2001-2011\Frontline.S2004E11.The.Plea.PBS.WEB-DL.AAC.2.0.H.264.mp4 with title: 2001-2011 - Frontline.S2004E11.The.Plea.PBS.WEB-DL.AAC.2.0.H.264
# 21:28:42 - Upload successful! Video ID: vQJIL2DBlXg
# 21:28:42 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2001-2011\Frontline.S2004E15.The.Persuaders.PBS.WEB-DL.AAC.2.0.H.264.mp4 with title: 2001-2011 - Frontline.S2004E15.The.Persuaders.PBS.WEB-DL.AAC.2.0.H.264
# 21:34:41 - Upload successful! Video ID: svqG_iGKqa8
# 21:34:41 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2001-2011\Frontline.S28E17.The.Vaccine.War.iNTERNAL.480p.x264-mSD.mkv with title: 2001-2011 - Frontline.S28E17.The.Vaccine.War.iNTERNAL.480p.x264-mSD
# 21:36:49 - Upload successful! Video ID: BXCmqn92U5o
# 21:36:49 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2001-2011\PBS Frontline - The Meth Epidemic (2006.HDTV.SoS).avi with title: 2001-2011 - PBS Frontline - The Meth Epidemic (2006.HDTV.SoS)
# 21:40:25 - Upload successful! Video ID: s0Y4PAmF97Y
# 21:40:25 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2001-2011\PBS.Frontline.2001.The.Merchants.of.Cool.DVDRip.XviD.MP3.MVGroup.Forum.avi with title: 2001-2011 - PBS.Frontline.2001.The.Merchants.of.Cool.DVDRip.XviD.MP3.MVGroup.Forum
# 21:44:36 - Upload successful! Video ID: enIQJA6bDq4
# 21:44:36 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2001-2011\PBS.Frontline.2002.The.Man.Who.Knew.720p.HDTV.x264.AAC.MVGroup.org.mkv with title: 2001-2011 - PBS.Frontline.2002.The.Man.Who.Knew.720p.HDTV.x264.AAC.MVGroup.org
# 21:48:44 - Upload successful! Video ID: 4m8f1wSZRVQ
# 21:48:44 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2001-2011\PBS.Frontline.2004.E06.Ghosts.of.Rwanda.1of2.DivX-AC3.MVGroup.org.avi with title: 2001-2011 - PBS.Frontline.2004.E06.Ghosts.of.Rwanda.1of2.DivX-AC3.MVGroup.org
# 21:52:57 - Upload successful! Video ID: PSTL-QVcYeQ
# 21:52:57 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2001-2011\PBS.Frontline.2004.E06.Ghosts.of.Rwanda.2of2.DivX-AC3.MVGroup.org.avi with title: 2001-2011 - PBS.Frontline.2004.E06.Ghosts.of.Rwanda.2of2.DivX-AC3.MVGroup.org
# 21:57:09 - Upload successful! Video ID: DsZb6eVMh4E
# 21:57:09 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2001-2011\PBS.Frontline.2006.The.Tank.Man.PDTV.Xvid.MP3.MVGroup.Forum.avi with title: 2001-2011 - PBS.Frontline.2006.The.Tank.Man.PDTV.Xvid.MP3.MVGroup.Forum
# 22:00:27 - Upload successful! Video ID: PWRvAAJJ_ZU
# 22:00:27 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2001-2011\PBS.Frontline.2007.News.War.1of4.Secrets.Sources.and.Spin.Pt.1.DVDRip.x264.AAC.MVGroup.org.mp4 with title: 2001-2011 - PBS.Frontline.2007.News.War.1of4.Secrets.Sources.and.Spin.Pt.1.DVDRip.x264.AAC.MVGroup.o
# 22:04:49 - Upload successful! Video ID: -xifZFol3ME
# 22:04:49 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2001-2011\PBS.Frontline.2007.News.War.2of4.Secrets.Sources.and.Spin.Pt.2.DVDRip.x264.AAC.MVGroup.org.mp4 with title: 2001-2011 - PBS.Frontline.2007.News.War.2of4.Secrets.Sources.and.Spin.Pt.2.DVDRip.x264.AAC.MVGroup.o
# 22:09:56 - Upload successful! Video ID: oPr3wqax3PA
# 22:09:56 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2001-2011\PBS.Frontline.2007.News.War.3of4.Whats.Happening.to.the.News.DVDRip.x264.AAC.MVGroup.org.mp4 with title: 2001-2011 - PBS.Frontline.2007.News.War.3of4.Whats.Happening.to.the.News.DVDRip.x264.AAC.MVGroup.org
# 22:16:55 - Upload successful! Video ID: koyFA9Y14LI
# 22:16:55 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2001-2011\PBS.Frontline.2007.News.War.4of4.Stories.from.a.Small.Planet.DVDRip.x264.AAC.MVGroup.org.mp4 with title: 2001-2011 - PBS.Frontline.2007.News.War.4of4.Stories.from.a.Small.Planet.DVDRip.x264.AAC.MVGroup.org
# 22:22:57 - Upload successful! Video ID: vzGtEP5QY7U
# 22:22:57 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2001-2011\PBS.Frontline.2008.Rules.of.Engagement.720p.HDTV.x264.AAC.MVGroup.org.mp4 with title: 2001-2011 - PBS.Frontline.2008.Rules.of.Engagement.720p.HDTV.x264.AAC.MVGroup.org
# 22:27:08 - Upload successful! Video ID: B8JwjxVi08k
# 22:27:08 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2001-2011\PBS.Frontline.2009.The.Warning.720p.HDTV.x264.AAC.MVGroup.org.mp4 with title: 2001-2011 - PBS.Frontline.2009.The.Warning.720p.HDTV.x264.AAC.MVGroup.org
# 22:31:10 - Upload successful! Video ID: X20Qa5MPTvM
# 22:31:10 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2001-2011\PBS.Frontline.2010.College.Inc.720p.HDTV.x264.AAC.MVGroup.org.mp4 with title: 2001-2011 - PBS.Frontline.2010.College.Inc.720p.HDTV.x264.AAC.MVGroup.org
# 22:35:58 - Upload successful! Video ID: EyTbBSK8fHI
# 22:35:58 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2001-2011\PBS.Frontline.2010.Death.by.Fire.720p.HDTV.x264.AAC.MVGroup.org.mp4 with title: 2001-2011 - PBS.Frontline.2010.Death.by.Fire.720p.HDTV.x264.AAC.MVGroup.org
# 22:39:24 - Upload successful! Video ID: E1-iN8lt97A
# 22:39:24 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2001-2011\PBS.Frontline.2010.Flying.Cheap.720p.HDTV.x264.AAC.MVGroup.org.mp4 with title: 2001-2011 - PBS.Frontline.2010.Flying.Cheap.720p.HDTV.x264.AAC.MVGroup.org
# 22:43:46 - Upload successful! Video ID: 77NzgSYNx4U
# 22:43:46 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2001-2011\PBS.Frontline.2010.Law.and.Disorder.720p.HDTV.x264.AAC.MVGroup.org.mp4 with title: 2001-2011 - PBS.Frontline.2010.Law.and.Disorder.720p.HDTV.x264.AAC.MVGroup.org
# 22:49:34 - Upload successful! Video ID: GTlJRy8Alhw
# 22:49:34 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2001-2011\PBS.Frontline.2010.The.Spill.720p.HDTV.x264.AAC.MVGroup.org.mp4 with title: 2001-2011 - PBS.Frontline.2010.The.Spill.720p.HDTV.x264.AAC.MVGroup.org
# 22:54:51 - Upload successful! Video ID: BimDFCktvjs
# 22:54:51 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2001-2011\PBS.Frontline.2011.Football.High.720p.x264.AAC.MVGroup.org.mp4 with title: 2001-2011 - PBS.Frontline.2011.Football.High.720p.x264.AAC.MVGroup.org
# 23:01:50 - Upload successful! Video ID: rzOOuCYoWuk
# 23:01:50 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2001-2011\PBS.Frontline.2011.The.Anthrax.Files.720p.HDTV.x264.AAC.MVGroup.org.mp4 with title: 2001-2011 - PBS.Frontline.2011.The.Anthrax.Files.720p.HDTV.x264.AAC.MVGroup.org
# 23:05:19 - Upload successful! Video ID: -vqszibKsNk
# 23:05:19 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2001-2011\PBS.Frontline.2011.Wikisecrets.720p.x264.AAC.MVGroup.org.mp4 with title: 2001-2011 - PBS.Frontline.2011.Wikisecrets.720p.x264.AAC.MVGroup.org
# 23:11:17 - Upload successful! Video ID: wyelCaZRHeI
# 23:11:17 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2001-2011\PBS.Frontline.Secret.History.of.the.Credit.Card.XviD.AC3.MVGroup.org.avi with title: 2001-2011 - PBS.Frontline.Secret.History.of.the.Credit.Card.XviD.AC3.MVGroup.org
# 23:16:57 - Upload successful! Video ID: nZuF7lQ4_8A
# 23:16:57 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2001-2011\PBS.Frontline.The.Al.Qaeda.Files.1.of.7.Hunting.Bin.Laden.XviD.MP3.HongBearr.avi with title: 2001-2011 - PBS.Frontline.The.Al.Qaeda.Files.1.of.7.Hunting.Bin.Laden.XviD.MP3.HongBearr
# 23:20:36 - Upload successful! Video ID: 0w2U2vSjrfI
# 23:20:36 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2001-2011\PBS.Frontline.The.Al.Qaeda.Files.2.of.7.Looking.For.Answers.XviD.MP3.HongBearr.avi with title: 2001-2011 - PBS.Frontline.The.Al.Qaeda.Files.2.of.7.Looking.For.Answers.XviD.MP3.HongBearr
# 23:24:16 - Upload successful! Video ID: knEWvzC0618
# 23:24:16 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2001-2011\PBS.Frontline.The.Al.Qaeda.Files.3.of.7.The.Man.Who.Knew.XviD.MP3.HongBearr.avi with title: 2001-2011 - PBS.Frontline.The.Al.Qaeda.Files.3.of.7.The.Man.Who.Knew.XviD.MP3.HongBearr
# 23:27:58 - Upload successful! Video ID: YS2jVbRfpnE
# 23:27:58 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2001-2011\PBS.Frontline.The.Al.Qaeda.Files.4.of.7.In.Search.Of.Al.Qaeda.XviD.MP3.HongBearr.avi with title: 2001-2011 - PBS.Frontline.The.Al.Qaeda.Files.4.of.7.In.Search.Of.Al.Qaeda.XviD.MP3.HongBearr
# 23:31:37 - Upload successful! Video ID: cm2o5fvxUHA
# 23:31:37 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2001-2011\PBS.Frontline.The.Al.Qaeda.Files.5.of.7.Chasing.The.Sleeper.Cell.XviD.MP3.HongBearr.avi with title: 2001-2011 - PBS.Frontline.The.Al.Qaeda.Files.5.of.7.Chasing.The.Sleeper.Cell.XviD.MP3.HongBearr
# 23:35:16 - Upload successful! Video ID: EzGd78X1To8
# 23:35:16 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2001-2011\PBS.Frontline.The.Al.Qaeda.Files.6.of.7.Son.Of.Al.Qaeda.XviD.MP3.HongBearr.avi with title: 2001-2011 - PBS.Frontline.The.Al.Qaeda.Files.6.of.7.Son.Of.Al.Qaeda.XviD.MP3.HongBearr
# 23:38:49 - Upload successful! Video ID: LxKzQPtS1To
# 23:38:49 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2001-2011\PBS.Frontline.The.Al.Qaeda.Files.7.of.7.Al.Qaedas.New.Front.XviD.MP3.HongBearr.avi with title: 2001-2011 - PBS.Frontline.The.Al.Qaeda.Files.7.of.7.Al.Qaedas.New.Front.XviD.MP3.HongBearr
# 23:42:29 - Upload successful! Video ID: peB2qubA02s
# 23:42:29 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2001-2011\PBS.Frontline.The.Card.Game.720p.HDTV.x264.AC3.MVGroup.Forum.mkv with title: 2001-2011 - PBS.Frontline.The.Card.Game.720p.HDTV.x264.AC3.MVGroup.Forum
# 23:51:24 - Upload successful! Video ID: 0uRzkK3J4z0
# 23:51:24 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2001-2011\PBS.Frontline.The.Madoff.Affair.720p.HDTV.x264.AC3.MVGroup.org.mkv with title: 2001-2011 - PBS.Frontline.The.Madoff.Affair.720p.HDTV.x264.AC3.MVGroup.org
# 23:57:40 - Upload successful! Video ID: kMvT3Zn3pZw
# 23:57:40 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2001-2011\PBS.Frontline.The.Spill.PDTV.x264.AAC.MVGroup.Forum.mkv with title: 2001-2011 - PBS.Frontline.The.Spill.PDTV.x264.AAC.MVGroup.Forum
# 00:02:07 - Upload successful! Video ID: 23LRsAsycXc
# 00:02:07 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2001-2011\PBS.Frontline[2008]Growing.Up.Online.avi with title: 2001-2011 - PBS.Frontline[2008]Growing.Up.Online
# 00:04:59 - Upload successful! Video ID: wCvwEyrZ0yA
# 00:04:59 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2001-2011\pbs_frontline_(oct_2004)_rumsfelds_war_(divx_1h24m)_conres.avi with title: 2001-2011 - pbs_frontline_(oct_2004)_rumsfelds_war_(divx_1h24m)_conres
# 00:07:31 - Upload successful! Video ID: Nmi1Cz7mARc
# 00:07:31 - Processing subfolder: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2012
# 00:07:31 - Found 10 files to process in //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2012.
# 00:07:31 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2012\Frontline.S31E05.Poor.Kds.480p.x264-mSD.mkv with title: 2012 - Frontline.S31E05.Poor.Kds.480p.x264-mSD
# 00:09:00 - Upload successful! Video ID: mNmMPDvvAOk
# 00:09:00 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2012\PBS.Frontline.2012.Alaska.Gold.480p.x264.AAC.MVGroup.org.mp4 with title: 2012 - PBS.Frontline.2012.Alaska.Gold.480p.x264.AAC.MVGroup.org
# 00:11:52 - Upload successful! Video ID: afmjLEWc_-Y
# 00:11:52 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2012\PBS.Frontline.2012.Big.Sky.Big.Money.480p.x264.AAC.MVGroup.org.mp4 with title: 2012 - PBS.Frontline.2012.Big.Sky.Big.Money.480p.x264.AAC.MVGroup.org
# 00:14:20 - Upload successful! Video ID: 6ZwALRlBUOo
# 00:14:20 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2012\PBS.Frontline.2012.Cell.Tower.Deaths.and.Six.Billion.Dollar.Bet.720p.HDTV.x264.AAC.MVGroup.org.mp4 with title: 2012 - PBS.Frontline.2012.Cell.Tower.Deaths.and.Six.Billion.Dollar.Bet.720p.HDTV.x264.AAC.MVGroup.or
# 00:18:58 - Upload successful! Video ID: BBI4J0mVNPQ
# 00:18:58 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2012\PBS.Frontline.2012.Climate.of.Doubt.480p.x264.AAC.MVGroup.Forum.mkv with title: 2012 - PBS.Frontline.2012.Climate.of.Doubt.480p.x264.AAC.MVGroup.Forum
# 00:21:22 - Upload successful! Video ID: 45J7CqHXl7Q
# 00:21:22 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2012\PBS.Frontline.2012.Money.Power.and.Wall.Street.1of2.720p.HDTV.x264.AAC.MVGroup.org.mp4 with title: 2012 - PBS.Frontline.2012.Money.Power.and.Wall.Street.1of2.720p.HDTV.x264.AAC.MVGroup.org
# 00:31:19 - Upload successful! Video ID: EVzg2MiAbt8
# 00:31:19 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2012\PBS.Frontline.2012.Money.Power.and.Wall.Street.2of2.720p.HDTV.x264.AAC.MVGroup.org.mp4 with title: 2012 - PBS.Frontline.2012.Money.Power.and.Wall.Street.2of2.720p.HDTV.x264.AAC.MVGroup.org
# 00:41:19 - Upload successful! Video ID: lLXUM1ekDT0
# 00:41:19 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2012\PBS.Frontline.2012.The.Real.CSI.720p.x264.AAC.MVGroup.org.mp4 with title: 2012 - PBS.Frontline.2012.The.Real.CSI.720p.x264.AAC.MVGroup.org
# 00:45:14 - Upload successful! Video ID: V-4zJzAslKQ
# 00:45:14 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2012\PBS.Frontline.2012.The.Secret.War.and.Opium.Brides.720p.HDTV.x264.AAC.MVGroup.org.mkv with title: 2012 - PBS.Frontline.2012.The.Secret.War.and.Opium.Brides.720p.HDTV.x264.AAC.MVGroup.org
# 00:50:53 - Upload successful! Video ID: 0DP0K0oD8P0
# 00:50:53 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2012\PBS.Frontline.2012.The.Suicide.Plan.720p.x264.AAC.MVGroup.org.mp4 with title: 2012 - PBS.Frontline.2012.The.Suicide.Plan.720p.x264.AAC.MVGroup.org
# 00:57:12 - Upload successful! Video ID: 3k_gNsdMk6M
# 00:57:12 - Processing subfolder: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2013
# 00:57:12 - Found 15 files to process in //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2013.
# 00:57:12 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2013\PBS.Frontline.2013.A.Death.in.St.Augustine.720p.x264.AAC.MVGroup.org.mp4 with title: 2013 - PBS.Frontline.2013.A.Death.in.St.Augustine.720p.x264.AAC.MVGroup.org
# 01:01:33 - Upload successful! Video ID: Ig9AK0iZnyY
# 01:01:33 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2013\PBS.Frontline.2013.Cliffhanger.540p.x264.AAC.MVGroup.org.mp4 with title: 2013 - PBS.Frontline.2013.Cliffhanger.540p.x264.AAC.MVGroup.org
# 01:04:03 - Upload successful! Video ID: 9cOwlBxjAT0
# 01:04:03 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2013\PBS.Frontline.2013.Egypt.in.Crisis.720p.x264.AAC.MVGroup.org.mp4 with title: 2013 - PBS.Frontline.2013.Egypt.in.Crisis.720p.x264.AAC.MVGroup.org
# 01:10:42 - Upload successful! Video ID: rDI6Gv0i-sU
# 01:10:42 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2013\PBS.Frontline.2013.Hunting.the.Nightmare.Bacteria.720p.x264.AAC.MVGroup.org.mp4 with title: 2013 - PBS.Frontline.2013.Hunting.the.Nightmare.Bacteria.720p.x264.AAC.MVGroup.org
# 01:15:45 - Upload successful! Video ID: 7xJDghBYmIc
# 01:15:45 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2013\PBS.Frontline.2013.Inside.Obamas.Presidency.480p.x264.AAC.MVGroup.org.mp4 with title: 2013 - PBS.Frontline.2013.Inside.Obamas.Presidency.480p.x264.AAC.MVGroup.org
# 01:17:48 - Upload successful! Video ID: dD41pMne3UU
# 01:17:48 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2013\PBS.Frontline.2013.League.of.Denial.720p.x264.AAC.MVGroup.org.mp4 with title: 2013 - PBS.Frontline.2013.League.of.Denial.720p.x264.AAC.MVGroup.org
# 01:27:16 - Upload successful! Video ID: Rl7W_C6OKJ0
# 01:27:16 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2013\PBS.Frontline.2013.Raising.Adam.Lanza.540p.x264.AAC.MVGroup.org.mp4 with title: 2013 - PBS.Frontline.2013.Raising.Adam.Lanza.540p.x264.AAC.MVGroup.org
# 01:30:57 - Upload successful! Video ID: iOGcRSFccPw
# 01:30:57 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2013\PBS.Frontline.2013.Rape.in.the.Fields.720p.x264.AAC.MVGroup.org.mp4 with title: 2013 - PBS.Frontline.2013.Rape.in.the.Fields.720p.x264.AAC.MVGroup.org
# 01:36:01 - Upload successful! Video ID: h9pAa4rrsu0
# 01:36:01 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2013\PBS.Frontline.2013.Syria.Behind.the.Lines.720p.HDTV.x264.AAC.MVGroup.org.mp4 with title: 2013 - PBS.Frontline.2013.Syria.Behind.the.Lines.720p.HDTV.x264.AAC.MVGroup.org
# 01:41:26 - Upload successful! Video ID: sySyZhh6bKk
# 01:41:26 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2013\PBS.Frontline.2013.The.Education.of.Michelle.Rhee.480p.x264.AAC.MVGroup.org.mp4 with title: 2013 - PBS.Frontline.2013.The.Education.of.Michelle.Rhee.480p.x264.AAC.MVGroup.org
# 01:44:29 - Upload successful! Video ID: WlO8O4_0SYM
# 01:44:29 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2013\PBS.Frontline.2013.The.Retirement.Gamble.720p.x264.AAC.MVGroup.org.mp4 with title: 2013 - PBS.Frontline.2013.The.Retirement.Gamble.720p.x264.AAC.MVGroup.org
# 01:49:22 - Upload successful! Video ID: zs7TGPsV7nk
# 01:49:22 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2013\PBS.Frontline.2013.The.Untouchables.540p.x264.AAC.MVGroup.org.mp4 with title: 2013 - PBS.Frontline.2013.The.Untouchables.540p.x264.AAC.MVGroup.org
# 01:52:10 - Upload successful! Video ID: XM-2w-m7JcI
# 01:52:10 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2013\PBS.Frontline.2013.Top.Secret.America.911.to.the.Boston.Bombings.720p.x264.AAC.MVGroup.org.mp4 with title: 2013 - PBS.Frontline.2013.Top.Secret.America.911.to.the.Boston.Bombings.720p.x264.AAC.MVGroup.org
# 01:56:48 - Upload successful! Video ID: hKBKmrfD0PM
# 01:56:48 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2013\PBS.Frontline.2013.Two.American.Families.720p.x264.AAC.MVGroup.org.mp4 with title: 2013 - PBS.Frontline.2013.Two.American.Families.720p.x264.AAC.MVGroup.org
# 02:06:27 - Upload successful! Video ID: 0YaDu_bPk20
# 02:06:27 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2013\PBS.Frontline.2013.Who.Was.Lee.Harvey.Oswald.720p.x264.AAC.MVGroup.org.mp4 with title: 2013 - PBS.Frontline.2013.Who.Was.Lee.Harvey.Oswald.720p.x264.AAC.MVGroup.org
# 02:26:22 - Upload successful! Video ID: 2kTv2D1s8cg
# 02:26:22 - Processing subfolder: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2014
# 02:26:22 - Found 22 files to process in //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2014.
# 02:26:22 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2014\frontline.s32e02.secret.state.of.north.korea.720p.hdtv.x264-w4f.mkv with title: 2014 - frontline.s32e02.secret.state.of.north.korea.720p.hdtv.x264-w4f
# 02:31:01 - Upload successful! Video ID: h7Wp5Qx9Lzw
# 02:31:01 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2014\Frontline.S32E02.Secret.State.of.North.Korea.XviD-AFG.avi with title: 2014 - Frontline.S32E02.Secret.State.of.North.Korea.XviD-AFG
# 02:33:48 - Upload successful! Video ID: Pxf5v7x4J-I
# 02:33:48 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2014\Frontline.S32E14.Ebola.Outbreak-Hunting.Boko.Haram.480p.HDTV.x264-mSD.mkv with title: 2014 - Frontline.S32E14.Ebola.Outbreak-Hunting.Boko.Haram.480p.HDTV.x264-mSD
# 02:35:41 - Upload successful! Video ID: RvbOntSDh1Y
# 02:35:41 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2014\Frontline.S32E16.The.Rise.of.ISIS.480p.HDTV.x264-mSD.mkv with title: 2014 - Frontline.S32E16.The.Rise.of.ISIS.480p.HDTV.x264-mSD
# 02:37:38 - Upload successful! Video ID: FvFcuZ-wwuc
# 02:37:38 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2014\PBS FrontLine Ebola Outbreak Hunting Boko Haram 360p.mp4 with title: 2014 - PBS FrontLine Ebola Outbreak Hunting Boko Haram 360p
# 02:38:56 - Upload successful! Video ID: OCtNr8Sapis
# 02:38:56 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2014\PBS.Frontline.2014.E01.To.Catch.a.Trader.720p.HDTV.x264.AAC.MVGroup.org.mp4 with title: 2014 - PBS.Frontline.2014.E01.To.Catch.a.Trader.720p.HDTV.x264.AAC.MVGroup.org
# 02:42:52 - Upload successful! Video ID: B9ulNttS8Gk
# 02:42:52 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2014\PBS.Frontline.2014.E02.Secret.State.of.North.Korea.480p.WEBRip.mp4 with title: 2014 - PBS.Frontline.2014.E02.Secret.State.of.North.Korea.480p.WEBRip
# 02:48:53 - Upload successful! Video ID: kc_uWkuq1Wo
# 02:48:53 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2014\PBS.Frontline.2014.E03.Syrias.Second.Front.And.Children.of.Aleppo.720p.HDTV.x264.MVGroup.org.mp4 with title: 2014 - PBS.Frontline.2014.E03.Syrias.Second.Front.And.Children.of.Aleppo.720p.HDTV.x264.MVGroup.org
# 02:55:01 - Upload successful! Video ID: iap6iB5T5PE
# 02:55:01 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2014\PBS.Frontline.2014.E04.Generation.Like.480p.x264-mSD.mkv with title: 2014 - PBS.Frontline.2014.E04.Generation.Like.480p.x264-mSD
# 02:56:45 - Upload successful! Video ID: 9S2vllBpW7A
# 02:56:45 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2014\PBS.Frontline.2014.E04.Generation.Like.720p.HDTV.x264.MVGroup.org.mp4 with title: 2014 - PBS.Frontline.2014.E04.Generation.Like.720p.HDTV.x264.MVGroup.org
# 03:01:56 - Upload successful! Video ID: OkSCb9yThu0
# 03:01:56 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2014\PBS.Frontline.2014.E05.Secrets.of.The.Vatican.720p.HDTV.x264.MVGroup.org.mp4 with title: 2014 - PBS.Frontline.2014.E05.Secrets.of.The.Vatican.720p.HDTV.x264.MVGroup.org
# 03:08:46 - Upload successful! Video ID: YLdxocXrOzU
# 03:08:46 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2014\PBS.Frontline.2014.E07.Locked.Up.in.America.1of2.Solitary.Nation.720p.HDTV.x264.AAC.MVGroup.org.mp4 with title: 2014 - PBS.Frontline.2014.E07.Locked.Up.in.America.1of2.Solitary.Nation.720p.HDTV.x264.AAC.MVGroup.o
# 03:13:09 - Upload successful! Video ID: eLcyfkdTuHE
# 03:13:09 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2014\PBS.Frontline.2014.E08.Locked.Up.in.America.2of2.Prison.State.720p.HDTV.x264.AAC.MVGroup.org.mp4 with title: 2014 - PBS.Frontline.2014.E08.Locked.Up.in.America.2of2.Prison.State.720p.HDTV.x264.AAC.MVGroup.org
# 03:20:41 - Upload successful! Video ID: BZ0w_K9AL2A
# 03:20:41 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2014\PBS.Frontline.2014.E09.United.States.of.Secrets.1of2.720p.HDTV.x264.MVGroup.org.mp4 with title: 2014 - PBS.Frontline.2014.E09.United.States.of.Secrets.1of2.720p.HDTV.x264.MVGroup.org
# 03:28:50 - Upload successful! Video ID: -QVf8NOwjiA
# 03:28:50 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2014\PBS.Frontline.2014.E10.United.States.of.Secrets.2of2.720p.HDTV.x264.MVGroup.org.mkv with title: 2014 - PBS.Frontline.2014.E10.United.States.of.Secrets.2of2.720p.HDTV.x264.MVGroup.org
# 03:35:02 - Upload successful! Video ID: MFXkbIxSiyg
# 03:35:02 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2014\PBS.Frontline.2014.E11.Battle.For.Ukraine.And.Syria.Arming.The.Rebels.720p.HDTV.x264.MVGroup.org.mp4 with title: 2014 - PBS.Frontline.2014.E11.Battle.For.Ukraine.And.Syria.Arming.The.Rebels.720p.HDTV.x264.MVGroup.
# 03:41:10 - Upload successful! Video ID: frurUXMr5r0
# 03:41:10 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2014\PBS.Frontline.2014.E12.Separate.and.Unequal.720p.HDTV.x264.AAC.MVGroup.org.mp4 with title: 2014 - PBS.Frontline.2014.E12.Separate.and.Unequal.720p.HDTV.x264.AAC.MVGroup.org
# 03:44:44 - Upload successful! Video ID: plszQIOl74U
# 03:44:44 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2014\PBS.Frontline.2014.E13.Losing.Iraq.720p.HDTV.x264.AAC.MVGroup.org.mp4 with title: 2014 - PBS.Frontline.2014.E13.Losing.Iraq.720p.HDTV.x264.AAC.MVGroup.org
# 03:52:03 - Upload successful! Video ID: pDhMrHk8K6k
# 03:52:03 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2014\PBS.Frontline.2014.E15.The.Trouble.with.Antibiotics.720p.HDTV.x264.AAC.MVGroup.org.mp4 with title: 2014 - PBS.Frontline.2014.E15.The.Trouble.with.Antibiotics.720p.HDTV.x264.AAC.MVGroup.org
# 03:56:43 - Upload successful! Video ID: S71pTuZPi4o
# 03:56:43 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2014\PBS.Frontline.2014.E16.The.Rise.of.ISIS.720p.HDTV.x264-bajskorv.mkv with title: 2014 - PBS.Frontline.2014.E16.The.Rise.of.ISIS.720p.HDTV.x264-bajskorv
# 04:04:50 - Upload successful! Video ID: 8NhOedCeBsk
# 04:04:50 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2014\PBS.Frontline.2014.E17.Firestone.and.the.Warlord.720p.HDTV.x264.AAC.MVGroup.org.mp4 with title: 2014 - PBS.Frontline.2014.E17.Firestone.and.the.Warlord.720p.HDTV.x264.AAC.MVGroup.org
# 04:12:21 - Upload successful! Video ID: -rOoiifqS1I
# 04:12:21 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2014\PBS.Frontline.2014.E18.Stickup Kid.720p.mp4 with title: 2014 - PBS.Frontline.2014.E18.Stickup Kid.720p
# 04:13:44 - Upload successful! Video ID: rePhcJ_hHNg
# 04:13:44 - Processing subfolder: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2015
# 04:13:44 - Found 21 files to process in //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2015.
# 04:13:44 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2015\Frontline.S33E21.ISIS.in.Afghanistan.480p.x264-mSD.mkv with title: 2015 - Frontline.S33E21.ISIS.in.Afghanistan.480p.x264-mSD
# 04:13:45 - Encountered 403 Forbidden with reason "quotaExceeded"
# 04:13:45 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2015\Frontline.S33E21.ISIS.in.Afghanistan.480p.x264-mSD.mkv to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 04:13:45 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2015\Frontline.S33E21.ISIS.in.Afghanistan.480p.x264-mSD.mkv in 3 minutes...
# 04:16:45 - Encountered 403 Forbidden with reason "quotaExceeded"
# 04:16:45 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2015\Frontline.S33E21.ISIS.in.Afghanistan.480p.x264-mSD.mkv to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 04:16:45 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2015\Frontline.S33E21.ISIS.in.Afghanistan.480p.x264-mSD.mkv in 3 minutes...
# 04:19:45 - Encountered 403 Forbidden with reason "quotaExceeded"
# 04:19:45 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2015\Frontline.S33E21.ISIS.in.Afghanistan.480p.x264-mSD.mkv to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 04:19:45 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2015\Frontline.S33E21.ISIS.in.Afghanistan.480p.x264-mSD.mkv after 3 attempts.
# 04:19:45 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2015\Frontline.S33E21.ISIS.in.Afghanistan.480p.x264-mSD.mkv
# 04:19:45 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2015\PBS.Frontline.2015.E01.Gunned.Down.The.Power.of.the.NRA.720p.HDTV.x264.AAC.MVGroup.org.mp4 with title: 2015 - PBS.Frontline.2015.E01.Gunned.Down.The.Power.of.the.NRA.720p.HDTV.x264.AAC.MVGroup.org
# 04:19:45 - Encountered 403 Forbidden with reason "quotaExceeded"
# 04:19:45 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2015\PBS.Frontline.2015.E01.Gunned.Down.The.Power.of.the.NRA.720p.HDTV.x264.AAC.MVGroup.org.mp4 to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 04:19:45 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2015\PBS.Frontline.2015.E01.Gunned.Down.The.Power.of.the.NRA.720p.HDTV.x264.AAC.MVGroup.org.mp4 in 3 minutes...
# 04:22:45 - Encountered 403 Forbidden with reason "quotaExceeded"
# 04:22:45 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2015\PBS.Frontline.2015.E01.Gunned.Down.The.Power.of.the.NRA.720p.HDTV.x264.AAC.MVGroup.org.mp4 to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 04:22:45 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2015\PBS.Frontline.2015.E01.Gunned.Down.The.Power.of.the.NRA.720p.HDTV.x264.AAC.MVGroup.org.mp4 in 3 minutes...
# 04:25:46 - Encountered 403 Forbidden with reason "quotaExceeded"
# 04:25:46 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2015\PBS.Frontline.2015.E01.Gunned.Down.The.Power.of.the.NRA.720p.HDTV.x264.AAC.MVGroup.org.mp4 to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 04:25:46 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2015\PBS.Frontline.2015.E01.Gunned.Down.The.Power.of.the.NRA.720p.HDTV.x264.AAC.MVGroup.org.mp4 after 3 attempts.
# 04:25:46 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2015\PBS.Frontline.2015.E01.Gunned.Down.The.Power.of.the.NRA.720p.HDTV.x264.AAC.MVGroup.org.mp4
# 04:25:46 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2015\PBS.Frontline.2015.E02.Putins.Way.720p.HDTV.x264.AAC.MVGroup.org.mp4 with title: 2015 - PBS.Frontline.2015.E02.Putins.Way.720p.HDTV.x264.AAC.MVGroup.org
# 04:25:46 - Encountered 403 Forbidden with reason "quotaExceeded"
# 04:25:46 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2015\PBS.Frontline.2015.E02.Putins.Way.720p.HDTV.x264.AAC.MVGroup.org.mp4 to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 04:25:46 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2015\PBS.Frontline.2015.E02.Putins.Way.720p.HDTV.x264.AAC.MVGroup.org.mp4 in 3 minutes...
# 04:28:46 - Encountered 403 Forbidden with reason "quotaExceeded"
# 04:28:46 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2015\PBS.Frontline.2015.E02.Putins.Way.720p.HDTV.x264.AAC.MVGroup.org.mp4 to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 04:28:46 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2015\PBS.Frontline.2015.E02.Putins.Way.720p.HDTV.x264.AAC.MVGroup.org.mp4 in 3 minutes...
# 04:31:46 - Encountered 403 Forbidden with reason "quotaExceeded"
# 04:31:46 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2015\PBS.Frontline.2015.E02.Putins.Way.720p.HDTV.x264.AAC.MVGroup.org.mp4 to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 04:31:46 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2015\PBS.Frontline.2015.E02.Putins.Way.720p.HDTV.x264.AAC.MVGroup.org.mp4 after 3 attempts.
# 04:31:46 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2015\PBS.Frontline.2015.E02.Putins.Way.720p.HDTV.x264.AAC.MVGroup.org.mp4
# 04:31:46 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2015\PBS.Frontline.2015.E03.Being.Mortal.720p.HDTV.x264.AAC.MVGroup.org.mp4 with title: 2015 - PBS.Frontline.2015.E03.Being.Mortal.720p.HDTV.x264.AAC.MVGroup.org
# 04:31:46 - Encountered 403 Forbidden with reason "quotaExceeded"
# 04:31:46 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2015\PBS.Frontline.2015.E03.Being.Mortal.720p.HDTV.x264.AAC.MVGroup.org.mp4 to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 04:31:46 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2015\PBS.Frontline.2015.E03.Being.Mortal.720p.HDTV.x264.AAC.MVGroup.org.mp4 in 3 minutes...
# 04:34:46 - Encountered 403 Forbidden with reason "quotaExceeded"
# 04:34:46 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2015\PBS.Frontline.2015.E03.Being.Mortal.720p.HDTV.x264.AAC.MVGroup.org.mp4 to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 04:34:46 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2015\PBS.Frontline.2015.E03.Being.Mortal.720p.HDTV.x264.AAC.MVGroup.org.mp4 in 3 minutes...
# 04:37:47 - Encountered 403 Forbidden with reason "quotaExceeded"
# 04:37:47 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2015\PBS.Frontline.2015.E03.Being.Mortal.720p.HDTV.x264.AAC.MVGroup.org.mp4 to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 04:37:47 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2015\PBS.Frontline.2015.E03.Being.Mortal.720p.HDTV.x264.AAC.MVGroup.org.mp4 after 3 attempts.
# 04:37:47 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2015\PBS.Frontline.2015.E03.Being.Mortal.720p.HDTV.x264.AAC.MVGroup.org.mp4
# 04:37:47 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2015\PBS.Frontline.2015.E04.The.Vaccine.War.720p.HDTV.x264.AAC.MVGroup.org.mp4 with title: 2015 - PBS.Frontline.2015.E04.The.Vaccine.War.720p.HDTV.x264.AAC.MVGroup.org
# 04:37:47 - Encountered 403 Forbidden with reason "quotaExceeded"
# 04:37:47 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2015\PBS.Frontline.2015.E04.The.Vaccine.War.720p.HDTV.x264.AAC.MVGroup.org.mp4 to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 04:37:47 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2015\PBS.Frontline.2015.E04.The.Vaccine.War.720p.HDTV.x264.AAC.MVGroup.org.mp4 in 3 minutes...
# 04:40:47 - Encountered 403 Forbidden with reason "quotaExceeded"
# 04:40:47 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2015\PBS.Frontline.2015.E04.The.Vaccine.War.720p.HDTV.x264.AAC.MVGroup.org.mp4 to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 04:40:47 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2015\PBS.Frontline.2015.E04.The.Vaccine.War.720p.HDTV.x264.AAC.MVGroup.org.mp4 in 3 minutes...
# 04:43:47 - Encountered 403 Forbidden with reason "quotaExceeded"
# ...
# 07:50:01 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.E12.The.Choice.2016.HDTV.x264.mkv after 3 attempts.
# 07:50:01 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.E12.The.Choice.2016.HDTV.x264.mkv
# 07:50:01 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.E13.Confronting.ISIS.480p.x264-mSD.mkv with title: 2016 - PBS.Frontline.2016.E13.Confronting.ISIS.480p.x264-mSD
# 07:50:01 - Encountered 403 Forbidden with reason "quotaExceeded"
# 07:50:01 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.E13.Confronting.ISIS.480p.x264-mSD.mkv to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 07:50:01 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.E13.Confronting.ISIS.480p.x264-mSD.mkv in 3 minutes...
# 07:53:01 - Encountered 403 Forbidden with reason "quotaExceeded"
# 07:53:01 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.E13.Confronting.ISIS.480p.x264-mSD.mkv to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 07:53:01 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.E13.Confronting.ISIS.480p.x264-mSD.mkv in 3 minutes...
# 07:56:01 - Encountered 403 Forbidden with reason "quotaExceeded"
# 07:56:01 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.E13.Confronting.ISIS.480p.x264-mSD.mkv to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 07:56:01 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.E13.Confronting.ISIS.480p.x264-mSD.mkv after 3 attempts.
# 07:56:01 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.E13.Confronting.ISIS.480p.x264-mSD.mkv
# 07:56:01 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.E14.Terror.In.Europe.480p.x264-mSD.mkv with title: 2016 - PBS.Frontline.2016.E14.Terror.In.Europe.480p.x264-mSD
# 07:56:01 - Encountered 403 Forbidden with reason "quotaExceeded"
# 07:56:01 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.E14.Terror.In.Europe.480p.x264-mSD.mkv to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 07:56:01 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.E14.Terror.In.Europe.480p.x264-mSD.mkv in 3 minutes...
# 07:59:01 - Encountered 403 Forbidden with reason "quotaExceeded"
# 07:59:01 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.E14.Terror.In.Europe.480p.x264-mSD.mkv to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 07:59:01 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.E14.Terror.In.Europe.480p.x264-mSD.mkv in 3 minutes...
# 08:02:01 - Encountered 403 Forbidden with reason "quotaExceeded"
# 08:02:01 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.E14.Terror.In.Europe.480p.x264-mSD.mkv to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 08:02:01 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.E14.Terror.In.Europe.480p.x264-mSD.mkv after 3 attempts.
# 08:02:01 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.E14.Terror.In.Europe.480p.x264-mSD.mkv
# 08:02:01 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.E15.Exodus.480p.HDTV.x264.RmTeam.mkv with title: 2016 - PBS.Frontline.2016.E15.Exodus.480p.HDTV.x264.RmTeam
# 08:02:02 - Encountered 403 Forbidden with reason "quotaExceeded"
# 08:02:02 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.E15.Exodus.480p.HDTV.x264.RmTeam.mkv to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 08:02:02 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.E15.Exodus.480p.HDTV.x264.RmTeam.mkv in 3 minutes...
# 08:05:02 - Encountered 403 Forbidden with reason "quotaExceeded"
# 08:05:02 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.E15.Exodus.480p.HDTV.x264.RmTeam.mkv to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 08:05:02 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.E15.Exodus.480p.HDTV.x264.RmTeam.mkv in 3 minutes...
# 08:08:02 - Encountered 403 Forbidden with reason "quotaExceeded"
# 08:08:02 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.E15.Exodus.480p.HDTV.x264.RmTeam.mkv to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 08:08:02 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.E15.Exodus.480p.HDTV.x264.RmTeam.mkv after 3 attempts.
# 08:08:02 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.E15.Exodus.480p.HDTV.x264.RmTeam.mkv
# 08:08:02 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.E15.Exodus.720p.HEVC.x265-MeGusta.mkv with title: 2016 - PBS.Frontline.2016.E15.Exodus.720p.HEVC.x265-MeGusta
# 08:08:02 - Encountered 403 Forbidden with reason "quotaExceeded"
# 08:08:02 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.E15.Exodus.720p.HEVC.x265-MeGusta.mkv to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 08:08:02 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.E15.Exodus.720p.HEVC.x265-MeGusta.mkv in 3 minutes...
# 08:11:02 - Encountered 403 Forbidden with reason "quotaExceeded"
# 08:11:02 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.E15.Exodus.720p.HEVC.x265-MeGusta.mkv to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 08:11:02 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.E15.Exodus.720p.HEVC.x265-MeGusta.mkv in 3 minutes...
# 08:14:02 - Encountered 403 Forbidden with reason "quotaExceeded"
# 08:14:02 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.E15.Exodus.720p.HEVC.x265-MeGusta.mkv to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 08:14:02 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.E15.Exodus.720p.HEVC.x265-MeGusta.mkv after 3 attempts.
# 08:14:02 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.E15.Exodus.720p.HEVC.x265-MeGusta.mkv
# 08:14:02 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.Supplements.and.Safety.720p.HDTV.x264.AAC.MVGroup.org.mkv with title: 2016 - PBS.Frontline.2016.Supplements.and.Safety.720p.HDTV.x264.AAC.MVGroup.org
# 08:14:03 - Encountered 403 Forbidden with reason "quotaExceeded"
# 08:14:03 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.Supplements.and.Safety.720p.HDTV.x264.AAC.MVGroup.org.mkv to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 08:14:03 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.Supplements.and.Safety.720p.HDTV.x264.AAC.MVGroup.org.mkv in 3 minutes...
# 08:17:03 - Encountered 403 Forbidden with reason "quotaExceeded"
# 08:17:03 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.Supplements.and.Safety.720p.HDTV.x264.AAC.MVGroup.org.mkv to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 08:17:03 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.Supplements.and.Safety.720p.HDTV.x264.AAC.MVGroup.org.mkv in 3 minutes...
# 08:20:03 - Encountered 403 Forbidden with reason "quotaExceeded"
# 08:20:03 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.Supplements.and.Safety.720p.HDTV.x264.AAC.MVGroup.org.mkv to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 08:20:03 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.Supplements.and.Safety.720p.HDTV.x264.AAC.MVGroup.org.mkv after 3 attempts.
# 08:20:03 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/a/Docs/Frontline\2016\PBS.Frontline.2016.Supplements.and.Safety.720p.HDTV.x264.AAC.MVGroup.org.mkv
# 08:20:03 - All subfolders processed.
