# %%
import os
import sys
import glob
import logging
from datetime import datetime
from pathlib import Path
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import tkinter as tk
from tkinter import filedialog
from google_auth_oauthlib.flow import InstalledAppFlow
from google.oauth2.credentials import Credentials
from google.auth.transport.requests import Request
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload
import time

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(message)s',
    datefmt='%H:%M:%S',
    handlers=[
        logging.FileHandler('upload_all.log', encoding='utf-8'),
        logging.StreamHandler()
    ]
)

TOKEN_FILE = "token.json"
SCOPES = ["https://www.googleapis.com/auth/youtube.upload"]

os.environ['OAUTHLIB_INSECURE_TRANSPORT'] = '1'
os.environ['PYTHONHTTPSVERIFY'] = '0'

def get_authenticated_service(client_secrets_file: str):
    creds = None
    if os.path.exists(TOKEN_FILE):
        creds = Credentials.from_authorized_user_file(TOKEN_FILE, SCOPES)
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(client_secrets_file, SCOPES)
            creds = flow.run_local_server(port=0)
        with open(TOKEN_FILE, 'w') as token:
            token.write(creds.to_json())
    return build('youtube', 'v3', credentials=creds)

def upload_to_youtube(youtube, video_path: str, title: str, description: str = "Uploaded by script"):
    MAX_RETRIES = 3
    RETRY_DELAY_SECONDS = 180  # 3 minutes
    for attempt in range(1, MAX_RETRIES + 1):
        try:
            body = {
                'snippet': {
                    'title': title,
                    'description': description,
                    'tags': ['tutorial', 'education']
                },
                'status': {
                    'privacyStatus': 'unlisted',
                    'selfDeclaredMadeForKids': False
                }
            }
            insert_request = youtube.videos().insert(
                part=','.join(body.keys()),
                body=body,
                media_body=MediaFileUpload(video_path, chunksize=-1, resumable=True)
            )
            response = None
            while response is None:
                status, response = insert_request.next_chunk()
                if status:
                    logging.info(f"Upload {int(status.progress() * 100)}% complete for {video_path}")
            return response['id']
        except Exception as e:
            logging.error(f"Error uploading {video_path} to YouTube (attempt {attempt}): {str(e)}")
            if attempt < MAX_RETRIES:
                logging.info(f"Retrying upload for {video_path} in {RETRY_DELAY_SECONDS // 60} minutes...")
                time.sleep(RETRY_DELAY_SECONDS)
            else:
                logging.error(f"Upload failed for {video_path} after {MAX_RETRIES} attempts.")
                return None

def select_folder_dialog(title="Select folder"):
    """Open a folder selection dialog and return the selected path."""
    try:
        root = tk.Tk()
        root.withdraw()
        root.update_idletasks()
        width = root.winfo_screenwidth()
        height = root.winfo_screenheight()
        x = (width - 400) // 2
        y = (height - 300) // 2
        root.geometry(f'400x300+{x}+{y}')
        folder_path = filedialog.askdirectory(
            title=title,
            mustexist=True
        )
        root.destroy()
        return folder_path
    except Exception as e:
        logging.error(f"Error in folder selection: {str(e)}")
        return None

def process_folder(youtube, input_folder):
    folder_name = os.path.basename(input_folder)
    VIDEO_EXTENSIONS = ('.mp4', '.mkv', '.avi', '.mov', '.wmv', '.flv', '.webm')
    video_files = [os.path.join(input_folder, f) for f in os.listdir(input_folder)
                  if os.path.isfile(os.path.join(input_folder, f))
                  and f.lower().endswith(VIDEO_EXTENSIONS)
                  and not f.endswith('.txt')]
    if not video_files:
        logging.info(f"No files found in the folder: {input_folder}")
        return
    logging.info(f"Found {len(video_files)} files to process in {input_folder}.")
    video_files = [f for f in video_files if not os.path.exists(os.path.splitext(f)[0] + '.txt')]
    for video_path in video_files:
        video_name = os.path.splitext(os.path.basename(video_path))[0]
        MAX_TITLE_LENGTH = 100
        title = f"{folder_name} - {video_name}"
        if len(title) > MAX_TITLE_LENGTH:
            title = title[:MAX_TITLE_LENGTH]
        logging.info(f"Uploading: {video_path} with title: {title}")
        video_id = upload_to_youtube(youtube, video_path, title)
        if video_id:
            link_file = os.path.join(input_folder, f"{video_name}.txt")
            with open(link_file, 'w') as f:
                f.write(f"https://www.youtube.com/watch?v={video_id}\n")
            try:
                os.remove(video_path)
            except Exception as e:
                logging.error(f"Failed to delete uploaded video file: {video_path}: {str(e)}")
            logging.info(f"Upload successful! Video ID: {video_id}")
        else:
            logging.error(f"Upload failed for {video_path}")

def main():
    # Select parent folder
    parent_folder = select_folder_dialog(title="Select parent folder containing subfolders of videos to upload")
    if not parent_folder or not os.path.exists(parent_folder):
        logging.error("No folder selected or folder does not exist")
        return
    cwd = os.getcwd()
    client_secrets_file = os.path.join(cwd, "client_secret.dlc.json")
    if not os.path.exists(client_secrets_file):
        logging.error(f"Client secrets file not found at: {client_secrets_file}")
        return
    youtube = get_authenticated_service(client_secrets_file)
    logging.info("YouTube authentication complete.")
    # Find all immediate subfolders
    subfolders = [os.path.join(parent_folder, d) for d in os.listdir(parent_folder)
                  if os.path.isdir(os.path.join(parent_folder, d))]
    if not subfolders:
        logging.info("No subfolders found in the selected parent folder.")
        return
    for subfolder in subfolders:
        logging.info(f"Processing subfolder: {subfolder}")
        process_folder(youtube, subfolder)
    logging.info("All subfolders processed.")

if __name__ == "__main__":
    main()
# Out:
# 10:32:11 - file_cache is only supported with oauth2client<4.0.0
# 10:32:11 - YouTube authentication complete.
# 10:32:11 - Processing subfolder: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism/Arabs/Black Ducks\Pre Season 01
# 10:32:11 - No files found in the folder: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism/Arabs/Black Ducks\Pre Season 01
# 10:32:11 - Processing subfolder: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism/Arabs/Black Ducks\Season 01
# 10:32:11 - Found 56 files to process in //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism/Arabs/Black Ducks\Season 01.
# 10:32:11 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism/Arabs/Black Ducks\Season 01\برنامج البط الأسود - حلقة 1 - مع الملحد ألبير صابر من مصر.mp4 with title: Season 01 - برنامج البط الأسود - حلقة 1 - مع الملحد ألبير صابر من مصر
# 10:32:43 - Upload successful! Video ID: 65tSixPl9eY
# 10:32:43 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism/Arabs/Black Ducks\Season 01\برنامج البط الأسود - حلقة 10 - مع الدكتور الشبراوى.mp4 with title: Season 01 - برنامج البط الأسود - حلقة 10 - مع الدكتور الشبراوى
# 10:33:30 - Upload successful! Video ID: XIKv3RoKSdg
# 10:33:30 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism/Arabs/Black Ducks\Season 01\برنامج البط الأسود - حلقة 13 - مع المُلحد المصري عزيز سليمان.mp4 with title: Season 01 - برنامج البط الأسود - حلقة 13 - مع المُلحد المصري عزيز سليمان
# 10:33:56 - Upload successful! Video ID: j7Gh7PDHMrE
# 10:33:56 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism/Arabs/Black Ducks\Season 01\برنامج البط الأسود - حلقة 15 - مع ميلاد سليمان ج2 - عن التعليم.mp4 with title: Season 01 - برنامج البط الأسود - حلقة 15 - مع ميلاد سليمان ج2 - عن التعليم
# 10:34:40 - Upload successful! Video ID: PCrVYBcoPxE
# 10:34:40 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism/Arabs/Black Ducks\Season 01\برنامج البط الأسود - حلقة 16 - مع مروان بن سعدة من تونس.mp4 with title: Season 01 - برنامج البط الأسود - حلقة 16 - مع مروان بن سعدة من تونس
# 10:35:15 - Upload successful! Video ID: DvH6k1rNtuM
# 10:35:15 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism/Arabs/Black Ducks\Season 01\برنامج البط الأسود - حلقة 17 - مع أيمن رمزي .. بابا الإنسانية.mp4 with title: Season 01 - برنامج البط الأسود - حلقة
mp4 with title: Season 01 - برنامج البط الأسود - حلقة 59 - لماذا أنا مُلحد مع المُلحد المغربي ابو قتادة
# 10:57:34 - Upload successful! Video ID: fTx1BN3uuvY
# 10:57:34 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism/Arabs/Black Ducks\Season 01\برنامج البط الأسود - حلقة 6 - مع الملحدة الصعيدية المصرية زوزو دودو.mp4 with title: Season 01 - برنامج البط الأسود - حلقة 6 - مع الملحدة الصعيدية المصرية زوزو دودو
# 10:57:58 - Upload successful! Video ID: QVRSyfo5HjI
# 10:57:58 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism/Arabs/Black Ducks\Season 01\برنامج البط الأسود - حلقة 61 - مع الملحد المصري مجدي ( قانون إزدراء الاديان.mp4 with title: Season 01 - برنامج البط الأسود - حلقة 61 - مع الملحد المصري مجدي ( قانون إزدراء الاديان
# 10:58:12 - Upload successful! Video ID: W8_IxW0qXcs
# 10:58:12 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism/Arabs/Black Ducks\Season 01\برنامج البط الأسود - حلقة 62 - مع الملحد السوري سام ( الاخلاق والحقائق ومعنى الحياة.mp4 with title: Season 01 - برنامج البط الأسود - حلقة 62 - مع الملحد السوري سام ( الاخلاق والحقائق ومعنى الحياة
# 10:59:04 - Upload successful! Video ID: BrHaLUUqJRs
# 10:59:04 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism/Arabs/Black Ducks\Season 01\برنامج البط الأسود - حلقة 63 - مع الملحد المصري جورج ( الالحاد والملحدين في الاعلام المصري.mp4 with title: Season 01 - برنامج البط الأسود - حلقة 63 - مع الملحد المصري جورج ( الالحاد والملحدين في الاعلام المص
# 11:00:49 - Upload successful! Video ID: AGsINoMR8o0
# 11:00:49 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism/Arabs/Black Ducks\Season 01\برنامج البط الأسود - حلقة 64 - قانون إزدراء الاديان مع الملحد ميمي المصري.mp4 with title: Season 01 - برنامج البط الأسود - حلقة 64 - قانون إزدراء الاديان مع الملحد ميمي المصري
# 11:01:31 - Upload successful! Video ID: _R-0gMI1-Ig
# 11:01:31 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism/Arabs/Black Ducks\Season 01\برنامج البط الأسود - حلقة 66 - لا أله إلا العقل مع الملحد المصري أحمد صابر.mp4 with title: Season 01 - برنامج البط الأسود - حلقة 66 - لا أله إلا العقل مع الملحد المصري أحمد صابر
# 11:02:20 - Upload successful! Video ID: 05ID983Rz8s
# 11:02:20 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism/Arabs/Black Ducks\Season 01\برنامج البط الأسود - حلقة 67 - معنى الحريّة مع الملحدة العراقية جايا ج1.mp4 with title: Season 01 - برنامج البط الأسود - حلقة 67 - معنى الحريّة مع الملحدة العراقية جايا ج1
# 11:02:38 - Upload successful! Video ID: -Xy5i6_O6kU
# 11:02:38 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism/Arabs/Black Ducks\Season 01\برنامج البط الأسود - حلقة 68 - معنى الحريّة مع الملحدة العراقية جايا ج2.mp4 with title: Season 01 - برنامج البط الأسود - حلقة 68 - معنى الحريّة مع الملحدة العراقية جايا ج2
# 11:03:02 - Upload successful! Video ID: -M6EHIYokXY
# 11:03:02 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism/Arabs/Black Ducks\Season 01\برنامج البط الأسود - حلقة 69 - أصنام العقل مع الملحد المغربي حمدي هادي ( سلفي سابق.mp4 with title: Season 01 - برنامج البط الأسود - حلقة 69 - أصنام العقل مع الملحد المغربي حمدي هادي ( سلفي سابق
# 11:03:49 - Upload successful! Video ID: arfT2ARwISI
# 11:03:49 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism/Arabs/Black Ducks\Season 01\برنامج البط الأسود - حلقة 70 - الرهبان المصريين مع الملحد المصري أيمن رمزي.mp4 with title: Season 01 - برنامج البط الأسود - حلقة 70 - الرهبان المصريين مع الملحد المصري أيمن رمزي
# 11:04:22 - Upload successful! Video ID: jnWTLRgOk5s
# 11:04:22 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism/Arabs/Black Ducks\Season 01\برنامج البط الأسود - حلقة 71 - ماصايمينش مع عماد الدين حبيب و آمين بوخليق.mp4 with title: Season 01 - برنامج البط الأسود - حلقة 71 - ماصايمينش مع عماد الدين حبيب و آمين بوخليق
# 11:05:41 - Upload successful! Video ID: aTPJuLfQVzo
# 11:05:41 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism/Arabs/Black Ducks\Season 01\برنامج البط الأسود - حلقة 72 - إزدراء أديان مع عماد السمباوي (3.mp4 with title: Season 01 - برنامج البط الأسود - حلقة 72 - إزدراء أديان مع عماد السمباوي (3
# 11:06:02 - Upload successful! Video ID: a1m9vRwnzpU
# 11:06:02 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism/Arabs/Black Ducks\Season 01\برنامج البط الأسود - حلقة 73 - الجنس كإله في المجتمعات العربية مع ملحد مصري مجهول.mp4 with title: Season 01 - برنامج البط الأسود - حلقة 73 - الجنس كإله في المجتمعات العربية مع ملحد مصري مجهول
# 11:06:41 - Upload successful! Video ID: 9fSiiMxzlx4
# 11:06:41 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism/Arabs/Black Ducks\Season 01\برنامج البط الأسود - حلقة 74 - الحرية لمريم حمدي.mp4 with title: Season 01 - برنامج البط الأسود - حلقة 74 - الحرية لمريم حمدي
# 11:07:06 - Upload successful! Video ID: IH9DzDPmvPM
# 11:07:06 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism/Arabs/Black Ducks\Season 01\برنامج البط الأسود - حلقة 75 - أوروبا والمسيحية والكنيسة مع الملحد منير المغربي.mp4 with title: Season 01 - برنامج البط الأسود - حلقة 75 - أوروبا والمسيحية والكنيسة مع الملحد منير المغربي
# 11:07:50 - Upload successful! Video ID: wXcVBms8ojg
# 11:07:50 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism/Arabs/Black Ducks\Season 01\برنامج البط الأسود - حلقة 76 - مع الملحدة العراقية زينة عزيز (مسيحية سابقة .mp4 with title: Season 01 - برنامج البط الأسود - حلقة 76 - مع الملحدة العراقية زينة عزيز (مسيحية سابقة
# 11:08:38 - Upload successful! Video ID: BgCLjFgSckg
# 11:08:38 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism/Arabs/Black Ducks\Season 01\برنامج البط الأسود - حلقة 77 - مع الملحد اللبناني ريان عمّار ( مسلم شيعي سابق.mp4 with title: Season 01 - برنامج البط الأسود - حلقة 77 - مع الملحد اللبناني ريان عمّار ( مسلم شيعي سابق
# 11:10:13 - Upload successful! Video ID: 9RmdZwGqxpY
# 11:10:13 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism/Arabs/Black Ducks\Season 01\برنامج البط الأسود - فاصل ونواصل.mp4 with title: Season 01 - برنامج البط الأسود - فاصل ونواصل
# 11:10:18 - Upload successful! Video ID: T0qED15yJkM
# 11:10:18 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism/Arabs/Black Ducks\Season 01\برنامج البط الأسود - قصيدة أعلن إلحادي للملحد جان برّو من سوريا.mp4 with title: Season 01 - برنامج البط الأسود - قصيدة أعلن إلحادي للملحد جان برّو من سوريا
# 11:10:24 - Upload successful! Video ID: jnIw2q979Dw
# 11:10:24 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism/Arabs/Black Ducks\Season 01\برنامج البط الأسود - منبر للّادينيين والملحدين العرب - انتظرونا في مزيد من الحلقات قريباً.mp4 with title: Season 01 - برنامج البط الأسود - منبر للّادينيين والملحدين العرب - انتظرونا في مزيد من الحلقات قريبا
# 11:10:27 - Upload successful! Video ID: RnFHJJQ-VNY
# 11:10:27 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism/Arabs/Black Ducks\Season 01\نهاية موسم البحر الأبيض من برنامج البط الاسود - 92 - مع أول ملحدة مجاهرة من السعودية.mp4 with title: Season 01 - نهاية موسم البحر الأبيض من برنامج البط الاسود - 92 - مع أول ملحدة مجاهرة من السعودية
# 11:12:46 - Upload successful! Video ID: _CyKr2GnYjU
# 11:12:46 - Processing subfolder: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism/Arabs/Black Ducks\Season 02
# 11:12:46 - Found 2 files to process in //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism/Arabs/Black Ducks\Season 02.
# 11:12:46 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism/Arabs/Black Ducks\Season 02\بداية موسم البحر الأحمر من برنامج البط الأسود - 93 - من خَلق الكون؟ مع شريف فاروق‬ - YouTube.mp4 with title: Season 02 - بداية موسم البحر الأحمر من برنامج البط الأسود - 93 - من خَلق الكون؟ مع شريف فاروق‬ - You
# 11:15:03 - Upload successful! Video ID: 7JbK9ibJ6kg
# 11:15:03 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science/Religion And Atheism/Arabs/Black Ducks\Season 02\برنامج البط الأسود - 94 - الأزهر ( الكهنوت في الإسلام ) مع الملحد المصري شريف فاروق‬ - YouTube.mp4 with title: Season 02 - برنامج البط الأسود - 94 - الأزهر ( الكهنوت في الإسلام ) مع الملحد المصري شريف فاروق‬ - Y
# 11:16:14 - Upload successful! Video ID: TZsCLOPeus4
# 11:16:14 - All subfolders processed.
