# %%
import os
import sys
import glob
import logging
from datetime import datetime
from pathlib import Path
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import tkinter as tk
from tkinter import filedialog
from google_auth_oauthlib.flow import InstalledAppFlow
from google.oauth2.credentials import Credentials
from google.auth.transport.requests import Request
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(message)s',
    datefmt='%H:%M:%S',
    handlers=[
        logging.FileHandler('upload_all.log', encoding='utf-8'),
        logging.StreamHandler()
    ]
)

TOKEN_FILE = "token.json"
SCOPES = ["https://www.googleapis.com/auth/youtube.upload"]

os.environ['OAUTHLIB_INSECURE_TRANSPORT'] = '1'
os.environ['PYTHONHTTPSVERIFY'] = '0'

def get_authenticated_service(client_secrets_file: str):
    creds = None
    if os.path.exists(TOKEN_FILE):
        creds = Credentials.from_authorized_user_file(TOKEN_FILE, SCOPES)
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(client_secrets_file, SCOPES)
            creds = flow.run_local_server(port=0)
        with open(TOKEN_FILE, 'w') as token:
            token.write(creds.to_json())
    return build('youtube', 'v3', credentials=creds)

def upload_to_youtube(youtube, video_path: str, title: str, description: str = "Uploaded by script"):
    try:
        body = {
            'snippet': {
                'title': title,
                'description': description,
                'tags': ['tutorial', 'education']
            },
            'status': {
                'privacyStatus': 'unlisted',
                'selfDeclaredMadeForKids': False
            }
        }
        insert_request = youtube.videos().insert(
            part=','.join(body.keys()),
            body=body,
            media_body=MediaFileUpload(video_path, chunksize=-1, resumable=True)
        )
        response = None
        while response is None:
            status, response = insert_request.next_chunk()
            if status:
                logging.info(f"Upload {int(status.progress() * 100)}% complete for {video_path}")
        return response['id']
    except Exception as e:
        logging.error(f"Error uploading {video_path} to YouTube: {str(e)}")
        return None

def select_folder_dialog(title="Select folder"):
    """Open a folder selection dialog and return the selected path."""
    try:
        root = tk.Tk()
        root.withdraw()
        root.update_idletasks()
        width = root.winfo_screenwidth()
        height = root.winfo_screenheight()
        x = (width - 400) // 2
        y = (height - 300) // 2
        root.geometry(f'400x300+{x}+{y}')
        folder_path = filedialog.askdirectory(
            title=title,
            mustexist=True
        )
        root.destroy()
        return folder_path
    except Exception as e:
        logging.error(f"Error in folder selection: {str(e)}")
        return None

def process_folder(youtube, input_folder):
    folder_name = os.path.basename(input_folder)
    video_files = [os.path.join(input_folder, f) for f in os.listdir(input_folder)
                  if os.path.isfile(os.path.join(input_folder, f)) and not f.endswith('.txt')]
    if not video_files:
        logging.info(f"No files found in the folder: {input_folder}")
        return
    logging.info(f"Found {len(video_files)} files to process in {input_folder}.")
    video_files = [f for f in video_files if not os.path.exists(os.path.splitext(f)[0] + '.txt')]
    for video_path in video_files:
        video_name = os.path.splitext(os.path.basename(video_path))[0]
        MAX_TITLE_LENGTH = 100
        title = f"{folder_name} - {video_name}"
        if len(title) > MAX_TITLE_LENGTH:
            title = title[:MAX_TITLE_LENGTH]
        logging.info(f"Uploading: {video_path} with title: {title}")
        video_id = upload_to_youtube(youtube, video_path, title)
        if video_id:
            link_file = os.path.join(input_folder, f"{video_name}.txt")
            with open(link_file, 'w') as f:
                f.write(f"https://www.youtube.com/watch?v={video_id}\n")
            try:
                os.remove(video_path)
            except Exception as e:
                logging.error(f"Failed to delete uploaded video file: {video_path}: {str(e)}")
            logging.info(f"Upload successful! Video ID: {video_id}")
        else:
            logging.error(f"Upload failed for {video_path}")

def main():
    # Select parent folder
    parent_folder = select_folder_dialog(title="Select parent folder containing subfolders of videos to upload")
    if not parent_folder or not os.path.exists(parent_folder):
        logging.error("No folder selected or folder does not exist")
        return
    cwd = os.getcwd()
    client_secrets_file = os.path.join(cwd, "client_secret.dlc.json")
    if not os.path.exists(client_secrets_file):
        logging.error(f"Client secrets file not found at: {client_secrets_file}")
        return
    youtube = get_authenticated_service(client_secrets_file)
    logging.info("YouTube authentication complete.")
    # Find all immediate subfolders
    subfolders = [os.path.join(parent_folder, d) for d in os.listdir(parent_folder)
                  if os.path.isdir(os.path.join(parent_folder, d))]
    if not subfolders:
        logging.info("No subfolders found in the selected parent folder.")
        return
    for subfolder in subfolders:
        logging.info(f"Processing subfolder: {subfolder}")
        process_folder(youtube, subfolder)
    logging.info("All subfolders processed.")

if __name__ == "__main__":
    main()
# Out:
# 10:38:52 - file_cache is only supported with oauth2client<4.0.0
# 10:38:52 - YouTube authentication complete.
# 10:38:52 - Processing subfolder: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2004 - The Planets
# 10:38:52 - Found 8 files to process in //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2004 - The Planets.
# 10:38:52 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2004 - The Planets\BBC - The Planets - 1 - Different Worlds.avi with title: 2004 - The Planets - BBC - The Planets - 1 - Different Worlds
# 10:40:57 - Upload successful! Video ID: KC6ggbMeSTU
# 10:40:57 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2004 - The Planets\BBC - The Planets - 2 - Terra Firma.avi with title: 2004 - The Planets - BBC - The Planets - 2 - Terra Firma
# 10:43:01 - Upload successful! Video ID: wQ9bd6H3ZaY
# 10:43:01 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2004 - The Planets\BBC - The Planets - 3 - Giants.avi with title: 2004 - The Planets - BBC - The Planets - 3 - Giants
# 10:45:03 - Upload successful! Video ID: ZG6it_k9VZ8
# 10:45:03 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2004 - The Planets\BBC - The Planets - 4 -  Moon.avi with title: 2004 - The Planets - BBC - The Planets - 4 -  Moon
# 10:47:05 - Upload successful! Video ID: gY2NIB-U1WU
# 10:47:05 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2004 - The Planets\BBC - The Planets - 5 - Star.avi with title: 2004 - The Planets - BBC - The Planets - 5 - Star
# 10:49:07 - Upload successful! Video ID: uyRH-BwOuUg
# 10:49:07 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2004 - The Planets\BBC - The Planets - 6 - Atmosphere.avi with title: 2004 - The Planets - BBC - The Planets - 6 - Atmosphere
# 10:51:10 - Upload successful! Video ID: aF05Ad4Jxec
# 10:51:10 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2004 - The Planets\BBC - The Planets - 7 - Life Beyond the Sun.avi with title: 2004 - The Planets - BBC - The Planets - 7 - Life Beyond the Sun
# 10:53:10 - Upload successful! Video ID: tWhucrocVfo
# 10:53:10 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2004 - The Planets\BBC - The Planets - 8 - Destiny.avi with title: 2004 - The Planets - BBC - The Planets - 8 - Destiny
# 10:55:17 - Upload successful! Video ID: GvdVnCCgQAE
# 10:55:17 - Processing subfolder: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2005 - The Story of God
# 10:55:17 - Found 4 files to process in //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2005 - The Story of God.
# 10:55:17 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2005 - The Story of God\folder.jpg with title: 2005 - The Story of God - folder
# 10:55:17 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2005 - The Story of God\folder.jpg to YouTube: <HttpError 400 when requesting None returned "Media type 'image/jpeg' is not supported.". Details: "[{'message': "Media type 'image/jpeg' is not supported. ", 'domain': 'global', 'reason': 'badRequest'}]">
# 10:55:17 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2005 - The Story of God\folder.jpg
# 10:55:17 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2005 - The Story of God\The Story Of God-Episode I Of III(WTC-SWE).avi with title: 2005 - The Story of God - The Story Of God-Episode I Of III(WTC-SWE)
# 10:58:51 - Upload successful! Video ID: 5BNiRPwHNR0
# 10:58:51 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2005 - The Story of God\The Story Of God-Episode II Of III(WTC-SWE).avi with title: 2005 - The Story of God - The Story Of God-Episode II Of III(WTC-SWE)
# 11:02:25 - Upload successful! Video ID: GAgfrbnb0SM
# 11:02:25 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2005 - The Story of God\The Story Of God-Episode III Of III(WTC-SWE).avi with title: 2005 - The Story of God - The Story Of God-Episode III Of III(WTC-SWE)
# 11:06:00 - Upload successful! Video ID: -6A7oiInX4Q
# 11:06:00 - Processing subfolder: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2006 - Planet Earth
# 11:06:00 - Found 11 files to process in //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2006 - Planet Earth.
# 11:06:00 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2006 - Planet Earth\Planet.Earth.EP01.From.Pole.to.Pole.2006.720p.HDDVD.x264 [YIFY].mkv with title: 2006 - Planet Earth - Planet.Earth.EP01.From.Pole.to.Pole.2006.720p.HDDVD.x264 [YIFY]
# 11:08:13 - Upload successful! Video ID: u_ljxNHmbDM
# 11:08:13 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2006 - Planet Earth\Planet.Earth.EP02.Mountains.2006.720p.HDDVD.x264 [YIFY].mkv with title: 2006 - Planet Earth - Planet.Earth.EP02.Mountains.2006.720p.HDDVD.x264 [YIFY]
# 11:10:21 - Upload successful! Video ID: KZc6fujN04w
# 11:10:21 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2006 - Planet Earth\Planet.Earth.EP03.Fresh.Water.2006.720p.HDDVD.x264 [YIFY].mkv with title: 2006 - Planet Earth - Planet.Earth.EP03.Fresh.Water.2006.720p.HDDVD.x264 [YIFY]
# 11:12:33 - Upload successful! Video ID: PABdAK-I5WQ
# 11:12:33 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2006 - Planet Earth\Planet.Earth.EP04.Caves.2006.720p.HDDVD.x264 [YIFY].mkv with title: 2006 - Planet Earth - Planet.Earth.EP04.Caves.2006.720p.HDDVD.x264 [YIFY]
# 11:14:43 - Upload successful! Video ID: dZ0MQUBfiMo
# 11:14:43 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2006 - Planet Earth\Planet.Earth.EP05.Deserts.2006.720p.HDDVD.x264 [YIFY].mkv with title: 2006 - Planet Earth - Planet.Earth.EP05.Deserts.2006.720p.HDDVD.x264 [YIFY]
# 11:16:54 - Upload successful! Video ID: nPSVqJSXUm0
# 11:16:54 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2006 - Planet Earth\Planet.Earth.EP06.Ice.Worlds.2006.720p.HDDVD.x264 [YIFY].mkv with title: 2006 - Planet Earth - Planet.Earth.EP06.Ice.Worlds.2006.720p.HDDVD.x264 [YIFY]
# 11:19:06 - Upload successful! Video ID: Jofm5-d6S_A
# 11:19:06 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2006 - Planet Earth\Planet.Earth.EP07.Great.Plains.2006.720p.HDDVD.x264 [YIFY].mkv with title: 2006 - Planet Earth - Planet.Earth.EP07.Great.Plains.2006.720p.HDDVD.x264 [YIFY]
# 11:21:17 - Upload successful! Video ID: vN7sb2mFEaA
# 11:21:17 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2006 - Planet Earth\Planet.Earth.EP08.Jungles.2006.720p.HDDVD.x264 [YIFY].mkv with title: 2006 - Planet Earth - Planet.Earth.EP08.Jungles.2006.720p.HDDVD.x264 [YIFY]
# 11:22:08 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2006 - Planet Earth\Planet.Earth.EP08.Jungles.2006.720p.HDDVD.x264 [YIFY].mkv to YouTube: [WinError 10054] An existing connection was forcibly closed by the remote host
# 11:22:08 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2006 - Planet Earth\Planet.Earth.EP08.Jungles.2006.720p.HDDVD.x264 [YIFY].mkv
# 11:22:08 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2006 - Planet Earth\Planet.Earth.EP09.Shallow.Seas.2006.720p.HDDVD.x264 [YIFY].mkv with title: 2006 - Planet Earth - Planet.Earth.EP09.Shallow.Seas.2006.720p.HDDVD.x264 [YIFY]
# 11:22:08 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2006 - Planet Earth\Planet.Earth.EP09.Shallow.Seas.2006.720p.HDDVD.x264 [YIFY].mkv to YouTube: [WinError 10054] An existing connection was forcibly closed by the remote host
# 11:22:08 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2006 - Planet Earth\Planet.Earth.EP09.Shallow.Seas.2006.720p.HDDVD.x264 [YIFY].mkv
# 11:22:08 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2006 - Planet Earth\Planet.Earth.EP10.Seasonal.Forests.2006.720p.HDDVD.x264 [YIFY].mkv with title: 2006 - Planet Earth - Planet.Earth.EP10.Seasonal.Forests.2006.720p.HDDVD.x264 [YIFY]
# 11:24:26 - Upload successful! Video ID: PlOuT-3aoCs
# 11:24:26 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2006 - Planet Earth\Planet.Earth.EP11.Ocean.Deep.2006.720p.HDDVD.x264 [YIFY].mkv with title: 2006 - Planet Earth - Planet.Earth.EP11.Ocean.Deep.2006.720p.HDDVD.x264 [YIFY]
# 11:26:43 - Upload successful! Video ID: 3V_Q5HXdY1s
# 11:26:43 - Processing subfolder: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2006 - Planet Earth II
# 11:26:43 - Found 6 files to process in //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2006 - Planet Earth II.
# 11:26:43 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2006 - Planet Earth II\Planet.Earth.II.S01E01.Islands.720p.BrRip.2CH.x265.HEVC-PSA.mkv with title: 2006 - Planet Earth II - Planet.Earth.II.S01E01.Islands.720p.BrRip.2CH.x265.HEVC-PSA
# 11:30:43 - Upload successful! Video ID: fKJF4ozaYQk
# 11:30:43 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2006 - Planet Earth II\Planet.Earth.II.S01E02.Mountains.720p.BrRip.2CH.x265.HEVC-PSA.mkv with title: 2006 - Planet Earth II - Planet.Earth.II.S01E02.Mountains.720p.BrRip.2CH.x265.HEVC-PSA
# 11:33:47 - Upload successful! Video ID: lXQeibNX2OY
# 11:33:47 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2006 - Planet Earth II\Planet.Earth.II.S01E03.Jungles.720p.BrRip.2CH.x265.HEVC-PSA.mkv with title: 2006 - Planet Earth II - Planet.Earth.II.S01E03.Jungles.720p.BrRip.2CH.x265.HEVC-PSA
# 11:37:35 - Upload successful! Video ID: UXbEJdxhR0I
# 11:37:35 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2006 - Planet Earth II\Planet.Earth.II.S01E04.Deserts.720p.BrRip.2CH.x265.HEVC-PSA.mkv with title: 2006 - Planet Earth II - Planet.Earth.II.S01E04.Deserts.720p.BrRip.2CH.x265.HEVC-PSA
# 11:41:02 - Upload successful! Video ID: pfYdgzJt17A
# 11:41:02 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2006 - Planet Earth II\Planet.Earth.II.S01E05.Grasslands.720p.BrRip.2CH.x265.HEVC-PSA.mkv with title: 2006 - Planet Earth II - Planet.Earth.II.S01E05.Grasslands.720p.BrRip.2CH.x265.HEVC-PSA
# 11:45:16 - Upload successful! Video ID: ixs024dHfxU
# 11:45:16 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2006 - Planet Earth II\Planet.Earth.II.S01E06.Cities.720p.BrRip.2CH.x265.HEVC-PSA.mkv with title: 2006 - Planet Earth II - Planet.Earth.II.S01E06.Cities.720p.BrRip.2CH.x265.HEVC-PSA
# 11:48:11 - Upload successful! Video ID: Fuj6shflAC8
# 11:48:11 - Processing subfolder: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2007 - 20th Century Battlefields
# 11:48:11 - Found 9 files to process in //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2007 - 20th Century Battlefields.
# 11:48:11 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2007 - 20th Century Battlefields\20th Century Battlefields - 1918 Western Front.avi with title: 2007 - 20th Century Battlefields - 20th Century Battlefields - 1918 Western Front
# 11:52:32 - Upload successful! Video ID: AfxtxBD2rSw
# 11:52:32 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2007 - 20th Century Battlefields\20th Century Battlefields - 1942 Battle of Midway.avi with title: 2007 - 20th Century Battlefields - 20th Century Battlefields - 1942 Battle of Midway
# 11:56:53 - Upload successful! Video ID: _iZmldUXVh0
# 11:56:53 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2007 - 20th Century Battlefields\20th.Century.Battlefields.-.1942.Stalingrad.avi with title: 2007 - 20th Century Battlefields - 20th.Century.Battlefields.-.1942.Stalingrad
# 12:01:14 - Upload successful! Video ID: 6wrhxFI8uZ0
# 12:01:14 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2007 - 20th Century Battlefields\20th.Century.Battlefields.-.1951.Korea.avi with title: 2007 - 20th Century Battlefields - 20th.Century.Battlefields.-.1951.Korea
# 12:05:34 - Upload successful! Video ID: kQJvmrCMyLI
# 12:05:34 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2007 - 20th Century Battlefields\20th.Century.Battlefields.-.1968.Vietnam.avi with title: 2007 - 20th Century Battlefields - 20th.Century.Battlefields.-.1968.Vietnam
# 12:09:47 - Upload successful! Video ID: xWzsRxoBTqQ
# 12:09:47 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2007 - 20th Century Battlefields\20th.Century.Battlefields.-.1973.Middle.East.avi with title: 2007 - 20th Century Battlefields - 20th.Century.Battlefields.-.1973.Middle.East
# 12:13:59 - Upload successful! Video ID: hQODa4ELlFo
# 12:13:59 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2007 - 20th Century Battlefields\20th.Century.Battlefields.-.1973.Yom Kippur War.avi with title: 2007 - 20th Century Battlefields - 20th.Century.Battlefields.-.1973.Yom Kippur War
# 12:18:12 - Upload successful! Video ID: B8w_mbf_0YU
# 12:18:12 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2007 - 20th Century Battlefields\20th.Century.Battlefields.-.1982.Falklands.avi with title: 2007 - 20th Century Battlefields - 20th.Century.Battlefields.-.1982.Falklands
# 12:22:29 - Upload successful! Video ID: wVj-E4x63Rg
# 12:22:29 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2007 - 20th Century Battlefields\20th.Century.Battlefields.-.1991.Gulf.avi with title: 2007 - 20th Century Battlefields - 20th.Century.Battlefields.-.1991.Gulf
# 12:26:38 - Upload successful! Video ID: CDslAq1lHlY
# 12:26:38 - Processing subfolder: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2007 - The Truth About Food
# 12:26:38 - Found 6 files to process in //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2007 - The Truth About Food.
# 12:26:38 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2007 - The Truth About Food\BBC_The_truth_about_food_1of6.avi with title: 2007 - The Truth About Food - BBC_The_truth_about_food_1of6
# 12:30:47 - Upload successful! Video ID: Al90u_-gu48
# 12:30:47 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2007 - The Truth About Food\BBC_The_truth_about_food_2of6.avi with title: 2007 - The Truth About Food - BBC_The_truth_about_food_2of6
# 12:33:46 - Upload successful! Video ID: 7SweCl07OWA
# 12:33:46 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2007 - The Truth About Food\BBC_The_truth_about_food_3of6.avi with title: 2007 - The Truth About Food - BBC_The_truth_about_food_3of6
# 12:35:52 - Upload successful! Video ID: WYvbce_xnDk
# 12:35:52 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2007 - The Truth About Food\BBC_The_truth_about_food_4of6.avi with title: 2007 - The Truth About Food - BBC_The_truth_about_food_4of6
# 12:38:51 - Upload successful! Video ID: An0RetmhweA
# 12:38:51 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2007 - The Truth About Food\BBC_The_truth_about_food_5of6.avi with title: 2007 - The Truth About Food - BBC_The_truth_about_food_5of6
# 12:41:49 - Upload successful! Video ID: iUjNo5fdd8s
# 12:41:49 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2007 - The Truth About Food\BBC_The_truth_about_food_6of6.avi with title: 2007 - The Truth About Food - BBC_The_truth_about_food_6of6
# 12:44:47 - Upload successful! Video ID: GBWAygZwnSM
# 12:44:47 - Processing subfolder: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - A History of Christianity
# 12:44:47 - Found 6 files to process in //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - A History of Christianity.
# 12:44:47 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - A History of Christianity\BBC.A.History.of.Christianity.1of6.The.First.Christianity.HDTV.x264.AC3.MVGroup.org.mkv with title: 2009 - A History of Christianity - BBC.A.History.of.Christianity.1of6.The.First.Christianity.HDTV.x2
# 12:53:36 - Upload successful! Video ID: 6_nxxLxM2qQ
# 12:53:36 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - A History of Christianity\BBC.A.History.of.Christianity.2of6.Catholicism.The.Unpredictable.Rise.of.Rome.HDTV.x264.AC3.MVGroup.org.mkv with title: 2009 - A History of Christianity - BBC.A.History.of.Christianity.2of6.Catholicism.The.Unpredictable.
# 13:02:26 - Upload successful! Video ID: I5CBjl3YEO4
# 13:02:26 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - A History of Christianity\BBC.A.History.of.Christianity.3of6.Orthodoxy.From.Empire.To.Empire.HDTV.x264.AC3.MVGroup.org.mkv with title: 2009 - A History of Christianity - BBC.A.History.of.Christianity.3of6.Orthodoxy.From.Empire.To.Empir
# 13:11:11 - Upload successful! Video ID: hSTLOmJRHyI
# 13:11:11 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - A History of Christianity\BBC.A.History.of.Christianity.4of6.Reformation.The.Individual.Before.God.HDTV.x264.AC3.MVGroup.org.mkv with title: 2009 - A History of Christianity - BBC.A.History.of.Christianity.4of6.Reformation.The.Individual.Bef
# 13:20:00 - Upload successful! Video ID: YhrWB5mMU74
# 13:20:00 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - A History of Christianity\BBC.A.History.of.Christianity.5of6.Protestantism.The.Evangelical.Explosion.HDTV.x264.AC3.MVGroup.org.mkv with title: 2009 - A History of Christianity - BBC.A.History.of.Christianity.5of6.Protestantism.The.Evangelical.
# 13:28:45 - Upload successful! Video ID: gMtrDxjgWEo
# 13:28:45 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - A History of Christianity\BBC.A.History.of.Christianity.6of6.God.In.The.Dock.HDTV.x264.AC3.MVGroup.org.mkv with title: 2009 - A History of Christianity - BBC.A.History.of.Christianity.6of6.God.In.The.Dock.HDTV.x264.AC3.
# 13:37:33 - Upload successful! Video ID: 10U2YBIUf5I
# 13:37:33 - Processing subfolder: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - International Terrorism Since 1945
# 13:37:33 - Found 26 files to process in //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - International Terrorism Since 1945.
# 13:37:33 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - International Terrorism Since 1945\International.Terrorism.01of26.Early.Israeli.Terrorism.DVDRip.x264.AAC.MVGroup.org.mp4 with title: 2009 - International Terrorism Since 1945 - International.Terrorism.01of26.Early.Israeli.Terrorism.D
# 13:39:04 - Upload successful! Video ID: rsv5npIfreE
# 13:39:04 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - International Terrorism Since 1945\International.Terrorism.02of26.The.Al.Qaeda.Menace.DVDRip.x264.AAC.MVGroup.org.mp4 with title: 2009 - International Terrorism Since 1945 - International.Terrorism.02of26.The.Al.Qaeda.Menace.DVDRi
# 13:40:36 - Upload successful! Video ID: UhilBvMbGcY
# 13:40:36 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - International Terrorism Since 1945\International.Terrorism.03of26.The.IRA.DVDRip.x264.AAC.MVGroup.org.mp4 with title: 2009 - International Terrorism Since 1945 - International.Terrorism.03of26.The.IRA.DVDRip.x264.AAC.M
# 13:42:06 - Upload successful! Video ID: 7CY2qLiww5M
# 13:42:06 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - International Terrorism Since 1945\International.Terrorism.04of26.Fata.Hamas.DVDRip.x264.AAC.MVGroup.org.mp4 with title: 2009 - International Terrorism Since 1945 - International.Terrorism.04of26.Fata.Hamas.DVDRip.x264.AA
# 13:43:38 - Upload successful! Video ID: kKsIaktx6DU
# 13:43:38 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - International Terrorism Since 1945\International.Terrorism.05of26.PLO.DVDRip.x264.AAC.MVGroup.org.mp4 with title: 2009 - International Terrorism Since 1945 - International.Terrorism.05of26.PLO.DVDRip.x264.AAC.MVGro
# 13:45:08 - Upload successful! Video ID: EPncnqbUoeo
# 13:45:08 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - International Terrorism Since 1945\International.Terrorism.06of26.ETA.DVDRip.x264.AAC.MVGroup.org.mp4 with title: 2009 - International Terrorism Since 1945 - International.Terrorism.06of26.ETA.DVDRip.x264.AAC.MVGro
# 13:46:39 - Upload successful! Video ID: XQOgD5i7jtg
# 13:46:39 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - International Terrorism Since 1945\International.Terrorism.07of26.The.Baader.Meinhof.Gang.DVDRip.x264.AAC.MVGroup.org.mp4 with title: 2009 - International Terrorism Since 1945 - International.Terrorism.07of26.The.Baader.Meinhof.Gang.D
# 13:48:10 - Upload successful! Video ID: TP3wd-e0ySA
# 13:48:10 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - International Terrorism Since 1945\International.Terrorism.08of26.EOKA.DVDRip.x264.AAC.MVGroup.org.mp4 with title: 2009 - International Terrorism Since 1945 - International.Terrorism.08of26.EOKA.DVDRip.x264.AAC.MVGr
# 13:49:40 - Upload successful! Video ID: kUJUW53jUoA
# 13:49:40 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - International Terrorism Since 1945\International.Terrorism.09of26.Nasser.and.Egyptian.Terrorism.DVDRip.x264.AAC.MVGroup.org.mp4 with title: 2009 - International Terrorism Since 1945 - International.Terrorism.09of26.Nasser.and.Egyptian.Terro
# 13:51:11 - Upload successful! Video ID: QnR23K7CuJ8
# 13:51:11 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - International Terrorism Since 1945\International.Terrorism.10of26.Colonel.Gaddafi.and.Libya.DVDRip.x264.AAC.MVGroup.org.mp4 with title: 2009 - International Terrorism Since 1945 - International.Terrorism.10of26.Colonel.Gaddafi.and.Libya
# 13:52:41 - Upload successful! Video ID: DLhUTV0MTJo
# 13:52:41 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - International Terrorism Since 1945\International.Terrorism.11of26.The.OAS.DVDRip.x264.AAC.MVGroup.org.mp4 with title: 2009 - International Terrorism Since 1945 - International.Terrorism.11of26.The.OAS.DVDRip.x264.AAC.M
# 13:54:12 - Upload successful! Video ID: t0zAmRBgGCo
# 13:54:12 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - International Terrorism Since 1945\International.Terrorism.12of26.The.SLA.and.Patty.Hearst.DVDRip.x264.AAC.MVGroup.org.mp4 with title: 2009 - International Terrorism Since 1945 - International.Terrorism.12of26.The.SLA.and.Patty.Hearst.
# 13:55:43 - Upload successful! Video ID: S9V1cY9FEWk
# 13:55:43 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - International Terrorism Since 1945\International.Terrorism.13of26.The.Weathermen.DVDRip.x264.AAC.MVGroup.org.mp4 with title: 2009 - International Terrorism Since 1945 - International.Terrorism.13of26.The.Weathermen.DVDRip.x26
# 13:57:15 - Upload successful! Video ID: jNewVJqUUSY
# 13:57:15 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - International Terrorism Since 1945\International.Terrorism.14of26.The.Oklahoma.Bomber.DVDRip.x264.AAC.MVGroup.org.mp4 with title: 2009 - International Terrorism Since 1945 - International.Terrorism.14of26.The.Oklahoma.Bomber.DVDRi
# 13:58:45 - Upload successful! Video ID: O0HeGNfwBgI
# 13:58:45 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - International Terrorism Since 1945\International.Terrorism.15of26.The.Ku.Klux.Klan.DVDRip.x264.AAC.MVGroup.org.mp4 with title: 2009 - International Terrorism Since 1945 - International.Terrorism.15of26.The.Ku.Klux.Klan.DVDRip.x
# 14:00:17 - Upload successful! Video ID: ppULC7O-pGY
# 14:00:17 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - International Terrorism Since 1945\International.Terrorism.16of26.Japanese.Sarin.Cult.DVDRip.x264.AAC.MVGroup.org.mp4 with title: 2009 - International Terrorism Since 1945 - International.Terrorism.16of26.Japanese.Sarin.Cult.DVDRi
# 14:01:48 - Upload successful! Video ID: iwx7dabKuaI
# 14:01:48 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - International Terrorism Since 1945\International.Terrorism.17of26.The.Mahdi.Army.DVDRip.x264.AAC.MVGroup.org.mp4 with title: 2009 - International Terrorism Since 1945 - International.Terrorism.17of26.The.Mahdi.Army.DVDRip.x26
# 14:03:20 - Upload successful! Video ID: rY8y7CcAAvo
# 14:03:20 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - International Terrorism Since 1945\International.Terrorism.18of26.Che.Guevara.DVDRip.x264.AAC.MVGroup.org.mp4 with title: 2009 - International Terrorism Since 1945 - International.Terrorism.18of26.Che.Guevara.DVDRip.x264.A
# 14:04:50 - Upload successful! Video ID: G2EoYnMnSL4
# 14:04:50 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - International Terrorism Since 1945\International.Terrorism.19of26.Fidel.Castro.DVDRip.x264.AAC.MVGroup.org.mp4 with title: 2009 - International Terrorism Since 1945 - International.Terrorism.19of26.Fidel.Castro.DVDRip.x264.
# 14:06:21 - Upload successful! Video ID: s52XIbU9fRw
# 14:06:21 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - International Terrorism Since 1945\International.Terrorism.20of26.Somali.Warlords.DVDRip.x264.AAC.MVGroup.org.mp4 with title: 2009 - International Terrorism Since 1945 - International.Terrorism.20of26.Somali.Warlords.DVDRip.x2
# 14:07:52 - Upload successful! Video ID: D2EU5nbBC0w
# 14:07:52 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - International Terrorism Since 1945\International.Terrorism.21of26.The.Taliban.DVDRip.x264.AAC.MVGroup.org.mp4 with title: 2009 - International Terrorism Since 1945 - International.Terrorism.21of26.The.Taliban.DVDRip.x264.A
# 14:09:23 - Upload successful! Video ID: t-MXbGTZYyw
# 14:09:23 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - International Terrorism Since 1945\International.Terrorism.22of26.The.Tamil.Tigers.DVDRip.x264.AAC.MVGroup.org.mp4 with title: 2009 - International Terrorism Since 1945 - International.Terrorism.22of26.The.Tamil.Tigers.DVDRip.x
# 14:10:54 - Upload successful! Video ID: gSE81pAU2QA
# 14:10:54 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - International Terrorism Since 1945\International.Terrorism.23of26.Chechen.Extremism.DVDRip.x264.AAC.MVGroup.org.mp4 with title: 2009 - International Terrorism Since 1945 - International.Terrorism.23of26.Chechen.Extremism.DVDRip.
# 14:12:25 - Upload successful! Video ID: mKR3KwDG7Gs
# 14:12:25 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - International Terrorism Since 1945\International.Terrorism.24of26.The.Moluccan.Separatists.DVDRip.x264.AAC.MVGroup.org.mp4 with title: 2009 - International Terrorism Since 1945 - International.Terrorism.24of26.The.Moluccan.Separatists.
# 14:13:56 - Upload successful! Video ID: rXpv7MW7L1E
# 14:13:56 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - International Terrorism Since 1945\International.Terrorism.25of26.The.Mau.Mau.DVDRip.x264.AAC.MVGroup.org.mp4 with title: 2009 - International Terrorism Since 1945 - International.Terrorism.25of26.The.Mau.Mau.DVDRip.x264.A
# 14:13:57 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - International Terrorism Since 1945\International.Terrorism.25of26.The.Mau.Mau.DVDRip.x264.AAC.MVGroup.org.mp4 to YouTube: <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 14:13:57 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - International Terrorism Since 1945\International.Terrorism.25of26.The.Mau.Mau.DVDRip.x264.AAC.MVGroup.org.mp4
# 14:13:57 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - International Terrorism Since 1945\International.Terrorism.26of26.The.Red.Brigade.DVDRip.x264.AAC.MVGroup.org.mp4 with title: 2009 - International Terrorism Since 1945 - International.Terrorism.26of26.The.Red.Brigade.DVDRip.x2
# 14:13:57 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - International Terrorism Since 1945\International.Terrorism.26of26.The.Red.Brigade.DVDRip.x264.AAC.MVGroup.org.mp4 to YouTube: <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 14:13:57 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - International Terrorism Since 1945\International.Terrorism.26of26.The.Red.Brigade.DVDRip.x264.AAC.MVGroup.org.mp4
# 14:13:57 - Processing subfolder: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - The Incredible Human Journey
# 14:13:57 - Found 5 files to process in //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - The Incredible Human Journey.
# 14:13:57 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - The Incredible Human Journey\BBC.The.Incredible.Human.Journey.1of5.Out.of.Africa.XviD.AC3.MVGroup.org.avi with title: 2009 - The Incredible Human Journey - BBC.The.Incredible.Human.Journey.1of5.Out.of.Africa.XviD.AC3.M
# 14:13:58 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - The Incredible Human Journey\BBC.The.Incredible.Human.Journey.1of5.Out.of.Africa.XviD.AC3.MVGroup.org.avi to YouTube: <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 14:13:58 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - The Incredible Human Journey\BBC.The.Incredible.Human.Journey.1of5.Out.of.Africa.XviD.AC3.MVGroup.org.avi
# 14:13:58 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - The Incredible Human Journey\BBC.The.Incredible.Human.Journey.2of5.Asia.XviD.AC3.MVGroup.org.avi with title: 2009 - The Incredible Human Journey - BBC.The.Incredible.Human.Journey.2of5.Asia.XviD.AC3.MVGroup.or
# 14:13:58 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - The Incredible Human Journey\BBC.The.Incredible.Human.Journey.2of5.Asia.XviD.AC3.MVGroup.org.avi to YouTube: <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 14:13:58 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - The Incredible Human Journey\BBC.The.Incredible.Human.Journey.2of5.Asia.XviD.AC3.MVGroup.org.avi
# 14:13:58 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - The Incredible Human Journey\BBC.The.Incredible.Human.Journey.3of5.Europe.XviD.AC3.MVGroup.org.avi with title: 2009 - The Incredible Human Journey - BBC.The.Incredible.Human.Journey.3of5.Europe.XviD.AC3.MVGroup.
# 14:13:58 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - The Incredible Human Journey\BBC.The.Incredible.Human.Journey.3of5.Europe.XviD.AC3.MVGroup.org.avi to YouTube: <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 14:13:58 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - The Incredible Human Journey\BBC.The.Incredible.Human.Journey.3of5.Europe.XviD.AC3.MVGroup.org.avi
# 14:13:58 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - The Incredible Human Journey\BBC.The.Incredible.Human.Journey.4of5.Australia.XviD.AC3.MVGroup.org.avi with title: 2009 - The Incredible Human Journey - BBC.The.Incredible.Human.Journey.4of5.Australia.XviD.AC3.MVGro
# 14:13:59 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - The Incredible Human Journey\BBC.The.Incredible.Human.Journey.4of5.Australia.XviD.AC3.MVGroup.org.avi to YouTube: <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 14:13:59 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - The Incredible Human Journey\BBC.The.Incredible.Human.Journey.4of5.Australia.XviD.AC3.MVGroup.org.avi
# 14:13:59 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - The Incredible Human Journey\BBC.The.Incredible.Human.Journey.5of5.The.Americas.XviD.AC3.MVGroup.org.avi with title: 2009 - The Incredible Human Journey - BBC.The.Incredible.Human.Journey.5of5.The.Americas.XviD.AC3.MV
# 14:14:00 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - The Incredible Human Journey\BBC.The.Incredible.Human.Journey.5of5.The.Americas.XviD.AC3.MVGroup.org.avi to YouTube: <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 14:14:00 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2009 - The Incredible Human Journey\BBC.The.Incredible.Human.Journey.5of5.The.Americas.XviD.AC3.MVGroup.org.avi
# 14:14:00 - Processing subfolder: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2010 - Ancient Worlds
# 14:14:00 - Found 12 files to process in //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2010 - Ancient Worlds.
# 14:14:00 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2010 - Ancient Worlds\BBC.Ancient.Worlds.1of6.Come.Together.HDTV.x264.AC3.MVGroup.org.mkv with title: 2010 - Ancient Worlds - BBC.Ancient.Worlds.1of6.Come.Together.HDTV.x264.AC3.MVGroup.org
# 14:14:01 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2010 - Ancient Worlds\BBC.Ancient.Worlds.1of6.Come.Together.HDTV.x264.AC3.MVGroup.org.mkv to YouTube: <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 14:14:01 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2010 - Ancient Worlds\BBC.Ancient.Worlds.1of6.Come.Together.HDTV.x264.AC3.MVGroup.org.mkv
# 14:14:01 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2010 - Ancient Worlds\BBC.Ancient.Worlds.1of6.Come.Together.HDTV.x264.AC3.MVGroup.org.srt with title: 2010 - Ancient Worlds - BBC.Ancient.Worlds.1of6.Come.Together.HDTV.x264.AC3.MVGroup.org
# 14:14:01 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2010 - Ancient Worlds\BBC.Ancient.Worlds.1of6.Come.Together.HDTV.x264.AC3.MVGroup.org.srt to YouTube: <HttpError 400 when requesting None returned "Media type 'text/plain' is not supported.". Details: "[{'message': "Media type 'text/plain' is not supported. ", 'domain': 'global', 'reason': 'badRequest'}]">
# 14:14:01 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2010 - Ancient Worlds\BBC.Ancient.Worlds.1of6.Come.Together.HDTV.x264.AC3.MVGroup.org.srt
# 14:14:01 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2010 - Ancient Worlds\BBC.Ancient.Worlds.2of6.The.Age.of.Iron.HDTV.x264.AC3.MVGroup.org.mkv with title: 2010 - Ancient Worlds - BBC.Ancient.Worlds.2of6.The.Age.of.Iron.HDTV.x264.AC3.MVGroup.org
# 14:14:01 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2010 - Ancient Worlds\BBC.Ancient.Worlds.2of6.The.Age.of.Iron.HDTV.x264.AC3.MVGroup.org.mkv to YouTube: <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 14:14:01 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2010 - Ancient Worlds\BBC.Ancient.Worlds.2of6.The.Age.of.Iron.HDTV.x264.AC3.MVGroup.org.mkv
# 14:14:01 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2010 - Ancient Worlds\BBC.Ancient.Worlds.2of6.The.Age.of.Iron.HDTV.x264.AC3.MVGroup.org.srt with title: 2010 - Ancient Worlds - BBC.Ancient.Worlds.2of6.The.Age.of.Iron.HDTV.x264.AC3.MVGroup.org
# 14:14:02 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2010 - Ancient Worlds\BBC.Ancient.Worlds.2of6.The.Age.of.Iron.HDTV.x264.AC3.MVGroup.org.srt to YouTube: <HttpError 400 when requesting None returned "Media type 'text/plain' is not supported.". Details: "[{'message': "Media type 'text/plain' is not supported. ", 'domain': 'global', 'reason': 'badRequest'}]">
# 14:14:02 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2010 - Ancient Worlds\BBC.Ancient.Worlds.2of6.The.Age.of.Iron.HDTV.x264.AC3.MVGroup.org.srt
# 14:14:02 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2010 - Ancient Worlds\BBC.Ancient.Worlds.3of6.The.Greek.Thing.HDTV.x264.AC3.MVGroup.org.mkv with title: 2010 - Ancient Worlds - BBC.Ancient.Worlds.3of6.The.Greek.Thing.HDTV.x264.AC3.MVGroup.org
# 14:14:02 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2010 - Ancient Worlds\BBC.Ancient.Worlds.3of6.The.Greek.Thing.HDTV.x264.AC3.MVGroup.org.mkv to YouTube: <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 14:14:02 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2010 - Ancient Worlds\BBC.Ancient.Worlds.3of6.The.Greek.Thing.HDTV.x264.AC3.MVGroup.org.mkv
# 14:14:02 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2010 - Ancient Worlds\BBC.Ancient.Worlds.3of6.The.Greek.Thing.HDTV.x264.AC3.MVGroup.org.srt with title: 2010 - Ancient Worlds - BBC.Ancient.Worlds.3of6.The.Greek.Thing.HDTV.x264.AC3.MVGroup.org
# 14:14:02 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2010 - Ancient Worlds\BBC.Ancient.Worlds.3of6.The.Greek.Thing.HDTV.x264.AC3.MVGroup.org.srt to YouTube: <HttpError 400 when requesting None returned "Media type 'text/plain' is not supported.". Details: "[{'message': "Media type 'text/plain' is not supported. ", 'domain': 'global', 'reason': 'badRequest'}]">
# 14:14:02 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2010 - Ancient Worlds\BBC.Ancient.Worlds.3of6.The.Greek.Thing.HDTV.x264.AC3.MVGroup.org.srt
# 14:14:02 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2010 - Ancient Worlds\BBC.Ancient.Worlds.4of6.Return.of.the.King.HDTV.x264.AC3.MVGroup.org.mkv with title: 2010 - Ancient Worlds - BBC.Ancient.Worlds.4of6.Return.of.the.King.HDTV.x264.AC3.MVGroup.org
# 14:14:03 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2010 - Ancient Worlds\BBC.Ancient.Worlds.4of6.Return.of.the.King.HDTV.x264.AC3.MVGroup.org.mkv to YouTube: <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 14:14:03 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2010 - Ancient Worlds\BBC.Ancient.Worlds.4of6.Return.of.the.King.HDTV.x264.AC3.MVGroup.org.mkv
# 14:14:03 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2010 - Ancient Worlds\BBC.Ancient.Worlds.4of6.Return.of.the.King.HDTV.x264.AC3.MVGroup.org.srt with title: 2010 - Ancient Worlds - BBC.Ancient.Worlds.4of6.Return.of.the.King.HDTV.x264.AC3.MVGroup.org
# 14:14:03 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2010 - Ancient Worlds\BBC.Ancient.Worlds.4of6.Return.of.the.King.HDTV.x264.AC3.MVGroup.org.srt to YouTube: <HttpError 400 when requesting None returned "Media type 'text/plain' is not supported.". Details: "[{'message': "Media type 'text/plain' is not supported. ", 'domain': 'global', 'reason': 'badRequest'}]">
# 14:14:03 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2010 - Ancient Worlds\BBC.Ancient.Worlds.4of6.Return.of.the.King.HDTV.x264.AC3.MVGroup.org.srt
# 14:14:03 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2010 - Ancient Worlds\BBC.Ancient.Worlds.5of6.The.Republic.of.Virtue.HDTV.x264.AC3.MVGroup.org.mkv with title: 2010 - Ancient Worlds - BBC.Ancient.Worlds.5of6.The.Republic.of.Virtue.HDTV.x264.AC3.MVGroup.org
# 14:14:03 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2010 - Ancient Worlds\BBC.Ancient.Worlds.5of6.The.Republic.of.Virtue.HDTV.x264.AC3.MVGroup.org.mkv to YouTube: <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 14:14:03 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2010 - Ancient Worlds\BBC.Ancient.Worlds.5of6.The.Republic.of.Virtue.HDTV.x264.AC3.MVGroup.org.mkv
# 14:14:03 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2010 - Ancient Worlds\BBC.Ancient.Worlds.5of6.The.Republic.of.Virtue.HDTV.x264.AC3.MVGroup.org.srt with title: 2010 - Ancient Worlds - BBC.Ancient.Worlds.5of6.The.Republic.of.Virtue.HDTV.x264.AC3.MVGroup.org
# 14:14:04 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2010 - Ancient Worlds\BBC.Ancient.Worlds.5of6.The.Republic.of.Virtue.HDTV.x264.AC3.MVGroup.org.srt to YouTube: <HttpError 400 when requesting None returned "Media type 'text/plain' is not supported.". Details: "[{'message': "Media type 'text/plain' is not supported. ", 'domain': 'global', 'reason': 'badRequest'}]">
# 14:14:04 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2010 - Ancient Worlds\BBC.Ancient.Worlds.5of6.The.Republic.of.Virtue.HDTV.x264.AC3.MVGroup.org.srt
# 14:14:04 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\2010 - Ancient Worlds\BBC.Ancient.Worlds.6of6.City.of.Man.City.of.God.HDTV.x264.AC3.MVGroup.org.mkv with title: 2010 - Ancient Worlds - BBC.Ancient.Worlds.6of6.City.of.Man.City.of.God.HDTV.x264.AC3.MVGroup.org
# ...
# 14:14:14 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections II\14 - Bright Ideas.avi
# 14:14:14 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections II\15 - Making Waves.avi with title: Connections II - 15 - Making Waves
# 14:14:14 - Encountered 403 Forbidden with reason "quotaExceeded"
# 14:14:14 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections II\15 - Making Waves.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 14:14:14 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections II\15 - Making Waves.avi
# 14:14:14 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections II\16 - Routes .avi with title: Connections II - 16 - Routes
# 14:14:14 - Encountered 403 Forbidden with reason "quotaExceeded"
# 14:14:14 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections II\16 - Routes .avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 14:14:14 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections II\16 - Routes .avi
# 14:14:14 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections II\17 - One Word.avi with title: Connections II - 17 - One Word
# 14:14:14 - Encountered 403 Forbidden with reason "quotaExceeded"
# 14:14:14 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections II\17 - One Word.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 14:14:14 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections II\17 - One Word.avi
# 14:14:14 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections II\18 - Sign Here.avi with title: Connections II - 18 - Sign Here
# 14:14:15 - Encountered 403 Forbidden with reason "quotaExceeded"
# 14:14:15 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections II\18 - Sign Here.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 14:14:15 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections II\18 - Sign Here.avi
# 14:14:15 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections II\19 - Better Than the Real Thing.avi with title: Connections II - 19 - Better Than the Real Thing
# 14:14:15 - Encountered 403 Forbidden with reason "quotaExceeded"
# 14:14:15 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections II\19 - Better Than the Real Thing.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 14:14:15 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections II\19 - Better Than the Real Thing.avi
# 14:14:15 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections II\20 - Flexible Response.avi with title: Connections II - 20 - Flexible Response
# 14:14:15 - Encountered 403 Forbidden with reason "quotaExceeded"
# 14:14:15 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections II\20 - Flexible Response.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 14:14:15 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections II\20 - Flexible Response.avi
# 14:14:15 - Processing subfolder: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections III
# 14:14:15 - Found 10 files to process in //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections III.
# 14:14:15 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections III\01 - Feedback.avi with title: Connections III - 01 - Feedback
# 14:14:15 - Encountered 403 Forbidden with reason "quotaExceeded"
# 14:14:15 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections III\01 - Feedback.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 14:14:15 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections III\01 - Feedback.avi
# 14:14:15 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections III\02 - What's in a Name.avi with title: Connections III - 02 - What's in a Name
# 14:14:15 - Encountered 403 Forbidden with reason "quotaExceeded"
# 14:14:15 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections III\02 - What's in a Name.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 14:14:15 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections III\02 - What's in a Name.avi
# 14:14:15 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections III\03 - Drop the Apple.avi with title: Connections III - 03 - Drop the Apple
# 14:14:15 - Encountered 403 Forbidden with reason "quotaExceeded"
# 14:14:15 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections III\03 - Drop the Apple.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 14:14:15 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections III\03 - Drop the Apple.avi
# 14:14:15 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections III\04 - An Invisible Object.avi with title: Connections III - 04 - An Invisible Object
# 14:14:15 - Encountered 403 Forbidden with reason "quotaExceeded"
# 14:14:15 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections III\04 - An Invisible Object.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 14:14:15 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections III\04 - An Invisible Object.avi
# 14:14:15 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections III\05 - Life is No Picnic.avi with title: Connections III - 05 - Life is No Picnic
# 14:14:16 - Encountered 403 Forbidden with reason "quotaExceeded"
# 14:14:16 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections III\05 - Life is No Picnic.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 14:14:16 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections III\05 - Life is No Picnic.avi
# 14:14:16 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections III\06 - Elementary Stuff.avi with title: Connections III - 06 - Elementary Stuff
# 14:14:16 - Encountered 403 Forbidden with reason "quotaExceeded"
# 14:14:16 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections III\06 - Elementary Stuff.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 14:14:16 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections III\06 - Elementary Stuff.avi
# 14:14:16 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections III\07 - A Special Place.avi with title: Connections III - 07 - A Special Place
# 14:14:16 - Encountered 403 Forbidden with reason "quotaExceeded"
# 14:14:16 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections III\07 - A Special Place.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 14:14:16 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections III\07 - A Special Place.avi
# 14:14:16 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections III\08 - Fire from the Sky.avi with title: Connections III - 08 - Fire from the Sky
# 14:14:16 - Encountered 403 Forbidden with reason "quotaExceeded"
# 14:14:16 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections III\08 - Fire from the Sky.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 14:14:16 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections III\08 - Fire from the Sky.avi
# 14:14:16 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections III\09 - Hit the Water.avi with title: Connections III - 09 - Hit the Water
# 14:14:16 - Encountered 403 Forbidden with reason "quotaExceeded"
# 14:14:16 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections III\09 - Hit the Water.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 14:14:16 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections III\09 - Hit the Water.avi
# 14:14:16 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections III\10 - In Touch.avi with title: Connections III - 10 - In Touch
# 14:14:16 - Encountered 403 Forbidden with reason "quotaExceeded"
# 14:14:16 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections III\10 - In Touch.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 14:14:16 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/D/s\Connections III\10 - In Touch.avi
# 14:14:16 - All subfolders processed.
