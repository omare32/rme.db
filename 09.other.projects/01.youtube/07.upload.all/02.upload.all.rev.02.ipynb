# %%
import os
import glob
import logging
from datetime import datetime
from pathlib import Path
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
from google_auth_oauthlib.flow import InstalledAppFlow
from google.oauth2.credentials import Credentials
from google.auth.transport.requests import Request
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload
import tkinter as tk
from tkinter import filedialog

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(message)s',
    datefmt='%H:%M:%S',
    handlers=[
        logging.FileHandler('upload_all.log', encoding='utf-8'),
        logging.StreamHandler()
    ]
)

TOKEN_FILE = "token.json"
SCOPES = ["https://www.googleapis.com/auth/youtube.upload"]

os.environ['OAUTHLIB_INSECURE_TRANSPORT'] = '1'
os.environ['PYTHONHTTPSVERIFY'] = '0'

def get_authenticated_service(client_secrets_file: str):
    creds = None
    if os.path.exists(TOKEN_FILE):
        creds = Credentials.from_authorized_user_file(TOKEN_FILE, SCOPES)
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(client_secrets_file, SCOPES)
            creds = flow.run_local_server(port=0)
        with open(TOKEN_FILE, 'w') as token:
            token.write(creds.to_json())
    return build('youtube', 'v3', credentials=creds)

def upload_to_youtube(youtube, video_path: str, title: str, description: str = "Uploaded by script"):
    try:
        body = {
            'snippet': {
                'title': title,
                'description': description,
                'tags': ['tutorial', 'education']
            },
            'status': {
                'privacyStatus': 'unlisted',
                'selfDeclaredMadeForKids': False
            }
        }
        insert_request = youtube.videos().insert(
            part=','.join(body.keys()),
            body=body,
            media_body=MediaFileUpload(video_path, chunksize=-1, resumable=True)
        )
        response = None
        while response is None:
            status, response = insert_request.next_chunk()
            if status:
                logging.info(f"Upload {int(status.progress() * 100)}% complete for {video_path}")
        return response['id']
    except Exception as e:
        logging.error(f"Error uploading {video_path} to YouTube: {str(e)}")
        return None

def select_folder_dialog(title="Select the folder containing videos to upload"):
    root = tk.Tk()
    root.withdraw()
    folder_selected = filedialog.askdirectory(title=title)
    root.destroy()
    return folder_selected

def main():
    cwd = os.getcwd()
    client_secrets_file = os.path.join(cwd, "client_secret.dlc.json")
    if not os.path.exists(client_secrets_file):
        logging.error("Client secrets file not found")
        return
    youtube = get_authenticated_service(client_secrets_file)
    logging.info("YouTube authentication complete.")
    # Ask user for folder containing videos to upload
    input_folder = select_folder_dialog()
    if not input_folder or not os.path.exists(input_folder):
        logging.warning("No folder selected or path does not exist. Using current working directory.")
        input_folder = cwd
    folder_name = os.path.basename(input_folder)
    # Find all video files in the folder (no recursion)
    extensions = ("*.mp4", "*.avi", "*.mkv", "*.mov", "*.flv", "*.rmvb")
    video_files = []
    for ext in extensions:
        video_files.extend(glob.glob(os.path.join(input_folder, ext)))
    if not video_files:
        logging.info("No video files found in the folder.")
        return
    logging.info(f"Found {len(video_files)} videos to upload.")
    for video_path in video_files:
        video_name = os.path.splitext(os.path.basename(video_path))[0]
        title = f"{folder_name} - {video_name}"
        logging.info(f"Uploading: {video_path} with title: {title}")
        video_id = upload_to_youtube(youtube, video_path, title)
        if video_id:
            link_file = os.path.join(input_folder, f"{video_name}.txt")
            with open(link_file, 'w') as f:
                f.write(f"https://www.youtube.com/watch?v={video_id}\n")
            try:
                os.remove(video_path)
            except Exception as e:
                logging.error(f"Failed to delete uploaded video file: {video_path}: {str(e)}")
            logging.info(f"Upload successful! Video ID: {video_id}")
        else:
            logging.error(f"Upload failed for {video_path}")

main()
# Out:
# 10:53:05 - file_cache is only supported with oauth2client<4.0.0
# 10:53:06 - YouTube authentication complete.
# 10:53:09 - Found 128 videos to upload.
# 10:53:09 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\An Islamic History Of Europe (Bbc Documentary).avi with title: BBC Horizon - An Islamic History Of Europe (Bbc Documentary)
# 10:57:48 - Upload successful! Video ID: zHJRYE3bD9c
# 10:57:48 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Whatever Happened to the Energy Crisis.avi with title: BBC Horizon - Whatever Happened to the Energy Crisis
# 11:00:58 - Upload successful! Video ID: xxi-qxzxboQ
# 11:00:58 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Who Built Stonehenge.avi with title: BBC Horizon - Who Built Stonehenge
# 11:03:26 - Upload successful! Video ID: Ri9Xzm5euN0
# 11:03:26 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Who Wrote The Bible.avi with title: BBC Horizon - Who Wrote The Bible
# 11:07:38 - Upload successful! Video ID: jTj7LRnIeQo
# 11:07:38 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Who's Afraid of Designer Babies.avi with title: BBC Horizon - Who's Afraid of Designer Babies
# 11:09:53 - Upload successful! Video ID: IWyNsbq8GQY
# 11:09:53 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Why Democracy Taxi To The Dark Side.avi with title: BBC Horizon - Why Democracy Taxi To The Dark Side
# 11:13:58 - Upload successful! Video ID: N44-kDmRAwc
# 11:13:58 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Why Do We Talk.avi with title: BBC Horizon - Why Do We Talk
# 11:18:25 - Upload successful! Video ID: foI08Pqsm1g
# 11:18:25 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Wings Of Angels.avi with title: BBC Horizon - Wings Of Angels
# 11:22:30 - Upload successful! Video ID: epGwBEEv8ds
# 11:22:30 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Winning Gold in 2012.avi with title: BBC Horizon - Winning Gold in 2012
# 11:26:40 - Upload successful! Video ID: 64stzgo4TbQ
# 11:26:40 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Woof Horizon Guide To Dogs.avi with title: BBC Horizon - Woof Horizon Guide To Dogs
# 11:29:27 - Upload successful! Video ID: LruK-z3ky8k
# 11:29:27 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Wot U Looking At.avi with title: BBC Horizon - Wot U Looking At
# 11:33:04 - Upload successful! Video ID: wjZLR0-1eKw
# 11:33:04 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Zero G.avi with title: BBC Horizon - Zero G
# 11:35:35 - Upload successful! Video ID: qLsI6vFrrZk
# 11:35:35 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1999 - Atlantis Reborn.mkv with title: BBC Horizon - 1999 - Atlantis Reborn
# 11:39:44 - Upload successful! Video ID: 2Av7kM_l_ig
# 11:39:44 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2000 - Extreme Dinosaurs.mkv with title: BBC Horizon - 2000 - Extreme Dinosaurs
# 11:43:51 - Upload successful! Video ID: -0UJ0jSVbUc
# 11:43:51 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2001 - Cloning The First Human.mkv with title: BBC Horizon - 2001 - Cloning The First Human
# 11:48:07 - Upload successful! Video ID: sTGIE3L-JsI
# 11:48:07 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2002 - Freak Wave.mkv with title: BBC Horizon - 2002 - Freak Wave
# 11:52:12 - Upload successful! Video ID: khIVe4T6EnQ
# 11:52:12 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2008 - Allergy Planet.mkv with title: BBC Horizon - 2008 - Allergy Planet
# 11:56:43 - Upload successful! Video ID: z0IJZ0ZhIuA
# 11:56:43 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2008 - Do You Know What Time It Is.mkv with title: BBC Horizon - 2008 - Do You Know What Time It Is
# 12:00:51 - Upload successful! Video ID: J808S2v7zBE
# 12:00:51 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2008 - How To Make Better Decisions.mkv with title: BBC Horizon - 2008 - How To Make Better Decisions
# 12:04:23 - Upload successful! Video ID: vgp9gJ8NvHI
# 12:04:23 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2009 - Cannabis The Evil Weed.mkv with title: BBC Horizon - 2009 - Cannabis The Evil Weed
# 12:08:30 - Upload successful! Video ID: 90MIwmA2ZDQ
# 12:08:30 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2009 - Do I Drink Too Much.mkv with title: BBC Horizon - 2009 - Do I Drink Too Much
# 12:12:37 - Upload successful! Video ID: _3corTqvyE8
# 12:12:37 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2009 - Fix Me.mkv with title: BBC Horizon - 2009 - Fix Me
# 12:16:45 - Upload successful! Video ID: fw5rTwEKFIA
# 12:16:45 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2009 - How Long Is A Piece of String (720p).mkv with title: BBC Horizon - 2009 - How Long Is A Piece of String (720p)
# 12:26:31 - Upload successful! Video ID: hgkTagXVtzw
# 12:26:31 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2009 - How Many People Can Live on Planet Earth.mkv with title: BBC Horizon - 2009 - How Many People Can Live on Planet Earth
# 12:30:39 - Upload successful! Video ID: Mk4TQezaaqg
# 12:30:39 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2010 - Asteroids The Good the Bad and the Ugly (720p).mkv with title: BBC Horizon - 2010 - Asteroids The Good the Bad and the Ugly (720p)
# 12:40:22 - Upload successful! Video ID: zzOgkbOCk4k
# 12:40:22 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2010 - Back From The Dead (720p).mkv with title: BBC Horizon - 2010 - Back From The Dead (720p)
# 12:49:56 - Upload successful! Video ID: ExRlwWRzjmU
# 12:49:56 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2010 - Deepwater Disaster The Untold Story (720p).mkv with title: BBC Horizon - 2010 - Deepwater Disaster The Untold Story (720p)
# 12:59:44 - Upload successful! Video ID: QY0YHa_kirw
# 12:59:44 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2010 - Don't Grow Old (720p).mkv with title: BBC Horizon - 2010 - Don't Grow Old (720p)
# 13:09:58 - Upload successful! Video ID: iJn64Syf62c
# 13:09:58 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2010 - What Happened Before The Big Bang (720p).mkv with title: BBC Horizon - 2010 - What Happened Before The Big Bang (720p)
# 13:20:13 - Upload successful! Video ID: f-TNTsDSxM4
# 13:20:13 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2011 - Are We Still Evolving (720p).mkv with title: BBC Horizon - 2011 - Are We Still Evolving (720p)
# 13:30:33 - Upload successful! Video ID: 6ySLYslD76g
# 13:30:33 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2011 - Are You Good or Evil (720p).mkv with title: BBC Horizon - 2011 - Are You Good or Evil (720p)
# 13:40:41 - Upload successful! Video ID: CGiZ58ZNJLY
# 13:40:41 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2011 - Do You See What I See (720p).mkv with title: BBC Horizon - 2011 - Do You See What I See (720p)
# 13:50:50 - Upload successful! Video ID: DYKuSa3IbD4
# 13:50:50 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2011 - How To Mend A Broken Heart (720p).mkv with title: BBC Horizon - 2011 - How To Mend A Broken Heart (720p)
# 14:01:09 - Upload successful! Video ID: PRsA1UUGYhQ
# 14:01:09 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2011 - Is Nuclear Power Safe (720p).mkv with title: BBC Horizon - 2011 - Is Nuclear Power Safe (720p)
# 14:10:42 - Upload successful! Video ID: QERrD3z0cmA
# 14:10:42 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2012 - Defeating Cancer (720p).mkv with title: BBC Horizon - 2012 - Defeating Cancer (720p)
# 14:19:36 - Upload successful! Video ID: kUp_cB2GRUk
# 14:19:36 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2012 - Defeating The Superbugs (720p).mkv with title: BBC Horizon - 2012 - Defeating The Superbugs (720p)
# 14:27:14 - Upload successful! Video ID: wLnQ10oA6qQ
# 14:27:14 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2012 - Eat, Fast And Live Longer (720p).mkv with title: BBC Horizon - 2012 - Eat, Fast And Live Longer (720p)
# 14:35:41 - Upload successful! Video ID: GfLmqTdGKoo
# 14:35:41 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2012 - Global Weirding (720p).mkv with title: BBC Horizon - 2012 - Global Weirding (720p)
# 14:44:57 - Upload successful! Video ID: ykPDg6fkJ_g
# 14:44:57 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2012 - How Big Is The Universe (720p).mkv with title: BBC Horizon - 2012 - How Big Is The Universe (720p)
# 14:54:34 - Upload successful! Video ID: 4BIQVrbDmDE
# 14:54:34 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2012 - How Small Is the Universe (720p).mkv with title: BBC Horizon - 2012 - How Small Is the Universe (720p)
# 15:04:38 - Upload successful! Video ID: srgKX9whwQs
# 15:04:38 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2013 - Comet of the Century (720p).mkv with title: BBC Horizon - 2013 - Comet of the Century (720p)
# 15:10:31 - Upload successful! Video ID: hyMbWLQ-5E4
# 15:10:31 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2013 - Defeating The Hackers (720p).mkv with title: BBC Horizon - 2013 - Defeating The Hackers (720p)
# 15:18:17 - Upload successful! Video ID: G3gQsRRYtZg
# 15:18:17 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2013 - Dinosaurs The Hunt For Life (720p).mkv with title: BBC Horizon - 2013 - Dinosaurs The Hunt For Life (720p)
# 15:24:24 - Upload successful! Video ID: J8rtYvDwi7o
# 15:24:24 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2013 - Fracking The New Energy Rush (720p).mkv with title: BBC Horizon - 2013 - Fracking The New Energy Rush (720p)
# 15:31:38 - Upload successful! Video ID: gjgUM5a2BSU
# 15:31:38 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2013 - How To Avoid Mistakes In Surgery (720p).mkv with title: BBC Horizon - 2013 - How To Avoid Mistakes In Surgery (720p)
# 15:38:05 - Upload successful! Video ID: VjLg2dmoUz4
# 15:38:05 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2014 - How You Really Make Decisions (720p).mkv with title: BBC Horizon - 2014 - How You Really Make Decisions (720p)
# 15:46:51 - Upload successful! Video ID: qDYcdOZ-ddM
# 15:46:51 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2014 - Man On Mars - Mission To The Red Planet (720p).mkv with title: BBC Horizon - 2014 - Man On Mars - Mission To The Red Planet (720p)
# 15:53:20 - Upload successful! Video ID: kIyFmyqMEws
# 15:53:20 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\BBC.Horizon.2013.The.Age.of.Big.Data.720p.mkv with title: BBC Horizon - BBC.Horizon.2013.The.Age.of.Big.Data.720p
# 16:01:15 - Upload successful! Video ID: 7FFk2J5b7TA
# 16:01:15 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\BBC.Horizon.2014.Inside.the.Dark.Web.720p.mkv with title: BBC Horizon - BBC.Horizon.2014.Inside.the.Dark.Web.720p
# 16:08:55 - Upload successful! Video ID: FTrOLaQixS0
# 16:08:55 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Horizon S46E06 Where's My Robot 720p HDTV AC3 x264 -lulz.mkv with title: BBC Horizon - Horizon S46E06 Where's My Robot 720p HDTV AC3 x264 -lulz
# 16:19:08 - Upload successful! Video ID: eWrhmkUM4ec
# 16:19:08 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Horizon S48E06 720p HDTV DD2.0 x264 BoK.mkv with title: BBC Horizon - Horizon S48E06 720p HDTV DD2.0 x264 BoK
