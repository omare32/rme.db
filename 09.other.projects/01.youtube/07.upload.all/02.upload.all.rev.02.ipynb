# %%
import os
import glob
import logging
from datetime import datetime
from pathlib import Path
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
from google_auth_oauthlib.flow import InstalledAppFlow
from google.oauth2.credentials import Credentials
from google.auth.transport.requests import Request
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload
import tkinter as tk
from tkinter import filedialog

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(message)s',
    datefmt='%H:%M:%S',
    handlers=[
        logging.FileHandler('upload_all.log', encoding='utf-8'),
        logging.StreamHandler()
    ]
)

TOKEN_FILE = "token.json"
SCOPES = ["https://www.googleapis.com/auth/youtube.upload"]

os.environ['OAUTHLIB_INSECURE_TRANSPORT'] = '1'
os.environ['PYTHONHTTPSVERIFY'] = '0'

def get_authenticated_service(client_secrets_file: str):
    creds = None
    if os.path.exists(TOKEN_FILE):
        creds = Credentials.from_authorized_user_file(TOKEN_FILE, SCOPES)
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(client_secrets_file, SCOPES)
            creds = flow.run_local_server(port=0)
        with open(TOKEN_FILE, 'w') as token:
            token.write(creds.to_json())
    return build('youtube', 'v3', credentials=creds)

def upload_to_youtube(youtube, video_path: str, title: str, description: str = "Uploaded by script"):
    try:
        body = {
            'snippet': {
                'title': title,
                'description': description,
                'tags': ['tutorial', 'education']
            },
            'status': {
                'privacyStatus': 'unlisted',
                'selfDeclaredMadeForKids': False
            }
        }
        insert_request = youtube.videos().insert(
            part=','.join(body.keys()),
            body=body,
            media_body=MediaFileUpload(video_path, chunksize=-1, resumable=True)
        )
        response = None
        while response is None:
            status, response = insert_request.next_chunk()
            if status:
                logging.info(f"Upload {int(status.progress() * 100)}% complete for {video_path}")
        return response['id']
    except Exception as e:
        logging.error(f"Error uploading {video_path} to YouTube: {str(e)}")
        return None

def select_folder_dialog(title="Select the folder containing videos to upload"):
    root = tk.Tk()
    root.withdraw()
    folder_selected = filedialog.askdirectory(title=title)
    root.destroy()
    return folder_selected

def main():
    cwd = os.getcwd()
    client_secrets_file = os.path.join(cwd, "client_secret.dlc.json")
    if not os.path.exists(client_secrets_file):
        logging.error("Client secrets file not found")
        return
    youtube = get_authenticated_service(client_secrets_file)
    logging.info("YouTube authentication complete.")
    # Ask user for folder containing videos to upload
    input_folder = select_folder_dialog()
    if not input_folder or not os.path.exists(input_folder):
        logging.warning("No folder selected or path does not exist. Using current working directory.")
        input_folder = cwd
    folder_name = os.path.basename(input_folder)
    # Find all video files in the folder (no recursion)
    extensions = ("*.mp4", "*.avi", "*.mkv", "*.mov", "*.flv", "*.rmvb")
    video_files = []
    for ext in extensions:
        video_files.extend(glob.glob(os.path.join(input_folder, ext)))
    if not video_files:
        logging.info("No video files found in the folder.")
        return
    logging.info(f"Found {len(video_files)} videos to upload.")
    for video_path in video_files:
        video_name = os.path.splitext(os.path.basename(video_path))[0]
        title = f"{folder_name} - {video_name}"
        logging.info(f"Uploading: {video_path} with title: {title}")
        video_id = upload_to_youtube(youtube, video_path, title)
        if video_id:
            link_file = os.path.join(input_folder, f"{video_name}.txt")
            with open(link_file, 'w') as f:
                f.write(f"https://www.youtube.com/watch?v={video_id}\n")
            try:
                os.remove(video_path)
            except Exception as e:
                logging.error(f"Failed to delete uploaded video file: {video_path}: {str(e)}")
            logging.info(f"Upload successful! Video ID: {video_id}")
        else:
            logging.error(f"Upload failed for {video_path}")

main()
# Out:
# 10:17:21 - file_cache is only supported with oauth2client<4.0.0
# 10:17:21 - YouTube authentication complete.
# 10:17:30 - Found 421 videos to upload.
# 10:17:30 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1996 - BSE - The Invisible Enemy.avi with title: BBC Horizon - 1996 - BSE - The Invisible Enemy
# 10:20:27 - Upload successful! Video ID: UuhGSVW67xI
# 10:20:27 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1996 - Fallout From Chernobyl.avi with title: BBC Horizon - 1996 - Fallout From Chernobyl
# 10:22:30 - Upload successful! Video ID: jw7kM0HH3hI
# 10:22:30 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1996 - Fermat's Last Theorum.avi with title: BBC Horizon - 1996 - Fermat's Last Theorum
# 10:24:49 - Upload successful! Video ID: dTDWr1KfcXA
# 10:24:49 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1996 - Inside Chernobyl's Sarcophagus (Update).avi with title: BBC Horizon - 1996 - Inside Chernobyl's Sarcophagus (Update)
# 10:25:38 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1996 - Inside Chernobyl's Sarcophagus (Update).avi to YouTube: [WinError 10054] An existing connection was forcibly closed by the remote host
# 10:25:38 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1996 - Inside Chernobyl's Sarcophagus (Update).avi
# 10:25:38 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1997 - Antarctica 1of3 The Ice Lives.avi with title: BBC Horizon - 1997 - Antarctica 1of3 The Ice Lives
# 10:25:38 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1997 - Antarctica 1of3 The Ice Lives.avi to YouTube: [WinError 10054] An existing connection was forcibly closed by the remote host
# 10:25:38 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1997 - Antarctica 1of3 The Ice Lives.avi
# 10:25:38 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1997 - Antarctica 2of3 The Ice Forms.avi with title: BBC Horizon - 1997 - Antarctica 2of3 The Ice Forms
# 10:26:15 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1997 - Antarctica 2of3 The Ice Forms.avi to YouTube: [WinError 10054] An existing connection was forcibly closed by the remote host
# 10:26:15 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1997 - Antarctica 2of3 The Ice Forms.avi
# 10:26:15 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1997 - Antarctica 3of3 The Ice Melts.avi with title: BBC Horizon - 1997 - Antarctica 3of3 The Ice Melts
# 10:26:15 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1997 - Antarctica 3of3 The Ice Melts.avi to YouTube: [WinError 10054] An existing connection was forcibly closed by the remote host
# 10:26:15 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1997 - Antarctica 3of3 The Ice Melts.avi
# 10:26:15 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1997 - Crater of Death.avi with title: BBC Horizon - 1997 - Crater of Death
# 10:26:55 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1997 - Crater of Death.avi to YouTube: [WinError 10054] An existing connection was forcibly closed by the remote host
# 10:26:55 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1997 - Crater of Death.avi
# 10:26:55 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1997 - Dawn of The Clone Age.avi with title: BBC Horizon - 1997 - Dawn of The Clone Age
# 10:26:55 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1997 - Dawn of The Clone Age.avi to YouTube: [WinError 10054] An existing connection was forcibly closed by the remote host
# 10:26:55 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1997 - Dawn of The Clone Age.avi
# 10:26:55 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1997 - Genius of The Jet.avi with title: BBC Horizon - 1997 - Genius of The Jet
# 10:29:42 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1997 - Genius of The Jet.avi to YouTube: [WinError 10054] An existing connection was forcibly closed by the remote host
# 10:29:42 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1997 - Genius of The Jet.avi
# 10:29:42 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1998 - Beyond A Joke.avi with title: BBC Horizon - 1998 - Beyond A Joke
# 10:29:42 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1998 - Beyond A Joke.avi to YouTube: [WinError 10054] An existing connection was forcibly closed by the remote host
# 10:29:42 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1998 - Beyond A Joke.avi
# 10:29:42 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1998 - Fat Files - Born To Be Fat.avi with title: BBC Horizon - 1998 - Fat Files - Born To Be Fat
# 10:30:06 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1998 - Fat Files - Born To Be Fat.avi to YouTube: [WinError 10054] An existing connection was forcibly closed by the remote host
# 10:30:06 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1998 - Fat Files - Born To Be Fat.avi
# 10:30:06 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1998 - Fat Files - Fixing Fat.avi with title: BBC Horizon - 1998 - Fat Files - Fixing Fat
# 10:30:06 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1998 - Fat Files - Fixing Fat.avi to YouTube: [WinError 10054] An existing connection was forcibly closed by the remote host
# 10:30:06 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1998 - Fat Files - Fixing Fat.avi
# 10:30:06 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1998 - Fat Files - Living on Air.avi with title: BBC Horizon - 1998 - Fat Files - Living on Air
# 10:30:29 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1998 - Fat Files - Living on Air.avi to YouTube: [WinError 10054] An existing connection was forcibly closed by the remote host
# 10:30:29 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1998 - Fat Files - Living on Air.avi
# 10:30:29 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1998 - Hopeful Monsters.avi with title: BBC Horizon - 1998 - Hopeful Monsters
# 10:30:30 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1998 - Hopeful Monsters.avi to YouTube: [WinError 10054] An existing connection was forcibly closed by the remote host
# 10:30:30 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1998 - Hopeful Monsters.avi
# 10:30:30 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1999 - Anatomy of An Avalanche.avi with title: BBC Horizon - 1999 - Anatomy of An Avalanche
# 10:31:19 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1999 - Anatomy of An Avalanche.avi to YouTube: [WinError 10054] An existing connection was forcibly closed by the remote host
# 10:31:19 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1999 - Anatomy of An Avalanche.avi
# 10:31:19 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1999 - Atlantis Uncovered.avi with title: BBC Horizon - 1999 - Atlantis Uncovered
# 10:31:19 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1999 - Atlantis Uncovered.avi to YouTube: [WinError 10054] An existing connection was forcibly closed by the remote host
# 10:31:19 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1999 - Atlantis Uncovered.avi
# 10:31:19 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2000 - Atlantis Reborn Again.avi with title: BBC Horizon - 2000 - Atlantis Reborn Again
# 10:33:18 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2000 - Atlantis Reborn Again.avi to YouTube: [WinError 10054] An existing connection was forcibly closed by the remote host
# 10:33:18 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2000 - Atlantis Reborn Again.avi
# 10:33:18 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2000 - Complete Obsession - Body Dysmorphia.avi with title: BBC Horizon - 2000 - Complete Obsession - Body Dysmorphia
# 10:33:18 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2000 - Complete Obsession - Body Dysmorphia.avi to YouTube: [WinError 10054] An existing connection was forcibly closed by the remote host
# 10:33:18 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2000 - Complete Obsession - Body Dysmorphia.avi
# 10:33:18 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2000 - Conjoined Twins.avi with title: BBC Horizon - 2000 - Conjoined Twins
# 10:38:03 - Upload successful! Video ID: qA7NFGj0LFg
# 10:38:03 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2000 - Destination Mars.avi with title: BBC Horizon - 2000 - Destination Mars
# 10:41:18 - Upload successful! Video ID: aWdOjkLf1yA
# 10:41:18 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2001 - Ecstasy And Agony.avi with title: BBC Horizon - 2001 - Ecstasy And Agony
# 10:43:09 - Upload successful! Video ID: SfFiH4qjdLU
# 10:43:09 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2002 - Archimedes' Secret.avi with title: BBC Horizon - 2002 - Archimedes' Secret
# 10:47:36 - Upload successful! Video ID: gczc7Iiw9fY
# 10:47:36 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2002 - Death of The Iceman.avi with title: BBC Horizon - 2002 - Death of The Iceman
# 10:52:02 - Upload successful! Video ID: T02q7nvPNlY
# 10:52:02 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2002 - Helike - The Real Atlantis.avi with title: BBC Horizon - 2002 - Helike - The Real Atlantis
# 10:56:50 - Upload successful! Video ID: bWdyc7NJDuo
# 10:56:50 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2002 - Homeopathy - The Test.avi with title: BBC Horizon - 2002 - Homeopathy - The Test
# 11:01:27 - Upload successful! Video ID: WzFj0ES7IY8
# 11:01:27 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2002 - Parallel Universes.avi with title: BBC Horizon - 2002 - Parallel Universes
# 11:03:54 - Upload successful! Video ID: BNN3zBVW1Do
# 11:03:54 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2003 - Averting Armageddon.avi with title: BBC Horizon - 2003 - Averting Armageddon
# 11:06:51 - Upload successful! Video ID: slAu71boDGI
# 11:06:51 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2003 - Dirty Bomb.avi with title: BBC Horizon - 2003 - Dirty Bomb
# 11:09:40 - Upload successful! Video ID: uszkO_RHekA
# 11:09:40 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2003 - Earthquake Storms.avi with title: BBC Horizon - 2003 - Earthquake Storms
# 11:14:20 - Upload successful! Video ID: FuManhgN2Ag
# 11:14:20 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2003 - Flight 587.avi with title: BBC Horizon - 2003 - Flight 587
# 11:16:48 - Upload successful! Video ID: sczL9cWplGk
# 11:16:48 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2003 - God On The Brain.avi with title: BBC Horizon - 2003 - God On The Brain
# 11:17:38 - Upload successful! Video ID: 4ypSKo9rwOk
# 11:17:38 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2004 - Derek Tastes of Earwax.avi with title: BBC Horizon - 2004 - Derek Tastes of Earwax
# 11:19:30 - Upload successful! Video ID: 3VWQpkviaOM
# 11:19:30 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2004 - Dr Money And The Boy With No Penis.avi with title: BBC Horizon - 2004 - Dr Money And The Boy With No Penis
# 11:21:40 - Upload successful! Video ID: X-9Emz6a7u4
# 11:21:40 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2004 - First Olympian.avi with title: BBC Horizon - 2004 - First Olympian
# 11:26:24 - Upload successful! Video ID: MezIywq71Q0
# 11:26:24 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2005 - An Experiment To Save the World.avi with title: BBC Horizon - 2005 - An Experiment To Save the World
# 11:29:13 - Upload successful! Video ID: pZcrHeBC3E8
# 11:29:13 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2005 - Can Fish Make My Child Smart.avi with title: BBC Horizon - 2005 - Can Fish Make My Child Smart
# 11:32:08 - Upload successful! Video ID: c9WI_Diu41I
# 11:32:08 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2005 - Einstein's Equation of Life And Death.avi with title: BBC Horizon - 2005 - Einstein's Equation of Life And Death
# 11:35:04 - Upload successful! Video ID: QFRs34p4nWI
# 11:35:04 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2005 - Einstein's Unfinished Symphony.avi with title: BBC Horizon - 2005 - Einstein's Unfinished Symphony
# 11:37:42 - Upload successful! Video ID: KNiasIyDB8M
# 11:37:42 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2005 - Global Dimming.avi with title: BBC Horizon - 2005 - Global Dimming
# 11:41:58 - Upload successful! Video ID: pcaqqKRWD58
# 11:41:58 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2006 - A War On Science.avi with title: BBC Horizon - 2006 - A War On Science
# 11:44:42 - Upload successful! Video ID: THS45zx4K0M
# 11:44:42 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2006 - Bye Bye Planet Pluto.avi with title: BBC Horizon - 2006 - Bye Bye Planet Pluto
# 11:48:37 - Upload successful! Video ID: bUBgYoCAB_0
# 11:48:37 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2006 - Chimps are People too.avi with title: BBC Horizon - 2006 - Chimps are People too
# 11:53:08 - Upload successful! Video ID: 1rb9WD-hlxs
# 11:53:08 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2006 - Human v2.0.avi with title: BBC Horizon - 2006 - Human v2.0
# 11:57:39 - Upload successful! Video ID: Fh0ZDMSiwxk
# 11:57:39 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2006x19.BBC.Horizon.[2006-11-14].We.are.the.Aliens.avi with title: BBC Horizon - 2006x19.BBC.Horizon.[2006-11-14].We.are.the.Aliens
# 12:00:07 - Upload successful! Video ID: Ij5JbDq2_fM
# 12:00:07 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2007 - Battle of The Brains.avi with title: BBC Horizon - 2007 - Battle of The Brains
# 12:04:40 - Upload successful! Video ID: Qj0K8tuJGdg
# 12:04:40 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2007 - Everest Doctors in the Death Zone Part 01.avi with title: BBC Horizon - 2007 - Everest Doctors in the Death Zone Part 01
# 12:09:12 - Upload successful! Video ID: dExZPdKc5ZI
# 12:09:12 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2007 - Everest Doctors in the Death Zone Part 02.avi with title: BBC Horizon - 2007 - Everest Doctors in the Death Zone Part 02
# 12:13:44 - Upload successful! Video ID: 5KX5Z-fSNhM
# 12:13:44 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2007 - How To Commit The Perfect Murder.avi with title: BBC Horizon - 2007 - How To Commit The Perfect Murder
# 12:18:17 - Upload successful! Video ID: vgDfzAvB7lI
# 12:18:17 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2008 - Are We Alone In The Universe.avi with title: BBC Horizon - 2008 - Are We Alone In The Universe
# 12:22:11 - Upload successful! Video ID: O2YlGrzNsz4
# 12:22:11 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2008 - How Does Your Memory Work.avi with title: BBC Horizon - 2008 - How Does Your Memory Work
# 12:24:19 - Upload successful! Video ID: G4df9NRYL9k
# 12:24:19 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2008 - How Much Is Your Dead Body Worth.avi with title: BBC Horizon - 2008 - How Much Is Your Dead Body Worth
# 12:28:13 - Upload successful! Video ID: ZZFSmc0ZyDE
# 12:28:13 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2008 - How To Kill A Human Being.avi with title: BBC Horizon - 2008 - How To Kill A Human Being
# 12:32:06 - Upload successful! Video ID: 123ve46MFRU
# 12:32:06 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2008 - How To Live To Be 101.avi with title: BBC Horizon - 2008 - How To Live To Be 101
# 12:36:01 - Upload successful! Video ID: RT7PPF98RFU
# 12:36:01 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2009 - How To Survive A Disaster.avi with title: BBC Horizon - 2009 - How To Survive A Disaster
# 12:39:01 - Upload successful! Video ID: 4U0bf1tgG50
# 12:39:01 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2010 - Did Cooking Make Us Human.avi with title: BBC Horizon - 2010 - Did Cooking Make Us Human
# 12:43:48 - Upload successful! Video ID: wPBPx-fZ2r8
# 12:43:48 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2011 - Carrot or Stick A Horizon Guide to Raising Kids.avi with title: BBC Horizon - 2011 - Carrot or Stick A Horizon Guide to Raising Kids
# 12:46:54 - Upload successful! Video ID: su790-ZvC6A
# 12:46:54 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2011 - Extinct - A Horizon Guide to Dinosaurs.avi with title: BBC Horizon - 2011 - Extinct - A Horizon Guide to Dinosaurs
# 12:51:19 - Upload successful! Video ID: xXQUM0-NMM4
# 12:51:19 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Iceman (Update).avi with title: BBC Horizon - Iceman (Update)
# 12:54:19 - Upload successful! Video ID: hN_lkpPCh1w
# 12:54:19 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Iceman.avi with title: BBC Horizon - Iceman
# 12:56:50 - Upload successful! Video ID: VhjJfmX1lvk
# 12:56:50 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Icon Earth.avi with title: BBC Horizon - Icon Earth
# 12:59:31 - Upload successful! Video ID: w-pEQFTTTQY
# 12:59:31 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\In Search Of the 'Noble Savage'.avi with title: BBC Horizon - In Search Of the 'Noble Savage'
# 13:02:04 - Upload successful! Video ID: DSRqwLnJ8K8
# 13:02:04 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\In the Wake of HMS Sheffield.avi with title: BBC Horizon - In the Wake of HMS Sheffield
# 13:03:40 - Upload successful! Video ID: a1M_BiILaJg
# 13:03:40 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Is Alcohol Worse than Ecstasy.avi with title: BBC Horizon - Is Alcohol Worse than Ecstasy
# 13:07:45 - Upload successful! Video ID: eyDr0Jir7vw
# 13:07:45 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Is GM Safe.avi with title: BBC Horizon - Is GM Safe
# 13:11:57 - Upload successful! Video ID: IlNf67YhKCo
# 13:11:57 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Is Seeing Believing.avi with title: BBC Horizon - Is Seeing Believing
# 13:16:53 - Upload successful! Video ID: EdZE7__moqA
# 13:16:53 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Is.Alcohol.worse.than.ecstasy.avi with title: BBC Horizon - Is.Alcohol.worse.than.ecstasy
# 13:19:32 - Upload successful! Video ID: qWD1GxgYjyc
# 13:19:32 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Israel's Secret Weapon.avi with title: BBC Horizon - Israel's Secret Weapon
# 13:22:38 - Upload successful! Video ID: 0V8cPKRLo-w
# 13:22:38 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Japan Earthquake_ A Horizon Special.avi with title: BBC Horizon - Japan Earthquake_ A Horizon Special
# 13:27:25 - Upload successful! Video ID: iopPsxLu7gg
# 13:27:25 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Killer Algae.avi with title: BBC Horizon - Killer Algae
# 13:31:55 - Upload successful! Video ID: sFVmeZ896Dw
# 13:31:55 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Killer Lakes.avi with title: BBC Horizon - Killer Lakes
# 13:36:31 - Upload successful! Video ID: VC5o8H6PP4Q
# 13:36:31 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Last Flight of the Columbia.avi with title: BBC Horizon - Last Flight of the Columbia
# 13:38:42 - Upload successful! Video ID: pGib5xJIlhc
# 13:38:42 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Liar.avi with title: BBC Horizon - Liar
# 13:41:22 - Upload successful! Video ID: tRx7mCrjlH4
# 13:41:22 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Life and Death in the 21st Century - Living Forever.avi with title: BBC Horizon - Life and Death in the 21st Century - Living Forever
# 13:43:32 - Upload successful! Video ID: akJwWAA9018
# 13:43:32 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Life and Death in the 21st Century _ Future Plagues.avi with title: BBC Horizon - Life and Death in the 21st Century _ Future Plagues
# 13:47:13 - Upload successful! Video ID: emG8ndnHAf0
# 13:47:13 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Life and Death in the 21st Century_ Designer Babies.avi with title: BBC Horizon - Life and Death in the 21st Century_ Designer Babies
# 13:51:32 - Upload successful! Video ID: yvE5B6DMX9Y
# 13:51:32 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Life Blood.avi with title: BBC Horizon - Life Blood
# 13:53:43 - Upload successful! Video ID: fa4zGS_bnuw
# 13:53:43 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Life is Impossible.avi with title: BBC Horizon - Life is Impossible
# 13:56:11 - Upload successful! Video ID: zevp6j25wa4
# 13:56:11 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Life on Earth - Life in the Trees.avi with title: BBC Horizon - Life on Earth - Life in the Trees
# 14:00:28 - Upload successful! Video ID: x8klR89NS-o
# 14:00:28 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Life On Mars.avi with title: BBC Horizon - Life On Mars
# 14:04:48 - Upload successful! Video ID: wPLlAnmSyZc
# 14:04:48 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Life Story.avi with title: BBC Horizon - Life Story
# 14:09:07 - Upload successful! Video ID: ANu76_W4Wik
# 14:09:07 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Living Nightmare.avi with title: BBC Horizon - Living Nightmare
# 14:13:31 - Upload successful! Video ID: MWcgb-vfCKM
# 14:13:31 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Living With ADHD.avi with title: BBC Horizon - Living With ADHD
# 14:16:12 - Upload successful! Video ID: GAhZCibsimI
# 14:16:12 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Longitude.avi with title: BBC Horizon - Longitude
# 14:20:33 - Upload successful! Video ID: VCWRD0ley78
# 14:20:33 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Lost City Of New Orleans.avi with title: BBC Horizon - Lost City Of New Orleans
# 14:23:35 - Upload successful! Video ID: ht4AQTcyxXs
# 14:23:35 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Love Cigarettes.avi with title: BBC Horizon - Love Cigarettes
# 14:27:32 - Upload successful! Video ID: Q-sH32t2NQE
# 14:27:32 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Mad But Glad.avi with title: BBC Horizon - Mad But Glad
# 14:32:06 - Upload successful! Video ID: pwvYhS4rU4c
# 14:32:06 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Madagascar A Treetop Odyssey.avi with title: BBC Horizon - Madagascar A Treetop Odyssey
# 14:34:53 - Upload successful! Video ID: zPTYQmRl8UY
# 14:34:53 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Magic Bullet.avi with title: BBC Horizon - Magic Bullet
# 14:39:17 - Upload successful! Video ID: 5Yn1Y2dhbKo
# 14:39:17 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Making Sex Pay.avi with title: BBC Horizon - Making Sex Pay
# 14:43:21 - Upload successful! Video ID: 0JxiMMBXvBE
# 14:43:21 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Malaria Defeating The Curse.avi with title: BBC Horizon - Malaria Defeating The Curse
# 14:45:25 - Upload successful! Video ID: TTncEk_fPSg
# 14:45:25 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Malaria_ Battle Of the Merozoites.avi with title: BBC Horizon - Malaria_ Battle Of the Merozoites
# 14:47:45 - Upload successful! Video ID: 8PsWXBjcTCk
# 14:47:45 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Mars A Horizon Guide.avi with title: BBC Horizon - Mars A Horizon Guide
# 14:52:06 - Upload successful! Video ID: UPf29wldNVo
# 14:52:06 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Masters of the Ionisphere.avi with title: BBC Horizon - Masters of the Ionisphere
# 14:54:58 - Upload successful! Video ID: UTt-1R5YwZM
# 14:54:58 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Measuring the Roof of the World.avi with title: BBC Horizon - Measuring the Roof of the World
# 14:57:49 - Upload successful! Video ID: t9pmG4i_wHc
# 14:57:49 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Mega-Tsunami_ Wave of Destruction.avi with title: BBC Horizon - Mega-Tsunami_ Wave of Destruction
# 14:59:12 - Upload successful! Video ID: 0-_uQO9Js5M
# 14:59:12 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Message in the Rocks.avi with title: BBC Horizon - Message in the Rocks
# 15:03:03 - Upload successful! Video ID: 811nMI2LIJo
# 15:03:03 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Microworld.avi with title: BBC Horizon - Microworld
# 15:06:26 - Upload successful! Video ID: IBccSTeEj9A
# 15:06:26 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Mind over Body.avi with title: BBC Horizon - Mind over Body
# 15:09:10 - Upload successful! Video ID: jUrwzao4Lbc
# 15:09:10 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Miracle In Orbit.avi with title: BBC Horizon - Miracle In Orbit
# 15:13:22 - Upload successful! Video ID: q38c_3INWV4
# 15:13:22 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Mistaken Identity.avi with title: BBC Horizon - Mistaken Identity
# 15:17:27 - Upload successful! Video ID: 5VURiS2i2pk
# 15:17:27 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Molecules With Sunglasses.avi with title: BBC Horizon - Molecules With Sunglasses
# 15:19:36 - Upload successful! Video ID: zvTzW7WEa2c
# 15:19:36 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Moon children.avi with title: BBC Horizon - Moon children
# 15:23:50 - Upload successful! Video ID: I_B-KuuRhmc
# 15:23:50 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Moon For Sale.avi with title: BBC Horizon - Moon For Sale
# 15:28:11 - Upload successful! Video ID: l6fYGLZxp_o
# 15:28:11 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Morecambe and Wise - The Show What Paul Merton Did.avi with title: BBC Horizon - Morecambe and Wise - The Show What Paul Merton Did
# 15:31:15 - Upload successful! Video ID: p3yLyh4mPrk
# 15:31:15 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Most of Our Universe is Missing.avi with title: BBC Horizon - Most of Our Universe is Missing
# 15:35:40 - Upload successful! Video ID: PQ5lRLSvJCo
# 15:35:40 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Moving Still.avi with title: BBC Horizon - Moving Still
# 15:38:57 - Upload successful! Video ID: aCTTapqYcv4
# 15:38:57 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\My Pet Dinosaur.avi with title: BBC Horizon - My Pet Dinosaur
# 15:43:19 - Upload successful! Video ID: xn0Sy3MCU5k
# 15:43:19 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Mystery of the Left Hand.avi with title: BBC Horizon - Mystery of the Left Hand
# 15:43:20 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:43:20 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Mystery of the Left Hand.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:43:20 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Mystery of the Left Hand.avi
# 15:43:20 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\n and Marcus Go Forth and Multiply.avi with title: BBC Horizon - n and Marcus Go Forth and Multiply
# 15:43:20 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:43:20 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\n and Marcus Go Forth and Multiply.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:43:20 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\n and Marcus Go Forth and Multiply.avi
# 15:43:20 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Neanderthal.avi with title: BBC Horizon - Neanderthal
# 15:43:20 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:43:20 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Neanderthal.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:43:20 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Neanderthal.avi
# 15:43:20 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\New Asteroid Danger.avi with title: BBC Horizon - New Asteroid Danger
# 15:43:20 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:43:20 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\New Asteroid Danger.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:43:20 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\New Asteroid Danger.avi
# 15:43:20 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\New Star In Orbit.avi with title: BBC Horizon - New Star In Orbit
# 15:43:20 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:43:20 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\New Star In Orbit.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:43:20 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\New Star In Orbit.avi
# 15:43:20 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Nice Guys Finish First.avi with title: BBC Horizon - Nice Guys Finish First
# 15:43:21 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:43:21 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Nice Guys Finish First.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:43:21 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Nice Guys Finish First.avi
# 15:43:21 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\No Ordinary Genius Richard Feynman.avi with title: BBC Horizon - No Ordinary Genius Richard Feynman
# 15:43:21 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:43:21 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\No Ordinary Genius Richard Feynman.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:43:21 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\No Ordinary Genius Richard Feynman.avi
# 15:43:21 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Noahs Flood.avi with title: BBC Horizon - Noahs Flood
# 15:43:21 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:43:21 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Noahs Flood.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:43:21 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Noahs Flood.avi
# 15:43:21 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Now the chips are down.avi with title: BBC Horizon - Now the chips are down
# 15:43:21 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:43:21 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Now the chips are down.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:43:21 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Now the chips are down.avi
# 15:43:21 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Nuclear Nightmares.avi with title: BBC Horizon - Nuclear Nightmares
# 15:43:21 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:43:21 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Nuclear Nightmares.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:43:21 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Nuclear Nightmares.avi
# 15:43:21 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Of Big Bangs Stick Men and Galactic Holes.avi with title: BBC Horizon - Of Big Bangs Stick Men and Galactic Holes
# 15:43:21 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:43:21 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Of Big Bangs Stick Men and Galactic Holes.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:43:21 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Of Big Bangs Stick Men and Galactic Holes.avi
# 15:43:21 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Out of Asia.avi with title: BBC Horizon - Out of Asia
# 15:43:21 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:43:21 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Out of Asia.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:43:21 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Out of Asia.avi
# 15:43:21 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Painting by Numbers.avi with title: BBC Horizon - Painting by Numbers
# 15:43:22 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:43:22 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Painting by Numbers.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:43:22 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Painting by Numbers.avi
# 15:43:22 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Parallel Universes.avi with title: BBC Horizon - Parallel Universes
# 15:43:22 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:43:22 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Parallel Universes.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:43:22 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Parallel Universes.avi
# ...
# 15:43:57 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\To Infinity and Beyond (720p).mkv
# 15:43:57 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Tomorrows World (720p).mkv with title: BBC Horizon - Tomorrows World (720p)
# 15:43:57 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:43:57 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Tomorrows World (720p).mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:43:57 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Tomorrows World (720p).mkv
# 15:43:57 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Total Isolation.mkv with title: BBC Horizon - Total Isolation
# 15:43:57 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:43:57 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Total Isolation.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:43:57 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Total Isolation.mkv
# 15:43:57 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\What is One Degree (720p).mkv with title: BBC Horizon - What is One Degree (720p)
# 15:43:57 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:43:57 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\What is One Degree (720p).mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:43:57 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\What is One Degree (720p).mkv
# 15:43:57 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\What Is Reality (720p).mkv with title: BBC Horizon - What Is Reality (720p)
# 15:43:57 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:43:57 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\What Is Reality (720p).mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:43:57 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\What Is Reality (720p).mkv
# 15:43:57 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\What Makes a Genius (720p).mkv with title: BBC Horizon - What Makes a Genius (720p)
# 15:43:58 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:43:58 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\What Makes a Genius (720p).mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:43:58 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\What Makes a Genius (720p).mkv
# 15:43:58 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\What Makes Us Clever A Horizon Guide to Intelligence.mkv with title: BBC Horizon - What Makes Us Clever A Horizon Guide to Intelligence
# 15:43:58 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:43:58 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\What Makes Us Clever A Horizon Guide to Intelligence.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:43:58 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\What Makes Us Clever A Horizon Guide to Intelligence.mkv
# 15:43:58 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\What Makes Us Human (720p).mkv with title: BBC Horizon - What Makes Us Human (720p)
# 15:43:58 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:43:58 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\What Makes Us Human (720p).mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:43:58 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\What Makes Us Human (720p).mkv
# 15:43:58 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Whats Killing Our Bees (720p).mkv with title: BBC Horizon - Whats Killing Our Bees (720p)
# 15:43:58 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:43:58 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Whats Killing Our Bees (720p).mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:43:58 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Whats Killing Our Bees (720p).mkv
# 15:43:58 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Whats the Problem with Nudity.mkv with title: BBC Horizon - Whats the Problem with Nudity
# 15:43:58 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:43:58 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Whats the Problem with Nudity.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:43:58 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Whats the Problem with Nudity.mkv
# 15:43:58 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Wheres My Robot.mkv with title: BBC Horizon - Wheres My Robot
# 15:43:58 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:43:58 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Wheres My Robot.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:43:58 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Wheres My Robot.mkv
# 15:43:58 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Who's Afraid of a Big Black Hole (720p).mkv with title: BBC Horizon - Who's Afraid of a Big Black Hole (720p)
# 15:43:58 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:43:58 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Who's Afraid of a Big Black Hole (720p).mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:43:58 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Who's Afraid of a Big Black Hole (720p).mkv
# 15:43:58 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Why Are Thin People Not Fat.mkv with title: BBC Horizon - Why Are Thin People Not Fat
# 15:43:59 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:43:59 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Why Are Thin People Not Fat.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:43:59 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Why Are Thin People Not Fat.mkv
# 15:43:59 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Why Cant We Predict Earthquakes (720p).mkv with title: BBC Horizon - Why Cant We Predict Earthquakes (720p)
# 15:43:59 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:43:59 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Why Cant We Predict Earthquakes (720p).mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:43:59 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Why Cant We Predict Earthquakes (720p).mkv
# 15:43:59 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Why Do Viruses Kill (720p).mkv with title: BBC Horizon - Why Do Viruses Kill (720p)
# 15:43:59 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:43:59 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Why Do Viruses Kill (720p).mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:43:59 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Why Do Viruses Kill (720p).mkv
# 15:43:59 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Why Do We Dream.mkv with title: BBC Horizon - Why Do We Dream
# 15:43:59 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:43:59 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Why Do We Dream.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:43:59 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Why Do We Dream.mkv
# 15:43:59 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1999 - From Here To Infinity.mov with title: BBC Horizon - 1999 - From Here To Infinity
# 15:43:59 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:43:59 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1999 - From Here To Infinity.mov to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:43:59 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1999 - From Here To Infinity.mov
