# %%
import os
import glob
import logging
from datetime import datetime
from pathlib import Path
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
from google_auth_oauthlib.flow import InstalledAppFlow
from google.oauth2.credentials import Credentials
from google.auth.transport.requests import Request
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload
import tkinter as tk
from tkinter import filedialog

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(message)s',
    datefmt='%H:%M:%S',
    handlers=[
        logging.FileHandler('upload_all.log', encoding='utf-8'),
        logging.StreamHandler()
    ]
)

TOKEN_FILE = "token.json"
SCOPES = ["https://www.googleapis.com/auth/youtube.upload"]

os.environ['OAUTHLIB_INSECURE_TRANSPORT'] = '1'
os.environ['PYTHONHTTPSVERIFY'] = '0'

def get_authenticated_service(client_secrets_file: str):
    creds = None
    if os.path.exists(TOKEN_FILE):
        creds = Credentials.from_authorized_user_file(TOKEN_FILE, SCOPES)
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(client_secrets_file, SCOPES)
            creds = flow.run_local_server(port=0)
        with open(TOKEN_FILE, 'w') as token:
            token.write(creds.to_json())
    return build('youtube', 'v3', credentials=creds)

def upload_to_youtube(youtube, video_path: str, title: str, description: str = "Uploaded by script"):
    try:
        body = {
            'snippet': {
                'title': title,
                'description': description,
                'tags': ['tutorial', 'education']
            },
            'status': {
                'privacyStatus': 'unlisted',
                'selfDeclaredMadeForKids': False
            }
        }
        insert_request = youtube.videos().insert(
            part=','.join(body.keys()),
            body=body,
            media_body=MediaFileUpload(video_path, chunksize=-1, resumable=True)
        )
        response = None
        while response is None:
            status, response = insert_request.next_chunk()
            if status:
                logging.info(f"Upload {int(status.progress() * 100)}% complete for {video_path}")
        return response['id']
    except Exception as e:
        logging.error(f"Error uploading {video_path} to YouTube: {str(e)}")
        return None

def select_folder_dialog(title="Select the folder containing videos to upload"):
    root = tk.Tk()
    root.withdraw()
    folder_selected = filedialog.askdirectory(title=title)
    root.destroy()
    return folder_selected

def main():
    cwd = os.getcwd()
    client_secrets_file = os.path.join(cwd, "client_secret.dlc.json")
    if not os.path.exists(client_secrets_file):
        logging.error("Client secrets file not found")
        return
    youtube = get_authenticated_service(client_secrets_file)
    logging.info("YouTube authentication complete.")
    # Ask user for folder containing videos to upload
    input_folder = select_folder_dialog()
    if not input_folder or not os.path.exists(input_folder):
        logging.warning("No folder selected or path does not exist. Using current working directory.")
        input_folder = cwd
    folder_name = os.path.basename(input_folder)
    # Find all video files in the folder (no recursion)
    extensions = ("*.mp4", "*.avi", "*.mkv", "*.mov", "*.flv", "*.rmvb")
    video_files = []
    for ext in extensions:
        video_files.extend(glob.glob(os.path.join(input_folder, ext)))
    if not video_files:
        logging.info("No video files found in the folder.")
        return
    logging.info(f"Found {len(video_files)} videos to upload.")
    for video_path in video_files:
        video_name = os.path.splitext(os.path.basename(video_path))[0]
        title = f"{folder_name} - {video_name}"
        logging.info(f"Uploading: {video_path} with title: {title}")
        video_id = upload_to_youtube(youtube, video_path, title)
        if video_id:
            link_file = os.path.join(input_folder, f"{video_name}.txt")
            with open(link_file, 'w') as f:
                f.write(f"https://www.youtube.com/watch?v={video_id}\n")
            try:
                os.remove(video_path)
            except Exception as e:
                logging.error(f"Failed to delete uploaded video file: {video_path}: {str(e)}")
            logging.info(f"Upload successful! Video ID: {video_id}")
        else:
            logging.error(f"Upload failed for {video_path}")

main()
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=278603640083-k1p46852j17t0ghm5ejf0dlf33gjs3gg.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A64380%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fyoutube.upload&state=VzRaLfKW4G7UTpPiWfahPlVLFvzQ4w&access_type=offline
# 20:01:08 - "GET /?state=VzRaLfKW4G7UTpPiWfahPlVLFvzQ4w&code=4/0AUJR-x423TcLFio6ZfAfUpUakH8WHWGuUO1BHpnO-fm0Eh90bhSwhfYAcpnScESNrj9sGw&scope=https://www.googleapis.com/auth/youtube.upload HTTP/1.1" 200 65
# 20:01:09 - file_cache is only supported with oauth2client<4.0.0
# 20:01:09 - YouTube authentication complete.
# 20:01:16 - Found 47 videos to upload.
# 20:01:16 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Trumps.Unlikely.Superfans.720p.x264.AAC.MVGroup.org.mp4 with title: BBC Organize - BBC.Trumps.Unlikely.Superfans.720p.x264.AAC.MVGroup.org
# 20:01:17 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:17 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Trumps.Unlikely.Superfans.720p.x264.AAC.MVGroup.org.mp4 to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:17 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Trumps.Unlikely.Superfans.720p.x264.AAC.MVGroup.org.mp4
# 20:01:17 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.United.States.of.Hate.Muslims.Under.Attack.720p.x264.AAC.MVGroup.org.mp4 with title: BBC Organize - BBC.United.States.of.Hate.Muslims.Under.Attack.720p.x264.AAC.MVGroup.org
# 20:01:18 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:18 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.United.States.of.Hate.Muslims.Under.Attack.720p.x264.AAC.MVGroup.org.mp4 to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:18 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.United.States.of.Hate.Muslims.Under.Attack.720p.x264.AAC.MVGroup.org.mp4
# 20:01:18 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Correspondent.Israels.Secret.Weapon.XviD.mp3.avi with title: BBC Organize - BBC.Correspondent.Israels.Secret.Weapon.XviD.mp3
# 20:01:18 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:18 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Correspondent.Israels.Secret.Weapon.XviD.mp3.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:18 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Correspondent.Israels.Secret.Weapon.XviD.mp3.avi
# 20:01:18 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Irans.Nuclear.Secrets.DivX.mp3.avi with title: BBC Organize - BBC.Irans.Nuclear.Secrets.DivX.mp3
# 20:01:18 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:18 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Irans.Nuclear.Secrets.DivX.mp3.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:18 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Irans.Nuclear.Secrets.DivX.mp3.avi
# 20:01:18 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Modern.Spies.1of2.PDTV.XviD.AC3.MVGroup.org.avi with title: BBC Organize - BBC.Modern.Spies.1of2.PDTV.XviD.AC3.MVGroup.org
# 20:01:18 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:18 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Modern.Spies.1of2.PDTV.XviD.AC3.MVGroup.org.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:18 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Modern.Spies.1of2.PDTV.XviD.AC3.MVGroup.org.avi
# 20:01:18 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Modern.Spies.2of2.PDTV.XviD.AC3.MVGroup.org.avi with title: BBC Organize - BBC.Modern.Spies.2of2.PDTV.XviD.AC3.MVGroup.org
# 20:01:19 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:19 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Modern.Spies.2of2.PDTV.XviD.AC3.MVGroup.org.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:19 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Modern.Spies.2of2.PDTV.XviD.AC3.MVGroup.org.avi
# 20:01:19 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Stephen.Fry.in.America.1of6.New.World.XviD.AC3.MVGroup.org.avi with title: BBC Organize - BBC.Stephen.Fry.in.America.1of6.New.World.XviD.AC3.MVGroup.org
# 20:01:19 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:19 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Stephen.Fry.in.America.1of6.New.World.XviD.AC3.MVGroup.org.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:19 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Stephen.Fry.in.America.1of6.New.World.XviD.AC3.MVGroup.org.avi
# 20:01:19 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Stephen.Fry.in.America.2of6.Deep.South.XviD.AC3.MVGroup.org.avi with title: BBC Organize - BBC.Stephen.Fry.in.America.2of6.Deep.South.XviD.AC3.MVGroup.org
# 20:01:19 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:19 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Stephen.Fry.in.America.2of6.Deep.South.XviD.AC3.MVGroup.org.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:19 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Stephen.Fry.in.America.2of6.Deep.South.XviD.AC3.MVGroup.org.avi
# 20:01:19 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Stephen.Fry.in.America.3of6.Mississippi.XviD.AC3.MVGroup.org.avi with title: BBC Organize - BBC.Stephen.Fry.in.America.3of6.Mississippi.XviD.AC3.MVGroup.org
# 20:01:19 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:19 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Stephen.Fry.in.America.3of6.Mississippi.XviD.AC3.MVGroup.org.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:19 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Stephen.Fry.in.America.3of6.Mississippi.XviD.AC3.MVGroup.org.avi
# 20:01:19 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Stephen.Fry.in.America.4of6.Mountains.and.Plains.XviD.AC3.MVGroup.org.avi with title: BBC Organize - BBC.Stephen.Fry.in.America.4of6.Mountains.and.Plains.XviD.AC3.MVGroup.org
# 20:01:20 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:20 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Stephen.Fry.in.America.4of6.Mountains.and.Plains.XviD.AC3.MVGroup.org.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:20 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Stephen.Fry.in.America.4of6.Mountains.and.Plains.XviD.AC3.MVGroup.org.avi
# 20:01:20 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Stephen.Fry.in.America.5of6.True.West.XviD.AC3.MVGroup.org.avi with title: BBC Organize - BBC.Stephen.Fry.in.America.5of6.True.West.XviD.AC3.MVGroup.org
# 20:01:20 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:20 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Stephen.Fry.in.America.5of6.True.West.XviD.AC3.MVGroup.org.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:20 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Stephen.Fry.in.America.5of6.True.West.XviD.AC3.MVGroup.org.avi
# 20:01:20 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Stephen.Fry.in.America.6of6.Pacific.XviD.AC3.MVGroup.org.avi with title: BBC Organize - BBC.Stephen.Fry.in.America.6of6.Pacific.XviD.AC3.MVGroup.org
# 20:01:20 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:20 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Stephen.Fry.in.America.6of6.Pacific.XviD.AC3.MVGroup.org.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:20 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Stephen.Fry.in.America.6of6.Pacific.XviD.AC3.MVGroup.org.avi
# 20:01:20 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Suez.A.Very.British.Crisis.1of3.Betrayal.DVB.XviD.MP3.www.mvgroup.org.avi with title: BBC Organize - BBC.Suez.A.Very.British.Crisis.1of3.Betrayal.DVB.XviD.MP3.www.mvgroup.org
# 20:01:20 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:20 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Suez.A.Very.British.Crisis.1of3.Betrayal.DVB.XviD.MP3.www.mvgroup.org.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:20 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Suez.A.Very.British.Crisis.1of3.Betrayal.DVB.XviD.MP3.www.mvgroup.org.avi
# 20:01:20 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Suez.A.Very.British.Crisis.2of3.Conspiracy.DVB.XviD.MP3.www.mvgroup.org.avi with title: BBC Organize - BBC.Suez.A.Very.British.Crisis.2of3.Conspiracy.DVB.XviD.MP3.www.mvgroup.org
# 20:01:21 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:21 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Suez.A.Very.British.Crisis.2of3.Conspiracy.DVB.XviD.MP3.www.mvgroup.org.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:21 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Suez.A.Very.British.Crisis.2of3.Conspiracy.DVB.XviD.MP3.www.mvgroup.org.avi
# 20:01:21 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Suez.A.Very.British.Crisis.3of3.War.DVB.XviD.MP3.www.mvgroup.org.avi with title: BBC Organize - BBC.Suez.A.Very.British.Crisis.3of3.War.DVB.XviD.MP3.www.mvgroup.org
# 20:01:21 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:21 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Suez.A.Very.British.Crisis.3of3.War.DVB.XviD.MP3.www.mvgroup.org.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:21 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Suez.A.Very.British.Crisis.3of3.War.DVB.XviD.MP3.www.mvgroup.org.avi
# 20:01:21 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Birth.of.Israel.2008.DVBC.XviD.MP3.MVGroup.org.avi with title: BBC Organize - BBC.The.Birth.of.Israel.2008.DVBC.XviD.MP3.MVGroup.org
# 20:01:21 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:21 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Birth.of.Israel.2008.DVBC.XviD.MP3.MVGroup.org.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:21 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Birth.of.Israel.2008.DVBC.XviD.MP3.MVGroup.org.avi
# 20:01:21 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Other.Side.of.Suez.DVB.XviD.MP3.www.mvgroup.org.avi with title: BBC Organize - BBC.The.Other.Side.of.Suez.DVB.XviD.MP3.www.mvgroup.org
# 20:01:21 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:21 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Other.Side.of.Suez.DVB.XviD.MP3.www.mvgroup.org.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:21 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Other.Side.of.Suez.DVB.XviD.MP3.www.mvgroup.org.avi
# 20:01:21 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Why.Democracy.Bloody.Cartoons.DVB.Xvid.MP3.www.mvgroup.org.avi with title: BBC Organize - BBC.Why.Democracy.Bloody.Cartoons.DVB.Xvid.MP3.www.mvgroup.org
# 20:01:22 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:22 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Why.Democracy.Bloody.Cartoons.DVB.Xvid.MP3.www.mvgroup.org.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:22 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Why.Democracy.Bloody.Cartoons.DVB.Xvid.MP3.www.mvgroup.org.avi
# 20:01:22 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Why.Democracy.Egypt.We.Are.Watching.You.DVB.Xvid.MP3.www.mvgroup.org.avi with title: BBC Organize - BBC.Why.Democracy.Egypt.We.Are.Watching.You.DVB.Xvid.MP3.www.mvgroup.org
# 20:01:22 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:22 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Why.Democracy.Egypt.We.Are.Watching.You.DVB.Xvid.MP3.www.mvgroup.org.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:22 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Why.Democracy.Egypt.We.Are.Watching.You.DVB.Xvid.MP3.www.mvgroup.org.avi
# 20:01:22 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Why.Democracy.The.Ministry.of.Truth.2007.DVBC.XviD.MP3.www.mvgroup.org.avi with title: BBC Organize - BBC.Why.Democracy.The.Ministry.of.Truth.2007.DVBC.XviD.MP3.www.mvgroup.org
# 20:01:22 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:22 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Why.Democracy.The.Ministry.of.Truth.2007.DVBC.XviD.MP3.www.mvgroup.org.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:22 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Why.Democracy.The.Ministry.of.Truth.2007.DVBC.XviD.MP3.www.mvgroup.org.avi
# 20:01:22 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Afghanistan.2of3.The.Battle.for.Helmand.HDTV.x264.MVGroup.Forum.mkv with title: BBC Organize - BBC.Afghanistan.2of3.The.Battle.for.Helmand.HDTV.x264.MVGroup.Forum
# 20:01:22 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:22 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Afghanistan.2of3.The.Battle.for.Helmand.HDTV.x264.MVGroup.Forum.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:22 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Afghanistan.2of3.The.Battle.for.Helmand.HDTV.x264.MVGroup.Forum.mkv
# 20:01:22 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Afghanistan.3of3.The.Unknown.Country.HDTV.x264.AC3.MVGroup.Forum.mkv with title: BBC Organize - BBC.Afghanistan.3of3.The.Unknown.Country.HDTV.x264.AC3.MVGroup.Forum
# 20:01:23 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:23 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Afghanistan.3of3.The.Unknown.Country.HDTV.x264.AC3.MVGroup.Forum.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:23 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Afghanistan.3of3.The.Unknown.Country.HDTV.x264.AC3.MVGroup.Forum.mkv
# 20:01:23 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Afghanistan.The.Great.Game.1of2.720p.HDTV.x264.AAC.MVGroup.org.mkv with title: BBC Organize - BBC.Afghanistan.The.Great.Game.1of2.720p.HDTV.x264.AAC.MVGroup.org
# 20:01:23 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:23 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Afghanistan.The.Great.Game.1of2.720p.HDTV.x264.AAC.MVGroup.org.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:23 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Afghanistan.The.Great.Game.1of2.720p.HDTV.x264.AAC.MVGroup.org.mkv
# 20:01:23 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Afghanistan.The.Great.Game.2of2.720p.HDTV.x264.AAC.MVGroup.org.mkv with title: BBC Organize - BBC.Afghanistan.The.Great.Game.2of2.720p.HDTV.x264.AAC.MVGroup.org
# 20:01:23 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:23 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Afghanistan.The.Great.Game.2of2.720p.HDTV.x264.AAC.MVGroup.org.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:23 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Afghanistan.The.Great.Game.2of2.720p.HDTV.x264.AAC.MVGroup.org.mkv
# 20:01:23 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Britains.Muslim.Soldiers.720p.HDTV.x264.AAC.MVGroup.org.mkv with title: BBC Organize - BBC.Britains.Muslim.Soldiers.720p.HDTV.x264.AAC.MVGroup.org
# 20:01:23 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:23 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Britains.Muslim.Soldiers.720p.HDTV.x264.AAC.MVGroup.org.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:23 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Britains.Muslim.Soldiers.720p.HDTV.x264.AAC.MVGroup.org.mkv
# 20:01:23 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Frank.Gardners.Return.to.Saudi.Arabia.720p.HDTV.x264.AAC.MVGroup.org.mkv with title: BBC Organize - BBC.Frank.Gardners.Return.to.Saudi.Arabia.720p.HDTV.x264.AAC.MVGroup.org
# 20:01:24 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:24 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Frank.Gardners.Return.to.Saudi.Arabia.720p.HDTV.x264.AAC.MVGroup.org.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:24 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Frank.Gardners.Return.to.Saudi.Arabia.720p.HDTV.x264.AAC.MVGroup.org.mkv
# 20:01:24 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Horizon.2015.Are.Video.Games.Really.That.Bad.720p.HDTV.x264.AAC.MVGroup.org.mkv with title: BBC Organize - BBC.Horizon.2015.Are.Video.Games.Really.That.Bad.720p.HDTV.x264.AAC.MVGroup.org
# 20:01:24 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:24 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Horizon.2015.Are.Video.Games.Really.That.Bad.720p.HDTV.x264.AAC.MVGroup.org.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:24 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Horizon.2015.Are.Video.Games.Really.That.Bad.720p.HDTV.x264.AAC.MVGroup.org.mkv
# 20:01:24 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Iranian.Enough.PDTV.x264.AAC.MVGroup.org.mkv with title: BBC Organize - BBC.Iranian.Enough.PDTV.x264.AAC.MVGroup.org
# 20:01:24 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:24 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Iranian.Enough.PDTV.x264.AAC.MVGroup.org.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:24 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Iranian.Enough.PDTV.x264.AAC.MVGroup.org.mkv
# 20:01:24 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Israel.Facing.the.Future.720p.HDTV.x264.AAC.MVGroup.org.mkv with title: BBC Organize - BBC.Israel.Facing.the.Future.720p.HDTV.x264.AAC.MVGroup.org
# 20:01:24 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:24 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Israel.Facing.the.Future.720p.HDTV.x264.AAC.MVGroup.org.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:24 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Israel.Facing.the.Future.720p.HDTV.x264.AAC.MVGroup.org.mkv
# 20:01:24 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Natural.World.2011.Miracle.in.the.Marshes.of.Iraq.HDTV.x264.AC3.MVGroup.org.mkv with title: BBC Organize - BBC.Natural.World.2011.Miracle.in.the.Marshes.of.Iraq.HDTV.x264.AC3.MVGroup.org
# 20:01:25 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:25 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Natural.World.2011.Miracle.in.the.Marshes.of.Iraq.HDTV.x264.AC3.MVGroup.org.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:25 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Natural.World.2011.Miracle.in.the.Marshes.of.Iraq.HDTV.x264.AC3.MVGroup.org.mkv
# 20:01:25 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Newsnight.2016.The.Trump.Revolution.720p.HDTV.x264.AAC.MVGroup.org.mkv with title: BBC Organize - BBC.Newsnight.2016.The.Trump.Revolution.720p.HDTV.x264.AAC.MVGroup.org
# 20:01:25 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:25 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Newsnight.2016.The.Trump.Revolution.720p.HDTV.x264.AAC.MVGroup.org.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:25 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Newsnight.2016.The.Trump.Revolution.720p.HDTV.x264.AAC.MVGroup.org.mkv
# 20:01:25 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Newsnight.Iraq.10.Years.On.576p.HDTV.x264.AAC.MVGroup.Forum.mkv with title: BBC Organize - BBC.Newsnight.Iraq.10.Years.On.576p.HDTV.x264.AAC.MVGroup.Forum
# 20:01:25 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:25 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Newsnight.Iraq.10.Years.On.576p.HDTV.x264.AAC.MVGroup.Forum.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:25 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Newsnight.Iraq.10.Years.On.576p.HDTV.x264.AAC.MVGroup.Forum.mkv
# 20:01:25 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Nuclear.Secrets.Set.Two.1of2.Vanunu.and.the.Bomb.x264.AC3.MVGroup.org.mkv with title: BBC Organize - BBC.Nuclear.Secrets.Set.Two.1of2.Vanunu.and.the.Bomb.x264.AC3.MVGroup.org
# 20:01:25 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:25 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Nuclear.Secrets.Set.Two.1of2.Vanunu.and.the.Bomb.x264.AC3.MVGroup.org.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:25 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Nuclear.Secrets.Set.Two.1of2.Vanunu.and.the.Bomb.x264.AC3.MVGroup.org.mkv
# 20:01:25 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Nuclear.Secrets.Set.Two.2of2.The.Terror.Trader.x264.AC3.MVGroup.org.mkv with title: BBC Organize - BBC.Nuclear.Secrets.Set.Two.2of2.The.Terror.Trader.x264.AC3.MVGroup.org
# 20:01:26 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:26 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Nuclear.Secrets.Set.Two.2of2.The.Terror.Trader.x264.AC3.MVGroup.org.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:26 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Nuclear.Secrets.Set.Two.2of2.The.Terror.Trader.x264.AC3.MVGroup.org.mkv
# 20:01:26 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Our.War.10.Years.in.Afghanistan.1of3.Ambushed.PDTV.x264.AAC.MVGroup.Forum.mkv with title: BBC Organize - BBC.Our.War.10.Years.in.Afghanistan.1of3.Ambushed.PDTV.x264.AAC.MVGroup.Forum
# 20:01:26 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:26 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Our.War.10.Years.in.Afghanistan.1of3.Ambushed.PDTV.x264.AAC.MVGroup.Forum.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:26 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Our.War.10.Years.in.Afghanistan.1of3.Ambushed.PDTV.x264.AAC.MVGroup.Forum.mkv
# 20:01:26 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Our.War.10.Years.in.Afghanistan.2of3.The.Invisible.Enemy.PDTV.x264.AAC.MVGroup.Forum.mkv with title: BBC Organize - BBC.Our.War.10.Years.in.Afghanistan.2of3.The.Invisible.Enemy.PDTV.x264.AAC.MVGroup.Forum
# 20:01:26 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:26 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Our.War.10.Years.in.Afghanistan.2of3.The.Invisible.Enemy.PDTV.x264.AAC.MVGroup.Forum.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:26 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Our.War.10.Years.in.Afghanistan.2of3.The.Invisible.Enemy.PDTV.x264.AAC.MVGroup.Forum.mkv
# 20:01:26 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Our.War.10.Years.in.Afghanistan.3of3.Caught.in.the.Crossfire.PDTV.x264.AAC.MVGroup.Forum.mkv with title: BBC Organize - BBC.Our.War.10.Years.in.Afghanistan.3of3.Caught.in.the.Crossfire.PDTV.x264.AAC.MVGroup.Forum
# 20:01:26 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:26 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Our.War.10.Years.in.Afghanistan.3of3.Caught.in.the.Crossfire.PDTV.x264.AAC.MVGroup.Forum.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:26 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Our.War.10.Years.in.Afghanistan.3of3.Caught.in.the.Crossfire.PDTV.x264.AAC.MVGroup.Forum.mkv
# 20:01:26 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Secret.Pakistan.1of2.Double.Cross.PDTV.x264.AAC.MVGroup.org.mkv with title: BBC Organize - BBC.Secret.Pakistan.1of2.Double.Cross.PDTV.x264.AAC.MVGroup.org
# 20:01:27 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:27 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Secret.Pakistan.1of2.Double.Cross.PDTV.x264.AAC.MVGroup.org.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:27 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Secret.Pakistan.1of2.Double.Cross.PDTV.x264.AAC.MVGroup.org.mkv
# 20:01:27 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Secret.Pakistan.2of2.Backlash.PDTV.x264.AAC.MVGroup.org.mkv with title: BBC Organize - BBC.Secret.Pakistan.2of2.Backlash.PDTV.x264.AAC.MVGroup.org
# 20:01:27 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:27 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Secret.Pakistan.2of2.Backlash.PDTV.x264.AAC.MVGroup.org.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:27 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Secret.Pakistan.2of2.Backlash.PDTV.x264.AAC.MVGroup.org.mkv
# 20:01:27 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Conspiracy.Files.The.Trump.Dossier.720p.HDTV.x264.AAC.MVGroup.org.mkv with title: BBC Organize - BBC.The.Conspiracy.Files.The.Trump.Dossier.720p.HDTV.x264.AAC.MVGroup.org
# 20:01:27 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:27 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Conspiracy.Files.The.Trump.Dossier.720p.HDTV.x264.AAC.MVGroup.org.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:27 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Conspiracy.Files.The.Trump.Dossier.720p.HDTV.x264.AAC.MVGroup.org.mkv
# 20:01:27 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Genius.of.Turner.720p.HDTV.x264.AAC.MVGroup.org.mkv with title: BBC Organize - BBC.The.Genius.of.Turner.720p.HDTV.x264.AAC.MVGroup.org
# 20:01:28 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:28 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Genius.of.Turner.720p.HDTV.x264.AAC.MVGroup.org.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:28 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Genius.of.Turner.720p.HDTV.x264.AAC.MVGroup.org.mkv
# 20:01:28 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Iraq.War.1of3.Regime.Change.576p.HDTV.x264.AAC.MVGroup.Forum.mkv with title: BBC Organize - BBC.The.Iraq.War.1of3.Regime.Change.576p.HDTV.x264.AAC.MVGroup.Forum
# 20:01:28 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:28 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Iraq.War.1of3.Regime.Change.576p.HDTV.x264.AAC.MVGroup.Forum.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:28 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Iraq.War.1of3.Regime.Change.576p.HDTV.x264.AAC.MVGroup.Forum.mkv
# 20:01:28 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Iraq.War.2of3.After.the.Fall.576p.HDTV.x264.AAC.MVGroup.Forum.mkv with title: BBC Organize - BBC.The.Iraq.War.2of3.After.the.Fall.576p.HDTV.x264.AAC.MVGroup.Forum
# 20:01:28 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:28 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Iraq.War.2of3.After.the.Fall.576p.HDTV.x264.AAC.MVGroup.Forum.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:28 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Iraq.War.2of3.After.the.Fall.576p.HDTV.x264.AAC.MVGroup.Forum.mkv
# 20:01:28 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Iraq.War.3of3.Its.Hell.Mr.President.576p.HDTV.x264.AAC.MVGroup.Forum.mkv with title: BBC Organize - BBC.The.Iraq.War.3of3.Its.Hell.Mr.President.576p.HDTV.x264.AAC.MVGroup.Forum
# 20:01:29 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:29 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Iraq.War.3of3.Its.Hell.Mr.President.576p.HDTV.x264.AAC.MVGroup.Forum.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:29 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Iraq.War.3of3.Its.Hell.Mr.President.576p.HDTV.x264.AAC.MVGroup.Forum.mkv
# 20:01:29 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Refugee.Camp.Our.Desert.Home.1of2.720p.HDTV.x264.AAC.MVGroup.org.mkv with title: BBC Organize - BBC.The.Refugee.Camp.Our.Desert.Home.1of2.720p.HDTV.x264.AAC.MVGroup.org
# 20:01:29 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:29 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Refugee.Camp.Our.Desert.Home.1of2.720p.HDTV.x264.AAC.MVGroup.org.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:29 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Refugee.Camp.Our.Desert.Home.1of2.720p.HDTV.x264.AAC.MVGroup.org.mkv
# 20:01:29 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Refugee.Camp.Our.Desert.Home.2of2.720p.HDTV.x264.AAC.MVGroup.org.mkv with title: BBC Organize - BBC.The.Refugee.Camp.Our.Desert.Home.2of2.720p.HDTV.x264.AAC.MVGroup.org
# 20:01:29 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:29 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Refugee.Camp.Our.Desert.Home.2of2.720p.HDTV.x264.AAC.MVGroup.org.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:29 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Refugee.Camp.Our.Desert.Home.2of2.720p.HDTV.x264.AAC.MVGroup.org.mkv
# 20:01:29 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\The Ape That Took Over The World (BBC).flv with title: BBC Organize - The Ape That Took Over The World (BBC)
# 20:01:29 - Encountered 403 Forbidden with reason "quotaExceeded"
# 20:01:29 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\The Ape That Took Over The World (BBC).flv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 20:01:29 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\The Ape That Took Over The World (BBC).flv
