# %%
import os
import glob
import logging
from datetime import datetime
from pathlib import Path
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
from google_auth_oauthlib.flow import InstalledAppFlow
from google.oauth2.credentials import Credentials
from google.auth.transport.requests import Request
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload
import tkinter as tk
from tkinter import filedialog

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(message)s',
    datefmt='%H:%M:%S',
    handlers=[
        logging.FileHandler('upload_all.log', encoding='utf-8'),
        logging.StreamHandler()
    ]
)

TOKEN_FILE = "token.json"
SCOPES = ["https://www.googleapis.com/auth/youtube.upload"]

os.environ['OAUTHLIB_INSECURE_TRANSPORT'] = '1'
os.environ['PYTHONHTTPSVERIFY'] = '0'

def get_authenticated_service(client_secrets_file: str):
    creds = None
    if os.path.exists(TOKEN_FILE):
        creds = Credentials.from_authorized_user_file(TOKEN_FILE, SCOPES)
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(client_secrets_file, SCOPES)
            creds = flow.run_local_server(port=0)
        with open(TOKEN_FILE, 'w') as token:
            token.write(creds.to_json())
    return build('youtube', 'v3', credentials=creds)

def upload_to_youtube(youtube, video_path: str, title: str, description: str = "Uploaded by script"):
    try:
        body = {
            'snippet': {
                'title': title,
                'description': description,
                'tags': ['tutorial', 'education']
            },
            'status': {
                'privacyStatus': 'unlisted',
                'selfDeclaredMadeForKids': False
            }
        }
        insert_request = youtube.videos().insert(
            part=','.join(body.keys()),
            body=body,
            media_body=MediaFileUpload(video_path, chunksize=-1, resumable=True)
        )
        response = None
        while response is None:
            status, response = insert_request.next_chunk()
            if status:
                logging.info(f"Upload {int(status.progress() * 100)}% complete for {video_path}")
        return response['id']
    except Exception as e:
        logging.error(f"Error uploading {video_path} to YouTube: {str(e)}")
        return None

def select_folder_dialog(title="Select the folder containing videos to upload"):
    root = tk.Tk()
    root.withdraw()
    folder_selected = filedialog.askdirectory(title=title)
    root.destroy()
    return folder_selected

def main():
    cwd = os.getcwd()
    client_secrets_file = os.path.join(cwd, "client_secret.dlc.json")
    if not os.path.exists(client_secrets_file):
        logging.error("Client secrets file not found")
        return
    youtube = get_authenticated_service(client_secrets_file)
    logging.info("YouTube authentication complete.")
    # Ask user for folder containing videos to upload
    input_folder = select_folder_dialog()
    if not input_folder or not os.path.exists(input_folder):
        logging.warning("No folder selected or path does not exist. Using current working directory.")
        input_folder = cwd
    folder_name = os.path.basename(input_folder)
    # Find all video files in the folder (no recursion)
    extensions = ("*.mp4", "*.avi", "*.mkv", "*.mov", "*.flv", "*.rmvb")
    video_files = []
    for ext in extensions:
        video_files.extend(glob.glob(os.path.join(input_folder, ext)))
    if not video_files:
        logging.info("No video files found in the folder.")
        return
    logging.info(f"Found {len(video_files)} videos to upload.")
    for video_path in video_files:
        video_name = os.path.splitext(os.path.basename(video_path))[0]
        title = f"{folder_name} - {video_name}"
        logging.info(f"Uploading: {video_path} with title: {title}")
        video_id = upload_to_youtube(youtube, video_path, title)
        if video_id:
            link_file = os.path.join(input_folder, f"{video_name}.txt")
            with open(link_file, 'w') as f:
                f.write(f"https://www.youtube.com/watch?v={video_id}\n")
            try:
                os.remove(video_path)
            except Exception as e:
                logging.error(f"Failed to delete uploaded video file: {video_path}: {str(e)}")
            logging.info(f"Upload successful! Video ID: {video_id}")
        else:
            logging.error(f"Upload failed for {video_path}")

main()
# Out:
# 22:56:26 - file_cache is only supported with oauth2client<4.0.0
# 22:56:27 - YouTube authentication complete.
# 22:56:36 - Found 522 videos to upload.
# 22:56:36 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1992 - Dodging Doomsday.mp4 with title: BBC Horizon - 1992 - Dodging Doomsday
# 22:57:40 - Upload successful! Video ID: 4fP5CVO8qmQ
# 22:57:40 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1996 - Aliens From Mars.mp4 with title: BBC Horizon - 1996 - Aliens From Mars
# 22:59:04 - Upload successful! Video ID: EvmwEBJYDVU
# 22:59:04 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\2010 - Diet - A Horizon Guide.mp4 with title: BBC Horizon - 2010 - Diet - A Horizon Guide
# 23:00:43 - Upload successful! Video ID: 7DdULrnElfw
# 23:00:43 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Impact a Horizon Guide to Car Crashes.mp4 with title: BBC Horizon - Impact a Horizon Guide to Car Crashes
# 23:05:19 - Upload successful! Video ID: l_sqnttqjKY
# 23:05:19 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Killer in the Village.mp4 with title: BBC Horizon - Killer in the Village
# 23:08:19 - Upload successful! Video ID: i6lLeEvVO2E
# 23:08:19 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Mars Alive.mp4 with title: BBC Horizon - Mars Alive
# 23:09:26 - Upload successful! Video ID: Fd8_fBWPZ9Q
# 23:09:26 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Meditation and the Mind.mp4 with title: BBC Horizon - Meditation and the Mind
# 23:10:37 - Upload successful! Video ID: mmnoxNjBFy4
# 23:10:37 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Nanotopia.mp4 with title: BBC Horizon - Nanotopia
# 23:11:39 - Upload successful! Video ID: VJcnYQj12IY
# 23:11:39 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Navajo - The Last Red Indians.mp4 with title: BBC Horizon - Navajo - The Last Red Indians
# 23:13:44 - Upload successful! Video ID: Y95k7IyUa1U
# 23:13:44 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Pandemic_ A Horizon Guide.mp4 with title: BBC Horizon - Pandemic_ A Horizon Guide
# 23:15:38 - Upload successful! Video ID: BpSK7G0q0uc
# 23:15:38 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Porn Whats The Harm (720p).mp4 with title: BBC Horizon - Porn Whats The Harm (720p)
# 23:23:49 - Upload successful! Video ID: jPaVx8FZogE
# 23:23:49 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Psychedelic Science.mp4 with title: BBC Horizon - Psychedelic Science
# 23:24:49 - Upload successful! Video ID: XhI7iHrXmdQ
# 23:24:49 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Rail Crash.mp4 with title: BBC Horizon - Rail Crash
# 23:28:49 - Upload successful! Video ID: 9u-yfl0kxPs
# 23:28:49 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Sex_ A Horizon Guide.mp4 with title: BBC Horizon - Sex_ A Horizon Guide
# 23:33:22 - Upload successful! Video ID: H-0k0hdtte4
# 23:33:22 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Signs of Life.mp4 with title: BBC Horizon - Signs of Life
# 23:36:21 - Upload successful! Video ID: mimqvoCN0P0
# 23:36:21 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Some Like It Hot.mp4 with title: BBC Horizon - Some Like It Hot
# 23:37:20 - Upload successful! Video ID: TY9g7JlhUKk
# 23:37:20 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Taking the Credit.mp4 with title: BBC Horizon - Taking the Credit
# 23:38:21 - Upload successful! Video ID: HdBaVWZ2za0
# 23:38:21 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\The Case of The Ancient Astronauts.mp4 with title: BBC Horizon - The Case of The Ancient Astronauts
# 23:40:20 - Upload successful! Video ID: Jt70eH3wKVM
# 23:40:20 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\The Knowledge Explosion.mp4 with title: BBC Horizon - The Knowledge Explosion
# 23:40:50 - Upload successful! Video ID: kVdIf_Ur9vM
# 23:40:50 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\The Lysenko Affair.mp4 with title: BBC Horizon - The Lysenko Affair
# 23:43:24 - Upload successful! Video ID: 3QiuKB4SRFc
# 23:43:24 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\The Making of a Natural History Film.mp4 with title: BBC Horizon - The Making of a Natural History Film
# 23:46:12 - Upload successful! Video ID: 9SCAc17f9nk
# 23:46:12 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\The Race Against Time.mp4 with title: BBC Horizon - The Race Against Time
# 23:46:40 - Upload successful! Video ID: dDB1k55UkN0
# 23:46:40 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\The Secrets of Sleep.mp4 with title: BBC Horizon - The Secrets of Sleep
# 23:49:34 - Upload successful! Video ID: DKt3I0khdeQ
# 23:49:34 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Too Big Too Soon.mp4 with title: BBC Horizon - Too Big Too Soon
# 23:50:34 - Upload successful! Video ID: ktppyMzf7q8
# 23:50:34 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Whatever Happened to Star Wars.mp4 with title: BBC Horizon - Whatever Happened to Star Wars
# 23:51:28 - Upload successful! Video ID: b45lSmDdzCc
# 23:51:28 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Where Did the Colorado Go.mp4 with title: BBC Horizon - Where Did the Colorado Go
# 23:54:55 - Upload successful! Video ID: 2JEtaR4Z74c
# 23:54:55 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Worlds in Collision.mp4 with title: BBC Horizon - Worlds in Collision
# 23:55:55 - Upload successful! Video ID: LVcr13We-sE
# 23:55:55 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1980 - Anatomy of A Volcano.avi with title: BBC Horizon - 1980 - Anatomy of A Volcano
# 00:00:07 - Upload successful! Video ID: XvHwCMnpmZc
# 00:00:07 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1980 - Behind The Horoscope.avi with title: BBC Horizon - 1980 - Behind The Horoscope
# 00:04:27 - Upload successful! Video ID: Rov0YUhX7pw
# 00:04:27 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1980 - Beyond The Milky Way.avi with title: BBC Horizon - 1980 - Beyond The Milky Way
# 00:07:54 - Upload successful! Video ID: Up87OiIkGfg
# 00:07:54 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1980 - Encounter With Jupiter.avi with title: BBC Horizon - 1980 - Encounter With Jupiter
# 00:12:10 - Upload successful! Video ID: jy-zcZVvn0U
# 00:12:10 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1981 - Death of The Dinosaurs.avi with title: BBC Horizon - 1981 - Death of The Dinosaurs
# 00:16:39 - Upload successful! Video ID: wIGnITVBjx4
# 00:16:39 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1981 - Did Darwin Get It Wrong.avi with title: BBC Horizon - 1981 - Did Darwin Get It Wrong
# 00:20:46 - Upload successful! Video ID: byzsYhN0nTE
# 00:20:46 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1981 - Gentlemen, Lift Your Skirts.avi with title: BBC Horizon - 1981 - Gentlemen, Lift Your Skirts
# 00:23:19 - Upload successful! Video ID: EuZ7_hlUOzg
# 00:23:19 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1982 - 25 Years In Space.avi with title: BBC Horizon - 1982 - 25 Years In Space
# 00:30:03 - Upload successful! Video ID: 8ykKt-m5opw
# 00:30:03 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1982 - Hard Feynman Interview.avi with title: BBC Horizon - 1982 - Hard Feynman Interview
# 00:30:35 - Upload successful! Video ID: -PtaHvnOxCg
# 00:30:35 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1983 - A Child's Guide To Languages.avi with title: BBC Horizon - 1983 - A Child's Guide To Languages
# 00:34:48 - Upload successful! Video ID: w7LlKEMuTZk
# 00:34:48 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1983 - Better Mind The Computer.avi with title: BBC Horizon - 1983 - Better Mind The Computer
# 00:38:26 - Upload successful! Video ID: FIppfd3RD-U
# 00:38:26 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1984 - A Mathematical Mystery Tour.avi with title: BBC Horizon - 1984 - A Mathematical Mystery Tour
# 00:40:56 - Upload successful! Video ID: 7_03qSCy0M4
# 00:40:56 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1984 - Beyond The Moon.avi with title: BBC Horizon - 1984 - Beyond The Moon
# 00:44:10 - Upload successful! Video ID: on3PrmqoZIY
# 00:44:10 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1984 - Biology At War - A Plague In The Wind.avi with title: BBC Horizon - 1984 - Biology At War - A Plague In The Wind
# 00:48:37 - Upload successful! Video ID: QOT7gMf1Vpk
# 00:48:37 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1985 - Colourful Notions.avi with title: BBC Horizon - 1985 - Colourful Notions
# 00:53:15 - Upload successful! Video ID: p_j5W3_wD5A
# 00:53:15 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1985 - Halley's Comet - The Apparition.avi with title: BBC Horizon - 1985 - Halley's Comet - The Apparition
# 00:57:19 - Upload successful! Video ID: Zd5Dj6KnSwg
# 00:57:19 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1985 - How To Film the Impossible.avi with title: BBC Horizon - 1985 - How To Film the Impossible
# 00:59:36 - Upload successful! Video ID: 6J0XwiH0Ad4
# 00:59:36 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1986 - Genesis.avi with title: BBC Horizon - 1986 - Genesis
# 01:03:16 - Upload successful! Video ID: lZeelbN4Q9g
# 01:03:16 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1987 - Aircrash The Burning Issue.avi with title: BBC Horizon - 1987 - Aircrash The Burning Issue
# 01:07:16 - Upload successful! Video ID: oryXWLAdA1I
# 01:07:16 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1987 - Bruno Bettelheim - A Sense of Surviving.avi with title: BBC Horizon - 1987 - Bruno Bettelheim - A Sense of Surviving
# 01:09:06 - Upload successful! Video ID: oWoPod9UTOU
# 01:09:06 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1987 - Bruno Bettelheim - The Man Who Cared For Children.avi with title: BBC Horizon - 1987 - Bruno Bettelheim - The Man Who Cared For Children
# 01:13:24 - Upload successful! Video ID: _SGIxqTkjug
# 01:13:24 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1987 - Can AIDS Be Stopped.avi with title: BBC Horizon - 1987 - Can AIDS Be Stopped
# 01:16:38 - Upload successful! Video ID: L4UMZ9fcnFQ
# 01:16:38 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1988 - A Good Test.avi with title: BBC Horizon - 1988 - A Good Test
# 01:19:50 - Upload successful! Video ID: zmTzh2ttXDk
# 01:19:50 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1988 - A Newsday Revolution.avi with title: BBC Horizon - 1988 - A Newsday Revolution
# 01:21:52 - Upload successful! Video ID: NbmK-OvS-5U
# 01:21:52 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1988 - Cancer At Bay.avi with title: BBC Horizon - 1988 - Cancer At Bay
# 01:23:46 - Upload successful! Video ID: P5nXGV9EMw0
# 01:23:46 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1988 - Death of A Star.avi with title: BBC Horizon - 1988 - Death of A Star
# 01:26:10 - Upload successful! Video ID: q7xEcyiEwwY
# 01:26:10 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1988 - Death of the Working Classes.avi with title: BBC Horizon - 1988 - Death of the Working Classes
# 01:27:16 - Upload successful! Video ID: 8NumRPG8soY
# 01:27:16 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1988 - Easter Island The Secrets.avi with title: BBC Horizon - 1988 - Easter Island The Secrets
# 01:29:51 - Upload successful! Video ID: ulzaHqxACVo
# 01:29:51 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1988 - Easter Island The Story.avi with title: BBC Horizon - 1988 - Easter Island The Story
# 01:32:28 - Upload successful! Video ID: JlWQTmKpIs4
# 01:32:28 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1988 - Greenhouse Effect.avi with title: BBC Horizon - 1988 - Greenhouse Effect
# 01:36:55 - Upload successful! Video ID: ibCf4Op3Vp4
# 01:36:55 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1988 - The Canal In The Jungle.avi with title: BBC Horizon - 1988 - The Canal In The Jungle
# 01:40:10 - Upload successful! Video ID: RpBLtRaA8-c
# 01:40:10 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1989 - Concerto.avi with title: BBC Horizon - 1989 - Concerto
# 01:40:10 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:40:10 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1989 - Concerto.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:40:10 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1989 - Concerto.avi
# 01:40:10 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1989 - Crash.avi with title: BBC Horizon - 1989 - Crash
# 01:40:10 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:40:10 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1989 - Crash.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:40:10 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1989 - Crash.avi
# 01:40:10 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1989 - Gaze In Wonder.avi with title: BBC Horizon - 1989 - Gaze In Wonder
# 01:40:11 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:40:11 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1989 - Gaze In Wonder.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:40:11 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1989 - Gaze In Wonder.avi
# 01:40:11 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1990 - AIDS - A Quest For A Cure.avi with title: BBC Horizon - 1990 - AIDS - A Quest For A Cure
# 01:40:11 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:40:11 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1990 - AIDS - A Quest For A Cure.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:40:11 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1990 - AIDS - A Quest For A Cure.avi
# 01:40:11 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1990 - Cold Fusion.avi with title: BBC Horizon - 1990 - Cold Fusion
# 01:40:11 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:40:11 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1990 - Cold Fusion.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:40:11 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1990 - Cold Fusion.avi
# 01:40:11 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1990 - Encounter With Neptune.avi with title: BBC Horizon - 1990 - Encounter With Neptune
# 01:40:11 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:40:11 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1990 - Encounter With Neptune.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:40:11 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1990 - Encounter With Neptune.avi
# 01:40:11 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1990 - From Earth To Miranda.avi with title: BBC Horizon - 1990 - From Earth To Miranda
# 01:40:11 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:40:11 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1990 - From Earth To Miranda.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:40:11 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1990 - From Earth To Miranda.avi
# 01:40:11 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1990 - Hurricane!.avi with title: BBC Horizon - 1990 - Hurricane!
# 01:40:11 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:40:11 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1990 - Hurricane!.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:40:11 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1990 - Hurricane!.avi
# 01:40:11 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1991 - Colonising Cyberspace.avi with title: BBC Horizon - 1991 - Colonising Cyberspace
# 01:40:11 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:40:12 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1991 - Colonising Cyberspace.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:40:12 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1991 - Colonising Cyberspace.avi
# 01:40:12 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1991 - Emerging Viruses.avi with title: BBC Horizon - 1991 - Emerging Viruses
# 01:40:12 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:40:12 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1991 - Emerging Viruses.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:40:12 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1991 - Emerging Viruses.avi
# 01:40:12 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1992 - A Close Encounter of The Second Kind.avi with title: BBC Horizon - 1992 - A Close Encounter of The Second Kind
# 01:40:12 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:40:12 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1992 - A Close Encounter of The Second Kind.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:40:12 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1992 - A Close Encounter of The Second Kind.avi
# 01:40:12 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1992 - An Expensive Theology.avi with title: BBC Horizon - 1992 - An Expensive Theology
# 01:40:12 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:40:12 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1992 - An Expensive Theology.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:40:12 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1992 - An Expensive Theology.avi
# 01:40:12 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1992 - Before Babel.avi with title: BBC Horizon - 1992 - Before Babel
# 01:42:43 - Upload successful! Video ID: GpKxUoE1ghQ
# 01:42:43 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1992 - Hide And Seek In Iraq.avi with title: BBC Horizon - 1992 - Hide And Seek In Iraq
# 01:42:43 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:42:43 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1992 - Hide And Seek In Iraq.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:42:43 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1992 - Hide And Seek In Iraq.avi
# 01:42:43 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1992 - Hitler's Bomb.avi with title: BBC Horizon - 1992 - Hitler's Bomb
# 01:42:44 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:42:44 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1992 - Hitler's Bomb.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:42:44 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1992 - Hitler's Bomb.avi
# 01:42:44 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1992 - Hot Jam In The Doughnut.avi with title: BBC Horizon - 1992 - Hot Jam In The Doughnut
# 01:42:44 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:42:44 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1992 - Hot Jam In The Doughnut.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:42:44 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1992 - Hot Jam In The Doughnut.avi
# 01:42:44 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1993 - A Vital Poison.avi with title: BBC Horizon - 1993 - A Vital Poison
# 01:42:44 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:42:44 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1993 - A Vital Poison.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:42:44 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1993 - A Vital Poison.avi
# 01:42:44 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1993 - Allergic To The 20th Century.avi with title: BBC Horizon - 1993 - Allergic To The 20th Century
# 01:42:44 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:42:44 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1993 - Allergic To The 20th Century.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:42:44 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1993 - Allergic To The 20th Century.avi
# 01:42:44 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1993 - Awakening The Frozen Addicts.avi with title: BBC Horizon - 1993 - Awakening The Frozen Addicts
# 01:42:44 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:42:44 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1993 - Awakening The Frozen Addicts.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:42:44 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1993 - Awakening The Frozen Addicts.avi
# 01:42:44 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1993 - Chimp Talk.avi with title: BBC Horizon - 1993 - Chimp Talk
# 01:42:44 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:42:44 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1993 - Chimp Talk.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:42:44 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1993 - Chimp Talk.avi
# 01:42:44 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1993 - Dante Goes To Hell.avi with title: BBC Horizon - 1993 - Dante Goes To Hell
# 01:42:44 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:42:44 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1993 - Dante Goes To Hell.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:42:44 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1993 - Dante Goes To Hell.avi
# 01:42:44 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1993 - Ghost In The Dinosaur Graveyard.avi with title: BBC Horizon - 1993 - Ghost In The Dinosaur Graveyard
# 01:42:45 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:42:45 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1993 - Ghost In The Dinosaur Graveyard.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:42:45 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1993 - Ghost In The Dinosaur Graveyard.avi
# 01:42:45 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1993 - Here Be Monsters.avi with title: BBC Horizon - 1993 - Here Be Monsters
# 01:42:45 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:42:45 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1993 - Here Be Monsters.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:42:45 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1993 - Here Be Monsters.avi
# 01:42:45 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1994 - Against The Clock.avi with title: BBC Horizon - 1994 - Against The Clock
# 01:42:45 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:42:45 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1994 - Against The Clock.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:42:45 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1994 - Against The Clock.avi
# 01:42:45 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1994 - Auschwitz The Blueprint of Genocide.avi with title: BBC Horizon - 1994 - Auschwitz The Blueprint of Genocide
# 01:42:45 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:42:45 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1994 - Auschwitz The Blueprint of Genocide.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:42:45 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1994 - Auschwitz The Blueprint of Genocide.avi
# 01:42:45 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1994 - Close Encounters.avi with title: BBC Horizon - 1994 - Close Encounters
# 01:42:45 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:42:45 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1994 - Close Encounters.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:42:45 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1994 - Close Encounters.avi
# 01:42:45 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1994 - Death Wish - The Untold Story.avi with title: BBC Horizon - 1994 - Death Wish - The Untold Story
# 01:42:45 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:42:45 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1994 - Death Wish - The Untold Story.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:42:45 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1994 - Death Wish - The Untold Story.avi
# 01:42:45 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1994 - Designer Wines.avi with title: BBC Horizon - 1994 - Designer Wines
# 01:42:45 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:42:45 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1994 - Designer Wines.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:42:45 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1994 - Designer Wines.avi
# 01:42:45 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1994 - Genie.avi with title: BBC Horizon - 1994 - Genie
# 01:42:46 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:42:46 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1994 - Genie.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:42:46 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1994 - Genie.avi
# 01:42:46 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1994 - Hubble Vision.avi with title: BBC Horizon - 1994 - Hubble Vision
# 01:42:46 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:42:46 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1994 - Hubble Vision.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:42:46 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1994 - Hubble Vision.avi
# 01:42:46 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1994 - Whispers of Creation.avi with title: BBC Horizon - 1994 - Whispers of Creation
# 01:42:46 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:42:46 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1994 - Whispers of Creation.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:42:46 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1994 - Whispers of Creation.avi
# 01:42:46 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1995 - A Code In The Nose.avi with title: BBC Horizon - 1995 - A Code In The Nose
# 01:42:46 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:42:46 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1995 - A Code In The Nose.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:42:46 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1995 - A Code In The Nose.avi
# 01:42:46 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1995 - AIDS - Behind Closed Doors.avi with title: BBC Horizon - 1995 - AIDS - Behind Closed Doors
# 01:42:46 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:42:46 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1995 - AIDS - Behind Closed Doors.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:42:46 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1995 - AIDS - Behind Closed Doors.avi
# 01:42:46 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1995 - Bones of Contention.avi with title: BBC Horizon - 1995 - Bones of Contention
# 01:42:46 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:42:46 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1995 - Bones of Contention.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:42:46 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1995 - Bones of Contention.avi
# 01:42:46 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1995 - Exodus.avi with title: BBC Horizon - 1995 - Exodus
# ...
# 01:48:40 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\To Infinity and Beyond (720p).mkv
# 01:48:40 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Tomorrows World (720p).mkv with title: BBC Horizon - Tomorrows World (720p)
# 01:48:40 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:48:40 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Tomorrows World (720p).mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:48:40 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Tomorrows World (720p).mkv
# 01:48:40 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Total Isolation.mkv with title: BBC Horizon - Total Isolation
# 01:48:41 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:48:41 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Total Isolation.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:48:41 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Total Isolation.mkv
# 01:48:41 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\What is One Degree (720p).mkv with title: BBC Horizon - What is One Degree (720p)
# 01:48:41 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:48:41 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\What is One Degree (720p).mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:48:41 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\What is One Degree (720p).mkv
# 01:48:41 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\What Is Reality (720p).mkv with title: BBC Horizon - What Is Reality (720p)
# 01:48:41 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:48:41 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\What Is Reality (720p).mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:48:41 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\What Is Reality (720p).mkv
# 01:48:41 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\What Makes a Genius (720p).mkv with title: BBC Horizon - What Makes a Genius (720p)
# 01:48:41 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:48:41 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\What Makes a Genius (720p).mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:48:41 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\What Makes a Genius (720p).mkv
# 01:48:41 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\What Makes Us Clever A Horizon Guide to Intelligence.mkv with title: BBC Horizon - What Makes Us Clever A Horizon Guide to Intelligence
# 01:48:41 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:48:41 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\What Makes Us Clever A Horizon Guide to Intelligence.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:48:41 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\What Makes Us Clever A Horizon Guide to Intelligence.mkv
# 01:48:41 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\What Makes Us Human (720p).mkv with title: BBC Horizon - What Makes Us Human (720p)
# 01:48:41 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:48:41 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\What Makes Us Human (720p).mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:48:41 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\What Makes Us Human (720p).mkv
# 01:48:41 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Whats Killing Our Bees (720p).mkv with title: BBC Horizon - Whats Killing Our Bees (720p)
# 01:48:41 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:48:41 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Whats Killing Our Bees (720p).mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:48:41 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Whats Killing Our Bees (720p).mkv
# 01:48:41 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Whats the Problem with Nudity.mkv with title: BBC Horizon - Whats the Problem with Nudity
# 01:48:41 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:48:41 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Whats the Problem with Nudity.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:48:41 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Whats the Problem with Nudity.mkv
# 01:48:41 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Wheres My Robot.mkv with title: BBC Horizon - Wheres My Robot
# 01:48:42 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:48:42 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Wheres My Robot.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:48:42 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Wheres My Robot.mkv
# 01:48:42 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Who's Afraid of a Big Black Hole (720p).mkv with title: BBC Horizon - Who's Afraid of a Big Black Hole (720p)
# 01:48:42 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:48:42 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Who's Afraid of a Big Black Hole (720p).mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:48:42 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Who's Afraid of a Big Black Hole (720p).mkv
# 01:48:42 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Why Are Thin People Not Fat.mkv with title: BBC Horizon - Why Are Thin People Not Fat
# 01:48:42 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:48:42 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Why Are Thin People Not Fat.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:48:42 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Why Are Thin People Not Fat.mkv
# 01:48:42 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Why Cant We Predict Earthquakes (720p).mkv with title: BBC Horizon - Why Cant We Predict Earthquakes (720p)
# 01:48:42 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:48:42 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Why Cant We Predict Earthquakes (720p).mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:48:42 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Why Cant We Predict Earthquakes (720p).mkv
# 01:48:42 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Why Do Viruses Kill (720p).mkv with title: BBC Horizon - Why Do Viruses Kill (720p)
# 01:48:42 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:48:42 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Why Do Viruses Kill (720p).mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:48:42 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Why Do Viruses Kill (720p).mkv
# 01:48:42 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Why Do We Dream.mkv with title: BBC Horizon - Why Do We Dream
# 01:48:42 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:48:42 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Why Do We Dream.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:48:42 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\Why Do We Dream.mkv
# 01:48:42 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1999 - From Here To Infinity.mov with title: BBC Horizon - 1999 - From Here To Infinity
# 01:48:42 - Encountered 403 Forbidden with reason "quotaExceeded"
# 01:48:42 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1999 - From Here To Infinity.mov to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 01:48:42 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs/BBC/BBC Horizon\1999 - From Here To Infinity.mov
