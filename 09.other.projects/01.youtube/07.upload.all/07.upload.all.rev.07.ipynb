# %%
import os
import sys
import glob
import logging
from datetime import datetime
from pathlib import Path
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import tkinter as tk
from tkinter import filedialog
from google_auth_oauthlib.flow import InstalledAppFlow
from google.oauth2.credentials import Credentials
from google.auth.transport.requests import Request
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload
import time

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(message)s',
    datefmt='%H:%M:%S',
    handlers=[
        logging.FileHandler('upload_all.log', encoding='utf-8'),
        logging.StreamHandler()
    ]
)

TOKEN_FILE = "token.json"
SCOPES = ["https://www.googleapis.com/auth/youtube.upload"]

os.environ['OAUTHLIB_INSECURE_TRANSPORT'] = '1'
os.environ['PYTHONHTTPSVERIFY'] = '0'

def get_authenticated_service(client_secrets_file: str):
    creds = None
    if os.path.exists(TOKEN_FILE):
        creds = Credentials.from_authorized_user_file(TOKEN_FILE, SCOPES)
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(client_secrets_file, SCOPES)
            creds = flow.run_local_server(port=0)
        with open(TOKEN_FILE, 'w') as token:
            token.write(creds.to_json())
    return build('youtube', 'v3', credentials=creds)

def upload_to_youtube(youtube, video_path: str, title: str, description: str = "Uploaded by script"):
    MAX_RETRIES = 3
    RETRY_DELAY_SECONDS = 180  # 3 minutes
    for attempt in range(1, MAX_RETRIES + 1):
        try:
            body = {
                'snippet': {
                    'title': title,
                    'description': description,
                    'tags': ['tutorial', 'education']
                },
                'status': {
                    'privacyStatus': 'unlisted',
                    'selfDeclaredMadeForKids': False
                }
            }
            insert_request = youtube.videos().insert(
                part=','.join(body.keys()),
                body=body,
                media_body=MediaFileUpload(video_path, chunksize=-1, resumable=True)
            )
            response = None
            while response is None:
                status, response = insert_request.next_chunk()
                if status:
                    logging.info(f"Upload {int(status.progress() * 100)}% complete for {video_path}")
            return response['id']
        except Exception as e:
            logging.error(f"Error uploading {video_path} to YouTube (attempt {attempt}): {str(e)}")
            if attempt < MAX_RETRIES:
                logging.info(f"Retrying upload for {video_path} in {RETRY_DELAY_SECONDS // 60} minutes...")
                time.sleep(RETRY_DELAY_SECONDS)
            else:
                logging.error(f"Upload failed for {video_path} after {MAX_RETRIES} attempts.")
                return None

def select_folder_dialog(title="Select folder"):
    """Open a folder selection dialog and return the selected path."""
    try:
        root = tk.Tk()
        root.withdraw()
        root.update_idletasks()
        width = root.winfo_screenwidth()
        height = root.winfo_screenheight()
        x = (width - 400) // 2
        y = (height - 300) // 2
        root.geometry(f'400x300+{x}+{y}')
        folder_path = filedialog.askdirectory(
            title=title,
            mustexist=True
        )
        root.destroy()
        return folder_path
    except Exception as e:
        logging.error(f"Error in folder selection: {str(e)}")
        return None

def main():
    # Select parent folder
    parent_folder = select_folder_dialog(title="Select parent folder containing videos to upload recursively")
    if not parent_folder or not os.path.exists(parent_folder):
        logging.error("No folder selected or folder does not exist")
        return
    cwd = os.getcwd()
    client_secrets_file = os.path.join(cwd, "client_secret.dlc.json")
    if not os.path.exists(client_secrets_file):
        logging.error(f"Client secrets file not found at: {client_secrets_file}")
        return
    youtube = get_authenticated_service(client_secrets_file)
    logging.info("YouTube authentication complete.")
    VIDEO_EXTENSIONS = ('.mp4', '.mkv', '.avi', '.mov', '.wmv', '.flv', '.webm')
    for root, _, files in os.walk(parent_folder):
        for file in files:
            if file.lower().endswith(VIDEO_EXTENSIONS) and not file.endswith('.txt'):
                video_path = os.path.join(root, file)
                video_name = os.path.splitext(file)[0]
                link_file = os.path.join(root, f"{video_name}.txt")
                if not os.path.exists(link_file):
                    folder_name = os.path.basename(root)
                    MAX_TITLE_LENGTH = 100
                    title = f"{folder_name} - {video_name}"
                    if len(title) > MAX_TITLE_LENGTH:
                        title = title[:MAX_TITLE_LENGTH]
                    logging.info(f"Uploading: {video_path} with title: {title}")
                    video_id = upload_to_youtube(youtube, video_path, title)
                    if video_id:
                        with open(link_file, 'w') as f:
                            f.write(f"https://www.youtube.com/watch?v={video_id}\n")
                        try:
                            os.remove(video_path)
                        except Exception as e:
                            logging.error(f"Failed to delete uploaded video file: {video_path}: {str(e)}")
                        logging.info(f"Upload successful! Video ID: {video_id}")
                    else:
                        logging.error(f"Upload failed for {video_path}")
                else:
                    logging.info(f"Link file already exists for {video_path}. Skipping upload.")
    logging.info("All specified folders and subfolders processed.")

if __name__ == "__main__":
    main()
# Out:
# 08:53:57 - file_cache is only supported with oauth2client<4.0.0
# 08:53:57 - YouTube authentication complete.
# 08:53:57 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Anthropologists\Jared Diamond\Skeptics.Lecture.Dr.Jared.Diamond.The.Great.Leap.Forward.Xvid.MP3.avi with title: Jared Diamond - Skeptics.Lecture.Dr.Jared.Diamond.The.Great.Leap.Forward.Xvid.MP3
# 08:56:13 - Upload successful! Video ID: B4CFpEnb0ac
# 08:56:13 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Psychology Edu\Lectures And Courses\Psych 1\Psych 1 - General Psychology - Lecture 1.mkv with title: Psych 1 - Psych 1 - General Psychology - Lecture 1
# 08:56:39 - Upload successful! Video ID: EYgzwQSX9hw
# 08:56:39 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Psychology Edu\Lectures And Courses\Psych 1\Psych 1 - General Psychology - Lecture 10.mkv with title: Psych 1 - Psych 1 - General Psychology - Lecture 10
# 08:57:01 - Upload successful! Video ID: YXGfobPL0k0
# 08:57:01 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Psychology Edu\Lectures And Courses\Psych 1\Psych 1 - General Psychology - Lecture 11.mkv with title: Psych 1 - Psych 1 - General Psychology - Lecture 11
# 08:57:25 - Upload successful! Video ID: 54rnij3fKvc
# 08:57:25 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Psychology Edu\Lectures And Courses\Psych 1\Psych 1 - General Psychology - Lecture 12.mkv with title: Psych 1 - Psych 1 - General Psychology - Lecture 12
# 08:57:51 - Upload successful! Video ID: YTZFp3tUJzE
# 08:57:51 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Psychology Edu\Lectures And Courses\Psych 1\Psych 1 - General Psychology - Lecture 13.mkv with title: Psych 1 - Psych 1 - General Psychology - Lecture 13
# 08:58:14 - Upload successful! Video ID: uoRkexlCTyk
# 08:58:14 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Psychology Edu\Lectures And Courses\Psych 1\Psych 1 - General Psychology - Lecture 14.mkv with title: Psych 1 - Psych 1 - General Psychology - Lecture 14
# 08:58:38 - Upload successful! Video ID: qEcl_vIuOpM
# 08:58:38 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Psychology Edu\Lectures And Courses\Psych 1\Psych 1 - General Psychology - Lecture 15.mkv with title: Psych 1 - Psych 1 - General Psychology - Lecture 15
# 08:59:05 - Upload successful! Video ID: HWveQWUU_VY
# 08:59:05 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Psychology Edu\Lectures And Courses\Psych 1\Psych 1 - General Psychology - Lecture 16.mkv with title: Psych 1 - Psych 1 - General Psychology - Lecture 16
# 08:59:28 - Upload successful! Video ID: 2xvjhA6LC40
# 08:59:28 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Psychology Edu\Lectures And Courses\Psych 1\Psych 1 - General Psychology - Lecture 17.mkv with title: Psych 1 - Psych 1 - General Psychology - Lecture 17
# 08:59:52 - Upload successful! Video ID: VNCbusi2NBs
# 08:59:52 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Psychology Edu\Lectures And Courses\Psych 1\Psych 1 - General Psychology - Lecture 18.mkv with title: Psych 1 - Psych 1 - General Psychology - Lecture 18
# 09:00:09 - Upload successful! Video ID: D91mK3LRjoA
# 09:00:09 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Psychology Edu\Lectures And Courses\Psych 1\Psych 1 - General Psychology - Lecture 2.mkv with title: Psych 1 - Psych 1 - General Psychology - Lecture 2
# 09:00:27 - Upload successful! Video ID: GpBcusksrSs
# 09:00:27 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Psychology Edu\Lectures And Courses\Psych 1\Psych 1 - General Psychology - Lecture 20.mkv with title: Psych 1 - Psych 1 - General Psychology - Lecture 20
# 09:00:53 - Upload successful! Video ID: OnCQyA6LQws
# 09:00:53 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Psychology Edu\Lectures And Courses\Psych 1\Psych 1 - General Psychology - Lecture 21.mkv with title: Psych 1 - Psych 1 - General Psychology - Lecture 21
# 09:01:18 - Upload successful! Video ID: -daYFVkGpOM
# 09:01:18 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Psychology Edu\Lectures And Courses\Psych 1\Psych 1 - General Psychology - Lecture 22.mkv with title: Psych 1 - Psych 1 - General Psychology - Lecture 22
# 09:01:43 - Upload successful! Video ID: QPlD_NY75sw
# 09:01:43 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Psychology Edu\Lectures And Courses\Psych 1\Psych 1 - General Psychology - Lecture 23.mkv with title: Psych 1 - Psych 1 - General Psychology - Lecture 23
# 09:02:09 - Upload successful! Video ID: TZqWOnHF_ns
# 09:02:09 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Psychology Edu\Lectures And Courses\Psych 1\Psych 1 - General Psychology - Lecture 24.mkv with title: Psych 1 - Psych 1 - General Psychology - Lecture 24
# 09:02:34 - Upload successful! Video ID: JAZxjWMA3dI
# 09:02:34 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Psychology Edu\Lectures And Courses\Psych 1\Psych 1 - General Psychology - Lecture 25.mkv with title: Psych 1 - Psych 1 - General Psychology - Lecture 25
# 09:02:48 - Upload successful! Video ID: WmeoI-qIFC4
# 09:02:48 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Psychology Edu\Lectures And Courses\Psych 1\Psych 1 - General Psychology - Lecture 3.mkv with title: Psych 1 - Psych 1 - General Psychology - Lecture 3
# 09:03:12 - Upload successful! Video ID: 0twcX_rYJhg
# 09:03:12 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Psychology Edu\Lectures And Courses\Psych 1\Psych 1 - General Psychology - Lecture 4.mkv with title: Psych 1 - Psych 1 - General Psychology - Lecture 4
# 09:03:38 - Upload successful! Video ID: XPplGMY2j-0
# 09:03:38 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Psychology Edu\Lectures And Courses\Psych 1\Psych 1 - General Psychology - Lecture 5.mkv with title: Psych 1 - Psych 1 - General Psychology - Lecture 5
# 09:04:04 - Upload successful! Video ID: X-V7_Si70nU
# 09:04:04 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Psychology Edu\Lectures And Courses\Psych 1\Psych 1 - General Psychology - Lecture 6.mkv with title: Psych 1 - Psych 1 - General Psychology - Lecture 6
# 09:04:29 - Upload successful! Video ID: 4DeKmPQQrv4
# 09:04:29 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Psychology Edu\Lectures And Courses\Psych 1\Psych 1 - General Psychology - Lecture 7.mkv with title: Psych 1 - Psych 1 - General Psychology - Lecture 7
# 09:04:57 - Upload successful! Video ID: 3PXyoft7hQw
# 09:04:57 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Psychology Edu\Lectures And Courses\Psych 1\Psych 1 - General Psychology - Lecture 8.mkv with title: Psych 1 - Psych 1 - General Psychology - Lecture 8
# 09:05:20 - Upload successful! Video ID: VQD4JBlKGh4
# 09:05:20 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Psychology Edu\Lectures And Courses\Psych 1\Psych 1 - General Psychology - Lecture 9.mkv with title: Psych 1 - Psych 1 - General Psychology - Lecture 9
# 09:05:44 - Upload successful! Video ID: Dh6EswQ7e8w
# 09:05:44 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\0.1 - Introduction 01 - Definitions And Science.mp4 with title: Biology 301 Lectures - 0.1 - Introduction 01 - Definitions And Science
# 09:07:19 - Upload successful! Video ID: Y741m4Gn9y8
# 09:07:19 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\0.2 - Introduction 02 - Scientific Method.mp4 with title: Biology 301 Lectures - 0.2 - Introduction 02 - Scientific Method
# 09:09:19 - Upload successful! Video ID: gljILj6iP9o
# 09:09:19 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\0.3 - Introduction 03 - Characteristics of Living Things.mp4 with title: Biology 301 Lectures - 0.3 - Introduction 03 - Characteristics of Living Things
# 09:10:48 - Upload successful! Video ID: dyTPXmrWtYg
# 09:10:48 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\0.4 - Introduction 04 - Evolution.mp4 with title: Biology 301 Lectures - 0.4 - Introduction 04 - Evolution
# 09:12:31 - Upload successful! Video ID: 1m3-6a6RXK4
# 09:12:31 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\0.5 - Introduction 05 - Evolution And Religion.mp4 with title: Biology 301 Lectures - 0.5 - Introduction 05 - Evolution And Religion
# 09:14:06 - Upload successful! Video ID: mVkgVMwCmh0
# 09:14:06 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\1.1 - Intro To Chemistry 01.mp4 with title: Biology 301 Lectures - 1.1 - Intro To Chemistry 01
# 09:15:32 - Upload successful! Video ID: _Jf0zDz0A34
# 09:15:32 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\1.2 - Intro To Chemistry 02.mp4 with title: Biology 301 Lectures - 1.2 - Intro To Chemistry 02
# 09:16:56 - Upload successful! Video ID: _o5BvdH8sVQ
# 09:16:56 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\1.3 - Intro To Chemistry 03.mp4 with title: Biology 301 Lectures - 1.3 - Intro To Chemistry 03
# 09:18:18 - Upload successful! Video ID: d-X1-0tf7LE
# 09:18:18 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\1.4 - Intro To Chemistry 04.mp4 with title: Biology 301 Lectures - 1.4 - Intro To Chemistry 04
# 09:20:03 - Upload successful! Video ID: heTwPzPskM0
# 09:20:03 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\2.1 - Biological Chemistristy 01 - Monosaccharides & Disaccharides.mp4 with title: Biology 301 Lectures - 2.1 - Biological Chemistristy 01 - Monosaccharides & Disaccharides
# 09:20:55 - Upload successful! Video ID: CxAj1j0-EEQ
# 09:20:55 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\2.2 - Biological Chemistristy 02 - Polysaccharides & Fatty Acids.mp4 with title: Biology 301 Lectures - 2.2 - Biological Chemistristy 02 - Polysaccharides & Fatty Acids
# 09:22:24 - Upload successful! Video ID: DRLyiHX8K1o
# 09:22:24 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\2.3 - Biological Chemistristy 03 - Phospholipids, Steroids & Intro To Proteins.mp4 with title: Biology 301 Lectures - 2.3 - Biological Chemistristy 03 - Phospholipids, Steroids & Intro To Protein
# 09:24:29 - Upload successful! Video ID: Onk4wab7jnc
# 09:24:29 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\2.4 - Biological Chemistristy 04 - Prteins & Nucleic Acids.mp4 with title: Biology 301 Lectures - 2.4 - Biological Chemistristy 04 - Prteins & Nucleic Acids
# 09:25:44 - Upload successful! Video ID: bIqS09-dzIg
# 09:25:44 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\3.1 - Cytology 01.mp4 with title: Biology 301 Lectures - 3.1 - Cytology 01
# 09:27:30 - Upload successful! Video ID: _62si9DLCUM
# 09:27:30 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\3.2 - Cytology 02.mp4 with title: Biology 301 Lectures - 3.2 - Cytology 02
# 09:29:16 - Upload successful! Video ID: FdAu98RabSE
# 09:29:16 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\3.3 - Cytology 03.mp4 with title: Biology 301 Lectures - 3.3 - Cytology 03
# 09:31:34 - Upload successful! Video ID: OPcRpaNzcMk
# 09:31:34 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\4.1 - Metabolic Reactions 01 - Enzymes & Coenzymes.mp4 with title: Biology 301 Lectures - 4.1 - Metabolic Reactions 01 - Enzymes & Coenzymes
# 09:32:25 - Upload successful! Video ID: bkVvMuZROvI
# 09:32:25 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\4.2 - Metabolic Reactions 02 - Minerals & Vitamins.mp4 with title: Biology 301 Lectures - 4.2 - Metabolic Reactions 02 - Minerals & Vitamins
# 09:32:25 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:32:25 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\4.2 - Metabolic Reactions 02 - Minerals & Vitamins.mp4 to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:32:25 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\4.2 - Metabolic Reactions 02 - Minerals & Vitamins.mp4 in 3 minutes...
# 09:35:25 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:35:25 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\4.2 - Metabolic Reactions 02 - Minerals & Vitamins.mp4 to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:35:25 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\4.2 - Metabolic Reactions 02 - Minerals & Vitamins.mp4 in 3 minutes...
# 09:38:25 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:38:25 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\4.2 - Metabolic Reactions 02 - Minerals & Vitamins.mp4 to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:38:25 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\4.2 - Metabolic Reactions 02 - Minerals & Vitamins.mp4 after 3 attempts.
# 09:38:25 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\4.2 - Metabolic Reactions 02 - Minerals & Vitamins.mp4
# 09:38:25 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\4.3 - Metabolic Reactions 03 - Enzyme Inhibitors.mp4 with title: Biology 301 Lectures - 4.3 - Metabolic Reactions 03 - Enzyme Inhibitors
# 09:38:26 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:38:26 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\4.3 - Metabolic Reactions 03 - Enzyme Inhibitors.mp4 to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:38:26 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\4.3 - Metabolic Reactions 03 - Enzyme Inhibitors.mp4 in 3 minutes...
# 09:41:26 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:41:26 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\4.3 - Metabolic Reactions 03 - Enzyme Inhibitors.mp4 to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:41:26 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\4.3 - Metabolic Reactions 03 - Enzyme Inhibitors.mp4 in 3 minutes...
# 09:44:26 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:44:26 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\4.3 - Metabolic Reactions 03 - Enzyme Inhibitors.mp4 to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:44:26 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\4.3 - Metabolic Reactions 03 - Enzyme Inhibitors.mp4 after 3 attempts.
# 09:44:26 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\4.3 - Metabolic Reactions 03 - Enzyme Inhibitors.mp4
# 09:44:26 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\5.1 - Photosynthesis 01.mp4 with title: Biology 301 Lectures - 5.1 - Photosynthesis 01
# 09:44:26 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:44:26 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\5.1 - Photosynthesis 01.mp4 to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:44:26 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\5.1 - Photosynthesis 01.mp4 in 3 minutes...
# 09:47:26 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:47:26 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\5.1 - Photosynthesis 01.mp4 to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:47:26 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\5.1 - Photosynthesis 01.mp4 in 3 minutes...
# 09:50:27 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:50:27 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\5.1 - Photosynthesis 01.mp4 to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:50:27 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\5.1 - Photosynthesis 01.mp4 after 3 attempts.
# 09:50:27 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\5.1 - Photosynthesis 01.mp4
# 09:50:27 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\5.2 - Photosynthesis 02.mp4 with title: Biology 301 Lectures - 5.2 - Photosynthesis 02
# 09:50:27 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:50:27 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\5.2 - Photosynthesis 02.mp4 to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:50:27 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\5.2 - Photosynthesis 02.mp4 in 3 minutes...
# 09:53:27 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:53:27 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\5.2 - Photosynthesis 02.mp4 to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:53:27 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\5.2 - Photosynthesis 02.mp4 in 3 minutes...
# 09:56:27 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:56:27 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\5.2 - Photosynthesis 02.mp4 to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:56:27 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\5.2 - Photosynthesis 02.mp4 after 3 attempts.
# 09:56:27 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\5.2 - Photosynthesis 02.mp4
# 09:56:27 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\5.3 - Photosynthesis 03 - Chlorophyll, Rhodopsin & Vision.mp4 with title: Biology 301 Lectures - 5.3 - Photosynthesis 03 - Chlorophyll, Rhodopsin & Vision
# 09:56:27 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:56:27 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\5.3 - Photosynthesis 03 - Chlorophyll, Rhodopsin & Vision.mp4 to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:56:27 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\5.3 - Photosynthesis 03 - Chlorophyll, Rhodopsin & Vision.mp4 in 3 minutes...
# 09:59:28 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:59:28 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\5.3 - Photosynthesis 03 - Chlorophyll, Rhodopsin & Vision.mp4 to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:59:28 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\5.3 - Photosynthesis 03 - Chlorophyll, Rhodopsin & Vision.mp4 in 3 minutes...
# 10:03:40 - Upload successful! Video ID: Gks2c01haO0
# 10:03:40 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\5.4 - Photosynthesis 04 - Light & Dark Reactions.mp4 with title: Biology 301 Lectures - 5.4 - Photosynthesis 04 - Light & Dark Reactions
# 10:05:01 - Upload successful! Video ID: OJPAYzG3iBI
# 10:05:01 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\6.1 - Cellular Respiration 01.mp4 with title: Biology 301 Lectures - 6.1 - Cellular Respiration 01
# 10:05:02 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\6.1 - Cellular Respiration 01.mp4 to YouTube (attempt 1): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 10:05:02 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\6.1 - Cellular Respiration 01.mp4 in 3 minutes...
# 10:08:02 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\6.1 - Cellular Respiration 01.mp4 to YouTube (attempt 2): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 10:08:02 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\6.1 - Cellular Respiration 01.mp4 in 3 minutes...
# 10:11:03 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\6.1 - Cellular Respiration 01.mp4 to YouTube (attempt 3): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 10:11:03 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\6.1 - Cellular Respiration 01.mp4 after 3 attempts.
# 10:11:03 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\6.1 - Cellular Respiration 01.mp4
# 10:11:03 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\6.2 - Cellular Respiration 02.mp4 with title: Biology 301 Lectures - 6.2 - Cellular Respiration 02
# 10:11:03 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\6.2 - Cellular Respiration 02.mp4 to YouTube (attempt 1): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 10:11:03 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\6.2 - Cellular Respiration 02.mp4 in 3 minutes...
# 10:14:03 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\6.2 - Cellular Respiration 02.mp4 to YouTube (attempt 2): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 10:14:03 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\6.2 - Cellular Respiration 02.mp4 in 3 minutes...
# 10:17:04 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\6.2 - Cellular Respiration 02.mp4 to YouTube (attempt 3): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 10:17:04 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\6.2 - Cellular Respiration 02.mp4 after 3 attempts.
# 10:17:04 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\6.2 - Cellular Respiration 02.mp4
# 10:17:04 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\6.3 - Cellular Respiration 03.mp4 with title: Biology 301 Lectures - 6.3 - Cellular Respiration 03
# 10:17:04 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\6.3 - Cellular Respiration 03.mp4 to YouTube (attempt 1): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 10:17:04 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\6.3 - Cellular Respiration 03.mp4 in 3 minutes...
# 10:20:05 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\6.3 - Cellular Respiration 03.mp4 to YouTube (attempt 2): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 10:20:05 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\6.3 - Cellular Respiration 03.mp4 in 3 minutes...
# 10:23:05 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\6.3 - Cellular Respiration 03.mp4 to YouTube (attempt 3): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 10:23:05 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\6.3 - Cellular Respiration 03.mp4 after 3 attempts.
# 10:23:05 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\6.3 - Cellular Respiration 03.mp4
# 10:23:05 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\7.1 - Ecosystems 01 - Food Chains & Biomes.mp4 with title: Biology 301 Lectures - 7.1 - Ecosystems 01 - Food Chains & Biomes
# 10:23:06 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\7.1 - Ecosystems 01 - Food Chains & Biomes.mp4 to YouTube (attempt 1): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 10:23:06 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\7.1 - Ecosystems 01 - Food Chains & Biomes.mp4 in 3 minutes...
# 10:26:06 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\7.1 - Ecosystems 01 - Food Chains & Biomes.mp4 to YouTube (attempt 2): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 10:26:06 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\7.1 - Ecosystems 01 - Food Chains & Biomes.mp4 in 3 minutes...
# 10:29:06 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\7.1 - Ecosystems 01 - Food Chains & Biomes.mp4 to YouTube (attempt 3): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 10:29:06 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\7.1 - Ecosystems 01 - Food Chains & Biomes.mp4 after 3 attempts.
# 10:29:06 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\7.1 - Ecosystems 01 - Food Chains & Biomes.mp4
# 10:29:06 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\7.2 - Ecosystems 02 - Carbon Cycle & Global Warming.mp4 with title: Biology 301 Lectures - 7.2 - Ecosystems 02 - Carbon Cycle & Global Warming
# 10:29:07 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\7.2 - Ecosystems 02 - Carbon Cycle & Global Warming.mp4 to YouTube (attempt 1): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 10:29:07 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\7.2 - Ecosystems 02 - Carbon Cycle & Global Warming.mp4 in 3 minutes...
# 10:32:07 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\7.2 - Ecosystems 02 - Carbon Cycle & Global Warming.mp4 to YouTube (attempt 2): <HttpError 400 when requesting None returned "The user has exceeded the number of videos they may upload.". Details: "[{'message': 'The user has exceeded the number of videos they may upload.', 'domain': 'youtube.video', 'reason': 'uploadLimitExceeded'}]">
# 10:32:07 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\7.2 - Ecosystems 02 - Carbon Cycle & Global Warming.mp4 in 3 minutes...
# 10:36:27 - Upload successful! Video ID: WTSwnTmPr_4
# 10:36:27 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\8.1- Reproductive System 01.mp4 with title: Biology 301 Lectures - 8.1- Reproductive System 01
# 10:38:07 - Upload successful! Video ID: -O_KOVIOO1s
# 10:38:07 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\8.2- Reproductive System 02.mp4 with title: Biology 301 Lectures - 8.2- Reproductive System 02
# 10:40:09 - Upload successful! Video ID: JsI9UZA8Un0
# 10:40:09 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\9.1 - Chromosome Anomalies & Genetic Diseases.mp4 with title: Biology 301 Lectures - 9.1 - Chromosome Anomalies & Genetic Diseases
# 10:41:14 - Upload successful! Video ID: L4EwObjuO74
# 10:41:14 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\9.2 - Introduction To Genetics.mp4 with title: Biology 301 Lectures - 9.2 - Introduction To Genetics
# 10:42:25 - Upload successful! Video ID: DqWeU4SPbH8
# 10:42:25 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\9.3 - Cancer; Viruses & The Immune System.mp4 with title: Biology 301 Lectures - 9.3 - Cancer; Viruses & The Immune System
# 10:43:10 - Upload successful! Video ID: wWyvihu7idk
# 10:43:10 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolution Docs Arabic\من القرد وحتي الإنسان.flv with title: Evolution Docs Arabic - من القرد وحتي الإنسان
# 10:46:12 - Upload successful! Video ID: NqIIlfdZw7g
# 10:46:12 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Donald Prothero\Evolution- How We Know it Happened & Why it Matters (with Dr. Donald Prothero) - YouTube.mp4 with title: Donald Prothero - Evolution- How We Know it Happened & Why it Matters (with Dr. Donald Prothero) - Y
# 10:49:06 - Upload successful! Video ID: OSPeaX_gGng
# 10:49:06 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Jerry A. Coyne\Why Evolution Is True' by Jerry Coyne, AAI 2009.mp4 with title: Jerry A. Coyne - Why Evolution Is True' by Jerry Coyne, AAI 2009
# 10:50:26 - Upload successful! Video ID: 9CoOEGC072E
# 10:50:26 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Nicholas Wade\Faith Instinct Lecture by Nicholas Wade.flv with title: Nicholas Wade - Faith Instinct Lecture by Nicholas Wade
# 10:51:48 - Upload successful! Video ID: AvzFsbAL6ys
# 10:51:48 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\1987 - The Blind Watchmaker\The Blind Watchmaker, by Richard Dawkins.mp4 with title: 1987 - The Blind Watchmaker - The Blind Watchmaker, by Richard Dawkins
# 10:53:29 - Upload successful! Video ID: sBnrtAMqHkg
# 10:53:29 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\1991 - Growing Up In The Universe\1 - Waking Up in the Universe.avi with title: 1991 - Growing Up In The Universe - 1 - Waking Up in the Universe
# 10:57:40 - Upload successful! Video ID: sT-nizpBELo
# 10:57:40 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\1991 - Growing Up In The Universe\2 - Designed and Designoid Objects.avi with title: 1991 - Growing Up In The Universe - 2 - Designed and Designoid Objects
# 11:01:55 - Upload successful! Video ID: 0HlZTeXa6SQ
# 11:01:55 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\1991 - Growing Up In The Universe\3 - Climbing Mount Improbable.avi with title: 1991 - Growing Up In The Universe - 3 - Climbing Mount Improbable
# 11:06:08 - Upload successful! Video ID: sjXa6gS7ivM
# 11:06:08 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\1991 - Growing Up In The Universe\4 - The Ultraviolet Garden.avi with title: 1991 - Growing Up In The Universe - 4 - The Ultraviolet Garden
# 11:10:23 - Upload successful! Video ID: RT_65JzBwng
# 11:10:23 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\1991 - Growing Up In The Universe\5 - The Genesis of Purpose.avi with title: 1991 - Growing Up In The Universe - 5 - The Genesis of Purpose
# 11:14:40 - Upload successful! Video ID: ueqBwZ1JXSQ
# 11:14:40 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\1991 - Growing Up In The Universe\Intro.avi with title: 1991 - Growing Up In The Universe - Intro
# 11:14:52 - Upload successful! Video ID: cfV05h5JkZc
# 11:14:52 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2006 - The Root of All Evil\01 - The God Delusion.avi with title: 2006 - The Root of All Evil - 01 - The God Delusion
# 11:17:55 - Upload successful! Video ID: xxIwMvh0FgE
# 11:17:55 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2006 - The Root of All Evil\02 - The Virus of Faith.avi with title: 2006 - The Root of All Evil - 02 - The Virus of Faith
# 11:20:03 - Upload successful! Video ID: gEp_e036Sto
# 11:20:03 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2007 - Enemies of Reason\Enemies of Reason (Part 1).avi with title: 2007 - Enemies of Reason - Enemies of Reason (Part 1)
# 11:24:19 - Upload successful! Video ID: rrS2j1w3bOw
# 11:24:19 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2007 - Enemies of Reason\Enemies of Reason (Part 2).avi with title: 2007 - Enemies of Reason - Enemies of Reason (Part 2)
# 11:28:30 - Upload successful! Video ID: RnRhdQpZOv8
# 11:28:30 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin\The.Genius.of.Charles.Darwin.1of3.Life.Darwin.and.Everything.XviD.AC3.MVGroup.org.avi with title: 2008 - The Genius of Charles Darwin - The.Genius.of.Charles.Darwin.1of3.Life.Darwin.and.Everything.X
# 11:33:05 - Failed to delete uploaded video file: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin\The.Genius.of.Charles.Darwin.1of3.Life.Darwin.and.Everything.XviD.AC3.MVGroup.org.avi: [WinError 5] Access is denied: '//fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\\Biology And Psychology\\Evolutionary Biologists\\Richard Dawkins\\2008 - The Genius of Charles Darwin\\The.Genius.of.Charles.Darwin.1of3.Life.Darwin.and.Everything.XviD.AC3.MVGroup.org.avi'
# 11:33:05 - Upload successful! Video ID: ekIqfZqxoqw
# 11:33:05 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin\The.Genius.of.Charles.Darwin.2of3.The.Fifth.Ape.XviD.AC3.MVGroup.org.avi with title: 2008 - The Genius of Charles Darwin - The.Genius.of.Charles.Darwin.2of3.The.Fifth.Ape.XviD.AC3.MVGro
# 11:37:37 - Failed to delete uploaded video file: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin\The.Genius.of.Charles.Darwin.2of3.The.Fifth.Ape.XviD.AC3.MVGroup.org.avi: [WinError 5] Access is denied: '//fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\\Biology And Psychology\\Evolutionary Biologists\\Richard Dawkins\\2008 - The Genius of Charles Darwin\\The.Genius.of.Charles.Darwin.2of3.The.Fifth.Ape.XviD.AC3.MVGroup.org.avi'
# 11:37:37 - Upload successful! Video ID: 5vHkgb7jP-A
# 11:37:37 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin\The.Genius.of.Charles.Darwin.3of3.God.Strikes.Back.XviD.AC3.MVGroup.org.avi with title: 2008 - The Genius of Charles Darwin - The.Genius.of.Charles.Darwin.3of3.God.Strikes.Back.XviD.AC3.MV
# 11:42:11 - Failed to delete uploaded video file: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin\The.Genius.of.Charles.Darwin.3of3.God.Strikes.Back.XviD.AC3.MVGroup.org.avi: [WinError 5] Access is denied: '//fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\\Biology And Psychology\\Evolutionary Biologists\\Richard Dawkins\\2008 - The Genius of Charles Darwin\\The.Genius.of.Charles.Darwin.3of3.God.Strikes.Back.XviD.AC3.MVGroup.org.avi'
# 11:42:11 - Upload successful! Video ID: VStPaAdmCfc
# 11:42:11 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin - The Uncut Interviews\The.Genius.of.Charles.Darwin.EXTRAS.XviD.AC3.MVGroup.org.avi with title: 2008 - The Genius of Charles Darwin - The Uncut Interviews - The.Genius.of.Charles.Darwin.EXTRAS.Xvi
# 11:44:28 - Upload successful! Video ID: GusYArn9EIw
# 11:44:28 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin - The Uncut Interviews\The.Genius.of.Charles.Darwin.The.Uncut.Interviews.Archbishop.Rowan.Williams.avi with title: 2008 - The Genius of Charles Darwin - The Uncut Interviews - The.Genius.of.Charles.Darwin.The.Uncut.
# 11:47:11 - Upload successful! Video ID: eEI20jGlbNM
# 11:47:11 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin - The Uncut Interviews\The.Genius.of.Charles.Darwin.The.Uncut.Interviews.Bishop.Bonifes.Adoyo.avi with title: 2008 - The Genius of Charles Darwin - The Uncut Interviews - The.Genius.of.Charles.Darwin.The.Uncut.
# 11:50:01 - Upload successful! Video ID: 4oEyYmh68FE
# 11:50:01 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin - The Uncut Interviews\The.Genius.of.Charles.Darwin.The.Uncut.Interviews.Claus.Rodgaard.avi with title: 2008 - The Genius of Charles Darwin - The Uncut Interviews - The.Genius.of.Charles.Darwin.The.Uncut.
# 11:54:04 - Upload successful! Video ID: Pcsy4g2zaRU
# 11:54:04 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin - The Uncut Interviews\The.Genius.of.Charles.Darwin.The.Uncut.Interviews.Craig.Venter.avi with title: 2008 - The Genius of Charles Darwin - The Uncut Interviews - The.Genius.of.Charles.Darwin.The.Uncut.
# 11:58:11 - Upload successful! Video ID: rDq802hG-kQ
# 11:58:11 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin - The Uncut Interviews\The.Genius.of.Charles.Darwin.The.Uncut.Interviews.Daniel.Dennett.avi with title: 2008 - The Genius of Charles Darwin - The Uncut Interviews - The.Genius.of.Charles.Darwin.The.Uncut.
# 12:03:01 - Upload successful! Video ID: tXvFgDQdEkE
# 12:03:01 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin - The Uncut Interviews\The.Genius.of.Charles.Darwin.The.Uncut.Interviews.Eric.Beinhocker.avi with title: 2008 - The Genius of Charles Darwin - The Uncut Interviews - The.Genius.of.Charles.Darwin.The.Uncut.
# 12:05:30 - Upload successful! Video ID: w98qKgYu09g
# 12:05:30 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin - The Uncut Interviews\The.Genius.of.Charles.Darwin.The.Uncut.Interviews.Frans.De.Waal.avi with title: 2008 - The Genius of Charles Darwin - The Uncut Interviews - The.Genius.of.Charles.Darwin.The.Uncut.
# 12:14:23 - Upload successful! Video ID: 4tRUIDO-9oA
# 12:14:23 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin - The Uncut Interviews\The.Genius.of.Charles.Darwin.The.Uncut.Interviews.Irish.French.avi with title: 2008 - The Genius of Charles Darwin - The Uncut Interviews - The.Genius.of.Charles.Darwin.The.Uncut.
# 12:15:10 - Upload successful! Video ID: SXiBvpGttPE
# 12:15:10 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin - The Uncut Interviews\The.Genius.of.Charles.Darwin.The.Uncut.Interviews.John.Mackay.avi with title: 2008 - The Genius of Charles Darwin - The Uncut Interviews - The.Genius.of.Charles.Darwin.The.Uncut.
# 12:17:00 - Upload successful! Video ID: 41CMAwXgBIA
# 12:17:00 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin - The Uncut Interviews\The.Genius.of.Charles.Darwin.The.Uncut.Interviews.Jonathan.Kingdon.avi with title: 2008 - The Genius of Charles Darwin - The Uncut Interviews - The.Genius.of.Charles.Darwin.The.Uncut.
# 12:20:19 - Upload successful! Video ID: 4VSV6XuAAbE
# 12:20:19 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin - The Uncut Interviews\The.Genius.of.Charles.Darwin.The.Uncut.Interviews.Larry.Gelmon.avi with title: 2008 - The Genius of Charles Darwin - The Uncut Interviews - The.Genius.of.Charles.Darwin.The.Uncut.
# 12:22:53 - Upload successful! Video ID: gY8eOLa00tg
# 12:22:53 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin - The Uncut Interviews\The.Genius.of.Charles.Darwin.The.Uncut.Interviews.Nick.Cowan.avi with title: 2008 - The Genius of Charles Darwin - The Uncut Interviews - The.Genius.of.Charles.Darwin.The.Uncut.
# 12:24:43 - Upload successful! Video ID: D53BUylG0-g
# 12:24:43 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin - The Uncut Interviews\The.Genius.of.Charles.Darwin.The.Uncut.Interviews.Peter.Singer.avi with title: 2008 - The Genius of Charles Darwin - The Uncut Interviews - The.Genius.of.Charles.Darwin.The.Uncut.
# 12:28:58 - Upload successful! Video ID: 9NmyFS-Tbj4
# 12:28:58 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin - The Uncut Interviews\The.Genius.of.Charles.Darwin.The.Uncut.Interviews.Randall.Keynes.avi with title: 2008 - The Genius of Charles Darwin - The Uncut Interviews - The.Genius.of.Charles.Darwin.The.Uncut.
# 12:34:21 - Upload successful! Video ID: VFHxF_TDSQk
# 12:34:21 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin - The Uncut Interviews\The.Genius.of.Charles.Darwin.The.Uncut.Interviews.Randolph.Nesse.avi with title: 2008 - The Genius of Charles Darwin - The Uncut Interviews - The.Genius.of.Charles.Darwin.The.Uncut.
# 12:38:51 - Upload successful! Video ID: g5VRqGKH3GQ
# 12:38:51 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin - The Uncut Interviews\The.Genius.of.Charles.Darwin.The.Uncut.Interviews.Richard.Hulbert.Jr.avi with title: 2008 - The Genius of Charles Darwin - The Uncut Interviews - The.Genius.of.Charles.Darwin.The.Uncut.
# 12:40:27 - Upload successful! Video ID: tY0TPGUIzgY
# 12:40:27 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin - The Uncut Interviews\The.Genius.of.Charles.Darwin.The.Uncut.Interviews.Richard.Leakey.avi with title: 2008 - The Genius of Charles Darwin - The Uncut Interviews - The.Genius.of.Charles.Darwin.The.Uncut.
# 12:43:51 - Upload successful! Video ID: qxcxQZm6okY
# 12:43:51 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin - The Uncut Interviews\The.Genius.of.Charles.Darwin.The.Uncut.Interviews.Science.Class.avi with title: 2008 - The Genius of Charles Darwin - The Uncut Interviews - The.Genius.of.Charles.Darwin.The.Uncut.
# 12:47:43 - Upload successful! Video ID: bmCU1GEbPqQ
# 12:47:43 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin - The Uncut Interviews\The.Genius.of.Charles.Darwin.The.Uncut.Interviews.Science.Teachers.avi with title: 2008 - The Genius of Charles Darwin - The Uncut Interviews - The.Genius.of.Charles.Darwin.The.Uncut.
# 12:50:31 - Upload successful! Video ID: Jfoxcy_EIa8
# 12:50:31 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin - The Uncut Interviews\The.Genius.of.Charles.Darwin.The.Uncut.Interviews.Sean.Casey.avi with title: 2008 - The Genius of Charles Darwin - The Uncut Interviews - The.Genius.of.Charles.Darwin.The.Uncut.
