# %%
import os
import sys
import glob
import logging
from datetime import datetime
from pathlib import Path
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import tkinter as tk
from tkinter import filedialog
from google_auth_oauthlib.flow import InstalledAppFlow
from google.oauth2.credentials import Credentials
from google.auth.transport.requests import Request
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload
import time

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(message)s',
    datefmt='%H:%M:%S',
    handlers=[
        logging.FileHandler('upload_all.log', encoding='utf-8'),
        logging.StreamHandler()
    ]
)

TOKEN_FILE = "token.json"
SCOPES = ["https://www.googleapis.com/auth/youtube.upload"]

os.environ['OAUTHLIB_INSECURE_TRANSPORT'] = '1'
os.environ['PYTHONHTTPSVERIFY'] = '0'

def get_authenticated_service(client_secrets_file: str):
    creds = None
    if os.path.exists(TOKEN_FILE):
        creds = Credentials.from_authorized_user_file(TOKEN_FILE, SCOPES)
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(client_secrets_file, SCOPES)
            creds = flow.run_local_server(port=0)
        with open(TOKEN_FILE, 'w') as token:
            token.write(creds.to_json())
    return build('youtube', 'v3', credentials=creds)

def upload_to_youtube(youtube, video_path: str, title: str, description: str = "Uploaded by script"):
    MAX_RETRIES = 3
    RETRY_DELAY_SECONDS = 180  # 3 minutes
    for attempt in range(1, MAX_RETRIES + 1):
        try:
            body = {
                'snippet': {
                    'title': title,
                    'description': description,
                    'tags': ['tutorial', 'education']
                },
                'status': {
                    'privacyStatus': 'unlisted',
                    'selfDeclaredMadeForKids': False
                }
            }
            insert_request = youtube.videos().insert(
                part=','.join(body.keys()),
                body=body,
                media_body=MediaFileUpload(video_path, chunksize=-1, resumable=True)
            )
            response = None
            while response is None:
                status, response = insert_request.next_chunk()
                if status:
                    logging.info(f"Upload {int(status.progress() * 100)}% complete for {video_path}")
            return response['id']
        except Exception as e:
            logging.error(f"Error uploading {video_path} to YouTube (attempt {attempt}): {str(e)}")
            if attempt < MAX_RETRIES:
                logging.info(f"Retrying upload for {video_path} in {RETRY_DELAY_SECONDS // 60} minutes...")
                time.sleep(RETRY_DELAY_SECONDS)
            else:
                logging.error(f"Upload failed for {video_path} after {MAX_RETRIES} attempts.")
                return None

def select_folder_dialog(title="Select folder"):
    """Open a folder selection dialog and return the selected path."""
    try:
        root = tk.Tk()
        root.withdraw()
        root.update_idletasks()
        width = root.winfo_screenwidth()
        height = root.winfo_screenheight()
        x = (width - 400) // 2
        y = (height - 300) // 2
        root.geometry(f'400x300+{x}+{y}')
        folder_path = filedialog.askdirectory(
            title=title,
            mustexist=True
        )
        root.destroy()
        return folder_path
    except Exception as e:
        logging.error(f"Error in folder selection: {str(e)}")
        return None

def main():
    # Select parent folder
    parent_folder = select_folder_dialog(title="Select parent folder containing videos to upload recursively")
    if not parent_folder or not os.path.exists(parent_folder):
        logging.error("No folder selected or folder does not exist")
        return
    cwd = os.getcwd()
    client_secrets_file = os.path.join(cwd, "client_secret.dlc.json")
    if not os.path.exists(client_secrets_file):
        logging.error(f"Client secrets file not found at: {client_secrets_file}")
        return
    youtube = get_authenticated_service(client_secrets_file)
    logging.info("YouTube authentication complete.")
    VIDEO_EXTENSIONS = ('.mp4', '.mkv', '.avi', '.mov', '.wmv', '.flv', '.webm')
    for root, _, files in os.walk(parent_folder):
        for file in files:
            if file.lower().endswith(VIDEO_EXTENSIONS) and not file.endswith('.txt'):
                video_path = os.path.join(root, file)
                video_name = os.path.splitext(file)[0]
                link_file = os.path.join(root, f"{video_name}.txt")
                if not os.path.exists(link_file):
                    folder_name = os.path.basename(root)
                    MAX_TITLE_LENGTH = 100
                    title = f"{folder_name} - {video_name}"
                    if len(title) > MAX_TITLE_LENGTH:
                        title = title[:MAX_TITLE_LENGTH]
                    logging.info(f"Uploading: {video_path} with title: {title}")
                    video_id = upload_to_youtube(youtube, video_path, title)
                    if video_id:
                        with open(link_file, 'w') as f:
                            f.write(f"https://www.youtube.com/watch?v={video_id}\n")
                        try:
                            os.remove(video_path)
                        except Exception as e:
                            logging.error(f"Failed to delete uploaded video file: {video_path}: {str(e)}")
                        logging.info(f"Upload successful! Video ID: {video_id}")
                    else:
                        logging.error(f"Upload failed for {video_path}")
                else:
                    logging.info(f"Link file already exists for {video_path}. Skipping upload.")
    logging.info("All specified folders and subfolders processed.")

if __name__ == "__main__":
    main()
# Out:
# 12:29:31 - file_cache is only supported with oauth2client<4.0.0
# 12:29:32 - YouTube authentication complete.
# 12:29:42 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\43. Stars—Distant Suns.avi with title: TTC - Understanding The Universe - 43. Stars—Distant Suns
# 12:30:28 - Upload successful! Video ID: 3UO8RkKt0oc
# 12:30:28 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\44. The Intrinsic Brightnesses of Stars.avi with title: TTC - Understanding The Universe - 44. The Intrinsic Brightnesses of Stars
# 12:31:12 - Upload successful! Video ID: 9rKRTQmMWpg
# 12:31:12 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\45. The Diverse Sizes of Stars.avi with title: TTC - Understanding The Universe - 45. The Diverse Sizes of Stars
# 12:31:57 - Upload successful! Video ID: bOVesBBS-8U
# 12:31:57 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\46. Binary Stars and Stellar Masses.avi with title: TTC - Understanding The Universe - 46. Binary Stars and Stellar Masses
# 12:32:42 - Upload successful! Video ID: ZGnDA90TndE
# 12:32:42 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\47. Star Clusters, Ages, and Remote Distances.avi with title: TTC - Understanding The Universe - 47. Star Clusters, Ages, and Remote Distances
# 12:33:26 - Upload successful! Video ID: Q2jGpZX2tsg
# 12:33:26 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\74. The Evolution of Galaxies.avi with title: TTC - Understanding The Universe - 74. The Evolution of Galaxies
# 12:34:11 - Upload successful! Video ID: gBIqi0ARZ0k
# 12:34:11 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\75. Active Galaxies and Quasars.avi with title: TTC - Understanding The Universe - 75. Active Galaxies and Quasars
# 12:34:56 - Upload successful! Video ID: PKdycIGOSmY
# 12:34:56 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\76. Cosmic Powerhouses of the Distant Past.avi with title: TTC - Understanding The Universe - 76. Cosmic Powerhouses of the Distant Past
# 12:35:41 - Upload successful! Video ID: LXQ1Gu-MlMY
# 12:35:41 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\77. Supermassive Black Holes.avi with title: TTC - Understanding The Universe - 77. Supermassive Black Holes
# 12:36:26 - Upload successful! Video ID: dqEy_dQy2lo
# 12:36:26 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\78. Feeding the Monster.avi with title: TTC - Understanding The Universe - 78. Feeding the Monster
# 12:37:11 - Upload successful! Video ID: JF73m-Tb5jg
# 12:37:11 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\79. The Paradox of the Dark Night Sky.avi with title: TTC - Understanding The Universe - 79. The Paradox of the Dark Night Sky
# 12:37:56 - Upload successful! Video ID: j9Vv9yH0ECE
# 12:37:56 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\80. The Age of the Universe.avi with title: TTC - Understanding The Universe - 80. The Age of the Universe
# 12:38:41 - Upload successful! Video ID: 4VvY-V3lMzQ
# 12:38:41 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\81. When Geometry Is Destiny.avi with title: TTC - Understanding The Universe - 81. When Geometry Is Destiny
# 12:39:26 - Upload successful! Video ID: G9XFCna4fm8
# 12:39:26 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\82. The Mass Density of the Universe.avi with title: TTC - Understanding The Universe - 82. The Mass Density of the Universe
# 12:40:11 - Upload successful! Video ID: NgVXRL0Kgf4
# 12:40:11 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\83. Einstein's Biggest Blunder.avi with title: TTC - Understanding The Universe - 83. Einstein's Biggest Blunder
# 12:40:56 - Upload successful! Video ID: 0vXc4VG-Qdc
# 12:40:56 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\84. The Afterglow of the Big Bang.avi with title: TTC - Understanding The Universe - 84. The Afterglow of the Big Bang
# 12:41:40 - Upload successful! Video ID: 7StwD2uQ1Cc
# 12:41:40 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\85. Ripples in the Cosmic Background Radiation.avi with title: TTC - Understanding The Universe - 85. Ripples in the Cosmic Background Radiation
# 12:42:25 - Upload successful! Video ID: 73F3Kf8yPgk
# 12:42:25 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\86. The Stuff of the Cosmos.avi with title: TTC - Understanding The Universe - 86. The Stuff of the Cosmos
# 12:43:09 - Upload successful! Video ID: xAEFYhAOWMA
# 12:43:09 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\87. Dark Energy—Quantum Fluctuations.avi with title: TTC - Understanding The Universe - 87. Dark Energy—Quantum Fluctuations
# 12:43:54 - Upload successful! Video ID: qfPrrnAQq-E
# 12:43:54 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\88. Dark Energy—Quintessence.avi with title: TTC - Understanding The Universe - 88. Dark Energy—Quintessence
# 12:44:39 - Upload successful! Video ID: Jlw9WjHeVKE
# 12:44:39 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\89. Grand Unification & Theories of Everything.avi with title: TTC - Understanding The Universe - 89. Grand Unification & Theories of Everything
# 12:45:24 - Upload successful! Video ID: Y8uBrgo5NF0
# 12:45:24 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\90. Searching for Hidden Dimensions.avi with title: TTC - Understanding The Universe - 90. Searching for Hidden Dimensions
# 12:46:09 - Upload successful! Video ID: w-WtDlpsgMI
# 12:46:09 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\91. The Shape, Size, and Fate of the Universe.avi with title: TTC - Understanding The Universe - 91. The Shape, Size, and Fate of the Universe
# 12:46:54 - Upload successful! Video ID: kTvLUw1DnOY
# 12:46:54 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\92. In the Beginning.avi with title: TTC - Understanding The Universe - 92. In the Beginning
# 12:47:39 - Upload successful! Video ID: nLUhwrvQtaw
# 12:47:39 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\93. The Inflationary Universe.avi with title: TTC - Understanding The Universe - 93. The Inflationary Universe
# 12:48:24 - Upload successful! Video ID: CzA9u5PPk2o
# 12:48:24 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\94. The Ultimate Free Lunch.avi with title: TTC - Understanding The Universe - 94. The Ultimate Free Lunch
# 12:49:09 - Upload successful! Video ID: D_RpUkMHwR8
# 12:49:09 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\95. A Universe of Universes.avi with title: TTC - Understanding The Universe - 95. A Universe of Universes
# 12:49:54 - Upload successful! Video ID: 85sY5kXboN8
# 12:49:54 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\96. Reflections on Life and the Cosmos.avi with title: TTC - Understanding The Universe - 96. Reflections on Life and the Cosmos
# 12:50:38 - Upload successful! Video ID: S1uiZgSCneE
# 12:50:38 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\Lecture 49.avi with title: TTC - Understanding The Universe - Lecture 49
# 12:51:23 - Upload successful! Video ID: MeCvlGtw40s
# 12:51:23 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\Lecture 50.avi with title: TTC - Understanding The Universe - Lecture 50
# 12:52:08 - Upload successful! Video ID: ikK5DBbUNAE
# 12:52:08 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\Lecture 51.avi with title: TTC - Understanding The Universe - Lecture 51
# 12:52:53 - Upload successful! Video ID: 3td8s-Q6UiQ
# 12:52:53 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\Lecture 52.avi with title: TTC - Understanding The Universe - Lecture 52
# 12:53:38 - Upload successful! Video ID: aP3VoM4JD90
# 12:53:38 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\Lecture 53.avi with title: TTC - Understanding The Universe - Lecture 53
# 12:54:23 - Upload successful! Video ID: YLHEhw6ZxMg
# 12:54:24 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\Lecture 54.avi with title: TTC - Understanding The Universe - Lecture 54
# 12:55:08 - Upload successful! Video ID: 6ohHTi4HIJ4
# 12:55:08 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\Lecture 55.avi with title: TTC - Understanding The Universe - Lecture 55
# 12:55:54 - Upload successful! Video ID: IiWETxDzBAA
# 12:55:54 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\Lecture 56.avi with title: TTC - Understanding The Universe - Lecture 56
# 12:56:39 - Upload successful! Video ID: EMVp2xMznQ0
# 12:56:39 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\Lecture 57.avi with title: TTC - Understanding The Universe - Lecture 57
# 12:57:24 - Upload successful! Video ID: _rjx0kWncxw
# 12:57:24 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\Lecture 58.avi with title: TTC - Understanding The Universe - Lecture 58
# 12:58:09 - Upload successful! Video ID: euul6k2RjA8
# 12:58:09 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\Lecture 59.avi with title: TTC - Understanding The Universe - Lecture 59
# 12:58:54 - Upload successful! Video ID: dzponB7OuU4
# 12:58:54 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\Lecture 60.avi with title: TTC - Understanding The Universe - Lecture 60
# 12:59:40 - Upload successful! Video ID: ZyfouvRShwE
# 12:59:40 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\Lecture 61.avi with title: TTC - Understanding The Universe - Lecture 61
# 13:00:26 - Upload successful! Video ID: akt9eUl1i2U
# 13:00:26 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\Lecture 62.avi with title: TTC - Understanding The Universe - Lecture 62
# 13:01:11 - Upload successful! Video ID: 89gjxCvbehc
# 13:01:11 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\Lecture 63.avi with title: TTC - Understanding The Universe - Lecture 63
# 13:01:56 - Upload successful! Video ID: ZjRKNey7s6E
# 13:01:56 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\Lecture 64.avi with title: TTC - Understanding The Universe - Lecture 64
# 13:02:42 - Upload successful! Video ID: gZmDPc-PpJM
# 13:02:42 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\Lecture 65.avi with title: TTC - Understanding The Universe - Lecture 65
# 13:03:28 - Upload successful! Video ID: ciNImakOlu8
# 13:03:28 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\Lecture 66.avi with title: TTC - Understanding The Universe - Lecture 66
# 13:04:13 - Upload successful! Video ID: vpV_B028wm0
# 13:04:13 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\Lecture 67.avi with title: TTC - Understanding The Universe - Lecture 67
# 13:04:58 - Upload successful! Video ID: TuvftoTsGAw
# 13:04:58 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\LECTURE 68.avi with title: TTC - Understanding The Universe - LECTURE 68
# 13:05:43 - Upload successful! Video ID: Nmy_EWQDrws
# 13:05:43 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\lECTURE 69.avi with title: TTC - Understanding The Universe - lECTURE 69
# 13:06:29 - Upload successful! Video ID: laq4rCc1BBM
# 13:06:29 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\Lecture 70.avi with title: TTC - Understanding The Universe - Lecture 70
# 13:07:14 - Upload successful! Video ID: eWuRT5Ryrec
# 13:07:14 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\Lecture 71.avi with title: TTC - Understanding The Universe - Lecture 71
# 13:08:00 - Upload successful! Video ID: DAINcWmOZt4
# 13:08:00 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Physics And Cosmology\TTC\TTC - Understanding The Universe\Lecture 72.avi with title: TTC - Understanding The Universe - Lecture 72
# 13:08:45 - Upload successful! Video ID: tKy1KzDxq24
# 13:08:46 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\'Flames of War' Feature Film to Intimidate West.MP4 with title: ISIS - 'Flames of War' Feature Film to Intimidate West
# 13:13:34 - Upload successful! Video ID: HkZFJNJh7j8
# 13:13:34 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\04 - ISIS 4th Propaganda Film - Not Suitable for Under 18s.mp4 with title: ISIS - 04 - ISIS 4th Propaganda Film - Not Suitable for Under 18s
# 13:15:27 - Upload successful! Video ID: 7sfo-ccnYjY
# 13:15:27 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\al-e1b8a5ayc481t-media-center-22lets-go-for-jihc481d22_dvd.mp4 with title: ISIS - al-e1b8a5ayc481t-media-center-22lets-go-for-jihc481d22_dvd
# 13:15:49 - Upload successful! Video ID: bT5JNBwB7KU
# 13:15:49 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\Incredible- Man Survives an ISIS Massacre - The New York Times.mp4 with title: ISIS - Incredible- Man Survives an ISIS Massacre - The New York Times
# 13:16:30 - Upload successful! Video ID: zEn069_CrQI
# 13:16:30 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\ISIS - -Islamic- Extremism- - Full Documentary - HD - YouTube.mp4 with title: ISIS - ISIS - -Islamic- Extremism- - Full Documentary - HD - YouTube
# 13:17:42 - Upload successful! Video ID: I443bIL8Nzo
# 13:17:42 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\LiveLeak.com - --VERY GRAPHIC-- - Footage showing the beheading of a civilian in Idlib.mp4 with title: ISIS - LiveLeak.com - --VERY GRAPHIC-- - Footage showing the beheading of a civilian in Idlib
# 13:17:54 - Upload successful! Video ID: p7E79z91DB8
# 13:17:54 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\LiveLeak.com - 50 Soldiers Beheaded And Their Heads Put On Poles.mp4 with title: ISIS - LiveLeak.com - 50 Soldiers Beheaded And Their Heads Put On Poles
# 13:17:59 - Upload successful! Video ID: X7CJ_DWHkyc
# 13:17:59 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\LiveLeak.com - British rapper identified as ISIL militant who beheaded James Foley.mp4 with title: ISIS - LiveLeak.com - British rapper identified as ISIL militant who beheaded James Foley
# 13:18:02 - Upload successful! Video ID: -7sUDiP1hZ4
# 13:18:02 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\LiveLeak.com - GRAPHIC(21+)- Syria- A leaked video shows Isis terrorists carrying on a mass execution including children.mp4 with title: ISIS - LiveLeak.com - GRAPHIC(21+)- Syria- A leaked video shows Isis terrorists carrying on a mass e
# 13:18:10 - Upload successful! Video ID: _OJknwLERbk
# 13:18:10 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\LiveLeak.com - Iraqi Soldier_Militiaman Takes A Clear HeadShot During Firefight Against ISIS.mp4 with title: ISIS - LiveLeak.com - Iraqi Soldier_Militiaman Takes A Clear HeadShot During Firefight Against ISIS
# 13:18:14 - Upload successful! Video ID: pJ8UREKks1g
# 13:18:14 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\LiveLeak.com - ISIS beheading American James Wright Foley.mp4 with title: ISIS - LiveLeak.com - ISIS beheading American James Wright Foley
# 13:18:24 - Upload successful! Video ID: oMYzr6f6hcM
# 13:18:24 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\LiveLeak.com - ISIS Extremists Release Video Purportedly Showing Beheading.mp4 with title: ISIS - LiveLeak.com - ISIS Extremists Release Video Purportedly Showing Beheading
# 13:18:28 - Upload successful! Video ID: hcax9JlN0_8
# 13:18:28 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\LiveLeak.com - NEW ISIS VIDEO SHOWING BATTLE & EXECUTION FOOTAGE.flv with title: ISIS - LiveLeak.com - NEW ISIS VIDEO SHOWING BATTLE & EXECUTION FOOTAGE
# 13:20:39 - Upload successful! Video ID: 5A9nmhrCqD8
# 13:20:39 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\LiveLeak.com - Syria- ISIS Technical Pick-Up and Its Crews Vaporized by Al-Nusra Shell (Insurgent Infighting).mp4 with title: ISIS - LiveLeak.com - Syria- ISIS Technical Pick-Up and Its Crews Vaporized by Al-Nusra Shell (Insur
# 13:20:41 - Upload successful! Video ID: Maw_kD_0hLg
# 13:20:41 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\LiveLeak.com - The moment when a Kurdish sniper eliminated two Islamist terrorists.mp4 with title: ISIS - LiveLeak.com - The moment when a Kurdish sniper eliminated two Islamist terrorists
# 13:20:44 - Upload successful! Video ID: VDOVl9q3R50
# 13:20:44 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\LiveLeak.com - VERY GRAPHIC - Al-Qaida cuts off heads of 2 men.mp4 with title: ISIS - LiveLeak.com - VERY GRAPHIC - Al-Qaida cuts off heads of 2 men
# 13:20:49 - Upload successful! Video ID: N1LgDx2P2Wk
# 13:20:49 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\Losing Iraq - The Rise of ISIS.mp4 with title: ISIS - Losing Iraq - The Rise of ISIS
# 13:21:42 - Upload successful! Video ID: 75wEld4Ov_w
# 13:21:42 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\Sex-Slave Raping & Selling Girls In Syria And ISIS.mp4 with title: ISIS - Sex-Slave Raping & Selling Girls In Syria And ISIS
# 13:23:50 - Upload successful! Video ID: B4jy-_ok5E4
# 13:23:50 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\Surviving an ISIS Massacre - Video - NYTimes.com.mp4 with title: ISIS - Surviving an ISIS Massacre - Video - NYTimes.com
# 13:24:26 - Upload successful! Video ID: cAnT2IQpZOI
# 13:24:26 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\The Evolution of ISIS - The New York Times - YouTube (1).mp4 with title: ISIS - The Evolution of ISIS - The New York Times - YouTube (1)
# 13:25:01 - Upload successful! Video ID: o81yAyr3WBc
# 13:25:01 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\The Evolution of ISIS - The New York Times - YouTube.mp4 with title: ISIS - The Evolution of ISIS - The New York Times - YouTube
# 13:25:35 - Upload successful! Video ID: UqIieaNyVrU
# 13:25:35 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\the-islamic-state-22crack-down-upon-them-wilacc84yat-al-raqqah22_hd (January 27, 2017).MP4 with title: ISIS - the-islamic-state-22crack-down-upon-them-wilacc84yat-al-raqqah22_hd (January 27, 2017)
# 13:28:20 - Upload successful! Video ID: ajzCEHISZoY
# 13:28:20 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\the-islamic-state-22it-is-those-who-are-the-truthful-coverage-of-the-life-of-emigrants-from-eastern-turkista.MP4 with title: ISIS - the-islamic-state-22it-is-those-who-are-the-truthful-coverage-of-the-life-of-emigrants-from-e
# 13:29:10 - Upload successful! Video ID: aCAOBJpJ3Lk
# 13:29:10 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\the-islamic-state-22the-bravery-of-men-wilacc84yat-al-furacc84t22_hd.MP4 with title: ISIS - the-islamic-state-22the-bravery-of-men-wilacc84yat-al-furacc84t22_hd
# 13:30:31 - Upload successful! Video ID: DxtNnZz4t1g
# 13:30:31 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\the-islamic-state-22the-castle-of-glories-wilacc84yat-baghdacc84d22_hd.MP4 with title: ISIS - the-islamic-state-22the-castle-of-glories-wilacc84yat-baghdacc84d22_hd
# 13:32:40 - Upload successful! Video ID: xKMlZ9iJAjI
# 13:32:40 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\the-islamic-state-e2809cthe-flame-of-sacrifice-2-e28093-wilacc84yat-scca3alacc84hcca3-al-dicc84ne2809d_hd.MP4 with title: ISIS - the-islamic-state-e2809cthe-flame-of-sacrifice-2-e28093-wilacc84yat-scca3alacc84hcca3-al-dicc
# 13:34:03 - Upload successful! Video ID: qlFHQTsNJ2A
# 13:34:03 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\داعش في بيع وشراء النساء اليزيديات لاختصابهن‬.mp4 with title: ISIS - داعش في بيع وشراء النساء اليزيديات لاختصابهن‬
# 13:34:09 - Upload successful! Video ID: vy8BNfJyFZY
# 13:34:09 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\داعش يرجُم امرأة حتى الموت في ريف حماة الشرقي بتهمة الزنا.mp4 with title: ISIS - داعش يرجُم امرأة حتى الموت في ريف حماة الشرقي بتهمة الزنا
# 13:34:19 - Upload successful! Video ID: 6JAO4p_taIE
# 13:34:19 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\ولاية سيناء التابعة للدولة الإسلامية تقدم الإصدار الإعلامي بعنوان صولة الأنصار.mp4 with title: ISIS - ولاية سيناء التابعة للدولة الإسلامية تقدم الإصدار الإعلامي بعنوان صولة الأنصار
# 13:37:56 - Upload successful! Video ID: fJLuhMHEQGU
# 13:37:56 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\Wilayat Sina\the-islamic-state-22a-glimmer-of-hope-for-the-sword-wilacc84yat-al-khayr22_hd.MP4 with title: Wilayat Sina - the-islamic-state-22a-glimmer-of-hope-for-the-sword-wilacc84yat-al-khayr22_hd
# 13:39:52 - Upload successful! Video ID: xd9MxdVvmD0
# 13:39:52 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\Wilayat Sina\the-islamic-state-22and-fight-against-the-polytheists-collectively-miscca3r22_hd.MP4 with title: Wilayat Sina - the-islamic-state-22and-fight-against-the-polytheists-collectively-miscca3r22_hd
# 13:42:49 - Upload successful! Video ID: T0Q9tXsSM_g
# 13:42:49 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\Wilayat Sina\the-islamic-state-22incision-of-the-necks-wilacc84yat-saynacc8422_hd.MP4 with title: Wilayat Sina - the-islamic-state-22incision-of-the-necks-wilacc84yat-saynacc8422_hd
# 13:43:23 - Upload successful! Video ID: zWWrDeC5ppI
# 13:43:23 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\Wilayat Sina\the-islamic-state-22indeed-with-hardship-will-be-ease-wilacc84yat-al-fallucc84jah22_hd.MP4 with title: Wilayat Sina - the-islamic-state-22indeed-with-hardship-will-be-ease-wilacc84yat-al-fallucc84jah22_h
# 13:43:55 - Upload successful! Video ID: 08xVQqllXew
# 13:43:55 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\Wilayat Sina\the-islamic-state-22message-to-our-brothers-in-the-sinai-wilacc84yat-hcca3amacc84h22_hd.MP4 with title: Wilayat Sina - the-islamic-state-22message-to-our-brothers-in-the-sinai-wilacc84yat-hcca3amacc84h22_
# 13:44:43 - Upload successful! Video ID: B3LW8UDzhrM
# 13:44:43 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\Wilayat Sina\the-islamic-state-22sinai-land-of-epic-battles-and-redemption-wilacc84yat-dimashq22_hd.MP4 with title: Wilayat Sina - the-islamic-state-22sinai-land-of-epic-battles-and-redemption-wilacc84yat-dimashq22_h
# 13:45:00 - Upload successful! Video ID: 3h0UGKHKl6A
# 13:45:00 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\Wilayat Sina\the-islamic-state-22sinai-the-gateway-to-jerusalem-wilacc84yat-hcca3imscca322_hd.MP4 with title: Wilayat Sina - the-islamic-state-22sinai-the-gateway-to-jerusalem-wilacc84yat-hcca3imscca322_hd
# 13:45:30 - Upload successful! Video ID: CRaI3fySk7g
# 13:45:30 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\New York Times\The Evolution of ISIS - The New York Times.mp4 with title: New York Times - The Evolution of ISIS - The New York Times
# 13:46:04 - Upload successful! Video ID: hMdaXroMV_M
# 13:46:04 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Authors\Abdullah al-Qasemi\Kosaymy\العقلية العربية عند عبدالله القصيمي.mp4 with title: Kosaymy - العقلية العربية عند عبدالله القصيمي
# 13:46:18 - Upload successful! Video ID: b4wtpBr8TmE
# 13:46:18 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Authors\Abdullah al-Qasemi\Kosaymy\اللّغة العربية عند عبدالله القصيمي.mp4 with title: Kosaymy - اللّغة العربية عند عبدالله القصيمي
# 13:46:26 - Upload successful! Video ID: kb8iAaM_qok
# 13:46:26 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Authors\Abdullah al-Qasemi\Kosaymy\برنامج قصيميات - الإرهاب الفكري وحرية التفكير والتعبير.mp4 with title: Kosaymy - برنامج قصيميات - الإرهاب الفكري وحرية التفكير والتعبير
# 13:46:32 - Upload successful! Video ID: 2CMocC3AJc4
# 13:46:32 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Authors\Abdullah al-Qasemi\Kosaymy\برنامج قصيميات - التقدم والثورة عند عبدالله القصيمي.mp4 with title: Kosaymy - برنامج قصيميات - التقدم والثورة عند عبدالله القصيمي
# 13:46:40 - Upload successful! Video ID: Q73DxEavSMI
# 13:46:40 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Authors\Abdullah al-Qasemi\Kosaymy\برنامج قصيميات - العرب ظاهرة صوتية.mp4 with title: Kosaymy - برنامج قصيميات - العرب ظاهرة صوتية
# 13:46:47 - Upload successful! Video ID: WFMi4Slt2Ds
# 13:46:47 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Authors\Abdullah al-Qasemi\Kosaymy\برنامج قصيميات - تُهمة الإلحاد عند عبدالله القصيمي.mp4 with title: Kosaymy - برنامج قصيميات - تُهمة الإلحاد عند عبدالله القصيمي
# 13:46:58 - Upload successful! Video ID: 6Me-5eAXQ_8
# 13:46:58 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Authors\Abdullah al-Qasemi\Kosaymy\برنامج قصيميات - دور الكاتب والمعلم مع الإسقاط على الاديان عند عبدالله القصيمي.mp4 with title: Kosaymy - برنامج قصيميات - دور الكاتب والمعلم مع الإسقاط على الاديان عند عبدالله القصيمي
# 13:47:06 - Upload successful! Video ID: nEESM9FeYpU
# 13:47:07 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_100.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_100
# 13:48:14 - Encountered 403 Forbidden with reason "authenticatedUserAccountSuspended"
# 13:48:14 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_100.wmv to YouTube (attempt 1): <HttpError 403 when requesting https://youtube.googleapis.com/upload/youtube/v3/videos?part=snippet%2Cstatus&alt=json&uploadType=resumable returned "The YouTube account of the authenticated user is suspended. In case the authenticated user is acting on behalf of another Google account, then this error refers to the latter.". Details: "[{'message': 'The YouTube account of the authenticated user is suspended. In case the authenticated user is acting on behalf of another Google account, then this error refers to the latter.', 'domain': 'youtube.common', 'reason': 'authenticatedUserAccountSuspended'}]">
# 13:48:14 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_100.wmv in 3 minutes...
# 13:51:15 - Encountered 403 Forbidden with reason "authenticatedUserAccountSuspended"
# 13:51:15 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_100.wmv to YouTube (attempt 2): <HttpError 403 when requesting None returned "The YouTube account of the authenticated user is suspended. In case the authenticated user is acting on behalf of another Google account, then this error refers to the latter.". Details: "[{'message': 'The YouTube account of the authenticated user is suspended. In case the authenticated user is acting on behalf of another Google account, then this error refers to the latter.', 'domain': 'youtube.common', 'reason': 'authenticatedUserAccountSuspended'}]">
# 13:51:15 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_100.wmv in 3 minutes...
# 13:54:15 - Encountered 403 Forbidden with reason "authenticatedUserAccountSuspended"
# 13:54:15 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_100.wmv to YouTube (attempt 3): <HttpError 403 when requesting None returned "The YouTube account of the authenticated user is suspended. In case the authenticated user is acting on behalf of another Google account, then this error refers to the latter.". Details: "[{'message': 'The YouTube account of the authenticated user is suspended. In case the authenticated user is acting on behalf of another Google account, then this error refers to the latter.', 'domain': 'youtube.common', 'reason': 'authenticatedUserAccountSuspended'}]">
# 13:54:15 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_100.wmv after 3 attempts.
# 13:54:15 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_100.wmv
# 13:54:15 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_101.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_101
# 13:54:15 - Encountered 403 Forbidden with reason "authenticatedUserAccountSuspended"
# 13:54:15 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_101.wmv to YouTube (attempt 1): <HttpError 403 when requesting None returned "The YouTube account of the authenticated user is suspended. In case the authenticated user is acting on behalf of another Google account, then this error refers to the latter.". Details: "[{'message': 'The YouTube account of the authenticated user is suspended. In case the authenticated user is acting on behalf of another Google account, then this error refers to the latter.', 'domain': 'youtube.common', 'reason': 'authenticatedUserAccountSuspended'}]">
# 13:54:15 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_101.wmv in 3 minutes...
# 13:57:15 - Encountered 403 Forbidden with reason "quotaExceeded"
# 13:57:15 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_101.wmv to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 13:57:15 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_101.wmv in 3 minutes...
# 14:00:15 - Encountered 403 Forbidden with reason "quotaExceeded"
# 14:00:15 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_101.wmv to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 14:00:15 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_101.wmv after 3 attempts.
# 14:00:15 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_101.wmv
# 14:00:15 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_103.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_103
# 14:00:16 - Encountered 403 Forbidden with reason "quotaExceeded"
# 14:00:16 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_103.wmv to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 14:00:16 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_103.wmv in 3 minutes...
# 14:03:16 - Encountered 403 Forbidden with reason "quotaExceeded"
# 14:03:16 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_103.wmv to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 14:03:16 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_103.wmv in 3 minutes...
# 14:06:16 - Encountered 403 Forbidden with reason "quotaExceeded"
# 14:06:16 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_103.wmv to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 14:06:16 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_103.wmv after 3 attempts.
# 14:06:16 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_103.wmv
# 14:06:16 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_104.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_104
# 14:06:16 - Encountered 403 Forbidden with reason "quotaExceeded"
# 14:06:16 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_104.wmv to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 14:06:16 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_104.wmv in 3 minutes...
# 14:09:16 - Encountered 403 Forbidden with reason "quotaExceeded"
# 14:09:16 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_104.wmv to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 14:09:16 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_104.wmv in 3 minutes...
# 14:12:17 - Encountered 403 Forbidden with reason "quotaExceeded"
# 14:12:17 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_104.wmv to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 14:12:17 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_104.wmv after 3 attempts.
# 14:12:17 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_104.wmv
# 14:12:17 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_105.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_105
# 14:12:17 - Encountered 403 Forbidden with reason "quotaExceeded"
# 14:12:17 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_105.wmv to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 14:12:17 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_105.wmv in 3 minutes...
# 14:15:17 - Encountered 403 Forbidden with reason "quotaExceeded"
# 14:15:17 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_105.wmv to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 14:15:17 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_105.wmv in 3 minutes...
# 14:18:17 - Encountered 403 Forbidden with reason "quotaExceeded"
# 14:18:17 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_105.wmv to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 14:18:17 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_105.wmv after 3 attempts.
# ...
# 16:24:29 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_127.wmv in 3 minutes...
# 16:27:30 - Encountered 403 Forbidden with reason "quotaExceeded"
# 16:27:30 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_127.wmv to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 16:27:30 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_127.wmv in 3 minutes...
# 16:30:30 - Encountered 403 Forbidden with reason "quotaExceeded"
# 16:30:30 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_127.wmv to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 16:30:30 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_127.wmv after 3 attempts.
# 16:30:30 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_127.wmv
# 16:30:30 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_128.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_128
# 16:30:30 - Encountered 403 Forbidden with reason "quotaExceeded"
# 16:30:30 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_128.wmv to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 16:30:30 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_128.wmv in 3 minutes...
# 16:33:30 - Encountered 403 Forbidden with reason "quotaExceeded"
# 16:33:30 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_128.wmv to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 16:33:30 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_128.wmv in 3 minutes...
# 16:36:30 - Encountered 403 Forbidden with reason "quotaExceeded"
# 16:36:30 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_128.wmv to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 16:36:30 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_128.wmv after 3 attempts.
# 16:36:30 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_128.wmv
# 16:36:30 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_129.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_129
# 16:36:30 - Encountered 403 Forbidden with reason "quotaExceeded"
# 16:36:30 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_129.wmv to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 16:36:30 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_129.wmv in 3 minutes...
# 16:39:31 - Encountered 403 Forbidden with reason "quotaExceeded"
# 16:39:31 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_129.wmv to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 16:39:31 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_129.wmv in 3 minutes...
# 16:42:31 - Encountered 403 Forbidden with reason "quotaExceeded"
# 16:42:31 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_129.wmv to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 16:42:31 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_129.wmv after 3 attempts.
# 16:42:31 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_129.wmv
# 16:42:31 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_131.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_131
# 16:42:31 - Encountered 403 Forbidden with reason "quotaExceeded"
# 16:42:31 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_131.wmv to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 16:42:31 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_131.wmv in 3 minutes...
# 16:45:31 - Encountered 403 Forbidden with reason "quotaExceeded"
# 16:45:31 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_131.wmv to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 16:45:31 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_131.wmv in 3 minutes...
# 16:48:31 - Encountered 403 Forbidden with reason "quotaExceeded"
# 16:48:31 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_131.wmv to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 16:48:31 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_131.wmv after 3 attempts.
# 16:48:31 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_131.wmv
# 16:48:31 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_132.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_132
# 16:48:31 - Encountered 403 Forbidden with reason "quotaExceeded"
# 16:48:31 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_132.wmv to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 16:48:31 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_132.wmv in 3 minutes...
# 16:51:32 - Encountered 403 Forbidden with reason "quotaExceeded"
# 16:51:32 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_132.wmv to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 16:51:32 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_132.wmv in 3 minutes...
# 16:54:32 - Encountered 403 Forbidden with reason "quotaExceeded"
# 16:54:32 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_132.wmv to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 16:54:32 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_132.wmv after 3 attempts.
# 16:54:32 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_132.wmv
# 16:54:32 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_133.wmv with title: 7ewar Al 7aq - 7ewar_al_7aq_133
# 16:54:32 - Encountered 403 Forbidden with reason "quotaExceeded"
# 16:54:32 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_133.wmv to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 16:54:32 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_133.wmv in 3 minutes...
# 16:57:33 - Encountered 403 Forbidden with reason "quotaExceeded"
# 16:57:33 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_133.wmv to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 16:57:33 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Religion And Atheism\Arabs\Christians\7ewar Al 7aq\7ewar_al_7aq_133.wmv in 3 minutes...
