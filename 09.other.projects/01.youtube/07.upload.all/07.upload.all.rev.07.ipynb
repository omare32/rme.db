# %%
import os
import sys
import glob
import logging
from datetime import datetime
from pathlib import Path
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import tkinter as tk
from tkinter import filedialog
from google_auth_oauthlib.flow import InstalledAppFlow
from google.oauth2.credentials import Credentials
from google.auth.transport.requests import Request
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload
import time

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(message)s',
    datefmt='%H:%M:%S',
    handlers=[
        logging.FileHandler('upload_all.log', encoding='utf-8'),
        logging.StreamHandler()
    ]
)

TOKEN_FILE = "token.json"
SCOPES = ["https://www.googleapis.com/auth/youtube.upload"]

os.environ['OAUTHLIB_INSECURE_TRANSPORT'] = '1'
os.environ['PYTHONHTTPSVERIFY'] = '0'

def get_authenticated_service(client_secrets_file: str):
    creds = None
    if os.path.exists(TOKEN_FILE):
        creds = Credentials.from_authorized_user_file(TOKEN_FILE, SCOPES)
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(client_secrets_file, SCOPES)
            creds = flow.run_local_server(port=0)
        with open(TOKEN_FILE, 'w') as token:
            token.write(creds.to_json())
    return build('youtube', 'v3', credentials=creds)

def upload_to_youtube(youtube, video_path: str, title: str, description: str = "Uploaded by script"):
    MAX_RETRIES = 3
    RETRY_DELAY_SECONDS = 180  # 3 minutes
    for attempt in range(1, MAX_RETRIES + 1):
        try:
            body = {
                'snippet': {
                    'title': title,
                    'description': description,
                    'tags': ['tutorial', 'education']
                },
                'status': {
                    'privacyStatus': 'unlisted',
                    'selfDeclaredMadeForKids': False
                }
            }
            insert_request = youtube.videos().insert(
                part=','.join(body.keys()),
                body=body,
                media_body=MediaFileUpload(video_path, chunksize=-1, resumable=True)
            )
            response = None
            while response is None:
                status, response = insert_request.next_chunk()
                if status:
                    logging.info(f"Upload {int(status.progress() * 100)}% complete for {video_path}")
            return response['id']
        except Exception as e:
            logging.error(f"Error uploading {video_path} to YouTube (attempt {attempt}): {str(e)}")
            if attempt < MAX_RETRIES:
                logging.info(f"Retrying upload for {video_path} in {RETRY_DELAY_SECONDS // 60} minutes...")
                time.sleep(RETRY_DELAY_SECONDS)
            else:
                logging.error(f"Upload failed for {video_path} after {MAX_RETRIES} attempts.")
                return None

def select_folder_dialog(title="Select folder"):
    """Open a folder selection dialog and return the selected path."""
    try:
        root = tk.Tk()
        root.withdraw()
        root.update_idletasks()
        width = root.winfo_screenwidth()
        height = root.winfo_screenheight()
        x = (width - 400) // 2
        y = (height - 300) // 2
        root.geometry(f'400x300+{x}+{y}')
        folder_path = filedialog.askdirectory(
            title=title,
            mustexist=True
        )
        root.destroy()
        return folder_path
    except Exception as e:
        logging.error(f"Error in folder selection: {str(e)}")
        return None

def main():
    # Select parent folder
    parent_folder = select_folder_dialog(title="Select parent folder containing videos to upload recursively")
    if not parent_folder or not os.path.exists(parent_folder):
        logging.error("No folder selected or folder does not exist")
        return
    cwd = os.getcwd()
    client_secrets_file = os.path.join(cwd, "client_secret.dlc.json")
    if not os.path.exists(client_secrets_file):
        logging.error(f"Client secrets file not found at: {client_secrets_file}")
        return
    youtube = get_authenticated_service(client_secrets_file)
    logging.info("YouTube authentication complete.")
    VIDEO_EXTENSIONS = ('.mp4', '.mkv', '.avi', '.mov', '.wmv', '.flv', '.webm')
    for root, _, files in os.walk(parent_folder):
        for file in files:
            if file.lower().endswith(VIDEO_EXTENSIONS) and not file.endswith('.txt'):
                video_path = os.path.join(root, file)
                video_name = os.path.splitext(file)[0]
                link_file = os.path.join(root, f"{video_name}.txt")
                if not os.path.exists(link_file):
                    folder_name = os.path.basename(root)
                    MAX_TITLE_LENGTH = 100
                    title = f"{folder_name} - {video_name}"
                    if len(title) > MAX_TITLE_LENGTH:
                        title = title[:MAX_TITLE_LENGTH]
                    logging.info(f"Uploading: {video_path} with title: {title}")
                    video_id = upload_to_youtube(youtube, video_path, title)
                    if video_id:
                        with open(link_file, 'w') as f:
                            f.write(f"https://www.youtube.com/watch?v={video_id}\n")
                        try:
                            os.remove(video_path)
                        except Exception as e:
                            logging.error(f"Failed to delete uploaded video file: {video_path}: {str(e)}")
                        logging.info(f"Upload successful! Video ID: {video_id}")
                    else:
                        logging.error(f"Upload failed for {video_path}")
                else:
                    logging.info(f"Link file already exists for {video_path}. Skipping upload.")
    logging.info("All specified folders and subfolders processed.")

if __name__ == "__main__":
    main()
# Out:
# 13:49:16 - file_cache is only supported with oauth2client<4.0.0
# 13:49:16 - YouTube authentication complete.
# 13:49:17 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\4.2 - Metabolic Reactions 02 - Minerals & Vitamins.mp4 with title: Biology 301 Lectures - 4.2 - Metabolic Reactions 02 - Minerals & Vitamins
# 13:50:01 - Upload successful! Video ID: t_A34Snwp0w
# 13:50:01 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\4.3 - Metabolic Reactions 03 - Enzyme Inhibitors.mp4 with title: Biology 301 Lectures - 4.3 - Metabolic Reactions 03 - Enzyme Inhibitors
# 13:51:06 - Upload successful! Video ID: zhMkO_ydcaU
# 13:51:06 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\5.1 - Photosynthesis 01.mp4 with title: Biology 301 Lectures - 5.1 - Photosynthesis 01
# 13:52:23 - Upload successful! Video ID: o6eeLn05b14
# 13:52:23 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\5.2 - Photosynthesis 02.mp4 with title: Biology 301 Lectures - 5.2 - Photosynthesis 02
# 13:53:54 - Upload successful! Video ID: PBSZj4FqxWs
# 13:53:54 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\6.1 - Cellular Respiration 01.mp4 with title: Biology 301 Lectures - 6.1 - Cellular Respiration 01
# 13:55:43 - Upload successful! Video ID: y_wA9rcKhxo
# 13:55:43 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\6.2 - Cellular Respiration 02.mp4 with title: Biology 301 Lectures - 6.2 - Cellular Respiration 02
# 13:57:49 - Upload successful! Video ID: uCZP-baGbxE
# 13:57:49 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\6.3 - Cellular Respiration 03.mp4 with title: Biology 301 Lectures - 6.3 - Cellular Respiration 03
# 13:58:47 - Upload successful! Video ID: mVd9U97XgvA
# 13:58:47 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Educational\Steven Fink\Biology 301 Lectures\7.1 - Ecosystems 01 - Food Chains & Biomes.mp4 with title: Biology 301 Lectures - 7.1 - Ecosystems 01 - Food Chains & Biomes
# 14:00:56 - Upload successful! Video ID: PoE5Df8God4
# 14:00:57 - Link file already exists for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin\The.Genius.of.Charles.Darwin.1of3.Life.Darwin.and.Everything.XviD.AC3.MVGroup.org.avi. Skipping upload.
# 14:00:57 - Link file already exists for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin\The.Genius.of.Charles.Darwin.2of3.The.Fifth.Ape.XviD.AC3.MVGroup.org.avi. Skipping upload.
# 14:00:57 - Link file already exists for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin\The.Genius.of.Charles.Darwin.3of3.God.Strikes.Back.XviD.AC3.MVGroup.org.avi. Skipping upload.
# 14:00:57 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin - The Uncut Interviews\The.Genius.of.Charles.Darwin.The.Uncut.Interviews.Sean.Casey.avi with title: 2008 - The Genius of Charles Darwin - The Uncut Interviews - The.Genius.of.Charles.Darwin.The.Uncut.
# 14:03:26 - Upload successful! Video ID: FO-mNvnQ5mE
# 14:03:26 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin - The Uncut Interviews\The.Genius.of.Charles.Darwin.The.Uncut.Interviews.Sperm.Bank.Women.avi with title: 2008 - The Genius of Charles Darwin - The Uncut Interviews - The.Genius.of.Charles.Darwin.The.Uncut.
# 14:08:58 - Upload successful! Video ID: RZZlAtNwYsg
# 14:08:58 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin - The Uncut Interviews\The.Genius.of.Charles.Darwin.The.Uncut.Interviews.Steven.Pinker.avi with title: 2008 - The Genius of Charles Darwin - The Uncut Interviews - The.Genius.of.Charles.Darwin.The.Uncut.
# 14:12:48 - Upload successful! Video ID: 3ok9XQgvqsI
# 14:12:48 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin - The Uncut Interviews\The.Genius.of.Charles.Darwin.The.Uncut.Interviews.Steven.Rose.avi with title: 2008 - The Genius of Charles Darwin - The Uncut Interviews - The.Genius.of.Charles.Darwin.The.Uncut.
# 14:18:45 - Upload successful! Video ID: ZxFqV1cNCfc
# 14:18:45 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin - The Uncut Interviews\The.Genius.of.Charles.Darwin.The.Uncut.Interviews.Wayne.Besen.avi with title: 2008 - The Genius of Charles Darwin - The Uncut Interviews - The.Genius.of.Charles.Darwin.The.Uncut.
# 14:19:55 - Upload successful! Video ID: 2VvfKRs-h04
# 14:19:55 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2008 - The Genius of Charles Darwin - The Uncut Interviews\The.Genius.of.Charles.Darwin.The.Uncut.Interviews.Wendy.Wright.avi with title: 2008 - The Genius of Charles Darwin - The Uncut Interviews - The.Genius.of.Charles.Darwin.The.Uncut.
# 14:26:11 - Upload successful! Video ID: sNbgOxi475Y
# 14:26:11 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2010 - The God Delusion\The God Delusion (Channel 4 - 2010).avi with title: 2010 - The God Delusion - The God Delusion (Channel 4 - 2010)
# 14:30:44 - Upload successful! Video ID: 59cBkx77hlI
# 14:30:44 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2012 - Sex, Death and the Meaning of Life\Ch4.Sex.Death.and.the.Meaning.of.Life.3of3.PDTV.x264.AAC.MVGroup.org.mkv with title: 2012 - Sex, Death and the Meaning of Life - Ch4.Sex.Death.and.the.Meaning.of.Life.3of3.PDTV.x264.AAC
# 14:33:35 - Upload successful! Video ID: 6Gw4Wtnq-s0
# 14:33:35 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2012 - Sex, Death and the Meaning of Life\sex.death.and.the.meaning.of.life.s01e01.720p.hdtv.x264-knifesharp.mkv with title: 2012 - Sex, Death and the Meaning of Life - sex.death.and.the.meaning.of.life.s01e01.720p.hdtv.x264-
# 14:39:13 - Upload successful! Video ID: 81yjxRNgpOw
# 14:39:13 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2012 - Sex, Death and the Meaning of Life\sex.death.and.the.meaning.of.life.s01e02.720p.hdtv.x264-knifesharp.mkv with title: 2012 - Sex, Death and the Meaning of Life - sex.death.and.the.meaning.of.life.s01e02.720p.hdtv.x264-
# 14:44:49 - Upload successful! Video ID: SsPbYVwwzDI
# 14:44:49 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2013 - The Unbelievers\The Unbelievers.mkv with title: 2013 - The Unbelievers - The Unbelievers
# 14:48:18 - Upload successful! Video ID: uFAlxUr_kAE
# 14:48:18 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2013 - The Unbelievers\Extras\01 - Extended Interviews.mkv with title: Extras - 01 - Extended Interviews
# 14:50:56 - Upload successful! Video ID: YFb9sT5G8dM
# 14:50:56 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2013 - The Unbelievers\Extras\02 - Deleted Scenes.mkv with title: Extras - 02 - Deleted Scenes
# 14:51:39 - Upload successful! Video ID: vANiKoQ26pk
# 14:51:39 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2013 - The Unbelievers\Extras\03 - On The Road.mkv with title: Extras - 03 - On The Road
# 14:52:23 - Upload successful! Video ID: OIdxl03Iwes
# 14:52:23 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Evolutionary Biologists\Richard Dawkins\2013 - The Unbelievers\Extras\04 - Original Trailer.mkv with title: Extras - 04 - Original Trailer
# 14:52:33 - Upload successful! Video ID: QC9wlilYWCg
# 14:52:33 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Neurologists\Julian Jaynes\Barriers to Understanding Julian Jaynes  Theory (1 of 2).mkv with title: Julian Jaynes - Barriers to Understanding Julian Jaynes  Theory (1 of 2)
# 14:52:40 - Upload successful! Video ID: GZzahaQwSm8
# 14:52:40 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Neurologists\Julian Jaynes\Barriers to Understanding Julian Jaynes  Theory (2 of 2).mkv with title: Julian Jaynes - Barriers to Understanding Julian Jaynes  Theory (2 of 2)
# 14:52:45 - Upload successful! Video ID: DFzwdbO-1FQ
# 14:52:45 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Neurologists\Julian Jaynes\Brian J. McVeigh - Julian Jaynes and Neurotheology.mkv with title: Julian Jaynes - Brian J. McVeigh - Julian Jaynes and Neurotheology
# 14:52:53 - Upload successful! Video ID: hfuyKnzI88o
# 14:52:53 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Neurologists\Julian Jaynes\Jan Sleutels - Greek Zombies (Part 1 of 3).mkv with title: Julian Jaynes - Jan Sleutels - Greek Zombies (Part 1 of 3)
# 14:53:00 - Upload successful! Video ID: XKPst0cN70U
# 14:53:00 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Neurologists\Julian Jaynes\Jan Sleutels - Greek Zombies (Part 2 of 3).mkv with title: Julian Jaynes - Jan Sleutels - Greek Zombies (Part 2 of 3)
# 14:53:07 - Upload successful! Video ID: -Du2mCsEsrg
# 14:53:07 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Neurologists\Julian Jaynes\Jan Sleutels - Greek Zombies (Part 3 of 3).mkv with title: Julian Jaynes - Jan Sleutels - Greek Zombies (Part 3 of 3)
# 14:53:11 - Upload successful! Video ID: qCdgYpL3SuM
# 14:53:11 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Neurologists\Julian Jaynes\Julian Jaynes and the Bicameral Mind Theory.mkv with title: Julian Jaynes - Julian Jaynes and the Bicameral Mind Theory
# 14:53:26 - Upload successful! Video ID: Od06almUrNA
# 14:53:26 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Neurologists\Julian Jaynes\Prof. John Limber - Consciousness is Just A Word.mp4 with title: Julian Jaynes - Prof. John Limber - Consciousness is Just A Word
# 14:53:36 - Upload successful! Video ID: NR4ykU5PEtw
# 14:53:36 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Neurologists\Julian Jaynes\William Woodward - Julian Jaynes After 1976 (Part 1 of 2).mkv with title: Julian Jaynes - William Woodward - Julian Jaynes After 1976 (Part 1 of 2)
# 14:53:41 - Upload successful! Video ID: U6zK7hrfx7k
# 14:53:41 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Neurologists\Julian Jaynes\William Woodward - Julian Jaynes After 1976 (Part 2 of 2).mkv with title: Julian Jaynes - William Woodward - Julian Jaynes After 1976 (Part 2 of 2)
# 14:53:46 - Upload successful! Video ID: Wmz14enjMyo
# 14:53:46 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Neurologists\V. S. Ramachandran\V.S. Ramachandran -The Tell-Tale Brain- A Neuroscientist_s Quest for What Makes Us Human - YouTube.flv with title: V. S. Ramachandran - V.S. Ramachandran -The Tell-Tale Brain- A Neuroscientist_s Quest for What Makes
# 14:54:45 - Upload successful! Video ID: h2-umAEfANE
# 14:54:45 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychologists\Daniel Kahneman\Explorations of the Mind- Intuition with Daniel Kahneman - YouTube.mp4 with title: Daniel Kahneman - Explorations of the Mind- Intuition with Daniel Kahneman - YouTube
# 14:55:32 - Upload successful! Video ID: 8gayOJMqfUE
# 14:55:32 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychologists\Daniel Kahneman\Explorations of the Mind- Well-Being with Daniel Kahneman - YouTube_2.mp4 with title: Daniel Kahneman - Explorations of the Mind- Well-Being with Daniel Kahneman - YouTube_2
# 14:56:14 - Upload successful! Video ID: h6WD6aYmnY4
# 14:56:14 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychologists\Steven Pinker\Richard.Dawkins.Interviews.with.Steven.Pinker.mp4 with title: Steven Pinker - Richard.Dawkins.Interviews.with.Steven.Pinker
# 14:59:20 - Upload successful! Video ID: qiuROCx1jj8
# 14:59:20 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychologists\Steven Pinker\Steven Pinker - The Past, Present and Future of Violence - YouTube.mp4 with title: Steven Pinker - Steven Pinker - The Past, Present and Future of Violence - YouTube
# 15:00:27 - Upload successful! Video ID: y3KtXZjo3iE
# 15:00:27 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychologists\Steven Pinker\Steven Pinker on Good Writing, with Ian McEwan - YouTube.mp4 with title: Steven Pinker - Steven Pinker on Good Writing, with Ian McEwan - YouTube
# 15:01:39 - Upload successful! Video ID: LbABJtSKdIQ
# 15:01:39 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychologists\Steven Pinker\Steven Pinker, -The Sense of Style- - YouTube.mp4 with title: Steven Pinker - Steven Pinker, -The Sense of Style- - YouTube
# 15:01:40 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:01:40 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychologists\Steven Pinker\Steven Pinker, -The Sense of Style- - YouTube.mp4 to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:01:40 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychologists\Steven Pinker\Steven Pinker, -The Sense of Style- - YouTube.mp4 in 3 minutes...
# 15:04:40 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:04:40 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychologists\Steven Pinker\Steven Pinker, -The Sense of Style- - YouTube.mp4 to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:04:40 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychologists\Steven Pinker\Steven Pinker, -The Sense of Style- - YouTube.mp4 in 3 minutes...
# 15:07:40 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:07:40 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychologists\Steven Pinker\Steven Pinker, -The Sense of Style- - YouTube.mp4 to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:07:40 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychologists\Steven Pinker\Steven Pinker, -The Sense of Style- - YouTube.mp4 after 3 attempts.
# 15:07:40 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychologists\Steven Pinker\Steven Pinker, -The Sense of Style- - YouTube.mp4
# 15:07:40 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychologists\Steven Pinker\Steven Pinker- Linguistics as a Window to Understanding the Brain - YouTube.mp4 with title: Steven Pinker - Steven Pinker- Linguistics as a Window to Understanding the Brain - YouTube
# 15:07:40 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:07:40 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychologists\Steven Pinker\Steven Pinker- Linguistics as a Window to Understanding the Brain - YouTube.mp4 to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:07:40 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychologists\Steven Pinker\Steven Pinker- Linguistics as a Window to Understanding the Brain - YouTube.mp4 in 3 minutes...
# 15:10:40 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:10:40 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychologists\Steven Pinker\Steven Pinker- Linguistics as a Window to Understanding the Brain - YouTube.mp4 to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:10:40 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychologists\Steven Pinker\Steven Pinker- Linguistics as a Window to Understanding the Brain - YouTube.mp4 in 3 minutes...
# 15:13:40 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:13:40 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychologists\Steven Pinker\Steven Pinker- Linguistics as a Window to Understanding the Brain - YouTube.mp4 to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:13:40 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychologists\Steven Pinker\Steven Pinker- Linguistics as a Window to Understanding the Brain - YouTube.mp4 after 3 attempts.
# 15:13:40 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychologists\Steven Pinker\Steven Pinker- Linguistics as a Window to Understanding the Brain - YouTube.mp4
# 15:13:40 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychologists\Steven Pinker\Understanding Human Nature with Steven Pinker - Conversations with History - YouTube.mp4 with title: Steven Pinker - Understanding Human Nature with Steven Pinker - Conversations with History - YouTube
# 15:13:40 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:13:40 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychologists\Steven Pinker\Understanding Human Nature with Steven Pinker - Conversations with History - YouTube.mp4 to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:13:40 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychologists\Steven Pinker\Understanding Human Nature with Steven Pinker - Conversations with History - YouTube.mp4 in 3 minutes...
# 15:16:40 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:16:40 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychologists\Steven Pinker\Understanding Human Nature with Steven Pinker - Conversations with History - YouTube.mp4 to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:16:40 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychologists\Steven Pinker\Understanding Human Nature with Steven Pinker - Conversations with History - YouTube.mp4 in 3 minutes...
# 15:19:41 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:19:41 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychologists\Steven Pinker\Understanding Human Nature with Steven Pinker - Conversations with History - YouTube.mp4 to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:19:41 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychologists\Steven Pinker\Understanding Human Nature with Steven Pinker - Conversations with History - YouTube.mp4 after 3 attempts.
# 15:19:41 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychologists\Steven Pinker\Understanding Human Nature with Steven Pinker - Conversations with History - YouTube.mp4
# 15:19:41 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 1.mkv with title: New Folder - Psych 1 - General Psychology - Lecture 1
# 15:19:41 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:19:41 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 1.mkv to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:19:41 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 1.mkv in 3 minutes...
# 15:22:41 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:22:41 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 1.mkv to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:22:41 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 1.mkv in 3 minutes...
# 15:25:41 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:25:41 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 1.mkv to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:25:41 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 1.mkv after 3 attempts.
# 15:25:41 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 1.mkv
# 15:25:41 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 10.mkv with title: New Folder - Psych 1 - General Psychology - Lecture 10
# 15:25:41 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:25:41 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 10.mkv to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:25:41 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 10.mkv in 3 minutes...
# 15:28:41 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:28:41 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 10.mkv to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:28:41 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 10.mkv in 3 minutes...
# 15:31:42 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:31:42 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 10.mkv to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:31:42 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 10.mkv after 3 attempts.
# 15:31:42 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 10.mkv
# 15:31:42 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 11.mkv with title: New Folder - Psych 1 - General Psychology - Lecture 11
# 15:31:42 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:31:42 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 11.mkv to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:31:42 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 11.mkv in 3 minutes...
# 15:34:42 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:34:42 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 11.mkv to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:34:42 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 11.mkv in 3 minutes...
# 15:37:42 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:37:42 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 11.mkv to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:37:42 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 11.mkv after 3 attempts.
# 15:37:42 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 11.mkv
# 15:37:42 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 12.mkv with title: New Folder - Psych 1 - General Psychology - Lecture 12
# 15:37:42 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:37:42 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 12.mkv to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:37:42 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 12.mkv in 3 minutes...
# 15:40:42 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:40:42 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 12.mkv to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:40:42 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 12.mkv in 3 minutes...
# 15:43:42 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:43:42 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 12.mkv to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:43:42 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 12.mkv after 3 attempts.
# 15:43:42 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 12.mkv
# 15:43:42 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 13.mkv with title: New Folder - Psych 1 - General Psychology - Lecture 13
# 15:43:42 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:43:42 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 13.mkv to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:43:42 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 13.mkv in 3 minutes...
# 15:46:43 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:46:43 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 13.mkv to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:46:43 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 13.mkv in 3 minutes...
# 15:49:43 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:49:43 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 13.mkv to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:49:43 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 13.mkv after 3 attempts.
# 15:49:43 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 13.mkv
# 15:49:43 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 14.mkv with title: New Folder - Psych 1 - General Psychology - Lecture 14
# 15:49:43 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:49:43 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 14.mkv to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:49:43 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 14.mkv in 3 minutes...
# 15:52:43 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:52:43 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 14.mkv to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:52:43 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 14.mkv in 3 minutes...
# 15:55:43 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:55:43 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 14.mkv to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:55:43 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 14.mkv after 3 attempts.
# 15:55:43 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 14.mkv
# 15:55:43 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 15.mkv with title: New Folder - Psych 1 - General Psychology - Lecture 15
# 15:55:44 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:55:44 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 15.mkv to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:55:44 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 15.mkv in 3 minutes...
# 15:58:44 - Encountered 403 Forbidden with reason "quotaExceeded"
# 15:58:44 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 15.mkv to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 15:58:44 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 15.mkv in 3 minutes...
# 16:01:44 - Encountered 403 Forbidden with reason "quotaExceeded"
# 16:01:44 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 15.mkv to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 16:01:44 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Biology And Psychology\Psychology\New Folder\Psych 1 - General Psychology - Lecture 15.mkv after 3 attempts.
# ...
# 21:45:48 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\the-islamic-state-e2809cthe-flame-of-sacrifice-2-e28093-wilacc84yat-scca3alacc84hcca3-al-dicc84ne2809d_hd.MP4 in 3 minutes...
# 21:48:48 - Encountered 403 Forbidden with reason "quotaExceeded"
# 21:48:48 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\the-islamic-state-e2809cthe-flame-of-sacrifice-2-e28093-wilacc84yat-scca3alacc84hcca3-al-dicc84ne2809d_hd.MP4 to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 21:48:48 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\the-islamic-state-e2809cthe-flame-of-sacrifice-2-e28093-wilacc84yat-scca3alacc84hcca3-al-dicc84ne2809d_hd.MP4 after 3 attempts.
# 21:48:48 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\the-islamic-state-e2809cthe-flame-of-sacrifice-2-e28093-wilacc84yat-scca3alacc84hcca3-al-dicc84ne2809d_hd.MP4
# 21:48:48 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\داعش في بيع وشراء النساء اليزيديات لاختصابهن‬.mp4 with title: ISIS - داعش في بيع وشراء النساء اليزيديات لاختصابهن‬
# 21:48:48 - Encountered 403 Forbidden with reason "quotaExceeded"
# 21:48:48 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\داعش في بيع وشراء النساء اليزيديات لاختصابهن‬.mp4 to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 21:48:48 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\داعش في بيع وشراء النساء اليزيديات لاختصابهن‬.mp4 in 3 minutes...
# 21:51:48 - Encountered 403 Forbidden with reason "quotaExceeded"
# 21:51:48 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\داعش في بيع وشراء النساء اليزيديات لاختصابهن‬.mp4 to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 21:51:48 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\داعش في بيع وشراء النساء اليزيديات لاختصابهن‬.mp4 in 3 minutes...
# 21:54:48 - Encountered 403 Forbidden with reason "quotaExceeded"
# 21:54:48 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\داعش في بيع وشراء النساء اليزيديات لاختصابهن‬.mp4 to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 21:54:48 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\داعش في بيع وشراء النساء اليزيديات لاختصابهن‬.mp4 after 3 attempts.
# 21:54:48 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\داعش في بيع وشراء النساء اليزيديات لاختصابهن‬.mp4
# 21:54:48 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\داعش يرجُم امرأة حتى الموت في ريف حماة الشرقي بتهمة الزنا.mp4 with title: ISIS - داعش يرجُم امرأة حتى الموت في ريف حماة الشرقي بتهمة الزنا
# 21:54:48 - Encountered 403 Forbidden with reason "quotaExceeded"
# 21:54:48 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\داعش يرجُم امرأة حتى الموت في ريف حماة الشرقي بتهمة الزنا.mp4 to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 21:54:48 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\داعش يرجُم امرأة حتى الموت في ريف حماة الشرقي بتهمة الزنا.mp4 in 3 minutes...
# 21:57:48 - Encountered 403 Forbidden with reason "quotaExceeded"
# 21:57:48 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\داعش يرجُم امرأة حتى الموت في ريف حماة الشرقي بتهمة الزنا.mp4 to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 21:57:48 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\داعش يرجُم امرأة حتى الموت في ريف حماة الشرقي بتهمة الزنا.mp4 in 3 minutes...
# 22:00:48 - Encountered 403 Forbidden with reason "quotaExceeded"
# 22:00:48 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\داعش يرجُم امرأة حتى الموت في ريف حماة الشرقي بتهمة الزنا.mp4 to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 22:00:48 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\داعش يرجُم امرأة حتى الموت في ريف حماة الشرقي بتهمة الزنا.mp4 after 3 attempts.
# 22:00:48 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\داعش يرجُم امرأة حتى الموت في ريف حماة الشرقي بتهمة الزنا.mp4
# 22:00:48 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\ولاية سيناء التابعة للدولة الإسلامية تقدم الإصدار الإعلامي بعنوان صولة الأنصار.mp4 with title: ISIS - ولاية سيناء التابعة للدولة الإسلامية تقدم الإصدار الإعلامي بعنوان صولة الأنصار
# 22:00:49 - Encountered 403 Forbidden with reason "quotaExceeded"
# 22:00:49 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\ولاية سيناء التابعة للدولة الإسلامية تقدم الإصدار الإعلامي بعنوان صولة الأنصار.mp4 to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 22:00:49 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\ولاية سيناء التابعة للدولة الإسلامية تقدم الإصدار الإعلامي بعنوان صولة الأنصار.mp4 in 3 minutes...
# 22:03:49 - Encountered 403 Forbidden with reason "quotaExceeded"
# 22:03:49 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\ولاية سيناء التابعة للدولة الإسلامية تقدم الإصدار الإعلامي بعنوان صولة الأنصار.mp4 to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 22:03:49 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\ولاية سيناء التابعة للدولة الإسلامية تقدم الإصدار الإعلامي بعنوان صولة الأنصار.mp4 in 3 minutes...
# 22:06:49 - Encountered 403 Forbidden with reason "quotaExceeded"
# 22:06:49 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\ولاية سيناء التابعة للدولة الإسلامية تقدم الإصدار الإعلامي بعنوان صولة الأنصار.mp4 to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 22:06:49 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\ولاية سيناء التابعة للدولة الإسلامية تقدم الإصدار الإعلامي بعنوان صولة الأنصار.mp4 after 3 attempts.
# 22:06:49 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\ولاية سيناء التابعة للدولة الإسلامية تقدم الإصدار الإعلامي بعنوان صولة الأنصار.mp4
# 22:06:49 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\Wilayat Sina\the-islamic-state-22a-glimmer-of-hope-for-the-sword-wilacc84yat-al-khayr22_hd.MP4 with title: Wilayat Sina - the-islamic-state-22a-glimmer-of-hope-for-the-sword-wilacc84yat-al-khayr22_hd
# 22:06:49 - Encountered 403 Forbidden with reason "quotaExceeded"
# 22:06:49 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\Wilayat Sina\the-islamic-state-22a-glimmer-of-hope-for-the-sword-wilacc84yat-al-khayr22_hd.MP4 to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 22:06:49 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\Wilayat Sina\the-islamic-state-22a-glimmer-of-hope-for-the-sword-wilacc84yat-al-khayr22_hd.MP4 in 3 minutes...
# 22:09:49 - Encountered 403 Forbidden with reason "quotaExceeded"
# 22:09:49 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\Wilayat Sina\the-islamic-state-22a-glimmer-of-hope-for-the-sword-wilacc84yat-al-khayr22_hd.MP4 to YouTube (attempt 2): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 22:09:49 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\Wilayat Sina\the-islamic-state-22a-glimmer-of-hope-for-the-sword-wilacc84yat-al-khayr22_hd.MP4 in 3 minutes...
# 22:12:50 - Encountered 403 Forbidden with reason "quotaExceeded"
# 22:12:50 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\Wilayat Sina\the-islamic-state-22a-glimmer-of-hope-for-the-sword-wilacc84yat-al-khayr22_hd.MP4 to YouTube (attempt 3): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 22:12:50 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\Wilayat Sina\the-islamic-state-22a-glimmer-of-hope-for-the-sword-wilacc84yat-al-khayr22_hd.MP4 after 3 attempts.
# 22:12:50 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\Wilayat Sina\the-islamic-state-22a-glimmer-of-hope-for-the-sword-wilacc84yat-al-khayr22_hd.MP4
# 22:12:50 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\Wilayat Sina\the-islamic-state-22and-fight-against-the-polytheists-collectively-miscca3r22_hd.MP4 with title: Wilayat Sina - the-islamic-state-22and-fight-against-the-polytheists-collectively-miscca3r22_hd
# 22:12:50 - Encountered 403 Forbidden with reason "quotaExceeded"
# 22:12:50 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\Wilayat Sina\the-islamic-state-22and-fight-against-the-polytheists-collectively-miscca3r22_hd.MP4 to YouTube (attempt 1): <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 22:12:50 - Retrying upload for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Science\Politics And Ethics\ISIS\Wilayat Sina\the-islamic-state-22and-fight-against-the-polytheists-collectively-miscca3r22_hd.MP4 in 3 minutes...
