# %%
import os
import glob
import logging
from datetime import datetime
from pathlib import Path
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
from google_auth_oauthlib.flow import InstalledAppFlow
from google.oauth2.credentials import Credentials
from google.auth.transport.requests import Request
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload
import tkinter as tk
from tkinter import filedialog

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(message)s',
    datefmt='%H:%M:%S',
    handlers=[
        logging.FileHandler('upload_all.log', encoding='utf-8'),
        logging.StreamHandler()
    ]
)

TOKEN_FILE = "token.json"
SCOPES = ["https://www.googleapis.com/auth/youtube.upload"]

os.environ['OAUTHLIB_INSECURE_TRANSPORT'] = '1'
os.environ['PYTHONHTTPSVERIFY'] = '0'

def get_authenticated_service(client_secrets_file: str):
    creds = None
    if os.path.exists(TOKEN_FILE):
        creds = Credentials.from_authorized_user_file(TOKEN_FILE, SCOPES)
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(client_secrets_file, SCOPES)
            creds = flow.run_local_server(port=0)
        with open(TOKEN_FILE, 'w') as token:
            token.write(creds.to_json())
    return build('youtube', 'v3', credentials=creds)

def upload_to_youtube(youtube, video_path: str, title: str, description: str = "Uploaded by script"):
    try:
        body = {
            'snippet': {
                'title': title,
                'description': description,
                'tags': ['tutorial', 'education']
            },
            'status': {
                'privacyStatus': 'unlisted',
                'selfDeclaredMadeForKids': False
            }
        }
        insert_request = youtube.videos().insert(
            part=','.join(body.keys()),
            body=body,
            media_body=MediaFileUpload(video_path, chunksize=-1, resumable=True)
        )
        response = None
        while response is None:
            status, response = insert_request.next_chunk()
            if status:
                logging.info(f"Upload {int(status.progress() * 100)}% complete for {video_path}")
        return response['id']
    except Exception as e:
        logging.error(f"Error uploading {video_path} to YouTube: {str(e)}")
        return None

def select_folder_dialog(title="Select the folder containing videos to upload"):
    root = tk.Tk()
    root.withdraw()
    folder_selected = filedialog.askdirectory(title=title)
    root.destroy()
    return folder_selected

def main():
    cwd = os.getcwd()
    client_secrets_file = os.path.join(cwd, "client_secret.dlc.json")
    if not os.path.exists(client_secrets_file):
        logging.error("Client secrets file not found")
        return
    youtube = get_authenticated_service(client_secrets_file)
    logging.info("YouTube authentication complete.")
    # Ask user for folder containing videos to upload
    input_folder = select_folder_dialog()
    if not input_folder or not os.path.exists(input_folder):
        logging.warning("No folder selected or path does not exist. Using current working directory.")
        input_folder = cwd
    folder_name = os.path.basename(input_folder)
    # Find all files in the folder (no recursion)
    video_files = [f for f in os.listdir(input_folder) 
                  if os.path.isfile(os.path.join(input_folder, f)) and 
                  not f.endswith('.txt')]  # Skip any existing .txt files
    
    if not video_files:
        logging.info("No files found in the folder.")
        return
        
    logging.info(f"Found {len(video_files)} files to process.")
    
    # Filter out any non-video files that might have been processed before
    video_files = [f for f in video_files if not os.path.exists(os.path.join(input_folder, os.path.splitext(f)[0] + '.txt'))]
    for video_path in video_files:
        video_name = os.path.splitext(os.path.basename(video_path))[0]
        title = f"{folder_name} - {video_name}"
        logging.info(f"Uploading: {video_path} with title: {title}")
        video_id = upload_to_youtube(youtube, video_path, title)
        if video_id:
            link_file = os.path.join(input_folder, f"{video_name}.txt")
            with open(link_file, 'w') as f:
                f.write(f"https://www.youtube.com/watch?v={video_id}\n")
            try:
                os.remove(video_path)
            except Exception as e:
                logging.error(f"Failed to delete uploaded video file: {video_path}: {str(e)}")
            logging.info(f"Upload successful! Video ID: {video_id}")
        else:
            logging.error(f"Upload failed for {video_path}")

main()
# Out:
# 18:40:07 - file_cache is only supported with oauth2client<4.0.0
# 18:40:07 - YouTube authentication complete.
# 18:40:10 - Found 14 files to process.
# 18:40:10 - Uploading: 1996 - Einstein - Fame.mpg with title: BBC Horizon - 1996 - Einstein - Fame
# 18:40:10 - Error uploading 1996 - Einstein - Fame.mpg to YouTube: [Errno 2] No such file or directory: '1996 - Einstein - Fame.mpg'
# 18:40:10 - Upload failed for 1996 - Einstein - Fame.mpg
# 18:40:10 - Uploading: 1996 - Einstein - The Miracle Year.mpg with title: BBC Horizon - 1996 - Einstein - The Miracle Year
# 18:40:10 - Error uploading 1996 - Einstein - The Miracle Year.mpg to YouTube: [Errno 2] No such file or directory: '1996 - Einstein - The Miracle Year.mpg'
# 18:40:10 - Upload failed for 1996 - Einstein - The Miracle Year.mpg
# 18:40:10 - Uploading: 2004 - Diamond Labs.mpg with title: BBC Horizon - 2004 - Diamond Labs
# 18:40:10 - Error uploading 2004 - Diamond Labs.mpg to YouTube: [Errno 2] No such file or directory: '2004 - Diamond Labs.mpg'
# 18:40:10 - Upload failed for 2004 - Diamond Labs.mpg
# 18:40:10 - Uploading: Isaac Newton - The Dark Heretic.mpg with title: BBC Horizon - Isaac Newton - The Dark Heretic
# 18:40:10 - Error uploading Isaac Newton - The Dark Heretic.mpg to YouTube: [Errno 2] No such file or directory: 'Isaac Newton - The Dark Heretic.mpg'
# 18:40:10 - Upload failed for Isaac Newton - The Dark Heretic.mpg
# 18:40:10 - Uploading: Japan - Future Japan.mpg with title: BBC Horizon - Japan - Future Japan
# 18:40:10 - Error uploading Japan - Future Japan.mpg to YouTube: [Errno 2] No such file or directory: 'Japan - Future Japan.mpg'
# 18:40:10 - Upload failed for Japan - Future Japan.mpg
# 18:40:10 - Uploading: Making Millions the Easy Way.mpg with title: BBC Horizon - Making Millions the Easy Way
# 18:40:10 - Error uploading Making Millions the Easy Way.mpg to YouTube: [Errno 2] No such file or directory: 'Making Millions the Easy Way.mpg'
# 18:40:10 - Upload failed for Making Millions the Easy Way.mpg
# 18:40:10 - Uploading: Music In Japan.mpg with title: BBC Horizon - Music In Japan
# 18:40:10 - Error uploading Music In Japan.mpg to YouTube: [Errno 2] No such file or directory: 'Music In Japan.mpg'
# 18:40:10 - Upload failed for Music In Japan.mpg
# 18:40:10 - Uploading: Orange Sherbet Kisses.mpg with title: BBC Horizon - Orange Sherbet Kisses
# 18:40:10 - Error uploading Orange Sherbet Kisses.mpg to YouTube: [Errno 2] No such file or directory: 'Orange Sherbet Kisses.mpg'
# 18:40:10 - Upload failed for Orange Sherbet Kisses.mpg
# 18:40:10 - Uploading: Police Stress - The John Wayne Syndrome.divx with title: BBC Horizon - Police Stress - The John Wayne Syndrome
# 18:40:10 - Error uploading Police Stress - The John Wayne Syndrome.divx to YouTube: [Errno 2] No such file or directory: 'Police Stress - The John Wayne Syndrome.divx'
# 18:40:10 - Upload failed for Police Stress - The John Wayne Syndrome.divx
# 18:40:10 - Uploading: Sex In Japan.mpg with title: BBC Horizon - Sex In Japan
# 18:40:10 - Error uploading Sex In Japan.mpg to YouTube: [Errno 2] No such file or directory: 'Sex In Japan.mpg'
# 18:40:10 - Upload failed for Sex In Japan.mpg
# 18:40:10 - Uploading: stein's Miracle Year.mpg with title: BBC Horizon - stein's Miracle Year
# 18:40:10 - Error uploading stein's Miracle Year.mpg to YouTube: [Errno 2] No such file or directory: "stein's Miracle Year.mpg"
# 18:40:10 - Upload failed for stein's Miracle Year.mpg
# 18:40:10 - Uploading: Taming the Problem Child.divx with title: BBC Horizon - Taming the Problem Child
# 18:40:10 - Error uploading Taming the Problem Child.divx to YouTube: [Errno 2] No such file or directory: 'Taming the Problem Child.divx'
# 18:40:10 - Upload failed for Taming the Problem Child.divx
# 18:40:10 - Uploading: The Atkins Diet.mpg with title: BBC Horizon - The Atkins Diet
# 18:40:10 - Error uploading The Atkins Diet.mpg to YouTube: [Errno 2] No such file or directory: 'The Atkins Diet.mpg'
# 18:40:10 - Upload failed for The Atkins Diet.mpg
# 18:40:10 - Uploading: The Mysterious Mr Tesla.mpg with title: BBC Horizon - The Mysterious Mr Tesla
# 18:40:10 - Error uploading The Mysterious Mr Tesla.mpg to YouTube: [Errno 2] No such file or directory: 'The Mysterious Mr Tesla.mpg'
# 18:40:10 - Upload failed for The Mysterious Mr Tesla.mpg
