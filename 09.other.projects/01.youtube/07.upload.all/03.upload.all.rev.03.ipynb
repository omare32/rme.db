# %%
import os
import sys
import glob
import logging
from datetime import datetime
from pathlib import Path
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import tkinter as tk
from tkinter import filedialog
from google_auth_oauthlib.flow import InstalledAppFlow
from google.oauth2.credentials import Credentials
from google.auth.transport.requests import Request
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(message)s',
    datefmt='%H:%M:%S',
    handlers=[
        logging.FileHandler('upload_all.log', encoding='utf-8'),
        logging.StreamHandler()
    ]
)

TOKEN_FILE = "token.json"
SCOPES = ["https://www.googleapis.com/auth/youtube.upload"]

os.environ['OAUTHLIB_INSECURE_TRANSPORT'] = '1'
os.environ['PYTHONHTTPSVERIFY'] = '0'

def get_authenticated_service(client_secrets_file: str):
    creds = None
    if os.path.exists(TOKEN_FILE):
        creds = Credentials.from_authorized_user_file(TOKEN_FILE, SCOPES)
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(client_secrets_file, SCOPES)
            creds = flow.run_local_server(port=0)
        with open(TOKEN_FILE, 'w') as token:
            token.write(creds.to_json())
    return build('youtube', 'v3', credentials=creds)

def upload_to_youtube(youtube, video_path: str, title: str, description: str = "Uploaded by script"):
    try:
        body = {
            'snippet': {
                'title': title,
                'description': description,
                'tags': ['tutorial', 'education']
            },
            'status': {
                'privacyStatus': 'unlisted',
                'selfDeclaredMadeForKids': False
            }
        }
        insert_request = youtube.videos().insert(
            part=','.join(body.keys()),
            body=body,
            media_body=MediaFileUpload(video_path, chunksize=-1, resumable=True)
        )
        response = None
        while response is None:
            status, response = insert_request.next_chunk()
            if status:
                logging.info(f"Upload {int(status.progress() * 100)}% complete for {video_path}")
        return response['id']
    except Exception as e:
        logging.error(f"Error uploading {video_path} to YouTube: {str(e)}")
        return None



def select_folder_dialog():
    """Open a folder selection dialog and return the selected path."""
    try:
        # Initialize Tkinter
        root = tk.Tk()
        root.withdraw()  # Hide the root window
        
        # Set dialog to center of screen
        root.update_idletasks()
        width = root.winfo_screenwidth()
        height = root.winfo_screenheight()
        x = (width - 400) // 2
        y = (height - 300) // 2
        root.geometry(f'400x300+{x}+{y}')
        
        # Show folder selection dialog
        folder_path = filedialog.askdirectory(
            title="Select folder containing videos to upload",
            mustexist=True
        )
        
        # Cleanup
        root.destroy()
        return folder_path
    except Exception as e:
        logging.error(f"Error in folder selection: {str(e)}")
        return None

def main():
    # Get folder path from dialog
    input_folder = select_folder_dialog()
    if not input_folder or not os.path.exists(input_folder):
        logging.error("No folder selected or folder does not exist")
        return
        
    cwd = os.getcwd()
    client_secrets_file = os.path.join(cwd, "client_secret.dlc.json")
    if not os.path.exists(client_secrets_file):
        logging.error(f"Client secrets file not found at: {client_secrets_file}")
        return
        
    youtube = get_authenticated_service(client_secrets_file)
    logging.info("YouTube authentication complete.")
    folder_name = os.path.basename(input_folder)
    # Find all files in the folder (no recursion)
    video_files = [os.path.join(input_folder, f) for f in os.listdir(input_folder) 
                  if os.path.isfile(os.path.join(input_folder, f)) and 
                  not f.endswith('.txt')]  # Skip any existing .txt files
    
    if not video_files:
        logging.info("No files found in the folder.")
        return
        
    logging.info(f"Found {len(video_files)} files to process.")
    
    # Filter out any files that have already been processed
    video_files = [f for f in video_files 
                  if not os.path.exists(os.path.splitext(f)[0] + '.txt')]
                  
    for video_path in video_files:
        video_name = os.path.splitext(os.path.basename(video_path))[0]
        title = f"{folder_name} - {video_name}"
        logging.info(f"Uploading: {video_path} with title: {title}")
        video_id = upload_to_youtube(youtube, video_path, title)
        if video_id:
            link_file = os.path.join(input_folder, f"{video_name}.txt")
            with open(link_file, 'w') as f:
                f.write(f"https://www.youtube.com/watch?v={video_id}\n")
            try:
                os.remove(video_path)
            except Exception as e:
                logging.error(f"Failed to delete uploaded video file: {video_path}: {str(e)}")
            logging.info(f"Upload successful! Video ID: {video_id}")
        else:
            logging.error(f"Upload failed for {video_path}")

main()
# Out:
# 08:17:04 - file_cache is only supported with oauth2client<4.0.0
# 08:17:04 - YouTube authentication complete.
# 08:17:04 - Found 41 files to process.
# 08:17:04 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Afghanistan.2of3.The.Battle.for.Helmand.HDTV.x264.MVGroup.Forum.mkv with title: BBC Organize - BBC.Afghanistan.2of3.The.Battle.for.Helmand.HDTV.x264.MVGroup.Forum
# 08:27:27 - Upload successful! Video ID: PIr4X22Hmw8
# 08:27:27 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Afghanistan.3of3.The.Unknown.Country.HDTV.x264.AC3.MVGroup.Forum.mkv with title: BBC Organize - BBC.Afghanistan.3of3.The.Unknown.Country.HDTV.x264.AC3.MVGroup.Forum
# 08:37:59 - Upload successful! Video ID: 12m42DcnUuo
# 08:37:59 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Afghanistan.The.Great.Game.1of2.720p.HDTV.x264.AAC.MVGroup.org.mkv with title: BBC Organize - BBC.Afghanistan.The.Great.Game.1of2.720p.HDTV.x264.AAC.MVGroup.org
# 08:48:00 - Upload successful! Video ID: ZjDqjY-gmdA
# 08:48:00 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Afghanistan.The.Great.Game.2of2.720p.HDTV.x264.AAC.MVGroup.org.mkv with title: BBC Organize - BBC.Afghanistan.The.Great.Game.2of2.720p.HDTV.x264.AAC.MVGroup.org
# 08:57:43 - Upload successful! Video ID: tjG-Y3E74Sg
# 08:57:43 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Britains.Muslim.Soldiers.720p.HDTV.x264.AAC.MVGroup.org.mkv with title: BBC Organize - BBC.Britains.Muslim.Soldiers.720p.HDTV.x264.AAC.MVGroup.org
# 09:02:00 - Upload successful! Video ID: HX30eyydzKk
# 09:02:00 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Correspondent.Israels.Secret.Weapon.XviD.mp3.avi with title: BBC Organize - BBC.Correspondent.Israels.Secret.Weapon.XviD.mp3
# 09:04:53 - Upload successful! Video ID: -C311ut2JQo
# 09:04:53 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Frank.Gardners.Return.to.Saudi.Arabia.720p.HDTV.x264.AAC.MVGroup.org.mkv with title: BBC Organize - BBC.Frank.Gardners.Return.to.Saudi.Arabia.720p.HDTV.x264.AAC.MVGroup.org
# 09:13:04 - Upload successful! Video ID: 0FtJt7sbVbg
# 09:13:04 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Horizon.2015.Are.Video.Games.Really.That.Bad.720p.HDTV.x264.AAC.MVGroup.org.mkv with title: BBC Organize - BBC.Horizon.2015.Are.Video.Games.Really.That.Bad.720p.HDTV.x264.AAC.MVGroup.org
# 09:20:04 - Upload successful! Video ID: UydCAykEtbk
# 09:20:04 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Iranian.Enough.PDTV.x264.AAC.MVGroup.org.mkv with title: BBC Organize - BBC.Iranian.Enough.PDTV.x264.AAC.MVGroup.org
# 09:23:08 - Upload successful! Video ID: dnuvgROHOnQ
# 09:23:08 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Irans.Nuclear.Secrets.DivX.mp3.avi with title: BBC Organize - BBC.Irans.Nuclear.Secrets.DivX.mp3
# 09:26:47 - Upload successful! Video ID: wwg6fpe92R4
# 09:26:47 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Israel.Facing.the.Future.720p.HDTV.x264.AAC.MVGroup.org.mkv with title: BBC Organize - BBC.Israel.Facing.the.Future.720p.HDTV.x264.AAC.MVGroup.org
# 09:35:21 - Upload successful! Video ID: jGppENapaoc
# 09:35:21 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Modern.Spies.1of2.PDTV.XviD.AC3.MVGroup.org.avi with title: BBC Organize - BBC.Modern.Spies.1of2.PDTV.XviD.AC3.MVGroup.org
# 09:39:21 - Upload successful! Video ID: CenYcK4_wlY
# 09:39:21 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Modern.Spies.2of2.PDTV.XviD.AC3.MVGroup.org.avi with title: BBC Organize - BBC.Modern.Spies.2of2.PDTV.XviD.AC3.MVGroup.org
# 09:39:22 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:39:22 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Modern.Spies.2of2.PDTV.XviD.AC3.MVGroup.org.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:39:22 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Modern.Spies.2of2.PDTV.XviD.AC3.MVGroup.org.avi
# 09:39:22 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Natural.World.2011.Miracle.in.the.Marshes.of.Iraq.HDTV.x264.AC3.MVGroup.org.mkv with title: BBC Organize - BBC.Natural.World.2011.Miracle.in.the.Marshes.of.Iraq.HDTV.x264.AC3.MVGroup.org
# 09:39:22 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:39:22 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Natural.World.2011.Miracle.in.the.Marshes.of.Iraq.HDTV.x264.AC3.MVGroup.org.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:39:22 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Natural.World.2011.Miracle.in.the.Marshes.of.Iraq.HDTV.x264.AC3.MVGroup.org.mkv
# 09:39:22 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Newsnight.2016.The.Trump.Revolution.720p.HDTV.x264.AAC.MVGroup.org.mkv with title: BBC Organize - BBC.Newsnight.2016.The.Trump.Revolution.720p.HDTV.x264.AAC.MVGroup.org
# 09:39:22 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:39:22 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Newsnight.2016.The.Trump.Revolution.720p.HDTV.x264.AAC.MVGroup.org.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:39:22 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Newsnight.2016.The.Trump.Revolution.720p.HDTV.x264.AAC.MVGroup.org.mkv
# 09:39:22 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Newsnight.Iraq.10.Years.On.576p.HDTV.x264.AAC.MVGroup.Forum.mkv with title: BBC Organize - BBC.Newsnight.Iraq.10.Years.On.576p.HDTV.x264.AAC.MVGroup.Forum
# 09:39:22 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:39:22 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Newsnight.Iraq.10.Years.On.576p.HDTV.x264.AAC.MVGroup.Forum.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:39:22 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Newsnight.Iraq.10.Years.On.576p.HDTV.x264.AAC.MVGroup.Forum.mkv
# 09:39:22 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Nuclear.Secrets.Set.Two.1of2.Vanunu.and.the.Bomb.x264.AC3.MVGroup.org.mkv with title: BBC Organize - BBC.Nuclear.Secrets.Set.Two.1of2.Vanunu.and.the.Bomb.x264.AC3.MVGroup.org
# 09:39:22 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:39:22 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Nuclear.Secrets.Set.Two.1of2.Vanunu.and.the.Bomb.x264.AC3.MVGroup.org.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:39:22 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Nuclear.Secrets.Set.Two.1of2.Vanunu.and.the.Bomb.x264.AC3.MVGroup.org.mkv
# 09:39:22 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Nuclear.Secrets.Set.Two.2of2.The.Terror.Trader.x264.AC3.MVGroup.org.mkv with title: BBC Organize - BBC.Nuclear.Secrets.Set.Two.2of2.The.Terror.Trader.x264.AC3.MVGroup.org
# 09:39:22 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:39:22 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Nuclear.Secrets.Set.Two.2of2.The.Terror.Trader.x264.AC3.MVGroup.org.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:39:22 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Nuclear.Secrets.Set.Two.2of2.The.Terror.Trader.x264.AC3.MVGroup.org.mkv
# 09:39:22 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Our.War.10.Years.in.Afghanistan.1of3.Ambushed.PDTV.x264.AAC.MVGroup.Forum.mkv with title: BBC Organize - BBC.Our.War.10.Years.in.Afghanistan.1of3.Ambushed.PDTV.x264.AAC.MVGroup.Forum
# 09:39:22 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:39:22 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Our.War.10.Years.in.Afghanistan.1of3.Ambushed.PDTV.x264.AAC.MVGroup.Forum.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:39:22 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Our.War.10.Years.in.Afghanistan.1of3.Ambushed.PDTV.x264.AAC.MVGroup.Forum.mkv
# 09:39:22 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Our.War.10.Years.in.Afghanistan.2of3.The.Invisible.Enemy.PDTV.x264.AAC.MVGroup.Forum.mkv with title: BBC Organize - BBC.Our.War.10.Years.in.Afghanistan.2of3.The.Invisible.Enemy.PDTV.x264.AAC.MVGroup.Forum
# 09:39:22 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:39:22 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Our.War.10.Years.in.Afghanistan.2of3.The.Invisible.Enemy.PDTV.x264.AAC.MVGroup.Forum.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:39:22 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Our.War.10.Years.in.Afghanistan.2of3.The.Invisible.Enemy.PDTV.x264.AAC.MVGroup.Forum.mkv
# 09:39:22 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Our.War.10.Years.in.Afghanistan.3of3.Caught.in.the.Crossfire.PDTV.x264.AAC.MVGroup.Forum.mkv with title: BBC Organize - BBC.Our.War.10.Years.in.Afghanistan.3of3.Caught.in.the.Crossfire.PDTV.x264.AAC.MVGroup.Forum
# 09:39:22 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:39:22 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Our.War.10.Years.in.Afghanistan.3of3.Caught.in.the.Crossfire.PDTV.x264.AAC.MVGroup.Forum.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:39:22 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Our.War.10.Years.in.Afghanistan.3of3.Caught.in.the.Crossfire.PDTV.x264.AAC.MVGroup.Forum.mkv
# 09:39:22 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Secret.Pakistan.1of2.Double.Cross.PDTV.x264.AAC.MVGroup.org.mkv with title: BBC Organize - BBC.Secret.Pakistan.1of2.Double.Cross.PDTV.x264.AAC.MVGroup.org
# 09:39:23 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:39:23 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Secret.Pakistan.1of2.Double.Cross.PDTV.x264.AAC.MVGroup.org.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:39:23 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Secret.Pakistan.1of2.Double.Cross.PDTV.x264.AAC.MVGroup.org.mkv
# 09:39:23 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Secret.Pakistan.2of2.Backlash.PDTV.x264.AAC.MVGroup.org.mkv with title: BBC Organize - BBC.Secret.Pakistan.2of2.Backlash.PDTV.x264.AAC.MVGroup.org
# 09:39:23 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:39:23 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Secret.Pakistan.2of2.Backlash.PDTV.x264.AAC.MVGroup.org.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:39:23 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Secret.Pakistan.2of2.Backlash.PDTV.x264.AAC.MVGroup.org.mkv
# 09:39:23 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Suez.A.Very.British.Crisis.1of3.Betrayal.DVB.XviD.MP3.www.mvgroup.org.avi with title: BBC Organize - BBC.Suez.A.Very.British.Crisis.1of3.Betrayal.DVB.XviD.MP3.www.mvgroup.org
# 09:39:23 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:39:23 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Suez.A.Very.British.Crisis.1of3.Betrayal.DVB.XviD.MP3.www.mvgroup.org.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:39:23 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Suez.A.Very.British.Crisis.1of3.Betrayal.DVB.XviD.MP3.www.mvgroup.org.avi
# 09:39:23 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Suez.A.Very.British.Crisis.2of3.Conspiracy.DVB.XviD.MP3.www.mvgroup.org.avi with title: BBC Organize - BBC.Suez.A.Very.British.Crisis.2of3.Conspiracy.DVB.XviD.MP3.www.mvgroup.org
# 09:39:23 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:39:23 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Suez.A.Very.British.Crisis.2of3.Conspiracy.DVB.XviD.MP3.www.mvgroup.org.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:39:23 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Suez.A.Very.British.Crisis.2of3.Conspiracy.DVB.XviD.MP3.www.mvgroup.org.avi
# 09:39:23 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Suez.A.Very.British.Crisis.3of3.War.DVB.XviD.MP3.www.mvgroup.org.avi with title: BBC Organize - BBC.Suez.A.Very.British.Crisis.3of3.War.DVB.XviD.MP3.www.mvgroup.org
# 09:39:23 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:39:23 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Suez.A.Very.British.Crisis.3of3.War.DVB.XviD.MP3.www.mvgroup.org.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:39:23 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Suez.A.Very.British.Crisis.3of3.War.DVB.XviD.MP3.www.mvgroup.org.avi
# 09:39:23 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Birth.of.Israel.2008.DVBC.XviD.MP3.MVGroup.org.avi with title: BBC Organize - BBC.The.Birth.of.Israel.2008.DVBC.XviD.MP3.MVGroup.org
# 09:39:23 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:39:23 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Birth.of.Israel.2008.DVBC.XviD.MP3.MVGroup.org.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:39:23 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Birth.of.Israel.2008.DVBC.XviD.MP3.MVGroup.org.avi
# 09:39:23 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Conspiracy.Files.The.Trump.Dossier.720p.HDTV.x264.AAC.MVGroup.org.mkv with title: BBC Organize - BBC.The.Conspiracy.Files.The.Trump.Dossier.720p.HDTV.x264.AAC.MVGroup.org
# 09:39:23 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:39:23 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Conspiracy.Files.The.Trump.Dossier.720p.HDTV.x264.AAC.MVGroup.org.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:39:23 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Conspiracy.Files.The.Trump.Dossier.720p.HDTV.x264.AAC.MVGroup.org.mkv
# 09:39:23 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Genius.of.Turner.720p.HDTV.x264.AAC.MVGroup.org.mkv with title: BBC Organize - BBC.The.Genius.of.Turner.720p.HDTV.x264.AAC.MVGroup.org
# 09:39:24 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:39:24 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Genius.of.Turner.720p.HDTV.x264.AAC.MVGroup.org.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:39:24 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Genius.of.Turner.720p.HDTV.x264.AAC.MVGroup.org.mkv
# 09:39:24 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Iraq.War.1of3.Regime.Change.576p.HDTV.x264.AAC.MVGroup.Forum.mkv with title: BBC Organize - BBC.The.Iraq.War.1of3.Regime.Change.576p.HDTV.x264.AAC.MVGroup.Forum
# 09:39:24 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:39:24 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Iraq.War.1of3.Regime.Change.576p.HDTV.x264.AAC.MVGroup.Forum.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:39:24 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Iraq.War.1of3.Regime.Change.576p.HDTV.x264.AAC.MVGroup.Forum.mkv
# 09:39:24 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Iraq.War.2of3.After.the.Fall.576p.HDTV.x264.AAC.MVGroup.Forum.mkv with title: BBC Organize - BBC.The.Iraq.War.2of3.After.the.Fall.576p.HDTV.x264.AAC.MVGroup.Forum
# 09:39:24 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:39:24 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Iraq.War.2of3.After.the.Fall.576p.HDTV.x264.AAC.MVGroup.Forum.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:39:24 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Iraq.War.2of3.After.the.Fall.576p.HDTV.x264.AAC.MVGroup.Forum.mkv
# 09:39:24 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Iraq.War.3of3.Its.Hell.Mr.President.576p.HDTV.x264.AAC.MVGroup.Forum.mkv with title: BBC Organize - BBC.The.Iraq.War.3of3.Its.Hell.Mr.President.576p.HDTV.x264.AAC.MVGroup.Forum
# 09:39:24 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:39:24 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Iraq.War.3of3.Its.Hell.Mr.President.576p.HDTV.x264.AAC.MVGroup.Forum.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:39:24 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Iraq.War.3of3.Its.Hell.Mr.President.576p.HDTV.x264.AAC.MVGroup.Forum.mkv
# 09:39:24 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Other.Side.of.Suez.DVB.XviD.MP3.www.mvgroup.org.avi with title: BBC Organize - BBC.The.Other.Side.of.Suez.DVB.XviD.MP3.www.mvgroup.org
# 09:39:24 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:39:24 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Other.Side.of.Suez.DVB.XviD.MP3.www.mvgroup.org.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:39:24 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Other.Side.of.Suez.DVB.XviD.MP3.www.mvgroup.org.avi
# 09:39:24 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Refugee.Camp.Our.Desert.Home.1of2.720p.HDTV.x264.AAC.MVGroup.org.mkv with title: BBC Organize - BBC.The.Refugee.Camp.Our.Desert.Home.1of2.720p.HDTV.x264.AAC.MVGroup.org
# 09:39:24 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:39:24 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Refugee.Camp.Our.Desert.Home.1of2.720p.HDTV.x264.AAC.MVGroup.org.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:39:24 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Refugee.Camp.Our.Desert.Home.1of2.720p.HDTV.x264.AAC.MVGroup.org.mkv
# 09:39:24 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Refugee.Camp.Our.Desert.Home.2of2.720p.HDTV.x264.AAC.MVGroup.org.mkv with title: BBC Organize - BBC.The.Refugee.Camp.Our.Desert.Home.2of2.720p.HDTV.x264.AAC.MVGroup.org
# 09:39:24 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:39:24 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Refugee.Camp.Our.Desert.Home.2of2.720p.HDTV.x264.AAC.MVGroup.org.mkv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:39:24 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.The.Refugee.Camp.Our.Desert.Home.2of2.720p.HDTV.x264.AAC.MVGroup.org.mkv
# 09:39:24 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Trumps.Unlikely.Superfans.720p.x264.AAC.MVGroup.org.mp4 with title: BBC Organize - BBC.Trumps.Unlikely.Superfans.720p.x264.AAC.MVGroup.org
# 09:39:24 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:39:24 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Trumps.Unlikely.Superfans.720p.x264.AAC.MVGroup.org.mp4 to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:39:24 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Trumps.Unlikely.Superfans.720p.x264.AAC.MVGroup.org.mp4
# 09:39:24 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.United.States.of.Hate.Muslims.Under.Attack.720p.x264.AAC.MVGroup.org.mp4 with title: BBC Organize - BBC.United.States.of.Hate.Muslims.Under.Attack.720p.x264.AAC.MVGroup.org
# 09:39:25 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:39:25 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.United.States.of.Hate.Muslims.Under.Attack.720p.x264.AAC.MVGroup.org.mp4 to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:39:25 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.United.States.of.Hate.Muslims.Under.Attack.720p.x264.AAC.MVGroup.org.mp4
# 09:39:25 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Why.Democracy.Bloody.Cartoons.DVB.Xvid.MP3.www.mvgroup.org.avi with title: BBC Organize - BBC.Why.Democracy.Bloody.Cartoons.DVB.Xvid.MP3.www.mvgroup.org
# 09:39:25 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:39:25 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Why.Democracy.Bloody.Cartoons.DVB.Xvid.MP3.www.mvgroup.org.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:39:25 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Why.Democracy.Bloody.Cartoons.DVB.Xvid.MP3.www.mvgroup.org.avi
# 09:39:25 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Why.Democracy.Egypt.We.Are.Watching.You.DVB.Xvid.MP3.www.mvgroup.org.avi with title: BBC Organize - BBC.Why.Democracy.Egypt.We.Are.Watching.You.DVB.Xvid.MP3.www.mvgroup.org
# 09:39:25 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:39:25 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Why.Democracy.Egypt.We.Are.Watching.You.DVB.Xvid.MP3.www.mvgroup.org.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:39:25 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Why.Democracy.Egypt.We.Are.Watching.You.DVB.Xvid.MP3.www.mvgroup.org.avi
# 09:39:25 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Why.Democracy.The.Ministry.of.Truth.2007.DVBC.XviD.MP3.www.mvgroup.org.avi with title: BBC Organize - BBC.Why.Democracy.The.Ministry.of.Truth.2007.DVBC.XviD.MP3.www.mvgroup.org
# 09:39:25 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:39:25 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Why.Democracy.The.Ministry.of.Truth.2007.DVBC.XviD.MP3.www.mvgroup.org.avi to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:39:25 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\BBC.Why.Democracy.The.Ministry.of.Truth.2007.DVBC.XviD.MP3.www.mvgroup.org.avi
# 09:39:25 - Uploading: //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\The Ape That Took Over The World (BBC).flv with title: BBC Organize - The Ape That Took Over The World (BBC)
# 09:39:25 - Encountered 403 Forbidden with reason "quotaExceeded"
# 09:39:25 - Error uploading //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\The Ape That Took Over The World (BBC).flv to YouTube: <HttpError 403 when requesting None returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# 09:39:25 - Upload failed for //fileserver2/Head Office Server/Projects Control (PC)/10 Backup/05 Software/Docs/Docs Organize/BBC Organize\The Ape That Took Over The World (BBC).flv
