# %%
import os
import subprocess
import time
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials

# Google API configuration
SCOPES = ["https://www.googleapis.com/auth/youtube.upload"]
CLIENT_SECRETS_FILE = "client_secret.json"
TOKEN_FILE = "token.json"

def get_authenticated_service():
    """
    Authenticate with YouTube API and return a service object.
    Reuses saved credentials to avoid repeated logins.
    """
    creds = None

    if os.path.exists(TOKEN_FILE):
        creds = Credentials.from_authorized_user_file(TOKEN_FILE)

    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(CLIENT_SECRETS_FILE, SCOPES)
            creds = flow.run_local_server(port=0)

        with open(TOKEN_FILE, "w") as token_file:
            token_file.write(creds.to_json())

    return build("youtube", "v3", credentials=creds)

def get_video_duration(video_path):
    """
    Returns the duration of a video in seconds.
    """
    try:
        result = subprocess.run(
            ["ffprobe", "-v", "error", "-show_entries", "format=duration",
             "-of", "default=noprint_wrappers=1:nokey=1", video_path],
            stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True
        )
        return float(result.stdout.strip())
    except Exception as e:
        print(f"⚠️ Warning: Could not read duration for {video_path}. Error: {e}")
        return None

def try_merge_videos(folder_path, video_files, expected_duration, merge_attempt):
    """
    Attempts to merge videos directly without conversion. If the merged duration 
    is incorrect, fall back to converting and merging again.
    """
    file_list_path = os.path.join(folder_path, "file_list.txt")
    merged_video_path = os.path.join(folder_path, "merged_video.mp4")

    with open(file_list_path, "w", encoding="utf-8") as f:
        for video_file in video_files:
            f.write(f"file '{video_file}'\n")

    print(f"🔗 Attempt {merge_attempt}: Merging videos...")
    subprocess.run(
        ["ffmpeg", "-f", "concat", "-safe", "0", "-i", file_list_path, "-c", "copy", merged_video_path],
        stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True
    )

    merged_duration = get_video_duration(merged_video_path)
    if merged_duration and abs(merged_duration - expected_duration) <= 5:
        print(f"✅ Merge successful! Duration: {merged_duration:.2f} sec")
        return merged_video_path
    else:
        print(f"❌ Merge failed. Merged duration: {merged_duration:.2f} sec, Expected: {expected_duration:.2f} sec")
        os.remove(merged_video_path)  # Delete incorrect merge
        return None  # Signal to perform full conversion

def merge_videos_and_create_timestamps(folder_path):
    """
    Converts MP4 videos to a uniform format if needed, merges them, and creates timestamps.
    Returns the merged video path, description content (timestamps), and total duration.
    """
    print(f"📂 Checking folder: {folder_path}")

    if not os.path.exists(folder_path):
        print(f"❌ Error: The folder path '{folder_path}' does not exist.")
        return None, None, None

    video_files = []
    timestamps = []
    total_duration = 0

    for filename in sorted(os.listdir(folder_path)):
        if filename.lower().endswith(".mp4"):
            filepath = os.path.join(folder_path, filename)
            video_files.append(filepath)
            duration = get_video_duration(filepath)
            if duration:
                timestamps.append((filename, total_duration))
                total_duration += duration

    if not video_files:
        print("❌ No MP4 files found.")
        return None, None, None

    # ✅ Try merging original videos first
    merged_video_path = try_merge_videos(folder_path, video_files, total_duration, merge_attempt=1)
    if merged_video_path:
        return merged_video_path, "\n".join(f"{f} - {t}" for f, t in timestamps), total_duration

    # ✅ Convert videos and merge again if direct merge failed
    converted_folder = os.path.join(folder_path, "converted_videos")
    os.makedirs(converted_folder, exist_ok=True)
    converted_files = []

    print("🔄 Converting videos due to merge failure...")
    for idx, video in enumerate(video_files):
        converted_video = os.path.join(converted_folder, f"converted_{idx}.mp4")
        print(f"🔄 Converting: {os.path.basename(video)} ...")
        subprocess.run(
            ["ffmpeg", "-i", video, "-c:v", "libx264", "-c:a", "aac", "-strict", "experimental", converted_video],
            stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True
        )
        converted_files.append(converted_video)
        print(f"✅ Finished converting: {os.path.basename(video)}")

    # ✅ Merge converted videos
    return try_merge_videos(folder_path, converted_files, total_duration, merge_attempt=2), "\n".join(f"{f} - {t}" for f, t in timestamps), total_duration

def upload_to_youtube(video_path, title, description, folder_path):
    """
    Uploads a video to YouTube and saves the video URL in 'youtube link.txt'.
    """
    print(f"📤 Uploading: {title}...")
    youtube = get_authenticated_service()
    request = youtube.videos().insert(
        part="snippet,status",
        body={
            "snippet": {
                "title": title,
                "description": description,
                "tags": ["training", "tutorial", "video"],
                "categoryId": "27"
            },
            "status": {
                "privacyStatus": "unlisted"
            }
        },
        media_body=MediaFileUpload(video_path, chunksize=-1, resumable=True)
    )

    response = None
    while response is None:
        try:
            status, response = request.next_chunk()
            if status:
                print(f"Uploaded {int(status.progress() * 100)}%")
        except Exception as e:
            raise Exception(f"Error during upload: {e}")

    video_url = f"https://www.youtube.com/watch?v={response['id']}"
    with open(os.path.join(folder_path, "youtube link.txt"), "w") as f:
        f.write(video_url + "\n")

    print(f"✅ Upload complete! Video URL: {video_url}")
    return video_url

def cleanup_files(folder_path, total_duration):
    """
    Deletes original and converted videos if the merged video duration is within ±5 seconds.
    """
    merged_video_path = os.path.join(folder_path, "merged_video.mp4")
    merged_duration = get_video_duration(merged_video_path)

    if merged_duration and abs(merged_duration - total_duration) <= 5:
        print("🧹 Cleanup: Deleting original and converted videos...")

        for filename in os.listdir(folder_path):
            if filename.lower().endswith(".mp4"):
                os.remove(os.path.join(folder_path, filename))

        converted_folder = os.path.join(folder_path, "converted_videos")
        if os.path.exists(converted_folder):
            for filename in os.listdir(converted_folder):
                os.remove(os.path.join(converted_folder, filename))
            os.rmdir(converted_folder)

        print("✅ Cleanup completed!")
    else:
        print("⚠️ Cleanup skipped: Merged video duration mismatch!")

if __name__ == "__main__":
    parent_folder = input("📂 Enter the parent folder containing all video subfolders: ").strip()

    for subfolder in sorted(os.listdir(parent_folder)):
        subfolder_path = os.path.join(parent_folder, subfolder)

        if os.path.isdir(subfolder_path) and any(f.lower().endswith('.mp4') for f in os.listdir(subfolder_path)):
            print(f"🚀 Processing folder: {subfolder_path}")

            merged_video_path, description, total_duration = merge_videos_and_create_timestamps(subfolder_path)

            if merged_video_path and description:
                folder_parts = os.path.normpath(subfolder_path).split(os.sep)
                title = " - ".join(folder_parts[-4:]) if len(folder_parts) >= 4 else "Merged Video"

                upload_to_youtube(merged_video_path, title, description, subfolder_path)

                cleanup_files(subfolder_path, total_duration)

    print("✅ All subfolders processed!")
# Out:
# 🚀 Processing folder: H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Photoshop\Lynda\Photoshop CC 2018 One-on-One - Advanced
# 📂 Checking folder: H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Photoshop\Lynda\Photoshop CC 2018 One-on-One - Advanced
# 🔗 Attempt 1: Merging videos...
# ❌ Merge failed. Merged duration: 29631.43 sec, Expected: 64609.86 sec
# 🔄 Converting videos due to merge failure...
# 🔄 Converting: 001 Welcome to One-on-One.mp4 ...
# ✅ Finished converting: 001 Welcome to One-on-One.mp4
# 🔄 Converting: 002 Previously on Photoshop CC 2018 One-on-One.mp4 ...
# ✅ Finished converting: 002 Previously on Photoshop CC 2018 One-on-One.mp4
# 🔄 Converting: 003 Color range, focus area, and more.mp4 ...
# ✅ Finished converting: 003 Color range, focus area, and more.mp4
# 🔄 Converting: 004 Introducing the Color Range command.mp4 ...
# ✅ Finished converting: 004 Introducing the Color Range command.mp4
# 🔄 Converting: 005 Customizing a Color Range selection.mp4 ...
# ✅ Finished converting: 005 Customizing a Color Range selection.mp4
# 🔄 Converting: 006 Localized Color Clusters and Detect Faces.mp4 ...
# ✅ Finished converting: 006 Localized Color Clusters and Detect Faces.mp4
# 🔄 Converting: 007 Selecting a real-world photographic object.mp4 ...
# ✅ Finished converting: 007 Selecting a real-world photographic object.mp4
# 🔄 Converting: 008 Cleaning up with the Wand and Brush tools.mp4 ...
# ✅ Finished converting: 008 Cleaning up with the Wand and Brush tools.mp4
# 🔄 Converting: 009 Refining your mask to absolute perfection.mp4 ...
# ✅ Finished converting: 009 Refining your mask to absolute perfection.mp4
# 🔄 Converting: 010 Shading the airplane to match the sky.mp4 ...
# ✅ Finished converting: 010 Shading the airplane to match the sky.mp4
# 🔄 Converting: 011 Infusing the airplane with sky colors.mp4 ...
# ✅ Finished converting: 011 Infusing the airplane with sky colors.mp4
# 🔄 Converting: 012 Adding a custom Motion Blur effect.mp4 ...
# ✅ Finished converting: 012 Adding a custom Motion Blur effect.mp4
# 🔄 Converting: 013 Adding a rocket plume.mp4 ...
# ✅ Finished converting: 013 Adding a rocket plume.mp4
# 🔄 Converting: 014 Introducing the Focus Area command.mp4 ...
# ✅ Finished converting: 014 Introducing the Focus Area command.mp4
# 🔄 Converting: 015 Using the Focus Area tool.mp4 ...
# ✅ Finished converting: 015 Using the Focus Area tool.mp4
# 🔄 Converting: 016 Cleaning up a jagged Focus Area mask.mp4 ...
# ✅ Finished converting: 016 Cleaning up a jagged Focus Area mask.mp4
# 🔄 Converting: 017 Finessing hair and other details.mp4 ...
# ✅ Finished converting: 017 Finessing hair and other details.mp4
# 🔄 Converting: 018 Using the Select _ Subject command.mp4 ...
# ✅ Finished converting: 018 Using the Select _ Subject command.mp4
# 🔄 Converting: 019 Compositing like a pro.mp4 ...
# ✅ Finished converting: 019 Compositing like a pro.mp4
# 🔄 Converting: 020 Static selection vs. dynamic layer mask.mp4 ...
# ✅ Finished converting: 020 Static selection vs. dynamic layer mask.mp4
# 🔄 Converting: 021 Perfecting mask edges with the Smudge tool.mp4 ...
# ✅ Finished converting: 021 Perfecting mask edges with the Smudge tool.mp4
# 🔄 Converting: 022 White reveals, black conceals.mp4 ...
# ✅ Finished converting: 022 White reveals, black conceals.mp4
# 🔄 Converting: 023 Real-world layer masking.mp4 ...
# ✅ Finished converting: 023 Real-world layer masking.mp4
# 🔄 Converting: 024 Combining multiple passes of Color Range.mp4 ...
# ✅ Finished converting: 024 Combining multiple passes of Color Range.mp4
# 🔄 Converting: 025 Painting away gaps in a layer mask.mp4 ...
# ✅ Finished converting: 025 Painting away gaps in a layer mask.mp4
# 🔄 Converting: 026 Making your mask the best it can be.mp4 ...
# ✅ Finished converting: 026 Making your mask the best it can be.mp4
# 🔄 Converting: 027 Feather and Density = even better hair.mp4 ...
# ✅ Finished converting: 027 Feather and Density = even better hair.mp4
# 🔄 Converting: 028 Introducing the Select and Mask command.mp4 ...
# ✅ Finished converting: 028 Introducing the Select and Mask command.mp4
# 🔄 Converting: 029 The Global Refinements settings.mp4 ...
# ✅ Finished converting: 029 The Global Refinements settings.mp4
# 🔄 Converting: 030 Edge Detection and Smart Radius.mp4 ...
# ✅ Finished converting: 030 Edge Detection and Smart Radius.mp4
# 🔄 Converting: 031 Refine Edge Brush and Decontaminated Colors.mp4 ...
# ✅ Finished converting: 031 Refine Edge Brush and Decontaminated Colors.mp4
# 🔄 Converting: 032 Turning day into night with Camera Raw.mp4 ...
# ✅ Finished converting: 032 Turning day into night with Camera Raw.mp4
# 🔄 Converting: 033 Blending hair into a nighttime sky.mp4 ...
# ✅ Finished converting: 033 Blending hair into a nighttime sky.mp4
# 🔄 Converting: 034 Bringing back good old Refine Mask.mp4 ...
# ✅ Finished converting: 034 Bringing back good old Refine Mask.mp4
# 🔄 Converting: 035 Meet the transformations.mp4 ...
# ✅ Finished converting: 035 Meet the transformations.mp4
# 🔄 Converting: 036 Introducing the Free Transform command.mp4 ...
# ✅ Finished converting: 036 Introducing the Free Transform command.mp4
# 🔄 Converting: 037 Skewing and distorting a layer.mp4 ...
# ✅ Finished converting: 037 Skewing and distorting a layer.mp4
# 🔄 Converting: 038 Bending and otherwise warping a layer.mp4 ...
# ✅ Finished converting: 038 Bending and otherwise warping a layer.mp4
# 🔄 Converting: 039 Creating a cheerful bat-faced moon.mp4 ...
# ✅ Finished converting: 039 Creating a cheerful bat-faced moon.mp4
# 🔄 Converting: 040 Real-world scaling and compositing.mp4 ...
# ✅ Finished converting: 040 Real-world scaling and compositing.mp4
# 🔄 Converting: 041 Quick-and-dirty layer masking.mp4 ...
# ✅ Finished converting: 041 Quick-and-dirty layer masking.mp4
# 🔄 Converting: 042 Transform and duplicate in one operation.mp4 ...
# ✅ Finished converting: 042 Transform and duplicate in one operation.mp4
# 🔄 Converting: 043 Removing the color from a layer.mp4 ...
# ✅ Finished converting: 043 Removing the color from a layer.mp4
# 🔄 Converting: 044 Transforming a selection outline.mp4 ...
# ✅ Finished converting: 044 Transforming a selection outline.mp4
# 🔄 Converting: 045 Repeating one or more transformations.mp4 ...
# ✅ Finished converting: 045 Repeating one or more transformations.mp4
# 🔄 Converting: 046 Transforming and warping text.mp4 ...
# ✅ Finished converting: 046 Transforming and warping text.mp4
# 🔄 Converting: 047 Filling text with a warped gradient.mp4 ...
# ✅ Finished converting: 047 Filling text with a warped gradient.mp4
# 🔄 Converting: 048 Indestructible envelopes.mp4 ...
# ✅ Finished converting: 048 Indestructible envelopes.mp4
# 🔄 Converting: 049 Three ways to create a smart object.mp4 ...
# ✅ Finished converting: 049 Three ways to create a smart object.mp4
# 🔄 Converting: 050 Applying nondestructive transformations.mp4 ...
# ✅ Finished converting: 050 Applying nondestructive transformations.mp4
# 🔄 Converting: 051 Applying nondestructive distortions.mp4 ...
# ✅ Finished converting: 051 Applying nondestructive distortions.mp4
# 🔄 Converting: 052 Masking smart objects.mp4 ...
# ✅ Finished converting: 052 Masking smart objects.mp4
# 🔄 Converting: 053 Editing the contents of a smart object.mp4 ...
# ✅ Finished converting: 053 Editing the contents of a smart object.mp4
# 🔄 Converting: 054 Applying editable smart adjustments.mp4 ...
# ✅ Finished converting: 054 Applying editable smart adjustments.mp4
# 🔄 Converting: 055 Applying and blending smart filters.mp4 ...
# ✅ Finished converting: 055 Applying and blending smart filters.mp4
# 🔄 Converting: 056 Editing a filter mask.mp4 ...
# ✅ Finished converting: 056 Editing a filter mask.mp4
# 🔄 Converting: 057 Applying Camera Raw as a smart filter.mp4 ...
# ✅ Finished converting: 057 Applying Camera Raw as a smart filter.mp4
# 🔄 Converting: 058 Opening a Camera Raw smart object.mp4 ...
# ✅ Finished converting: 058 Opening a Camera Raw smart object.mp4
# 🔄 Converting: 059 Two ways to duplicate a smart object.mp4 ...
# ✅ Finished converting: 059 Two ways to duplicate a smart object.mp4
# 🔄 Converting: 060 Protecting editable text.mp4 ...
# ✅ Finished converting: 060 Protecting editable text.mp4
# 🔄 Converting: 061 Using nested smart objects.mp4 ...
# ✅ Finished converting: 061 Using nested smart objects.mp4
# 🔄 Converting: 062 Editing text inside a nested smart object.mp4 ...
# ✅ Finished converting: 062 Editing text inside a nested smart object.mp4
# 🔄 Converting: 063 Pasting smart objects from Illustrator.mp4 ...
# ✅ Finished converting: 063 Pasting smart objects from Illustrator.mp4
# 🔄 Converting: 064 Applying Photoshop effects to Illustrator art.mp4 ...
# ✅ Finished converting: 064 Applying Photoshop effects to Illustrator art.mp4
# 🔄 Converting: 065 Troubleshooting Illustrator smart objects.mp4 ...
# ✅ Finished converting: 065 Troubleshooting Illustrator smart objects.mp4
# 🔄 Converting: 066 Restoring missing details.mp4 ...
# ✅ Finished converting: 066 Restoring missing details.mp4
# 🔄 Converting: 067 ўcrUncroppingўot a photo by expanding the canvas.mp4 ...
# ✅ Finished converting: 067 ўcrUncroppingўot a photo by expanding the canvas.mp4
# 🔄 Converting: 068 Using the Content-Aware Scale command.mp4 ...
# ✅ Finished converting: 068 Using the Content-Aware Scale command.mp4
# 🔄 Converting: 069 Restoring a missing photographic element.mp4 ...
# ✅ Finished converting: 069 Restoring a missing photographic element.mp4
# 🔄 Converting: 070 Fitting an image to a custom print size.mp4 ...
# ✅ Finished converting: 070 Fitting an image to a custom print size.mp4
# 🔄 Converting: 071 Applying an image stack mode.mp4 ...
# ✅ Finished converting: 071 Applying an image stack mode.mp4
# 🔄 Converting: 072 Combining a stack mode with spot healing.mp4 ...
# ✅ Finished converting: 072 Combining a stack mode with spot healing.mp4
# 🔄 Converting: 073 Erasing people with the Median mode.mp4 ...
# ✅ Finished converting: 073 Erasing people with the Median mode.mp4
# 🔄 Converting: 074 Blurring away registration problems.mp4 ...
# ✅ Finished converting: 074 Blurring away registration problems.mp4
# 🔄 Converting: 075 Auto-blending multiple depths of field.mp4 ...
# ✅ Finished converting: 075 Auto-blending multiple depths of field.mp4
# 🔄 Converting: 076 Auto-blending with more flexibility.mp4 ...
# ✅ Finished converting: 076 Auto-blending with more flexibility.mp4
# 🔄 Converting: 077 Perfecting the human form.mp4 ...
# ✅ Finished converting: 077 Perfecting the human form.mp4
# 🔄 Converting: 078 Introducing the Liquify filter.mp4 ...
# ✅ Finished converting: 078 Introducing the Liquify filter.mp4
# 🔄 Converting: 079 Using the Pucker and Bloat tools.mp4 ...
# ✅ Finished converting: 079 Using the Pucker and Bloat tools.mp4
# 🔄 Converting: 080 The Twirl, Push, and Smooth tools.mp4 ...
# ✅ Finished converting: 080 The Twirl, Push, and Smooth tools.mp4
# 🔄 Converting: 081 Using Liquify's masking tools.mp4 ...
# ✅ Finished converting: 081 Using Liquify's masking tools.mp4
# 🔄 Converting: 082 Face-Aware Liquify.mp4 ...
# ✅ Finished converting: 082 Face-Aware Liquify.mp4
# 🔄 Converting: 083 Special face-recognition scenarios.mp4 ...
# ✅ Finished converting: 083 Special face-recognition scenarios.mp4
# 🔄 Converting: 084 Making direct edits with the Face tool.mp4 ...
# ✅ Finished converting: 084 Making direct edits with the Face tool.mp4
# 🔄 Converting: 085 Resetting any and all facial features.mp4 ...
# ✅ Finished converting: 085 Resetting any and all facial features.mp4
# 🔄 Converting: 086 The Photoshop alternative to pixels.mp4 ...
# ✅ Finished converting: 086 The Photoshop alternative to pixels.mp4
# 🔄 Converting: 087 How vector-based shape layers work.mp4 ...
# ✅ Finished converting: 087 How vector-based shape layers work.mp4
# 🔄 Converting: 088 Drawing a rectangle with round corners.mp4 ...
# ✅ Finished converting: 088 Drawing a rectangle with round corners.mp4
# 🔄 Converting: 089 Making your path outlines easier to see.mp4 ...
# ✅ Finished converting: 089 Making your path outlines easier to see.mp4
# 🔄 Converting: 090 Creating a dashed or dotted border.mp4 ...
# ✅ Finished converting: 090 Creating a dashed or dotted border.mp4
# 🔄 Converting: 091 Drawing and aligning custom shapes.mp4 ...
# ✅ Finished converting: 091 Drawing and aligning custom shapes.mp4
# 🔄 Converting: 092 Creating your own custom shape.mp4 ...
# ✅ Finished converting: 092 Creating your own custom shape.mp4
# 🔄 Converting: 093 Designing a custom shape in Illustrator.mp4 ...
# ✅ Finished converting: 093 Designing a custom shape in Illustrator.mp4
# 🔄 Converting: 094 Selecting, modifying, and combining shapes.mp4 ...
# ✅ Finished converting: 094 Selecting, modifying, and combining shapes.mp4
# 🔄 Converting: 095 Duplicating and centering shapes.mp4 ...
# ✅ Finished converting: 095 Duplicating and centering shapes.mp4
# 🔄 Converting: 096 Centering a star inside a circle.mp4 ...
# ✅ Finished converting: 096 Centering a star inside a circle.mp4
# 🔄 Converting: 097 Beveling your shapes with Pillow Emboss.mp4 ...
# ✅ Finished converting: 097 Beveling your shapes with Pillow Emboss.mp4
# 🔄 Converting: 098 Combining shapes into a smart object.mp4 ...
# ✅ Finished converting: 098 Combining shapes into a smart object.mp4
# 🔄 Converting: 099 Applying lighting and photorealism.mp4 ...
# ✅ Finished converting: 099 Applying lighting and photorealism.mp4
# 🔄 Converting: 100 Converting text to a shape layer.mp4 ...
# ✅ Finished converting: 100 Converting text to a shape layer.mp4
# 🔄 Converting: 101 Editing the shape of a character of type.mp4 ...
# ✅ Finished converting: 101 Editing the shape of a character of type.mp4
# 🔄 Converting: 102 Blending layers like a pro.mp4 ...
# ✅ Finished converting: 102 Blending layers like a pro.mp4
# 🔄 Converting: 103 Normal and Dissolve.mp4 ...
# ✅ Finished converting: 103 Normal and Dissolve.mp4
# 🔄 Converting: 104 Using the Dissolve mode.mp4 ...
# ✅ Finished converting: 104 Using the Dissolve mode.mp4
# 🔄 Converting: 105 Multiply and the other darken modes.mp4 ...
# ✅ Finished converting: 105 Multiply and the other darken modes.mp4
# 🔄 Converting: 106 Using the Multiply mode.mp4 ...
# ✅ Finished converting: 106 Using the Multiply mode.mp4
# 🔄 Converting: 107 Screen and the other lighten modes.mp4 ...
# ✅ Finished converting: 107 Screen and the other lighten modes.mp4
# 🔄 Converting: 108 Using the Screen mode.mp4 ...
# ✅ Finished converting: 108 Using the Screen mode.mp4
# 🔄 Converting: 109 Using the Dodge and Burn modes.mp4 ...
# ✅ Finished converting: 109 Using the Dodge and Burn modes.mp4
# 🔄 Converting: 110 Overlay and the contrast modes.mp4 ...
# ✅ Finished converting: 110 Overlay and the contrast modes.mp4
# 🔄 Converting: 111 Using the Overlay and Soft Light modes.mp4 ...
# ✅ Finished converting: 111 Using the Overlay and Soft Light modes.mp4
# 🔄 Converting: 112 Difference, Exclusion, Subtract, and Divide.mp4 ...
# ✅ Finished converting: 112 Difference, Exclusion, Subtract, and Divide.mp4
# 🔄 Converting: 113 Capturing the differences between images.mp4 ...
# ✅ Finished converting: 113 Capturing the differences between images.mp4
# 🔄 Converting: 114 Hue, Saturation, Color, and Luminosity.mp4 ...
# ✅ Finished converting: 114 Hue, Saturation, Color, and Luminosity.mp4
# 🔄 Converting: 115 Blend mode keyboard shortcuts.mp4 ...
# ✅ Finished converting: 115 Blend mode keyboard shortcuts.mp4
# 🔄 Converting: 116 The Brush tool blend modes.mp4 ...
# ✅ Finished converting: 116 The Brush tool blend modes.mp4
# 🔄 Converting: 117 The remarkable Fill Opacity Eight.mp4 ...
# ✅ Finished converting: 117 The remarkable Fill Opacity Eight.mp4
# 🔄 Converting: 118 Blend If - This layer and underlying layer.mp4 ...
# ✅ Finished converting: 118 Blend If - This layer and underlying layer.mp4
# 🔄 Converting: 119 Depth, contour, and texture.mp4 ...
# ✅ Finished converting: 119 Depth, contour, and texture.mp4
# 🔄 Converting: 120 Applying a Drop Shadow.mp4 ...
# ✅ Finished converting: 120 Applying a Drop Shadow.mp4
# 🔄 Converting: 121 Working with Fill Opacity.mp4 ...
# ✅ Finished converting: 121 Working with Fill Opacity.mp4
# 🔄 Converting: 122 Applying an Inner Shadow.mp4 ...
# ✅ Finished converting: 122 Applying an Inner Shadow.mp4
# 🔄 Converting: 123 Working with Global Light.mp4 ...
# ✅ Finished converting: 123 Working with Global Light.mp4
# 🔄 Converting: 124 Creating blurry, spray paint-style type.mp4 ...
# ✅ Finished converting: 124 Creating blurry, spray paint-style type.mp4
# 🔄 Converting: 125 Creating your own custom Contour.mp4 ...
# ✅ Finished converting: 125 Creating your own custom Contour.mp4
# 🔄 Converting: 126 Introducing Bevel &amp; Emboss.mp4 ...
# ✅ Finished converting: 126 Introducing Bevel &amp; Emboss.mp4
# 🔄 Converting: 127 Combining multiple layer effects.mp4 ...
# ✅ Finished converting: 127 Combining multiple layer effects.mp4
# 🔄 Converting: 128 Copying effects between layers and groups.mp4 ...
# ✅ Finished converting: 128 Copying effects between layers and groups.mp4
# 🔄 Converting: 129 Assigning multiple strokes to a single layer.mp4 ...
# ✅ Finished converting: 129 Assigning multiple strokes to a single layer.mp4
# 🔄 Converting: 130 Combining multiple drop shadows.mp4 ...
# ✅ Finished converting: 130 Combining multiple drop shadows.mp4
# 🔄 Converting: 131 Mastering the histogram.mp4 ...
# ✅ Finished converting: 131 Mastering the histogram.mp4
# 🔄 Converting: 132 Correcting an image automatically.mp4 ...
# ✅ Finished converting: 132 Correcting an image automatically.mp4
# 🔄 Converting: 133 Customizing a Levels adjustment.mp4 ...
# ✅ Finished converting: 133 Customizing a Levels adjustment.mp4
# 🔄 Converting: 134 Previewing clipped pixels.mp4 ...
# ✅ Finished converting: 134 Previewing clipped pixels.mp4
# 🔄 Converting: 135 Understanding the Gamma value.mp4 ...
# ✅ Finished converting: 135 Understanding the Gamma value.mp4
# 🔄 Converting: 136 Making channel-by-channel adjustments.mp4 ...
# ✅ Finished converting: 136 Making channel-by-channel adjustments.mp4
# 🔄 Converting: 137 Cleaning up scanned line art.mp4 ...
# ✅ Finished converting: 137 Cleaning up scanned line art.mp4
# 🔄 Converting: 138 Cleaning up complex mechanicals.mp4 ...
# ✅ Finished converting: 138 Cleaning up complex mechanicals.mp4
# 🔄 Converting: 139 Quicker layer masks with Levels.mp4 ...
# ✅ Finished converting: 139 Quicker layer masks with Levels.mp4
# 🔄 Converting: 140 Introducing the Curves adjustment.mp4 ...
# ✅ Finished converting: 140 Introducing the Curves adjustment.mp4
# 🔄 Converting: 141 The Curves Targeted Adjustment tool.mp4 ...
# ✅ Finished converting: 141 The Curves Targeted Adjustment tool.mp4
# 🔄 Converting: 142 Assigning shortcuts to adjustment layers.mp4 ...
# ✅ Finished converting: 142 Assigning shortcuts to adjustment layers.mp4
# 🔄 Converting: 143 What to do when everything is crooked.mp4 ...
# ✅ Finished converting: 143 What to do when everything is crooked.mp4
# 🔄 Converting: 144 Introducing Lens Correction.mp4 ...
# ✅ Finished converting: 144 Introducing Lens Correction.mp4
# 🔄 Converting: 145 Distortion, aberrations, and vignette.mp4 ...
# ✅ Finished converting: 145 Distortion, aberrations, and vignette.mp4
# 🔄 Converting: 146 Adjusting angle and perspective.mp4 ...
# ✅ Finished converting: 146 Adjusting angle and perspective.mp4
# 🔄 Converting: 147 Using the Perspective Warp command.mp4 ...
# ✅ Finished converting: 147 Using the Perspective Warp command.mp4
# 🔄 Converting: 148 Fine-tuning your perspective adjustment.mp4 ...
# ✅ Finished converting: 148 Fine-tuning your perspective adjustment.mp4
# 🔄 Converting: 149 Evening out color and lighting.mp4 ...
# ✅ Finished converting: 149 Evening out color and lighting.mp4
# 🔄 Converting: 150 The most powerful Photoshop plugin returns.mp4 ...
# ✅ Finished converting: 150 The most powerful Photoshop plugin returns.mp4
# 🔄 Converting: 151 Automatic lens correction and Defringe.mp4 ...
# ✅ Finished converting: 151 Automatic lens correction and Defringe.mp4
# 🔄 Converting: 152 Auto-correcting a JPEG image.mp4 ...
# ✅ Finished converting: 152 Auto-correcting a JPEG image.mp4
# 🔄 Converting: 153 Auto-correcting an undocumented photo.mp4 ...
# ✅ Finished converting: 153 Auto-correcting an undocumented photo.mp4
# 🔄 Converting: 154 Auto-Straighten, Transform, and Upright.mp4 ...
# ✅ Finished converting: 154 Auto-Straighten, Transform, and Upright.mp4
# 🔄 Converting: 155 Using the Tone Curve graphs.mp4 ...
# ✅ Finished converting: 155 Using the Tone Curve graphs.mp4
# 🔄 Converting: 156 Painting with the Adjustment Brush.mp4 ...
# ✅ Finished converting: 156 Painting with the Adjustment Brush.mp4
# 🔄 Converting: 157 Using the Graduated Filter tool.mp4 ...
# ✅ Finished converting: 157 Using the Graduated Filter tool.mp4
# 🔄 Converting: 158 Using the Radial Filter tool.mp4 ...
# ✅ Finished converting: 158 Using the Radial Filter tool.mp4
# 🔄 Converting: 159 Dehaze and Post-Crop Vignetting.mp4 ...
# ✅ Finished converting: 159 Dehaze and Post-Crop Vignetting.mp4
# 🔄 Converting: 160 Shoot in color, convert to black and white.mp4 ...
# ✅ Finished converting: 160 Shoot in color, convert to black and white.mp4
# 🔄 Converting: 161 Three ways to convert to grayscale.mp4 ...
# ✅ Finished converting: 161 Three ways to convert to grayscale.mp4
# 🔄 Converting: 162 Introducing the Channel Mixer.mp4 ...
# ✅ Finished converting: 162 Introducing the Channel Mixer.mp4
# 🔄 Converting: 163 Mixing a custom black-and-white image.mp4 ...
# ✅ Finished converting: 163 Mixing a custom black-and-white image.mp4
# 🔄 Converting: 164 Creating an infrared-snow effect.mp4 ...
# ✅ Finished converting: 164 Creating an infrared-snow effect.mp4
# 🔄 Converting: 165 Introducing the Black &amp; White adjustment.mp4 ...
# ✅ Finished converting: 165 Introducing the Black &amp; White adjustment.mp4
# 🔄 Converting: 166 Customizing a Black &amp; White adjustment.mp4 ...
# ✅ Finished converting: 166 Customizing a Black &amp; White adjustment.mp4
# 🔄 Converting: 167 Tinting an image.mp4 ...
# ✅ Finished converting: 167 Tinting an image.mp4
# 🔄 Converting: 168 Blending black-and-white with color.mp4 ...
# ✅ Finished converting: 168 Blending black-and-white with color.mp4
# 🔄 Converting: 169 Convert to Grayscale in Camera Raw.mp4 ...
# ✅ Finished converting: 169 Convert to Grayscale in Camera Raw.mp4
# 🔄 Converting: 170 Split Toning in Camera Raw.mp4 ...
# ✅ Finished converting: 170 Split Toning in Camera Raw.mp4
# 🔄 Converting: 171 Infusing black-and-white with color.mp4 ...
# ✅ Finished converting: 171 Infusing black-and-white with color.mp4
# 🔄 Converting: 172 Quick-and-dirty colorization.mp4 ...
# ✅ Finished converting: 172 Quick-and-dirty colorization.mp4
# 🔄 Converting: 173 Creating a professional-quality sepia tone.mp4 ...
# ✅ Finished converting: 173 Creating a professional-quality sepia tone.mp4
# 🔄 Converting: 174 The best of the best - Gradient Map.mp4 ...
# ✅ Finished converting: 174 The best of the best - Gradient Map.mp4
# 🔄 Converting: 175 Loading my free, tailor-made gradients.mp4 ...
# ✅ Finished converting: 175 Loading my free, tailor-made gradients.mp4
# 🔄 Converting: 176 Designing your own custom quadtone.mp4 ...
# ✅ Finished converting: 176 Designing your own custom quadtone.mp4
# 🔄 Converting: 177 Creating psychedelic arbitrary maps.mp4 ...
# ✅ Finished converting: 177 Creating psychedelic arbitrary maps.mp4
# 🔄 Converting: 178 How sharpening works.mp4 ...
# ✅ Finished converting: 178 How sharpening works.mp4
# 🔄 Converting: 179 Introducing Unsharp Mask.mp4 ...
# ✅ Finished converting: 179 Introducing Unsharp Mask.mp4
# 🔄 Converting: 180 Blending your sharpening effect.mp4 ...
# ✅ Finished converting: 180 Blending your sharpening effect.mp4
# 🔄 Converting: 181 Reining in sharpness with a filter mask.mp4 ...
# ✅ Finished converting: 181 Reining in sharpness with a filter mask.mp4
# 🔄 Converting: 182 Introducing Smart Sharpen.mp4 ...
# ✅ Finished converting: 182 Introducing Smart Sharpen.mp4
# 🔄 Converting: 183 Remove - Lens Blur and Reduce Noise.mp4 ...
# ✅ Finished converting: 183 Remove - Lens Blur and Reduce Noise.mp4
# 🔄 Converting: 184 Preventing shadow-highlight clipping.mp4 ...
# ✅ Finished converting: 184 Preventing shadow-highlight clipping.mp4
# 🔄 Converting: 185 Compensating for camera shake.mp4 ...
# ✅ Finished converting: 185 Compensating for camera shake.mp4
# 🔄 Converting: 186 Further compensating with Emboss.mp4 ...
# ✅ Finished converting: 186 Further compensating with Emboss.mp4
# 🔄 Converting: 187 Sharpening with the High Pass filter.mp4 ...
# ✅ Finished converting: 187 Sharpening with the High Pass filter.mp4
# 🔄 Converting: 188 Painting with the Sharpen tool.mp4 ...
# ✅ Finished converting: 188 Painting with the Sharpen tool.mp4
# 🔄 Converting: 189 Until next time.mp4 ...
# ✅ Finished converting: 189 Until next time.mp4
# 🔗 Attempt 2: Merging videos...
# ✅ Merge successful! Duration: 64609.88 sec
# 📤 Uploading: Adobe - Photoshop - Lynda - Photoshop CC 2018 One-on-One - Advanced...
# ---------------------------------------------------------------------------
# ResumableUploadError                      Traceback (most recent call last)
# Cell In[1], line 156, in upload_to_youtube(video_path, title, description, folder_path)
#     155 try:
# --> 156     status, response = request.next_chunk()
#     157     if status:
#
# File c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python312\Lib\site-packages\googleapiclient\_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python312\Lib\site-packages\googleapiclient\http.py:1022, in HttpRequest.next_chunk(self, http, num_retries)
#    1021     else:
# -> 1022         raise ResumableUploadError(resp, content)
#    1023 elif self._in_error_state:
#    1024     # If we are in an error state then query the server for current state of
#    1025     # the upload by sending an empty PUT and reading the 'range' header in
#    1026     # the response.
#
# ResumableUploadError: <HttpError 400 when requesting None returned "The request metadata specifies an invalid video description.". Details: "[{'message': 'The request metadata specifies an invalid video description.', 'domain': 'youtube.video', 'reason': 'invalidDescription', 'location': 'body.snippet.description', 'locationType': 'other'}]">
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 208
#     205             folder_parts = os.path.normpath(subfolder_path).split(os.sep)
#     206             title = " - ".join(folder_parts[-4:]) if len(folder_parts) >= 4 else "Merged Video"
# --> 208             upload_to_youtube(merged_video_path, title, description, subfolder_path)
#     210             cleanup_files(subfolder_path, total_duration)
#     212 print("✅ All subfolders processed!")
#
# Cell In[1], line 160, in upload_to_youtube(video_path, title, description, folder_path)
#     158             print(f"Uploaded {int(status.progress() * 100)}%")
#     159     except Exception as e:
# --> 160         raise Exception(f"Error during upload: {e}")
#     162 video_url = f"https://www.youtube.com/watch?v={response['id']}"
#     163 with open(os.path.join(folder_path, "youtube link.txt"), "w") as f:
#
# Exception: Error during upload: <HttpError 400 when requesting None returned "The request metadata specifies an invalid video description.". Details: "[{'message': 'The request metadata specifies an invalid video description.', 'domain': 'youtube.video', 'reason': 'invalidDescription', 'location': 'body.snippet.description', 'locationType': 'other'}]">
