# %%
import os
import time
import logging
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from moviepy.video.io.VideoFileClip import VideoFileClip
from moviepy import concatenate_videoclips

# Set up logging
logging.basicConfig(
    format='%(asctime)s - %(levelname)s - %(message)s',
    level=logging.INFO,  # Adjust log level here (DEBUG, INFO, WARNING, ERROR, CRITICAL)
    handlers=[logging.StreamHandler()]  # Output to console
)

# Suppress the verbose logging from moviepy/ffmpeg
logging.getLogger("moviepy").setLevel(logging.ERROR)
logging.getLogger("ffmpeg").setLevel(logging.ERROR)

# Google API configuration
SCOPES = ["https://www.googleapis.com/auth/youtube.upload"]
CLIENT_SECRETS_FILE = "client_secret.json"
TOKEN_FILE = "token.json"
YOUTUBE_MAX_DURATION = 43200  # 12 hours in seconds

MERGE_TIMEOUT = 2400  # 40 minutes
CONVERT_TIMEOUT = 7200  # 2 hours
MAX_VIDEO_DURATION = 21600  # 6 hours in seconds


def get_authenticated_service():
    """
    Authenticate with YouTube API and return a service object.
    """
    creds = None

    if os.path.exists(TOKEN_FILE):
        creds = Credentials.from_authorized_user_file(TOKEN_FILE)

    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            try:
                logging.info("🔄 Token expired. Attempting to refresh...")
                creds.refresh(Request())
                logging.info("✅ Token refreshed successfully!")
            except Exception as e:
                logging.error(f"⚠️ Token refresh failed: {e}\n🌐 Opening browser for re-authentication...")
                creds = None  # Force re-authentication

        if creds is None:
            logging.info("🌐 Opening browser for authentication...")
            flow = InstalledAppFlow.from_client_secrets_file(CLIENT_SECRETS_FILE, SCOPES)
            creds = flow.run_local_server(port=0)

        with open(TOKEN_FILE, "w") as token_file:
            token_file.write(creds.to_json())

    return build("youtube", "v3", credentials=creds)

def get_video_duration(video_path):
    """
    Returns the duration of a video in seconds.
    """
    try:
        video_clip = VideoFileClip(video_path)
        duration = video_clip.duration
        video_clip.close()
        return duration
    except Exception as e:
        logging.warning(f"⚠️ Warning: Could not read duration for {video_path}. Error: {e}")
        return None

def convert_videos(folder_path, video_files):
    """
    Converts videos to a uniform format (same codec, resolution, frame rate, etc.).
    Skips videos with no valid duration.
    """
    converted_folder = os.path.join(folder_path, "converted_videos")
    os.makedirs(converted_folder, exist_ok=True)
    converted_files = []

    # Filter out videos with no valid duration
    video_files = [f for f in video_files if get_video_duration(f) is not None]

    if not video_files:
        logging.warning(f"⚠️ No valid videos to convert in {folder_path}. Skipping...")
        return []

    logging.info(f"🔄 Starting video conversion... (Timeout: {CONVERT_TIMEOUT // 3600} hours)")

    start_time = time.time()
    for video in video_files:
        converted_video = os.path.join(converted_folder, os.path.basename(video))

        try:
            video_clip = VideoFileClip(video)
            video_clip = video_clip.resize(height=720)  # Resize to 720p
            video_clip.write_videofile(converted_video, codec="libx264", audio_codec="aac", threads=4)
            video_clip.close()
        except Exception as e:
            logging.error(f"❌ Error during conversion of {video}: {e}")
            continue

        converted_files.append(converted_video)

        elapsed_time = time.time() - start_time
        if elapsed_time > CONVERT_TIMEOUT:
            logging.warning("⏳ Total conversion exceeded allowed time. Aborting conversion...")
            return []

    logging.info("✅ Video conversion complete!")
    return converted_files

def try_merge_videos(folder_path, video_files, expected_duration, merge_attempt):
    """
    Merges videos using MoviePy.
    """
    merged_video_path = os.path.join(folder_path, "merged_video.mp4")

    # Filter out videos with no valid duration
    video_files = [f for f in video_files if get_video_duration(f) is not None]

    if not video_files:
        logging.warning(f"⚠️ No valid videos to merge in {folder_path}. Skipping...")
        return None

    logging.info(f"🔗 Attempt {merge_attempt}: Merging videos... (Timeout: {MERGE_TIMEOUT // 60} min)")

    try:
        video_clips = [VideoFileClip(f) for f in video_files]
        final_clip = concatenate_videoclips(video_clips, method="compose")
        final_clip.write_videofile(merged_video_path, codec="libx264", audio_codec="aac", threads=4)
        final_clip.close()

        merged_duration = get_video_duration(merged_video_path)
        if merged_duration and abs(merged_duration - expected_duration) <= 5:
            logging.info(f"✅ Merge successful! Duration: {merged_duration:.2f} sec")
            return merged_video_path
        else:
            logging.error(f"❌ Merge failed. Merged duration: {merged_duration:.2f} sec, Expected: {expected_duration:.2f} sec")
            os.remove(merged_video_path)
            return None
    except Exception as e:
        logging.error(f"❌ Error during merge: {e}")
        return None

def merge_videos_and_create_timestamps(folder_path, video_files, part_number=None):
    """
    Merges videos, creates timestamps, and returns the final video path, description, and total duration.
    """
    logging.info(f"📂 Checking folder: {folder_path}")

    if not os.path.exists(folder_path):
        logging.error(f"❌ Error: The folder path '{folder_path}' does not exist.")
        return None, None, None

    # Skip corrupted videos
    video_files = [f for f in video_files if get_video_duration(f) is not None]

    if not video_files:
        logging.warning(f"⚠️ No valid videos found in {folder_path}. Skipping folder...")
        return None, None, None

    total_duration = sum(get_video_duration(f) or 0 for f in video_files)

    # Split videos if total duration > 6 hours
    if total_duration > MAX_VIDEO_DURATION:
        logging.warning(f"⚠️ Video duration too long ({total_duration} sec). Splitting into two parts...")
        mid_index = len(video_files) // 2
        first_half = video_files[:mid_index]
        second_half = video_files[mid_index:]

        merged_video_path_1 = try_merge_videos(folder_path, first_half, sum(get_video_duration(f) or 0 for f in first_half), merge_attempt=1)
        merged_video_path_2 = try_merge_videos(folder_path, second_half, sum(get_video_duration(f) or 0 for f in second_half), merge_attempt=2)

        if merged_video_path_1 and merged_video_path_2:
            return [merged_video_path_1, merged_video_path_2], "\n".join(os.path.basename(f) for f in video_files), total_duration
        else:
            return None, None, None

    # Try merging normally if duration is within limit
    merged_video_path = try_merge_videos(folder_path, video_files, total_duration, merge_attempt=1)
    if merged_video_path:
        return merged_video_path, "\n".join(os.path.basename(f) for f in video_files), total_duration

    logging.info("🔄 Converting videos due to merge failure...")
    converted_files = convert_videos(folder_path, video_files)

    if not converted_files:
        logging.error(f"❌ Conversion failed for {folder_path}. Skipping upload.")
        return None, None, None

    return try_merge_videos(folder_path, converted_files, total_duration, merge_attempt=2), "\n".join(os.path.basename(f) for f in converted_files), total_duration


def upload_to_youtube(video_path, title, description, folder_path):
    """
    Uploads a video to YouTube and saves the video URL in 'youtube link.txt'.
    """
    logging.info(f"📤 Uploading: {title}...")
    youtube = get_authenticated_service()
    request = youtube.videos().insert(
        part="snippet,status",
        body={"snippet": {"title": title, "description": description, "categoryId": "27"}, "status": {"privacyStatus": "unlisted"}},
        media_body=MediaFileUpload(video_path, chunksize=-1, resumable=True)
    )

    _, response = request.next_chunk()
    video_url = f"https://www.youtube.com/watch?v={response['id']}"
    with open(os.path.join(folder_path, "youtube_link.txt"), "w") as f:
        f.write(video_url + "\n")

    logging.info(f"✅ Upload complete! Video URL: {video_url}")
    return video_url

if __name__ == "__main__":
    parent_folder = input("📂 Enter the parent folder containing all video subfolders: ").strip()

    for subfolder in sorted(os.listdir(parent_folder)):
        subfolder_path = os.path.join(parent_folder, subfolder)

        if os.path.isdir(subfolder_path):
            logging.info(f"🚀 Processing folder: {subfolder_path}")

            video_files = sorted([os.path.join(subfolder_path, f) for f in os.listdir(subfolder_path) if f.endswith('.mp4')])
            merged_video_path, description, _ = merge_videos_and_create_timestamps(subfolder_path, video_files)
            if merged_video_path:
                upload_to_youtube(merged_video_path, subfolder, description, subfolder_path)

    logging.info("✅ All subfolders processed!")
# Out:
# 2025-02-27 10:19:09,797 - INFO - 🚀 Processing folder: H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training
# 2025-02-27 10:19:09,801 - INFO - 📂 Checking folder: H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'mp42isom', 'creation_time': '2017-08-22T17:09:18.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 554, 'fps': 15.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': 'TELE', 'encoder': 'Apple ProRes 422'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 160, 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 167.13, 'bitrate': 720, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 720], 'video_bitrate': 554, 'video_fps': 15.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 160, 'video_duration': 167.13, 'video_n_frames': 2506}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\01. Welcome.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'mp42isom', 'creation_time': '2017-08-22T17:02:33.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 199, 'fps': 15.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': 'TELE', 'encoder': 'Apple ProRes 422'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 160, 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 71.33, 'bitrate': 364, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 720], 'video_bitrate': 199, 'video_fps': 15.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 160, 'video_duration': 71.33, 'video_n_frames': 1069}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\02. What you should know.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'mp42isom', 'creation_time': '2017-08-22T17:05:13.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 119, 'fps': 15.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': 'TELE', 'encoder': 'Apple ProRes 422'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 160, 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 105.07, 'bitrate': 284, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 720], 'video_bitrate': 119, 'video_fps': 15.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 160, 'video_duration': 105.07, 'video_n_frames': 1576}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\03. Using the exercise files.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'mp42isom', 'creation_time': '2017-08-22T17:13:10.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 195, 'fps': 15.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': 'TELE', 'encoder': 'Apple ProRes 422'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 160, 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 316.87, 'bitrate': 360, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 720], 'video_bitrate': 195, 'video_fps': 15.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 160, 'video_duration': 316.87, 'video_n_frames': 4753}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\04. Using shapes.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'mp42isom', 'creation_time': '2017-08-22T16:53:19.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 194, 'fps': 15.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': 'TELE', 'encoder': 'Apple ProRes 422'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 160, 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 316.93, 'bitrate': 359, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 720], 'video_bitrate': 194, 'video_fps': 15.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 160, 'video_duration': 316.93, 'video_n_frames': 4753}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\05. Using custom inputs.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'mp42isom', 'creation_time': '2017-08-22T17:03:15.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 179, 'fps': 15.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': 'TELE', 'encoder': 'Apple ProRes 422'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 160, 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 294.13, 'bitrate': 344, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 720], 'video_bitrate': 179, 'video_fps': 15.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 160, 'video_duration': 294.13, 'video_n_frames': 4411}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\06. Advantages of the multiswitch node.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'mp42isom', 'creation_time': '2017-08-22T16:53:11.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 225, 'fps': 15.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': 'TELE', 'encoder': 'Apple ProRes 422'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 159, 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 187.93, 'bitrate': 390, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 720], 'video_bitrate': 225, 'video_fps': 15.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 159, 'video_duration': 187.93, 'video_n_frames': 2818}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\07. Transformation 2D nodes.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'mp42isom', 'creation_time': '2017-08-22T16:50:41.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 183, 'fps': 15.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': 'TELE', 'encoder': 'Apple ProRes 422'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 160, 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 288.53, 'bitrate': 348, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 720], 'video_bitrate': 183, 'video_fps': 15.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 160, 'video_duration': 288.53, 'video_n_frames': 4327}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\08. Inner-panel masking.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'mp42isom', 'creation_time': '2017-08-22T16:59:44.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 258, 'fps': 15.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': 'TELE', 'encoder': 'Apple ProRes 422'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 160, 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 255.13, 'bitrate': 422, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 720], 'video_bitrate': 258, 'video_fps': 15.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 160, 'video_duration': 255.13, 'video_n_frames': 3826}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\09. Creating edge detailing.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'mp42isom', 'creation_time': '2017-08-22T17:10:06.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 219, 'fps': 15.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': 'TELE', 'encoder': 'Apple ProRes 422'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 160, 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 152.87, 'bitrate': 384, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 720], 'video_bitrate': 219, 'video_fps': 15.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 160, 'video_duration': 152.87, 'video_n_frames': 2293}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\10. Edge masking.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'mp42isom', 'creation_time': '2017-08-22T16:51:41.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 186, 'fps': 15.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': 'TELE', 'encoder': 'Apple ProRes 422'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 160, 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 208.53, 'bitrate': 351, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 720], 'video_bitrate': 186, 'video_fps': 15.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 160, 'video_duration': 208.53, 'video_n_frames': 3127}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\11. Rivet generation.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'mp42isom', 'creation_time': '2017-08-22T17:00:39.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 208, 'fps': 15.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': 'TELE', 'encoder': 'Apple ProRes 422'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 160, 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 198.07, 'bitrate': 373, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 720], 'video_bitrate': 208, 'video_fps': 15.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 160, 'video_duration': 198.07, 'video_n_frames': 2971}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\12. Normal map creation.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'mp42isom', 'creation_time': '2017-08-22T16:54:51.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 264, 'fps': 15.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': 'TELE', 'encoder': 'Apple ProRes 422'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 160, 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 199.73, 'bitrate': 429, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 720], 'video_bitrate': 264, 'video_fps': 15.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 160, 'video_duration': 199.73, 'video_n_frames': 2995}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\13. Diffuse creation.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'mp42isom', 'creation_time': '2017-08-22T16:50:39.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 209, 'fps': 15.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': 'TELE', 'encoder': 'Apple ProRes 422'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 160, 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 258.47, 'bitrate': 374, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 720], 'video_bitrate': 209, 'video_fps': 15.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 160, 'video_duration': 258.47, 'video_n_frames': 3877}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\14. Ambient occlusion.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'mp42isom', 'creation_time': '2017-08-22T17:02:19.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 88, 'fps': 15.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': 'TELE', 'encoder': 'Apple ProRes 422'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 159, 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 177.0, 'bitrate': 253, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 720], 'video_bitrate': 88, 'video_fps': 15.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 159, 'video_duration': 177.0, 'video_n_frames': 2655}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\15. The Welcome dialogue.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'mp42isom', 'creation_time': '2017-08-22T16:50:01.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 81, 'fps': 15.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': 'TELE', 'encoder': 'Apple ProRes 422'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 160, 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 293.33, 'bitrate': 246, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 720], 'video_bitrate': 81, 'video_fps': 15.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 160, 'video_duration': 293.33, 'video_n_frames': 4399}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\16. Preferences and important setup.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'mp42isom', 'creation_time': '2017-08-22T17:02:00.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 40, 'fps': 15.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': 'TELE', 'encoder': 'Apple ProRes 422'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 159, 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 121.73, 'bitrate': 206, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 720], 'video_bitrate': 40, 'video_fps': 15.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 159, 'video_duration': 121.73, 'video_n_frames': 1825}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\17. What is a Substance Package.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'mp42isom', 'creation_time': '2017-08-22T17:02:43.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 116, 'fps': 15.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': 'TELE', 'encoder': 'Apple ProRes 422'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 159, 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 179.47, 'bitrate': 281, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 720], 'video_bitrate': 116, 'video_fps': 15.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 159, 'video_duration': 179.47, 'video_n_frames': 2692}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\18. What is a substance graph.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'mp42isom', 'creation_time': '2017-08-22T16:52:06.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 75, 'fps': 15.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': 'TELE', 'encoder': 'Apple ProRes 422'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 160, 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 227.87, 'bitrate': 240, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 720], 'video_bitrate': 75, 'video_fps': 15.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 160, 'video_duration': 227.87, 'video_n_frames': 3418}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\19. Choosing the correct graph template.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'mp42isom', 'creation_time': '2017-08-22T17:16:08.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 89, 'fps': 15.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': 'TELE', 'encoder': 'Apple ProRes 422'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 160, 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 233.67000000000002, 'bitrate': 254, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 720], 'video_bitrate': 89, 'video_fps': 15.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 160, 'video_duration': 233.67000000000002, 'video_n_frames': 3505}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\20. Setting our graph properties.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'mp42isom', 'creation_time': '2017-08-22T17:10:55.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 220, 'fps': 15.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': 'TELE', 'encoder': 'Apple ProRes 422'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 160, 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 239.2, 'bitrate': 385, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 720], 'video_bitrate': 220, 'video_fps': 15.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 160, 'video_duration': 239.2, 'video_n_frames': 3588}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\21. Mesh setup prior to export.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'mp42isom', 'creation_time': '2017-08-22T16:53:02.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 170, 'fps': 15.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': 'TELE', 'encoder': 'Apple ProRes 422'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 160, 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 306.07, 'bitrate': 335, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 720], 'video_bitrate': 170, 'video_fps': 15.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 160, 'video_duration': 306.07, 'video_n_frames': 4591}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\22. ImportingÂ meshes and maps into Designer.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'mp42isom', 'creation_time': '2017-08-22T17:03:08.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 155, 'fps': 15.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': 'TELE', 'encoder': 'Apple ProRes 422'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 160, 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 362.47, 'bitrate': 320, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 720], 'video_bitrate': 155, 'video_fps': 15.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 160, 'video_duration': 362.47, 'video_n_frames': 5437}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\23. Baking out mesh specific maps.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'mp42isom', 'creation_time': '2017-08-22T17:11:18.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 351, 'fps': 15.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': 'TELE', 'encoder': 'Apple ProRes 422'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 159, 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 203.6, 'bitrate': 516, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 720], 'video_bitrate': 351, 'video_fps': 15.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 159, 'video_duration': 203.6, 'video_n_frames': 3054}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\24. Adjust the UI layout.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'mp42isom', 'creation_time': '2017-08-22T16:52:31.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 252, 'fps': 15.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': 'TELE', 'encoder': 'Apple ProRes 422'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 160, 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 191.93, 'bitrate': 417, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 720], 'video_bitrate': 252, 'video_fps': 15.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 160, 'video_duration': 191.93, 'video_n_frames': 2878}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\25. Menu items and options.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'mp42isom', 'creation_time': '2017-08-22T17:09:12.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 252, 'fps': 15.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': 'TELE', 'encoder': 'Apple ProRes 422'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 160, 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 342.4, 'bitrate': 417, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 720], 'video_bitrate': 252, 'video_fps': 15.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 160, 'video_duration': 342.4, 'video_n_frames': 5136}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\26. The Explorer section.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'mp42isom', 'creation_time': '2017-08-22T16:58:12.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 245, 'fps': 15.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': 'TELE', 'encoder': 'Apple ProRes 422'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 159, 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 210.13, 'bitrate': 410, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 720], 'video_bitrate': 245, 'video_fps': 15.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 159, 'video_duration': 210.13, 'video_n_frames': 3151}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\27. What is the Library.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'mp42isom', 'creation_time': '2017-08-22T16:56:24.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 294, 'fps': 15.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': 'TELE', 'encoder': 'Apple ProRes 422'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 160, 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 181.47, 'bitrate': 459, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 720], 'video_bitrate': 294, 'video_fps': 15.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 160, 'video_duration': 181.47, 'video_n_frames': 2722}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\28. The parameters section.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'mp42isom', 'creation_time': '2017-08-22T17:11:50.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 331, 'fps': 15.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': 'TELE', 'encoder': 'Apple ProRes 422'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 160, 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 138.6, 'bitrate': 496, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 720], 'video_bitrate': 331, 'video_fps': 15.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 160, 'video_duration': 138.6, 'video_n_frames': 2079}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\29. Navigating and using the Graph view.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# ...
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\63. Adding the FX map.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'mp42isom', 'creation_time': '2017-08-22T17:13:13.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 101, 'fps': 15.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': 'TELE', 'encoder': 'Apple ProRes 422'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 160, 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 414.93, 'bitrate': 266, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 720], 'video_bitrate': 101, 'video_fps': 15.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 160, 'video_duration': 414.93, 'video_n_frames': 6223}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\64. Building an FX map, part 1.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'mp42isom', 'creation_time': '2017-08-22T17:22:25.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 120, 'fps': 15.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': 'TELE', 'encoder': 'Apple ProRes 422'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 160, 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 352.47, 'bitrate': 285, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 720], 'video_bitrate': 120, 'video_fps': 15.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 160, 'video_duration': 352.47, 'video_n_frames': 5287}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\65. Building an FX map, part 2.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'mp42isom', 'creation_time': '2017-08-22T16:52:13.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 164, 'fps': 15.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': 'TELE', 'encoder': 'Apple ProRes 422'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 160, 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 166.32999999999998, 'bitrate': 329, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 720], 'video_bitrate': 164, 'video_fps': 15.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 160, 'video_duration': 166.32999999999998, 'video_n_frames': 2494}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\66. Finalizing the functions.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'mp42isom', 'creation_time': '2017-08-22T16:54:19.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 261, 'fps': 15.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': 'TELE', 'encoder': 'Apple ProRes 422'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 160, 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 406.73, 'bitrate': 425, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 720], 'video_bitrate': 261, 'video_fps': 15.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 160, 'video_duration': 406.73, 'video_n_frames': 6100}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\67. Exposing substance parameters.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'mp42isom', 'creation_time': '2017-08-22T17:05:56.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 302, 'fps': 15.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': 'TELE', 'encoder': 'Apple ProRes 422'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 160, 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 218.53, 'bitrate': 467, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 720], 'video_bitrate': 302, 'video_fps': 15.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 160, 'video_duration': 218.53, 'video_n_frames': 3277}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\68. Exporting bitmaps.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'mp42isom', 'creation_time': '2017-08-22T16:56:59.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 261, 'fps': 15.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': 'TELE', 'encoder': 'Apple ProRes 422'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 160, 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 208.07, 'bitrate': 426, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 720], 'video_bitrate': 261, 'video_fps': 15.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 160, 'video_duration': 208.07, 'video_n_frames': 3121}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\69. Publishing a substance.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'mp42isom', 'creation_time': '2017-08-22T16:56:23.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 270, 'fps': 15.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': 'TELE', 'encoder': 'Apple ProRes 422'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 160, 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 456.6, 'bitrate': 435, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 720], 'video_bitrate': 270, 'video_fps': 15.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 160, 'video_duration': 456.6, 'video_n_frames': 6849}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\70. Importing a substance into UE4.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'mp42isom', 'creation_time': '2017-08-22T16:56:27.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 370, 'fps': 15.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': 'TELE', 'encoder': 'Apple ProRes 422'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 160, 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 296.6, 'bitrate': 535, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 720], 'video_bitrate': 370, 'video_fps': 15.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 160, 'video_duration': 296.6, 'video_n_frames': 4449}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\71. Adding finishing touches.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'mp42isom', 'creation_time': '2017-08-22T17:15:49.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 255, 'fps': 15.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': 'TELE', 'encoder': 'Apple ProRes 422'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 160, 'metadata': {'Metadata': '', 'handler_name': 'Telestream Inc. Dib Library - ReleaseVantage 2014.59.138974', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 79.47, 'bitrate': 421, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1280, 720], 'video_bitrate': 255, 'video_fps': 15.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 160, 'video_duration': 79.47, 'video_n_frames': 1192}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\72. Next steps.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# MoviePy - Building video H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\merged_video.mp4.
# MoviePy - Writing audio in merged_videoTEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# MoviePy - Writing video H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Substance Designer\Lynda\Substance Designer Essential Training\merged_video.mp4
# frame_index:   2%|▏         | 6165/263985 [15:28<10:56:29,  6.55it/s, now=None]
