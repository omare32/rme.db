# %%
import os
import time
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from moviepy.video.io.VideoFileClip import VideoFileClip
from moviepy import concatenate_videoclips

# Disable SSL
import ssl
import googleapiclient.discovery

ssl._create_default_https_context = ssl._create_unverified_context

# Google API configuration
SCOPES = ["https://www.googleapis.com/auth/youtube.upload"]
CLIENT_SECRETS_FILE = "client_secret.json"
TOKEN_FILE = "token.json"
YOUTUBE_MAX_DURATION = 43200  # 12 hours in seconds

MERGE_TIMEOUT = 2400  # 40 minutes
CONVERT_TIMEOUT = 7200  # 2 hours

def get_authenticated_service():
    """
    Authenticate with YouTube API and return a service object.
    If re-authentication is required, open a browser before starting the process.
    """
    creds = None

    # ✅ Check if a token file exists
    if os.path.exists(TOKEN_FILE):
        creds = Credentials.from_authorized_user_file(TOKEN_FILE)

    # ✅ If token is missing or invalid, refresh or re-authenticate before merging starts
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            try:
                print("🔄 Token expired. Attempting to refresh...")
                creds.refresh(Request())
                print("✅ Token refreshed successfully!")
            except Exception as e:
                print(f"⚠️ Token refresh failed: {e}\n🌐 Opening browser for re-authentication...")
                creds = None  # Force re-authentication

        if creds is None:
            print("🌐 Opening browser for authentication...")
            flow = InstalledAppFlow.from_client_secrets_file(CLIENT_SECRETS_FILE, SCOPES)
            creds = flow.run_local_server(port=0)

        # ✅ Save the new token immediately
        with open(TOKEN_FILE, "w") as token_file:
            token_file.write(creds.to_json())

    return build("youtube", "v3", credentials=creds)

# 🔥 Call authentication before any conversion or merging starts!
youtube_service = get_authenticated_service()
print("✅ Authentication successful! Now processing videos...")

def get_video_duration(video_path):
    """
    Returns the duration of a video in seconds.
    """
    try:
        video_clip = VideoFileClip(video_path)
        duration = video_clip.duration
        video_clip.close()
        return duration
    except Exception as e:
        print(f"⚠️ Warning: Could not read duration for {video_path}. Error: {e}")
        return None

MAX_VIDEO_DURATION = 21600  # 6 hours in seconds

def convert_videos(folder_path, video_files):
    """
    Converts videos to a uniform format (same codec, resolution, frame rate, etc.).
    Skips videos with no valid duration.
    """
    converted_folder = os.path.join(folder_path, "converted_videos")
    os.makedirs(converted_folder, exist_ok=True)
    converted_files = []

    # ✅ Filter out videos with no valid duration
    video_files = [f for f in video_files if get_video_duration(f) is not None]

    if not video_files:
        print(f"⚠️ No valid videos to convert in {folder_path}. Skipping...")
        return []

    print(f"🔄 Starting video conversion... (Timeout: {CONVERT_TIMEOUT // 3600} hours)")

    start_time = time.time()
    for video in video_files:
        converted_video = os.path.join(converted_folder, os.path.basename(video))

        try:
            video_clip = VideoFileClip(video)
            video_clip = video_clip.resize(height=720)  # Resize to 720p
            video_clip.write_videofile(converted_video, codec="libx264", audio_codec="aac", threads=4)
            video_clip.close()
        except Exception as e:
            print(f"❌ Error during conversion of {video}: {e}")
            continue

        converted_files.append(converted_video)

        elapsed_time = time.time() - start_time
        if elapsed_time > CONVERT_TIMEOUT:
            print("⏳ Total conversion exceeded allowed time. Aborting conversion...")
            return []

    print("✅ Video conversion complete!")
    return converted_files

def try_merge_videos(folder_path, video_files, expected_duration, merge_attempt):
    """
    Merges videos using MoviePy.
    Skips videos with no valid duration.
    """
    merged_video_path = os.path.join(folder_path, "merged_video.mp4")

    # ✅ Filter out videos with no valid duration
    video_files = [f for f in video_files if get_video_duration(f) is not None]

    if not video_files:
        print(f"⚠️ No valid videos to merge in {folder_path}. Skipping...")
        return None

    print(f"🔗 Attempt {merge_attempt}: Merging videos... (Timeout: {MERGE_TIMEOUT // 60} min)")

    try:
        video_clips = [VideoFileClip(f) for f in video_files]
        final_clip = concatenate_videoclips(video_clips, method="compose")
        final_clip.write_videofile(merged_video_path, codec="libx264", audio_codec="aac", threads=4)
        final_clip.close()

        merged_duration = get_video_duration(merged_video_path)
        if merged_duration and abs(merged_duration - expected_duration) <= 5:
            print(f"✅ Merge successful! Duration: {merged_duration:.2f} sec")
            return merged_video_path
        else:
            print(f"❌ Merge failed. Merged duration: {merged_duration:.2f} sec, Expected: {expected_duration:.2f} sec")
            os.remove(merged_video_path)
            return None
    except Exception as e:
        print(f"❌ Error during merge: {e}")
        return None

def merge_videos_and_create_timestamps(folder_path, video_files, part_number=None):
    """
    Merges videos, creates timestamps, and returns the final video path, description, and total duration.
    Splits the videos into parts if total duration exceeds 6 hours.
    """
    print(f"📂 Checking folder: {folder_path}")

    if not os.path.exists(folder_path):
        print(f"❌ Error: The folder path '{folder_path}' does not exist.")
        return None, None, None

    # ✅ Skip corrupted videos
    video_files = [f for f in video_files if get_video_duration(f) is not None]

    if not video_files:
        print(f"⚠️ No valid videos found in {folder_path}. Skipping folder...")
        return None, None, None

    total_duration = sum(get_video_duration(f) or 0 for f in video_files)

    # ✅ Split videos if total duration > 6 hours
    if total_duration > MAX_VIDEO_DURATION:
        print(f"⚠️ Video duration too long ({total_duration} sec). Splitting into two parts...")
        mid_index = len(video_files) // 2
        first_half = video_files[:mid_index]
        second_half = video_files[mid_index:]

        merged_video_path_1 = try_merge_videos(folder_path, first_half, sum(get_video_duration(f) or 0 for f in first_half), merge_attempt=1)
        merged_video_path_2 = try_merge_videos(folder_path, second_half, sum(get_video_duration(f) or 0 for f in second_half), merge_attempt=2)

        if merged_video_path_1 and merged_video_path_2:
            return [merged_video_path_1, merged_video_path_2], "\n".join(os.path.basename(f) for f in video_files), total_duration
        else:
            return None, None, None

    # ✅ Try merging normally if duration is within limit
    merged_video_path = try_merge_videos(folder_path, video_files, total_duration, merge_attempt=1)
    if merged_video_path:
        return merged_video_path, "\n".join(os.path.basename(f) for f in video_files), total_duration

    print("🔄 Converting videos due to merge failure...")
    converted_files = convert_videos(folder_path, video_files)

    if not converted_files:
        print(f"❌ Conversion failed for {folder_path}. Skipping upload.")
        return None, None, None

    return try_merge_videos(folder_path, converted_files, total_duration, merge_attempt=2), "\n".join(os.path.basename(f) for f in converted_files), total_duration

def upload_to_youtube(video_path, title, description, folder_path):
    """
    Uploads a video to YouTube and saves the video URL in 'youtube link.txt'.
    """
    print(f"📤 Uploading: {title}...")
    youtube = get_authenticated_service()
    request = youtube.videos().insert(
        part="snippet,status",
        body={"snippet": {"title": title, "description": description, "categoryId": "27"}, "status": {"privacyStatus": "unlisted"}},
        media_body=MediaFileUpload(video_path, chunksize=-1, resumable=True)
    )

    _, response = request.next_chunk()
    video_url = f"https://www.youtube.com/watch?v={response['id']}"
    with open(os.path.join(folder_path, "youtube_link.txt"), "w") as f:
        f.write(video_url + "\n")

    print(f"✅ Upload complete! Video URL: {video_url}")
    return video_url

if __name__ == "__main__":
    parent_folder = input("📂 Enter the parent folder containing all video subfolders: ").strip()

    for subfolder in sorted(os.listdir(parent_folder)):
        subfolder_path = os.path.join(parent_folder, subfolder)

        if os.path.isdir(subfolder_path):
            print(f"🚀 Processing folder: {subfolder_path}")

            video_files = sorted([os.path.join(subfolder_path, f) for f in os.listdir(subfolder_path) if f.endswith('.mp4')])
            merged_video_path, description, _ = merge_videos_and_create_timestamps(subfolder_path, video_files)
            if merged_video_path:
                upload_to_youtube(merged_video_path, subfolder, description, subfolder_path)

    print("✅ All subfolders processed!")
# Out:
# ✅ Authentication successful! Now processing videos...
# 🚀 Processing folder: H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories
# 📂 Checking folder: H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'isomiso2avc1mp41mp42', 'creation_time': '2017-06-03T12:15:28.000000Z', 'encoder': 'Lavf53.32.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 1658, 'fps': 30.0, 'codec_name': 'h264', 'profile': '(High)', 'metadata': {'Metadata': '', 'creation_time': '2017-06-03T12:15:28.000000Z', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 189, 'metadata': {'Metadata': '', 'creation_time': '2017-06-03T12:15:28.000000Z', 'handler_name': 'SoundHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 136.82999999999998, 'bitrate': 1849, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(High)', 'video_size': [1280, 720], 'video_bitrate': 1658, 'video_fps': 30.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 189, 'video_duration': 136.82999999999998, 'video_n_frames': 4104}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\01-Course_Overview.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'isomiso2avc1mp41mp42', 'creation_time': '2017-05-27T15:58:51.000000Z', 'encoder': 'Lavf53.32.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 247, 'fps': 30.0, 'codec_name': 'h264', 'profile': '(High)', 'metadata': {'Metadata': '', 'creation_time': '2017-05-27T15:58:51.000000Z', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 189, 'metadata': {'Metadata': '', 'creation_time': '2017-05-27T15:58:51.000000Z', 'handler_name': 'SoundHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 163.14, 'bitrate': 439, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(High)', 'video_size': [1280, 720], 'video_bitrate': 247, 'video_fps': 30.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 189, 'video_duration': 163.14, 'video_n_frames': 4894}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\02-A_First_Look_At_Adobe_Spark.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'isomiso2avc1mp41mp42', 'creation_time': '2017-05-28T10:29:42.000000Z', 'encoder': 'Lavf53.32.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 196, 'fps': 30.0, 'codec_name': 'h264', 'profile': '(High)', 'metadata': {'Metadata': '', 'creation_time': '2017-05-28T10:29:42.000000Z', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 189, 'metadata': {'Metadata': '', 'creation_time': '2017-05-28T10:29:42.000000Z', 'handler_name': 'SoundHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 123.56, 'bitrate': 389, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(High)', 'video_size': [1280, 720], 'video_bitrate': 196, 'video_fps': 30.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 189, 'video_duration': 123.56, 'video_n_frames': 3706}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\03-Create_Account_In_Adobe_Spark.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'isomiso2avc1mp41mp42', 'creation_time': '2017-05-28T19:45:34.000000Z', 'encoder': 'Lavf53.32.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 218, 'fps': 30.0, 'codec_name': 'h264', 'profile': '(High)', 'metadata': {'Metadata': '', 'creation_time': '2017-05-28T19:45:34.000000Z', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 189, 'metadata': {'Metadata': '', 'creation_time': '2017-05-28T19:45:34.000000Z', 'handler_name': 'SoundHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 253.97, 'bitrate': 411, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(High)', 'video_size': [1280, 720], 'video_bitrate': 218, 'video_fps': 30.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 189, 'video_duration': 253.97, 'video_n_frames': 7619}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\04-Understanding_Adobe_Spark_Dashboard.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'isomiso2avc1mp41mp42', 'creation_time': '2017-05-29T00:03:39.000000Z', 'encoder': 'Lavf53.32.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 657, 'fps': 30.0, 'codec_name': 'h264', 'profile': '(High)', 'metadata': {'Metadata': '', 'creation_time': '2017-05-29T00:03:39.000000Z', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 189, 'metadata': {'Metadata': '', 'creation_time': '2017-05-29T00:03:39.000000Z', 'handler_name': 'SoundHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 468.37, 'bitrate': 850, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(High)', 'video_size': [1280, 720], 'video_bitrate': 657, 'video_fps': 30.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 189, 'video_duration': 468.37, 'video_n_frames': 14051}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\05-Some_Inspiration_For_What_You_Can_Do_With_Adobe_Spark.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'isomiso2avc1mp41mp42', 'creation_time': '2017-05-29T19:45:56.000000Z', 'encoder': 'Lavf53.32.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 284, 'fps': 30.0, 'codec_name': 'h264', 'profile': '(High)', 'metadata': {'Metadata': '', 'creation_time': '2017-05-29T19:45:56.000000Z', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 189, 'metadata': {'Metadata': '', 'creation_time': '2017-05-29T19:45:56.000000Z', 'handler_name': 'SoundHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 386.62, 'bitrate': 477, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(High)', 'video_size': [1280, 720], 'video_bitrate': 284, 'video_fps': 30.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 189, 'video_duration': 386.62, 'video_n_frames': 11598}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\06-Create_A_Social_Media_Post_With_Adobe_Spark.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'isomiso2avc1mp41mp42', 'creation_time': '2017-05-30T05:57:35.000000Z', 'encoder': 'Lavf53.32.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 632, 'fps': 30.0, 'codec_name': 'h264', 'profile': '(High)', 'metadata': {'Metadata': '', 'creation_time': '2017-05-30T05:57:35.000000Z', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 189, 'metadata': {'Metadata': '', 'creation_time': '2017-05-30T05:57:35.000000Z', 'handler_name': 'SoundHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 99.78, 'bitrate': 824, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(High)', 'video_size': [1280, 720], 'video_bitrate': 632, 'video_fps': 30.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 189, 'video_duration': 99.78, 'video_n_frames': 2993}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\07-Section_Intro.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'isomiso2avc1mp41mp42', 'creation_time': '2017-05-30T07:54:02.000000Z', 'encoder': 'Lavf53.32.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 987, 'fps': 30.0, 'codec_name': 'h264', 'profile': '(High)', 'metadata': {'Metadata': '', 'creation_time': '2017-05-30T07:54:02.000000Z', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 189, 'metadata': {'Metadata': '', 'creation_time': '2017-05-30T07:54:02.000000Z', 'handler_name': 'SoundHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 201.82999999999998, 'bitrate': 1179, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(High)', 'video_size': [1280, 720], 'video_bitrate': 987, 'video_fps': 30.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 189, 'video_duration': 201.82999999999998, 'video_n_frames': 6054}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\08-Few_Examples_Of_Quotes_To_Generate_Ideas.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'isomiso2avc1mp41mp42', 'creation_time': '2017-05-31T18:39:22.000000Z', 'encoder': 'Lavf53.32.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 188, 'fps': 30.0, 'codec_name': 'h264', 'profile': '(High)', 'metadata': {'Metadata': '', 'creation_time': '2017-05-31T18:39:22.000000Z', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 189, 'metadata': {'Metadata': '', 'creation_time': '2017-05-31T18:39:22.000000Z', 'handler_name': 'SoundHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 257.54, 'bitrate': 381, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(High)', 'video_size': [1280, 720], 'video_bitrate': 188, 'video_fps': 30.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 189, 'video_duration': 257.54, 'video_n_frames': 7726}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\09-Create_A_Inspirational_Quote_Image_From_Sketch.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'isomiso2avc1mp41mp42', 'creation_time': '2017-05-30T04:39:06.000000Z', 'encoder': 'Lavf53.32.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 648, 'fps': 30.0, 'codec_name': 'h264', 'profile': '(High)', 'metadata': {'Metadata': '', 'creation_time': '2017-05-30T04:39:06.000000Z', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 189, 'metadata': {'Metadata': '', 'creation_time': '2017-05-30T04:39:06.000000Z', 'handler_name': 'SoundHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 85.31, 'bitrate': 839, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(High)', 'video_size': [1280, 720], 'video_bitrate': 648, 'video_fps': 30.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 189, 'video_duration': 85.31, 'video_n_frames': 2559}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\10-Section_Intro.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'isomiso2avc1mp41mp42', 'creation_time': '2017-05-30T06:41:51.000000Z', 'encoder': 'Lavf53.32.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 508, 'fps': 30.0, 'codec_name': 'h264', 'profile': '(High)', 'metadata': {'Metadata': '', 'creation_time': '2017-05-30T06:41:51.000000Z', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 189, 'metadata': {'Metadata': '', 'creation_time': '2017-05-30T06:41:51.000000Z', 'handler_name': 'SoundHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 173.99, 'bitrate': 700, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(High)', 'video_size': [1280, 720], 'video_bitrate': 508, 'video_fps': 30.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 189, 'video_duration': 173.99, 'video_n_frames': 5219}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\11-Few_Example_Of_Blog_Images_To_Generate_Ideas.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'isomiso2avc1mp41mp42', 'creation_time': '2017-05-31T04:04:38.000000Z', 'encoder': 'Lavf53.32.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 233, 'fps': 30.0, 'codec_name': 'h264', 'profile': '(High)', 'metadata': {'Metadata': '', 'creation_time': '2017-05-31T04:04:38.000000Z', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 189, 'metadata': {'Metadata': '', 'creation_time': '2017-05-31T04:04:38.000000Z', 'handler_name': 'SoundHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 248.02, 'bitrate': 425, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(High)', 'video_size': [1280, 720], 'video_bitrate': 233, 'video_fps': 30.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 189, 'video_duration': 248.02, 'video_n_frames': 7440}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\12-Create_A_Blog_Title_Image_From_Sketch.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'isomiso2avc1mp41mp42', 'creation_time': '2017-05-30T05:34:59.000000Z', 'encoder': 'Lavf53.32.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 648, 'fps': 30.0, 'codec_name': 'h264', 'profile': '(High)', 'metadata': {'Metadata': '', 'creation_time': '2017-05-30T05:34:59.000000Z', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 189, 'metadata': {'Metadata': '', 'creation_time': '2017-05-30T05:34:59.000000Z', 'handler_name': 'SoundHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 85.31, 'bitrate': 839, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(High)', 'video_size': [1280, 720], 'video_bitrate': 648, 'video_fps': 30.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 189, 'video_duration': 85.31, 'video_n_frames': 2559}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\13-Section_Intro.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'isomiso2avc1mp41mp42', 'creation_time': '2017-05-30T07:00:29.000000Z', 'encoder': 'Lavf53.32.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 364, 'fps': 30.0, 'codec_name': 'h264', 'profile': '(High)', 'metadata': {'Metadata': '', 'creation_time': '2017-05-30T07:00:29.000000Z', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 189, 'metadata': {'Metadata': '', 'creation_time': '2017-05-30T07:00:29.000000Z', 'handler_name': 'SoundHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 130.45, 'bitrate': 556, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(High)', 'video_size': [1280, 720], 'video_bitrate': 364, 'video_fps': 30.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 189, 'video_duration': 130.45, 'video_n_frames': 3913}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\14-Few_Example_Of_YT_Thumbnail_To_Generate_Ideas.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'isomiso2avc1mp41mp42', 'creation_time': '2017-05-31T02:42:52.000000Z', 'encoder': 'Lavf53.32.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 237, 'fps': 30.0, 'codec_name': 'h264', 'profile': '(High)', 'metadata': {'Metadata': '', 'creation_time': '2017-05-31T02:42:52.000000Z', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 189, 'metadata': {'Metadata': '', 'creation_time': '2017-05-31T02:42:52.000000Z', 'handler_name': 'SoundHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 464.7, 'bitrate': 429, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(High)', 'video_size': [1280, 720], 'video_bitrate': 237, 'video_fps': 30.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 189, 'video_duration': 464.7, 'video_n_frames': 13941}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\15-Create_A_YouTube_Thumbnail_From_Sketch.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'isomiso2avc1mp41mp42', 'creation_time': '2017-05-31T20:13:40.000000Z', 'encoder': 'Lavf53.32.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 874, 'fps': 30.0, 'codec_name': 'h264', 'profile': '(High)', 'metadata': {'Metadata': '', 'creation_time': '2017-05-31T20:13:40.000000Z', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 189, 'metadata': {'Metadata': '', 'creation_time': '2017-05-31T20:13:40.000000Z', 'handler_name': 'SoundHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 64.11, 'bitrate': 1064, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(High)', 'video_size': [1280, 720], 'video_bitrate': 874, 'video_fps': 30.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 189, 'video_duration': 64.11, 'video_n_frames': 1923}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\16-Section_Intro.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'isomiso2avc1mp41mp42', 'creation_time': '2017-06-02T03:41:26.000000Z', 'encoder': 'Lavf53.32.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 427, 'fps': 30.0, 'codec_name': 'h264', 'profile': '(High)', 'metadata': {'Metadata': '', 'creation_time': '2017-06-02T03:41:26.000000Z', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 189, 'metadata': {'Metadata': '', 'creation_time': '2017-06-02T03:41:26.000000Z', 'handler_name': 'SoundHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 1052.74, 'bitrate': 620, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(High)', 'video_size': [1280, 720], 'video_bitrate': 427, 'video_fps': 30.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 189, 'video_duration': 1052.74, 'video_n_frames': 31582}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\17-Create_Self_Hosted_Web_Pages_Form_Sketch.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'isomiso2avc1mp41mp42', 'creation_time': '2017-06-01T22:38:35.000000Z', 'encoder': 'Lavf53.32.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 482, 'fps': 30.0, 'codec_name': 'h264', 'profile': '(High)', 'metadata': {'Metadata': '', 'creation_time': '2017-06-01T22:38:35.000000Z', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 189, 'metadata': {'Metadata': '', 'creation_time': '2017-06-01T22:38:35.000000Z', 'handler_name': 'SoundHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 178.07, 'bitrate': 674, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(High)', 'video_size': [1280, 720], 'video_bitrate': 482, 'video_fps': 30.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 189, 'video_duration': 178.07, 'video_n_frames': 5342}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\18-Section_Intro.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'isomiso2avc1mp41mp42', 'creation_time': '2017-06-02T20:29:04.000000Z', 'encoder': 'Lavf53.32.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 176, 'fps': 30.0, 'codec_name': 'h264', 'profile': '(High)', 'metadata': {'Metadata': '', 'creation_time': '2017-06-02T20:29:04.000000Z', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 189, 'metadata': {'Metadata': '', 'creation_time': '2017-06-02T20:29:04.000000Z', 'handler_name': 'SoundHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 376.04, 'bitrate': 368, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(High)', 'video_size': [1280, 720], 'video_bitrate': 176, 'video_fps': 30.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 189, 'video_duration': 376.04, 'video_n_frames': 11281}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\19-Create_An_Engaging_Video_Using_Adobe_Spark_(Part_1).mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'isomiso2avc1mp41mp42', 'creation_time': '2017-06-03T00:50:56.000000Z', 'encoder': 'Lavf53.32.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 231, 'fps': 30.0, 'codec_name': 'h264', 'profile': '(High)', 'metadata': {'Metadata': '', 'creation_time': '2017-06-03T00:50:56.000000Z', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 189, 'metadata': {'Metadata': '', 'creation_time': '2017-06-03T00:50:56.000000Z', 'handler_name': 'SoundHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 980.25, 'bitrate': 424, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(High)', 'video_size': [1280, 720], 'video_bitrate': 231, 'video_fps': 30.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 189, 'video_duration': 980.25, 'video_n_frames': 29407}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\20-Create_A_Engaging_Video_Using_Adobe_Spark_(Part_2).mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'isomiso2avc1mp41mp42', 'creation_time': '2017-05-07T22:18:24.000000Z', 'encoder': 'Lavf53.32.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 671, 'fps': 30.0, 'codec_name': 'h264', 'profile': '(High)', 'metadata': {'Metadata': '', 'creation_time': '2017-05-07T22:18:24.000000Z', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 189, 'metadata': {'Metadata': '', 'creation_time': '2017-05-07T22:18:24.000000Z', 'handler_name': 'SoundHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 646.27, 'bitrate': 863, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(High)', 'video_size': [1280, 720], 'video_bitrate': 671, 'video_fps': 30.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 189, 'video_duration': 646.27, 'video_n_frames': 19388}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\21-Get_Tons_Of_Royalty_Free_Images.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'isomiso2avc1mp41mp42', 'creation_time': '2017-06-07T19:17:00.000000Z', 'encoder': 'Lavf53.32.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 209, 'fps': 30.0, 'codec_name': 'h264', 'profile': '(High)', 'metadata': {'Metadata': '', 'creation_time': '2017-06-07T19:17:00.000000Z', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 189, 'metadata': {'Metadata': '', 'creation_time': '2017-06-07T19:17:00.000000Z', 'handler_name': 'SoundHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 266.52, 'bitrate': 401, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(High)', 'video_size': [1280, 720], 'video_bitrate': 209, 'video_fps': 30.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 189, 'video_duration': 266.52, 'video_n_frames': 7995}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\22-Get_Thousands_Of_Icons_For_Free.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'isomiso2avc1mp41mp42', 'creation_time': '2017-05-27T07:54:18.000000Z', 'encoder': 'Lavf53.32.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 431, 'fps': 30.0, 'codec_name': 'h264', 'profile': '(High)', 'metadata': {'Metadata': '', 'creation_time': '2017-05-27T07:54:18.000000Z', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 189, 'metadata': {'Metadata': '', 'creation_time': '2017-05-27T07:54:18.000000Z', 'handler_name': 'SoundHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 77.25, 'bitrate': 622, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(High)', 'video_size': [1280, 720], 'video_bitrate': 431, 'video_fps': 30.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 189, 'video_duration': 77.25, 'video_n_frames': 2317}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\23-The_End_Of_Adobe_Spark_Course.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'isomiso2avc1mp41mp42', 'creation_time': '2017-06-03T12:15:28.000000Z', 'encoder': 'Lavf53.32.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 1658, 'fps': 30.0, 'codec_name': 'h264', 'profile': '(High)', 'metadata': {'Metadata': '', 'creation_time': '2017-06-03T12:15:28.000000Z', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 189, 'metadata': {'Metadata': '', 'creation_time': '2017-06-03T12:15:28.000000Z', 'handler_name': 'SoundHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 136.82999999999998, 'bitrate': 1849, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(High)', 'video_size': [1280, 720], 'video_bitrate': 1658, 'video_fps': 30.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 189, 'video_duration': 136.82999999999998, 'video_n_frames': 4104}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\01-Course_Overview.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'isomiso2avc1mp41mp42', 'creation_time': '2017-05-27T15:58:51.000000Z', 'encoder': 'Lavf53.32.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 247, 'fps': 30.0, 'codec_name': 'h264', 'profile': '(High)', 'metadata': {'Metadata': '', 'creation_time': '2017-05-27T15:58:51.000000Z', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 189, 'metadata': {'Metadata': '', 'creation_time': '2017-05-27T15:58:51.000000Z', 'handler_name': 'SoundHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 163.14, 'bitrate': 439, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(High)', 'video_size': [1280, 720], 'video_bitrate': 247, 'video_fps': 30.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 189, 'video_duration': 163.14, 'video_n_frames': 4894}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\02-A_First_Look_At_Adobe_Spark.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'isomiso2avc1mp41mp42', 'creation_time': '2017-05-28T10:29:42.000000Z', 'encoder': 'Lavf53.32.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 196, 'fps': 30.0, 'codec_name': 'h264', 'profile': '(High)', 'metadata': {'Metadata': '', 'creation_time': '2017-05-28T10:29:42.000000Z', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 189, 'metadata': {'Metadata': '', 'creation_time': '2017-05-28T10:29:42.000000Z', 'handler_name': 'SoundHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 123.56, 'bitrate': 389, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(High)', 'video_size': [1280, 720], 'video_bitrate': 196, 'video_fps': 30.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 189, 'video_duration': 123.56, 'video_n_frames': 3706}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\03-Create_Account_In_Adobe_Spark.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'isomiso2avc1mp41mp42', 'creation_time': '2017-05-28T19:45:34.000000Z', 'encoder': 'Lavf53.32.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 218, 'fps': 30.0, 'codec_name': 'h264', 'profile': '(High)', 'metadata': {'Metadata': '', 'creation_time': '2017-05-28T19:45:34.000000Z', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 189, 'metadata': {'Metadata': '', 'creation_time': '2017-05-28T19:45:34.000000Z', 'handler_name': 'SoundHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 253.97, 'bitrate': 411, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(High)', 'video_size': [1280, 720], 'video_bitrate': 218, 'video_fps': 30.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 189, 'video_duration': 253.97, 'video_n_frames': 7619}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\04-Understanding_Adobe_Spark_Dashboard.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'isomiso2avc1mp41mp42', 'creation_time': '2017-05-29T00:03:39.000000Z', 'encoder': 'Lavf53.32.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 657, 'fps': 30.0, 'codec_name': 'h264', 'profile': '(High)', 'metadata': {'Metadata': '', 'creation_time': '2017-05-29T00:03:39.000000Z', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 189, 'metadata': {'Metadata': '', 'creation_time': '2017-05-29T00:03:39.000000Z', 'handler_name': 'SoundHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 468.37, 'bitrate': 850, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(High)', 'video_size': [1280, 720], 'video_bitrate': 657, 'video_fps': 30.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 189, 'video_duration': 468.37, 'video_n_frames': 14051}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\05-Some_Inspiration_For_What_You_Can_Do_With_Adobe_Spark.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# ...
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\21-Get_Tons_Of_Royalty_Free_Images.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'isomiso2avc1mp41mp42', 'creation_time': '2017-06-07T19:17:00.000000Z', 'encoder': 'Lavf53.32.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 209, 'fps': 30.0, 'codec_name': 'h264', 'profile': '(High)', 'metadata': {'Metadata': '', 'creation_time': '2017-06-07T19:17:00.000000Z', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 189, 'metadata': {'Metadata': '', 'creation_time': '2017-06-07T19:17:00.000000Z', 'handler_name': 'SoundHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 266.52, 'bitrate': 401, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(High)', 'video_size': [1280, 720], 'video_bitrate': 209, 'video_fps': 30.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 189, 'video_duration': 266.52, 'video_n_frames': 7995}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\22-Get_Thousands_Of_Icons_For_Free.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'isomiso2avc1mp41mp42', 'creation_time': '2017-05-27T07:54:18.000000Z', 'encoder': 'Lavf53.32.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1280, 720], 'bitrate': 431, 'fps': 30.0, 'codec_name': 'h264', 'profile': '(High)', 'metadata': {'Metadata': '', 'creation_time': '2017-05-27T07:54:18.000000Z', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 189, 'metadata': {'Metadata': '', 'creation_time': '2017-05-27T07:54:18.000000Z', 'handler_name': 'SoundHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 77.25, 'bitrate': 622, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(High)', 'video_size': [1280, 720], 'video_bitrate': 431, 'video_fps': 30.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 189, 'video_duration': 77.25, 'video_n_frames': 2317}
# c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe -i H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\23-The_End_Of_Adobe_Spark_Course.mp4 -loglevel error -f image2pipe -vf scale=1280:720 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# MoviePy - Building video H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\merged_video.mp4.
# MoviePy - Writing audio in merged_videoTEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# MoviePy - Writing video H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\merged_video.mp4
# frame_index:   2%|▏         | 4099/207620 [10:40<8:10:38,  6.91it/s, now=None] c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\moviepy\video\io\ffmpeg_reader.py:178: UserWarning: In file H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\01-Course_Overview.mp4, 2764800 bytes wanted but 0 bytes read at frame index 4098 (out of a total 4104 frames), at time 136.60/136.83 sec. Using the last valid frame instead.
#   warnings.warn(
# frame_index:   2%|▏         | 4100/207620 [10:40<8:11:03,  6.91it/s, now=None]c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\moviepy\video\io\ffmpeg_reader.py:178: UserWarning: In file H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\01-Course_Overview.mp4, 2764800 bytes wanted but 0 bytes read at frame index 4099 (out of a total 4104 frames), at time 136.63/136.83 sec. Using the last valid frame instead.
#   warnings.warn(
# frame_index:   2%|▏         | 4101/207620 [10:40<8:07:15,  6.96it/s, now=None]c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\moviepy\video\io\ffmpeg_reader.py:178: UserWarning: In file H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\01-Course_Overview.mp4, 2764800 bytes wanted but 0 bytes read at frame index 4100 (out of a total 4104 frames), at time 136.67/136.83 sec. Using the last valid frame instead.
#   warnings.warn(
# frame_index:   2%|▏         | 4102/207620 [10:40<8:12:25,  6.89it/s, now=None]c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\moviepy\video\io\ffmpeg_reader.py:178: UserWarning: In file H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\01-Course_Overview.mp4, 2764800 bytes wanted but 0 bytes read at frame index 4101 (out of a total 4104 frames), at time 136.70/136.83 sec. Using the last valid frame instead.
#   warnings.warn(
# frame_index:   2%|▏         | 4103/207620 [10:40<8:03:47,  7.01it/s, now=None]c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\moviepy\video\io\ffmpeg_reader.py:178: UserWarning: In file H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\01-Course_Overview.mp4, 2764800 bytes wanted but 0 bytes read at frame index 4102 (out of a total 4104 frames), at time 136.73/136.83 sec. Using the last valid frame instead.
#   warnings.warn(
# frame_index:   2%|▏         | 4104/207620 [10:40<8:08:21,  6.95it/s, now=None]c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\moviepy\video\io\ffmpeg_reader.py:178: UserWarning: In file H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\01-Course_Overview.mp4, 2764800 bytes wanted but 0 bytes read at frame index 4103 (out of a total 4104 frames), at time 136.77/136.83 sec. Using the last valid frame instead.
#   warnings.warn(
# frame_index:   2%|▏         | 4105/207620 [10:41<8:00:25,  7.06it/s, now=None]c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\moviepy\video\io\ffmpeg_reader.py:178: UserWarning: In file H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\01-Course_Overview.mp4, 2764800 bytes wanted but 0 bytes read at frame index 4104 (out of a total 4104 frames), at time 136.80/136.83 sec. Using the last valid frame instead.
#   warnings.warn(
# frame_index:   4%|▍         | 8993/207620 [22:37<8:05:25,  6.82it/s, now=None]c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\moviepy\video\io\ffmpeg_reader.py:178: UserWarning: In file H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\02-A_First_Look_At_Adobe_Spark.mp4, 2764800 bytes wanted but 0 bytes read at frame index 4887 (out of a total 4894 frames), at time 162.90/163.14 sec. Using the last valid frame instead.
#   warnings.warn(
# frame_index:   4%|▍         | 8994/207620 [22:37<7:50:49,  7.03it/s, now=None]c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\moviepy\video\io\ffmpeg_reader.py:178: UserWarning: In file H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\02-A_First_Look_At_Adobe_Spark.mp4, 2764800 bytes wanted but 0 bytes read at frame index 4888 (out of a total 4894 frames), at time 162.93/163.14 sec. Using the last valid frame instead.
#   warnings.warn(
# frame_index:   4%|▍         | 8995/207620 [22:37<7:57:35,  6.93it/s, now=None]c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\moviepy\video\io\ffmpeg_reader.py:178: UserWarning: In file H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\02-A_First_Look_At_Adobe_Spark.mp4, 2764800 bytes wanted but 0 bytes read at frame index 4889 (out of a total 4894 frames), at time 162.97/163.14 sec. Using the last valid frame instead.
#   warnings.warn(
# frame_index:   4%|▍         | 8996/207620 [22:37<7:53:19,  6.99it/s, now=None]c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\moviepy\video\io\ffmpeg_reader.py:178: UserWarning: In file H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\02-A_First_Look_At_Adobe_Spark.mp4, 2764800 bytes wanted but 0 bytes read at frame index 4890 (out of a total 4894 frames), at time 163.00/163.14 sec. Using the last valid frame instead.
#   warnings.warn(
# frame_index:   4%|▍         | 8997/207620 [22:37<7:43:33,  7.14it/s, now=None]c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\moviepy\video\io\ffmpeg_reader.py:178: UserWarning: In file H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\02-A_First_Look_At_Adobe_Spark.mp4, 2764800 bytes wanted but 0 bytes read at frame index 4891 (out of a total 4894 frames), at time 163.03/163.14 sec. Using the last valid frame instead.
#   warnings.warn(
# frame_index:   4%|▍         | 8998/207620 [22:37<7:38:29,  7.22it/s, now=None]c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\moviepy\video\io\ffmpeg_reader.py:178: UserWarning: In file H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\02-A_First_Look_At_Adobe_Spark.mp4, 2764800 bytes wanted but 0 bytes read at frame index 4892 (out of a total 4894 frames), at time 163.07/163.14 sec. Using the last valid frame instead.
#   warnings.warn(
# frame_index:   4%|▍         | 8999/207620 [22:38<7:33:57,  7.29it/s, now=None]c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\moviepy\video\io\ffmpeg_reader.py:178: UserWarning: In file H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\02-A_First_Look_At_Adobe_Spark.mp4, 2764800 bytes wanted but 0 bytes read at frame index 4893 (out of a total 4894 frames), at time 163.10/163.14 sec. Using the last valid frame instead.
#   warnings.warn(
# frame_index:   4%|▍         | 9000/207620 [22:38<7:27:43,  7.39it/s, now=None]c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\moviepy\video\io\ffmpeg_reader.py:178: UserWarning: In file H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\02-A_First_Look_At_Adobe_Spark.mp4, 2764800 bytes wanted but 0 bytes read at frame index 4894 (out of a total 4894 frames), at time 163.13/163.14 sec. Using the last valid frame instead.
#   warnings.warn(
# frame_index:   6%|▌         | 12701/207620 [32:16<7:54:42,  6.84it/s, now=None] c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\moviepy\video\io\ffmpeg_reader.py:178: UserWarning: In file H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\03-Create_Account_In_Adobe_Spark.mp4, 2764800 bytes wanted but 0 bytes read at frame index 3700 (out of a total 3706 frames), at time 123.33/123.56 sec. Using the last valid frame instead.
#   warnings.warn(
# frame_index:   6%|▌         | 12702/207620 [32:16<7:49:58,  6.91it/s, now=None]c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\moviepy\video\io\ffmpeg_reader.py:178: UserWarning: In file H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\03-Create_Account_In_Adobe_Spark.mp4, 2764800 bytes wanted but 0 bytes read at frame index 3701 (out of a total 3706 frames), at time 123.37/123.56 sec. Using the last valid frame instead.
#   warnings.warn(
# frame_index:   6%|▌         | 12703/207620 [32:16<7:35:28,  7.13it/s, now=None]c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\moviepy\video\io\ffmpeg_reader.py:178: UserWarning: In file H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\03-Create_Account_In_Adobe_Spark.mp4, 2764800 bytes wanted but 0 bytes read at frame index 3702 (out of a total 3706 frames), at time 123.40/123.56 sec. Using the last valid frame instead.
#   warnings.warn(
# frame_index:   6%|▌         | 12704/207620 [32:16<7:25:20,  7.29it/s, now=None]c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\moviepy\video\io\ffmpeg_reader.py:178: UserWarning: In file H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\03-Create_Account_In_Adobe_Spark.mp4, 2764800 bytes wanted but 0 bytes read at frame index 3703 (out of a total 3706 frames), at time 123.43/123.56 sec. Using the last valid frame instead.
#   warnings.warn(
# frame_index:   6%|▌         | 12705/207620 [32:16<7:20:12,  7.38it/s, now=None]c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\moviepy\video\io\ffmpeg_reader.py:178: UserWarning: In file H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\03-Create_Account_In_Adobe_Spark.mp4, 2764800 bytes wanted but 0 bytes read at frame index 3704 (out of a total 3706 frames), at time 123.47/123.56 sec. Using the last valid frame instead.
#   warnings.warn(
# frame_index:   6%|▌         | 12706/207620 [32:16<7:28:05,  7.25it/s, now=None]c:\Users\Omar Essam2\AppData\Local\Programs\Python\Python313\Lib\site-packages\moviepy\video\io\ffmpeg_reader.py:178: UserWarning: In file H:\Projects Control (PC)\10 Backup\05 Tutorials\Adobe\Spark\Udemy\Create Amazing Images Videos And Web Stories\03-Create_Account_In_Adobe_Spark.mp4, 2764800 bytes wanted but 0 bytes read at frame index 3705 (out of a total 3706 frames), at time 123.50/123.56 sec. Using the last valid frame instead.
#   warnings.warn(
# frame_index:   9%|▉         | 18892/207620 [47:22<8:21:47,  6.27it/s, now=None]
