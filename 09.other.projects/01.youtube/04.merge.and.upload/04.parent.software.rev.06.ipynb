# %%
#!/usr/bin/env python3
import os
import glob
import json
import time
import shutil
import logging
import re
from datetime import datetime
import subprocess
from pathlib import Path
from typing import List, Dict, Optional, Tuple
import ffmpeg
import tkinter as tk
from tkinter import ttk, messagebox
import ssl
import httplib2
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload
from googleapiclient.errors import HttpError

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(message)s',
    datefmt='%H:%M:%S',
    handlers=[
        logging.FileHandler('video_processing.log', encoding='utf-8'),
        logging.StreamHandler()
    ]
)

TOKEN_FILE = "token.json"
SCOPES = ["https://www.googleapis.com/auth/youtube.upload"]

class ProgressWindow:
    def __init__(self, title="Progress", parent=None):
        self.root = tk.Toplevel(parent) if parent else tk.Tk()
        self.root.title(title)
        self.root.geometry("600x200")
        
        # Center the window
        self.root.update_idletasks()
        width = self.root.winfo_width()
        height = self.root.winfo_height()
        x = (self.root.winfo_screenwidth() // 2) - (width // 2)
        y = (self.root.winfo_screenheight() // 2) - (height // 2)
        self.root.geometry(f'+{x}+{y}')
        
        # Make window stay on top
        self.root.attributes('-topmost', True)
        
        # Create main frame
        main_frame = ttk.Frame(self.root, padding="10")
        main_frame.pack(fill=tk.BOTH, expand=True)
        
        # Status label
        self.status_var = tk.StringVar(value="Initializing...")
        self.status_label = ttk.Label(main_frame, textvariable=self.status_var)
        self.status_label.pack(pady=(0, 5))
        
        # Progress bar
        self.progress_var = tk.DoubleVar(value=0)
        self.progress_bar = ttk.Progressbar(
            main_frame, 
            variable=self.progress_var,
            maximum=100,
            length=500
        )
        self.progress_bar.pack(pady=5)
        
        # Details frame
        details_frame = ttk.LabelFrame(main_frame, text="Details", padding="5")
        details_frame.pack(fill=tk.X, pady=5)
        
        # Time info
        time_frame = ttk.Frame(details_frame)
        time_frame.pack(fill=tk.X, pady=2)
        
        self.elapsed_var = tk.StringVar(value="Elapsed: 0:00:00")
        self.remaining_var = tk.StringVar(value="Remaining: --:--:--")
        
        ttk.Label(time_frame, textvariable=self.elapsed_var).pack(side=tk.LEFT, padx=5)
        ttk.Label(time_frame, textvariable=self.remaining_var).pack(side=tk.RIGHT, padx=5)
        
        # Stats frame
        stats_frame = ttk.Frame(details_frame)
        stats_frame.pack(fill=tk.X, pady=2)
        
        self.speed_var = tk.StringVar(value="Speed: --")
        self.size_var = tk.StringVar(value="Size: --")
        
        ttk.Label(stats_frame, textvariable=self.speed_var).pack(side=tk.LEFT, padx=5)
        ttk.Label(stats_frame, textvariable=self.size_var).pack(side=tk.RIGHT, padx=5)
        
        self.start_time = time.time()
        self.root.protocol("WM_DELETE_WINDOW", self.on_closing)
        self.allow_close = False

    def on_closing(self):
        if self.allow_close:
            self.root.destroy()

    def update_progress(self, current_duration: float, total_duration: float, 
                       speed: str = "", size: str = "", status: str = None):
        """Update progress bar and stats."""
        if status:
            self.status_var.set(status)
        
        # Update progress bar
        progress = (current_duration / total_duration * 100) if total_duration > 0 else 0
        self.progress_var.set(progress)
        
        # Update elapsed time
        elapsed = time.time() - self.start_time
        elapsed_str = time.strftime('%H:%M:%S', time.gmtime(elapsed))
        self.elapsed_var.set(f"Elapsed: {elapsed_str}")
        
        # Update estimated remaining time
        if progress > 0:
            total_estimated = elapsed / (progress / 100)
            remaining = total_estimated - elapsed
            remaining_str = time.strftime('%H:%M:%S', time.gmtime(remaining))
            self.remaining_var.set(f"Remaining: {remaining_str}")
        
        # Update speed and size
        if speed:
            self.speed_var.set(f"Speed: {speed}")
        if size:
            self.size_var.set(f"Size: {size}")
        
        # Update the window
        self.root.update()

    def close(self):
        """Allow and perform window close."""
        self.allow_close = True
        self.root.destroy()

def get_folder_path_gui() -> str:
    """Create a Tkinter window to get the folder path."""
    try:
        def on_submit():
            window.quit()

        # Create the main window
        window = tk.Tk()
        window.title("Enter Folder Path")
        window.geometry("800x150")  # Make window wider for long paths
        
        # Create and pack a frame
        frame = ttk.Frame(window, padding="10")
        frame.pack(fill=tk.BOTH, expand=True)
        
        # Create label
        ttk.Label(frame, text="Enter the full path to the tutorials folder:").pack(pady=5)
        
        # Create entry field
        path_var = tk.StringVar()
        entry = ttk.Entry(frame, textvariable=path_var, width=100)  # Make entry field wider
        entry.pack(pady=5, fill=tk.X)
        
        # Create submit button
        ttk.Button(frame, text="Submit", command=on_submit).pack(pady=10)
        
        # Focus on entry field and bind Enter key
        entry.focus()
        window.bind('<Return>', lambda e: on_submit())
        
        # Bring window to front
        window.lift()
        window.attributes('-topmost', True)
        window.attributes('-topmost', False)
        
        # Start the window
        window.mainloop()
        
        # Get the path and destroy the window
        path = path_var.get().strip()
        window.destroy()
        return path
        
    except Exception as e:
        logging.error(f"Error creating GUI window: {str(e)}")
        # Fallback to console input if GUI fails
        return input("Enter folder path (GUI failed): ")

def authenticate_youtube(client_secrets_file: str) -> Optional[object]:
    """Authenticate with YouTube as the very first step."""
    try:
        print("\nChecking YouTube authentication...")
        if not os.path.exists(client_secrets_file):
            print("Error: Client secrets file not found")
            return None
            
        creds = None
        # Check if token file exists
        if os.path.exists(TOKEN_FILE):
            try:
                creds = Credentials.from_authorized_user_file(TOKEN_FILE, SCOPES)
                print("Found existing token")
            except Exception as e:
                print(f"Error loading token: {e}")
                creds = None

        # If token is missing or invalid, refresh or re-authenticate
        if not creds or not creds.valid:
            if creds and creds.expired and creds.refresh_token:
                try:
                    print("Token expired, refreshing...")
                    creds.refresh(Request())
                    print("Token refreshed successfully")
                except Exception as e:
                    print(f"Token refresh failed: {e}")
                    creds = None

            if not creds:
                print("\nOpening browser for YouTube authentication...")
                print("Please select your Google account and grant access...")
                flow = InstalledAppFlow.from_client_secrets_file(client_secrets_file, SCOPES)
                creds = flow.run_local_server(port=0)

                # Save the new token
                with open(TOKEN_FILE, "w") as token:
                    token.write(creds.to_json())
                print("New token saved")

        # Build and return the YouTube service
        youtube = build("youtube", "v3", credentials=creds)
        print("YouTube authentication successful!")
        return youtube
        
    except Exception as e:
        print(f"Authentication error: {e}")
        return None

def get_structured_title(path: str) -> str:
    """Generate a structured title from the path levels after '05 Tutorials'."""
    try:
        parts = Path(path).parts
        # Find the index of "05 Tutorials"
        for i, part in enumerate(parts):
            if part == "05 Tutorials":
                # Take exactly 4 parts after "05 Tutorials"
                relevant_parts = parts[i+1:i+5]  # This will get: Google, Slides, Lynda, Google Slides Essential Training
                # Join parts and ensure total length is under 100 characters
                title = " - ".join(relevant_parts)
                if len(title) > 95:  # Leave some margin for safety
                    # If too long, take first word of each part except the last one
                    shortened_parts = []
                    for j, part in enumerate(relevant_parts):
                        if j < len(relevant_parts) - 1:
                            # For all parts except the last, take just the first word
                            first_word = part.split()[0]
                            shortened_parts.append(first_word)
                        else:
                            # For the last part (course name), keep more detail but limit length
                            last_part = part[:50]  # Limit last part to 50 chars
                            shortened_parts.append(last_part)
                    title = " - ".join(shortened_parts)
                    # If still too long, truncate to 95 chars
                    if len(title) > 95:
                        title = title[:95]
                return title
        return os.path.basename(path)[:95]  # Fallback with length limit
    except Exception as e:
        logging.error(f"Error in get_structured_title: {str(e)}")
        # Return a safe fallback title
        return os.path.basename(path)[:95]

def is_tutorial_folder(path: str) -> bool:
    """
    Check if this is a tutorial folder.
    A tutorial folder is either:
    1. A level 4 folder under '05 Tutorials' (e.g. .../05 Tutorials/Google/Youtube/Lynda/Course Name)
    2. A folder containing video files in a proper course structure
    """
    try:
        parts = Path(path).parts
        
        # First check: Is this a level 4 folder under '05 Tutorials'?
        for i, part in enumerate(parts):
            if part == "05 Tutorials":
                remaining_parts = parts[i+1:]
                if len(remaining_parts) == 4:  # Exactly 4 levels after "05 Tutorials"
                    return True
        
        # Second check: Does this folder contain video files in a course structure?
        # Look for video files in subdirectories that match course patterns
        video_count = 0
        has_numbered_folders = False
        
        for root, dirs, files in os.walk(path):
            # Check if any directory names start with numbers (common in courses)
            if any(re.match(r'^\d+', d) for d in dirs):
                has_numbered_folders = True
            
            # Count video files
            video_count += sum(1 for f in files if f.lower().endswith(('.mp4', '.avi', '.mkv')))
            
            # If we find both numbered folders and videos, it's likely a course
            if has_numbered_folders and video_count > 0:
                return True
            
            # If we find a significant number of videos, it's likely a course
            if video_count >= 5:
                return True
        
        return False
        
    except Exception as e:
        logging.error(f"Error in is_tutorial_folder: {str(e)}")
        return False

def collect_videos(folder_path: str) -> List[Tuple[str, str]]:
    """Collect all videos from folder and subfolders, sorted by folder structure and filename."""
    video_files = []
    try:
        # Walk through all subdirectories
        for root, _, files in os.walk(folder_path):
            # Filter and sort video files
            video_files.extend(
                (os.path.join(root, f), os.path.relpath(os.path.join(root, f), folder_path))
                for f in sorted(files)
                if f.lower().endswith(('.mp4', '.avi', '.mkv'))
            )
        
        # Sort by full path to maintain folder structure order
        return sorted(video_files, key=lambda x: x[0].lower())
    except Exception as e:
        logging.error(f"Error collecting videos: {str(e)}")
        return []

def get_video_duration(video_path: str) -> Optional[float]:
    """Get video duration using ffprobe with better error handling and retries."""
    max_retries = 3
    for attempt in range(max_retries):
        try:
            result = subprocess.run(
                ["ffprobe", "-v", "error", 
                 "-show_entries", "format=duration",
                 "-of", "default=noprint_wrappers=1:nokey=1", 
                 video_path],
                stdout=subprocess.PIPE,
                stderr=subprocess.PIPE,
                text=True,
                check=True,
                timeout=30  # Add timeout
            )
            duration = float(result.stdout.strip())
            return duration
        except subprocess.TimeoutExpired:
            logging.warning(f"Timeout getting duration for {os.path.basename(video_path)}, attempt {attempt + 1}/{max_retries}")
            if attempt == max_retries - 1:
                return None
            time.sleep(2)  # Wait before retry
        except Exception as e:
            logging.warning(f"Could not get duration for {os.path.basename(video_path)}: {str(e)}")
            return None

def generate_timestamps(video_files: List[Tuple[str, str]]) -> str:
    """Generate timestamps for video description with proper duration handling."""
    timestamps = []
    current_time = 0
    
    for full_path, rel_path in video_files:
        duration = get_video_duration(full_path)
        if duration is None:
            logging.warning(f"Skipping timestamp for {rel_path} - could not get duration")
            continue
            
        hours = int(current_time // 3600)
        minutes = int((current_time % 3600) // 60)
        seconds = int(current_time % 60)
        
        timestamp = f"{hours:02d}:{minutes:02d}:{seconds:02d}"
        video_name = os.path.splitext(os.path.basename(rel_path))[0]
        timestamps.append(f"{timestamp} - {video_name}")
        
        current_time += duration
    
    return '\n'.join(timestamps)

def parse_ffmpeg_progress(line: str) -> Dict[str, str]:
    """Parse ffmpeg progress output line."""
    result = {}
    
    # Extract time
    time_match = re.search(r'time=(\d+:\d+:\d+\.\d+)', line)
    if time_match:
        time_str = time_match.group(1)
        h, m, s = time_str.split(':')
        s = float(s)
        result['duration'] = float(h) * 3600 + float(m) * 60 + s
    
    # Extract speed
    speed_match = re.search(r'speed=(\d+\.?\d*x)', line)
    if speed_match:
        result['speed'] = speed_match.group(1)
    
    # Extract size
    size_match = re.search(r'size=\s*(\d+.*?B)', line)
    if size_match:
        result['size'] = size_match.group(1)
    
    return result

def merge_videos(video_files: List[Tuple[str, str]], output_path: str) -> bool:
    """Merge videos using ffmpeg with proper format settings and UI progress bar."""
    progress_window = None
    try:
        # Create file list
        list_path = os.path.join(os.path.dirname(output_path), "file_list.txt")
        with open(list_path, 'w', encoding='utf-8') as f:
            for full_path, _ in video_files:
                # Use escaped paths for ffmpeg
                escaped_path = full_path.replace('\\', '/')
                f.write(f"file '{escaped_path}'\n")
        
        # Calculate expected duration
        total_duration = 0
        logging.info(f"\nAnalyzing {len(video_files)} videos for merge:")
        for i, (full_path, rel_path) in enumerate(video_files, 1):
            duration = get_video_duration(full_path) or 0
            total_duration += duration
            logging.info(f"Video {i}/{len(video_files)}: {rel_path}")

        if total_duration == 0:
            logging.error("Could not calculate total duration of videos")
            return False
            
        logging.info(f"\nTotal expected duration: {total_duration:.2f} seconds")
        
        # Create progress window
        progress_window = ProgressWindow("Merging Videos")
        progress_window.update_progress(0, total_duration, status="Starting merge process...")
        
        # Merge videos with specific format settings
        cmd = [
            "ffmpeg",
            "-f", "concat",
            "-safe", "0",
            "-i", list_path,
            "-c:v", "libx264",     # Use H.264 codec
            "-preset", "fast",      # Faster encoding
            "-crf", "23",          # Good quality/size balance
            "-c:a", "aac",         # AAC audio codec
            "-b:a", "128k",        # Audio bitrate
            "-movflags", "+faststart",  # Web playback optimization
            "-max_muxing_queue_size", "1024",  # Increase queue size
            "-y"                   # Overwrite output file
        ]
        
        # Add output path
        cmd.append(output_path)
        
        # Run ffmpeg with progress monitoring
        process = subprocess.Popen(
            cmd,
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            universal_newlines=True,
            bufsize=1
        )

        # Monitor the encoding progress through stderr
        error_output = []
        while True:
            stderr_line = process.stderr.readline()
            if not stderr_line and process.poll() is not None:
                break
                
            # Store error output
            error_output.append(stderr_line)
                
            # Parse progress information
            if "time=" in stderr_line:
                progress_data = parse_ffmpeg_progress(stderr_line)
                if progress_data:
                    current_duration = progress_data.get('duration', 0)
                    speed = progress_data.get('speed', '')
                    size = progress_data.get('size', '')
                    
                    # Update progress window
                    if progress_window:
                        status = f"Merging videos... ({current_duration:.1f}s / {total_duration:.1f}s)"
                        progress_window.update_progress(
                            current_duration, 
                            total_duration,
                            speed=speed,
                            size=size,
                            status=status
                        )

        # Get the final status
        return_code = process.wait()
        
        if return_code != 0:
            error_msg = '\n'.join(error_output)
            logging.error(f"FFmpeg error: {error_msg}")
            if progress_window:
                progress_window.update_progress(0, total_duration, status="Error in merge process!")
                time.sleep(3)  # Show error briefly
            return False
            
        # Verify output duration
        output_duration = get_video_duration(output_path)
        if output_duration is None:
            logging.error("Could not verify output video duration")
            return False
            
        # Allow 5% tolerance for duration mismatch
        duration_diff = abs(output_duration - total_duration)
        duration_tolerance = total_duration * 0.05  # 5% tolerance
        
        if duration_diff > duration_tolerance:
            logging.error(f"Output duration ({output_duration:.2f}s) doesn't match expected ({total_duration:.2f}s)")
            return False
            
        if progress_window:
            progress_window.update_progress(total_duration, total_duration, status="Merge completed successfully!")
            time.sleep(2)  # Show completion message briefly
            
        logging.info(f"Merge completed successfully! Final video duration: {output_duration:.2f} seconds")
        return True
        
    except Exception as e:
        logging.error(f"Error merging videos: {str(e)}")
        if progress_window:
            progress_window.update_progress(0, total_duration, status=f"Error: {str(e)}")
            time.sleep(3)  # Show error briefly
        return False
    finally:
        if os.path.exists(list_path):
            try:
                os.remove(list_path)
            except:
                pass
        if progress_window:
            progress_window.close()

def upload_to_youtube(youtube, video_path: str, title: str, description: str) -> Optional[Dict]:
    """Upload video to YouTube with improved error handling and retry logic."""
    try:
        # Ensure title is not empty and within limits
        if not title or len(title) > 100:
            title = title[:95] if title else "Untitled Video"
        
        logging.info(f"Starting upload: {title}")
        
        body = {
            "snippet": {
                "title": title,
                "description": description,
                "categoryId": "27",  # Education category
                "tags": ["tutorial", "education"]
            },
            "status": {
                "privacyStatus": "unlisted",
                "selfDeclaredMadeForKids": False
            }
        }

        # Create insert request
        insert_request = youtube.videos().insert(
            part=",".join(body.keys()),
            body=body,
            media_body=MediaFileUpload(
                video_path, 
                chunksize=1024*1024*8,  # 8MB chunks for better reliability
                resumable=True
            )
        )

        response = None
        retries = 3
        chunk_retries = 5  # Number of retries per chunk
        
        while response is None and retries > 0:
            try:
                chunk_retry_count = chunk_retries
                while chunk_retry_count > 0:
                    try:
                        status, response = insert_request.next_chunk()
                        if response:
                            logging.info("Upload completed successfully")
                            return response
                        elif status:
                            logging.info(f"Upload progress: {int(status.progress() * 100)}%")
                        break  # Successful chunk upload, continue to next chunk
                    except (ConnectionError, httplib2.HttpLib2Error) as chunk_error:
                        chunk_retry_count -= 1
                        if chunk_retry_count == 0:
                            raise  # Re-raise if we're out of chunk retries
                        logging.warning(f"Chunk upload failed, waiting 10 seconds before retry... ({str(chunk_error)})")
                        time.sleep(10)  # Longer wait between chunk retries
                
            except Exception as e:
                retries -= 1
                if retries == 0:
                    raise
                logging.warning(f"Upload attempt failed, waiting 30 seconds before retry... ({str(e)})")
                time.sleep(30)  # Much longer wait between full upload retries

    except Exception as e:
        logging.error(f"Error uploading to YouTube: {str(e)}")
        return None

def cleanup_and_save_link(folder_path: str, video_id: str, title: str):
    """Save YouTube link and clean up files."""
    link_file = os.path.join(folder_path, "youtube link.txt")
    with open(link_file, 'w') as f:
        f.write(f"Title: {title}\n")
        f.write(f"URL: https://www.youtube.com/watch?v={video_id}\n")
        f.write(f"Uploaded: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

def delete_video_folders(tutorial_path: str) -> bool:
    """Delete all subfolders containing videos after successful upload."""
    try:
        deleted_folders = 0
        # Walk through all subfolders
        for root, dirs, files in os.walk(tutorial_path, topdown=False):
            # Skip the tutorial root folder itself
            if root == tutorial_path:
                continue
                
            # Check if this is a folder containing videos
            has_videos = any(f.lower().endswith(('.mp4', '.avi', '.mkv')) for f in files)
            if has_videos:
                try:
                    shutil.rmtree(root)
                    deleted_folders += 1
                    logging.info(f"Deleted folder: {root}")
                except Exception as e:
                    logging.error(f"Failed to delete folder {root}: {str(e)}")
                    return False
        
        logging.info(f"Deleted {deleted_folders} folders containing videos")
        return True
    except Exception as e:
        logging.error(f"Error deleting video folders: {str(e)}")
        return False

def shorten_folder_name(folder_name: str) -> str:
    """Create a shorter version of the folder name that's still meaningful."""
    # Remove special characters and spaces
    cleaned = re.sub(r'[^\w\s-]', '', folder_name)
    # Replace spaces with underscores
    cleaned = cleaned.replace(' ', '_')
    # Take first word of each segment
    words = [part.split('_')[0] for part in cleaned.split('-')]
    # Join with underscores and limit to 50 characters
    shortened = '_'.join(words)[:50]
    return shortened

def create_temp_folder_with_videos(original_path: str) -> Tuple[Optional[str], Optional[str]]:
    """
    Creates a temporary folder with a shorter name and copies videos there.
    Returns tuple of (temp_folder_path, original_folder_name) or (None, None) on failure.
    """
    try:
        # Get original folder name and create shortened version
        original_folder_name = os.path.basename(original_path)
        short_name = shorten_folder_name(original_folder_name)
        
        # Create temp folder in parent directory
        parent_dir = os.path.dirname(original_path)
        temp_folder = os.path.join(parent_dir, f"temp_{short_name}")
        
        # If temp folder already exists, delete it
        if os.path.exists(temp_folder):
            shutil.rmtree(temp_folder)
        
        # Create new temp folder and copy structure
        os.makedirs(temp_folder)
        
        # Copy all video files maintaining relative paths
        for root, _, files in os.walk(original_path):
            for file in files:
                if file.lower().endswith(('.mp4', '.avi', '.mkv')):
                    # Get relative path
                    rel_path = os.path.relpath(root, original_path)
                    # Create corresponding folder in temp directory
                    temp_subdir = os.path.join(temp_folder, rel_path)
                    os.makedirs(temp_subdir, exist_ok=True)
                    # Copy file
                    src_file = os.path.join(root, file)
                    dst_file = os.path.join(temp_subdir, file)
                    shutil.copy2(src_file, dst_file)
        
        return temp_folder, original_folder_name
    except Exception as e:
        logging.error(f"Error creating temporary folder: {str(e)}")
        return None, None

def cleanup_temp_folder(temp_folder: str):
    """Clean up the temporary folder."""
    try:
        if os.path.exists(temp_folder):
            shutil.rmtree(temp_folder)
            logging.info(f"Cleaned up temporary folder: {temp_folder}")
    except Exception as e:
        logging.warning(f"Failed to clean up temporary folder: {str(e)}")

def process_tutorial_folder(tutorial_path: str, youtube: object):
    """Process a single tutorial folder containing videos."""
    merged_path = None
    temp_folder = None
    try:
        logging.info(f"\nProcessing tutorial folder: {tutorial_path}")
        
        # Check if this folder has already been processed
        link_file = os.path.join(tutorial_path, "youtube link.txt")
        if os.path.exists(link_file):
            logging.info(f"Folder already processed (found youtube link.txt). Skipping: {tutorial_path}")
            return
            
        # Verify this is a level 4 tutorial folder
        if not is_tutorial_folder(tutorial_path):
            logging.error(f"Not a tutorial folder (level 4): {tutorial_path}")
            return
        
        # Create temporary folder with shorter path if needed
        original_folder_name = os.path.basename(tutorial_path)
        if len(tutorial_path) > 200:  # Path is too long
            temp_folder, original_folder_name = create_temp_folder_with_videos(tutorial_path)
            if not temp_folder:
                logging.error("Failed to create temporary folder")
                return
            working_path = temp_folder
        else:
            working_path = tutorial_path
        
        # Get videos from working path
        video_files = collect_videos(working_path)
        if not video_files:
            logging.error(f"No video files found in {working_path}")
            return
            
        logging.info(f"Found {len(video_files)} videos:")
        for _, rel_path in video_files:
            logging.info(f"  - {rel_path}")
        
        # Get structured title using original folder name
        title = get_structured_title(tutorial_path)
        logging.info(f"Generated title: {title}")
        
        # Create merged file in the working folder
        merged_filename = f"{shorten_folder_name(original_folder_name)}_merged.mp4"
        merged_path = os.path.join(working_path, merged_filename)
        
        logging.info("Starting video merge...")
        if not merge_videos(video_files, merged_path):
            logging.error("Failed to merge videos")
            return
            
        logging.info("Videos merged successfully")
        
        # Generate timestamps
        timestamps = generate_timestamps(video_files)
        description = "Tutorial Contents:\n\n" + timestamps
        
        # Upload with retries
        max_upload_attempts = 3
        upload_response = None
        
        for attempt in range(max_upload_attempts):
            try:
                logging.info(f"Upload attempt {attempt + 1}/{max_upload_attempts}")
                upload_response = upload_to_youtube(youtube, merged_path, title, description)
                if upload_response:
                    break
                time.sleep(30)
            except Exception as e:
                logging.error(f"Upload attempt {attempt + 1} failed: {str(e)}")
                if attempt < max_upload_attempts - 1:
                    logging.info("Waiting 60 seconds before next attempt...")
                    time.sleep(60)
                continue
        
        if upload_response and upload_response.get('id'):
            video_id = upload_response['id']
            logging.info(f"Upload successful! Video ID: {video_id}")
            
            # Save link file in the original tutorial folder
            cleanup_and_save_link(tutorial_path, video_id, title)
            logging.info(f"Video URL: https://www.youtube.com/watch?v={video_id}")
            
            # Only proceed with cleanup if we have a valid video ID and link file
            link_file = os.path.join(tutorial_path, "youtube link.txt")
            if os.path.exists(link_file):
                # Delete all folders containing videos first
                if delete_video_folders(tutorial_path):
                    logging.info("Successfully deleted all video folders")
                else:
                    logging.error("Failed to delete some video folders")
                    
                # Clean up merged video file
                try:
                    os.remove(merged_path)
                    logging.info(f"Cleaned up merged video file: {merged_path}")
                except Exception as e:
                    logging.warning(f"Could not clean up merged video: {str(e)}")
            else:
                logging.warning("Link file not created. Skipping cleanup to be safe.")
        else:
            logging.error("Upload failed after all attempts. Keeping files for retry.")
            
    except Exception as e:
        logging.error(f"Error processing tutorial folder: {str(e)}")
    finally:
        # Clean up temporary folder if it exists
        if temp_folder:
            cleanup_temp_folder(temp_folder)

def find_tutorial_folders(parent_path: str) -> List[str]:
    """Find all tutorial folders under the given parent path."""
    tutorial_folders = []
    try:
        logging.info(f"\nScanning for tutorial folders in: {parent_path}")
        
        # First, look for direct tutorial folders (level 4)
        if is_tutorial_folder(parent_path):
            # Check if this folder has videos
            has_videos = False
            for root, _, files in os.walk(parent_path):
                if any(f.lower().endswith(('.mp4', '.avi', '.mkv')) for f in files):
                    has_videos = True
                    break
            if has_videos:
                tutorial_folders.append(parent_path)
                logging.info(f"Found tutorial folder: {parent_path}")
        
        # Then look for subfolders that might be tutorial folders
        for root, dirs, _ in os.walk(parent_path):
            for dir_name in dirs:
                full_path = os.path.join(root, dir_name)
                
                # Skip if already processed
                if os.path.exists(os.path.join(full_path, "youtube link.txt")):
                    logging.info(f"Skipping already processed folder: {full_path}")
                    continue
                
                # Check if this is a tutorial folder
                if is_tutorial_folder(full_path):
                    # Check if this folder has videos
                    has_videos = False
                    for _, _, files in os.walk(full_path):
                        if any(f.lower().endswith(('.mp4', '.avi', '.mkv')) for f in files):
                            has_videos = True
                            break
                    
                    if has_videos:
                        tutorial_folders.append(full_path)
                        logging.info(f"Found tutorial folder: {full_path}")
                    else:
                        logging.info(f"Skipping folder with no videos: {full_path}")
        
        # Sort folders by path for consistent processing order
        tutorial_folders.sort()
        
        if tutorial_folders:
            logging.info(f"\nFound {len(tutorial_folders)} tutorial folders to process:")
            for folder in tutorial_folders:
                logging.info(f"  - {folder}")
        else:
            logging.warning("No tutorial folders with videos found")
            
        return tutorial_folders
        
    except Exception as e:
        logging.error(f"Error finding tutorial folders: {str(e)}")
        return []

def process_folder(parent_path: str, youtube: object):
    """Process all tutorial folders under the given parent path."""
    try:
        # Find all tutorial folders
        tutorial_folders = find_tutorial_folders(parent_path)
        
        if not tutorial_folders:
            logging.error("No tutorial folders with videos found")
            return
        
        # Process each tutorial folder
        total_folders = len(tutorial_folders)
        for i, tutorial_folder in enumerate(tutorial_folders, 1):
            logging.info(f"\nProcessing tutorial {i}/{total_folders}: {tutorial_folder}")
            
            # Check if already processed
            if os.path.exists(os.path.join(tutorial_folder, "youtube link.txt")):
                logging.info("Folder already processed (found youtube link.txt). Skipping.")
                continue
                
            try:
                process_tutorial_folder(tutorial_folder, youtube)
            except Exception as e:
                logging.error(f"Error processing tutorial folder {tutorial_folder}: {str(e)}")
                continue
            
    except Exception as e:
        logging.error(f"Error in process_folder: {str(e)}")

def get_script_directory():
    """Get the directory containing the script, works in both .py and .ipynb"""
    try:
        # For .py files
        return os.path.dirname(os.path.abspath(__file__))
    except NameError:
        # For Jupyter notebooks
        try:
            import nbformat
            from notebook import notebookapp
            import jupyter_client
            
            # Try to get the current notebook's path
            connection_file = jupyter_client.find_connection_file()
            kernel_id = os.path.basename(connection_file).split('-', 1)[1].split('.')[0]
            
            for srv in notebookapp.list_running_servers():
                for note in srv['notebook_dir']:
                    if kernel_id in note:
                        return os.path.dirname(note['path'])
                        
        except:
            # Fallback: Look in current working directory
            return os.getcwd()

def find_client_secrets():
    """Find client_secret.json in various possible locations"""
    possible_locations = [
        # Current directory
        os.path.join(os.getcwd(), "client_secret.json"),
        # Script directory (for .py files)
        os.path.join(get_script_directory(), "client_secret.json"),
        # One level up
        os.path.join(os.path.dirname(os.getcwd()), "client_secret.json"),
        # In 04.merge.and.upload directory
        os.path.join(os.getcwd(), "04.merge.and.upload", "client_secret.json"),
    ]
    
    for location in possible_locations:
        if os.path.exists(location):
            print(f"Found client_secret.json at: {location}")
            return location
            
    print("Searched in the following locations:")
    for location in possible_locations:
        print(f"- {location}")
    return None

def main():
    try:
        print("\n=== Starting YouTube Video Processor ===")
        
        # Find client secrets file
        client_secrets_file = find_client_secrets()
        if not client_secrets_file:
            print("Error: client_secret.json not found in any expected location")
            return
            
        # Authenticate with YouTube as the very first step
        youtube = authenticate_youtube(client_secrets_file)
        if not youtube:
            print("Failed to authenticate with YouTube. Please try again.")
            return
            
        # Now get folder path using GUI
        print("\nOpening folder selection window...")
        folder_path = get_folder_path_gui()
        if not folder_path:
            print("No path entered")
            return
            
        if not os.path.exists(folder_path):
            print("Path does not exist")
            return
            
        # Process folders with the authenticated service
        print(f"\nStarting to process folder: {folder_path}")
        process_folder(folder_path, youtube)
        
    except Exception as e:
        print(f"Error in main: {str(e)}")
        logging.error(f"Error in main: {str(e)}")
        import traceback
        traceback.print_exc()

if __name__ == "__main__":
    main()
# Out:
# === Starting YouTube Video Processor ===
# Found client_secret.json at: d:\OneDrive\OneDrive - Rowad Modern Engineering\x004 Data Science\03.rme.db\00.repo\rme.db\09.other.projects\01.youtube\04.merge.and.upload\client_secret.json
#
# Checking YouTube authentication...
# Found existing token
# Token expired, refreshing...
# 20:58:47 - file_cache is only supported with oauth2client<4.0.0
# Token refreshed successfully
# YouTube authentication successful!
#
# Opening folder selection window...
# 20:58:52 - Scanning for tutorial folders in: H:\Projects Control (PC)\10 Backup\05 Tutorials\Google\Youtube
# Starting to process folder: H:\Projects Control (PC)\10 Backup\05 Tutorials\Google\Youtube
# 20:58:52 - Found 7 tutorial folders
# 20:58:52 -
# Processing tutorial: H:\Projects Control (PC)\10 Backup\05 Tutorials\Google\Youtube\Lynda\Creating And Managing A YouTube Channel
# 20:58:52 -
# Processing tutorial folder: H:\Projects Control (PC)\10 Backup\05 Tutorials\Google\Youtube\Lynda\Creating And Managing A YouTube Channel
# 20:58:52 - Found 54 videos:
# 20:58:52 -   - 00_Introduction\01_What you'll learn in the course.mp4
# 20:58:52 -   - 00_Introduction\02_About the instructor.mp4
# 20:58:52 -   - 01_An Overview of YouTube Channels\03_What is a brand account.mp4
# 20:58:52 -   - 01_An Overview of YouTube Channels\04_The benefits and drawbacks of setting up a channel.mp4
# 20:58:52 -   - 01_An Overview of YouTube Channels\05_Relevant YouTube trends.mp4
# 20:58:52 -   - 01_An Overview of YouTube Channels\06_An overview of the Creator Studio.mp4
# 20:58:52 -   - 02_Understanding Google IDs\07_The role of a Google ID.mp4
# 20:58:52 -   - 02_Understanding Google IDs\08_The Google+ connection.mp4
# 20:58:52 -   - 02_Understanding Google IDs\09_Working with others on a team.mp4
# 20:58:52 -   - 02_Understanding Google IDs\10_Avoid sharing logins.mp4
# 20:58:52 -   - 02_Understanding Google IDs\11_Managing multiple channels.mp4
# 20:58:52 -   - 02_Understanding Google IDs\12_Connecting other social networks.mp4
# 20:58:52 -   - 03_Creating a New YouTube Channel\13_Channel creation essentials.mp4
# 20:58:52 -   - 03_Creating a New YouTube Channel\14_Required artwork.mp4
# 20:58:52 -   - 03_Creating a New YouTube Channel\15_Updating the About tab.mp4
# 20:58:52 -   - 03_Creating a New YouTube Channel\16_Adjusting discussion and subscription preferences.mp4
# 20:58:52 -   - 03_Creating a New YouTube Channel\17_Uploading a channel trailer.mp4
# 20:58:52 -   - 04_Creating Channel Artwork\18_Designing a channel icons.mp4
# 20:58:52 -   - 04_Creating Channel Artwork\19_Designing a channel art (banner).mp4
# 20:58:52 -   - 04_Creating Channel Artwork\20_Designing a watermark.mp4
# 20:58:52 -   - 04_Creating Channel Artwork\21_Verifying your channel and creating custom URLs.mp4
# 20:58:52 -   - 05_Uploading Video Content\22_Supported video formats.mp4
# 20:58:52 -   - 05_Uploading Video Content\23_Select a video’s privacy setting.mp4
# 20:58:52 -   - 05_Uploading Video Content\24_Populating a video’s basic information.mp4
# 20:58:52 -   - 05_Uploading Video Content\25_Uploading or choosing a custom video thumbnail.mp4
# 20:58:52 -   - 05_Uploading Video Content\26_Configuring advanced settings for a video.mp4
# 20:58:52 -   - 05_Uploading Video Content\27_SEO tips to help a video's discovery.mp4
# 20:58:52 -   - 05_Uploading Video Content\28_Batch uploading videos to YouTube.mp4
# 20:58:52 -   - 05_Uploading Video Content\29_Re-uploading videos limitations.mp4
# 20:58:52 -   - 05_Uploading Video Content\30_Using the video manager to modify a video.mp4
# 20:58:52 -   - 05_Uploading Video Content\31_A brief overview of the YouTube terms of service.mp4
# 20:58:52 -   - 06_Using Playlist,Sections and Navigation\32_Creating a playlist on YouTube.mp4
# 20:58:52 -   - 06_Using Playlist,Sections and Navigation\33_Managing YouTube playlists.mp4
# 20:58:52 -   - 06_Using Playlist,Sections and Navigation\34_Adding sections to your channel.mp4
# 20:58:52 -   - 06_Using Playlist,Sections and Navigation\35_Editing channel navigation.mp4
# 20:58:52 -   - 07_Using YouTube Cards and Captions\36_Using cards to modify a movie.mp4
# 20:58:52 -   - 07_Using YouTube Cards and Captions\37_Controlling automatic captions.mp4
# 20:58:52 -   - 07_Using YouTube Cards and Captions\38_Uploading custom captions.mp4
# 20:58:52 -   - 08_Building a YouTube Community\39_Enable community settings.mp4
# 20:58:52 -   - 08_Building a YouTube Community\40_Modifying channel settings for promotion.mp4
# 20:58:52 -   - 08_Building a YouTube Community\41_Promotion strategies for a YouTube channel.mp4
# 20:58:52 -   - 08_Building a YouTube Community\42_Interacting with your community.mp4
# 20:58:52 -   - 09_The Creator Studio\43_Using and customizing the dashboard.mp4
# 20:58:52 -   - 09_The Creator Studio\44_Adjusting multiple videos in the video manager.mp4
# 20:58:52 -   - 09_The Creator Studio\45_Essential channel controls.mp4
# 20:58:52 -   - 09_The Creator Studio\46_Switching interfaces in Creator Studio.mp4
# 20:58:52 -   - 10_Live Streaming on YouTube\47_Choosing a live stream type.mp4
# 20:58:52 -   - 10_Live Streaming on YouTube\48_Restrictions on live streaming.mp4
# 20:58:52 -   - 10_Live Streaming on YouTube\49_Going live with live events.mp4
# 20:58:52 -   - 10_Live Streaming on YouTube\50_Streaming live on demand.mp4
# 20:58:52 -   - 11_Signing Up for the Partner Program\51_Benefits of the YouTube Partner Program.mp4
# 20:58:52 -   - 11_Signing Up for the Partner Program\52_Signing up for the YouTube Partner Program.mp4
# 20:58:52 -   - 11_Signing Up for the Partner Program\53_Checking your status in the YouTube Partner Program.mp4
# 20:58:52 -   - 12_Conclusion\54_Next steps.mp4
# 20:58:52 - Generated title: Google - Youtube - Lynda - Creating And Managing A YouTube Channel
# 20:58:52 - Starting video merge...
# 20:58:52 -
# Analyzing 54 videos for merge:
# 20:58:53 - Video 1/54: 00_Introduction\01_What you'll learn in the course.mp4
# 20:58:53 - Video 2/54: 00_Introduction\02_About the instructor.mp4
# 20:58:54 - Video 3/54: 01_An Overview of YouTube Channels\03_What is a brand account.mp4
# 20:58:54 - Video 4/54: 01_An Overview of YouTube Channels\04_The benefits and drawbacks of setting up a channel.mp4
# 20:58:54 - Video 5/54: 01_An Overview of YouTube Channels\05_Relevant YouTube trends.mp4
# 20:58:55 - Video 6/54: 01_An Overview of YouTube Channels\06_An overview of the Creator Studio.mp4
# 20:58:55 - Video 7/54: 02_Understanding Google IDs\07_The role of a Google ID.mp4
# 20:58:55 - Video 8/54: 02_Understanding Google IDs\08_The Google+ connection.mp4
# 20:58:55 - Video 9/54: 02_Understanding Google IDs\09_Working with others on a team.mp4
# 20:58:56 - Video 10/54: 02_Understanding Google IDs\10_Avoid sharing logins.mp4
# 20:58:56 - Video 11/54: 02_Understanding Google IDs\11_Managing multiple channels.mp4
# 20:58:56 - Video 12/54: 02_Understanding Google IDs\12_Connecting other social networks.mp4
# 20:58:57 - Video 13/54: 03_Creating a New YouTube Channel\13_Channel creation essentials.mp4
# 20:58:57 - Video 14/54: 03_Creating a New YouTube Channel\14_Required artwork.mp4
# 20:58:57 - Video 15/54: 03_Creating a New YouTube Channel\15_Updating the About tab.mp4
# 20:58:58 - Video 16/54: 03_Creating a New YouTube Channel\16_Adjusting discussion and subscription preferences.mp4
# 20:58:58 - Video 17/54: 03_Creating a New YouTube Channel\17_Uploading a channel trailer.mp4
# 20:58:58 - Video 18/54: 04_Creating Channel Artwork\18_Designing a channel icons.mp4
# 20:58:59 - Video 19/54: 04_Creating Channel Artwork\19_Designing a channel art (banner).mp4
# 20:58:59 - Video 20/54: 04_Creating Channel Artwork\20_Designing a watermark.mp4
# 20:58:59 - Video 21/54: 04_Creating Channel Artwork\21_Verifying your channel and creating custom URLs.mp4
# 20:59:00 - Video 22/54: 05_Uploading Video Content\22_Supported video formats.mp4
# 20:59:00 - Video 23/54: 05_Uploading Video Content\23_Select a video’s privacy setting.mp4
# 20:59:00 - Video 24/54: 05_Uploading Video Content\24_Populating a video’s basic information.mp4
# 20:59:01 - Video 25/54: 05_Uploading Video Content\25_Uploading or choosing a custom video thumbnail.mp4
# 20:59:01 - Video 26/54: 05_Uploading Video Content\26_Configuring advanced settings for a video.mp4
# 20:59:01 - Video 27/54: 05_Uploading Video Content\27_SEO tips to help a video's discovery.mp4
# 20:59:01 - Video 28/54: 05_Uploading Video Content\28_Batch uploading videos to YouTube.mp4
# 20:59:02 - Video 29/54: 05_Uploading Video Content\29_Re-uploading videos limitations.mp4
# 20:59:02 - Video 30/54: 05_Uploading Video Content\30_Using the video manager to modify a video.mp4
# 20:59:02 - Video 31/54: 05_Uploading Video Content\31_A brief overview of the YouTube terms of service.mp4
# 20:59:03 - Video 32/54: 06_Using Playlist,Sections and Navigation\32_Creating a playlist on YouTube.mp4
# 20:59:03 - Video 33/54: 06_Using Playlist,Sections and Navigation\33_Managing YouTube playlists.mp4
# 20:59:03 - Video 34/54: 06_Using Playlist,Sections and Navigation\34_Adding sections to your channel.mp4
# 20:59:03 - Video 35/54: 06_Using Playlist,Sections and Navigation\35_Editing channel navigation.mp4
# 20:59:04 - Video 36/54: 07_Using YouTube Cards and Captions\36_Using cards to modify a movie.mp4
# 20:59:04 - Video 37/54: 07_Using YouTube Cards and Captions\37_Controlling automatic captions.mp4
# 20:59:04 - Video 38/54: 07_Using YouTube Cards and Captions\38_Uploading custom captions.mp4
# 20:59:05 - Video 39/54: 08_Building a YouTube Community\39_Enable community settings.mp4
# 20:59:05 - Video 40/54: 08_Building a YouTube Community\40_Modifying channel settings for promotion.mp4
# 20:59:05 - Video 41/54: 08_Building a YouTube Community\41_Promotion strategies for a YouTube channel.mp4
# 20:59:06 - Video 42/54: 08_Building a YouTube Community\42_Interacting with your community.mp4
# 20:59:06 - Video 43/54: 09_The Creator Studio\43_Using and customizing the dashboard.mp4
# 20:59:06 - Video 44/54: 09_The Creator Studio\44_Adjusting multiple videos in the video manager.mp4
# 20:59:06 - Video 45/54: 09_The Creator Studio\45_Essential channel controls.mp4
# 20:59:07 - Video 46/54: 09_The Creator Studio\46_Switching interfaces in Creator Studio.mp4
# 20:59:07 - Video 47/54: 10_Live Streaming on YouTube\47_Choosing a live stream type.mp4
# 20:59:07 - Video 48/54: 10_Live Streaming on YouTube\48_Restrictions on live streaming.mp4
# 20:59:08 - Video 49/54: 10_Live Streaming on YouTube\49_Going live with live events.mp4
# 20:59:08 - Video 50/54: 10_Live Streaming on YouTube\50_Streaming live on demand.mp4
# 20:59:08 - Video 51/54: 11_Signing Up for the Partner Program\51_Benefits of the YouTube Partner Program.mp4
# 20:59:09 - Video 52/54: 11_Signing Up for the Partner Program\52_Signing up for the YouTube Partner Program.mp4
# 20:59:09 - Video 53/54: 11_Signing Up for the Partner Program\53_Checking your status in the YouTube Partner Program.mp4
# 20:59:09 - Video 54/54: 12_Conclusion\54_Next steps.mp4
# 20:59:09 -
# Total expected duration: 15952.93 seconds
# 20:59:10 - FFmpeg error:
# 20:59:13 - Failed to merge videos
# 20:59:13 -
# Processing tutorial: H:\Projects Control (PC)\10 Backup\05 Tutorials\Google\Youtube\Lynda\Marketing And Monetizing on YouTube
# 20:59:13 -
# Processing tutorial folder: H:\Projects Control (PC)\10 Backup\05 Tutorials\Google\Youtube\Lynda\Marketing And Monetizing on YouTube
# 20:59:14 - Found 23 videos:
# 20:59:14 -   - 1.Introduction\01.Welcome.mp4
# 20:59:14 -   - 2.1. Marketing and Monetizing Overview\02.Set goals and expectations for YouTube.mp4
# 20:59:14 -   - 2.1. Marketing and Monetizing Overview\03.Understanding effective content strategies.mp4
# 20:59:14 -   - 3.2. Get Started with YouTube\04.Create a brand account on YouTube.mp4
# 20:59:14 -   - 3.2. Get Started with YouTube\05.Review the YouTube Creator Studio Dashboard.mp4
# 20:59:14 -   - 3.2. Get Started with YouTube\06.Optimize your video before uploading.mp4
# 20:59:14 -   - 3.2. Get Started with YouTube\07.Upload videos to YouTube.mp4
# 20:59:14 -   - 4.3. Customize Your YouTube Channel\08.Brand your channel page.mp4
# 20:59:14 -   - 4.3. Customize Your YouTube Channel\09.Create playlists.mp4
# 20:59:14 -   - 4.3. Customize Your YouTube Channel\10.Customize your channel layout.mp4
# 20:59:14 -   - 5.4. Monetize Your Channel with the YouTube Partner Program\11.Understanding YouTube advertising.mp4
# 20:59:14 -   - 5.4. Monetize Your Channel with the YouTube Partner Program\12.Apply to the YouTube Partner Program.mp4
# 20:59:14 -   - 5.4. Monetize Your Channel with the YouTube Partner Program\13.Additional YouTube monetization options.mp4
# 20:59:14 -   - 6.5. Build an Audience\14.Attract subscribers.mp4
# 20:59:14 -   - 6.5. Build an Audience\15.Work in the YouTube Community section.mp4
# 20:59:14 -   - 6.5. Build an Audience\16.Commenting on YouTube.mp4
# 20:59:14 -   - 7.6. Advanced Video Optimization on YouTube\17.Optimize video for search engines.mp4
# 20:59:14 -   - 7.6. Advanced Video Optimization on YouTube\18.Perform keyword research for SEO.mp4
# 20:59:14 -   - 7.6. Advanced Video Optimization on YouTube\19.Add end screens, cards, and links to videos.mp4
# 20:59:14 -   - 7.6. Advanced Video Optimization on YouTube\20.Secrets to successfully launching a new video.mp4
# 20:59:14 -   - 8.7. Use YouTube Analytics\21.Navigate YouTube analytics.mp4
# 20:59:14 -   - 8.7. Use YouTube Analytics\22.Gauge video success with analytics.mp4
# 20:59:14 -   - 9.Conclusion\23.Next steps.mp4
# 20:59:14 - Generated title: Google - Youtube - Lynda - Marketing And Monetizing on YouTube
# 20:59:14 - Starting video merge...
# 20:59:14 -
# Analyzing 23 videos for merge:
# 20:59:14 - Video 1/23: 1.Introduction\01.Welcome.mp4
# 20:59:14 - Video 2/23: 2.1. Marketing and Monetizing Overview\02.Set goals and expectations for YouTube.mp4
# 20:59:15 - Video 3/23: 2.1. Marketing and Monetizing Overview\03.Understanding effective content strategies.mp4
# 20:59:15 - Video 4/23: 3.2. Get Started with YouTube\04.Create a brand account on YouTube.mp4
# 20:59:15 - Video 5/23: 3.2. Get Started with YouTube\05.Review the YouTube Creator Studio Dashboard.mp4
# 20:59:16 - Video 6/23: 3.2. Get Started with YouTube\06.Optimize your video before uploading.mp4
# 20:59:16 - Video 7/23: 3.2. Get Started with YouTube\07.Upload videos to YouTube.mp4
# 20:59:16 - Video 8/23: 4.3. Customize Your YouTube Channel\08.Brand your channel page.mp4
# 20:59:17 - Video 9/23: 4.3. Customize Your YouTube Channel\09.Create playlists.mp4
# 20:59:17 - Video 10/23: 4.3. Customize Your YouTube Channel\10.Customize your channel layout.mp4
# 20:59:17 - Video 11/23: 5.4. Monetize Your Channel with the YouTube Partner Program\11.Understanding YouTube advertising.mp4
# 20:59:17 - Video 12/23: 5.4. Monetize Your Channel with the YouTube Partner Program\12.Apply to the YouTube Partner Program.mp4
# 20:59:18 - Video 13/23: 5.4. Monetize Your Channel with the YouTube Partner Program\13.Additional YouTube monetization options.mp4
# 20:59:18 - Video 14/23: 6.5. Build an Audience\14.Attract subscribers.mp4
# 20:59:18 - Video 15/23: 6.5. Build an Audience\15.Work in the YouTube Community section.mp4
# 20:59:19 - Video 16/23: 6.5. Build an Audience\16.Commenting on YouTube.mp4
# 20:59:19 - Video 17/23: 7.6. Advanced Video Optimization on YouTube\17.Optimize video for search engines.mp4
# 20:59:19 - Video 18/23: 7.6. Advanced Video Optimization on YouTube\18.Perform keyword research for SEO.mp4
# 20:59:19 - Video 19/23: 7.6. Advanced Video Optimization on YouTube\19.Add end screens, cards, and links to videos.mp4
# 20:59:20 - Video 20/23: 7.6. Advanced Video Optimization on YouTube\20.Secrets to successfully launching a new video.mp4
# 20:59:20 - Video 21/23: 8.7. Use YouTube Analytics\21.Navigate YouTube analytics.mp4
# 20:59:20 - Video 22/23: 8.7. Use YouTube Analytics\22.Gauge video success with analytics.mp4
# 20:59:20 - Video 23/23: 9.Conclusion\23.Next steps.mp4
# 20:59:20 -
# Total expected duration: 6449.43 seconds
# 21:03:46 - FFmpeg error:
# 21:03:49 - Failed to merge videos
# 21:03:49 -
# Processing tutorial: H:\Projects Control (PC)\10 Backup\05 Tutorials\Google\Youtube\Lynda\YouTube Tips Weekly Update 2019.01.18
# 21:03:49 -
# Processing tutorial folder: H:\Projects Control (PC)\10 Backup\05 Tutorials\Google\Youtube\Lynda\YouTube Tips Weekly Update 2019.01.18
# 21:03:49 - Found 9 videos:
# 21:03:49 -   - 01.New This Week\01.01.Use cards effectively.Update 20190118.mp4
# 21:03:49 -   - 02.Introduction\02.02.Tips for enhancing your YouTube channel.Update 20190118.mp4
# 21:03:49 -   - 03.YouTube Tips Weekly\03.03.What makes good content.Update 20190118.mp4
# 21:03:49 -   - 03.YouTube Tips Weekly\03.04.How long should videos be.Update 20190118.mp4
# 21:03:49 -   - 03.YouTube Tips Weekly\03.05.Viral video vs. building an audience.Update 20190118.mp4
# 21:03:49 -   - 03.YouTube Tips Weekly\03.06.How to write a strong title.Update 20190118.mp4
# 21:03:49 -   - 03.YouTube Tips Weekly\03.07.How to write a good description.Update 20190118.mp4
# 21:03:49 -   - 03.YouTube Tips Weekly\03.08.Make the most of tags.Update 20190118.mp4
# 21:03:49 -   - 03.YouTube Tips Weekly\03.09.How to work with end screens.Update 20190118.mp4
# 21:03:49 - Generated title: Google - Youtube - Lynda - YouTube Tips Weekly Update 2019.01.18
# 21:03:49 - Starting video merge...
# 21:03:49 -
# Analyzing 9 videos for merge:
# 21:03:49 - Video 1/9: 01.New This Week\01.01.Use cards effectively.Update 20190118.mp4
# 21:03:50 - Video 2/9: 02.Introduction\02.02.Tips for enhancing your YouTube channel.Update 20190118.mp4
# 21:03:50 - Video 3/9: 03.YouTube Tips Weekly\03.03.What makes good content.Update 20190118.mp4
# 21:03:50 - Video 4/9: 03.YouTube Tips Weekly\03.04.How long should videos be.Update 20190118.mp4
# 21:03:51 - Video 5/9: 03.YouTube Tips Weekly\03.05.Viral video vs. building an audience.Update 20190118.mp4
# 21:03:51 - Video 6/9: 03.YouTube Tips Weekly\03.06.How to write a strong title.Update 20190118.mp4
# 21:03:51 - Video 7/9: 03.YouTube Tips Weekly\03.07.How to write a good description.Update 20190118.mp4
# 21:03:52 - Video 8/9: 03.YouTube Tips Weekly\03.08.Make the most of tags.Update 20190118.mp4
# 21:03:52 - Video 9/9: 03.YouTube Tips Weekly\03.09.How to work with end screens.Update 20190118.mp4
# 21:03:52 -
# Total expected duration: 1877.27 seconds
# 21:06:34 - Merge completed successfully! Final video duration: 1877.27 seconds
# 21:06:34 - Videos merged successfully
# 21:06:35 - Upload attempt 1/3
# 21:06:35 - Starting upload: Google - Youtube - Lynda - YouTube Tips Weekly Update 2019.01.18
# 21:06:49 - Upload progress: 4%
# 21:06:59 - Upload progress: 8%
# 21:07:10 - Upload progress: 12%
# 21:07:18 - Upload progress: 16%
# 21:07:29 - Upload progress: 20%
# 21:07:37 - Upload progress: 24%
# 21:07:46 - Upload progress: 28%
# 21:07:52 - Upload progress: 32%
# 21:07:59 - Upload progress: 36%
# 21:08:05 - Upload progress: 40%
# 21:08:14 - Upload progress: 44%
# 21:08:18 - Upload progress: 48%
# 21:08:24 - Upload progress: 52%
# 21:08:30 - Upload progress: 56%
# 21:08:35 - Upload progress: 60%
# 21:08:42 - Upload progress: 64%
# 21:08:48 - Upload progress: 68%
# 21:08:54 - Upload progress: 72%
# 21:09:00 - Upload progress: 76%
# 21:09:05 - Upload progress: 80%
# 21:09:10 - Upload progress: 84%
# 21:09:17 - Upload progress: 88%
# 21:09:23 - Upload progress: 92%
# 21:09:28 - Upload progress: 96%
# 21:09:34 - Upload completed successfully
# 21:09:34 - Upload successful! Video ID: v9jzamEgVc0
# 21:09:34 - Video URL: https://www.youtube.com/watch?v=v9jzamEgVc0
# 21:09:34 - Deleted folder: H:\Projects Control (PC)\10 Backup\05 Tutorials\Google\Youtube\Lynda\YouTube Tips Weekly Update 2019.01.18\01.New This Week
# 21:09:34 - Deleted folder: H:\Projects Control (PC)\10 Backup\05 Tutorials\Google\Youtube\Lynda\YouTube Tips Weekly Update 2019.01.18\02.Introduction
# 21:09:34 - Deleted folder: H:\Projects Control (PC)\10 Backup\05 Tutorials\Google\Youtube\Lynda\YouTube Tips Weekly Update 2019.01.18\03.YouTube Tips Weekly
# 21:09:34 - Deleted 3 folders containing videos
# 21:09:34 - Successfully deleted all video folders
# 21:09:34 - Cleaned up merged video file: H:\Projects Control (PC)\10 Backup\05 Tutorials\Google\Youtube\Lynda\YouTube Tips Weekly Update 2019.01.18\YouTube_merged.mp4
# 21:09:34 -
# Processing tutorial: H:\Projects Control (PC)\10 Backup\05 Tutorials\Google\Youtube\Other\0 to 10k Subscribers in 12 Months
# 21:09:34 -
# Processing tutorial folder: H:\Projects Control (PC)\10 Backup\05 Tutorials\Google\Youtube\Other\0 to 10k Subscribers in 12 Months
# 21:09:34 - Found 8 videos:
# 21:09:34 -   - 1 – Results You Can Imitate.mp4
# 21:09:34 -   - 2 – My Story, Your Story.mp4
# 21:09:34 -   - 3 – My Google+ Tactics.mp4
# 21:09:34 -   - 4 – My YouTube Tactics.mp4
# 21:09:34 -   - 5 – My Off-YouTube Tactics.mp4
# 21:09:34 -   - Lindsay Weirich.mp4
# 21:09:34 -   - Lisa Lachri.mp4
# 21:09:34 -   - Steve Ramsey.mp4
# 21:09:34 - Generated title: Google - Youtube - Other - 0 to 10k Subscribers in 12 Months
# 21:09:34 - Starting video merge...
# 21:09:34 -
# Analyzing 8 videos for merge:
# 21:09:35 - Video 1/8: 1 – Results You Can Imitate.mp4
# 21:09:35 - Video 2/8: 2 – My Story, Your Story.mp4
# 21:09:35 - Video 3/8: 3 – My Google+ Tactics.mp4
# 21:09:36 - Video 4/8: 4 – My YouTube Tactics.mp4
# 21:09:36 - Video 5/8: 5 – My Off-YouTube Tactics.mp4
# 21:09:36 - Video 6/8: Lindsay Weirich.mp4
# 21:09:37 - Video 7/8: Lisa Lachri.mp4
# 21:09:37 - Video 8/8: Steve Ramsey.mp4
# 21:09:37 -
# Total expected duration: 5388.46 seconds
# 21:18:24 - Output duration (6735.56s) doesn't match expected (5388.46s)
# 21:18:24 - Failed to merge videos
# 21:18:24 -
# Processing tutorial: H:\Projects Control (PC)\10 Backup\05 Tutorials\Google\Youtube\Other\Accelerate Your Channel Growth
# 21:18:24 -
# Processing tutorial folder: H:\Projects Control (PC)\10 Backup\05 Tutorials\Google\Youtube\Other\Accelerate Your Channel Growth
# 21:18:24 - Found 12 videos:
# 21:18:24 -   - 1 – The Real Value of Collaborations.mp4
# 21:18:24 -   - 10 – Interview with Austin Null.mp4
# 21:18:24 -   - 11 – Interview with TheVideoInk.mp4
# 21:18:24 -   - 12 – Interview with NewMediaRockstars.mp4
# 21:18:24 -   - 2 – What To Prepare Before You Make Contact.mp4
# 21:18:24 -   - 3 – How To Find Creators for Collaborations.mp4
# 21:18:24 -   - 4 – The Key to Converting Someone Else’s Audience.mp4
# 21:18:24 -   - 5 – How To Contact a YouTube Influencer.mp4
# 21:18:24 -   - 6 – How To Get an Influencer to Notice You.mp4
# 21:18:24 -   - 7 – How To Get an Influencer to Promote You.mp4
# 21:18:24 -   - 8 – Ideas for Effective Collaborations.mp4
# 21:18:24 -   - 9 – Why Collaborations Matter.mp4
# 21:18:24 - Generated title: Google - Youtube - Other - Accelerate Your Channel Growth
# 21:18:24 - Starting video merge...
# 21:18:24 -
# Analyzing 12 videos for merge:
# 21:18:25 - Video 1/12: 1 – The Real Value of Collaborations.mp4
# 21:18:25 - Video 2/12: 10 – Interview with Austin Null.mp4
# 21:18:26 - Video 3/12: 11 – Interview with TheVideoInk.mp4
# 21:18:26 - Video 4/12: 12 – Interview with NewMediaRockstars.mp4
# 21:18:26 - Video 5/12: 2 – What To Prepare Before You Make Contact.mp4
# 21:18:27 - Video 6/12: 3 – How To Find Creators for Collaborations.mp4
# 21:18:27 - Video 7/12: 4 – The Key to Converting Someone Else’s Audience.mp4
# 21:18:27 - Video 8/12: 5 – How To Contact a YouTube Influencer.mp4
# 21:18:28 - Video 9/12: 6 – How To Get an Influencer to Notice You.mp4
# 21:18:28 - Video 10/12: 7 – How To Get an Influencer to Promote You.mp4
# 21:18:28 - Video 11/12: 8 – Ideas for Effective Collaborations.mp4
# 21:18:29 - Video 12/12: 9 – Why Collaborations Matter.mp4
# 21:18:29 -
# Total expected duration: 6409.91 seconds
# 21:26:14 - Merge completed successfully! Final video duration: 6409.91 seconds
# 21:26:14 - Videos merged successfully
# 21:26:17 - Upload attempt 1/3
# 21:26:17 - Starting upload: Google - Youtube - Other - Accelerate Your Channel Growth
# 21:26:33 - Upload progress: 1%
# 21:26:45 - Upload progress: 3%
# 21:26:54 - Upload progress: 5%
# 21:27:02 - Upload progress: 6%
# 21:27:07 - Upload progress: 8%
# 21:27:21 - Upload progress: 10%
# 21:27:27 - Upload progress: 12%
# 21:27:33 - Upload progress: 13%
# 21:27:39 - Upload progress: 15%
# 21:27:47 - Upload progress: 17%
# 21:27:53 - Upload progress: 19%
# 21:28:00 - Upload progress: 20%
# 21:28:06 - Upload progress: 22%
# 21:28:14 - Upload progress: 24%
# 21:28:21 - Upload progress: 26%
# 21:28:26 - Upload progress: 27%
# 21:28:32 - Upload progress: 29%
# 21:28:37 - Upload progress: 31%
# 21:28:44 - Upload progress: 33%
# 21:28:50 - Upload progress: 34%
# 21:28:56 - Upload progress: 36%
# 21:29:01 - Upload progress: 38%
# 21:29:06 - Upload progress: 40%
# 21:29:12 - Upload progress: 41%
# 21:29:19 - Upload progress: 43%
# 21:29:25 - Upload progress: 45%
# 21:29:31 - Upload progress: 47%
# 21:29:37 - Upload progress: 48%
# 21:29:42 - Upload progress: 50%
# 21:29:50 - Upload progress: 52%
# 21:29:55 - Upload progress: 53%
# 21:30:01 - Upload progress: 55%
# 21:30:07 - Upload progress: 57%
# 21:30:14 - Upload progress: 59%
# 21:30:21 - Upload progress: 60%
# 21:30:28 - Upload progress: 62%
# 21:30:34 - Upload progress: 64%
# 21:30:40 - Upload progress: 66%
# 21:30:46 - Upload progress: 67%
# 21:30:53 - Upload progress: 69%
# 21:30:58 - Upload progress: 71%
# 21:31:03 - Upload progress: 73%
# 21:31:11 - Upload progress: 74%
# 21:31:15 - Upload progress: 76%
# 21:31:20 - Upload progress: 78%
# 21:31:26 - Upload progress: 80%
# 21:31:33 - Upload progress: 81%
# 21:31:39 - Upload progress: 83%
# 21:31:46 - Upload progress: 85%
# 21:31:51 - Upload progress: 87%
# 21:31:57 - Upload progress: 88%
# 21:32:05 - Upload progress: 90%
# 21:32:10 - Upload progress: 92%
# 21:32:15 - Upload progress: 94%
# 21:32:21 - Upload progress: 95%
# 21:32:26 - Upload progress: 97%
# 21:32:33 - Upload progress: 99%
# 21:32:37 - Upload completed successfully
# 21:32:37 - Upload successful! Video ID: DwW4wbJLe1Y
# 21:32:37 - Video URL: https://www.youtube.com/watch?v=DwW4wbJLe1Y
# 21:32:37 - Deleted 0 folders containing videos
# 21:32:37 - Successfully deleted all video folders
# 21:32:37 - Cleaned up merged video file: H:\Projects Control (PC)\10 Backup\05 Tutorials\Google\Youtube\Other\Accelerate Your Channel Growth\Accelerate_merged.mp4
# 21:32:37 -
# Processing tutorial: H:\Projects Control (PC)\10 Backup\05 Tutorials\Google\Youtube\Udemy\The Complete Facebook, Google, YouTube Retargeting Course
# 21:32:37 -
# Processing tutorial folder: H:\Projects Control (PC)\10 Backup\05 Tutorials\Google\Youtube\Udemy\The Complete Facebook, Google, YouTube Retargeting Course
# 21:32:37 - Found 35 videos:
# 21:32:37 -   - Section 1 Overview\001-section1-intro-new.mp4
# 21:32:37 -   - Section 1 Overview\002-section1-What is Retargeting (remarketing).mp4
# 21:32:37 -   - Section 1 Overview\003-section1-why-Retarget-rev.mp4
# 21:32:37 -   - Section 2 Strategy Setup\004-section2-customers.mp4
# 21:32:37 -   - Section 2 Strategy Setup\005-section2-painpoints.mp4
# 21:32:37 -   - Section 2 Strategy Setup\006-section2-solutions.mp4
# 21:32:37 -   - Section 2 Strategy Setup\007-section2-objectives.mp4
# 21:32:37 -   - Section 2 Strategy Setup\008-section2-creatives.mp4
# 21:32:37 -   - Section 3 Facebook\009-section3-intro.mp4
# 21:32:37 -   - Section 3 Facebook\010-section3-pixel-rev.mp4
# 21:32:37 -   - Section 3 Facebook\011-section3-pixelinstall.mp4
# 21:32:37 -   - Section 3 Facebook\012-section3-pixel-audience-rev.mp4
# 21:32:37 -   - Section 3 Facebook\013-section3-customer-list.mp4
# 21:32:37 -   - Section 3 Facebook\014-section3-how-to-setup.mp4
# 21:32:37 -   - Section 3 Facebook\015-section3-ad-placements.mp4
# 21:32:37 -   - Section 3 Facebook\016-section3-dpa-intro.mp4
# 21:32:37 -   - Section 3 Facebook\017-section3-dpa-setup.mp4
# 21:32:37 -   - Section 4 Google Adwords\018-section4-intro-rev.mp4
# 21:32:37 -   - Section 4 Google Adwords\019-section4-howto-rev.mp4
# 21:32:37 -   - Section 4 Google Adwords\020-section4-howto2.mp4
# 21:32:37 -   - Section 4 Google Adwords\021-section4-conversion-track.mp4
# 21:32:37 -   - Section 4 Google Adwords\022-section4-remarketing-list.mp4
# 21:32:37 -   - Section 4 Google Adwords\023-section4-setup-ad.mp4
# 21:32:37 -   - Section 4 Google Adwords\024-section4-dpa-setup.mp4
# 21:32:37 -   - Section 5 YouTube\025-section5-intro.mp4
# 21:32:37 -   - Section 5 YouTube\026-section5-types.mp4
# 21:32:37 -   - Section 5 YouTube\027-section5-how-to.mp4
# 21:32:37 -   - Section 5 YouTube\028-section5-customer-match.mp4
# 21:32:37 -   - Section 6 Twitter\029-section6-intro.mp4
# 21:32:37 -   - Section 6 Twitter\030-section7-audience.mp4
# 21:32:37 -   - Section 6 Twitter\031-section7-howto-setup.mp4
# 21:32:37 -   - Section 7 Instagram\032-section7-intro-rev.mp4
# 21:32:37 -   - Section 7 Instagram\033-section8-howto.mp4
# 21:32:37 -   - Section 8 Gmail\034-section8-intro.mp4
# 21:32:37 -   - Section 8 Gmail\035-section9-How to setup.mp4
# 21:32:37 - Generated title: Google - Youtube - Udemy - The Complete Facebook, Google, YouTube Retargeting Course
# 21:32:37 - Starting video merge...
# 21:32:37 -
# Analyzing 35 videos for merge:
# 21:32:38 - Video 1/35: Section 1 Overview\001-section1-intro-new.mp4
# 21:32:38 - Video 2/35: Section 1 Overview\002-section1-What is Retargeting (remarketing).mp4
# 21:32:38 - Video 3/35: Section 1 Overview\003-section1-why-Retarget-rev.mp4
# 21:32:38 - Video 4/35: Section 2 Strategy Setup\004-section2-customers.mp4
# 21:32:39 - Video 5/35: Section 2 Strategy Setup\005-section2-painpoints.mp4
# 21:32:39 - Video 6/35: Section 2 Strategy Setup\006-section2-solutions.mp4
# 21:32:39 - Video 7/35: Section 2 Strategy Setup\007-section2-objectives.mp4
# 21:32:39 - Video 8/35: Section 2 Strategy Setup\008-section2-creatives.mp4
# 21:32:40 - Video 9/35: Section 3 Facebook\009-section3-intro.mp4
# 21:32:40 - Video 10/35: Section 3 Facebook\010-section3-pixel-rev.mp4
# 21:32:40 - Video 11/35: Section 3 Facebook\011-section3-pixelinstall.mp4
# 21:32:41 - Video 12/35: Section 3 Facebook\012-section3-pixel-audience-rev.mp4
# 21:32:41 - Video 13/35: Section 3 Facebook\013-section3-customer-list.mp4
# 21:32:41 - Video 14/35: Section 3 Facebook\014-section3-how-to-setup.mp4
# 21:32:41 - Video 15/35: Section 3 Facebook\015-section3-ad-placements.mp4
# 21:32:42 - Video 16/35: Section 3 Facebook\016-section3-dpa-intro.mp4
# 21:32:42 - Video 17/35: Section 3 Facebook\017-section3-dpa-setup.mp4
# 21:32:42 - Video 18/35: Section 4 Google Adwords\018-section4-intro-rev.mp4
# 21:32:42 - Video 19/35: Section 4 Google Adwords\019-section4-howto-rev.mp4
# 21:32:43 - Video 20/35: Section 4 Google Adwords\020-section4-howto2.mp4
# 21:32:43 - Video 21/35: Section 4 Google Adwords\021-section4-conversion-track.mp4
# 21:32:43 - Video 22/35: Section 4 Google Adwords\022-section4-remarketing-list.mp4
# 21:32:44 - Video 23/35: Section 4 Google Adwords\023-section4-setup-ad.mp4
# 21:32:44 - Video 24/35: Section 4 Google Adwords\024-section4-dpa-setup.mp4
# 21:32:44 - Video 25/35: Section 5 YouTube\025-section5-intro.mp4
# 21:32:45 - Video 26/35: Section 5 YouTube\026-section5-types.mp4
# 21:32:45 - Video 27/35: Section 5 YouTube\027-section5-how-to.mp4
# 21:32:45 - Video 28/35: Section 5 YouTube\028-section5-customer-match.mp4
# 21:32:45 - Video 29/35: Section 6 Twitter\029-section6-intro.mp4
# 21:32:46 - Video 30/35: Section 6 Twitter\030-section7-audience.mp4
# 21:32:46 - Video 31/35: Section 6 Twitter\031-section7-howto-setup.mp4
# 21:32:46 - Video 32/35: Section 7 Instagram\032-section7-intro-rev.mp4
# 21:32:46 - Video 33/35: Section 7 Instagram\033-section8-howto.mp4
# 21:32:47 - Video 34/35: Section 8 Gmail\034-section8-intro.mp4
# 21:32:47 - Video 35/35: Section 8 Gmail\035-section9-How to setup.mp4
# 21:32:47 -
# Total expected duration: 8733.26 seconds
# 21:49:04 - Merge completed successfully! Final video duration: 8733.26 seconds
# 21:49:04 - Videos merged successfully
# 21:49:12 - Upload attempt 1/3
# 21:49:12 - Starting upload: Google - Youtube - Udemy - The Complete Facebook, Google, YouTube Retargeting Course
# 21:49:23 - Upload progress: 3%
# 21:49:30 - Upload progress: 6%
# 21:49:34 - Upload progress: 9%
# 21:49:38 - Upload progress: 12%
# 21:49:42 - Upload progress: 15%
# 21:49:46 - Upload progress: 18%
# 21:49:50 - Upload progress: 21%
# 21:49:56 - Upload progress: 24%
# 21:50:00 - Upload progress: 27%
# 21:50:04 - Upload progress: 30%
# 21:50:09 - Upload progress: 34%
# 21:50:14 - Upload progress: 37%
# 21:50:18 - Upload progress: 40%
# 21:50:22 - Upload progress: 43%
# 21:50:26 - Upload progress: 46%
# 21:50:31 - Upload progress: 49%
# 21:50:36 - Upload progress: 52%
# 21:50:40 - Upload progress: 55%
# 21:50:44 - Upload progress: 58%
# 21:50:48 - Upload progress: 61%
# 21:50:54 - Upload progress: 64%
# 21:50:58 - Upload progress: 68%
# 21:51:02 - Upload progress: 71%
# 21:51:05 - Upload progress: 74%
# 21:51:09 - Upload progress: 77%
# 21:51:13 - Upload progress: 80%
# 21:51:17 - Upload progress: 83%
# 21:51:21 - Upload progress: 86%
# 21:51:26 - Upload progress: 89%
# 21:51:30 - Upload progress: 92%
# 21:51:34 - Upload progress: 95%
# 21:51:38 - Upload progress: 98%
# 21:51:40 - Upload completed successfully
# 21:51:40 - Upload successful! Video ID: d31tQsxbNBM
# 21:51:40 - Video URL: https://www.youtube.com/watch?v=d31tQsxbNBM
# 21:51:40 - Deleted folder: H:\Projects Control (PC)\10 Backup\05 Tutorials\Google\Youtube\Udemy\The Complete Facebook, Google, YouTube Retargeting Course\Section 1 Overview
# 21:51:40 - Deleted folder: H:\Projects Control (PC)\10 Backup\05 Tutorials\Google\Youtube\Udemy\The Complete Facebook, Google, YouTube Retargeting Course\Section 2 Strategy Setup
# 21:51:40 - Deleted folder: H:\Projects Control (PC)\10 Backup\05 Tutorials\Google\Youtube\Udemy\The Complete Facebook, Google, YouTube Retargeting Course\Section 3 Facebook
# 21:51:40 - Deleted folder: H:\Projects Control (PC)\10 Backup\05 Tutorials\Google\Youtube\Udemy\The Complete Facebook, Google, YouTube Retargeting Course\Section 4 Google Adwords
# 21:51:40 - Deleted folder: H:\Projects Control (PC)\10 Backup\05 Tutorials\Google\Youtube\Udemy\The Complete Facebook, Google, YouTube Retargeting Course\Section 5 YouTube
# 21:51:40 - Deleted folder: H:\Projects Control (PC)\10 Backup\05 Tutorials\Google\Youtube\Udemy\The Complete Facebook, Google, YouTube Retargeting Course\Section 6 Twitter
# 21:51:40 - Deleted folder: H:\Projects Control (PC)\10 Backup\05 Tutorials\Google\Youtube\Udemy\The Complete Facebook, Google, YouTube Retargeting Course\Section 7 Instagram
# 21:51:40 - Deleted folder: H:\Projects Control (PC)\10 Backup\05 Tutorials\Google\Youtube\Udemy\The Complete Facebook, Google, YouTube Retargeting Course\Section 8 Gmail
# 21:51:40 - Deleted 8 folders containing videos
# 21:51:40 - Successfully deleted all video folders
# 21:51:40 - Cleaned up merged video file: H:\Projects Control (PC)\10 Backup\05 Tutorials\Google\Youtube\Udemy\The Complete Facebook, Google, YouTube Retargeting Course\The_merged.mp4
# 21:51:40 -
# Processing tutorial: H:\Projects Control (PC)\10 Backup\05 Tutorials\Google\Youtube\Udemy\Youtube Complete Course 2017 - Your Guide To Youtube Sucsess
# 21:51:40 -
# Processing tutorial folder: H:\Projects Control (PC)\10 Backup\05 Tutorials\Google\Youtube\Udemy\Youtube Complete Course 2017 - Your Guide To Youtube Sucsess
# 21:51:40 - Found 22 videos:
# 21:51:40 -   - 1_-_Introduction_to_the_course\1_-_Introduction.mp4
# 21:51:40 -   - 1_-_Introduction_to_the_course\2_-_Why_YouTube.mp4
# 21:51:40 -   - 1_-_Introduction_to_the_course\3_-_Pre-requisite-_Nothing_as_such.mp4
# 21:51:40 -   - 1_-_Introduction_to_the_course\4_-_Where_to_start.mp4
# 21:51:40 -   - 2_-_Getting_First_10K_Views_on_YouTube_-_7_Things_to_follow\10_-_Tip_Number_5.mp4
# 21:51:40 -   - 2_-_Getting_First_10K_Views_on_YouTube_-_7_Things_to_follow\11_-_Tip_Number_6.mp4
# 21:51:40 -   - 2_-_Getting_First_10K_Views_on_YouTube_-_7_Things_to_follow\12_-_Tip_Number_7.mp4
# 21:51:40 -   - 2_-_Getting_First_10K_Views_on_YouTube_-_7_Things_to_follow\5_-_YouTube_New_10K_Policy_for_Monetisation.mp4
# 21:51:40 -   - 2_-_Getting_First_10K_Views_on_YouTube_-_7_Things_to_follow\6_-_Tip_Number_1.mp4
# 21:51:40 -   - 2_-_Getting_First_10K_Views_on_YouTube_-_7_Things_to_follow\7_-_Tip_Number_2.mp4
# 21:51:40 -   - 2_-_Getting_First_10K_Views_on_YouTube_-_7_Things_to_follow\8_-_Tip_Number_3.mp4
# 21:51:40 -   - 2_-_Getting_First_10K_Views_on_YouTube_-_7_Things_to_follow\9_-_Tip_Number_4.mp4
# 21:51:40 -   - 3_-_YouTube_Creator_Studio_Basics-_Personal_and_Brand_Channel-_Channel_SEO_Tools\13_-_Section_Introduction.mp4
# 21:51:40 -   - 3_-_YouTube_Creator_Studio_Basics-_Personal_and_Brand_Channel-_Channel_SEO_Tools\14_-_Things_To_Consider_Before_Creating_YouTube_Channel.mp4
# 21:51:40 -   - 3_-_YouTube_Creator_Studio_Basics-_Personal_and_Brand_Channel-_Channel_SEO_Tools\15_-_Creating_Personal_YouTube_Account.mp4
# 21:51:40 -   - 3_-_YouTube_Creator_Studio_Basics-_Personal_and_Brand_Channel-_Channel_SEO_Tools\16_-_Creating_Brand_YouTube_Channel.mp4
# 21:51:40 -   - 3_-_YouTube_Creator_Studio_Basics-_Personal_and_Brand_Channel-_Channel_SEO_Tools\17_-_YouTub_SEO-_Channel_Description.mp4
# 21:51:40 -   - 3_-_YouTube_Creator_Studio_Basics-_Personal_and_Brand_Channel-_Channel_SEO_Tools\18_-_YouTub_SEO-_Channel_Tags.mp4
# 21:51:40 -   - 3_-_YouTube_Creator_Studio_Basics-_Personal_and_Brand_Channel-_Channel_SEO_Tools\19_-_Channel_Logo_And_Channel_Art.mp4
# 21:51:40 -   - 3_-_YouTube_Creator_Studio_Basics-_Personal_and_Brand_Channel-_Channel_SEO_Tools\20_-_Creating_Channel_Logo_And_Channel_Art_for_FREE.mp4
# 21:51:40 -   - 4_-_Rank_Higher_in_Search-_Things_To_Do_Before_First_Video_Upload\21_-_Section_Introduction.mp4
# 21:51:40 -   - 4_-_Rank_Higher_in_Search-_Things_To_Do_Before_First_Video_Upload\22_-_Why_to_wait_Start_Right_Away_.mp4
# 21:51:40 - Generated title: Google - Youtube - Udemy - Youtube Complete Course 2017 - Your Guide To Youtube Sucsess
# 21:51:40 - Starting video merge...
# 21:51:40 -
# Analyzing 22 videos for merge:
# 21:51:40 - Video 1/22: 1_-_Introduction_to_the_course\1_-_Introduction.mp4
# 21:51:41 - Video 2/22: 1_-_Introduction_to_the_course\2_-_Why_YouTube.mp4
# 21:51:41 - Video 3/22: 1_-_Introduction_to_the_course\3_-_Pre-requisite-_Nothing_as_such.mp4
# 21:51:41 - Video 4/22: 1_-_Introduction_to_the_course\4_-_Where_to_start.mp4
# 21:51:42 - Video 5/22: 2_-_Getting_First_10K_Views_on_YouTube_-_7_Things_to_follow\10_-_Tip_Number_5.mp4
# 21:51:42 - Video 6/22: 2_-_Getting_First_10K_Views_on_YouTube_-_7_Things_to_follow\11_-_Tip_Number_6.mp4
# 21:51:42 - Video 7/22: 2_-_Getting_First_10K_Views_on_YouTube_-_7_Things_to_follow\12_-_Tip_Number_7.mp4
# 21:51:42 - Video 8/22: 2_-_Getting_First_10K_Views_on_YouTube_-_7_Things_to_follow\5_-_YouTube_New_10K_Policy_for_Monetisation.mp4
# 21:51:43 - Video 9/22: 2_-_Getting_First_10K_Views_on_YouTube_-_7_Things_to_follow\6_-_Tip_Number_1.mp4
# 21:51:43 - Video 10/22: 2_-_Getting_First_10K_Views_on_YouTube_-_7_Things_to_follow\7_-_Tip_Number_2.mp4
# 21:51:43 - Video 11/22: 2_-_Getting_First_10K_Views_on_YouTube_-_7_Things_to_follow\8_-_Tip_Number_3.mp4
# 21:51:43 - Video 12/22: 2_-_Getting_First_10K_Views_on_YouTube_-_7_Things_to_follow\9_-_Tip_Number_4.mp4
# 21:51:44 - Video 13/22: 3_-_YouTube_Creator_Studio_Basics-_Personal_and_Brand_Channel-_Channel_SEO_Tools\13_-_Section_Introduction.mp4
# 21:51:44 - Video 14/22: 3_-_YouTube_Creator_Studio_Basics-_Personal_and_Brand_Channel-_Channel_SEO_Tools\14_-_Things_To_Consider_Before_Creating_YouTube_Channel.mp4
# 21:51:44 - Video 15/22: 3_-_YouTube_Creator_Studio_Basics-_Personal_and_Brand_Channel-_Channel_SEO_Tools\15_-_Creating_Personal_YouTube_Account.mp4
# 21:51:44 - Video 16/22: 3_-_YouTube_Creator_Studio_Basics-_Personal_and_Brand_Channel-_Channel_SEO_Tools\16_-_Creating_Brand_YouTube_Channel.mp4
# 21:51:45 - Video 17/22: 3_-_YouTube_Creator_Studio_Basics-_Personal_and_Brand_Channel-_Channel_SEO_Tools\17_-_YouTub_SEO-_Channel_Description.mp4
# 21:51:45 - Video 18/22: 3_-_YouTube_Creator_Studio_Basics-_Personal_and_Brand_Channel-_Channel_SEO_Tools\18_-_YouTub_SEO-_Channel_Tags.mp4
# 21:51:45 - Video 19/22: 3_-_YouTube_Creator_Studio_Basics-_Personal_and_Brand_Channel-_Channel_SEO_Tools\19_-_Channel_Logo_And_Channel_Art.mp4
# 21:51:46 - Video 20/22: 3_-_YouTube_Creator_Studio_Basics-_Personal_and_Brand_Channel-_Channel_SEO_Tools\20_-_Creating_Channel_Logo_And_Channel_Art_for_FREE.mp4
# 21:51:46 - Video 21/22: 4_-_Rank_Higher_in_Search-_Things_To_Do_Before_First_Video_Upload\21_-_Section_Introduction.mp4
# 21:51:46 - Video 22/22: 4_-_Rank_Higher_in_Search-_Things_To_Do_Before_First_Video_Upload\22_-_Why_to_wait_Start_Right_Away_.mp4
# 21:51:46 -
# Total expected duration: 3732.25 seconds
# 21:58:55 - Merge completed successfully! Final video duration: 3732.24 seconds
# 21:58:55 - Videos merged successfully
# 21:59:00 - Upload attempt 1/3
# 21:59:00 - Starting upload: Google - Youtube - Udemy - Youtube Complete Course 2017 - Your Guide To Youtube Sucsess
# 21:59:10 - Upload progress: 1%
# 21:59:14 - Upload progress: 2%
# 21:59:19 - Upload progress: 3%
# 21:59:24 - Upload progress: 5%
# 21:59:28 - Upload progress: 6%
# 21:59:32 - Upload progress: 7%
# 21:59:39 - Upload progress: 9%
# 21:59:44 - Upload progress: 10%
# 21:59:49 - Upload progress: 11%
# 21:59:53 - Upload progress: 13%
# 21:59:57 - Upload progress: 14%
# 22:00:01 - Upload progress: 15%
# 22:00:05 - Upload progress: 17%
# 22:00:10 - Upload progress: 18%
# 22:00:15 - Upload progress: 19%
# 22:00:20 - Upload progress: 21%
# 22:00:25 - Upload progress: 22%
# 22:00:30 - Upload progress: 23%
# 22:00:35 - Upload progress: 25%
# 22:00:40 - Upload progress: 26%
# 22:00:43 - Upload progress: 27%
# 22:00:49 - Upload progress: 29%
# 22:00:54 - Upload progress: 30%
# 22:00:59 - Upload progress: 31%
# 22:01:05 - Upload progress: 33%
# 22:01:09 - Upload progress: 34%
# 22:01:13 - Upload progress: 35%
# 22:01:17 - Upload progress: 37%
# 22:01:21 - Upload progress: 38%
# 22:01:24 - Upload progress: 39%
# 22:01:29 - Upload progress: 41%
# 22:01:34 - Upload progress: 42%
# 22:01:40 - Upload progress: 43%
# 22:01:45 - Upload progress: 45%
# 22:01:49 - Upload progress: 46%
# 22:01:54 - Upload progress: 47%
# 22:01:59 - Upload progress: 49%
# 22:02:03 - Upload progress: 50%
# 22:02:08 - Upload progress: 51%
# 22:02:12 - Upload progress: 53%
# 22:02:15 - Upload progress: 54%
# 22:02:19 - Upload progress: 55%
# 22:02:22 - Upload progress: 57%
# 22:02:27 - Upload progress: 58%
# 22:02:30 - Upload progress: 59%
# 22:02:34 - Upload progress: 61%
# 22:02:37 - Upload progress: 62%
# 22:02:41 - Upload progress: 63%
# 22:02:45 - Upload progress: 65%
# 22:02:48 - Upload progress: 66%
# 22:02:52 - Upload progress: 67%
# 22:02:56 - Upload progress: 69%
# 22:03:00 - Upload progress: 70%
# 22:03:04 - Upload progress: 71%
# 22:03:07 - Upload progress: 73%
# 22:03:11 - Upload progress: 74%
# 22:03:14 - Upload progress: 75%
# 22:03:18 - Upload progress: 77%
# 22:03:22 - Upload progress: 78%
# 22:03:25 - Upload progress: 79%
# 22:03:30 - Upload progress: 81%
# 22:03:35 - Upload progress: 82%
# 22:03:40 - Upload progress: 83%
# 22:03:44 - Upload progress: 85%
# 22:03:48 - Upload progress: 86%
# 22:03:53 - Upload progress: 87%
# 22:03:58 - Upload progress: 89%
# 22:04:03 - Upload progress: 90%
# 22:04:06 - Upload progress: 91%
# 22:04:10 - Upload progress: 93%
# 22:04:14 - Upload progress: 94%
# 22:04:17 - Upload progress: 95%
# 22:04:21 - Upload progress: 97%
# 22:04:25 - Upload progress: 98%
# 22:04:29 - Upload progress: 99%
# 22:04:30 - Upload completed successfully
# 22:04:30 - Upload successful! Video ID: uAZkZH9IYjQ
# 22:04:30 - Video URL: https://www.youtube.com/watch?v=uAZkZH9IYjQ
# 22:04:30 - Deleted folder: H:\Projects Control (PC)\10 Backup\05 Tutorials\Google\Youtube\Udemy\Youtube Complete Course 2017 - Your Guide To Youtube Sucsess\1_-_Introduction_to_the_course
# 22:04:30 - Deleted folder: H:\Projects Control (PC)\10 Backup\05 Tutorials\Google\Youtube\Udemy\Youtube Complete Course 2017 - Your Guide To Youtube Sucsess\2_-_Getting_First_10K_Views_on_YouTube_-_7_Things_to_follow
# 22:04:30 - Deleted folder: H:\Projects Control (PC)\10 Backup\05 Tutorials\Google\Youtube\Udemy\Youtube Complete Course 2017 - Your Guide To Youtube Sucsess\3_-_YouTube_Creator_Studio_Basics-_Personal_and_Brand_Channel-_Channel_SEO_Tools
# 22:04:30 - Deleted folder: H:\Projects Control (PC)\10 Backup\05 Tutorials\Google\Youtube\Udemy\Youtube Complete Course 2017 - Your Guide To Youtube Sucsess\4_-_Rank_Higher_in_Search-_Things_To_Do_Before_First_Video_Upload
# 22:04:30 - Deleted 4 folders containing videos
# 22:04:30 - Successfully deleted all video folders
# 22:04:31 - Cleaned up merged video file: H:\Projects Control (PC)\10 Backup\05 Tutorials\Google\Youtube\Udemy\Youtube Complete Course 2017 - Your Guide To Youtube Sucsess\Youtube__merged.mp4
