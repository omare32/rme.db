# %%
#!/usr/bin/env python3
import os
import glob
import json
import time
import shutil
import logging
import re
from datetime import datetime
import subprocess
from pathlib import Path
from typing import List, Dict, Optional, Tuple
import ffmpeg
import tkinter as tk
from tkinter import ttk, messagebox
import ssl
import httplib2
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload
from googleapiclient.errors import HttpError

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(message)s',
    datefmt='%H:%M:%S',
    handlers=[
        logging.FileHandler('video_processing.log', encoding='utf-8'),
        logging.StreamHandler()
    ]
)

TOKEN_FILE = "token.json"
SCOPES = ["https://www.googleapis.com/auth/youtube.upload"]

class ProgressWindow:
    def __init__(self, title="Progress", parent=None):
        self.root = tk.Toplevel(parent) if parent else tk.Tk()
        self.root.title(title)
        self.root.geometry("600x200")
        
        # Center the window
        self.root.update_idletasks()
        width = self.root.winfo_width()
        height = self.root.winfo_height()
        x = (self.root.winfo_screenwidth() // 2) - (width // 2)
        y = (self.root.winfo_screenheight() // 2) - (height // 2)
        self.root.geometry(f'+{x}+{y}')
        
        # Make window stay on top
        self.root.attributes('-topmost', True)
        
        # Create main frame
        main_frame = ttk.Frame(self.root, padding="10")
        main_frame.pack(fill=tk.BOTH, expand=True)
        
        # Status label
        self.status_var = tk.StringVar(value="Initializing...")
        self.status_label = ttk.Label(main_frame, textvariable=self.status_var)
        self.status_label.pack(pady=(0, 5))
        
        # Progress bar
        self.progress_var = tk.DoubleVar(value=0)
        self.progress_bar = ttk.Progressbar(
            main_frame, 
            variable=self.progress_var,
            maximum=100,
            length=500
        )
        self.progress_bar.pack(pady=5)
        
        # Details frame
        details_frame = ttk.LabelFrame(main_frame, text="Details", padding="5")
        details_frame.pack(fill=tk.X, pady=5)
        
        # Time info
        time_frame = ttk.Frame(details_frame)
        time_frame.pack(fill=tk.X, pady=2)
        
        self.elapsed_var = tk.StringVar(value="Elapsed: 0:00:00")
        self.remaining_var = tk.StringVar(value="Remaining: --:--:--")
        
        ttk.Label(time_frame, textvariable=self.elapsed_var).pack(side=tk.LEFT, padx=5)
        ttk.Label(time_frame, textvariable=self.remaining_var).pack(side=tk.RIGHT, padx=5)
        
        # Stats frame
        stats_frame = ttk.Frame(details_frame)
        stats_frame.pack(fill=tk.X, pady=2)
        
        self.speed_var = tk.StringVar(value="Speed: --")
        self.size_var = tk.StringVar(value="Size: --")
        
        ttk.Label(stats_frame, textvariable=self.speed_var).pack(side=tk.LEFT, padx=5)
        ttk.Label(stats_frame, textvariable=self.size_var).pack(side=tk.RIGHT, padx=5)
        
        self.start_time = time.time()
        self.root.protocol("WM_DELETE_WINDOW", self.on_closing)
        self.allow_close = False

    def on_closing(self):
        if self.allow_close:
            self.root.destroy()

    def update_progress(self, current_duration: float, total_duration: float, 
                       speed: str = "", size: str = "", status: str = None):
        """Update progress bar and stats."""
        if status:
            self.status_var.set(status)
        
        # Update progress bar
        progress = (current_duration / total_duration * 100) if total_duration > 0 else 0
        self.progress_var.set(progress)
        
        # Update elapsed time
        elapsed = time.time() - self.start_time
        elapsed_str = time.strftime('%H:%M:%S', time.gmtime(elapsed))
        self.elapsed_var.set(f"Elapsed: {elapsed_str}")
        
        # Update estimated remaining time
        if progress > 0:
            total_estimated = elapsed / (progress / 100)
            remaining = total_estimated - elapsed
            remaining_str = time.strftime('%H:%M:%S', time.gmtime(remaining))
            self.remaining_var.set(f"Remaining: {remaining_str}")
        
        # Update speed and size
        if speed:
            self.speed_var.set(f"Speed: {speed}")
        if size:
            self.size_var.set(f"Size: {size}")
        
        # Update the window
        self.root.update()

    def close(self):
        """Allow and perform window close."""
        self.allow_close = True
        self.root.destroy()

def get_folder_path_gui() -> str:
    """Create a Tkinter window to get the folder path."""
    try:
        def on_submit():
            window.quit()

        # Create the main window
        window = tk.Tk()
        window.title("Enter Folder Path")
        window.geometry("800x150")  # Make window wider for long paths
        
        # Create and pack a frame
        frame = ttk.Frame(window, padding="10")
        frame.pack(fill=tk.BOTH, expand=True)
        
        # Create label
        ttk.Label(frame, text="Enter the full path to the tutorials folder:").pack(pady=5)
        
        # Create entry field
        path_var = tk.StringVar()
        entry = ttk.Entry(frame, textvariable=path_var, width=100)  # Make entry field wider
        entry.pack(pady=5, fill=tk.X)
        
        # Create submit button
        ttk.Button(frame, text="Submit", command=on_submit).pack(pady=10)
        
        # Focus on entry field and bind Enter key
        entry.focus()
        window.bind('<Return>', lambda e: on_submit())
        
        # Bring window to front
        window.lift()
        window.attributes('-topmost', True)
        window.attributes('-topmost', False)
        
        # Start the window
        window.mainloop()
        
        # Get the path and destroy the window
        path = path_var.get().strip()
        window.destroy()
        return path
        
    except Exception as e:
        logging.error(f"Error creating GUI window: {str(e)}")
        # Fallback to console input if GUI fails
        return input("Enter folder path (GUI failed): ")

def authenticate_youtube(client_secrets_file: str) -> Optional[object]:
    """Authenticate with YouTube as the very first step."""
    try:
        print("\nChecking YouTube authentication...")
        if not os.path.exists(client_secrets_file):
            print("Error: Client secrets file not found")
            return None
            
        creds = None
        # Check if token file exists
        if os.path.exists(TOKEN_FILE):
            try:
                creds = Credentials.from_authorized_user_file(TOKEN_FILE, SCOPES)
                print("Found existing token")
            except Exception as e:
                print(f"Error loading token: {e}")
                creds = None

        # If token is missing or invalid, refresh or re-authenticate
        if not creds or not creds.valid:
            if creds and creds.expired and creds.refresh_token:
                try:
                    print("Token expired, refreshing...")
                    creds.refresh(Request())
                    print("Token refreshed successfully")
                except Exception as e:
                    print(f"Token refresh failed: {e}")
                    creds = None

            if not creds:
                print("\nOpening browser for YouTube authentication...")
                print("Please select your Google account and grant access...")
                flow = InstalledAppFlow.from_client_secrets_file(client_secrets_file, SCOPES)
                creds = flow.run_local_server(port=0)

                # Save the new token
                with open(TOKEN_FILE, "w") as token:
                    token.write(creds.to_json())
                print("New token saved")

        # Build and return the YouTube service
        youtube = build("youtube", "v3", credentials=creds)
        print("YouTube authentication successful!")
        return youtube
        
    except Exception as e:
        print(f"Authentication error: {e}")
        return None

def get_structured_title(path: str) -> str:
    """Generate a structured title from the path levels after '05 Tutorials'."""
    try:
        parts = Path(path).parts
        # Find the index of "05 Tutorials"
        for i, part in enumerate(parts):
            if part == "05 Tutorials":
                # Take exactly 4 parts after "05 Tutorials"
                relevant_parts = parts[i+1:i+5]  # This will get: Google, Slides, Lynda, Google Slides Essential Training
                # Join parts and ensure total length is under 100 characters
                title = " - ".join(relevant_parts)
                if len(title) > 95:  # Leave some margin for safety
                    # If too long, take first word of each part except the last one
                    shortened_parts = []
                    for j, part in enumerate(relevant_parts):
                        if j < len(relevant_parts) - 1:
                            # For all parts except the last, take just the first word
                            first_word = part.split()[0]
                            shortened_parts.append(first_word)
                        else:
                            # For the last part (course name), keep more detail but limit length
                            last_part = part[:50]  # Limit last part to 50 chars
                            shortened_parts.append(last_part)
                    title = " - ".join(shortened_parts)
                    # If still too long, truncate to 95 chars
                    if len(title) > 95:
                        title = title[:95]
                return title
        return os.path.basename(path)[:95]  # Fallback with length limit
    except Exception as e:
        logging.error(f"Error in get_structured_title: {str(e)}")
        # Return a safe fallback title
        return os.path.basename(path)[:95]

def is_tutorial_folder(path: str) -> bool:
    """
    Check if this is a level 4 tutorial folder (e.g. 'Google Slides Essential Training').
    Path structure: .../05 Tutorials/level1/level2/level3/level4
    """
    try:
        parts = Path(path).parts
        # Find the index of "05 Tutorials"
        for i, part in enumerate(parts):
            if part == "05 Tutorials":
                # Check if we have exactly 4 levels after "05 Tutorials"
                remaining_parts = parts[i+1:]
                return len(remaining_parts) == 4
        return False
    except Exception as e:
        logging.error(f"Error in is_tutorial_folder: {str(e)}")
        return False

def collect_videos(folder_path: str) -> List[Tuple[str, str]]:
    """Collect all videos from folder and subfolders, sorted by folder structure and filename."""
    video_files = []
    try:
        # Walk through all subdirectories
        for root, _, files in os.walk(folder_path):
            # Filter and sort video files
            video_files.extend(
                (os.path.join(root, f), os.path.relpath(os.path.join(root, f), folder_path))
                for f in sorted(files)
                if f.lower().endswith(('.mp4', '.avi', '.mkv'))
            )
        
        # Sort by full path to maintain folder structure order
        return sorted(video_files, key=lambda x: x[0].lower())
    except Exception as e:
        logging.error(f"Error collecting videos: {str(e)}")
        return []

def get_video_duration(video_path: str) -> Optional[float]:
    """Get video duration using ffprobe with better error handling."""
    try:
        result = subprocess.run(
            ["ffprobe", "-v", "error", 
             "-show_entries", "format=duration",
             "-of", "default=noprint_wrappers=1:nokey=1", 
             video_path],
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            text=True,
            check=True
        )
        duration = float(result.stdout.strip())
        return duration
    except Exception as e:
        logging.warning(f"Could not get duration for {os.path.basename(video_path)}: {str(e)}")
        return None

def generate_timestamps(video_files: List[Tuple[str, str]]) -> str:
    """Generate timestamps for video description with proper duration handling."""
    timestamps = []
    current_time = 0
    
    for full_path, rel_path in video_files:
        duration = get_video_duration(full_path)
        if duration is None:
            logging.warning(f"Skipping timestamp for {rel_path} - could not get duration")
            continue
            
        hours = int(current_time // 3600)
        minutes = int((current_time % 3600) // 60)
        seconds = int(current_time % 60)
        
        timestamp = f"{hours:02d}:{minutes:02d}:{seconds:02d}"
        video_name = os.path.splitext(os.path.basename(rel_path))[0]
        timestamps.append(f"{timestamp} - {video_name}")
        
        current_time += duration
    
    return '\n'.join(timestamps)

def parse_ffmpeg_progress(line: str) -> Dict[str, str]:
    """Parse ffmpeg progress output line."""
    result = {}
    
    # Extract time
    time_match = re.search(r'time=(\d+:\d+:\d+\.\d+)', line)
    if time_match:
        time_str = time_match.group(1)
        h, m, s = time_str.split(':')
        s = float(s)
        result['duration'] = float(h) * 3600 + float(m) * 60 + s
    
    # Extract speed
    speed_match = re.search(r'speed=(\d+\.?\d*x)', line)
    if speed_match:
        result['speed'] = speed_match.group(1)
    
    # Extract size
    size_match = re.search(r'size=\s*(\d+.*?B)', line)
    if size_match:
        result['size'] = size_match.group(1)
    
    return result

def merge_videos(video_files: List[Tuple[str, str]], output_path: str) -> bool:
    """Merge videos using ffmpeg with proper format settings and UI progress bar."""
    progress_window = None
    try:
        # Create file list
        list_path = os.path.join(os.path.dirname(output_path), "file_list.txt")
        with open(list_path, 'w', encoding='utf-8') as f:
            for full_path, _ in video_files:
                f.write(f"file '{full_path}'\n")
        
        # Calculate expected duration
        total_duration = 0
        logging.info(f"\nAnalyzing {len(video_files)} videos for merge:")
        for i, (full_path, rel_path) in enumerate(video_files, 1):
            duration = get_video_duration(full_path) or 0
            total_duration += duration
            logging.info(f"Video {i}/{len(video_files)}: {rel_path}")

        if total_duration == 0:
            logging.error("Could not calculate total duration of videos")
            return False
            
        logging.info(f"\nTotal expected duration: {total_duration:.2f} seconds")
        
        # Create progress window
        progress_window = ProgressWindow("Merging Videos")
        progress_window.update_progress(0, total_duration, status="Starting merge process...")
        
        # Merge videos with specific format settings
        cmd = [
            "ffmpeg",
            "-f", "concat",
            "-safe", "0",
            "-i", list_path,
            "-c:v", "libx264",     # Use H.264 codec
            "-preset", "fast",      # Faster encoding
            "-crf", "23",          # Good quality/size balance
            "-c:a", "aac",         # AAC audio codec
            "-b:a", "128k",        # Audio bitrate
            "-movflags", "+faststart",  # Web playback optimization
            "-stats",              # Print encoding progress
            "-loglevel", "info",   # Show informative messages
            output_path,
            "-y"                   # Overwrite output file
        ]
        
        # Run ffmpeg with progress monitoring
        process = subprocess.Popen(
            cmd,
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            universal_newlines=True,
            bufsize=1
        )

        # Monitor the encoding progress through stderr
        while True:
            stderr_line = process.stderr.readline()
            if not stderr_line and process.poll() is not None:
                break
                
            # Parse progress information
            if "time=" in stderr_line:
                progress_data = parse_ffmpeg_progress(stderr_line)
                if progress_data:
                    current_duration = progress_data.get('duration', 0)
                    speed = progress_data.get('speed', '')
                    size = progress_data.get('size', '')
                    
                    # Update progress window
                    if progress_window:
                        status = f"Merging videos... ({current_duration:.1f}s / {total_duration:.1f}s)"
                        progress_window.update_progress(
                            current_duration, 
                            total_duration,
                            speed=speed,
                            size=size,
                            status=status
                        )

        # Get the final status
        return_code = process.wait()
        
        if return_code != 0:
            error_output = process.stderr.read()
            logging.error(f"FFmpeg error: {error_output}")
            if progress_window:
                progress_window.update_progress(0, total_duration, status="Error in merge process!")
                time.sleep(3)  # Show error briefly
            return False
            
        # Verify output duration
        output_duration = get_video_duration(output_path)
        if output_duration is None:
            logging.error("Could not verify output video duration")
            return False
            
        # Allow 5 second tolerance
        if abs(output_duration - total_duration) > 5:
            logging.error(f"Output duration ({output_duration:.2f}s) doesn't match expected ({total_duration:.2f}s)")
            return False
            
        if progress_window:
            progress_window.update_progress(total_duration, total_duration, status="Merge completed successfully!")
            time.sleep(2)  # Show completion message briefly
            
        logging.info(f"Merge completed successfully! Final video duration: {output_duration:.2f} seconds")
        return True
        
    except Exception as e:
        logging.error(f"Error merging videos: {str(e)}")
        if progress_window:
            progress_window.update_progress(0, total_duration, status=f"Error: {str(e)}")
            time.sleep(3)  # Show error briefly
        return False
    finally:
        if os.path.exists(list_path):
            os.remove(list_path)
        if progress_window:
            progress_window.close()

def upload_to_youtube(youtube, video_path: str, title: str, description: str) -> Optional[Dict]:
    """Upload video to YouTube with improved error handling and retry logic."""
    try:
        # Ensure title is not empty and within limits
        if not title or len(title) > 100:
            title = title[:95] if title else "Untitled Video"
        
        logging.info(f"Starting upload: {title}")
        
        body = {
            "snippet": {
                "title": title,
                "description": description,
                "categoryId": "27",  # Education category
                "tags": ["tutorial", "education"]
            },
            "status": {
                "privacyStatus": "unlisted",
                "selfDeclaredMadeForKids": False
            }
        }

        # Create insert request
        insert_request = youtube.videos().insert(
            part=",".join(body.keys()),
            body=body,
            media_body=MediaFileUpload(
                video_path, 
                chunksize=1024*1024*8,  # 8MB chunks for better reliability
                resumable=True
            )
        )

        response = None
        retries = 3
        chunk_retries = 5  # Number of retries per chunk
        
        while response is None and retries > 0:
            try:
                chunk_retry_count = chunk_retries
                while chunk_retry_count > 0:
                    try:
                        status, response = insert_request.next_chunk()
                        if response:
                            logging.info("Upload completed successfully")
                            return response
                        elif status:
                            logging.info(f"Upload progress: {int(status.progress() * 100)}%")
                        break  # Successful chunk upload, continue to next chunk
                    except (ConnectionError, httplib2.HttpLib2Error) as chunk_error:
                        chunk_retry_count -= 1
                        if chunk_retry_count == 0:
                            raise  # Re-raise if we're out of chunk retries
                        logging.warning(f"Chunk upload failed, waiting 10 seconds before retry... ({str(chunk_error)})")
                        time.sleep(10)  # Longer wait between chunk retries
                
            except Exception as e:
                retries -= 1
                if retries == 0:
                    raise
                logging.warning(f"Upload attempt failed, waiting 30 seconds before retry... ({str(e)})")
                time.sleep(30)  # Much longer wait between full upload retries

    except Exception as e:
        logging.error(f"Error uploading to YouTube: {str(e)}")
        return None

def cleanup_and_save_link(folder_path: str, video_id: str, title: str):
    """Save YouTube link and clean up files."""
    link_file = os.path.join(folder_path, "youtube link.txt")
    with open(link_file, 'w') as f:
        f.write(f"Title: {title}\n")
        f.write(f"URL: https://www.youtube.com/watch?v={video_id}\n")
        f.write(f"Uploaded: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

def delete_video_folders(tutorial_path: str) -> bool:
    """Delete all subfolders containing videos after successful upload."""
    try:
        deleted_folders = 0
        # Walk through all subfolders
        for root, dirs, files in os.walk(tutorial_path, topdown=False):
            # Skip the tutorial root folder itself
            if root == tutorial_path:
                continue
                
            # Check if this is a folder containing videos
            has_videos = any(f.lower().endswith(('.mp4', '.avi', '.mkv')) for f in files)
            if has_videos:
                try:
                    shutil.rmtree(root)
                    deleted_folders += 1
                    logging.info(f"Deleted folder: {root}")
                except Exception as e:
                    logging.error(f"Failed to delete folder {root}: {str(e)}")
                    return False
        
        logging.info(f"Deleted {deleted_folders} folders containing videos")
        return True
    except Exception as e:
        logging.error(f"Error deleting video folders: {str(e)}")
        return False

def shorten_folder_name(folder_name: str) -> str:
    """Create a shorter version of the folder name that's still meaningful."""
    # Remove special characters and spaces
    cleaned = re.sub(r'[^\w\s-]', '', folder_name)
    # Replace spaces with underscores
    cleaned = cleaned.replace(' ', '_')
    # Take first word of each segment
    words = [part.split('_')[0] for part in cleaned.split('-')]
    # Join with underscores and limit to 50 characters
    shortened = '_'.join(words)[:50]
    return shortened

def create_temp_folder_with_videos(original_path: str) -> Tuple[Optional[str], Optional[str]]:
    """
    Creates a temporary folder with a shorter name and copies videos there.
    Returns tuple of (temp_folder_path, original_folder_name) or (None, None) on failure.
    """
    try:
        # Get original folder name and create shortened version
        original_folder_name = os.path.basename(original_path)
        short_name = shorten_folder_name(original_folder_name)
        
        # Create temp folder in parent directory
        parent_dir = os.path.dirname(original_path)
        temp_folder = os.path.join(parent_dir, f"temp_{short_name}")
        
        # If temp folder already exists, delete it
        if os.path.exists(temp_folder):
            shutil.rmtree(temp_folder)
        
        # Create new temp folder and copy structure
        os.makedirs(temp_folder)
        
        # Copy all video files maintaining relative paths
        for root, _, files in os.walk(original_path):
            for file in files:
                if file.lower().endswith(('.mp4', '.avi', '.mkv')):
                    # Get relative path
                    rel_path = os.path.relpath(root, original_path)
                    # Create corresponding folder in temp directory
                    temp_subdir = os.path.join(temp_folder, rel_path)
                    os.makedirs(temp_subdir, exist_ok=True)
                    # Copy file
                    src_file = os.path.join(root, file)
                    dst_file = os.path.join(temp_subdir, file)
                    shutil.copy2(src_file, dst_file)
        
        return temp_folder, original_folder_name
    except Exception as e:
        logging.error(f"Error creating temporary folder: {str(e)}")
        return None, None

def cleanup_temp_folder(temp_folder: str):
    """Clean up the temporary folder."""
    try:
        if os.path.exists(temp_folder):
            shutil.rmtree(temp_folder)
            logging.info(f"Cleaned up temporary folder: {temp_folder}")
    except Exception as e:
        logging.warning(f"Failed to clean up temporary folder: {str(e)}")

def process_tutorial_folder(tutorial_path: str, youtube: object):
    """Process a single tutorial folder containing videos."""
    merged_path = None
    temp_folder = None
    try:
        logging.info(f"\nProcessing tutorial folder: {tutorial_path}")
        
        # Check if this folder has already been processed
        link_file = os.path.join(tutorial_path, "youtube link.txt")
        if os.path.exists(link_file):
            logging.info(f"Folder already processed (found youtube link.txt). Skipping: {tutorial_path}")
            return
            
        # Verify this is a level 4 tutorial folder
        if not is_tutorial_folder(tutorial_path):
            logging.error(f"Not a tutorial folder (level 4): {tutorial_path}")
            return
        
        # Create temporary folder with shorter path if needed
        original_folder_name = os.path.basename(tutorial_path)
        if len(tutorial_path) > 200:  # Path is too long
            temp_folder, original_folder_name = create_temp_folder_with_videos(tutorial_path)
            if not temp_folder:
                logging.error("Failed to create temporary folder")
                return
            working_path = temp_folder
        else:
            working_path = tutorial_path
        
        # Get videos from working path
        video_files = collect_videos(working_path)
        if not video_files:
            logging.error(f"No video files found in {working_path}")
            return
            
        logging.info(f"Found {len(video_files)} videos:")
        for _, rel_path in video_files:
            logging.info(f"  - {rel_path}")
        
        # Get structured title using original folder name
        title = get_structured_title(tutorial_path)
        logging.info(f"Generated title: {title}")
        
        # Create merged file in the working folder
        merged_filename = f"{shorten_folder_name(original_folder_name)}_merged.mp4"
        merged_path = os.path.join(working_path, merged_filename)
        
        logging.info("Starting video merge...")
        if not merge_videos(video_files, merged_path):
            logging.error("Failed to merge videos")
            return
            
        logging.info("Videos merged successfully")
        
        # Generate timestamps
        timestamps = generate_timestamps(video_files)
        description = "Tutorial Contents:\n\n" + timestamps
        
        # Upload with retries
        max_upload_attempts = 3
        upload_response = None
        
        for attempt in range(max_upload_attempts):
            try:
                logging.info(f"Upload attempt {attempt + 1}/{max_upload_attempts}")
                upload_response = upload_to_youtube(youtube, merged_path, title, description)
                if upload_response:
                    break
                time.sleep(30)
            except Exception as e:
                logging.error(f"Upload attempt {attempt + 1} failed: {str(e)}")
                if attempt < max_upload_attempts - 1:
                    logging.info("Waiting 60 seconds before next attempt...")
                    time.sleep(60)
                continue
        
        if upload_response and upload_response.get('id'):
            video_id = upload_response['id']
            logging.info(f"Upload successful! Video ID: {video_id}")
            
            # Save link file in the original tutorial folder
            cleanup_and_save_link(tutorial_path, video_id, title)
            logging.info(f"Video URL: https://www.youtube.com/watch?v={video_id}")
            
            # Only proceed with cleanup if we have a valid video ID and link file
            link_file = os.path.join(tutorial_path, "youtube link.txt")
            if os.path.exists(link_file):
                # Delete all folders containing videos first
                if delete_video_folders(tutorial_path):
                    logging.info("Successfully deleted all video folders")
                else:
                    logging.error("Failed to delete some video folders")
                    
                # Clean up merged video file
                try:
                    os.remove(merged_path)
                    logging.info(f"Cleaned up merged video file: {merged_path}")
                except Exception as e:
                    logging.warning(f"Could not clean up merged video: {str(e)}")
            else:
                logging.warning("Link file not created. Skipping cleanup to be safe.")
        else:
            logging.error("Upload failed after all attempts. Keeping files for retry.")
            
    except Exception as e:
        logging.error(f"Error processing tutorial folder: {str(e)}")
    finally:
        # Clean up temporary folder if it exists
        if temp_folder:
            cleanup_temp_folder(temp_folder)

def find_tutorial_folders(parent_path: str) -> List[str]:
    """Find all level 4 tutorial folders under the given parent path."""
    tutorial_folders = []
    try:
        # Walk through all subdirectories
        for root, _, files in os.walk(parent_path):
            # Check if this is a tutorial folder (level 4)
            if is_tutorial_folder(root):
                # Check if this folder has videos (directly or in subfolders)
                has_videos = False
                for _, _, fs in os.walk(root):
                    if any(f.lower().endswith(('.mp4', '.avi', '.mkv')) for f in fs):
                        has_videos = True
                        break
                if has_videos:
                    tutorial_folders.append(root)
    except Exception as e:
        logging.error(f"Error finding tutorial folders: {str(e)}")
    return sorted(tutorial_folders)

def process_folder(parent_path: str, youtube: object):
    """Process all tutorial folders under the given parent path."""
    try:
        logging.info(f"Scanning for tutorial folders in: {parent_path}")
        
        # Find all tutorial folders
        tutorial_folders = find_tutorial_folders(parent_path)
        
        if not tutorial_folders:
            logging.error("No tutorial folders with videos found")
            return
            
        logging.info(f"Found {len(tutorial_folders)} tutorial folders")
        
        # Process each tutorial folder
        for tutorial_folder in tutorial_folders:
            logging.info(f"\nProcessing tutorial: {tutorial_folder}")
            process_tutorial_folder(tutorial_folder, youtube)
            
    except Exception as e:
        logging.error(f"Error in process_folder: {str(e)}")

def get_script_directory():
    """Get the directory containing the script, works in both .py and .ipynb"""
    try:
        # For .py files
        return os.path.dirname(os.path.abspath(__file__))
    except NameError:
        # For Jupyter notebooks
        try:
            import nbformat
            from notebook import notebookapp
            import jupyter_client
            
            # Try to get the current notebook's path
            connection_file = jupyter_client.find_connection_file()
            kernel_id = os.path.basename(connection_file).split('-', 1)[1].split('.')[0]
            
            for srv in notebookapp.list_running_servers():
                for note in srv['notebook_dir']:
                    if kernel_id in note:
                        return os.path.dirname(note['path'])
                        
        except:
            # Fallback: Look in current working directory
            return os.getcwd()

def find_client_secrets():
    """Find client_secret.json in various possible locations"""
    possible_locations = [
        # Current directory
        os.path.join(os.getcwd(), "client_secret.json"),
        # Script directory (for .py files)
        os.path.join(get_script_directory(), "client_secret.json"),
        # One level up
        os.path.join(os.path.dirname(os.getcwd()), "client_secret.json"),
        # In 04.merge.and.upload directory
        os.path.join(os.getcwd(), "04.merge.and.upload", "client_secret.json"),
    ]
    
    for location in possible_locations:
        if os.path.exists(location):
            print(f"Found client_secret.json at: {location}")
            return location
            
    print("Searched in the following locations:")
    for location in possible_locations:
        print(f"- {location}")
    return None

def main():
    try:
        print("\n=== Starting YouTube Video Processor ===")
        
        # Find client secrets file
        client_secrets_file = find_client_secrets()
        if not client_secrets_file:
            print("Error: client_secret.json not found in any expected location")
            return
            
        # Authenticate with YouTube as the very first step
        youtube = authenticate_youtube(client_secrets_file)
        if not youtube:
            print("Failed to authenticate with YouTube. Please try again.")
            return
            
        # Now get folder path using GUI
        print("\nOpening folder selection window...")
        folder_path = get_folder_path_gui()
        if not folder_path:
            print("No path entered")
            return
            
        if not os.path.exists(folder_path):
            print("Path does not exist")
            return
            
        # Process folders with the authenticated service
        print(f"\nStarting to process folder: {folder_path}")
        process_folder(folder_path, youtube)
        
    except Exception as e:
        print(f"Error in main: {str(e)}")
        logging.error(f"Error in main: {str(e)}")
        import traceback
        traceback.print_exc()

if __name__ == "__main__":
    main()
# Out:
# === Starting YouTube Video Processor ===
# Found client_secret.json at: d:\OneDrive\OneDrive - Rowad Modern Engineering\x004 Data Science\03.rme.db\00.repo\rme.db\09.other.projects\01.youtube\04.merge.and.upload\client_secret.json
#
# Checking YouTube authentication...
# Found existing token
# Token expired, refreshing...
# 16:51:51 - file_cache is only supported with oauth2client<4.0.0
# Token refreshed successfully
# YouTube authentication successful!
#
# Opening folder selection window...
# 16:51:57 - Scanning for tutorial folders in: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Google\Google
# 16:51:58 - Found 4 tutorial folders
# 16:51:58 -
# Processing tutorial: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Google\Google\Coursera\Understanding Media by Understanding Google; Northwestern University
# 16:51:58 -
# Processing tutorial folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Google\Google\Coursera\Understanding Media by Understanding Google; Northwestern University
# 16:51:58 - Found 26 videos:
# 16:51:58 -   - 100 - 1 - Week 1_ Introduction (Lecture 1.0, 3_28).mp4
# 16:51:58 -   - 100 - 2 - Week 1_ Why Study Google and the Media%3F (Lecture 1.1, 11_42).mp4
# 16:51:58 -   - 100 - 3 - Week 1_ Google, Google Everywhere (Lecture 1.2, 10_03).mp4
# 16:51:58 -   - 100 - 4 - Week 1_ Google+ Hangout with Jeff Jarvis (Lecture 1.3, 22_03).mp4
# 16:51:58 -   - 100 - 5 - Week 1_ What Are You Searching For%3F (Lecture 1.4, 8_03).mp4
# 16:51:58 -   - 100 - 6 - Week 1_ Search and Research (Lecture 1.5, 13_30).mp4
# 16:51:58 -   - 200 - 1 - Week 2_ Google and News (Lecture 2.1, 8_45).mp4
# 16:51:58 -   - 200 - 2 - Week 2_ The New(ish) News Economy (Lecture 2.2, 10_58).mp4
# 16:51:58 -   - 200 - 3 - Week 2_ Google and Books (Lecture 2.3, 10_13).mp4
# 16:51:58 -   - 200 - 4 - Week 2_ Google+ Hangout with Siva Vaidhyanathan (Lecture 2.4, 26_19).mp4
# 16:51:58 -   - 300 - 1 - Week 3_ Google and Advertising_ What Are You Buying%3F (Lecture 3.1, 13_52).mp4
# 16:51:58 -   - 300 - 2 - Week 3_ Google, Personalization, and Privacy (Lecture 3.2, 15_25).mp4
# 16:51:58 -   - 300 - 3 - Week 3_ Google+ Hangout with Ted Shergalis (Lecture 3.3, 15_30).mp4
# 16:51:58 -   - 400 - 1 - Week 4_ Google, YouTube, and You (Lecture 4-1.1, 13_37).mp4
# 16:51:58 -   - 400 - 1 - Week 4_ Google, YouTube, and You (Lecture 4.1, 13_37).mp4
# 16:51:58 -   - 400 - 2 - Week 4_ YouTube (and Google) and the News (Lecture 4-1.2, 14_25).mp4
# 16:51:58 -   - 400 - 2 - Week 4_ YouTube (and Google) and the News (Lecture 4.2, 14_25).mp4
# 16:51:58 -   - 500 - 1 - Week 5_ We%5C're Mobile, We%5C're Smarter-1...Aren%5C't We%3F (Lecture 5.1, 13_52).mp4
# 16:51:58 -   - 500 - 1 - Week 5_ We%5C're Mobile, We%5C're Smarter...Aren%5C't We%3F (Lecture 5.1, 13_52).mp4
# 16:51:58 -   - 500 - 2 - Week 5_ Where Next%3F (Is %5C%22Wear%5C%22 Next%3F) (Lecture 5-1.2, 13_47).mp4
# 16:51:58 -   - 500 - 2 - Week 5_ Where Next%3F (Is %5C%22Wear%5C%22 Next%3F) (Lecture 5.2, 13_47).mp4
# 16:51:58 -   - 500 - 3 - Week 5_ Conversations with Steven Levy (Lecture 5-1.3, 17_39).mp4
# 16:51:58 -   - 500 - 3 - Week 5_ Conversations with Steven Levy (Lecture 5.3, 17_39).mp4
# 16:51:58 -   - 600 - 1 - Week 6_ The Social Circle (Lecture 6.1, 16_35).mp4
# 16:51:58 -   - 600 - 2 - Week 6_ The Private, The Public, The Politic(s) (Lecture 6.2, 16_46).mp4
# 16:51:58 -   - 600 - 3 - Week 6_ Google+ Hangouts on Privacy with Jeff Jarvis and Siva Vaidhyanathan (Lecture 6.3, 27_15).mp4
# 16:51:58 - Generated title: Google - Google - Coursera - Understanding Media by Understanding Google; North
# 16:51:58 - Starting video merge...
# 16:51:58 -
# Analyzing 26 videos for merge:
# Starting to process folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Google\Google
# 16:51:59 - Video 1/26: 100 - 1 - Week 1_ Introduction (Lecture 1.0, 3_28).mp4
# 16:51:59 - Video 2/26: 100 - 2 - Week 1_ Why Study Google and the Media%3F (Lecture 1.1, 11_42).mp4
# 16:51:59 - Video 3/26: 100 - 3 - Week 1_ Google, Google Everywhere (Lecture 1.2, 10_03).mp4
# 16:52:00 - Video 4/26: 100 - 4 - Week 1_ Google+ Hangout with Jeff Jarvis (Lecture 1.3, 22_03).mp4
# 16:52:00 - Video 5/26: 100 - 5 - Week 1_ What Are You Searching For%3F (Lecture 1.4, 8_03).mp4
# 16:52:00 - Video 6/26: 100 - 6 - Week 1_ Search and Research (Lecture 1.5, 13_30).mp4
# 16:52:01 - Video 7/26: 200 - 1 - Week 2_ Google and News (Lecture 2.1, 8_45).mp4
# 16:52:01 - Video 8/26: 200 - 2 - Week 2_ The New(ish) News Economy (Lecture 2.2, 10_58).mp4
# 16:52:01 - Video 9/26: 200 - 3 - Week 2_ Google and Books (Lecture 2.3, 10_13).mp4
# 16:52:02 - Video 10/26: 200 - 4 - Week 2_ Google+ Hangout with Siva Vaidhyanathan (Lecture 2.4, 26_19).mp4
# 16:52:02 - Video 11/26: 300 - 1 - Week 3_ Google and Advertising_ What Are You Buying%3F (Lecture 3.1, 13_52).mp4
# 16:52:02 - Video 12/26: 300 - 2 - Week 3_ Google, Personalization, and Privacy (Lecture 3.2, 15_25).mp4
# 16:52:02 - Video 13/26: 300 - 3 - Week 3_ Google+ Hangout with Ted Shergalis (Lecture 3.3, 15_30).mp4
# 16:52:03 - Video 14/26: 400 - 1 - Week 4_ Google, YouTube, and You (Lecture 4-1.1, 13_37).mp4
# 16:52:03 - Video 15/26: 400 - 1 - Week 4_ Google, YouTube, and You (Lecture 4.1, 13_37).mp4
# 16:52:03 - Video 16/26: 400 - 2 - Week 4_ YouTube (and Google) and the News (Lecture 4-1.2, 14_25).mp4
# 16:52:04 - Video 17/26: 400 - 2 - Week 4_ YouTube (and Google) and the News (Lecture 4.2, 14_25).mp4
# 16:52:04 - Video 18/26: 500 - 1 - Week 5_ We%5C're Mobile, We%5C're Smarter-1...Aren%5C't We%3F (Lecture 5.1, 13_52).mp4
# 16:52:04 - Video 19/26: 500 - 1 - Week 5_ We%5C're Mobile, We%5C're Smarter...Aren%5C't We%3F (Lecture 5.1, 13_52).mp4
# 16:52:05 - Video 20/26: 500 - 2 - Week 5_ Where Next%3F (Is %5C%22Wear%5C%22 Next%3F) (Lecture 5-1.2, 13_47).mp4
# 16:52:05 - Video 21/26: 500 - 2 - Week 5_ Where Next%3F (Is %5C%22Wear%5C%22 Next%3F) (Lecture 5.2, 13_47).mp4
# 16:52:05 - Video 22/26: 500 - 3 - Week 5_ Conversations with Steven Levy (Lecture 5-1.3, 17_39).mp4
# 16:52:05 - Video 23/26: 500 - 3 - Week 5_ Conversations with Steven Levy (Lecture 5.3, 17_39).mp4
# 16:52:06 - Video 24/26: 600 - 1 - Week 6_ The Social Circle (Lecture 6.1, 16_35).mp4
# 16:52:06 - Video 25/26: 600 - 2 - Week 6_ The Private, The Public, The Politic(s) (Lecture 6.2, 16_46).mp4
# 16:52:06 - Video 26/26: 600 - 3 - Week 6_ Google+ Hangouts on Privacy with Jeff Jarvis and Siva Vaidhyanathan (Lecture 6.3, 27_15).mp4
# 16:52:06 -
# Total expected duration: 22854.36 seconds
# 17:07:38 - Output duration (13544.70s) doesn't match expected (22854.36s)
# 17:07:38 - Failed to merge videos
# 17:07:38 -
# Processing tutorial: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Google\Google\Lynda\Google Tag Manager
# 17:07:38 -
# Processing tutorial folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Google\Google\Lynda\Google Tag Manager
# 17:07:38 - Found 23 videos:
# 17:07:38 -   - 1.Introduction\01.Welcome.mp4
# 17:07:38 -   - 1.Introduction\02.Understanding Google Tag Manager (GTM).mp4
# 17:07:38 -   - 1.Introduction\03.Understanding the GTM hierarchy.mp4
# 17:07:38 -   - 2.1. Work with Accounts and Containers\04.Understanding permissions and security.mp4
# 17:07:38 -   - 2.1. Work with Accounts and Containers\05.Create an account and container.mp4
# 17:07:38 -   - 2.1. Work with Accounts and Containers\06.Install your first container.mp4
# 17:07:38 -   - 2.1. Work with Accounts and Containers\07.Install a container on WordPress (CMS).mp4
# 17:07:38 -   - 3.2. Using Built-In Tags\08.Leveraging the Google Analytics built-in tags.mp4
# 17:07:38 -   - 3.2. Using Built-In Tags\09.Crazy Egg and other built-in tags.mp4
# 17:07:38 -   - 4.3. Work with Variables\10.Understanding basic variables.mp4
# 17:07:38 -   - 4.3. Work with Variables\11.Utilize built-in variables.mp4
# 17:07:38 -   - 4.3. Work with Variables\12.Create custom variables.mp4
# 17:07:38 -   - 4.3. Work with Variables\13.JavaScript and dynamic variables.mp4
# 17:07:38 -   - 5.4. Create Triggers\14.Understanding triggers.mp4
# 17:07:38 -   - 5.4. Create Triggers\15.Fire Google Analytics events using triggers.mp4
# 17:07:38 -   - 6.5. Control Versioning\16.Create versions and view publishing history.mp4
# 17:07:38 -   - 6.5. Control Versioning\17.Import and export configurations.mp4
# 17:07:38 -   - 7.6. Debug Your Tags\18.Using Preview and Debug modes.mp4
# 17:07:38 -   - 7.6. Debug Your Tags\19.Using WASP to debug.mp4
# 17:07:38 -   - 8.7. Use Custom HTML Tags\20.Understanding and using custom HTML tags.mp4
# 17:07:38 -   - 8.7. Use Custom HTML Tags\21.Understanding and using custom Image tags.mp4
# 17:07:38 -   - 8.7. Use Custom HTML Tags\22.Best practices for custom HTML tags.mp4
# 17:07:38 -   - 9.Conclusion\23.Next steps.mp4
# 17:07:38 - Generated title: Google - Google - Lynda - Google Tag Manager
# 17:07:38 - Starting video merge...
# 17:07:38 -
# Analyzing 23 videos for merge:
# 17:07:38 - Video 1/23: 1.Introduction\01.Welcome.mp4
# 17:07:38 - Video 2/23: 1.Introduction\02.Understanding Google Tag Manager (GTM).mp4
# 17:07:39 - Video 3/23: 1.Introduction\03.Understanding the GTM hierarchy.mp4
# 17:07:39 - Video 4/23: 2.1. Work with Accounts and Containers\04.Understanding permissions and security.mp4
# 17:07:39 - Video 5/23: 2.1. Work with Accounts and Containers\05.Create an account and container.mp4
# 17:07:40 - Video 6/23: 2.1. Work with Accounts and Containers\06.Install your first container.mp4
# 17:07:40 - Video 7/23: 2.1. Work with Accounts and Containers\07.Install a container on WordPress (CMS).mp4
# 17:07:40 - Video 8/23: 3.2. Using Built-In Tags\08.Leveraging the Google Analytics built-in tags.mp4
# 17:07:40 - Video 9/23: 3.2. Using Built-In Tags\09.Crazy Egg and other built-in tags.mp4
# 17:07:41 - Video 10/23: 4.3. Work with Variables\10.Understanding basic variables.mp4
# 17:07:41 - Video 11/23: 4.3. Work with Variables\11.Utilize built-in variables.mp4
# 17:07:41 - Video 12/23: 4.3. Work with Variables\12.Create custom variables.mp4
# 17:07:42 - Video 13/23: 4.3. Work with Variables\13.JavaScript and dynamic variables.mp4
# 17:07:42 - Video 14/23: 5.4. Create Triggers\14.Understanding triggers.mp4
# 17:07:42 - Video 15/23: 5.4. Create Triggers\15.Fire Google Analytics events using triggers.mp4
# 17:07:43 - Video 16/23: 6.5. Control Versioning\16.Create versions and view publishing history.mp4
# 17:07:43 - Video 17/23: 6.5. Control Versioning\17.Import and export configurations.mp4
# 17:07:43 - Video 18/23: 7.6. Debug Your Tags\18.Using Preview and Debug modes.mp4
# 17:07:44 - Video 19/23: 7.6. Debug Your Tags\19.Using WASP to debug.mp4
# 17:07:44 - Video 20/23: 8.7. Use Custom HTML Tags\20.Understanding and using custom HTML tags.mp4
# 17:07:44 - Video 21/23: 8.7. Use Custom HTML Tags\21.Understanding and using custom Image tags.mp4
# 17:07:44 - Video 22/23: 8.7. Use Custom HTML Tags\22.Best practices for custom HTML tags.mp4
# 17:07:45 - Video 23/23: 9.Conclusion\23.Next steps.mp4
# 17:07:45 -
# Total expected duration: 4960.27 seconds
# 17:15:11 - Merge completed successfully! Final video duration: 4960.20 seconds
# 17:15:11 - Videos merged successfully
# 17:15:17 - Upload attempt 1/3
# 17:15:17 - Starting upload: Google - Google - Lynda - Google Tag Manager
# 17:15:23 - Upload progress: 8%
# 17:15:27 - Upload progress: 16%
# 17:15:31 - Upload progress: 24%
# 17:15:35 - Upload progress: 32%
# 17:15:39 - Upload progress: 40%
# 17:15:43 - Upload progress: 48%
# 17:15:46 - Upload progress: 56%
# 17:15:50 - Upload progress: 65%
# 17:15:54 - Upload progress: 73%
# 17:15:58 - Upload progress: 81%
# 17:16:02 - Upload progress: 89%
# 17:16:06 - Upload progress: 97%
# 17:16:07 - Upload completed successfully
# 17:16:07 - Upload successful! Video ID: mYjB5CDeSSw
# 17:16:07 - Video URL: https://www.youtube.com/watch?v=mYjB5CDeSSw
# 17:16:08 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Google\Google\Lynda\Google Tag Manager\1.Introduction
# 17:16:08 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Google\Google\Lynda\Google Tag Manager\2.1. Work with Accounts and Containers
# 17:16:08 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Google\Google\Lynda\Google Tag Manager\3.2. Using Built-In Tags
# 17:16:08 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Google\Google\Lynda\Google Tag Manager\4.3. Work with Variables
# 17:16:08 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Google\Google\Lynda\Google Tag Manager\5.4. Create Triggers
# 17:16:08 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Google\Google\Lynda\Google Tag Manager\6.5. Control Versioning
# 17:16:08 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Google\Google\Lynda\Google Tag Manager\7.6. Debug Your Tags
# 17:16:08 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Google\Google\Lynda\Google Tag Manager\8.7. Use Custom HTML Tags
# 17:16:08 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Google\Google\Lynda\Google Tag Manager\9.Conclusion
# 17:16:08 - Deleted 9 folders containing videos
# 17:16:08 - Successfully deleted all video folders
# 17:16:08 - Cleaned up merged video file: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Google\Google\Lynda\Google Tag Manager\Google_merged.mp4
# 17:16:08 -
# Processing tutorial: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Google\Google\Udemy\Google Advanced Search - Find Stuff Like A Boss
# 17:16:08 -
# Processing tutorial folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Google\Google\Udemy\Google Advanced Search - Find Stuff Like A Boss
# 17:16:08 - Found 31 videos:
# 17:16:08 -   - 1-Welcome\01-Welcome.mp4
# 17:16:08 -   - 1-Welcome\02-Default_Search_Settings.mp4
# 17:16:08 -   - 2-Google_Logical_Operators\03-How_to_use_the_AND_logical_operator.mp4
# 17:16:08 -   - 2-Google_Logical_Operators\04-Examples_using_AND.mp4
# 17:16:08 -   - 2-Google_Logical_Operators\05-How_to_use_the_OR_logical_operator.mp4
# 17:16:08 -   - 2-Google_Logical_Operators\06-Examples_using_OR.mp4
# 17:16:08 -   - 2-Google_Logical_Operators\07-How_to_use_the_NOT_logical_operator.mp4
# 17:16:08 -   - 2-Google_Logical_Operators\08-Examples_using_NOT.mp4
# 17:16:08 -   - 3-Common_Specifiers\09-How_to_use_the_exact_match.mp4
# 17:16:08 -   - 3-Common_Specifiers\10-Examples_using_the_exact_match.mp4
# 17:16:08 -   - 3-Common_Specifiers\11-How_to_use_the_placeholder.mp4
# 17:16:08 -   - 3-Common_Specifiers\12-Examples_using_the_placeholder.mp4
# 17:16:08 -   - 3-Common_Specifiers\13-How_to_use_the_range.mp4
# 17:16:08 -   - 3-Common_Specifiers\14-Examples_using_the_range.mp4
# 17:16:08 -   - 4-Google_Shortcut_Specifiers\15-How_to_define_and_translate_word_expressions.mp4
# 17:16:08 -   - 4-Google_Shortcut_Specifiers\16-How_to_get_the_weather_time_and_coordinates_of_any_place.mp4
# 17:16:08 -   - 4-Google_Shortcut_Specifiers\17-How_to_activate_and_use_the_internal_calculator.mp4
# 17:16:08 -   - 4-Google_Shortcut_Specifiers\18-How_to_convert_units_of_measurement.mp4
# 17:16:08 -   - 5-Google_Sites_and_Documents_specifiers\19-How_to_get_results_from_a_URL.mp4
# 17:16:08 -   - 5-Google_Sites_and_Documents_specifiers\20-How_to_get_files_of_a_specific_type.mp4
# 17:16:08 -   - 5-Google_Sites_and_Documents_specifiers\21-How_to_find_related_websites.mp4
# 17:16:08 -   - 5-Google_Sites_and_Documents_specifiers\22-How_to_find_links_pointing_to_a_URL.mp4
# 17:16:08 -   - 5-Google_Sites_and_Documents_specifiers\23-How_to_retrieve_the_cached_version_of_a_webpage.mp4
# 17:16:08 -   - 5-Google_Sites_and_Documents_specifiers\24-How_to_get_additional_information_about_a_URL.mp4
# 17:16:08 -   - 6-Google_Metadata_Specifiers\25-How_to_filter_results_by_URL.mp4
# 17:16:08 -   - 6-Google_Metadata_Specifiers\26-How_to_filter_results_by_title.mp4
# 17:16:08 -   - 6-Google_Metadata_Specifiers\27-How_to_filter_results_by_clickable_text.mp4
# 17:16:08 -   - 6-Google_Metadata_Specifiers\28-How_to_filter_results_by_text.mp4
# 17:16:08 -   - 7-Google_Advanced_Search_Interfance_and_Custom_Settings\29-How_to_use_the_Google_Advanced_Search_Interface.mp4
# 17:16:08 -   - 7-Google_Advanced_Search_Interfance_and_Custom_Settings\30-How_to_set_your_Google_Search_preferences.mp4
# 17:16:08 -   - 8-Conclusion\31-Everything_youve_learned_so_far.mp4
# 17:16:08 - Generated title: Google - Google - Udemy - Google Advanced Search - Find Stuff Like A Boss
# 17:16:08 - Starting video merge...
# 17:16:08 -
# Analyzing 31 videos for merge:
# 17:16:08 - Video 1/31: 1-Welcome\01-Welcome.mp4
# 17:16:09 - Video 2/31: 1-Welcome\02-Default_Search_Settings.mp4
# 17:16:09 - Video 3/31: 2-Google_Logical_Operators\03-How_to_use_the_AND_logical_operator.mp4
# 17:16:09 - Video 4/31: 2-Google_Logical_Operators\04-Examples_using_AND.mp4
# 17:16:10 - Video 5/31: 2-Google_Logical_Operators\05-How_to_use_the_OR_logical_operator.mp4
# 17:16:10 - Video 6/31: 2-Google_Logical_Operators\06-Examples_using_OR.mp4
# 17:16:11 - Video 7/31: 2-Google_Logical_Operators\07-How_to_use_the_NOT_logical_operator.mp4
# 17:16:11 - Video 8/31: 2-Google_Logical_Operators\08-Examples_using_NOT.mp4
# 17:16:11 - Video 9/31: 3-Common_Specifiers\09-How_to_use_the_exact_match.mp4
# 17:16:12 - Video 10/31: 3-Common_Specifiers\10-Examples_using_the_exact_match.mp4
# 17:16:12 - Video 11/31: 3-Common_Specifiers\11-How_to_use_the_placeholder.mp4
# 17:16:12 - Video 12/31: 3-Common_Specifiers\12-Examples_using_the_placeholder.mp4
# 17:16:13 - Video 13/31: 3-Common_Specifiers\13-How_to_use_the_range.mp4
# 17:16:13 - Video 14/31: 3-Common_Specifiers\14-Examples_using_the_range.mp4
# 17:16:13 - Video 15/31: 4-Google_Shortcut_Specifiers\15-How_to_define_and_translate_word_expressions.mp4
# 17:16:14 - Video 16/31: 4-Google_Shortcut_Specifiers\16-How_to_get_the_weather_time_and_coordinates_of_any_place.mp4
# 17:16:14 - Video 17/31: 4-Google_Shortcut_Specifiers\17-How_to_activate_and_use_the_internal_calculator.mp4
# 17:16:15 - Video 18/31: 4-Google_Shortcut_Specifiers\18-How_to_convert_units_of_measurement.mp4
# 17:16:15 - Video 19/31: 5-Google_Sites_and_Documents_specifiers\19-How_to_get_results_from_a_URL.mp4
# 17:16:16 - Video 20/31: 5-Google_Sites_and_Documents_specifiers\20-How_to_get_files_of_a_specific_type.mp4
# 17:16:16 - Video 21/31: 5-Google_Sites_and_Documents_specifiers\21-How_to_find_related_websites.mp4
# 17:16:16 - Video 22/31: 5-Google_Sites_and_Documents_specifiers\22-How_to_find_links_pointing_to_a_URL.mp4
# 17:16:17 - Video 23/31: 5-Google_Sites_and_Documents_specifiers\23-How_to_retrieve_the_cached_version_of_a_webpage.mp4
# 17:16:17 - Video 24/31: 5-Google_Sites_and_Documents_specifiers\24-How_to_get_additional_information_about_a_URL.mp4
# 17:16:17 - Video 25/31: 6-Google_Metadata_Specifiers\25-How_to_filter_results_by_URL.mp4
# 17:16:18 - Video 26/31: 6-Google_Metadata_Specifiers\26-How_to_filter_results_by_title.mp4
# 17:16:18 - Video 27/31: 6-Google_Metadata_Specifiers\27-How_to_filter_results_by_clickable_text.mp4
# 17:16:19 - Video 28/31: 6-Google_Metadata_Specifiers\28-How_to_filter_results_by_text.mp4
# 17:16:19 - Video 29/31: 7-Google_Advanced_Search_Interfance_and_Custom_Settings\29-How_to_use_the_Google_Advanced_Search_Interface.mp4
# 17:16:19 - Video 30/31: 7-Google_Advanced_Search_Interfance_and_Custom_Settings\30-How_to_set_your_Google_Search_preferences.mp4
# 17:16:19 - Video 31/31: 8-Conclusion\31-Everything_youve_learned_so_far.mp4
# 17:16:19 -
# Total expected duration: 5074.02 seconds
# 17:28:06 - Merge completed successfully! Final video duration: 5074.00 seconds
# 17:28:06 - Videos merged successfully
# 17:28:16 - Upload attempt 1/3
# 17:28:16 - Starting upload: Google - Google - Udemy - Google Advanced Search - Find Stuff Like A Boss
# 17:28:21 - Upload progress: 1%
# 17:28:24 - Upload progress: 3%
# 17:28:28 - Upload progress: 5%
# 17:28:31 - Upload progress: 6%
# 17:28:35 - Upload progress: 8%
# 17:28:39 - Upload progress: 10%
# 17:28:42 - Upload progress: 11%
# 17:28:46 - Upload progress: 13%
# 17:28:50 - Upload progress: 15%
# 17:28:54 - Upload progress: 17%
# 17:28:57 - Upload progress: 18%
# 17:29:01 - Upload progress: 20%
# 17:29:05 - Upload progress: 22%
# 17:29:08 - Upload progress: 23%
# 17:29:12 - Upload progress: 25%
# 17:29:16 - Upload progress: 27%
# 17:29:19 - Upload progress: 29%
# 17:29:23 - Upload progress: 30%
# 17:29:27 - Upload progress: 32%
# 17:29:31 - Upload progress: 34%
# 17:29:34 - Upload progress: 35%
# 17:29:38 - Upload progress: 37%
# 17:29:42 - Upload progress: 39%
# 17:29:45 - Upload progress: 40%
# 17:29:49 - Upload progress: 42%
# 17:29:53 - Upload progress: 44%
# 17:29:56 - Upload progress: 46%
# 17:30:00 - Upload progress: 47%
# 17:30:04 - Upload progress: 49%
# 17:30:07 - Upload progress: 51%
# 17:30:11 - Upload progress: 52%
# 17:30:15 - Upload progress: 54%
# 17:30:18 - Upload progress: 56%
# 17:30:23 - Upload progress: 58%
# 17:30:26 - Upload progress: 59%
# 17:30:31 - Upload progress: 61%
# 17:30:35 - Upload progress: 63%
# 17:30:39 - Upload progress: 64%
# 17:30:42 - Upload progress: 66%
# 17:30:46 - Upload progress: 68%
# 17:30:49 - Upload progress: 69%
# 17:31:09 - Upload progress: 71%
# 17:31:13 - Upload progress: 73%
# 17:31:17 - Upload progress: 75%
# 17:31:21 - Upload progress: 76%
# 17:31:25 - Upload progress: 78%
# 17:31:28 - Upload progress: 80%
# 17:31:32 - Upload progress: 81%
# 17:31:36 - Upload progress: 83%
# 17:31:40 - Upload progress: 85%
# 17:31:44 - Upload progress: 87%
# 17:31:47 - Upload progress: 88%
# 17:31:52 - Upload progress: 90%
# 17:31:56 - Upload progress: 92%
# 17:32:00 - Upload progress: 93%
# 17:32:04 - Upload progress: 95%
# 17:32:07 - Upload progress: 97%
# 17:32:12 - Upload progress: 98%
# 17:32:16 - Upload completed successfully
# 17:32:16 - Upload successful! Video ID: 2zgvSFOPuDA
# 17:32:16 - Video URL: https://www.youtube.com/watch?v=2zgvSFOPuDA
# 17:32:16 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Google\Google\Udemy\Google Advanced Search - Find Stuff Like A Boss\1-Welcome
# 17:32:16 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Google\Google\Udemy\Google Advanced Search - Find Stuff Like A Boss\2-Google_Logical_Operators
# 17:32:16 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Google\Google\Udemy\Google Advanced Search - Find Stuff Like A Boss\3-Common_Specifiers
# 17:32:16 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Google\Google\Udemy\Google Advanced Search - Find Stuff Like A Boss\4-Google_Shortcut_Specifiers
# 17:32:16 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Google\Google\Udemy\Google Advanced Search - Find Stuff Like A Boss\5-Google_Sites_and_Documents_specifiers
# 17:32:16 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Google\Google\Udemy\Google Advanced Search - Find Stuff Like A Boss\6-Google_Metadata_Specifiers
# 17:32:16 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Google\Google\Udemy\Google Advanced Search - Find Stuff Like A Boss\7-Google_Advanced_Search_Interfance_and_Custom_Settings
# 17:32:16 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Google\Google\Udemy\Google Advanced Search - Find Stuff Like A Boss\8-Conclusion
# 17:32:16 - Deleted 8 folders containing videos
# 17:32:16 - Successfully deleted all video folders
# 17:32:16 - Cleaned up merged video file: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Google\Google\Udemy\Google Advanced Search - Find Stuff Like A Boss\Google__merged.mp4
# 17:32:16 -
# Processing tutorial: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Google\Google\Udemy\Google Seo For Images - Simple Search Engine Growth Hacking
# 17:32:16 -
# Processing tutorial folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Google\Google\Udemy\Google Seo For Images - Simple Search Engine Growth Hacking
# 17:32:16 - Found 32 videos:
# 17:32:16 -   - 1-Introduction\01-Introduction.mp4
# 17:32:16 -   - 1-Introduction\02-Course_Overview.mp4
# 17:32:16 -   - 1-Introduction\03-Why_is_Image_SEO_Important.mp4
# 17:32:16 -   - 1-Introduction\04-Benefits_of_Image_SEO.mp4
# 17:32:16 -   - 1-Introduction\05-Elements_of_Image_Optimization.mp4
# 17:32:16 -   - 1-Introduction\06-Who_NEEDS_Image_SEO.mp4
# 17:32:16 -   - 1-Introduction\07-Types_of_Image_Files.mp4
# 17:32:16 -   - 1-Introduction\08-What_Types_of_Images_Can_I_Use.mp4
# 17:32:16 -   - 1-Introduction\09-Check_for_Image_Packs.mp4
# 17:32:16 -   - 2-Image_SEO_Ranking_Factors\10-Image_File_Name.mp4
# 17:32:16 -   - 2-Image_SEO_Ranking_Factors\11-Image_alt_text.mp4
# 17:32:16 -   - 2-Image_SEO_Ranking_Factors\12-Image_Title_Text_(NOT_an_SEO_Factor).mp4
# 17:32:16 -   - 2-Image_SEO_Ranking_Factors\13-Captions.mp4
# 17:32:16 -   - 2-Image_SEO_Ranking_Factors\14-Related_Surrounding_Text.mp4
# 17:32:16 -   - 2-Image_SEO_Ranking_Factors\15-Are_your_images_mobile-friendly.mp4
# 17:32:16 -   - 2-Image_SEO_Ranking_Factors\16-Image_Sizes.mp4
# 17:32:16 -   - 2-Image_SEO_Ranking_Factors\17-ImageOptim.mp4
# 17:32:16 -   - 2-Image_SEO_Ranking_Factors\18-Image_Dimensions_and_Size.mp4
# 17:32:16 -   - 2-Image_SEO_Ranking_Factors\19-Compress_Image_File_Sizes.mp4
# 17:32:16 -   - 2-Image_SEO_Ranking_Factors\20-Domain_Authority_and_Popularity.mp4
# 17:32:16 -   - 3-How_to_Do_Image_Optimization\21-Examine_Keywords_for_Image_Possibilities.mp4
# 17:32:16 -   - 3-How_to_Do_Image_Optimization\22-Image_Optimization_Process.mp4
# 17:32:16 -   - 3-How_to_Do_Image_Optimization\23-Remove_EXIF_Data.mp4
# 17:32:16 -   - 3-How_to_Do_Image_Optimization\24-Creating_an_Image_Sitemap.mp4
# 17:32:16 -   - 3-How_to_Do_Image_Optimization\25-Image_Audit.mp4
# 17:32:16 -   - 4-Image_SEO_FAQ\26-Is_It_Okay_to_Use_Stock_Photos.mp4
# 17:32:16 -   - 4-Image_SEO_FAQ\27-How_Can_I_Enhance_Stock_Photos.mp4
# 17:32:16 -   - 4-Image_SEO_FAQ\28-A_word_about_iPhone_photos.mp4
# 17:32:16 -   - 4-Image_SEO_FAQ\29-What_About_Copyrights_and_Usage_Rights.mp4
# 17:32:16 -   - 4-Image_SEO_FAQ\30-How_to_Protect_Your_Images.mp4
# 17:32:16 -   - 5-BONUS_-_Image_SEO_for_Social_Media\31-Social_Media_Image_Optimization_Resources.mp4
# 17:32:16 -   - 6-Conclusion\32-Conclusion.mp4
# 17:32:16 - Generated title: Google - Google - Udemy - Google Seo For Images - Simple Search Engine Growth Hacking
# 17:32:16 - Starting video merge...
# 17:32:16 -
# Analyzing 32 videos for merge:
# 17:32:16 - Video 1/32: 1-Introduction\01-Introduction.mp4
# 17:32:17 - Video 2/32: 1-Introduction\02-Course_Overview.mp4
# 17:32:17 - Video 3/32: 1-Introduction\03-Why_is_Image_SEO_Important.mp4
# 17:32:17 - Video 4/32: 1-Introduction\04-Benefits_of_Image_SEO.mp4
# 17:32:18 - Video 5/32: 1-Introduction\05-Elements_of_Image_Optimization.mp4
# 17:32:18 - Video 6/32: 1-Introduction\06-Who_NEEDS_Image_SEO.mp4
# 17:32:18 - Video 7/32: 1-Introduction\07-Types_of_Image_Files.mp4
# 17:32:19 - Video 8/32: 1-Introduction\08-What_Types_of_Images_Can_I_Use.mp4
# 17:32:19 - Video 9/32: 1-Introduction\09-Check_for_Image_Packs.mp4
# 17:32:19 - Video 10/32: 2-Image_SEO_Ranking_Factors\10-Image_File_Name.mp4
# 17:32:19 - Video 11/32: 2-Image_SEO_Ranking_Factors\11-Image_alt_text.mp4
# 17:32:20 - Video 12/32: 2-Image_SEO_Ranking_Factors\12-Image_Title_Text_(NOT_an_SEO_Factor).mp4
# 17:32:20 - Video 13/32: 2-Image_SEO_Ranking_Factors\13-Captions.mp4
# 17:32:20 - Video 14/32: 2-Image_SEO_Ranking_Factors\14-Related_Surrounding_Text.mp4
# 17:32:21 - Video 15/32: 2-Image_SEO_Ranking_Factors\15-Are_your_images_mobile-friendly.mp4
# 17:32:21 - Video 16/32: 2-Image_SEO_Ranking_Factors\16-Image_Sizes.mp4
# 17:32:21 - Video 17/32: 2-Image_SEO_Ranking_Factors\17-ImageOptim.mp4
# 17:32:22 - Video 18/32: 2-Image_SEO_Ranking_Factors\18-Image_Dimensions_and_Size.mp4
# 17:32:22 - Video 19/32: 2-Image_SEO_Ranking_Factors\19-Compress_Image_File_Sizes.mp4
# 17:32:22 - Video 20/32: 2-Image_SEO_Ranking_Factors\20-Domain_Authority_and_Popularity.mp4
# 17:32:23 - Video 21/32: 3-How_to_Do_Image_Optimization\21-Examine_Keywords_for_Image_Possibilities.mp4
# 17:32:23 - Video 22/32: 3-How_to_Do_Image_Optimization\22-Image_Optimization_Process.mp4
# 17:32:23 - Video 23/32: 3-How_to_Do_Image_Optimization\23-Remove_EXIF_Data.mp4
# 17:32:23 - Video 24/32: 3-How_to_Do_Image_Optimization\24-Creating_an_Image_Sitemap.mp4
# 17:32:24 - Video 25/32: 3-How_to_Do_Image_Optimization\25-Image_Audit.mp4
# 17:32:24 - Video 26/32: 4-Image_SEO_FAQ\26-Is_It_Okay_to_Use_Stock_Photos.mp4
# 17:32:24 - Video 27/32: 4-Image_SEO_FAQ\27-How_Can_I_Enhance_Stock_Photos.mp4
# 17:32:25 - Video 28/32: 4-Image_SEO_FAQ\28-A_word_about_iPhone_photos.mp4
# 17:32:25 - Video 29/32: 4-Image_SEO_FAQ\29-What_About_Copyrights_and_Usage_Rights.mp4
# 17:32:25 - Video 30/32: 4-Image_SEO_FAQ\30-How_to_Protect_Your_Images.mp4
# 17:32:25 - Video 31/32: 5-BONUS_-_Image_SEO_for_Social_Media\31-Social_Media_Image_Optimization_Resources.mp4
# 17:32:26 - Video 32/32: 6-Conclusion\32-Conclusion.mp4
# 17:32:26 -
# Total expected duration: 9394.23 seconds
# 17:43:49 - Output duration (4550306.27s) doesn't match expected (9394.23s)
# 17:43:49 - Failed to merge videos
