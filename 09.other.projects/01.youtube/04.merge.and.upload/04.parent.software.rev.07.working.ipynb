# %%
#!/usr/bin/env python3
import os
import glob
import json
import time
import shutil
import logging
import re
from datetime import datetime
import subprocess
from pathlib import Path
from typing import List, Dict, Optional, Tuple
import ffmpeg
import tkinter as tk
from tkinter import ttk, messagebox
import ssl
import httplib2
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload
from googleapiclient.errors import HttpError

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(message)s',
    datefmt='%H:%M:%S',
    handlers=[
        logging.FileHandler('video_processing.log', encoding='utf-8'),
        logging.StreamHandler()
    ]
)

TOKEN_FILE = "token.json"
SCOPES = ["https://www.googleapis.com/auth/youtube.upload"]

class ProgressWindow:
    def __init__(self, title="Progress", parent=None):
        self.root = tk.Toplevel(parent) if parent else tk.Tk()
        self.root.title(title)
        self.root.geometry("600x200")
        
        # Center the window
        self.root.update_idletasks()
        width = self.root.winfo_width()
        height = self.root.winfo_height()
        x = (self.root.winfo_screenwidth() // 2) - (width // 2)
        y = (self.root.winfo_screenheight() // 2) - (height // 2)
        self.root.geometry(f'+{x}+{y}')
        
        # Make window stay on top
        self.root.attributes('-topmost', True)
        
        # Create main frame
        main_frame = ttk.Frame(self.root, padding="10")
        main_frame.pack(fill=tk.BOTH, expand=True)
        
        # Status label
        self.status_var = tk.StringVar(value="Initializing...")
        self.status_label = ttk.Label(main_frame, textvariable=self.status_var)
        self.status_label.pack(pady=(0, 5))
        
        # Progress bar
        self.progress_var = tk.DoubleVar(value=0)
        self.progress_bar = ttk.Progressbar(
            main_frame, 
            variable=self.progress_var,
            maximum=100,
            length=500
        )
        self.progress_bar.pack(pady=5)
        
        # Details frame
        details_frame = ttk.LabelFrame(main_frame, text="Details", padding="5")
        details_frame.pack(fill=tk.X, pady=5)
        
        # Time info
        time_frame = ttk.Frame(details_frame)
        time_frame.pack(fill=tk.X, pady=2)
        
        self.elapsed_var = tk.StringVar(value="Elapsed: 0:00:00")
        self.remaining_var = tk.StringVar(value="Remaining: --:--:--")
        
        ttk.Label(time_frame, textvariable=self.elapsed_var).pack(side=tk.LEFT, padx=5)
        ttk.Label(time_frame, textvariable=self.remaining_var).pack(side=tk.RIGHT, padx=5)
        
        # Stats frame
        stats_frame = ttk.Frame(details_frame)
        stats_frame.pack(fill=tk.X, pady=2)
        
        self.speed_var = tk.StringVar(value="Speed: --")
        self.size_var = tk.StringVar(value="Size: --")
        
        ttk.Label(stats_frame, textvariable=self.speed_var).pack(side=tk.LEFT, padx=5)
        ttk.Label(stats_frame, textvariable=self.size_var).pack(side=tk.RIGHT, padx=5)
        
        self.start_time = time.time()
        self.root.protocol("WM_DELETE_WINDOW", self.on_closing)
        self.allow_close = False

    def on_closing(self):
        if self.allow_close:
            self.root.destroy()

    def update_progress(self, current_duration: float, total_duration: float, 
                       speed: str = "", size: str = "", status: str = None):
        """Update progress bar and stats."""
        if status:
            self.status_var.set(status)
        
        # Update progress bar
        progress = (current_duration / total_duration * 100) if total_duration > 0 else 0
        self.progress_var.set(progress)
        
        # Update elapsed time
        elapsed = time.time() - self.start_time
        elapsed_str = time.strftime('%H:%M:%S', time.gmtime(elapsed))
        self.elapsed_var.set(f"Elapsed: {elapsed_str}")
        
        # Update estimated remaining time
        if progress > 0:
            total_estimated = elapsed / (progress / 100)
            remaining = total_estimated - elapsed
            remaining_str = time.strftime('%H:%M:%S', time.gmtime(remaining))
            self.remaining_var.set(f"Remaining: {remaining_str}")
        
        # Update speed and size
        if speed:
            self.speed_var.set(f"Speed: {speed}")
        if size:
            self.size_var.set(f"Size: {size}")
        
        # Update the window
        self.root.update()

    def close(self):
        """Allow and perform window close."""
        self.allow_close = True
        self.root.destroy()

def get_folder_path_gui() -> str:
    """Create a Tkinter window to get the folder path."""
    try:
        def on_submit():
            window.quit()

        # Create the main window
        window = tk.Tk()
        window.title("Enter Folder Path")
        window.geometry("800x150")  # Make window wider for long paths
        
        # Create and pack a frame
        frame = ttk.Frame(window, padding="10")
        frame.pack(fill=tk.BOTH, expand=True)
        
        # Create label
        ttk.Label(frame, text="Enter the full path to the tutorials folder:").pack(pady=5)
        
        # Create entry field
        path_var = tk.StringVar()
        entry = ttk.Entry(frame, textvariable=path_var, width=100)  # Make entry field wider
        entry.pack(pady=5, fill=tk.X)
        
        # Create submit button
        ttk.Button(frame, text="Submit", command=on_submit).pack(pady=10)
        
        # Focus on entry field and bind Enter key
        entry.focus()
        window.bind('<Return>', lambda e: on_submit())
        
        # Bring window to front
        window.lift()
        window.attributes('-topmost', True)
        window.attributes('-topmost', False)
        
        # Start the window
        window.mainloop()
        
        # Get the path and destroy the window
        path = path_var.get().strip()
        window.destroy()
        return path
        
    except Exception as e:
        logging.error(f"Error creating GUI window: {str(e)}")
        # Fallback to console input if GUI fails
        return input("Enter folder path (GUI failed): ")

def authenticate_youtube(client_secrets_file: str) -> Optional[object]:
    """Authenticate with YouTube as the very first step."""
    try:
        print("\nChecking YouTube authentication...")
        if not os.path.exists(client_secrets_file):
            print("Error: Client secrets file not found")
            return None
            
        creds = None
        # Check if token file exists
        if os.path.exists(TOKEN_FILE):
            try:
                creds = Credentials.from_authorized_user_file(TOKEN_FILE, SCOPES)
                print("Found existing token")
            except Exception as e:
                print(f"Error loading token: {e}")
                creds = None

        # If token is missing or invalid, refresh or re-authenticate
        if not creds or not creds.valid:
            if creds and creds.expired and creds.refresh_token:
                try:
                    print("Token expired, refreshing...")
                    creds.refresh(Request())
                    print("Token refreshed successfully")
                except Exception as e:
                    print(f"Token refresh failed: {e}")
                    creds = None

            if not creds:
                print("\nOpening browser for YouTube authentication...")
                print("Please select your Google account and grant access...")
                flow = InstalledAppFlow.from_client_secrets_file(client_secrets_file, SCOPES)
                creds = flow.run_local_server(port=0)

                # Save the new token
                with open(TOKEN_FILE, "w") as token:
                    token.write(creds.to_json())
                print("New token saved")

        # Build and return the YouTube service
        youtube = build("youtube", "v3", credentials=creds)
        print("YouTube authentication successful!")
        return youtube
        
    except Exception as e:
        print(f"Authentication error: {e}")
        return None

def get_structured_title(path: str) -> str:
    """Generate a structured title from the path levels after '05 Tutorials'."""
    try:
        parts = Path(path).parts
        # Find the index of "05 Tutorials"
        for i, part in enumerate(parts):
            if part == "05 Tutorials":
                # Take exactly 4 parts after "05 Tutorials"
                relevant_parts = parts[i+1:i+5]  # This will get: Google, Slides, Lynda, Google Slides Essential Training
                # Join parts and ensure total length is under 100 characters
                title = " - ".join(relevant_parts)
                if len(title) > 95:  # Leave some margin for safety
                    # If too long, take first word of each part except the last one
                    shortened_parts = []
                    for j, part in enumerate(relevant_parts):
                        if j < len(relevant_parts) - 1:
                            # For all parts except the last, take just the first word
                            first_word = part.split()[0]
                            shortened_parts.append(first_word)
                        else:
                            # For the last part (course name), keep more detail but limit length
                            last_part = part[:50]  # Limit last part to 50 chars
                            shortened_parts.append(last_part)
                    title = " - ".join(shortened_parts)
                    # If still too long, truncate to 95 chars
                    if len(title) > 95:
                        title = title[:95]
                return title
        return os.path.basename(path)[:95]  # Fallback with length limit
    except Exception as e:
        logging.error(f"Error in get_structured_title: {str(e)}")
        # Return a safe fallback title
        return os.path.basename(path)[:95]

def is_tutorial_folder(path: str) -> bool:
    """
    Check if this is a level 4 tutorial folder (e.g. 'Google Slides Essential Training').
    Path structure: .../05 Tutorials/level1/level2/level3/level4
    """
    try:
        parts = Path(path).parts
        # Find the index of "05 Tutorials"
        for i, part in enumerate(parts):
            if part == "05 Tutorials":
                # Check if we have exactly 4 levels after "05 Tutorials"
                remaining_parts = parts[i+1:]
                return len(remaining_parts) == 4
        return False
    except Exception as e:
        logging.error(f"Error in is_tutorial_folder: {str(e)}")
        return False

def collect_videos(folder_path: str) -> List[Tuple[str, str]]:
    """Collect all videos from folder and subfolders, sorted by folder structure and filename."""
    video_files = []
    try:
        # Walk through all subdirectories
        for root, _, files in os.walk(folder_path):
            # Filter and sort video files
            video_files.extend(
                (os.path.join(root, f), os.path.relpath(os.path.join(root, f), folder_path))
                for f in sorted(files)
                if f.lower().endswith(('.mp4', '.avi', '.mkv'))
            )
        
        # Sort by full path to maintain folder structure order
        return sorted(video_files, key=lambda x: x[0].lower())
    except Exception as e:
        logging.error(f"Error collecting videos: {str(e)}")
        return []

def get_video_duration(video_path: str) -> Optional[float]:
    """Get video duration using ffprobe with better error handling."""
    try:
        result = subprocess.run(
            ["ffprobe", "-v", "error", 
             "-show_entries", "format=duration",
             "-of", "default=noprint_wrappers=1:nokey=1", 
             video_path],
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            text=True,
            check=True
        )
        duration = float(result.stdout.strip())
        return duration
    except Exception as e:
        logging.warning(f"Could not get duration for {os.path.basename(video_path)}: {str(e)}")
        return None

def generate_timestamps(video_files: List[Tuple[str, str]]) -> str:
    """Generate timestamps for video description with proper duration handling."""
    timestamps = []
    current_time = 0
    
    for full_path, rel_path in video_files:
        duration = get_video_duration(full_path)
        if duration is None:
            logging.warning(f"Skipping timestamp for {rel_path} - could not get duration")
            continue
            
        hours = int(current_time // 3600)
        minutes = int((current_time % 3600) // 60)
        seconds = int(current_time % 60)
        
        timestamp = f"{hours:02d}:{minutes:02d}:{seconds:02d}"
        video_name = os.path.splitext(os.path.basename(rel_path))[0]
        timestamps.append(f"{timestamp} - {video_name}")
        
        current_time += duration
    
    return '\n'.join(timestamps)

def parse_ffmpeg_progress(line: str) -> Dict[str, str]:
    """Parse ffmpeg progress output line."""
    result = {}
    
    # Extract time
    time_match = re.search(r'time=(\d+:\d+:\d+\.\d+)', line)
    if time_match:
        time_str = time_match.group(1)
        h, m, s = time_str.split(':')
        s = float(s)
        result['duration'] = float(h) * 3600 + float(m) * 60 + s
    
    # Extract speed
    speed_match = re.search(r'speed=(\d+\.?\d*x)', line)
    if speed_match:
        result['speed'] = speed_match.group(1)
    
    # Extract size
    size_match = re.search(r'size=\s*(\d+.*?B)', line)
    if size_match:
        result['size'] = size_match.group(1)
    
    return result

def merge_videos(video_files: List[Tuple[str, str]], output_path: str) -> bool:
    """Merge videos using ffmpeg with proper format settings and UI progress bar."""
    progress_window = None
    try:
        # Create file list
        list_path = os.path.join(os.path.dirname(output_path), "file_list.txt")
        with open(list_path, 'w', encoding='utf-8') as f:
            for full_path, _ in video_files:
                f.write(f"file '{full_path}'\n")
        
        # Calculate expected duration
        total_duration = 0
        logging.info(f"\nAnalyzing {len(video_files)} videos for merge:")
        for i, (full_path, rel_path) in enumerate(video_files, 1):
            duration = get_video_duration(full_path) or 0
            total_duration += duration
            logging.info(f"Video {i}/{len(video_files)}: {rel_path}")

        if total_duration == 0:
            logging.error("Could not calculate total duration of videos")
            return False
            
        logging.info(f"\nTotal expected duration: {total_duration:.2f} seconds")
        
        # Create progress window
        progress_window = ProgressWindow("Merging Videos")
        progress_window.update_progress(0, total_duration, status="Starting merge process...")
        
        # Merge videos with specific format settings
        cmd = [
            "ffmpeg",
            "-f", "concat",
            "-safe", "0",
            "-i", list_path,
            "-c:v", "libx264",     # Use H.264 codec
            "-preset", "fast",      # Faster encoding
            "-crf", "23",          # Good quality/size balance
            "-c:a", "aac",         # AAC audio codec
            "-b:a", "128k",        # Audio bitrate
            "-movflags", "+faststart",  # Web playback optimization
            "-stats",              # Print encoding progress
            "-loglevel", "info",   # Show informative messages
            output_path,
            "-y"                   # Overwrite output file
        ]
        
        # Run ffmpeg with progress monitoring
        process = subprocess.Popen(
            cmd,
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            universal_newlines=True,
            bufsize=1
        )

        # Monitor the encoding progress through stderr
        while True:
            stderr_line = process.stderr.readline()
            if not stderr_line and process.poll() is not None:
                break
                
            # Parse progress information
            if "time=" in stderr_line:
                progress_data = parse_ffmpeg_progress(stderr_line)
                if progress_data:
                    current_duration = progress_data.get('duration', 0)
                    speed = progress_data.get('speed', '')
                    size = progress_data.get('size', '')
                    
                    # Update progress window
                    if progress_window:
                        status = f"Merging videos... ({current_duration:.1f}s / {total_duration:.1f}s)"
                        progress_window.update_progress(
                            current_duration, 
                            total_duration,
                            speed=speed,
                            size=size,
                            status=status
                        )

        # Get the final status
        return_code = process.wait()
        
        if return_code != 0:
            error_output = process.stderr.read()
            logging.error(f"FFmpeg error: {error_output}")
            if progress_window:
                progress_window.update_progress(0, total_duration, status="Error in merge process!")
                time.sleep(3)  # Show error briefly
            return False
            
        # Verify output duration
        output_duration = get_video_duration(output_path)
        if output_duration is None:
            logging.error("Could not verify output video duration")
            return False
            
        # Allow 5 second tolerance
        if abs(output_duration - total_duration) > 5:
            logging.error(f"Output duration ({output_duration:.2f}s) doesn't match expected ({total_duration:.2f}s)")
            return False
            
        if progress_window:
            progress_window.update_progress(total_duration, total_duration, status="Merge completed successfully!")
            time.sleep(2)  # Show completion message briefly
            
        logging.info(f"Merge completed successfully! Final video duration: {output_duration:.2f} seconds")
        return True
        
    except Exception as e:
        logging.error(f"Error merging videos: {str(e)}")
        if progress_window:
            progress_window.update_progress(0, total_duration, status=f"Error: {str(e)}")
            time.sleep(3)  # Show error briefly
        return False
    finally:
        if os.path.exists(list_path):
            os.remove(list_path)
        if progress_window:
            progress_window.close()

def upload_to_youtube(youtube, video_path: str, title: str, description: str) -> Optional[Dict]:
    """Upload video to YouTube with improved error handling and retry logic."""
    try:
        # Ensure title is not empty and within limits
        if not title or len(title) > 100:
            title = title[:95] if title else "Untitled Video"
        
        logging.info(f"Starting upload: {title}")
        
        body = {
            "snippet": {
                "title": title,
                "description": description,
                "categoryId": "27",  # Education category
                "tags": ["tutorial", "education"]
            },
            "status": {
                "privacyStatus": "unlisted",
                "selfDeclaredMadeForKids": False
            }
        }

        # Create insert request
        insert_request = youtube.videos().insert(
            part=",".join(body.keys()),
            body=body,
            media_body=MediaFileUpload(
                video_path, 
                chunksize=1024*1024*8,  # 8MB chunks for better reliability
                resumable=True
            )
        )

        response = None
        retries = 3
        chunk_retries = 5  # Number of retries per chunk
        
        while response is None and retries > 0:
            try:
                chunk_retry_count = chunk_retries
                while chunk_retry_count > 0:
                    try:
                        status, response = insert_request.next_chunk()
                        if response:
                            logging.info("Upload completed successfully")
                            return response
                        elif status:
                            logging.info(f"Upload progress: {int(status.progress() * 100)}%")
                        break  # Successful chunk upload, continue to next chunk
                    except (ConnectionError, httplib2.HttpLib2Error) as chunk_error:
                        chunk_retry_count -= 1
                        if chunk_retry_count == 0:
                            raise  # Re-raise if we're out of chunk retries
                        logging.warning(f"Chunk upload failed, waiting 10 seconds before retry... ({str(chunk_error)})")
                        time.sleep(10)  # Longer wait between chunk retries
                
            except Exception as e:
                retries -= 1
                if retries == 0:
                    raise
                logging.warning(f"Upload attempt failed, waiting 30 seconds before retry... ({str(e)})")
                time.sleep(30)  # Much longer wait between full upload retries

    except Exception as e:
        logging.error(f"Error uploading to YouTube: {str(e)}")
        return None

def cleanup_and_save_link(folder_path: str, video_id: str, title: str):
    """Save YouTube link and clean up files."""
    link_file = os.path.join(folder_path, "youtube link.txt")
    with open(link_file, 'w') as f:
        f.write(f"Title: {title}\n")
        f.write(f"URL: https://www.youtube.com/watch?v={video_id}\n")
        f.write(f"Uploaded: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

def delete_video_folders(tutorial_path: str) -> bool:
    """Delete all subfolders containing videos after successful upload."""
    try:
        deleted_folders = 0
        # Walk through all subfolders
        for root, dirs, files in os.walk(tutorial_path, topdown=False):
            # Skip the tutorial root folder itself
            if root == tutorial_path:
                continue
                
            # Check if this is a folder containing videos
            has_videos = any(f.lower().endswith(('.mp4', '.avi', '.mkv')) for f in files)
            if has_videos:
                try:
                    shutil.rmtree(root)
                    deleted_folders += 1
                    logging.info(f"Deleted folder: {root}")
                except Exception as e:
                    logging.error(f"Failed to delete folder {root}: {str(e)}")
                    return False
        
        logging.info(f"Deleted {deleted_folders} folders containing videos")
        return True
    except Exception as e:
        logging.error(f"Error deleting video folders: {str(e)}")
        return False

def shorten_folder_name(folder_name: str) -> str:
    """Create a shorter version of the folder name that's still meaningful."""
    # Remove special characters and spaces
    cleaned = re.sub(r'[^\w\s-]', '', folder_name)
    # Replace spaces with underscores
    cleaned = cleaned.replace(' ', '_')
    # Take first word of each segment
    words = [part.split('_')[0] for part in cleaned.split('-')]
    # Join with underscores and limit to 50 characters
    shortened = '_'.join(words)[:50]
    return shortened

def create_temp_folder_with_videos(original_path: str) -> Tuple[Optional[str], Optional[str]]:
    """
    Creates a temporary folder with a shorter name and copies videos there.
    Returns tuple of (temp_folder_path, original_folder_name) or (None, None) on failure.
    """
    try:
        # Get original folder name and create shortened version
        original_folder_name = os.path.basename(original_path)
        short_name = shorten_folder_name(original_folder_name)
        
        # Create temp folder in parent directory
        parent_dir = os.path.dirname(original_path)
        temp_folder = os.path.join(parent_dir, f"temp_{short_name}")
        
        # If temp folder already exists, delete it
        if os.path.exists(temp_folder):
            shutil.rmtree(temp_folder)
        
        # Create new temp folder and copy structure
        os.makedirs(temp_folder)
        
        # Copy all video files maintaining relative paths
        for root, _, files in os.walk(original_path):
            for file in files:
                if file.lower().endswith(('.mp4', '.avi', '.mkv')):
                    # Get relative path
                    rel_path = os.path.relpath(root, original_path)
                    # Create corresponding folder in temp directory
                    temp_subdir = os.path.join(temp_folder, rel_path)
                    os.makedirs(temp_subdir, exist_ok=True)
                    # Copy file
                    src_file = os.path.join(root, file)
                    dst_file = os.path.join(temp_subdir, file)
                    shutil.copy2(src_file, dst_file)
        
        return temp_folder, original_folder_name
    except Exception as e:
        logging.error(f"Error creating temporary folder: {str(e)}")
        return None, None

def cleanup_temp_folder(temp_folder: str):
    """Clean up the temporary folder."""
    try:
        if os.path.exists(temp_folder):
            shutil.rmtree(temp_folder)
            logging.info(f"Cleaned up temporary folder: {temp_folder}")
    except Exception as e:
        logging.warning(f"Failed to clean up temporary folder: {str(e)}")

def process_tutorial_folder(tutorial_path: str, youtube: object):
    """Process a single tutorial folder containing videos."""
    merged_path = None
    temp_folder = None
    try:
        logging.info(f"\nProcessing tutorial folder: {tutorial_path}")
        
        # Check if this folder has already been processed
        link_file = os.path.join(tutorial_path, "youtube link.txt")
        if os.path.exists(link_file):
            logging.info(f"Folder already processed (found youtube link.txt). Skipping: {tutorial_path}")
            return
            
        # Verify this is a level 4 tutorial folder
        if not is_tutorial_folder(tutorial_path):
            logging.error(f"Not a tutorial folder (level 4): {tutorial_path}")
            return
        
        # Create temporary folder with shorter path if needed
        original_folder_name = os.path.basename(tutorial_path)
        if len(tutorial_path) > 200:  # Path is too long
            temp_folder, original_folder_name = create_temp_folder_with_videos(tutorial_path)
            if not temp_folder:
                logging.error("Failed to create temporary folder")
                return
            working_path = temp_folder
        else:
            working_path = tutorial_path
        
        # Get videos from working path
        video_files = collect_videos(working_path)
        if not video_files:
            logging.error(f"No video files found in {working_path}")
            return
            
        logging.info(f"Found {len(video_files)} videos:")
        for _, rel_path in video_files:
            logging.info(f"  - {rel_path}")
        
        # Get structured title using original folder name
        title = get_structured_title(tutorial_path)
        logging.info(f"Generated title: {title}")
        
        # Create merged file in the working folder
        merged_filename = f"{shorten_folder_name(original_folder_name)}_merged.mp4"
        merged_path = os.path.join(working_path, merged_filename)
        
        logging.info("Starting video merge...")
        if not merge_videos(video_files, merged_path):
            logging.error("Failed to merge videos")
            return
            
        logging.info("Videos merged successfully")
        
        # Generate timestamps
        timestamps = generate_timestamps(video_files)
        description = "Tutorial Contents:\n\n" + timestamps
        
        # Upload with retries
        max_upload_attempts = 3
        upload_response = None
        
        for attempt in range(max_upload_attempts):
            try:
                logging.info(f"Upload attempt {attempt + 1}/{max_upload_attempts}")
                upload_response = upload_to_youtube(youtube, merged_path, title, description)
                if upload_response:
                    break
                time.sleep(30)
            except Exception as e:
                logging.error(f"Upload attempt {attempt + 1} failed: {str(e)}")
                if attempt < max_upload_attempts - 1:
                    logging.info("Waiting 60 seconds before next attempt...")
                    time.sleep(60)
                continue
        
        if upload_response and upload_response.get('id'):
            video_id = upload_response['id']
            logging.info(f"Upload successful! Video ID: {video_id}")
            
            # Save link file in the original tutorial folder
            cleanup_and_save_link(tutorial_path, video_id, title)
            logging.info(f"Video URL: https://www.youtube.com/watch?v={video_id}")
            
            # Only proceed with cleanup if we have a valid video ID and link file
            link_file = os.path.join(tutorial_path, "youtube link.txt")
            if os.path.exists(link_file):
                # Delete all folders containing videos first
                if delete_video_folders(tutorial_path):
                    logging.info("Successfully deleted all video folders")
                else:
                    logging.error("Failed to delete some video folders")
                    
                # Clean up merged video file
                try:
                    os.remove(merged_path)
                    logging.info(f"Cleaned up merged video file: {merged_path}")
                except Exception as e:
                    logging.warning(f"Could not clean up merged video: {str(e)}")
            else:
                logging.warning("Link file not created. Skipping cleanup to be safe.")
        else:
            logging.error("Upload failed after all attempts. Keeping files for retry.")
            
    except Exception as e:
        logging.error(f"Error processing tutorial folder: {str(e)}")
    finally:
        # Clean up temporary folder if it exists
        if temp_folder:
            cleanup_temp_folder(temp_folder)

def find_tutorial_folders(parent_path: str) -> List[str]:
    """Find all level 4 tutorial folders under the given parent path."""
    tutorial_folders = []
    try:
        # Walk through all subdirectories
        for root, _, files in os.walk(parent_path):
            # Check if this is a tutorial folder (level 4)
            if is_tutorial_folder(root):
                # Check if this folder has videos (directly or in subfolders)
                has_videos = False
                for _, _, fs in os.walk(root):
                    if any(f.lower().endswith(('.mp4', '.avi', '.mkv')) for f in fs):
                        has_videos = True
                        break
                if has_videos:
                    tutorial_folders.append(root)
    except Exception as e:
        logging.error(f"Error finding tutorial folders: {str(e)}")
    return sorted(tutorial_folders)

def process_folder(parent_path: str, youtube: object):
    """Process all tutorial folders under the given parent path."""
    try:
        logging.info(f"Scanning for tutorial folders in: {parent_path}")
        
        # Find all tutorial folders
        tutorial_folders = find_tutorial_folders(parent_path)
        
        if not tutorial_folders:
            logging.error("No tutorial folders with videos found")
            return
            
        logging.info(f"Found {len(tutorial_folders)} tutorial folders")
        
        # Process each tutorial folder
        for tutorial_folder in tutorial_folders:
            logging.info(f"\nProcessing tutorial: {tutorial_folder}")
            process_tutorial_folder(tutorial_folder, youtube)
            
    except Exception as e:
        logging.error(f"Error in process_folder: {str(e)}")

def get_script_directory():
    """Get the directory containing the script, works in both .py and .ipynb"""
    try:
        # For .py files
        return os.path.dirname(os.path.abspath(__file__))
    except NameError:
        # For Jupyter notebooks
        try:
            import nbformat
            from notebook import notebookapp
            import jupyter_client
            
            # Try to get the current notebook's path
            connection_file = jupyter_client.find_connection_file()
            kernel_id = os.path.basename(connection_file).split('-', 1)[1].split('.')[0]
            
            for srv in notebookapp.list_running_servers():
                for note in srv['notebook_dir']:
                    if kernel_id in note:
                        return os.path.dirname(note['path'])
                        
        except:
            # Fallback: Look in current working directory
            return os.getcwd()

def find_client_secrets():
    """Find client_secret.json in various possible locations"""
    possible_locations = [
        # Current directory
        os.path.join(os.getcwd(), "client_secret.json"),
        # Script directory (for .py files)
        os.path.join(get_script_directory(), "client_secret.json"),
        # One level up
        os.path.join(os.path.dirname(os.getcwd()), "client_secret.json"),
        # In 04.merge.and.upload directory
        os.path.join(os.getcwd(), "04.merge.and.upload", "client_secret.json"),
    ]
    
    for location in possible_locations:
        if os.path.exists(location):
            print(f"Found client_secret.json at: {location}")
            return location
            
    print("Searched in the following locations:")
    for location in possible_locations:
        print(f"- {location}")
    return None

def main():
    try:
        print("\n=== Starting YouTube Video Processor ===")
        
        # Find client secrets file
        client_secrets_file = find_client_secrets()
        if not client_secrets_file:
            print("Error: client_secret.json not found in any expected location")
            return
            
        # Authenticate with YouTube as the very first step
        youtube = authenticate_youtube(client_secrets_file)
        if not youtube:
            print("Failed to authenticate with YouTube. Please try again.")
            return
            
        # Now get folder path using GUI
        print("\nOpening folder selection window...")
        folder_path = get_folder_path_gui()
        if not folder_path:
            print("No path entered")
            return
            
        if not os.path.exists(folder_path):
            print("Path does not exist")
            return
            
        # Process folders with the authenticated service
        print(f"\nStarting to process folder: {folder_path}")
        process_folder(folder_path, youtube)
        
    except Exception as e:
        print(f"Error in main: {str(e)}")
        logging.error(f"Error in main: {str(e)}")
        import traceback
        traceback.print_exc()

if __name__ == "__main__":
    main()
# Out:
# === Starting YouTube Video Processor ===
# Found client_secret.json at: d:\OneDrive\OneDrive - Rowad Modern Engineering\x004 Data Science\03.rme.db\00.repo\rme.db\09.other.projects\01.youtube\04.merge.and.upload\client_secret.json
#
# Checking YouTube authentication...
# Found existing token
# Token expired, refreshing...
# 16:57:02 - file_cache is only supported with oauth2client<4.0.0
# Token refreshed successfully
# YouTube authentication successful!
#
# Opening folder selection window...
# 16:57:05 - Scanning for tutorial folders in: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure
# Starting to process folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure
# 16:57:05 - Found 10 tutorial folders
# 16:57:05 -
# Processing tutorial: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Lynda\Architecting Azure Infrastructure
# 16:57:05 -
# Processing tutorial folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Lynda\Architecting Azure Infrastructure
# 16:57:05 - Found 18 videos:
# 16:57:05 -   - 1. Introduction\01. Welcome.mp4
# 16:57:05 -   - 1. Introduction\02. What you need to know.mp4
# 16:57:05 -   - 2. 1. Design Virtual Machines (VMs)\03. Availability sets and fault and update domains.mp4
# 16:57:05 -   - 2. 1. Design Virtual Machines (VMs)\04. Select appropriate VM SKUs.mp4
# 16:57:05 -   - 2. 1. Design Virtual Machines (VMs)\05. Disks, migration, and DSC.mp4
# 16:57:05 -   - 3. 2. Design Template Deployment\06. Author ARM templates.mp4
# 16:57:05 -   - 3. 2. Design Template Deployment\07. Deploy ARM templates via PowerShell and CLI.mp4
# 16:57:05 -   - 4. 3. Design for Availability\08. Regional and high availability.mp4
# 16:57:05 -   - 5. 4. Design Azure Virtual Networks\09. Azure Load Balancer and Azure Traffic Manager.mp4
# 16:57:05 -   - 5. 4. Design Azure Virtual Networks\10. IP addressing.mp4
# 16:57:05 -   - 5. 4. Design Azure Virtual Networks\11. Define DNS and DHCP.mp4
# 16:57:05 -   - 5. 4. Design Azure Virtual Networks\12. Network security groups.mp4
# 16:57:05 -   - 5. 4. Design Azure Virtual Networks\13. User-defined routes and IP forwarding.mp4
# 16:57:05 -   - 5. 4. Design Azure Virtual Networks\14. Azure application gateway.mp4
# 16:57:05 -   - 6. 5. Azure VPN and ExpressRoute Architecture and Design\15. VPN gateways.mp4
# 16:57:05 -   - 6. 5. Azure VPN and ExpressRoute Architecture and Design\16. VPN gateway topologies.mp4
# 16:57:05 -   - 6. 5. Azure VPN and ExpressRoute Architecture and Design\17. Common Azure hierarchies.mp4
# 16:57:05 -   - 7. Conclusion\18. Next steps.mp4
# 16:57:05 - Generated title: Microsoft - Azure - Lynda - Architecting Azure Infrastructure
# 16:57:05 - Starting video merge...
# 16:57:05 -
# Analyzing 18 videos for merge:
# 16:57:06 - Video 1/18: 1. Introduction\01. Welcome.mp4
# 16:57:06 - Video 2/18: 1. Introduction\02. What you need to know.mp4
# 16:57:06 - Video 3/18: 2. 1. Design Virtual Machines (VMs)\03. Availability sets and fault and update domains.mp4
# 16:57:07 - Video 4/18: 2. 1. Design Virtual Machines (VMs)\04. Select appropriate VM SKUs.mp4
# 16:57:07 - Video 5/18: 2. 1. Design Virtual Machines (VMs)\05. Disks, migration, and DSC.mp4
# 16:57:07 - Video 6/18: 3. 2. Design Template Deployment\06. Author ARM templates.mp4
# 16:57:08 - Video 7/18: 3. 2. Design Template Deployment\07. Deploy ARM templates via PowerShell and CLI.mp4
# 16:57:08 - Video 8/18: 4. 3. Design for Availability\08. Regional and high availability.mp4
# 16:57:09 - Video 9/18: 5. 4. Design Azure Virtual Networks\09. Azure Load Balancer and Azure Traffic Manager.mp4
# 16:57:09 - Video 10/18: 5. 4. Design Azure Virtual Networks\10. IP addressing.mp4
# 16:57:09 - Video 11/18: 5. 4. Design Azure Virtual Networks\11. Define DNS and DHCP.mp4
# 16:57:09 - Video 12/18: 5. 4. Design Azure Virtual Networks\12. Network security groups.mp4
# 16:57:10 - Video 13/18: 5. 4. Design Azure Virtual Networks\13. User-defined routes and IP forwarding.mp4
# 16:57:10 - Video 14/18: 5. 4. Design Azure Virtual Networks\14. Azure application gateway.mp4
# 16:57:10 - Video 15/18: 6. 5. Azure VPN and ExpressRoute Architecture and Design\15. VPN gateways.mp4
# 16:57:10 - Video 16/18: 6. 5. Azure VPN and ExpressRoute Architecture and Design\16. VPN gateway topologies.mp4
# 16:57:11 - Video 17/18: 6. 5. Azure VPN and ExpressRoute Architecture and Design\17. Common Azure hierarchies.mp4
# 16:57:11 - Video 18/18: 7. Conclusion\18. Next steps.mp4
# 16:57:11 -
# Total expected duration: 4768.87 seconds
# 17:03:56 - Merge completed successfully! Final video duration: 4768.87 seconds
# 17:03:56 - Videos merged successfully
# 17:04:00 - Upload attempt 1/3
# 17:04:00 - Starting upload: Microsoft - Azure - Lynda - Architecting Azure Infrastructure
# 17:04:06 - Upload progress: 7%
# 17:04:09 - Upload progress: 14%
# 17:04:13 - Upload progress: 21%
# 17:04:16 - Upload progress: 28%
# 17:04:20 - Upload progress: 36%
# 17:04:23 - Upload progress: 43%
# 17:04:28 - Upload progress: 50%
# 17:04:32 - Upload progress: 57%
# 17:04:36 - Upload progress: 64%
# 17:04:39 - Upload progress: 72%
# 17:04:43 - Upload progress: 79%
# 17:04:47 - Upload progress: 86%
# 17:04:50 - Upload progress: 93%
# 17:04:54 - Upload completed successfully
# 17:04:54 - Upload successful! Video ID: JCrKBkEOW44
# 17:04:54 - Video URL: https://www.youtube.com/watch?v=JCrKBkEOW44
# 17:04:54 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Lynda\Architecting Azure Infrastructure\1. Introduction
# 17:04:54 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Lynda\Architecting Azure Infrastructure\2. 1. Design Virtual Machines (VMs)
# 17:04:54 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Lynda\Architecting Azure Infrastructure\3. 2. Design Template Deployment
# 17:04:54 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Lynda\Architecting Azure Infrastructure\4. 3. Design for Availability
# 17:04:54 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Lynda\Architecting Azure Infrastructure\5. 4. Design Azure Virtual Networks
# 17:04:54 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Lynda\Architecting Azure Infrastructure\6. 5. Azure VPN and ExpressRoute Architecture and Design
# 17:04:54 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Lynda\Architecting Azure Infrastructure\7. Conclusion
# 17:04:54 - Deleted 7 folders containing videos
# 17:04:54 - Successfully deleted all video folders
# 17:04:54 - Cleaned up merged video file: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Lynda\Architecting Azure Infrastructure\Architecting_merged.mp4
# 17:04:54 -
# Processing tutorial: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Other\Introduction to Azure Crash Course
# 17:04:54 -
# Processing tutorial folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Other\Introduction to Azure Crash Course
# 17:04:54 - Found 28 videos:
# 17:04:54 -   - 1 - Introduction\1 - Introduction.mp4
# 17:04:54 -   - 1 - Introduction\10 - Even More Azure Use Cases.mp4
# 17:04:54 -   - 1 - Introduction\11 - Summary of Key Azure Services.mp4
# 17:04:54 -   - 1 - Introduction\12 - Introduction to Azure Blob Storage.mp4
# 17:04:54 -   - 1 - Introduction\13 - Demo Azure Blob Storage.mp4
# 17:04:54 -   - 1 - Introduction\14 - Azure vs other Cloud Providers Google and AWS.mp4
# 17:04:54 -   - 1 - Introduction\15 - Understand Regions and Availability Zones.mp4
# 17:04:54 -   - 1 - Introduction\16 - Getting Started with Azure Certifications.mp4
# 17:04:54 -   - 1 - Introduction\17 - Azure Support Plans.mp4
# 17:27:52 - Upload progress: 80%
# 17:27:56 - Upload progress: 82%
# 17:28:01 - Upload progress: 84%
# 17:28:05 - Upload progress: 86%
# 17:28:09 - Upload progress: 88%
# 17:28:12 - Upload progress: 90%
# 17:28:17 - Upload progress: 92%
# 17:28:21 - Upload progress: 94%
# 17:28:25 - Upload progress: 97%
# 17:28:29 - Upload progress: 99%
# 17:28:31 - Upload completed successfully
# 17:28:31 - Upload successful! Video ID: zzmJb7-Su8U
# 17:28:31 - Video URL: https://www.youtube.com/watch?v=zzmJb7-Su8U
# 17:28:32 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Other\Introduction to Azure Crash Course\1 - Introduction
# 17:28:32 - Deleted 1 folders containing videos
# 17:28:32 - Successfully deleted all video folders
# 17:28:32 - Cleaned up merged video file: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Other\Introduction to Azure Crash Course\Introduction_merged.mp4
# 17:28:32 -
# Processing tutorial: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Analyzing Microsoft Azure Subscription Resource Utilization
# 17:28:32 -
# Processing tutorial folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Analyzing Microsoft Azure Subscription Resource Utilization
# 17:28:32 - Found 44 videos:
# 17:28:32 -   - 01.Course Overview\0101.Course Overview.mp4
# 17:28:32 -   - 02.Getting Started\0201.Introduction.mp4
# 17:28:32 -   - 02.Getting Started\0202.Overview.mp4
# 17:28:32 -   - 02.Getting Started\0203.Why Monitor Cloud Resources.mp4
# 17:28:32 -   - 02.Getting Started\0204.What Is Azure Monitor.mp4
# 17:28:32 -   - 02.Getting Started\0205.High-level View of Azure Monitor.mp4
# 17:28:32 -   - 02.Getting Started\0206.The 6 Azure Monitor Services We Are Going to Cover.mp4
# 17:28:32 -   - 02.Getting Started\0207.Summary.mp4
# 17:28:32 -   - 03.Viewing and Analyzing Alerts Across Subscription\0301.Overview.mp4
# 17:28:32 -   - 03.Viewing and Analyzing Alerts Across Subscription\0302.What Are Alerts.mp4
# 17:28:32 -   - 03.Viewing and Analyzing Alerts Across Subscription\0303.Alert Rules.mp4
# 17:28:32 -   - 03.Viewing and Analyzing Alerts Across Subscription\0304.Creating an Alert.mp4
# 17:28:32 -   - 03.Viewing and Analyzing Alerts Across Subscription\0305.Demo Create and Analyze Alerts in Azure.mp4
# 17:28:32 -   - 03.Viewing and Analyzing Alerts Across Subscription\0306.Summary.mp4
# 17:28:32 -   - 04.Viewing and Analyzing Metrics Across Subscription\0401.Overview.mp4
# 17:28:32 -   - 04.Viewing and Analyzing Metrics Across Subscription\0402.What Are Metrics.mp4
# 17:28:32 -   - 04.Viewing and Analyzing Metrics Across Subscription\0403.Metrics Attributes and Values.mp4
# 17:28:32 -   - 04.Viewing and Analyzing Metrics Across Subscription\0404.What Can You Do With Metrics.mp4
# 17:28:32 -   - 04.Viewing and Analyzing Metrics Across Subscription\0405.Demo View and Analyze Metrics in Azure .mp4
# 17:28:32 -   - 04.Viewing and Analyzing Metrics Across Subscription\0406.Summary.mp4
# 17:28:32 -   - 05.Creating Action Groups\0501.Overview.mp4
# 17:28:32 -   - 06.Monitoring and Reporting on Spend\0602.Two Options to Understand Your Azure Bill.mp4
# 17:28:32 -   - 06.Monitoring and Reporting on Spend\0603.Azure Monitor Hub & New Pricing Model.mp4
# 17:28:32 -   - 06.Monitoring and Reporting on Spend\0604.Impact of New Pricing Model.mp4
# 17:28:32 -   - 06.Monitoring and Reporting on Spend\0605.Changes When Moving to New Pricing Model.mp4
# 17:28:32 -   - 06.Monitoring and Reporting on Spend\0606.Demo Viewing Usage and Estimates Cost Page.mp4
# 17:28:32 -   - 06.Monitoring and Reporting on Spend\0607.Summary.mp4
# 17:28:32 -   - 07.Creating a Dashboard Using Designer\0701.Overview.mp4
# 17:28:32 -   - 07.Creating a Dashboard Using Designer\0702.How to Visualize Data in Azure Monitor.mp4
# 17:28:32 -   - 07.Creating a Dashboard Using Designer\0703.Azure Dashboard Limitations .mp4
# 17:28:32 -   - 07.Creating a Dashboard Using Designer\0704.Demo Creating a Dashboard Using Azure Designer.mp4
# 17:28:32 -   - 07.Creating a Dashboard Using Designer\0705.Summary.mp4
# 17:28:32 -   - 08.Utilizing Log Search Query Functions\0801.Overview.mp4
# 17:28:32 -   - 08.Utilizing Log Search Query Functions\0802.What Are Log Analytics and Queries.mp4
# 17:28:32 -   - 08.Utilizing Log Search Query Functions\0803.Where Are Log Queries Used.mp4
# 17:28:32 -   - 08.Utilizing Log Search Query Functions\0804.Log Analytics Data Organization .mp4
# 17:28:32 -   - 08.Utilizing Log Search Query Functions\0805.Using Functions in Log Analytics .mp4
# 17:28:32 -   - 08.Utilizing Log Search Query Functions\0806.Demo Create a Query and a Function in Log Analytics .mp4
# 17:28:32 -   - 08.Utilizing Log Search Query Functions\0807.Summary.mp4
# 17:28:32 -   - 09.Viewing Alerts in Log Analytics\0901.Overview.mp4
# 17:28:32 -   - 09.Viewing Alerts in Log Analytics\0902.What Are Log Alerts .mp4
# 17:28:32 -   - 09.Viewing Alerts in Log Analytics\0903.Demo Viewing Alerts in Log Analytics .mp4
# 17:28:32 -   - 09.Viewing Alerts in Log Analytics\0904.Summary.mp4
# 17:28:32 -   - 10.Wrapping Up\1001.Course Summary.mp4
# 17:28:32 - Generated title: Microsoft - Azure - Pluralsight - Analyzing Microsoft Azure Subscription Resource Utilization
# 17:28:32 - Starting video merge...
# 17:28:32 -
# Analyzing 44 videos for merge:
# 17:28:32 - Video 1/44: 01.Course Overview\0101.Course Overview.mp4
# 17:28:33 - Video 2/44: 02.Getting Started\0201.Introduction.mp4
# 17:28:33 - Video 3/44: 02.Getting Started\0202.Overview.mp4
# 17:28:33 - Video 4/44: 02.Getting Started\0203.Why Monitor Cloud Resources.mp4
# 17:28:33 - Video 5/44: 02.Getting Started\0204.What Is Azure Monitor.mp4
# 17:28:34 - Video 6/44: 02.Getting Started\0205.High-level View of Azure Monitor.mp4
# 17:28:34 - Video 7/44: 02.Getting Started\0206.The 6 Azure Monitor Services We Are Going to Cover.mp4
# 17:28:34 - Video 8/44: 02.Getting Started\0207.Summary.mp4
# 17:28:35 - Video 9/44: 03.Viewing and Analyzing Alerts Across Subscription\0301.Overview.mp4
# 17:28:35 - Video 10/44: 03.Viewing and Analyzing Alerts Across Subscription\0302.What Are Alerts.mp4
# 17:28:44 - Video 40/44: 09.Viewing Alerts in Log Analytics\0901.Overview.mp4
# 17:28:45 - Video 41/44: 09.Viewing Alerts in Log Analytics\0902.What Are Log Alerts .mp4
# 17:28:45 - Video 42/44: 09.Viewing Alerts in Log Analytics\0903.Demo Viewing Alerts in Log Analytics .mp4
# 17:28:45 - Video 43/44: 09.Viewing Alerts in Log Analytics\0904.Summary.mp4
# 17:28:45 - Video 44/44: 10.Wrapping Up\1001.Course Summary.mp4
# 17:28:45 -
# Total expected duration: 4125.89 seconds
# 17:34:11 - Merge completed successfully! Final video duration: 4125.92 seconds
# 17:34:11 - Videos merged successfully
# 17:34:21 - Upload attempt 1/3
# 17:34:21 - Starting upload: Microsoft - Azure - Pluralsight - Analyzing Microsoft Azure Subscription Resource Utilization
# 17:34:26 - Upload progress: 8%
# 17:34:29 - Upload progress: 16%
# 17:34:33 - Upload progress: 24%
# 17:34:37 - Upload progress: 32%
# 17:34:40 - Upload progress: 40%
# 17:34:44 - Upload progress: 48%
# 17:34:48 - Upload progress: 56%
# 17:34:51 - Upload progress: 64%
# 17:34:55 - Upload progress: 72%
# 17:34:59 - Upload progress: 80%
# 17:35:02 - Upload progress: 88%
# 17:35:06 - Upload progress: 96%
# 17:35:09 - Upload completed successfully
# 17:35:09 - Upload successful! Video ID: FJHi7S3iHbo
# 17:35:09 - Video URL: https://www.youtube.com/watch?v=FJHi7S3iHbo
# 17:35:09 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Analyzing Microsoft Azure Subscription Resource Utilization\01.Course Overview
# 17:35:09 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Analyzing Microsoft Azure Subscription Resource Utilization\02.Getting Started
# 17:35:09 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Analyzing Microsoft Azure Subscription Resource Utilization\03.Viewing and Analyzing Alerts Across Subscription
# 17:35:09 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Analyzing Microsoft Azure Subscription Resource Utilization\04.Viewing and Analyzing Metrics Across Subscription
# 17:35:09 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Analyzing Microsoft Azure Subscription Resource Utilization\05.Creating Action Groups
# 17:35:09 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Analyzing Microsoft Azure Subscription Resource Utilization\06.Monitoring and Reporting on Spend
# 17:35:09 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Analyzing Microsoft Azure Subscription Resource Utilization\07.Creating a Dashboard Using Designer
# 17:35:09 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Analyzing Microsoft Azure Subscription Resource Utilization\08.Utilizing Log Search Query Functions
# 17:35:09 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Analyzing Microsoft Azure Subscription Resource Utilization\09.Viewing Alerts in Log Analytics
# 17:35:09 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Analyzing Microsoft Azure Subscription Resource Utilization\10.Wrapping Up
# 17:35:09 - Deleted 10 folders containing videos
# 17:35:09 - Successfully deleted all video folders
# 17:35:09 - Cleaned up merged video file: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Analyzing Microsoft Azure Subscription Resource Utilization\Analyzing_merged.mp4
# 17:35:09 -
# Processing tutorial: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Cloud Design Patterns For Azure Availability And Resilience
# 17:35:09 -
# Processing tutorial folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Cloud Design Patterns For Azure Availability And Resilience
# 17:35:09 - Found 48 videos:
# 17:35:09 -   - 1. Course Overview\01. Course Overview.mp4
# 17:35:09 -   - 2. About the Availability and Resilience Patterns\02. Introduction.mp4
# 17:35:09 -   - 2. About the Availability and Resilience Patterns\03. Why Design Patterns Matter.mp4
# 17:35:09 -   - 2. About the Availability and Resilience Patterns\04. About the Cloud Design Patterns for Azure.mp4
# 17:35:09 -   - 2. About the Availability and Resilience Patterns\05. Summary.mp4
# 17:35:09 -   - 3. Circuit Breaker Pattern\06. Introduction.mp4
# 17:35:09 -   - 3. Circuit Breaker Pattern\07. The Problem to Be Solved.mp4
# 17:35:09 -   - 3. Circuit Breaker Pattern\08. The Solution to the Problem.mp4
# 17:35:09 -   - 3. Circuit Breaker Pattern\09. Things to Consider.mp4
# 17:35:09 -   - 3. Circuit Breaker Pattern\10. The Usage of the Pattern.mp4
# 17:35:09 -   - 3. Circuit Breaker Pattern\11. Demo - Circuit Breaker in a Console App.mp4
# 17:35:09 -   - 3. Circuit Breaker Pattern\12. Summary.mp4
# 17:35:09 -   - 4. Compensating Transaction Pattern\13. Introduction.mp4
# 17:35:09 -   - 4. Compensating Transaction Pattern\14. The Problem to Be Solved.mp4
# 17:35:09 -   - 4. Compensating Transaction Pattern\15. The Solution to the Problem.mp4
# 17:35:09 -   - 4. Compensating Transaction Pattern\16. Things to Consider.mp4
# 17:35:09 -   - 4. Compensating Transaction Pattern\17. The Usage of the Pattern.mp4
# 17:35:09 -   - 4. Compensating Transaction Pattern\18. Demo - Compensating Transaction in an Azure Logic App.mp4
# 17:35:09 -   - 4. Compensating Transaction Pattern\19. Summary.mp4
# 17:35:09 -   - 5. Health Endpoint Monitoring Pattern\20. Introduction.mp4
# 17:35:09 -   - 5. Health Endpoint Monitoring Pattern\21. The Problem to Be Solved.mp4
# 17:35:09 -   - 5. Health Endpoint Monitoring Pattern\22. The Solution to the Problem.mp4
# 17:35:09 -   - 5. Health Endpoint Monitoring Pattern\23. Things to Consider.mp4
# 17:35:09 -   - 5. Health Endpoint Monitoring Pattern\24. The Usage of the Pattern.mp4
# 17:35:09 -   - 5. Health Endpoint Monitoring Pattern\25. An Example of the Solution.mp4
# 17:35:09 -   - 5. Health Endpoint Monitoring Pattern\26. Summary.mp4
# 17:35:09 -   - 6. Queue-based Load Leveling Pattern\27. Introduction.mp4
# 17:35:09 -   - 6. Queue-based Load Leveling Pattern\28. The Problem to Be Solved.mp4
# 17:35:09 -   - 6. Queue-based Load Leveling Pattern\29. The Solution to the Problem.mp4
# 17:35:09 -   - 6. Queue-based Load Leveling Pattern\30. Things to Consider.mp4
# 17:35:09 -   - 6. Queue-based Load Leveling Pattern\31. The Usage of the Pattern.mp4
# 17:35:09 -   - 6. Queue-based Load Leveling Pattern\32. Demo - Azure Storage Queue.mp4
# 17:35:09 -   - 6. Queue-based Load Leveling Pattern\33. Demo - Azure Storage Queue and WebJob.mp4
# 17:35:09 -   - 6. Queue-based Load Leveling Pattern\34. Summary.mp4
# 17:35:09 -   - 7. Retry Pattern\35. Introduction.mp4
# 17:35:09 -   - 7. Retry Pattern\36. The Problem to Be Solved.mp4
# 17:35:09 -   - 7. Retry Pattern\37. The Solution to the Problem.mp4
# 17:35:09 -   - 7. Retry Pattern\38. Things to Consider.mp4
# 17:35:09 -   - 7. Retry Pattern\39. The Usage of the Pattern.mp4
# 17:35:09 -   - 7. Retry Pattern\40. Demo - Azure Storage Library Retry Policy.mp4
# 17:35:09 -   - 7. Retry Pattern\41. Summary.mp4
# 17:35:09 -   - 8. Throttling Pattern\42. Introduction.mp4
# 17:35:09 -   - 8. Throttling Pattern\43. The Problem to Be Solved.mp4
# 17:35:09 -   - 8. Throttling Pattern\44. The Solution to the Problem.mp4
# 17:35:09 -   - 8. Throttling Pattern\45. Things to Consider.mp4
# 17:35:09 -   - 8. Throttling Pattern\46. The Usage of the Pattern.mp4
# 17:35:09 -   - 8. Throttling Pattern\47. Demo - Throttling with Azure API Management.mp4
# 17:35:09 -   - 8. Throttling Pattern\48. Summary.mp4
# 17:35:09 - Generated title: Microsoft - Azure - Pluralsight - Cloud Design Patterns For Azure Availability And Resilience
# 17:35:09 - Starting video merge...
# 17:35:09 -
# Analyzing 48 videos for merge:
# 17:35:10 - Video 1/48: 1. Course Overview\01. Course Overview.mp4
# 17:35:10 - Video 2/48: 2. About the Availability and Resilience Patterns\02. Introduction.mp4
# 17:35:10 - Video 3/48: 2. About the Availability and Resilience Patterns\03. Why Design Patterns Matter.mp4
# 17:35:11 - Video 4/48: 2. About the Availability and Resilience Patterns\04. About the Cloud Design Patterns for Azure.mp4
# 17:35:11 - Video 5/48: 2. About the Availability and Resilience Patterns\05. Summary.mp4
# 17:35:11 - Video 6/48: 3. Circuit Breaker Pattern\06. Introduction.mp4
# 17:35:11 - Video 7/48: 3. Circuit Breaker Pattern\07. The Problem to Be Solved.mp4
# 17:35:12 - Video 8/48: 3. Circuit Breaker Pattern\08. The Solution to the Problem.mp4
# 17:35:12 - Video 9/48: 3. Circuit Breaker Pattern\09. Things to Consider.mp4
# 17:35:12 - Video 10/48: 3. Circuit Breaker Pattern\10. The Usage of the Pattern.mp4
# 17:35:13 - Video 11/48: 3. Circuit Breaker Pattern\11. Demo - Circuit Breaker in a Console App.mp4
# 17:35:13 - Video 12/48: 3. Circuit Breaker Pattern\12. Summary.mp4
# 17:35:13 - Video 13/48: 4. Compensating Transaction Pattern\13. Introduction.mp4
# 17:35:13 - Video 14/48: 4. Compensating Transaction Pattern\14. The Problem to Be Solved.mp4
# 17:35:14 - Video 15/48: 4. Compensating Transaction Pattern\15. The Solution to the Problem.mp4
# 17:35:14 - Video 16/48: 4. Compensating Transaction Pattern\16. Things to Consider.mp4
# 17:35:14 - Video 17/48: 4. Compensating Transaction Pattern\17. The Usage of the Pattern.mp4
# 17:35:15 - Video 18/48: 4. Compensating Transaction Pattern\18. Demo - Compensating Transaction in an Azure Logic App.mp4
# 17:35:15 - Video 19/48: 4. Compensating Transaction Pattern\19. Summary.mp4
# 17:35:15 - Video 20/48: 5. Health Endpoint Monitoring Pattern\20. Introduction.mp4
# 17:35:15 - Video 21/48: 5. Health Endpoint Monitoring Pattern\21. The Problem to Be Solved.mp4
# 17:35:16 - Video 22/48: 5. Health Endpoint Monitoring Pattern\22. The Solution to the Problem.mp4
# 17:35:16 - Video 23/48: 5. Health Endpoint Monitoring Pattern\23. Things to Consider.mp4
# 17:35:16 - Video 24/48: 5. Health Endpoint Monitoring Pattern\24. The Usage of the Pattern.mp4
- Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Cloud Design Patterns For Azure Availability And Resilience\1. Course Overview
# 17:42:44 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Cloud Design Patterns For Azure Availability And Resilience\2. About the Availability and Resilience Patterns
# 17:42:45 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Cloud Design Patterns For Azure Availability And Resilience\3. Circuit Breaker Pattern
# 17:42:45 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Cloud Design Patterns For Azure Availability And Resilience\4. Compensating Transaction Pattern
# 17:42:45 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Cloud Design Patterns For Azure Availability And Resilience\5. Health Endpoint Monitoring Pattern
# 17:42:45 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Cloud Design Patterns For Azure Availability And Resilience\6. Queue-based Load Leveling Pattern
# 17:42:45 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Cloud Design Patterns For Azure Availability And Resilience\7. Retry Pattern
# 17:42:45 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Cloud Design Patterns For Azure Availability And Resilience\8. Throttling Pattern
# 17:42:45 - Deleted 8 folders containing videos
# 17:42:45 - Successfully deleted all video folders
# 17:42:45 - Cleaned up merged video file: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Cloud Design Patterns For Azure Availability And Resilience\Cloud_merged.mp4
# 17:42:45 -
# Processing tutorial: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Implementing Azure Application Services
# 17:42:45 -
# Processing tutorial folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Implementing Azure Application Services
# 17:42:45 - Found 35 videos:
# 17:42:45 -   - 1. Course Overview\01. Course Overview.mp4
# 17:42:45 -   - 2. Cloud and Azure Overview\02. Module Introduction.mp4
# 17:42:45 -   - 2. Cloud and Azure Overview\03. Who Am I.mp4
# 17:42:45 -   - 2. Cloud and Azure Overview\04. Why This Is Important.mp4
# 17:42:45 -   - 2. Cloud and Azure Overview\05. Types of Cloud Service.mp4
# 17:42:45 -   - 2. Cloud and Azure Overview\06. Azure Subscriptions and Regions.mp4
# 17:42:45 -   - 2. Cloud and Azure Overview\07. Azure Services Overview.mp4
# 17:42:45 -   - 2. Cloud and Azure Overview\08. Resource Groups and RBAC.mp4
# 17:42:45 -   - 2. Cloud and Azure Overview\09. Module Summary.mp4
# 17:42:45 -   - 3. Utilizing Azure App Services\10. Module Introduction.mp4
# 17:42:45 -   - 3. Utilizing Azure App Services\11. Why Have PaaS.mp4
# 17:42:45 -   - 3. Utilizing Azure App Services\12. Azure App Services Overview.mp4
# 17:42:45 -   - 3. Utilizing Azure App Services\13. Azure App Service Plans.mp4
# 17:42:45 -   - 3. Utilizing Azure App Services\14. When to Use a New App Service Plan.mp4
# 17:42:45 -   - 3. Utilizing Azure App Services\15. Deployment Slots.mp4
# 17:42:45 -   - 3. Utilizing Azure App Services\16. Scale Options.mp4
# 17:42:45 -   - 3. Utilizing Azure App Services\17. Quotas and Metrics.mp4
# 17:42:45 -   - 3. Utilizing Azure App Services\18. Custom DNS and SSL Certificates.mp4
# 17:42:45 -   - 3. Utilizing Azure App Services\19. Application Backup and Restore.mp4
# 17:42:45 -   - 3. Utilizing Azure App Services\20. Azure App Services.mp4
# 17:42:45 -   - 3. Utilizing Azure App Services\21. Deploying a Web App.mp4
# 17:42:45 -   - 3. Utilizing Azure App Services\22. Network Integration.mp4
# 17:42:45 -   - 3. Utilizing Azure App Services\23. App Service Environment.mp4
# 17:42:45 -   - 3. Utilizing Azure App Services\24. Module Summary.mp4
# 17:42:45 -   - 4. Utilizing Azure Functions\25. Module Introduction.mp4
# 17:42:45 -   - 4. Utilizing Azure Functions\26. Serverless Compute Overview.mp4
# 17:42:45 -   - 4. Utilizing Azure Functions\27. Azure Functions.mp4
# 17:42:45 -   - 4. Utilizing Azure Functions\28. Logic Apps.mp4
# 17:42:45 -   - 4. Utilizing Azure Functions\29. Module Summary.mp4
# 17:42:45 -   - 5. Common Application Architectures in Azure\30. Module Introduction.mp4
# 17:42:45 -   - 5. Common Application Architectures in Azure\31. Multitiered Applications.mp4
# 17:42:45 -   - 5. Common Application Architectures in Azure\32. IaaS to PaaS Migration.mp4
# 17:42:45 -   - 5. Common Application Architectures in Azure\33. Containers and Container Services.mp4
# 17:42:45 -   - 5. Common Application Architectures in Azure\34. Azure Traffic Manager.mp4
# 17:42:45 -   - 5. Common Application Architectures in Azure\35. Module Summary.mp4
# 17:42:45 - Generated title: Microsoft - Azure - Pluralsight - Implementing Azure Application Services
# 17:42:45 - Starting video merge...
# 17:42:45 -
# Analyzing 35 videos for merge:
# 17:42:45 - Video 1/35: 1. Course Overview\01. Course Overview.mp4
# 17:42:45 - Video 2/35: 2. Cloud and Azure Overview\02. Module Introduction.mp4
# 17:42:46 - Video 3/35: 2. Cloud and Azure Overview\03. Who Am I.mp4
# 17:42:46 - Video 4/35: 2. Cloud and Azure Overview\04. Why This Is Important.mp4
# 17:42:46 - Video 5/35: 2. Cloud and Azure Overview\05. Types of Cloud Service.mp4
# 17:42:47 - Video 6/35: 2. Cloud and Azure Overview\06. Azure Subscriptions and Regions.mp4
# 17:42:47 - Video 7/35: 2. Cloud and Azure Overview\07. Azure Services Overview.mp4
# 17:42:47 - Video 8/35: 2. Cloud and Azure Overview\08. Resource Groups and RBAC.mp4
# 17:42:48 - Video 9/35: 2. Cloud and Azure Overview\09. Module Summary.mp4
# 17:42:48 - Video 10/35: 3. Utilizing Azure App Services\10. Module Introduction.mp4
# 17:42:48 - Video 11/35: 3. Utilizing Azure App Services\11. Why Have PaaS.mp4
# 17:42:49 - Video 12/35: 3. Utilizing Azure App Services\12. Azure App Services Overview.mp4
# 17:42:49 - Video 13/35: 3. Utilizing Azure App Services\13. Azure App Service Plans.mp4
# 17:42:49 - Video 14/35: 3. Utilizing Azure App Services\14. When to Use a New App Service Plan.mp4
# 17:42:50 - Video 15/35: 3. Utilizing Azure App Services\15. Deployment Slots.mp4
# 17:42:50 - Video 16/35: 3. Utilizing Azure App Services\16. Scale Options.mp4
# 17:42:50 - Video 17/35: 3. Utilizing Azure App Services\17. Quotas and Metrics.mp4
# 17:42:50 - Video 18/35: 3. Utilizing Azure App Services\18. Custom DNS and SSL Certificates.mp4
# 17:42:51 - Video 19/35: 3. Utilizing Azure App Services\19. Application Backup and Restore.mp4
# 17:42:51 - Video 20/35: 3. Utilizing Azure App Services\20. Azure App Services.mp4
- Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Implementing Azure Application Services\4. Utilizing Azure Functions
# 17:54:08 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Implementing Azure Application Services\5. Common Application Architectures in Azure
# 17:54:08 - Deleted 5 folders containing videos
# 17:54:08 - Successfully deleted all video folders
# 17:54:08 - Cleaned up merged video file: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Implementing Azure Application Services\Implementing_merged.mp4
# 17:54:08 -
# Processing tutorial: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Microsoft Azure Administration For AWS Administrators
# 17:54:08 -
# Processing tutorial folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Microsoft Azure Administration For AWS Administrators
# 17:54:08 - Found 60 videos:
# 17:54:08 -   - 1. Course Overview\01. Course Overview.mp4
# 17:54:08 -   - 2. Microsoft Azure Familiarization\02. Overview.mp4
# 17:54:08 -   - 2. Microsoft Azure Familiarization\03. About the Azure Portal.mp4
# 17:54:08 -   - 2. Microsoft Azure Familiarization\04. Demo - Tour the Azure Portal.mp4
# 17:54:08 -   - 2. Microsoft Azure Familiarization\05. Demo - Role-based Access Control (RBAC).mp4
# 17:54:08 -   - 2. Microsoft Azure Familiarization\06. Management Interfaces.mp4
# ...
# 18:13:04 - Video 36/62: 5. Designing Compute Solutions for Containers\36. Why Not Use a VM.mp4
# 18:13:05 - Video 37/62: 5. Designing Compute Solutions for Containers\37. Docker Overview.mp4
# 18:13:05 - Video 38/62: 5. Designing Compute Solutions for Containers\38. Image2Docker.mp4
# 18:13:05 - Video 39/62: 5. Designing Compute Solutions for Containers\39. Azure Container Service.mp4
# 18:13:06 - Video 40/62: 5. Designing Compute Solutions for Containers\40. Module Summary.mp4
# 18:13:06 - Video 41/62: 6. Designing Compute Solutions for PaaS\41. Module Introduction.mp4
# 18:13:06 - Video 42/62: 6. Designing Compute Solutions for PaaS\42. PaaS Overview.mp4
# 18:13:07 - Video 43/62: 6. Designing Compute Solutions for PaaS\43. App Service Plan.mp4
# 18:13:07 - Video 44/62: 6. Designing Compute Solutions for PaaS\44. When to Use a New App Service Plan.mp4
# 18:13:07 - Video 45/62: 6. Designing Compute Solutions for PaaS\45. Deployment Slots.mp4
# 18:13:08 - Video 46/62: 6. Designing Compute Solutions for PaaS\46. Scaling and Service Resiliency.mp4
# 18:13:08 - Video 47/62: 6. Designing Compute Solutions for PaaS\47. Network Integration.mp4
# 18:13:08 - Video 48/62: 6. Designing Compute Solutions for PaaS\48. App Service Environment.mp4
# 18:13:08 - Video 49/62: 6. Designing Compute Solutions for PaaS\49. Azure App Services.mp4
# 18:13:09 - Video 50/62: 6. Designing Compute Solutions for PaaS\50. Custom DNS and SSL Certificates.mp4
# 18:13:09 - Video 51/62: 6. Designing Compute Solutions for PaaS\51. Leveraging Multiple Regions.mp4
# 18:13:09 - Video 52/62: 6. Designing Compute Solutions for PaaS\52. Quotas and Metrics.mp4
# 18:13:10 - Video 53/62: 6. Designing Compute Solutions for PaaS\53. Service Fabric.mp4
# 18:13:10 - Video 54/62: 6. Designing Compute Solutions for PaaS\54. Serverless Compute.mp4
# 18:13:10 - Video 55/62: 6. Designing Compute Solutions for PaaS\55. Other Complementary Services.mp4
# 18:13:11 - Video 56/62: 6. Designing Compute Solutions for PaaS\56. Module Summary.mp4
- Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Planning And Designing Microsoft Azure Compute Solutions\7. Azure Service Architecture Case Study Review
# 18:27:46 - Deleted 7 folders containing videos
# 18:27:46 - Successfully deleted all video folders
# 18:27:46 - Cleaned up merged video file: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Planning And Designing Microsoft Azure Compute Solutions\Planning_merged.mp4
# 18:27:46 -
# Processing tutorial: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Understanding The Programming Models of Azure Service Fabric
# 18:27:46 -
# Processing tutorial folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Understanding The Programming Models of Azure Service Fabric
# 18:27:46 - Found 40 videos:
# 18:27:46 -   - 1.Course Overview\01.Course Overview.mp4
# 18:27:46 -   - 2.Getting Started\02.Course Introduction and Overview.mp4
# 18:27:46 -   - 2.Getting Started\03.Intended Audiences.mp4
# 18:27:46 -   - 2.Getting Started\04.Available Options.mp4
# 18:27:46 -   - 2.Getting Started\05.Programming Models.mp4
# 18:27:46 -   - 2.Getting Started\06.Demo Application.mp4
# 18:27:46 -   - 2.Getting Started\07.Summary.mp4
# 18:27:46 -   - 3.Installing Service Fabric\08.Overview.mp4
# 18:27:46 -   - 3.Installing Service Fabric\09.Supported Environments.mp4
# 18:27:46 -   - 3.Installing Service Fabric\10.Get Development Environment Ready.mp4
# 18:27:46 -   - 3.Installing Service Fabric\11.Getting Visual Studio Ready.mp4
# 18:27:46 -   - 3.Installing Service Fabric\12.Installing Azure Service Fabric SDK.mp4
# 18:27:46 -   - 3.Installing Service Fabric\13.Creating a Simple Application.mp4
# 18:27:46 -   - 3.Installing Service Fabric\14.Summary.mp4
# 18:27:46 -   - 4.Creating Service Fabric Services\15.Overview.mp4
# 18:27:46 -   - 4.Creating Service Fabric Services\16.What Is a Reliable Service.mp4
# 18:27:46 -   - 4.Creating Service Fabric Services\17.Creating Product Catalog.mp4
# 18:27:46 -   - 4.Creating Service Fabric Services\18.Service Lifecycle.mp4
# 18:27:46 -   - 4.Creating Service Fabric Services\19.Product Catalog Service.mp4
# 18:27:46 -   - 4.Creating Service Fabric Services\20.Creating Web API.mp4
# 18:27:46 -   - 4.Creating Service Fabric Services\21.Connecting Two Services Together.mp4
# 18:27:46 -   - 4.Creating Service Fabric Services\22.Summary.mp4
# 18:27:46 -   - 5.Exploring Actor Model Support\23.Overview.mp4
# 18:27:46 -   - 5.Exploring Actor Model Support\24.Actor Model Theory.mp4
# 18:27:46 -   - 5.Exploring Actor Model Support\25.Service Fabric Actors Implementation.mp4
# 18:27:46 -   - 5.Exploring Actor Model Support\26.Building User Service.mp4
# 18:27:46 -   - 5.Exploring Actor Model Support\27.Calling to Actors.mp4
# 18:27:46 -   - 5.Exploring Actor Model Support\28.Summary.mp4
# 18:27:46 -   - 6.Managing State in Service Fabric\29.Overview.mp4
# 18:27:46 -   - 6.Managing State in Service Fabric\30.Clusters and Nodes.mp4
# 18:27:46 -   - 6.Managing State in Service Fabric\31.Instances, Replicas, and Partitions.mp4
# 18:27:46 -   - 6.Managing State in Service Fabric\32.Creating Checkout Service.mp4
# 18:27:46 -   - 6.Managing State in Service Fabric\33.Configuring Service Partitions.mp4
# 18:27:46 -   - 6.Managing State in Service Fabric\34.Simulating Disasters.mp4
# 18:27:46 -   - 6.Managing State in Service Fabric\35.Summary.mp4
# 18:27:55 - Video 30/40: 6.Managing State in Service Fabric\30.Clusters and Nodes.mp4
# 18:27:55 - Video 31/40: 6.Managing State in Service Fabric\31.Instances, Replicas, and Partitions.mp4
# 18:27:56 - Video 32/40: 6.Managing State in Service Fabric\32.Creating Checkout Service.mp4
# 18:27:56 - Video 33/40: 6.Managing State in Service Fabric\33.Configuring Service Partitions.mp4
# 18:27:56 - Video 34/40: 6.Managing State in Service Fabric\34.Simulating Disasters.mp4
# 18:27:57 - Video 35/40: 6.Managing State in Service Fabric\35.Summary.mp4
# 18:27:57 - Video 36/40: 7.Getting Ready for Deployment\36.Overview.mp4
# 18:27:57 - Video 37/40: 7.Getting Ready for Deployment\37.Packaging Applications.mp4
# 18:27:58 - Video 38/40: 7.Getting Ready for Deployment\38.Installing Applications.mp4
# 18:27:58 - Video 39/40: 7.Getting Ready for Deployment\39.Upgrading and Deleting Applications.mp4
# 18:27:58 - Video 40/40: 7.Getting Ready for Deployment\40.Summary.mp4
# 18:27:58 -
# Total expected duration: 8009.47 seconds
# 18:34:39 - Merge completed successfully! Final video duration: 8009.47 seconds
# 18:34:39 - Videos merged successfully
# 18:34:48 - Upload attempt 1/3
# 18:34:48 - Starting upload: Microsoft - Azure - Pluralsight - Understanding The Programming Models of Azure Service Fabric
# 18:34:52 - Upload progress: 4%
# 18:34:56 - Upload progress: 9%
# 18:35:00 - Upload progress: 13%
# 18:35:04 - Upload progress: 18%
# 18:35:07 - Upload progress: 22%
# 18:35:10 - Upload progress: 27%
# 18:35:14 - Upload progress: 31%
# 18:35:18 - Upload progress: 36%
# 18:35:22 - Upload progress: 40%
# 18:35:25 - Upload progress: 45%
# 18:35:29 - Upload progress: 49%
# 18:35:32 - Upload progress: 54%
# 18:35:37 - Upload progress: 58%
# 18:35:40 - Upload progress: 63%
# 18:35:44 - Upload progress: 67%
# 18:35:47 - Upload progress: 72%
# 18:35:51 - Upload progress: 76%
# 18:35:55 - Upload progress: 81%
# 18:35:59 - Upload progress: 85%
# 18:36:02 - Upload progress: 90%
# 18:36:06 - Upload progress: 94%
# 18:36:11 - Upload progress: 99%
# 18:36:12 - Upload completed successfully
# 18:36:12 - Upload successful! Video ID: xgqCXTvLBUs
# 18:36:12 - Video URL: https://www.youtube.com/watch?v=xgqCXTvLBUs
# 18:36:12 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Understanding The Programming Models of Azure Service Fabric\1.Course Overview
# 18:36:12 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Understanding The Programming Models of Azure Service Fabric\2.Getting Started
# 18:36:12 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Understanding The Programming Models of Azure Service Fabric\3.Installing Service Fabric
# 18:36:12 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Understanding The Programming Models of Azure Service Fabric\4.Creating Service Fabric Services
# 18:36:12 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Understanding The Programming Models of Azure Service Fabric\5.Exploring Actor Model Support
# 18:36:12 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Understanding The Programming Models of Azure Service Fabric\6.Managing State in Service Fabric
# 18:36:12 - Deleted folder: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Understanding The Programming Models of Azure Service Fabric\7.Getting Ready for Deployment
# 18:36:12 - Deleted 7 folders containing videos
# 18:36:12 - Successfully deleted all video folders
# 18:36:12 - Cleaned up merged video file: \\fileserver2\Head Office Server\Projects Control (PC)\10 Backup\05 Tutorials\Microsoft\Azure\Pluralsight\Understanding The Programming Models of Azure Service Fabric\Understanding_merged.mp4
