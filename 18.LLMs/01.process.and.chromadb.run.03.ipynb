# %%
import os
import json
import pdfplumber
import pytesseract
from PIL import Image
import pandas as pd
from datetime import datetime
from docx import Document
from pptx import Presentation
import warnings
import re

# Suppress specific CropBox warning from pdfplumber
import logging
logging.getLogger("pdfminer").setLevel(logging.ERROR)

class CropBoxFilter:
    def filter(self, record):
        return not (record.levelno == logging.WARNING and 'CropBox missing from /Page, defaulting to MediaBox' in record.getMessage())

logging.getLogger().addFilter(CropBoxFilter())

# Add tkinter for folder selection
def select_folder():
    import tkinter as tk
    from tkinter import filedialog
    root = tk.Tk()
    root.withdraw()
    folder_selected = filedialog.askdirectory(title='Select folder to process')
    root.destroy()
    return folder_selected

def extract_text_from_pdf(pdf_path):
    text = ""
    try:
        with pdfplumber.open(pdf_path) as pdf:
            for page in pdf.pages:
                page_text = page.extract_text()
                if page_text:
                    text += page_text + "\n"
    except Exception:
        pass
    return text.strip()

def ocr_pdf(pdf_path):
    text = ""
    try:
        with pdfplumber.open(pdf_path) as pdf:
            for page in pdf.pages:
                img = page.to_image(resolution=300).original
                pil_img = Image.fromarray(img)
                page_text = pytesseract.image_to_string(pil_img)
                if page_text:
                    text += page_text + "\n"
    except Exception:
        pass
    return text.strip()

def extract_text_from_excel(excel_path):
    text = ""
    try:
        xls = pd.ExcelFile(excel_path)
        for sheet_name in xls.sheet_names:
            df = pd.read_excel(xls, sheet_name=sheet_name, dtype=str)
            text += f"\n--- Sheet: {sheet_name} ---\n"
            text += df.fillna('').to_string(index=False, header=True)
    except Exception:
        pass
    return text.strip()

def extract_text_from_docx(docx_path):
    text = ""
    try:
        doc = Document(docx_path)
        for para in doc.paragraphs:
            text += para.text + "\n"
    except Exception:
        pass
    return text.strip()

def extract_text_from_pptx(pptx_path):
    text = ""
    try:
        prs = Presentation(pptx_path)
        for slide in prs.slides:
            for shape in slide.shapes:
                if hasattr(shape, "text"):
                    text += shape.text + "\n"
    except Exception:
        pass
    return text.strip()

def process_folder(folder_path, output_json_path):
    data = []
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            print(f"[INFO] Processing file: {file}")
            file_path = os.path.join(root, file)
            ext = file.lower().split('.')[-1]
            entry = {
                'file_name': file,
                'file_path': file_path,
                'type': ext,
                'extracted_at': datetime.now().isoformat(),
                'text': ''
            }
            reason = None
            if ext == 'pdf':
                text = extract_text_from_pdf(file_path)
                if not text:
                    text = ocr_pdf(file_path)
                    if text:
                        reason = 'extracted via OCR'
                    else:
                        reason = 'no text extracted (PDF and OCR failed)'
                else:
                    reason = 'extracted as text PDF'
                entry['text'] = text
            elif ext in ['xls', 'xlsx']:
                text = extract_text_from_excel(file_path)
                entry['text'] = text
                reason = 'extracted from Excel' if text else 'no text extracted (Excel)'
            elif ext == 'docx':
                text = extract_text_from_docx(file_path)
                entry['text'] = text
                reason = 'extracted from Word' if text else 'no text extracted (Word)'
            elif ext == 'pptx':
                text = extract_text_from_pptx(file_path)
                entry['text'] = text
                reason = 'extracted from PowerPoint' if text else 'no text extracted (PowerPoint)'
            else:
                print(f"[WARN] Skipped unsupported file type: {file}")
                continue
            if entry['text']:
                data.append(entry)
            else:
                print(f"[WARN] No text extracted from: {file} ({reason})")
    with open(output_json_path, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=2)
    print(f"Processed {len(data)} documents. Output saved to {output_json_path}")

if __name__ == "__main__":
    # New output directory outside the repo
    output_dir = r'C:/Users/Omar Essam2/OneDrive - Rowad Modern Engineering/x004 Data Science/03.rme.db/05.llm/extracted_json'
    os.makedirs(output_dir, exist_ok=True)
    folder = select_folder()
    if not folder:
        print("No folder selected. Exiting.")
    else:
        folder_name = os.path.basename(os.path.normpath(folder))
        output_json = os.path.join(output_dir, f"{folder_name}_extracted.json")
        process_folder(folder, output_json)
# Out:
# [INFO] Processing file: Copy of G.M. %s Comparison Ehab 12-12-23.xlsb
# [WARN] Skipped unsupported file type: Copy of G.M. %s Comparison Ehab 12-12-23.xlsb
# [INFO] Processing file: G.M. %s Comparison Ehab 30-3-2024 cutdate 14-3-2024.xlsb
# [WARN] Skipped unsupported file type: G.M. %s Comparison Ehab 30-3-2024 cutdate 14-3-2024.xlsb
# [INFO] Processing file: G.M. %s Comparison Ehab 30-9-2023.xlsb
# [WARN] Skipped unsupported file type: G.M. %s Comparison Ehab 30-9-2023.xlsb
# [INFO] Processing file: G.M. %s Comparison Ehab 30-7-2023-1.xlsx
# [WARN] No text extracted from: G.M. %s Comparison Ehab 30-7-2023-1.xlsx (no text extracted (Excel))
# [INFO] Processing file: Copy of G.M. %s Comparison Ehab 30-9-2023LLNN.xlsb
# [WARN] Skipped unsupported file type: Copy of G.M. %s Comparison Ehab 30-9-2023LLNN.xlsb
# [INFO] Processing file: G.M. %s Comparison Ehab 30-9-2023L.xlsb
# [WARN] Skipped unsupported file type: G.M. %s Comparison Ehab 30-9-2023L.xlsb
# [INFO] Processing file: G.M. %s Comparison Ehab 30-9-2023LLN.xlsb
# [WARN] Skipped unsupported file type: G.M. %s Comparison Ehab 30-9-2023LLN.xlsb
# [INFO] Processing file: 03 Jun 2018 SWD Budget.rar
# [WARN] Skipped unsupported file type: 03 Jun 2018 SWD Budget.rar
# [INFO] Processing file: 04 Jul 2018 SWD Budget.rar
# [WARN] Skipped unsupported file type: 04 Jul 2018 SWD Budget.rar
# [INFO] Processing file: 05 Sep 2018 SWD Budget.rar
# [WARN] Skipped unsupported file type: 05 Sep 2018 SWD Budget.rar
# [INFO] Processing file: Benban Solar Power Plant.rar
# [WARN] Skipped unsupported file type: Benban Solar Power Plant.rar
# [INFO] Processing file: Contract Vs Cost.xlsx
# [WARN] No text extracted from: Contract Vs Cost.xlsx (no text extracted (Excel))
# [INFO] Processing file: Copy of 07 SWD Al-Awsaty Budget Rev 00 @30-12-2018.xlsx
# [WARN] No text extracted from: Copy of 07 SWD Al-Awsaty Budget Rev 00 @30-12-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: Copy of Cost Control Approvers.xls
# [WARN] No text extracted from: Copy of Cost Control Approvers.xls (no text extracted (Excel))
# [INFO] Processing file: RME Org Proje.xls
# [WARN] No text extracted from: RME Org Proje.xls (no text extracted (Excel))
# [INFO] Processing file: DOC001.PDF
# [WARN] No text extracted from: DOC001.PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 1.Pkg 53.rar
# [WARN] Skipped unsupported file type: 1.Pkg 53.rar
# [INFO] Processing file: ERP-PKG#53 Budget Update(Rev1).xlsx
# [WARN] No text extracted from: ERP-PKG#53 Budget Update(Rev1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 10.Ismalia Bridges.rar
# [WARN] Skipped unsupported file type: 10.Ismalia Bridges.rar
# [INFO] Processing file: 11.PI Park.rar
# [WARN] Skipped unsupported file type: 11.PI Park.rar
# [INFO] Processing file: SWD Budget for SLP Logisitc Center...xlsx
# [WARN] No text extracted from: SWD Budget for SLP Logisitc Center...xlsx (no text extracted (Excel))
# [INFO] Processing file: 12.Mostasmeeren Sub Station.rar
# [WARN] Skipped unsupported file type: 12.Mostasmeeren Sub Station.rar
# [INFO] Processing file: MOST-Revised-Budget-EAC.xlsx
# [WARN] No text extracted from: MOST-Revised-Budget-EAC.xlsx (no text extracted (Excel))
# [INFO] Processing file: 13.Banisuief SubStation.rar
# [WARN] Skipped unsupported file type: 13.Banisuief SubStation.rar
# [INFO] Processing file: SWD Budget for BSF-SS-Revised-EAC-Rev.01.xlsx
# [WARN] No text extracted from: SWD Budget for BSF-SS-Revised-EAC-Rev.01.xlsx (no text extracted (Excel))
# [INFO] Processing file: 14.Tamai Mdeed  Substation.rar
# [WARN] Skipped unsupported file type: 14.Tamai Mdeed  Substation.rar
# [INFO] Processing file: SWD Budget for TAM-SS-Revised-EAC-Rev.01.xlsx
# [WARN] No text extracted from: SWD Budget for TAM-SS-Revised-EAC-Rev.01.xlsx (no text extracted (Excel))
# [INFO] Processing file: 15.Ismalia Substation.rar
# [WARN] Skipped unsupported file type: 15.Ismalia Substation.rar
# [INFO] Processing file: SWD Budget for Ism-SS-Revised-EAC-Rev.01.xlsx
# [WARN] No text extracted from: SWD Budget for Ism-SS-Revised-EAC-Rev.01.xlsx (no text extracted (Excel))
# [INFO] Processing file: 16.Seiemens Ramsis.rar
# [WARN] Skipped unsupported file type: 16.Seiemens Ramsis.rar
# [INFO] Processing file: Seimens Budget Oricale 1-1-2018.xlsx
# [WARN] No text extracted from: Seimens Budget Oricale 1-1-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 18.Sodic Club house.rar
# [WARN] Skipped unsupported file type: 18.Sodic Club house.rar
# [INFO] Processing file: SWD Budget for SODIC ALLEGRIA Club House.xlsx
# [WARN] No text extracted from: SWD Budget for SODIC ALLEGRIA Club House.xlsx (no text extracted (Excel))
# [INFO] Processing file: Lock & Load Budget.xlsx
# [WARN] No text extracted from: Lock & Load Budget.xlsx (no text extracted (Excel))
# [INFO] Processing file: 2.Pkg 62.rar
# [WARN] Skipped unsupported file type: 2.Pkg 62.rar
# [INFO] Processing file: SWD Budget for BKG 62 Slope Stabilization for Village E PKG#62111.xlsx
# [WARN] No text extracted from: SWD Budget for BKG 62 Slope Stabilization for Village E PKG#62111.xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD Budget for Ministries Buildings-March-18.xlsx
# [WARN] No text extracted from: SWD Budget for Ministries Buildings-March-18.xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD Abu Sultan Bridge.xlsx
# [WARN] No text extracted from: SWD Abu Sultan Bridge.xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD El SokhnaTunnel.xlsx
# [WARN] No text extracted from: SWD El SokhnaTunnel.xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD Ismailia Bridge.xlsx
# [WARN] No text extracted from: SWD Ismailia Bridge.xlsx (no text extracted (Excel))
# [INFO] Processing file: Copy of SWD Budget for JICA NADA.xlsx
# [WARN] No text extracted from: Copy of SWD Budget for JICA NADA.xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD King Farouk Resthouse Restoration Budget Rev 00.xlsx
# [WARN] No text extracted from: SWD King Farouk Resthouse Restoration Budget Rev 00.xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD Mohamed Ali Budget Rev 00.xlsx
# [WARN] No text extracted from: SWD Mohamed Ali Budget Rev 00.xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD Nefisha Bridge.xlsx
# [WARN] No text extracted from: SWD Nefisha Bridge.xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD Budget for Mintra Factory Rev 00.xlsx
# [WARN] No text extracted from: SWD Budget for Mintra Factory Rev 00.xlsx (no text extracted (Excel))
# [INFO] Processing file: 3.pkg 107 and pkg 117.rar
# [WARN] Skipped unsupported file type: 3.pkg 107 and pkg 117.rar
# [INFO] Processing file: SWD Budget for Marassi - BP#117; Bridge 1  Project.xlsx
# [WARN] No text extracted from: SWD Budget for Marassi - BP#117; Bridge 1  Project.xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD Budget for PKG 107.xlsx
# [WARN] No text extracted from: SWD Budget for PKG 107.xlsx (no text extracted (Excel))
# [INFO] Processing file: 4.Cement Plant Banisuief.rar
# [WARN] Skipped unsupported file type: 4.Cement Plant Banisuief.rar
# [INFO] Processing file: Budget for cement plant.xlsx
# [WARN] No text extracted from: Budget for cement plant.xlsx (no text extracted (Excel))
# [INFO] Processing file: 5.Royal City.rar
# [WARN] Skipped unsupported file type: 5.Royal City.rar
# [INFO] Processing file: SWD Budget Royal City.xlsx
# [WARN] No text extracted from: SWD Budget Royal City.xlsx (no text extracted (Excel))
# [INFO] Processing file: 6.Rolling Mill.rar
# [WARN] Skipped unsupported file type: 6.Rolling Mill.rar
# [INFO] Processing file: SWD Rolling Mill Eleco Steel.xlsx
# [WARN] No text extracted from: SWD Rolling Mill Eleco Steel.xlsx (no text extracted (Excel))
# [INFO] Processing file: 7.Kyan.rar
# [WARN] Skipped unsupported file type: 7.Kyan.rar
# [INFO] Processing file: SWD Budget for Kayan.xlsx
# [WARN] No text extracted from: SWD Budget for Kayan.xlsx (no text extracted (Excel))
# [INFO] Processing file: 9.New Capital Tunnels.rar
# [WARN] Skipped unsupported file type: 9.New Capital Tunnels.rar
# [INFO] Processing file: SWD Budget New Capital Tunnels.xlsx
# [WARN] No text extracted from: SWD Budget New Capital Tunnels.xlsx (no text extracted (Excel))
# [INFO] Processing file: Copy of SWD Benban Budget Rev 00 .xlsx
# [WARN] No text extracted from: Copy of SWD Benban Budget Rev 00 .xlsx (no text extracted (Excel))
# [INFO] Processing file: Copy of SWD El Sokhna Budget Rev 00.xlsx
# [WARN] No text extracted from: Copy of SWD El Sokhna Budget Rev 00.xlsx (no text extracted (Excel))
# [INFO] Processing file: Copy of SWD JAZI Budget Rev 00.xlsx
# [WARN] No text extracted from: Copy of SWD JAZI Budget Rev 00.xlsx (no text extracted (Excel))
# [INFO] Processing file: Copy of SWD Mohamed Ali Budget Rev 00N.xlsx
# [WARN] No text extracted from: Copy of SWD Mohamed Ali Budget Rev 00N.xlsx (no text extracted (Excel))
# [INFO] Processing file: Copy of SWD Nefisha Bridge Rev 00.xlsx
# [WARN] No text extracted from: Copy of SWD Nefisha Bridge Rev 00.xlsx (no text extracted (Excel))
# [INFO] Processing file: Copy of SWD SLP Budget Rev 01.xlsx
# [WARN] No text extracted from: Copy of SWD SLP Budget Rev 01.xlsx (no text extracted (Excel))
# [INFO] Processing file: Al Jazi Mall.pdf
# [WARN] No text extracted from: Al Jazi Mall.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: El Sokhna Tunnel.pdf
# [WARN] No text extracted from: El Sokhna Tunnel.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: Mohamed Ali.pdf
# [WARN] No text extracted from: Mohamed Ali.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 03 Jun 2018 SWD Budget.rar
# [WARN] Skipped unsupported file type: 03 Jun 2018 SWD Budget.rar
# [INFO] Processing file: 21#107 Budget Rev 00 @26-6-2018.xlsx
# [WARN] No text extracted from: 21#107 Budget Rev 00 @26-6-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD Banisuief Power Plant Budget Rev 00 @28-6-2018.xlsx
# [WARN] No text extracted from: SWD Banisuief Power Plant Budget Rev 00 @28-6-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD New Giza University phase 1B Budget Rev 00 @5-7-2018.xlsx
# [WARN] No text extracted from: SWD New Giza University phase 1B Budget Rev 00 @5-7-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 10 SWD Benisuif Cement Plant Budget Rev 00 @28-6-2018.xlsx
# [WARN] No text extracted from: 10 SWD Benisuif Cement Plant Budget Rev 00 @28-6-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 11 SWD Benban Budget Rev 01 @26-6-2018.xlsx
# [WARN] No text extracted from: 11 SWD Benban Budget Rev 01 @26-6-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 15SWD PKG#117 Budget Rev 01 @5-7-2018.xlsx
# [WARN] No text extracted from: 15SWD PKG#117 Budget Rev 01 @5-7-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 01.Sodic System Rev 00 @21-6-2018.xlsx
# [WARN] No text extracted from: 01.Sodic System Rev 00 @21-6-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 01.SWD Sodic Allegria Budget Rev 00 @21-6-2018.xlsx
# [WARN] No text extracted from: 01.SWD Sodic Allegria Budget Rev 00 @21-6-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: Maxim mall_IPC Final 24.4.2018.xlsx
# [WARN] No text extracted from: Maxim mall_IPC Final 24.4.2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: Maxium System Rev 00 @ 22-6-2018.xls
# [WARN] No text extracted from: Maxium System Rev 00 @ 22-6-2018.xls (no text extracted (Excel))
# [INFO] Processing file: SWD Maxium Budget Rev 00 @21-6-2018.xlsx
# [WARN] No text extracted from: SWD Maxium Budget Rev 00 @21-6-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 18.PKG 62 System Rev 00 @26-6-2018.xlsx
# [WARN] No text extracted from: 18.PKG 62 System Rev 00 @26-6-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD PKG62 Budget Rev 00 @21-6-2018.xlsx
# [WARN] No text extracted from: SWD PKG62 Budget Rev 00 @21-6-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 20.SWD ROYAL CITY MALL Budget Rev 00 @26-6-2018.xlsx
# [WARN] No text extracted from: 20.SWD ROYAL CITY MALL Budget Rev 00 @26-6-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 10.SWD PKG 53 Budget Rev 00 @28-6-2018.xlsx
# [WARN] No text extracted from: 10.SWD PKG 53 Budget Rev 00 @28-6-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: ERP- RME- Mintra project Budget Rev 04 @ 28-6-2018.xlsx
# [WARN] No text extracted from: ERP- RME- Mintra project Budget Rev 04 @ 28-6-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 27. SWD Rolling Mill Budget Rev 00 3-7-2018.xlsx
# [WARN] No text extracted from: 27. SWD Rolling Mill Budget Rev 00 3-7-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 02.Siemens System Rev 00 @21-6-2018.xlsx
# [WARN] No text extracted from: 02.Siemens System Rev 00 @21-6-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 02.SWD Seimens Budget Rev 00 @24-6-2018.xlsx
# [WARN] No text extracted from: 02.SWD Seimens Budget Rev 00 @24-6-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 10.SWD JAZI Budget Rev 00 @21-6-2018.xlsx
# [WARN] No text extracted from: 10.SWD JAZI Budget Rev 00 @21-6-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 08. SLP System Rev 00 @21-6-2018.xlsx
# [WARN] No text extracted from: 08. SLP System Rev 00 @21-6-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD SLP Budget Rev 00@24-6-2018.xlsx
# [WARN] No text extracted from: SWD SLP Budget Rev 00@24-6-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 13.Mohamed Ali System Rev 00 @21-6-2018.xlsx
# [WARN] No text extracted from: 13.Mohamed Ali System Rev 00 @21-6-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 13.SWD Mohamed Ali Budget Rev 00 @21-6-2018.xlsx
# [WARN] No text extracted from: 13.SWD Mohamed Ali Budget Rev 00 @21-6-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: Mohamed Ali restoration cost.xlsx
# [WARN] No text extracted from: Mohamed Ali restoration cost.xlsx (no text extracted (Excel))
# [INFO] Processing file: OH Mohmed Ali- Rev02.xlsx
# [WARN] No text extracted from: OH Mohmed Ali- Rev02.xlsx (no text extracted (Excel))
# [INFO] Processing file: 07.Kayan Lock & Load System Rev 00 @21-6-2018.xlsx
# [WARN] No text extracted from: 07.Kayan Lock & Load System Rev 00 @21-6-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 07.SWD Kayan LockLoad Budget Rev 00 @21-6-2018.xlsx
# [WARN] No text extracted from: 07.SWD Kayan LockLoad Budget Rev 00 @21-6-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 12 SWD Nefisha Bridge Budget Rev 02 @28-6-2018.xlsx
# [WARN] No text extracted from: 12 SWD Nefisha Bridge Budget Rev 02 @28-6-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 09. EL Sokhna Tunnel System Rev 00 @21-6-2018.xlsx
# [WARN] No text extracted from: 09. EL Sokhna Tunnel System Rev 00 @21-6-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 09.SWD El Sokhna Tunnel Budget Rev 00@21-6-2018.xlsx
# [WARN] No text extracted from: 09.SWD El Sokhna Tunnel Budget Rev 00@21-6-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: Sokhna Tunnel.xlsx
# [WARN] No text extracted from: Sokhna Tunnel.xlsx (no text extracted (Excel))
# [INFO] Processing file: 16.SWD Ministries Buildings Budget Rev 00 @5-7-2018.xlsx
# [WARN] No text extracted from: 16.SWD Ministries Buildings Budget Rev 00 @5-7-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 22.SWD Alamein Budget Rev 00 @28-6-2018.xlsx
# [WARN] No text extracted from: 22.SWD Alamein Budget Rev 00 @28-6-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 23.SWD Abu Sultan Bridge Budget Rev 01 @28-6-2018.xlsx
# [WARN] No text extracted from: 23.SWD Abu Sultan Bridge Budget Rev 01 @28-6-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 28.SWD Ismailia Bridges Budget Rev 00 @3-7-2018.xlsx
# [WARN] No text extracted from: 28.SWD Ismailia Bridges Budget Rev 00 @3-7-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 29.SWD New Capital Tunnel Budget Rev 00 @3-7-2018.xlsx
# [WARN] No text extracted from: 29.SWD New Capital Tunnel Budget Rev 00 @3-7-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD Ismailia Substation Budget Rev 00 @5-7-2018.xlsx
# [WARN] No text extracted from: SWD Ismailia Substation Budget Rev 00 @5-7-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 30. SWD Fish Market  Budget Rev 01@4-7-2018.xlsx
# [WARN] No text extracted from: 30. SWD Fish Market  Budget Rev 01@4-7-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 31. SWD KAYAN 110 Budget Rev 01 @4-7-2018.xlsx
# [WARN] No text extracted from: 31. SWD KAYAN 110 Budget Rev 01 @4-7-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 06.SWD Tamay Amaded Substation Budget Rev 00 @5-7-2018.xlsx
# [WARN] No text extracted from: 06.SWD Tamay Amaded Substation Budget Rev 00 @5-7-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 05.SWD Benisuief Substation Budget Rev 00 @5-7-2018.xlsx
# [WARN] No text extracted from: 05.SWD Benisuief Substation Budget Rev 00 @5-7-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 05.SWD Mostasmereen Substation Budget Rev 00 @24-6-2018.xlsx
# [WARN] No text extracted from: 05.SWD Mostasmereen Substation Budget Rev 00 @24-6-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: Mostasmeren system.xls
# [WARN] No text extracted from: Mostasmeren system.xls (no text extracted (Excel))
# [INFO] Processing file: 0019 Ismalia Brigde 30.6.18.pdf
# [WARN] No text extracted from: 0019 Ismalia Brigde 30.6.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0032 Sodic Club House 30.6.18.pdf
# [WARN] No text extracted from: 0032 Sodic Club House 30.6.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0034 PKG-053 30.6.18.pdf
# [WARN] No text extracted from: 0034 PKG-053 30.6.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0040 Mostasmereen 30.6.18.pdf
# [WARN] No text extracted from: 0040 Mostasmereen 30.6.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0041 PKG-062 30.6.18.pdf
# [WARN] No text extracted from: 0041 PKG-062 30.6.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0045 Kayan 30.6.18.pdf
# [WARN] No text extracted from: 0045 Kayan 30.6.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0047 Benisueif Cement 30.6.18.pdf
# [WARN] No text extracted from: 0047 Benisueif Cement 30.6.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0051 Amadid Substataion 30.6.18.pdf
# [WARN] No text extracted from: 0051 Amadid Substataion 30.6.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0052 French Fund Substations ( Ismailia ) 30.6.18.pdf
# [WARN] No text extracted from: 0052 French Fund Substations ( Ismailia ) 30.6.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0058 PKG 107 Marassi Tank 30.6.18.pdf
# [WARN] No text extracted from: 0058 PKG 107 Marassi Tank 30.6.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0059 New Capital Tunnel 30.6.18.pdf
# [WARN] No text extracted from: 0059 New Capital Tunnel 30.6.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0060 Ministries Complex 30.6.18.pdf
# [WARN] No text extracted from: 0060 Ministries Complex 30.6.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0061 French Fund Substations (Bani-Swif) 30.6.18.pdf
# [WARN] No text extracted from: 0061 French Fund Substations (Bani-Swif) 30.6.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0063 Royal City Mall 30.6.18.pdf
# [WARN] No text extracted from: 0063 Royal City Mall 30.6.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0065 Sewedy Stores 30.6.18.pdf
# [WARN] No text extracted from: 0065 Sewedy Stores 30.6.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0068 Kayan Wall L&L 30.6.18.pdf
# [WARN] No text extracted from: 0068 Kayan Wall L&L 30.6.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0069 Suez Steel Factory 30.6.18.pdf
# [WARN] No text extracted from: 0069 Suez Steel Factory 30.6.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0071 PKG 117 30.6.18.pdf
# [WARN] No text extracted from: 0071 PKG 117 30.6.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0072 Siemens Power Station 30.6.18.pdf
# [WARN] No text extracted from: 0072 Siemens Power Station 30.6.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0074 Tunnel of Sokhna Road 30.6.18.pdf
# [WARN] No text extracted from: 0074 Tunnel of Sokhna Road 30.6.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0075 Abu Sultan Road Extension 30.6.18.pdf
# [WARN] No text extracted from: 0075 Abu Sultan Road Extension 30.6.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0076 Mintra New Factory 30.6.18.pdf
# [WARN] No text extracted from: 0076 Mintra New Factory 30.6.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0078 Mohamed Ali Palace Restoration 30.6.18.pdf
# [WARN] No text extracted from: 0078 Mohamed Ali Palace Restoration 30.6.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0079 New bridge Ismailiya Nefisha 30.6.18.pdf
# [WARN] No text extracted from: 0079 New bridge Ismailiya Nefisha 30.6.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0080 Fish Market 30.6.18.pdf
# [WARN] No text extracted from: 0080 Fish Market 30.6.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0081 AL-JAZI EGYPT 30.6.18.pdf
# [WARN] No text extracted from: 0081 AL-JAZI EGYPT 30.6.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0083 TSK Solar Benban 30.6.18.pdf
# [WARN] No text extracted from: 0083 TSK Solar Benban 30.6.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0084 Alamein 30.6.18.pdf
# [WARN] No text extracted from: 0084 Alamein 30.6.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: Beni Suef CCPP.pdf
# [WARN] No text extracted from: Beni Suef CCPP.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: Maxim Mall 30.6.18.pdf
# [WARN] No text extracted from: Maxim Mall 30.6.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: NGU.pdf
# [WARN] No text extracted from: NGU.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 32 .SWD El Sweedy University Budget Rev 02 @5-8-2018.xlsx
# [WARN] No text extracted from: 32 .SWD El Sweedy University Budget Rev 02 @5-8-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 33.SWD Abu Sultan Bridge 2 Budget Rev 02 @2-8-2018.xlsx
# [WARN] No text extracted from: 33.SWD Abu Sultan Bridge 2 Budget Rev 02 @2-8-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 34.SWD El Sokhna Tunnel 2 Budget Rev 01@2.8.2018.xlsx
# [WARN] No text extracted from: 34.SWD El Sokhna Tunnel 2 Budget Rev 01@2.8.2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD Abu Sultan Bridge 2 Budget Rev 02 @2-8-2018.pdf
# [WARN] No text extracted from: SWD Abu Sultan Bridge 2 Budget Rev 02 @2-8-2018.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: SWD El Sokhna Tunnel 2 Budget Rev 01@2.8.2018.pdf
# [WARN] No text extracted from: SWD El Sokhna Tunnel 2 Budget Rev 01@2.8.2018.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: SWD El Sweedy University Budget Rev 02 @5-8-2018.pdf
# [WARN] No text extracted from: SWD El Sweedy University Budget Rev 02 @5-8-2018.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: Sep 2018 SWD Budget - PDF.rar
# [WARN] Skipped unsupported file type: Sep 2018 SWD Budget - PDF.rar
# [INFO] Processing file: SWD Abu Sultan Bridge Budget Rev 04c.xlsx
# [WARN] No text extracted from: SWD Abu Sultan Bridge Budget Rev 04c.xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD Benban Budget Rev 01 @11-10-2018 (2).xlsx
# [WARN] No text extracted from: SWD Benban Budget Rev 01 @11-10-2018 (2).xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD Benisuif Cement Plant Budget Rev 00 @1-10-2018 (3).xlsx
# [WARN] No text extracted from: SWD Benisuif Cement Plant Budget Rev 00 @1-10-2018 (3).xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD El Sokhna Tunnel Budget Rev 07 (2)30.9.18.xlsx
# [WARN] No text extracted from: SWD El Sokhna Tunnel Budget Rev 07 (2)30.9.18.xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD El Sweedy University Budget Rev 02 @30-9-2018 (2).xlsx
# [WARN] No text extracted from: SWD El Sweedy University Budget Rev 02 @30-9-2018 (2).xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD Fish Market Budget Rev 05@30.9.18.xlsx
# [WARN] No text extracted from: SWD Fish Market Budget Rev 05@30.9.18.xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD Hyper El Temsah Budget Rev 02@30.9.18.xlsx
# [WARN] No text extracted from: SWD Hyper El Temsah Budget Rev 02@30.9.18.xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD Maxium Budget Rev 00 @1 10 2018.xlsx
# [WARN] No text extracted from: SWD Maxium Budget Rev 00 @1 10 2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD New Capital Tunnel Budget Rev 00 @30-9-2018 (2).xlsx
# [WARN] No text extracted from: SWD New Capital Tunnel Budget Rev 00 @30-9-2018 (2).xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD PKG 53 Budget Rev 00 @1-10-2018.xlsx
# [WARN] No text extracted from: SWD PKG 53 Budget Rev 00 @1-10-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD PKG62 Budget Rev 00 @1-10-2018.xlsx
# [WARN] No text extracted from: SWD PKG62 Budget Rev 00 @1-10-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD R05-0082 Budget Rev 01.xlsx
# [WARN] No text extracted from: SWD R05-0082 Budget Rev 01.xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD R05-0087 Budget Rev 01.xlsx
# [WARN] No text extracted from: SWD R05-0087 Budget Rev 01.xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD R05-0088 Budget Rev 01.xlsx
# [WARN] No text extracted from: SWD R05-0088 Budget Rev 01.xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD Rolling Mill Budget Rev 00 2-10-2018.xlsx
# [WARN] No text extracted from: SWD Rolling Mill Budget Rev 00 2-10-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD SLP Budget Rev 02 (Final 12.09.18).xlsx
# [WARN] No text extracted from: SWD SLP Budget Rev 02 (Final 12.09.18).xlsx (no text extracted (Excel))
# [INFO] Processing file: 0032 Sodic 30.9.18.pdf
# [WARN] No text extracted from: 0032 Sodic 30.9.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0034 PKG 53 30.9.18.pdf
# [WARN] No text extracted from: 0034 PKG 53 30.9.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0041 PKG 62 30.9.18.pdf
# [WARN] No text extracted from: 0041 PKG 62 30.9.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0047 BSF Cement 30.9.18.pdf
# [WARN] No text extracted from: 0047 BSF Cement 30.9.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0059 New Capital Tunnel 30.9.18.pdf
# [WARN] No text extracted from: 0059 New Capital Tunnel 30.9.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0065 SLP 12.9.18.pdf
# [WARN] No text extracted from: 0065 SLP 12.9.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0069 Rolling Mill 30.9.18.pdf
# [WARN] No text extracted from: 0069 Rolling Mill 30.9.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0070 Hayper Eltemsah 30.9.18.pdf
# [WARN] No text extracted from: 0070 Hayper Eltemsah 30.9.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0074 Tunnel of Sokhna 30.9.18.pdf
# [WARN] No text extracted from: 0074 Tunnel of Sokhna 30.9.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0075 Abu Sultan Road Extension 30.09.18.pdf
# [WARN] No text extracted from: 0075 Abu Sultan Road Extension 30.09.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0080 Fish Market 30.9.18.pdf
# [WARN] No text extracted from: 0080 Fish Market 30.9.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0082 R05 Z01 15.9.18.pdf
# [WARN] No text extracted from: 0082 R05 Z01 15.9.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0083 TSK Solar Benban 30.09.18.pdf
# [WARN] No text extracted from: 0083 TSK Solar Benban 30.09.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0085 ELsewedy Univ 30.9.18.pdf
# [WARN] No text extracted from: 0085 ELsewedy Univ 30.9.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0087 R05 Z03 15.9.18.pdf
# [WARN] No text extracted from: 0087 R05 Z03 15.9.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0088 R05 Z02 15.9.18.pdf
# [WARN] No text extracted from: 0088 R05 Z02 15.9.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 07.SWD 30-June Tunnel l&lBudget Rev 00 @30- Dec -2018.xlsx
# [WARN] No text extracted from: 07.SWD 30-June Tunnel l&lBudget Rev 00 @30- Dec -2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 07.SWD Al-Awsaty Budget Rev 00 @30-12-2018.xlsx
# [WARN] No text extracted from: 07.SWD Al-Awsaty Budget Rev 00 @30-12-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: Copy of SWD Mevida Budget Rev 02 @12-2-2018 (3).xlsx
# [WARN] No text extracted from: Copy of SWD Mevida Budget Rev 02 @12-2-2018 (3).xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD @31.12.18.rar
# [WARN] Skipped unsupported file type: SWD @31.12.18.rar
# [INFO] Processing file: 16.SWD Ministries Buildings Budget Rev 00 @5-7-2018.xlsx
# [WARN] No text extracted from: 16.SWD Ministries Buildings Budget Rev 00 @5-7-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 21#107 Budget Rev 00 @26-6-2018.xlsx
# [WARN] No text extracted from: 21#107 Budget Rev 00 @26-6-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 31. SWD KAYAN 110 Budget Rev 01 @4-7-2018.xlsx
# [WARN] No text extracted from: 31. SWD KAYAN 110 Budget Rev 01 @4-7-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 33.SWD Abu Sultan Bridge 2 Budget Rev 02 @2-8-2018.xlsx
# [WARN] No text extracted from: 33.SWD Abu Sultan Bridge 2 Budget Rev 02 @2-8-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD Banisuief Power Plant Budget Rev 00 @28-6-2018.xlsx
# [WARN] No text extracted from: SWD Banisuief Power Plant Budget Rev 00 @28-6-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD Benisuif Cement Plant Budget Rev 00 @1-10-2018 (3).xlsx
# [WARN] No text extracted from: SWD Benisuif Cement Plant Budget Rev 00 @1-10-2018 (3).xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD Green Houses Tunnel Budget Rev 00 @31.12.2018.xlsx
# [WARN] No text extracted from: SWD Green Houses Tunnel Budget Rev 00 @31.12.2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD New Giza University phase 1B Budget Rev 00 @5-7-2018.xlsx
# [WARN] No text extracted from: SWD New Giza University phase 1B Budget Rev 00 @5-7-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD PKG 53 Budget Rev 00 @1-10-2018.xlsx
# [WARN] No text extracted from: SWD PKG 53 Budget Rev 00 @1-10-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD PKG62 Budget Rev 00 @1-10-2018.xlsx
# [WARN] No text extracted from: SWD PKG62 Budget Rev 00 @1-10-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD R05-0082 Budget Rev 00@31.12.18.xlsx
# [WARN] No text extracted from: SWD R05-0082 Budget Rev 00@31.12.18.xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD R05-0087 Budget Rev 00@31.12.18.xlsx
# [WARN] No text extracted from: SWD R05-0087 Budget Rev 00@31.12.18.xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD R05-0088 Budget Rev 00@31.12.18.xlsx
# [WARN] No text extracted from: SWD R05-0088 Budget Rev 00@31.12.18.xlsx (no text extracted (Excel))
# [INFO] Processing file: 0000.pdf
# [WARN] No text extracted from: 0000.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0019. SWD Ismailia Bridges Budget Rev 00 @30.12.2018.pdf
# [WARN] No text extracted from: 0019. SWD Ismailia Bridges Budget Rev 00 @30.12.2018.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0032. SWD Sodic Allegria Budget Rev 00 @31-12-2018.pdf
# [WARN] No text extracted from: 0032. SWD Sodic Allegria Budget Rev 00 @31-12-2018.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0034. SWD PKG 53 Budget Rev 00 @30-12-2018.pdf
# [WARN] No text extracted from: 0034. SWD PKG 53 Budget Rev 00 @30-12-2018.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0045 SWD KAYAN 110 Budget Rev 00 @30-12-2018.pdf
# [WARN] No text extracted from: 0045 SWD KAYAN 110 Budget Rev 00 @30-12-2018.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0051. SWD Tamay Amaded Substation Budget Rev 00 @31-12-2018.pdf
# [WARN] No text extracted from: 0051. SWD Tamay Amaded Substation Budget Rev 00 @31-12-2018.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0052. SWD Ismailia Substation Budget Rev 00 @31-12-2018.pdf
# [WARN] No text extracted from: 0052. SWD Ismailia Substation Budget Rev 00 @31-12-2018.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0059. SWD New Capital Tunnel Budget Rev 01 @30.12.2018.pdf
# [WARN] No text extracted from: 0059. SWD New Capital Tunnel Budget Rev 01 @30.12.2018.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0060. SWD Ministries Buildings Budget Rev 00 @31-12-2018.pdf
# [WARN] No text extracted from: 0060. SWD Ministries Buildings Budget Rev 00 @31-12-2018.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0061. SWD Benisuief Substation Budget Rev 00 @31-12-2018.pdf
# [WARN] No text extracted from: 0061. SWD Benisuief Substation Budget Rev 00 @31-12-2018.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0063. SWD ROYAL CITY MALL Budget Rev 00 @31-12-2018.pdf
# [WARN] No text extracted from: 0063. SWD ROYAL CITY MALL Budget Rev 00 @31-12-2018.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0065. SWD SLP Budget Rev 00 @19.12.2018.pdf
# [WARN] No text extracted from: 0065. SWD SLP Budget Rev 00 @19.12.2018.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0066. SWD Mostakbal llBudget Rev 00 @30-12-2018.pdf
# [WARN] No text extracted from: 0066. SWD Mostakbal llBudget Rev 00 @30-12-2018.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0069. SWD ERP ELCO Steel ( Rolling Mill - Admin - MEP )30-12-2018.pdf
# [WARN] No text extracted from: 0069. SWD ERP ELCO Steel ( Rolling Mill - Admin - MEP )30-12-2018.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0070. SWD Hyper El Temsah Budget Rev 00 @31.12.2018.pdf
# [WARN] No text extracted from: 0070. SWD Hyper El Temsah Budget Rev 00 @31.12.2018.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0071. SWD PKG117 Budget Rev 00 @30-12-2018.pdf
# [WARN] No text extracted from: 0071. SWD PKG117 Budget Rev 00 @30-12-2018.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0072. SWD Seimens Budget Rev 00 @31-12-2018.pdf
# [WARN] No text extracted from: 0072. SWD Seimens Budget Rev 00 @31-12-2018.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0074. SWD El Sokhna Tunnel Budget Rev 00 @30.12.2018.pdf
# [WARN] No text extracted from: 0074. SWD El Sokhna Tunnel Budget Rev 00 @30.12.2018.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0075. SWD Abu Sultan Bridge Budget Rev 00 @30.12.2018.pdf
# [WARN] No text extracted from: 0075. SWD Abu Sultan Bridge Budget Rev 00 @30.12.2018.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0076. SWD Mintra project Budget Rev 00 @ 31.12.2018.pdf
# [WARN] No text extracted from: 0076. SWD Mintra project Budget Rev 00 @ 31.12.2018.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0078. SWD Mohamed Ali Budget Rev 00 @31.12.2018.pdf
# [WARN] No text extracted from: 0078. SWD Mohamed Ali Budget Rev 00 @31.12.2018.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0079.  SWD Nefisha Bridge Budget Rev 00 @31.12.2018.pdf
# [WARN] No text extracted from: 0079.  SWD Nefisha Bridge Budget Rev 00 @31.12.2018.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0080. SWD Fish Market Budget Rev 00 @31.12.2018.pdf
# [WARN] No text extracted from: 0080. SWD Fish Market Budget Rev 00 @31.12.2018.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0081.SWD JAZI Budget Rev 00 @31-12-2018.pdf
# [WARN] No text extracted from: 0081.SWD JAZI Budget Rev 00 @31-12-2018.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0082. SWD R05-Budget Rev 01@31.12.18.pdf
# [WARN] No text extracted from: 0082. SWD R05-Budget Rev 01@31.12.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0083. SWD Benban Budget Rev 00 @31.12.2018.pdf
# [WARN] No text extracted from: 0083. SWD Benban Budget Rev 00 @31.12.2018.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0085. SWD El Sweedy University Budget Rev 00 @30-12-2018.pdf
# [WARN] No text extracted from: 0085. SWD El Sweedy University Budget Rev 00 @30-12-2018.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0087. SWD R05-Budget Rev 01@31.12.18.pdf
# [WARN] No text extracted from: 0087. SWD R05-Budget Rev 01@31.12.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0088. SWD R05-Budget Rev 01@31.12.18.pdf
# [WARN] No text extracted from: 0088. SWD R05-Budget Rev 01@31.12.18.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0089. SWD Abu Sultan Bridge 2 Budget Rev 00 @30.12.2018.pdf
# [WARN] No text extracted from: 0089. SWD Abu Sultan Bridge 2 Budget Rev 00 @30.12.2018.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0090. SWD El Sokhna Tunnel 2 Budget Rev 00 @30.12.2018.pdf
# [WARN] No text extracted from: 0090. SWD El Sokhna Tunnel 2 Budget Rev 00 @30.12.2018.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0091.SWD Middle Tunnel Lock Load Budget Rev 00 @30-12-2018.pdf
# [WARN] No text extracted from: 0091.SWD Middle Tunnel Lock Load Budget Rev 00 @30-12-2018.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0092. SWD EDNC Offices and Retail project  Budget Rev 00 @30-12-2018.pdf
# [WARN] No text extracted from: 0092. SWD EDNC Offices and Retail project  Budget Rev 00 @30-12-2018.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0093. SWD MPORIUM  structure parking project  Budget Rev 00 @30-12-2018.pdf
# [WARN] No text extracted from: 0093. SWD MPORIUM  structure parking project  Budget Rev 00 @30-12-2018.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0094. SWD Port of Sokhna container terminal  project  Budget Rev 00 @30-12-2018 - Copy.pdf
# [WARN] No text extracted from: 0094. SWD Port of Sokhna container terminal  project  Budget Rev 00 @30-12-2018 - Copy.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0095. SWD PK 101 project  Budget Rev 00 @30-12-2018.pdf
# [WARN] No text extracted from: 0095. SWD PK 101 project  Budget Rev 00 @30-12-2018.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0096. Substation Elco Steel Rev00 @31.12.2018.pdf
# [WARN] No text extracted from: 0096. Substation Elco Steel Rev00 @31.12.2018.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 30 June Tunnel L&L.pdf
# [WARN] No text extracted from: 30 June Tunnel L&L.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: DP Algeria.pdf
# [WARN] No text extracted from: DP Algeria.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0019. SWD Ismailia Bridges Budget Rev 00 @30.12.2018.xlsx
# [WARN] No text extracted from: 0019. SWD Ismailia Bridges Budget Rev 00 @30.12.2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 0032. SWD Sodic Allegria Budget Rev 00 @31-12-2018.xlsx
# [WARN] No text extracted from: 0032. SWD Sodic Allegria Budget Rev 00 @31-12-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 0034. SWD PKG 53 Budget Rev 00 @30-12-2018.xlsx
# [WARN] No text extracted from: 0034. SWD PKG 53 Budget Rev 00 @30-12-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 0045 SWD KAYAN 110 Budget Rev 00 @30-12-2018.xlsx
# [WARN] No text extracted from: 0045 SWD KAYAN 110 Budget Rev 00 @30-12-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 0051. SWD Tamay Amaded Substation Budget Rev 00 @31-12-2018.xlsx
# [WARN] No text extracted from: 0051. SWD Tamay Amaded Substation Budget Rev 00 @31-12-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 0052. SWD Ismailia Substation Budget Rev 00 @31-12-2018.xlsx
# [WARN] No text extracted from: 0052. SWD Ismailia Substation Budget Rev 00 @31-12-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 0059. SWD New Capital Tunnel Budget Rev 01 @30.12.2018.xlsx
# [WARN] No text extracted from: 0059. SWD New Capital Tunnel Budget Rev 01 @30.12.2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 0060. SWD Ministries Buildings Budget Rev 00 @31-12-2018.xlsx
# [WARN] No text extracted from: 0060. SWD Ministries Buildings Budget Rev 00 @31-12-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 0061. SWD Benisuief Substation Budget Rev 00 @31-12-2018.xlsx
# [WARN] No text extracted from: 0061. SWD Benisuief Substation Budget Rev 00 @31-12-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 0063. SWD ROYAL CITY MALL Budget Rev 00 @31-12-2018.xlsx
# [WARN] No text extracted from: 0063. SWD ROYAL CITY MALL Budget Rev 00 @31-12-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 0065. SWD SLP Budget Rev 00 @19.12.2018.xlsx
# [WARN] No text extracted from: 0065. SWD SLP Budget Rev 00 @19.12.2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 0066. SWD Mostakbal llBudget Rev 00 @30-12-2018.xlsx
# [WARN] No text extracted from: 0066. SWD Mostakbal llBudget Rev 00 @30-12-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 0069. SWD ERP ELCO Steel ( Rolling Mill - Admin - MEP )30-12-2018.xlsx
# [WARN] No text extracted from: 0069. SWD ERP ELCO Steel ( Rolling Mill - Admin - MEP )30-12-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 0070. SWD Hyper El Temsah Budget Rev 00 @31.12.2018.xlsx
# [WARN] No text extracted from: 0070. SWD Hyper El Temsah Budget Rev 00 @31.12.2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 0071. SWD PKG117 Budget Rev 00 @30-12-2018.xlsx
# [WARN] No text extracted from: 0071. SWD PKG117 Budget Rev 00 @30-12-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 0072. SWD Seimens Budget Rev 00 @31-12-2018.xlsx
# [WARN] No text extracted from: 0072. SWD Seimens Budget Rev 00 @31-12-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 0074. SWD El Sokhna Tunnel Budget Rev 00 @30.12.2018.xlsx
# [WARN] No text extracted from: 0074. SWD El Sokhna Tunnel Budget Rev 00 @30.12.2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 0075. SWD Abu Sultan Bridge Budget Rev 00 @30.12.2018.xlsx
# [WARN] No text extracted from: 0075. SWD Abu Sultan Bridge Budget Rev 00 @30.12.2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 0076. SWD Mintra project Budget Rev 00 @ 31.12.2018.xlsx
# [WARN] No text extracted from: 0076. SWD Mintra project Budget Rev 00 @ 31.12.2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 0078. SWD Mohamed Ali Budget Rev 00 @31.12.2018.xlsx
# [WARN] No text extracted from: 0078. SWD Mohamed Ali Budget Rev 00 @31.12.2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 0079.  SWD Nefisha Bridge Budget Rev 00 @31.12.2018.xlsx
# [WARN] No text extracted from: 0079.  SWD Nefisha Bridge Budget Rev 00 @31.12.2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 0080. SWD Fish Market Budget Rev 00 @31.12.2018.xlsx
# [WARN] No text extracted from: 0080. SWD Fish Market Budget Rev 00 @31.12.2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 0081.SWD JAZI Budget Rev 00 @31-12-2018.xlsx
# [WARN] No text extracted from: 0081.SWD JAZI Budget Rev 00 @31-12-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 0082. SWD R05-Budget Rev 01@31.12.18.xlsx
# [WARN] No text extracted from: 0082. SWD R05-Budget Rev 01@31.12.18.xlsx (no text extracted (Excel))
# [INFO] Processing file: 0083. SWD Benban Budget Rev 00 @31.12.2018.xlsx
# [WARN] No text extracted from: 0083. SWD Benban Budget Rev 00 @31.12.2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 0085. SWD El Sweedy University Budget Rev 00 @30-12-2018.xlsx
# [WARN] No text extracted from: 0085. SWD El Sweedy University Budget Rev 00 @30-12-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 0087. SWD R05-Budget Rev 01@31.12.18.xlsx
# [WARN] No text extracted from: 0087. SWD R05-Budget Rev 01@31.12.18.xlsx (no text extracted (Excel))
# [INFO] Processing file: 0088. SWD R05-Budget Rev 01@31.12.18.xlsx
# [WARN] No text extracted from: 0088. SWD R05-Budget Rev 01@31.12.18.xlsx (no text extracted (Excel))
# [INFO] Processing file: 0089. SWD Abu Sultan Bridge 2 Budget Rev 00 @30.12.2018.xlsx
# [WARN] No text extracted from: 0089. SWD Abu Sultan Bridge 2 Budget Rev 00 @30.12.2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 0090. SWD El Sokhna Tunnel 2 Budget Rev 00 @30.12.2018.xlsx
# [WARN] No text extracted from: 0090. SWD El Sokhna Tunnel 2 Budget Rev 00 @30.12.2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 0091.SWD Middle Tunnel Lock Load Budget Rev 00 @30-12-2018.xlsx
# [WARN] No text extracted from: 0091.SWD Middle Tunnel Lock Load Budget Rev 00 @30-12-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 0092. SWD EDNC Offices and Retail project  Budget Rev 00 @30-12-2018.xlsx
# [WARN] No text extracted from: 0092. SWD EDNC Offices and Retail project  Budget Rev 00 @30-12-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 0093. SWD MPORIUM  structure parking project  Budget Rev 00 @30-12-2018.xlsx
# [WARN] No text extracted from: 0093. SWD MPORIUM  structure parking project  Budget Rev 00 @30-12-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 0094. SWD Port of Sokhna container terminal  project  Budget Rev 00 @30-12-2018 - Copy.xlsx
# [WARN] No text extracted from: 0094. SWD Port of Sokhna container terminal  project  Budget Rev 00 @30-12-2018 - Copy.xlsx (no text extracted (Excel))
# [INFO] Processing file: 0095. SWD PK 101 project  Budget Rev 00 @30-12-2018.xlsx
# [WARN] No text extracted from: 0095. SWD PK 101 project  Budget Rev 00 @30-12-2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 0096. Substation Elco Steel Rev00 @31.12.2018.xlsx
# [WARN] No text extracted from: 0096. Substation Elco Steel Rev00 @31.12.2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: 07.SWD 30-June Tunnel l&lBudget Rev 00 @30- Dec -2018.xlsx
# [WARN] No text extracted from: 07.SWD 30-June Tunnel l&lBudget Rev 00 @30- Dec -2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: SWD Algeria Budget Rev 01 @12 2 2018.xlsx
# [WARN] No text extracted from: SWD Algeria Budget Rev 01 @12 2 2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: Final Excel POC  Dec-2019.rar
# [WARN] Skipped unsupported file type: Final Excel POC  Dec-2019.rar
# [INFO] Processing file: POC Dec.2019 log.xls
# [WARN] No text extracted from: POC Dec.2019 log.xls (no text extracted (Excel))
# [INFO] Processing file: POC Mar-19 - Excel.rar
# [WARN] Skipped unsupported file type: POC Mar-19 - Excel.rar
# [INFO] Processing file: POC Mar.2019 log.xls
# [WARN] No text extracted from: POC Mar.2019 log.xls (no text extracted (Excel))
# [INFO] Processing file: Received POC 31.03.2019.pdf
# [WARN] No text extracted from: Received POC 31.03.2019.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 0032. SWD Sodic Allegria Budget Rev 00 @30-3-2019.xlsx
# ...
# [INFO] Processing file: July-21.xls.xlsb
# [WARN] Skipped unsupported file type: July-21.xls.xlsb
# [INFO] Processing file: all projects.pdf
# [INFO] Processing file: Indirect Log.xlsx
# [WARN] No text extracted from: Indirect Log.xlsx (no text extracted (Excel))
# [INFO] Processing file: Accommodation Budget 2022.xlsx
# [WARN] No text extracted from: Accommodation Budget 2022.xlsx (no text extracted (Excel))
# [INFO] Processing file: 6 June Cost 2022.xlsx
# [WARN] No text extracted from: 6 June Cost 2022.xlsx (no text extracted (Excel))
# [INFO] Processing file: Dash Board (Jul, 20 -Feb,22).xlsx
# [WARN] No text extracted from: Dash Board (Jul, 20 -Feb,22).xlsx (no text extracted (Excel))
# [INFO] Processing file: Total Internal Invoice (Feb-22).PDF
# [WARN] No text extracted from: Total Internal Invoice (Feb-22).PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: Line Dist 6-22.xlsb
# [WARN] Skipped unsupported file type: Line Dist 6-22.xlsb
# [INFO] Processing file: Monthly Billing June 2022Elmarakby.xlsx
# [WARN] No text extracted from: Monthly Billing June 2022Elmarakby.xlsx (no text extracted (Excel))
# [INFO] Processing file: 07 Planning Report July 22.xlsx
# [WARN] No text extracted from: 07 Planning Report July 22.xlsx (no text extracted (Excel))
# [INFO] Processing file: KSA-TAH-Internal VO BD.xlsx
# [WARN] No text extracted from: KSA-TAH-Internal VO BD.xlsx (no text extracted (Excel))
# [INFO] Processing file: Material movement new.xlsb
# [WARN] Skipped unsupported file type: Material movement new.xlsb
# [INFO] Processing file: C&R Oct.2023 Revenue-cash(in&out) - Rev.(01) final.xlsx
# [WARN] No text extracted from: C&R Oct.2023 Revenue-cash(in&out) - Rev.(01) final.xlsx (no text extracted (Excel))
# [INFO] Processing file: Cash Found mos Phase 2.xlsx
# [WARN] No text extracted from: Cash Found mos Phase 2.xlsx (no text extracted (Excel))
# [INFO] Processing file: Summary PT-cash.xlsx
# [WARN] No text extracted from: Summary PT-cash.xlsx (no text extracted (Excel))
# [INFO] Processing file: RBG - Manpower Productivity Report - 07122024.xlsx
# [WARN] No text extracted from: RBG - Manpower Productivity Report - 07122024.xlsx (no text extracted (Excel))
# [INFO] Processing file: RBG - Manpower Productivity Report - Carpentery.pdf
# [INFO] Processing file: RBG - Manpower Productivity Report - Casting.pdf
# [INFO] Processing file: RBG - Manpower Productivity Report - Steel Fixers.pdf
# [INFO] Processing file: RBG - Manpower Productivity Report - Total.pdf
# [INFO] Processing file: RBG - Manpower Productivity Report.pdf
# [INFO] Processing file: Manpower Productivity Report.html
# [WARN] Skipped unsupported file type: Manpower Productivity Report.html
# [INFO] Processing file: Manpower Productivity Report.mp4
# [WARN] Skipped unsupported file type: Manpower Productivity Report.mp4
# [INFO] Processing file: Manpower Productivity Report_config.xml
# [WARN] Skipped unsupported file type: Manpower Productivity Report_config.xml
# [INFO] Processing file: Manpower Productivity Report_embed.css
# [WARN] Skipped unsupported file type: Manpower Productivity Report_embed.css
# [INFO] Processing file: Manpower Productivity Report_player.html
# [WARN] Skipped unsupported file type: Manpower Productivity Report_player.html
# [INFO] Processing file: Manpower_Productivity_Report_First_Frame.png
# [WARN] Skipped unsupported file type: Manpower_Productivity_Report_First_Frame.png
# [INFO] Processing file: Untitled Project.tscproj
# [WARN] Skipped unsupported file type: Untitled Project.tscproj
# [INFO] Processing file: config_xml.js
# [WARN] Skipped unsupported file type: config_xml.js
# [INFO] Processing file: techsmith-smart-player.min.js
# [WARN] Skipped unsupported file type: techsmith-smart-player.min.js
# [INFO] Processing file: techsmith-smart-player.min.css
# [WARN] Skipped unsupported file type: techsmith-smart-player.min.css
# [INFO] Processing file: F-P-PC-01-01 Baseline Submission Checklist.xlsx
# [WARN] No text extracted from: F-P-PC-01-01 Baseline Submission Checklist.xlsx (no text extracted (Excel))
# [INFO] Processing file: Schedule Manual-Recording.mp4
# [WARN] Skipped unsupported file type: Schedule Manual-Recording.mp4
# [INFO] Processing file: 1.xlsx
# [WARN] No text extracted from: 1.xlsx (no text extracted (Excel))
# [INFO] Processing file: Part 1 Target 2024.rar
# [WARN] Skipped unsupported file type: Part 1 Target 2024.rar
# [INFO] Processing file: Part 2 Target 2024.rar
# [WARN] Skipped unsupported file type: Part 2 Target 2024.rar
# [INFO] Processing file: Total.xlsx
# [WARN] No text extracted from: Total.xlsx (no text extracted (Excel))
# [INFO] Processing file: Industrial Sector Invoicing Revenue Target Plan-2024.xlsb
# [WARN] Skipped unsupported file type: Industrial Sector Invoicing Revenue Target Plan-2024.xlsb
# [INFO] Processing file: Industrial Sector Target Milestones Deliverables-2024.xlsx
# [WARN] No text extracted from: Industrial Sector Target Milestones Deliverables-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: C&R Sector Invoicing Revenue Target Plan-2024.xlsx
# [WARN] No text extracted from: C&R Sector Invoicing Revenue Target Plan-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: C&R Sector Target Milestones Deliverables-2024.xlsx
# [WARN] No text extracted from: C&R Sector Target Milestones Deliverables-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: Army Sector Invoicing Revenue Target Plan-2024.xlsx
# [WARN] No text extracted from: Army Sector Invoicing Revenue Target Plan-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: Army Sector Target Milestones Deliverables-  2024.xlsx
# [WARN] No text extracted from: Army Sector Target Milestones Deliverables-  2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: Bridges Sector Invoicing Revenue Target Plan-2024.xlsb
# [WARN] Skipped unsupported file type: Bridges Sector Invoicing Revenue Target Plan-2024.xlsb
# [INFO] Processing file: Bridges Sector Target Milestones Deliverables-2024.xlsx
# [WARN] No text extracted from: Bridges Sector Target Milestones Deliverables-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: Governmental Sector Invoicing Revenue Target Plan -2024.xlsb
# [WARN] Skipped unsupported file type: Governmental Sector Invoicing Revenue Target Plan -2024.xlsb
# [INFO] Processing file: Governmental Sector Target Milestones Deliverables-2024 .xlsx
# [WARN] No text extracted from: Governmental Sector Target Milestones Deliverables-2024 .xlsx (no text extracted (Excel))
# [INFO] Processing file: Infra Invoicing Invoicing Revenue Target Plan - 2024.xlsx
# [WARN] No text extracted from: Infra Invoicing Invoicing Revenue Target Plan - 2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: Infra Sector Target Milestones Deliverables - 2024.xlsx
# [WARN] No text extracted from: Infra Sector Target Milestones Deliverables - 2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: Radamis Invoicing Revenue Target Plan- 2024.xlsb
# [WARN] Skipped unsupported file type: Radamis Invoicing Revenue Target Plan- 2024.xlsb
# [INFO] Processing file: Radamis Target Milestones Deliverables - 2024.xlsx
# [WARN] No text extracted from: Radamis Target Milestones Deliverables - 2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: Jawhara Invoicing Revenue Target Plan- 2024.xlsb
# [WARN] Skipped unsupported file type: Jawhara Invoicing Revenue Target Plan- 2024.xlsb
# [INFO] Processing file: Jawhara Target Milestones Deliverables -2024.xlsx
# [WARN] No text extracted from: Jawhara Target Milestones Deliverables -2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: Koumassi Invoicing Revenue Target Plan-2024.xlsb
# [WARN] Skipped unsupported file type: Koumassi Invoicing Revenue Target Plan-2024.xlsb
# [INFO] Processing file: Koumassi Target Milestones Deliverables -2024.xlsx
# [WARN] No text extracted from: Koumassi Target Milestones Deliverables -2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: Re-planned 2024 Vs Actual 2024.xlsx
# [WARN] No text extracted from: Re-planned 2024 Vs Actual 2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: Invoicing Revenues Tracking Sheet.xlsx
# [WARN] No text extracted from: Invoicing Revenues Tracking Sheet.xlsx (no text extracted (Excel))
# [INFO] Processing file: POC Revenue  cost Tracking Sheet.xlsx
# [WARN] No text extracted from: POC Revenue  cost Tracking Sheet.xlsx (no text extracted (Excel))
# [INFO] Processing file: 13-11-2024 Tracking 2024 till October.xlsx
# [WARN] No text extracted from: 13-11-2024 Tracking 2024 till October.xlsx (no text extracted (Excel))
# [INFO] Processing file: 15-12-2024 Tracking 2024 till November.xlsx
# [WARN] No text extracted from: 15-12-2024 Tracking 2024 till November.xlsx (no text extracted (Excel))
# [INFO] Processing file: 5-01-2025 Tracking 2024 till December(includes Galawa).xlsx
# [WARN] No text extracted from: 5-01-2025 Tracking 2024 till December(includes Galawa).xlsx (no text extracted (Excel))
# [INFO] Processing file: 5-01-2025 Tracking 2024 till December.xlsx
# [WARN] No text extracted from: 5-01-2025 Tracking 2024 till December.xlsx (no text extracted (Excel))
# [INFO] Processing file: Re-planned 2024 Vs Actual 2024.xlsx
# [WARN] No text extracted from: Re-planned 2024 Vs Actual 2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: POC Revenue-cost Tracking Sheet-Actuals.xlsx
# [WARN] No text extracted from: POC Revenue-cost Tracking Sheet-Actuals.xlsx (no text extracted (Excel))
# [INFO] Processing file: 2024 Plan-.pptx
# [INFO] Processing file: POC Revenue-cost Tracking Sheet-Actuals (National, KSA & JV).xlsx
# [WARN] No text extracted from: POC Revenue-cost Tracking Sheet-Actuals (National, KSA & JV).xlsx (no text extracted (Excel))
# [INFO] Processing file: POC Revenue-cost Tracking Sheet-Actuals (National, KSA).xlsx
# [WARN] No text extracted from: POC Revenue-cost Tracking Sheet-Actuals (National, KSA).xlsx (no text extracted (Excel))
# [INFO] Processing file: PPT POC Revenue-cost Tracking Sheet-Actuals (National, KSA).xlsx
# [WARN] No text extracted from: PPT POC Revenue-cost Tracking Sheet-Actuals (National, KSA).xlsx (no text extracted (Excel))
# [INFO] Processing file: POC Revenue-cost Tracking Sheet-Actuals (National, KSA).xlsx
# [WARN] No text extracted from: POC Revenue-cost Tracking Sheet-Actuals (National, KSA).xlsx (no text extracted (Excel))
# [INFO] Processing file: POC Revenue-cost Tracking Sheet-Actuals (National, KSA).xlsx
# [WARN] No text extracted from: POC Revenue-cost Tracking Sheet-Actuals (National, KSA).xlsx (no text extracted (Excel))
# [INFO] Processing file: 002. Q2 Actuals POC Revenue-cost Tracking Sheet-Actuals (National KSA).xlsx
# [WARN] No text extracted from: 002. Q2 Actuals POC Revenue-cost Tracking Sheet-Actuals (National KSA).xlsx (no text extracted (Excel))
# [INFO] Processing file: 13-8-2024 Copy of 00002. (002)edit.xlsx
# [WARN] No text extracted from: 13-8-2024 Copy of 00002. (002)edit.xlsx (no text extracted (Excel))
# [INFO] Processing file: 16-9-2024 Copy of 00002. (002)edit.xlsx
# [WARN] No text extracted from: 16-9-2024 Copy of 00002. (002)edit.xlsx (no text extracted (Excel))
# [INFO] Processing file: 13-10-2024 Tracking Sheet.xlsx
# [WARN] No text extracted from: 13-10-2024 Tracking Sheet.xlsx (no text extracted (Excel))
# [INFO] Processing file: 20-10-2024 Copy of 00002. (002)edit.xlsx
# [WARN] No text extracted from: 20-10-2024 Copy of 00002. (002)edit.xlsx (no text extracted (Excel))
# [INFO] Processing file: 2025 Tracking (10-Nov-2024) (version 4) 26 B.xlsx
# [WARN] No text extracted from: 2025 Tracking (10-Nov-2024) (version 4) 26 B.xlsx (no text extracted (Excel))
# [INFO] Processing file: 2025 Tracking (10-Nov-2024) Contracts 30 B.xlsx
# [WARN] No text extracted from: 2025 Tracking (10-Nov-2024) Contracts 30 B.xlsx (no text extracted (Excel))
# [INFO] Processing file: 2025 Tracking (19-Nov-2024)-23 B.xlsx
# [WARN] No text extracted from: 2025 Tracking (19-Nov-2024)-23 B.xlsx (no text extracted (Excel))
# [INFO] Processing file: 2025 Tracking Contracts 30 B.xlsx
# [WARN] No text extracted from: 2025 Tracking Contracts 30 B.xlsx (no text extracted (Excel))
# [INFO] Processing file: 17-3-2025 Tracking 2025.xlsx
# [WARN] No text extracted from: 17-3-2025 Tracking 2025.xlsx (no text extracted (Excel))
# [INFO] Processing file: 31-3 Tracking 2025 - (modified Infra Plan).xlsx
# [WARN] No text extracted from: 31-3 Tracking 2025 - (modified Infra Plan).xlsx (no text extracted (Excel))
# [INFO] Processing file: 31-3 Tracking 2025.xlsx
# [WARN] No text extracted from: 31-3 Tracking 2025.xlsx (no text extracted (Excel))
# [INFO] Processing file: 13-10-2024 Tracking Sheet--.xlsx
# [WARN] No text extracted from: 13-10-2024 Tracking Sheet--.xlsx (no text extracted (Excel))
# [INFO] Processing file: 14-10-2024 Comparison by Project.pdf
# [INFO] Processing file: 2024 Actual Jul-2024 Forecast edit 26-8-2024.pptx
# [INFO] Processing file: 26-8-2024 Comparison by Project.pdf
# [INFO] Processing file: 26-8-2024 Copy of 00002. (002)edit.xlsx
# [WARN] No text extracted from: 26-8-2024 Copy of 00002. (002)edit.xlsx (no text extracted (Excel))
# [INFO] Processing file: 2024 Actual Sep-2024 Forecast edit 14-Oct-24.pptx
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: 2024&2025.pptx
# [INFO] Processing file: Feb(2)-2025.pptx
# [INFO] Processing file: Feb-2025.pptx
# [INFO] Processing file: 02-C&R-Target-2025_R6.pptx
# [INFO] Processing file: 03-Industrial-Target-2025_R6.pptx
# [INFO] Processing file: 04-Infra-Target-2025_R5.pptx
# [INFO] Processing file: 05-B&R-Target-2025_R6.pptx
# [INFO] Processing file: 06-Restoration-Target-2025_R6_EGY & KSA.pptx
# [INFO] Processing file: 08-M.Abd-El-Fatah-Target-2025_R6.pptx
# [INFO] Processing file: 07-Fitout-Target-2025_R7.pptx
# [INFO] Processing file: 01- 2025 Revised Review Meeting.pptx
# [INFO] Processing file: 2025 Revised Review Details.pptx
# [INFO] Processing file: 09-KSA -Target-2025_Global R5.pptx
# [INFO] Processing file: Mar-2025.pptx
# [INFO] Processing file: Adel Rahmo EGP  USD.xlsx
# [WARN] No text extracted from: Adel Rahmo EGP  USD.xlsx (no text extracted (Excel))
# [INFO] Processing file: Hussien Bahget.xlsx
# [WARN] No text extracted from: Hussien Bahget.xlsx (no text extracted (Excel))
# [INFO] Processing file: Mariam youssef PL.xlsx
# [WARN] No text extracted from: Mariam youssef PL.xlsx (no text extracted (Excel))
# [INFO] Processing file: Mohamed Abdelfath PL.xlsx
# [WARN] No text extracted from: Mohamed Abdelfath PL.xlsx (no text extracted (Excel))
# [INFO] Processing file: Mohamed Abdelmokdter PL.xlsx
# [WARN] No text extracted from: Mohamed Abdelmokdter PL.xlsx (no text extracted (Excel))
# [INFO] Processing file: Mohamed El Ashry PL.xlsx
# [WARN] No text extracted from: Mohamed El Ashry PL.xlsx (no text extracted (Excel))
# [INFO] Processing file: Mohamed El Saman PL.xlsx
# [WARN] No text extracted from: Mohamed El Saman PL.xlsx (no text extracted (Excel))
# [INFO] Processing file: Adel Rahmo.xlsx
# [WARN] No text extracted from: Adel Rahmo.xlsx (no text extracted (Excel))
# [INFO] Processing file: Aly Tawfik.xlsx
# [WARN] No text extracted from: Aly Tawfik.xlsx (no text extracted (Excel))
# [INFO] Processing file: Hussin Bahgat.xlsx
# [WARN] No text extracted from: Hussin Bahgat.xlsx (no text extracted (Excel))
# [INFO] Processing file: Mariam Youssef.xlsx
# [WARN] No text extracted from: Mariam Youssef.xlsx (no text extracted (Excel))
# [INFO] Processing file: Mohamed Abdelfattah.xlsx
# [WARN] No text extracted from: Mohamed Abdelfattah.xlsx (no text extracted (Excel))
# [INFO] Processing file: Mohamed Abdelmoktader.xlsx
# [WARN] No text extracted from: Mohamed Abdelmoktader.xlsx (no text extracted (Excel))
# [INFO] Processing file: Mohamed El Ashry.xlsx
# [WARN] No text extracted from: Mohamed El Ashry.xlsx (no text extracted (Excel))
# [INFO] Processing file: Mohamed El Seman.xlsx
# [WARN] No text extracted from: Mohamed El Seman.xlsx (no text extracted (Excel))
# Processed 1007 documents. Output saved to C:/Users/Omar Essam2/OneDrive - Rowad Modern Engineering/x004 Data Science/03.rme.db/05.llm/extracted_json\07 RME Global Reports_extracted.json

# %%
import os
import json
import openai
import chromadb
from chromadb.config import Settings
from dotenv import load_dotenv
from tqdm import tqdm

# Load OpenAI API key from .env
load_dotenv()
openai.api_key = os.getenv('OPENAI_API_KEY')

# New paths outside the repo
EXTRACTED_DIR = r'C:/Users/Omar Essam2/OneDrive - Rowad Modern Engineering/x004 Data Science/03.rme.db/05.llm/extracted_json'
CHROMA_DB_DIR = r'C:/Users/Omar Essam2/OneDrive - Rowad Modern Engineering/x004 Data Science/03.rme.db/05.llm/chroma_db'
COLLECTION_NAME = 'company_docs'
CHUNK_SIZE = 1000  # characters per chunk
CHUNK_OVERLAP = 200
ID_TRACK_FILE = os.path.join(CHROMA_DB_DIR, 'embedded_chunk_ids.txt')

# Helper: chunk text
def chunk_text(text, chunk_size=CHUNK_SIZE, overlap=CHUNK_OVERLAP):
    chunks = []
    start = 0
    while start < len(text):
        end = min(start + chunk_size, len(text))
        chunks.append(text[start:end])
        start += chunk_size - overlap
    return chunks

# Helper: get OpenAI embeddings
def get_embedding(text):
    resp = openai.embeddings.create(
        input=[text],
        model="text-embedding-ada-002"
    )
    return resp.data[0].embedding

# Initialize Chroma DB
client = chromadb.PersistentClient(path=CHROMA_DB_DIR, settings=Settings(allow_reset=True))
if COLLECTION_NAME in [c.name for c in client.list_collections()]:
    collection = client.get_collection(COLLECTION_NAME)
else:
    collection = client.create_collection(COLLECTION_NAME)

def load_embedded_ids():
    if not os.path.exists(ID_TRACK_FILE):
        return set()
    with open(ID_TRACK_FILE, 'r', encoding='utf-8') as f:
        return set(line.strip() for line in f if line.strip())

def save_embedded_id(chunk_id):
    with open(ID_TRACK_FILE, 'a', encoding='utf-8') as f:
        f.write(chunk_id + '\n')

def process_json_files():
    files = [f for f in os.listdir(EXTRACTED_DIR) if f.endswith('.json')]
    doc_count = 0
    embedded_ids = load_embedded_ids()
    for file in files:
        with open(os.path.join(EXTRACTED_DIR, file), 'r', encoding='utf-8') as f:
            docs = json.load(f)
        for doc in tqdm(docs, desc=f"Processing {file}"):
            text = doc['text']
            if not text.strip():
                continue
            chunks = chunk_text(text)
            for i, chunk in enumerate(chunks):
                chunk_id = f"{doc['file_name']}_{i}"
                if chunk_id in embedded_ids:
                    continue  # Skip already embedded chunk
                meta = {
                    'file_name': doc['file_name'],
                    'file_path': doc['file_path'],
                    'type': doc['type'],
                    'extracted_at': doc['extracted_at'],
                    'chunk': i
                }
                try:
                    emb = get_embedding(chunk)
                    collection.add(
                        documents=[chunk],
                        embeddings=[emb],
                        metadatas=[meta],
                        ids=[chunk_id]
                    )
                    save_embedded_id(chunk_id)
                    doc_count += 1
                except Exception as e:
                    print(f"Error embedding chunk: {e}")
    print(f"Finished! {doc_count} new chunks embedded and stored in Chroma DB.")

if __name__ == "__main__":
    process_json_files()
# Out:
# Processing 01 Dash Boards_extracted.json: 100%|██████████| 29/29 [00:00<00:00, 56208.33it/s]
# Processing 02 artical_extracted.json: 100%|██████████| 21/21 [00:00<00:00, 24755.59it/s]
# Processing 02 Monthly Progress Presentation_extracted.json: 100%|██████████| 514/514 [00:00<00:00, 123397.19it/s]
# Processing 0207 Qasr Rashwan Lot A_extracted.json: 100%|██████████| 5/5 [00:00<00:00, 25731.93it/s]
# Processing 0208 Qasr Rashwan Lot B_extracted.json: 100%|██████████| 3/3 [00:00<00:00, 12006.60it/s]
# Processing 07 RME Global Reports_extracted.json: 100%|██████████| 1007/1007 [58:26<00:00,  3.48s/it]
# Finished! 6754 new chunks embedded and stored in Chroma DB.
