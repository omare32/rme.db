# %%
import os
import json
import pdfplumber
import pytesseract
from PIL import Image
import pandas as pd
from datetime import datetime
from docx import Document
from pptx import Presentation
import warnings
import re

# Suppress specific CropBox warning from pdfplumber
import logging
logging.getLogger("pdfminer").setLevel(logging.ERROR)

class CropBoxFilter:
    def filter(self, record):
        return not (record.levelno == logging.WARNING and 'CropBox missing from /Page, defaulting to MediaBox' in record.getMessage())

logging.getLogger().addFilter(CropBoxFilter())

# Add tkinter for folder selection
def select_folder():
    import tkinter as tk
    from tkinter import filedialog
    root = tk.Tk()
    root.withdraw()
    folder_selected = filedialog.askdirectory(title='Select folder to process')
    root.destroy()
    return folder_selected

def extract_text_from_pdf(pdf_path):
    text = ""
    try:
        with pdfplumber.open(pdf_path) as pdf:
            for page in pdf.pages:
                page_text = page.extract_text()
                if page_text:
                    text += page_text + "\n"
    except Exception:
        pass
    return text.strip()

def ocr_pdf(pdf_path):
    text = ""
    try:
        with pdfplumber.open(pdf_path) as pdf:
            for page in pdf.pages:
                img = page.to_image(resolution=300).original
                pil_img = Image.fromarray(img)
                page_text = pytesseract.image_to_string(pil_img)
                if page_text:
                    text += page_text + "\n"
    except Exception:
        pass
    return text.strip()

def extract_text_from_excel(excel_path):
    text = ""
    try:
        xls = pd.ExcelFile(excel_path)
        for sheet_name in xls.sheet_names:
            df = pd.read_excel(xls, sheet_name=sheet_name, dtype=str)
            text += f"\n--- Sheet: {sheet_name} ---\n"
            text += df.fillna('').to_string(index=False, header=True)
    except Exception:
        pass
    return text.strip()

def extract_text_from_docx(docx_path):
    text = ""
    try:
        doc = Document(docx_path)
        for para in doc.paragraphs:
            text += para.text + "\n"
    except Exception:
        pass
    return text.strip()

def extract_text_from_pptx(pptx_path):
    text = ""
    try:
        prs = Presentation(pptx_path)
        for slide in prs.slides:
            for shape in slide.shapes:
                if hasattr(shape, "text"):
                    text += shape.text + "\n"
    except Exception:
        pass
    return text.strip()

def process_folder(folder_path, output_json_path):
    data = []
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            print(f"[INFO] Processing file: {file}")
            file_path = os.path.join(root, file)
            ext = file.lower().split('.')[-1]
            entry = {
                'file_name': file,
                'file_path': file_path,
                'type': ext,
                'extracted_at': datetime.now().isoformat(),
                'text': ''
            }
            reason = None
            if ext == 'pdf':
                text = extract_text_from_pdf(file_path)
                if not text:
                    text = ocr_pdf(file_path)
                    if text:
                        reason = 'extracted via OCR'
                    else:
                        reason = 'no text extracted (PDF and OCR failed)'
                else:
                    reason = 'extracted as text PDF'
                entry['text'] = text
            elif ext in ['xls', 'xlsx']:
                text = extract_text_from_excel(file_path)
                entry['text'] = text
                reason = 'extracted from Excel' if text else 'no text extracted (Excel)'
            elif ext == 'docx':
                text = extract_text_from_docx(file_path)
                entry['text'] = text
                reason = 'extracted from Word' if text else 'no text extracted (Word)'
            elif ext == 'pptx':
                text = extract_text_from_pptx(file_path)
                entry['text'] = text
                reason = 'extracted from PowerPoint' if text else 'no text extracted (PowerPoint)'
            else:
                print(f"[WARN] Skipped unsupported file type: {file}")
                continue
            if entry['text']:
                data.append(entry)
            else:
                print(f"[WARN] No text extracted from: {file} ({reason})")
    with open(output_json_path, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=2)
    print(f"Processed {len(data)} documents. Output saved to {output_json_path}")

if __name__ == "__main__":
    # New output directory outside the repo
    output_dir = r'C:/Users/Omar Essam2/OneDrive - Rowad Modern Engineering/x004 Data Science/03.rme.db/05.llm/extracted_json'
    os.makedirs(output_dir, exist_ok=True)
    folder = select_folder()
    if not folder:
        print("No folder selected. Exiting.")
    else:
        folder_name = os.path.basename(os.path.normpath(folder))
        output_json = os.path.join(output_dir, f"{folder_name}_extracted.json")
        process_folder(folder, output_json)
# Out:
# [INFO] Processing file: 0. July Commercial & Residential Sector .xlsx
# [WARN] No text extracted from: 0. July Commercial & Residential Sector .xlsx (no text extracted (Excel))
# [INFO] Processing file: 0. July Commercial & Residential sector.pbix
# [WARN] Skipped unsupported file type: 0. July Commercial & Residential sector.pbix
# [INFO] Processing file: 0. August Army Sector.xlsx
# [WARN] No text extracted from: 0. August Army Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. August Army sector.pbix
# [WARN] Skipped unsupported file type: 1. August Army sector.pbix
# [INFO] Processing file: Bridges Sector All Data (2023.08.30).xlsx
# [WARN] No text extracted from: Bridges Sector All Data (2023.08.30).xlsx (no text extracted (Excel))
# [INFO] Processing file: Bridges Sector Cash Position (2023.08.30).pdf
# [INFO] Processing file: Bridges Sector Cash Position Justification.pdf
# [INFO] Processing file: Bridges Sector Planning Status 2023.09.04.pbix
# [WARN] Skipped unsupported file type: Bridges Sector Planning Status 2023.09.04.pbix
# [INFO] Processing file: 0. August Industrial Sector .xlsx
# [WARN] No text extracted from: 0. August Industrial Sector .xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. August Industrial sector.pbix
# [WARN] Skipped unsupported file type: 1. August Industrial sector.pbix
# [INFO] Processing file: 0. August Infrastructure & Governmental Sector.xlsx
# [WARN] No text extracted from: 0. August Infrastructure & Governmental Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. August Infrastructure & Governmental sector.pbix
# [WARN] Skipped unsupported file type: 1. August Infrastructure & Governmental sector.pbix
# [INFO] Processing file: 0. August Commercial & Residential Sector.xlsx
# [WARN] No text extracted from: 0. August Commercial & Residential Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. August Commercial & Residential sector.pbix
# [WARN] Skipped unsupported file type: 1. August Commercial & Residential sector.pbix
# [INFO] Processing file: Bridges Sector Control Dashboard (2023.09.30).pbix
# [WARN] Skipped unsupported file type: Bridges Sector Control Dashboard (2023.09.30).pbix
# [INFO] Processing file: 0. September Infrastructure & Governmental Sector.xlsx
# [WARN] No text extracted from: 0. September Infrastructure & Governmental Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. September Infrastructure & Governmental sector.pbix
# [WARN] Skipped unsupported file type: 1. September Infrastructure & Governmental sector.pbix
# [INFO] Processing file: 0. September Commercial & Residential Sector.xlsx
# [WARN] No text extracted from: 0. September Commercial & Residential Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. September Commercial & Residential sector.pbix
# [WARN] Skipped unsupported file type: 1. September Commercial & Residential sector.pbix
# [INFO] Processing file: 0. October Army Sector.xlsx
# [WARN] No text extracted from: 0. October Army Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. October Army sector.pbix
# [WARN] Skipped unsupported file type: 1. October Army sector.pbix
# [INFO] Processing file: 0. October Industrial Sector.xlsx
# [WARN] No text extracted from: 0. October Industrial Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. October Industrial sector.pbix
# [WARN] Skipped unsupported file type: 1. October Industrial sector.pbix
# [INFO] Processing file: 0. October Infrastructure & Governmental Sector.xlsx
# [WARN] No text extracted from: 0. October Infrastructure & Governmental Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. October Infrastructure & Governmental sector.pbix
# [WARN] Skipped unsupported file type: 1. October Infrastructure & Governmental sector.pbix
# [INFO] Processing file: 0. October Commercial & Residential Sector.xlsx
# [WARN] No text extracted from: 0. October Commercial & Residential Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. October Commercial & Residential sector.pbix
# [WARN] Skipped unsupported file type: 1. October Commercial & Residential sector.pbix
# [INFO] Processing file: 0. October Army Sector.xlsx
# [WARN] No text extracted from: 0. October Army Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. October Army sector.pbix
# [WARN] Skipped unsupported file type: 1. October Army sector.pbix
# [INFO] Processing file: 0. October Industrial Sector.xlsx
# [WARN] No text extracted from: 0. October Industrial Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. October Industrial sector.pbix
# [WARN] Skipped unsupported file type: 1. October Industrial sector.pbix
# [INFO] Processing file: 0. October Infrastructure & Governmental Sector.xlsx
# [WARN] No text extracted from: 0. October Infrastructure & Governmental Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. October Infrastructure & Governmental sector.pbix
# [WARN] Skipped unsupported file type: 1. October Infrastructure & Governmental sector.pbix
# [INFO] Processing file: 0. October Commercial & Residential Sector.xlsx
# [WARN] No text extracted from: 0. October Commercial & Residential Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. October Commercial & Residential sector.pbix
# [WARN] Skipped unsupported file type: 1. October Commercial & Residential sector.pbix
# [INFO] Processing file: Google Sheets Update.xlsx
# [WARN] No text extracted from: Google Sheets Update.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Army Sector - .pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Army Sector - .pbix
# [INFO] Processing file: Army Sector .xlsx
# [WARN] No text extracted from: Army Sector .xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB C&R Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB C&R Sector.pbix
# [INFO] Processing file: Commercial & Residential Sector .xlsx
# [WARN] No text extracted from: Commercial & Residential Sector .xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB LE Galawa.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB LE Galawa.pbix
# [INFO] Processing file: Comros Le Galawa.xlsx
# [WARN] No text extracted from: Comros Le Galawa.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Governmental Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Governmental Sector.pbix
# [INFO] Processing file: Governmental Sector.xlsx
# [WARN] No text extracted from: Governmental Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Industrial Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Industrial Sector.pbix
# [INFO] Processing file: Industrial Sector.xlsx
# [WARN] No text extracted from: Industrial Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Infra Structure.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Infra Structure.pbix
# [INFO] Processing file: Infrastructure Sector.xlsx
# [WARN] No text extracted from: Infrastructure Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Radamis.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Radamis.pbix
# [INFO] Processing file: Radamis.xlsx
# [WARN] No text extracted from: Radamis.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Jawhara.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Jawhara.pbix
# [INFO] Processing file: Jawhara.xlsx
# [WARN] No text extracted from: Jawhara.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Army Sector - .pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Army Sector - .pbix
# [INFO] Processing file: Army Sector .xlsx
# [WARN] No text extracted from: Army Sector .xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Bridges Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Bridges Sector.pbix
# [INFO] Processing file: Bridges Sector.xlsx
# [WARN] No text extracted from: Bridges Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB C&R Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB C&R Sector.pbix
# [INFO] Processing file: Commercial & Residential Sector .xlsx
# [WARN] No text extracted from: Commercial & Residential Sector .xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB LE Galawa.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB LE Galawa.pbix
# [INFO] Processing file: Comros Le Galawa.xlsx
# [WARN] No text extracted from: Comros Le Galawa.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Governmental Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Governmental Sector.pbix
# [INFO] Processing file: Governmental Sector.xlsx
# [WARN] No text extracted from: Governmental Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Industrial Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Industrial Sector.pbix
# [INFO] Processing file: Industrial Sector.xlsx
# [WARN] No text extracted from: Industrial Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Infra Structure.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Infra Structure.pbix
# [INFO] Processing file: Infrastructure Sector.xlsx
# [WARN] No text extracted from: Infrastructure Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Koumassi.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Koumassi.pbix
# [INFO] Processing file: Côte d'Ivoire Koumassi .xlsx
# [WARN] No text extracted from: Côte d'Ivoire Koumassi .xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Radamis.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Radamis.pbix
# [INFO] Processing file: Radamis.xlsx
# [WARN] No text extracted from: Radamis.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Jawhara.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Jawhara.pbix
# [INFO] Processing file: Jawhara.xlsx
# [WARN] No text extracted from: Jawhara.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Army Sector .pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Army Sector .pbix
# [INFO] Processing file: Army Sector.xlsx
# [WARN] No text extracted from: Army Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Bridges Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Bridges Sector.pbix
# [INFO] Processing file: Bridges Sector.xlsx
# [WARN] No text extracted from: Bridges Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB C&R Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB C&R Sector.pbix
# [INFO] Processing file: Commercial & Residential Sector .xlsx
# [WARN] No text extracted from: Commercial & Residential Sector .xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Governmental Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Governmental Sector.pbix
# [INFO] Processing file: Governmental Sector.xlsx
# [WARN] No text extracted from: Governmental Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Industrial Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Industrial Sector.pbix
# [INFO] Processing file: Industrial Sector  (1).xlsx
# [WARN] No text extracted from: Industrial Sector  (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Infra Structure.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Infra Structure.pbix
# [INFO] Processing file: Infrastructure Sector.xlsx
# [WARN] No text extracted from: Infrastructure Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Koumassi.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Koumassi.pbix
# [INFO] Processing file: Côte d'Ivoire Koumassi.xlsx
# [WARN] No text extracted from: Côte d'Ivoire Koumassi.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Radamis.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Radamis.pbix
# [INFO] Processing file: Radamis.xlsx
# [WARN] No text extracted from: Radamis.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Jawhara.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Jawhara.pbix
# [INFO] Processing file: Jawhara.xlsx
# [WARN] No text extracted from: Jawhara.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Army Sector - .pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Army Sector - .pbix
# [INFO] Processing file: Army Sector  (2).xlsx
# [WARN] No text extracted from: Army Sector  (2).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Bridges Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Bridges Sector.pbix
# [INFO] Processing file: Bridges Sector.xlsx
# [WARN] No text extracted from: Bridges Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB C&R Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB C&R Sector.pbix
# [INFO] Processing file: Commercial & Residential Sector  (1).xlsx
# [WARN] No text extracted from: Commercial & Residential Sector  (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Governmental Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Governmental Sector.pbix
# [INFO] Processing file: Governmental Sector.xlsx
# [WARN] No text extracted from: Governmental Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Industrial Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Industrial Sector.pbix
# [INFO] Processing file: Industrial Sector  (1).xlsx
# [WARN] No text extracted from: Industrial Sector  (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Infra Structure.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Infra Structure.pbix
# [INFO] Processing file: Infrastructure Sector.xlsx
# [WARN] No text extracted from: Infrastructure Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Koumassi.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Koumassi.pbix
# [INFO] Processing file: Côte d'Ivoire Koumassi (1).xlsx
# [WARN] No text extracted from: Côte d'Ivoire Koumassi (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Jawhara.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Jawhara.pbix
# [INFO] Processing file: Jawhara.xlsx
# [WARN] No text extracted from: Jawhara.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Army Sector - .pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Army Sector - .pbix
# [INFO] Processing file: 1. project progress DB Army Sector Rev01.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Army Sector Rev01.pbix
# [INFO] Processing file: Army Sector  (3).xlsx
# [WARN] No text extracted from: Army Sector  (3).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Bridges Sector Rev01.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Bridges Sector Rev01.pbix
# [INFO] Processing file: 1. project progress DB Bridges Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Bridges Sector.pbix
# [INFO] Processing file: Bridges Sector (1).xlsx
# [WARN] No text extracted from: Bridges Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB C&R Sector Rev01.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB C&R Sector Rev01.pbix
# [INFO] Processing file: 1. project progress DB C&R Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB C&R Sector.pbix
# [INFO] Processing file: Commercial & Residential Sector  (2).xlsx
# [WARN] No text extracted from: Commercial & Residential Sector  (2).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Governmental Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Governmental Sector.pbix
# [INFO] Processing file: Governmental Sector.xlsx
# [WARN] No text extracted from: Governmental Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Industrial Sector Rev01.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Industrial Sector Rev01.pbix
# [INFO] Processing file: 1. project progress DB Industrial Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Industrial Sector.pbix
# [INFO] Processing file: Industrial Sector  (2).xlsx
# [WARN] No text extracted from: Industrial Sector  (2).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Infra Structure Rev01.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Infra Structure Rev01.pbix
# [INFO] Processing file: 1. project progress DB Infra Structure.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Infra Structure.pbix
# [INFO] Processing file: Infrastructure Sector.xlsx
# [WARN] No text extracted from: Infrastructure Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Radamis.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Radamis.pbix
# [INFO] Processing file: Radamis.xlsx
# [WARN] No text extracted from: Radamis.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Jawhara.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Jawhara.pbix
# [INFO] Processing file: Jawhara (1).xlsx
# [WARN] No text extracted from: Jawhara (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Army Sector - .pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Army Sector - .pbix
# [INFO] Processing file: Army Sector  (3).xlsx
# [WARN] No text extracted from: Army Sector  (3).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Bridges Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Bridges Sector.pbix
# [INFO] Processing file: Bridges Sector (1).xlsx
# [WARN] No text extracted from: Bridges Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB C&R Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB C&R Sector.pbix
# [INFO] Processing file: Commercial & Residential Sector  (2).xlsx
# [WARN] No text extracted from: Commercial & Residential Sector  (2).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Governmental Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Governmental Sector.pbix
# [INFO] Processing file: Governmental Sector.xlsx
# [WARN] No text extracted from: Governmental Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Industrial Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Industrial Sector.pbix
# [INFO] Processing file: Industrial Sector  (2).xlsx
# [WARN] No text extracted from: Industrial Sector  (2).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Infra Structure.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Infra Structure.pbix
# [INFO] Processing file: Infrastructure Sector.xlsx
# [WARN] No text extracted from: Infrastructure Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Jawhara.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Jawhara.pbix
# [INFO] Processing file: Jawhara (1).xlsx
# [WARN] No text extracted from: Jawhara (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Army Sector - .pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Army Sector - .pbix
# [INFO] Processing file: 1. project progress DB Bridges Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Bridges Sector.pbix
# [INFO] Processing file: 1. project progress DB C&R Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB C&R Sector.pbix
# [INFO] Processing file: Commercial & Residential Sector  (2).xlsx
# [WARN] No text extracted from: Commercial & Residential Sector  (2).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Governmental Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Governmental Sector.pbix
# [INFO] Processing file: 1. project progress DB Industrial Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Industrial Sector.pbix
# [INFO] Processing file: 1. project progress DB Infra Structure.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Infra Structure.pbix
# [INFO] Processing file: 1. project progress DB Jawhara.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Jawhara.pbix
# [INFO] Processing file: Jawhara (1).xlsx
# [WARN] No text extracted from: Jawhara (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Army Sector - .pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Army Sector - .pbix
# [INFO] Processing file: 1. project progress DB Bridges Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Bridges Sector.pbix
# [INFO] Processing file: 1. project progress DB C&R Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB C&R Sector.pbix
# [INFO] Processing file: 1. project progress DB Governmental Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Governmental Sector.pbix
# [INFO] Processing file: 1. project progress DB Industrial Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Industrial Sector.pbix
# [INFO] Processing file: 1. project progress DB Infra Structure.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Infra Structure.pbix
# [INFO] Processing file: 1. project progress DB Koumassi.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Koumassi.pbix
# [INFO] Processing file: 1. project progress DB Jawhara.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Jawhara.pbix
# [INFO] Processing file: 1. project progress DB Army Sector - .pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Army Sector - .pbix
# [INFO] Processing file: Army Sector  (3).xlsx
# [WARN] No text extracted from: Army Sector  (3).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Bridges Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Bridges Sector.pbix
# [INFO] Processing file: Bridges Sector (1).xlsx
# [WARN] No text extracted from: Bridges Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB C&R Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB C&R Sector.pbix
# [INFO] Processing file: Commercial & Residential Sector  (2).xlsx
# [WARN] No text extracted from: Commercial & Residential Sector  (2).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Governmental Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Governmental Sector.pbix
# [INFO] Processing file: Governmental Sector.xlsx
# [WARN] No text extracted from: Governmental Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Industrial Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Industrial Sector.pbix
# [INFO] Processing file: Industrial Sector.xlsx
# [WARN] No text extracted from: Industrial Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Infra Structure.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Infra Structure.pbix
# [INFO] Processing file: Infrastructure Sector.xlsx
# [WARN] No text extracted from: Infrastructure Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Koumassi.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Koumassi.pbix
# [INFO] Processing file: Côte d'Ivoire Koumassi (1).xlsx
# [WARN] No text extracted from: Côte d'Ivoire Koumassi (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB KSA.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB KSA.pbix
# [INFO] Processing file: KSA Sector.xlsx
# [WARN] No text extracted from: KSA Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Jawhara.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Jawhara.pbix
# [INFO] Processing file: Jawhara (1).xlsx
# [WARN] No text extracted from: Jawhara (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Army Sector - .pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Army Sector - .pbix
# [INFO] Processing file: Army Sector  (3).xlsx
# [WARN] No text extracted from: Army Sector  (3).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Bridges Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Bridges Sector.pbix
# [INFO] Processing file: Bridges Sector (2).xlsx
# [WARN] No text extracted from: Bridges Sector (2).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB C&R Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB C&R Sector.pbix
# [INFO] Processing file: Commercial & Residential Sector  (3).xlsx
# [WARN] No text extracted from: Commercial & Residential Sector  (3).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Damietta Port.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Damietta Port.pbix
# [INFO] Processing file: Damietta Port.xlsx
# [WARN] No text extracted from: Damietta Port.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Governmental Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Governmental Sector.pbix
# [INFO] Processing file: Governmental Sector (1).xlsx
# [WARN] No text extracted from: Governmental Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Industrial Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Industrial Sector.pbix
# [INFO] Processing file: Industrial Sector  (3).xlsx
# [WARN] No text extracted from: Industrial Sector  (3).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Infra Structure.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Infra Structure.pbix
# [INFO] Processing file: Infrastructure Sector (1).xlsx
# [WARN] No text extracted from: Infrastructure Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Koumassi.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Koumassi.pbix
# [INFO] Processing file: Côte d'Ivoire Koumassi (1).xlsx
# [WARN] No text extracted from: Côte d'Ivoire Koumassi (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB KSA.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB KSA.pbix
# [INFO] Processing file: KSA Sector (1).xlsx
# [WARN] No text extracted from: KSA Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Jawhara.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Jawhara.pbix
# [INFO] Processing file: Jawhara (1).xlsx
# [WARN] No text extracted from: Jawhara (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Army Sector - .pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Army Sector - .pbix
# [INFO] Processing file: Army Sector  (3).xlsx
# [WARN] No text extracted from: Army Sector  (3).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Bridges Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Bridges Sector.pbix
# [INFO] Processing file: Bridges Sector (2).xlsx
# [WARN] No text extracted from: Bridges Sector (2).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB C&R Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB C&R Sector.pbix
# [INFO] Processing file: Commercial & Residential Sector  (3).xlsx
# [WARN] No text extracted from: Commercial & Residential Sector  (3).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Governmental Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Governmental Sector.pbix
# [INFO] Processing file: Governmental Sector (1).xlsx
# [WARN] No text extracted from: Governmental Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Industrial Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Industrial Sector.pbix
# [INFO] Processing file: Industrial Sector  (3).xlsx
# [WARN] No text extracted from: Industrial Sector  (3).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Infra Structure.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Infra Structure.pbix
# [INFO] Processing file: Infrastructure Sector (1).xlsx
# [WARN] No text extracted from: Infrastructure Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB KSA.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB KSA.pbix
# [INFO] Processing file: KSA Sector (1).xlsx
# [WARN] No text extracted from: KSA Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Jawhara.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Jawhara.pbix
# [INFO] Processing file: Jawhara (1).xlsx
# [WARN] No text extracted from: Jawhara (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Army Sector - .pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Army Sector - .pbix
# [INFO] Processing file: Army Sector  (3).xlsx
# [WARN] No text extracted from: Army Sector  (3).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Bridges Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Bridges Sector.pbix
# [INFO] Processing file: Bridges Sector (2).xlsx
# [WARN] No text extracted from: Bridges Sector (2).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB C&R Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB C&R Sector.pbix
# [INFO] Processing file: Commercial & Residential Sector  (3).xlsx
# [WARN] No text extracted from: Commercial & Residential Sector  (3).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Damietta Port.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Damietta Port.pbix
# [INFO] Processing file: Damietta Port.xlsx
# [WARN] No text extracted from: Damietta Port.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Governmental Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Governmental Sector.pbix
# [INFO] Processing file: Governmental Sector (1).xlsx
# [WARN] No text extracted from: Governmental Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Industrial Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Industrial Sector.pbix
# [INFO] Processing file: Industrial Sector  (3).xlsx
# [WARN] No text extracted from: Industrial Sector  (3).xlsx (no text extracted (Excel))
# [INFO] Processing file: Infrastructure Sector (1).xlsx
# [WARN] No text extracted from: Infrastructure Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Koumassi.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Koumassi.pbix
# [INFO] Processing file: Côte d'Ivoire Koumassi (1).xlsx
# [WARN] No text extracted from: Côte d'Ivoire Koumassi (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB KSA.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB KSA.pbix
# [INFO] Processing file: KSA Sector (1).xlsx
# [WARN] No text extracted from: KSA Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Army Sector - .pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Army Sector - .pbix
# [INFO] Processing file: Army Sector  (3).xlsx
# [WARN] No text extracted from: Army Sector  (3).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Bridges Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Bridges Sector.pbix
# [INFO] Processing file: Bridges Sector (2).xlsx
# [WARN] No text extracted from: Bridges Sector (2).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB C&R Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB C&R Sector.pbix
# [INFO] Processing file: Commercial & Residential Sector  (3).xlsx
# [WARN] No text extracted from: Commercial & Residential Sector  (3).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Damietta Port.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Damietta Port.pbix
# [INFO] Processing file: Damietta Port.xlsx
# [WARN] No text extracted from: Damietta Port.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Governmental Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Governmental Sector.pbix
# [INFO] Processing file: Governmental Sector (1).xlsx
# [WARN] No text extracted from: Governmental Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Industrial Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Industrial Sector.pbix
# [INFO] Processing file: 1. project progress DB Infra Structure.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Infra Structure.pbix
# [INFO] Processing file: Infrastructure Sector (1).xlsx
# [WARN] No text extracted from: Infrastructure Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Koumassi.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Koumassi.pbix
# [INFO] Processing file: Côte d'Ivoire Koumassi (1).xlsx
# [WARN] No text extracted from: Côte d'Ivoire Koumassi (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB KSA.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB KSA.pbix
# [INFO] Processing file: KSA Sector (1).xlsx
# [WARN] No text extracted from: KSA Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Jawhara.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Jawhara.pbix
# [INFO] Processing file: Jawhara (1).xlsx
# [WARN] No text extracted from: Jawhara (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: Commercial & Residential BU (National) 2025.xlsx
# [WARN] No text extracted from: Commercial & Residential BU (National) 2025.xlsx (no text extracted (Excel))
# [INFO] Processing file: Dashboard Commercial & Residential BU (National) 2025.pbix
# [WARN] Skipped unsupported file type: Dashboard Commercial & Residential BU (National) 2025.pbix
# [INFO] Processing file: Damietta Port.xlsx
# [WARN] No text extracted from: Damietta Port.xlsx (no text extracted (Excel))
# [INFO] Processing file: DB Damietta Port 2025.pbix
# [WARN] Skipped unsupported file type: DB Damietta Port 2025.pbix
# [INFO] Processing file: DB Industrial 2025.pbix
# [WARN] Skipped unsupported file type: DB Industrial 2025.pbix
# [INFO] Processing file: Dash Board Infrastructure BU National (2025).pbix
# [WARN] Skipped unsupported file type: Dash Board Infrastructure BU National (2025).pbix
# [INFO] Processing file: Dash Board Infrastructure BU National (2025).xlsx
# [WARN] No text extracted from: Dash Board Infrastructure BU National (2025).xlsx (no text extracted (Excel))
# [INFO] Processing file: Dashboard Bridges BU National (2025).pbix
# [WARN] Skipped unsupported file type: Dashboard Bridges BU National (2025).pbix
# [INFO] Processing file: Dashboard Bridges BU National (2025).xlsx
# [WARN] No text extracted from: Dashboard Bridges BU National (2025).xlsx (no text extracted (Excel))
# [INFO] Processing file: DB Governmental 2025.pbix
# [WARN] Skipped unsupported file type: DB Governmental 2025.pbix
# [INFO] Processing file: DB Governmental 2025.xlsx
# [WARN] No text extracted from: DB Governmental 2025.xlsx (no text extracted (Excel))
# [INFO] Processing file: Dashboard Restoration BU National (2025).pbix
# [WARN] Skipped unsupported file type: Dashboard Restoration BU National (2025).pbix
# [INFO] Processing file: Dashboard Restoration BU National (2025).xlsx
# [WARN] No text extracted from: Dashboard Restoration BU National (2025).xlsx (no text extracted (Excel))
# [INFO] Processing file: Dashboard Cote d'ivoire Branch (International) (2025).pbix
# [WARN] Skipped unsupported file type: Dashboard Cote d'ivoire Branch (International) (2025).pbix
# [INFO] Processing file: Dashboard Cote d'ivoire Branch (International) (2025).xlsx
# [WARN] No text extracted from: Dashboard Cote d'ivoire Branch (International) (2025).xlsx (no text extracted (Excel))
# [INFO] Processing file: Dashboard KSA Branch International (2025).pbix
# [WARN] Skipped unsupported file type: Dashboard KSA Branch International (2025).pbix
# [INFO] Processing file: Dashboard KSA Branch International (2025).xlsx
# [WARN] No text extracted from: Dashboard KSA Branch International (2025).xlsx (no text extracted (Excel))
# [INFO] Processing file: Monthly dash board 31-1-2025.pdf
# [INFO] Processing file: UGR - Monthly dash board No.10 cut-off date Jan-2025.pdf
# [INFO] Processing file: Commercial & Residential BU (National) 2025.xlsx
# [WARN] No text extracted from: Commercial & Residential BU (National) 2025.xlsx (no text extracted (Excel))
# [INFO] Processing file: Dashboard Commercial & Residential BU (National) 2025.pbix
# [WARN] Skipped unsupported file type: Dashboard Commercial & Residential BU (National) 2025.pbix
# [INFO] Processing file: DB Damietta Port 2025.pbix
# [WARN] Skipped unsupported file type: DB Damietta Port 2025.pbix
# [INFO] Processing file: DB Damietta Port 2025.xlsx
# [WARN] No text extracted from: DB Damietta Port 2025.xlsx (no text extracted (Excel))
# [INFO] Processing file: DB Industrial 2025.pbix
# [WARN] Skipped unsupported file type: DB Industrial 2025.pbix
# [INFO] Processing file: DB Industrial 2025.xlsx
# [WARN] No text extracted from: DB Industrial 2025.xlsx (no text extracted (Excel))
# [INFO] Processing file: Dash Board Infrastructure BU National (2025).pbix
# [WARN] Skipped unsupported file type: Dash Board Infrastructure BU National (2025).pbix
# [INFO] Processing file: Dash Board Infrastructure BU National (2025).xlsx
# [WARN] No text extracted from: Dash Board Infrastructure BU National (2025).xlsx (no text extracted (Excel))
# [INFO] Processing file: Dashboard Bridges BU National (2025).pbix
# [WARN] Skipped unsupported file type: Dashboard Bridges BU National (2025).pbix
# [INFO] Processing file: Dashboard Bridges BU National (2025).xlsx
# [WARN] No text extracted from: Dashboard Bridges BU National (2025).xlsx (no text extracted (Excel))
# [INFO] Processing file: DB Governmental 2025.pbix
# [WARN] Skipped unsupported file type: DB Governmental 2025.pbix
# [INFO] Processing file: DB Governmental 2025.xlsx
# [WARN] No text extracted from: DB Governmental 2025.xlsx (no text extracted (Excel))
# [INFO] Processing file: Dashboard Restoration BU National (2025).pbix
# [WARN] Skipped unsupported file type: Dashboard Restoration BU National (2025).pbix
# [INFO] Processing file: Dashboard Restoration BU National (2025).xlsx
# [WARN] No text extracted from: Dashboard Restoration BU National (2025).xlsx (no text extracted (Excel))
# [INFO] Processing file: Dashboard Cote d'ivoire Branch (International) (2025).pbix
# [WARN] Skipped unsupported file type: Dashboard Cote d'ivoire Branch (International) (2025).pbix
# [INFO] Processing file: Dashboard Cote d'ivoire Branch (International) (2025).xlsx
# [WARN] No text extracted from: Dashboard Cote d'ivoire Branch (International) (2025).xlsx (no text extracted (Excel))
# [INFO] Processing file: Dashboard KSA Branch International (2025).pbix
# [WARN] Skipped unsupported file type: Dashboard KSA Branch International (2025).pbix
# [INFO] Processing file: Dashboard KSA Branch International (2025).xlsx
# [WARN] No text extracted from: Dashboard KSA Branch International (2025).xlsx (no text extracted (Excel))
# [INFO] Processing file: Commercial & Residential Sector .xlsx
# [WARN] No text extracted from: Commercial & Residential Sector .xlsx (no text extracted (Excel))
# [INFO] Processing file: Dashboard Commercial & Residential BU (National) 2025.pbix
# [WARN] Skipped unsupported file type: Dashboard Commercial & Residential BU (National) 2025.pbix
# [INFO] Processing file: DB Damietta Port 2025.pbix
# [WARN] Skipped unsupported file type: DB Damietta Port 2025.pbix
# [INFO] Processing file: DB Industrial 2025.pbix
# [WARN] Skipped unsupported file type: DB Industrial 2025.pbix
# [INFO] Processing file: Dash Board Infrastructure BU National (2025).pbix
# [WARN] Skipped unsupported file type: Dash Board Infrastructure BU National (2025).pbix
# [INFO] Processing file: Dashboard Bridges BU National (2025).pbix
# [WARN] Skipped unsupported file type: Dashboard Bridges BU National (2025).pbix
# [INFO] Processing file: DB Governmental 2025.pbix
# [WARN] Skipped unsupported file type: DB Governmental 2025.pbix
# [INFO] Processing file: Dashboard Restoration BU National (2025).pbix
# [WARN] Skipped unsupported file type: Dashboard Restoration BU National (2025).pbix
# [INFO] Processing file: Dashboard Cote d'ivoire Branch (International) (2025).pbix
# [WARN] Skipped unsupported file type: Dashboard Cote d'ivoire Branch (International) (2025).pbix
# [INFO] Processing file: Dashboard KSA Branch International (2025).pbix
# [WARN] Skipped unsupported file type: Dashboard KSA Branch International (2025).pbix
# [INFO] Processing file: Dashboard Commercial & Residential BU (National) 2025.pbix
# [WARN] Skipped unsupported file type: Dashboard Commercial & Residential BU (National) 2025.pbix
# [INFO] Processing file: DB Damietta Port 2025.pbix
# [WARN] Skipped unsupported file type: DB Damietta Port 2025.pbix
# [INFO] Processing file: DB Industrial 2025.pbix
# [WARN] Skipped unsupported file type: DB Industrial 2025.pbix
# [INFO] Processing file: Dash Board Infrastructure BU National (2025).pbix
# [WARN] Skipped unsupported file type: Dash Board Infrastructure BU National (2025).pbix
# [INFO] Processing file: Dashboard Bridges BU National (2025).pbix
# [WARN] Skipped unsupported file type: Dashboard Bridges BU National (2025).pbix
# [INFO] Processing file: DB Governmental 2025.pbix
# [WARN] Skipped unsupported file type: DB Governmental 2025.pbix
# [INFO] Processing file: Dashboard Restoration BU National (2025).pbix
# [WARN] Skipped unsupported file type: Dashboard Restoration BU National (2025).pbix
# [INFO] Processing file: Dashboard Cote d'ivoire Branch (International) (2025).pbix
# [WARN] Skipped unsupported file type: Dashboard Cote d'ivoire Branch (International) (2025).pbix
# [INFO] Processing file: Dashboard KSA Branch International (2025).pbix
# [WARN] Skipped unsupported file type: Dashboard KSA Branch International (2025).pbix
# [INFO] Processing file: Baseline-EOT-Milestones-Projects Status Log - Final Mar.25.xlsx
# [WARN] No text extracted from: Baseline-EOT-Milestones-Projects Status Log - Final Mar.25.xlsx (no text extracted (Excel))
# [INFO] Processing file: CR 24,25 Planned Vs Actual.xlsx
# [WARN] No text extracted from: CR 24,25 Planned Vs Actual.xlsx (no text extracted (Excel))
# [INFO] Processing file: Baseline-EOT-Milestones-Projects Status Log - Final Jan.25.xlsx
# [WARN] No text extracted from: Baseline-EOT-Milestones-Projects Status Log - Final Jan.25.xlsx (no text extracted (Excel))
# [INFO] Processing file: General Milestones.pdf
# [INFO] Processing file: International Projects Intermediate milestones.pdf
# [INFO] Processing file: International Projects.pdf
# [INFO] Processing file: National Projects Intermediate Milestones ( Bridges, Infra, Industrial).pdf
# [INFO] Processing file: National Projects Intermediate Milestones ( Commercial, Restoration & GOV).pdf
# [INFO] Processing file: National Projects.pdf
# [INFO] Processing file: Project Control Department Report.pdf
# [INFO] Processing file: Project Control Department Report.pptx
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: Bridges Sector (2).xlsx
# [WARN] No text extracted from: Bridges Sector (2).xlsx (no text extracted (Excel))
# [INFO] Processing file: Commercial & Residential Sector  (3).xlsx
# [WARN] No text extracted from: Commercial & Residential Sector  (3).xlsx (no text extracted (Excel))
# [INFO] Processing file: Côte d'Ivoire Koumassi (1).xlsx
# [WARN] No text extracted from: Côte d'Ivoire Koumassi (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: Damietta Port.xlsx
# [WARN] No text extracted from: Damietta Port.xlsx (no text extracted (Excel))
# [INFO] Processing file: Governmental Sector (1).xlsx
# [WARN] No text extracted from: Governmental Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: Industrial Sector  (3).xlsx
# [WARN] No text extracted from: Industrial Sector  (3).xlsx (no text extracted (Excel))
# [INFO] Processing file: Infrastructure Sector (1).xlsx
# [WARN] No text extracted from: Infrastructure Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: Jawhara (1).xlsx
# [WARN] No text extracted from: Jawhara (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: KSA Sector (1).xlsx
# [WARN] No text extracted from: KSA Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: Baseline-EOT-Milestones-Projects Status Log - Final Feb.25.xlsx
# [WARN] No text extracted from: Baseline-EOT-Milestones-Projects Status Log - Final Feb.25.xlsx (no text extracted (Excel))
# [INFO] Processing file: Final Report.pdf
# [INFO] Processing file: Bridges Sector (2).xlsx
# [WARN] No text extracted from: Bridges Sector (2).xlsx (no text extracted (Excel))
# [INFO] Processing file: Commercial & Residential Sector  (3).xlsx
# [WARN] No text extracted from: Commercial & Residential Sector  (3).xlsx (no text extracted (Excel))
# [INFO] Processing file: Côte d'Ivoire Koumassi (1).xlsx
# [WARN] No text extracted from: Côte d'Ivoire Koumassi (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: Damietta Port.xlsx
# [WARN] No text extracted from: Damietta Port.xlsx (no text extracted (Excel))
# [INFO] Processing file: Governmental Sector (1).xlsx
# [WARN] No text extracted from: Governmental Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: Industrial Sector  (3).xlsx
# [WARN] No text extracted from: Industrial Sector  (3).xlsx (no text extracted (Excel))
# [INFO] Processing file: Infrastructure Sector (1).xlsx
# [WARN] No text extracted from: Infrastructure Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: Jawhara (1).xlsx
# [WARN] No text extracted from: Jawhara (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: KSA Sector (1).xlsx
# [WARN] No text extracted from: KSA Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: Budget Vs Actual Running Cost.pdf
# [INFO] Processing file: International Projects Intermediate milestones.pdf
# [INFO] Processing file: International Projects.pdf
# [INFO] Processing file: National Projects Intermediate Milestones ( Bridges, Infra, Industrial).pdf
# [INFO] Processing file: National Projects Intermediate Milestones ( Commercial, Restoration & GOV).pdf
# [INFO] Processing file: National Projects.pdf
# ...
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Silos..xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Silos..xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Silos.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Silos.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Suez 29-05-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Suez 29-05-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log AbuShanab 23-4-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log AbuShanab 23-4-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log Qasr Rashwan Lot A 22-04-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log Qasr Rashwan Lot A 22-04-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log Qasr Rashwan Lot B 22-04-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log Qasr Rashwan Lot B 22-04-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log- hosh issa..xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log- hosh issa..xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-CREEKSLANDSCAPE.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-CREEKSLANDSCAPE.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-MOC Engineering  23-04-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-MOC Engineering  23-04-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Mivida-26-03-2024.rev.01.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Mivida-26-03-2024.rev.01.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Ora Zed..xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Ora Zed..xlsx (no text extracted (Excel))
# [INFO] Processing file: ~$F-P-EN-01-01 E1 Log-Ora Zed.xlsx
# [WARN] No text extracted from: ~$F-P-EN-01-01 E1 Log-Ora Zed.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-UrbanK.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-UrbanK.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Jawhara Palace..xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Jawhara Palace..xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Red Sea Museum - 30-05-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Red Sea Museum - 30-05-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: 3-Infrastructure(Mohamed abdel moktader).rar
# [WARN] Skipped unsupported file type: 3-Infrastructure(Mohamed abdel moktader).rar
# [INFO] Processing file: Critical Delayed Drwaings Forecasting.xlsx
# [WARN] No text extracted from: Critical Delayed Drwaings Forecasting.xlsx (no text extracted (Excel))
# [INFO] Processing file: Engineering Follow up Dashboard (30-May-2024).pbix
# [WARN] Skipped unsupported file type: Engineering Follow up Dashboard (30-May-2024).pbix
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Sohag HSR Station-10.06.2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Sohag HSR Station-10.06.2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: 2-Industrial(Mohamed El Seman).rar
# [WARN] Skipped unsupported file type: 2-Industrial(Mohamed El Seman).rar
# [INFO] Processing file: F-P-EN-01-01 E1 log - Damietta Container Terminal.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 log - Damietta Container Terminal.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log -EIPICO 3 - CIVIL-ARC.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log -EIPICO 3 - CIVIL-ARC.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log - RABIGH.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log - RABIGH.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Silos..xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Silos..xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Suez - 09-06-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Suez - 09-06-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 Abo Shanab E1 Log Update 2-6-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 Abo Shanab E1 Log Update 2-6-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log Qasr Rashwan Lot A 28-5-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log Qasr Rashwan Lot A 28-5-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log Qasr Rashwan Lot B 28-5-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log Qasr Rashwan Lot B 28-5-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: 4-R&C(Osama el mezian).rar
# [WARN] Skipped unsupported file type: 4-R&C(Osama el mezian).rar
# [INFO] Processing file: F-P-EN-01-01 E1 Log- hosh issa..xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log- hosh issa..xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-CREEKSLANDSCAPE.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-CREEKSLANDSCAPE.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-MOC.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-MOC.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Mivida-06-06-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Mivida-06-06-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Ora Zed..xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Ora Zed..xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-UrbanK.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-UrbanK.xlsx (no text extracted (Excel))
# [INFO] Processing file: 5-Restoration(Mariam Youssef).rar
# [WARN] Skipped unsupported file type: 5-Restoration(Mariam Youssef).rar
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Jawhara Palace..xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Jawhara Palace..xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Red Sea Museum - 30-05-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Red Sea Museum - 30-05-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: 4-June.2024.rar
# [WARN] Skipped unsupported file type: 4-June.2024.rar
# [INFO] Processing file: Engineering Follow up Dashboard (30-June-2024).pbix
# [WARN] Skipped unsupported file type: Engineering Follow up Dashboard (30-June-2024).pbix
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Sohag HSR Station-1-7-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Sohag HSR Station-1-7-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 log - Damietta Container Terminal.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 log - Damietta Container Terminal.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log -EIPICO 3 - CIVIL-ARC -08-07-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log -EIPICO 3 - CIVIL-ARC -08-07-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log Rabigh-1-7-2024..xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log Rabigh-1-7-2024..xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Silos..xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Silos..xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-MEP Suez 30-06-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-MEP Suez 30-06-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Suez - 30-06-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Suez - 30-06-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log Abo Shanab Update 1-7-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log Abo Shanab Update 1-7-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log Qasr Rashwan Lot A 1-7-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log Qasr Rashwan Lot A 1-7-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 log Qasr Rshwan Lot B 1-7-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 log Qasr Rshwan Lot B 1-7-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log- hosh issa..xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log- hosh issa..xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-CREEKSLANDSCAPE 08-07-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-CREEKSLANDSCAPE 08-07-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Mivida-09-07-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Mivida-09-07-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Ora Zed. 09-07-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Ora Zed. 09-07-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Urban-K 08-07-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Urban-K 08-07-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log Jawhara Palace-01-07-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log Jawhara Palace-01-07-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log Red Sea 1-7-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log Red Sea 1-7-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: Engineering Follow up Dashboard (30-june-2024)..pbix
# [WARN] Skipped unsupported file type: Engineering Follow up Dashboard (30-june-2024)..pbix
# [INFO] Processing file: July.2024.rar
# [WARN] Skipped unsupported file type: July.2024.rar
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Sohag HSR Station 30-7-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Sohag HSR Station 30-7-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log -EIPICO 3 - CIVIL-ARC -30-07-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log -EIPICO 3 - CIVIL-ARC -30-07-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log Rabigh-30-7-2024..xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log Rabigh-30-7-2024..xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Silos..xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Silos..xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-MEP Suez 30-07-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-MEP Suez 30-07-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Suez - 30-07-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Suez - 30-07-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log Abo Shanab 30-7-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log Abo Shanab 30-7-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log Qasr Rashwan Lot A 30-7-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log Qasr Rashwan Lot A 30-7-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 log Qasr Rshwan Lot B 30-7-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 log Qasr Rshwan Lot B 30-7-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log- hosh issa 30-7-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log- hosh issa 30-7-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-CREEKSLANDSCAPE 30-07-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-CREEKSLANDSCAPE 30-07-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Mivida-30-07-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Mivida-30-07-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Ora Zed. 30-07-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Ora Zed. 30-07-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Urban-K 30-07-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Urban-K 30-07-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log Jawhara Palace 1-8-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log Jawhara Palace 1-8-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: 00- 05- F-P-EN-01-01 E1 Log Red Sea.xlsx
# [WARN] No text extracted from: 00- 05- F-P-EN-01-01 E1 Log Red Sea.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-CREEKSLANDSCAPE(Sep2024-).xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-CREEKSLANDSCAPE(Sep2024-).xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Mivida-30-08-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Mivida-30-08-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log Update-Abo Shanab- 30-09-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log Update-Abo Shanab- 30-09-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log Qasr Rashwan Lot A 30-09-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log Qasr Rashwan Lot A 30-09-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log Qasr Rashwan Lot B 30-09-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log Qasr Rashwan Lot B 30-09-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-CREEKSLANDSCAPE(Sep2024-).xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-CREEKSLANDSCAPE(Sep2024-).xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Mivida-30-08-2024.xlsx
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Mivida-30-08-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: ENG Query-Rev05.xlsx
# [WARN] No text extracted from: ENG Query-Rev05.xlsx (no text extracted (Excel))
# [INFO] Processing file: Engineering Follow up Dashboard Rev.05.pbix
# [WARN] Skipped unsupported file type: Engineering Follow up Dashboard Rev.05.pbix
# [INFO] Processing file: Shopdrawings-Rev.05.xlsx
# [WARN] No text extracted from: Shopdrawings-Rev.05.xlsx (no text extracted (Excel))
# [INFO] Processing file: Engineering dashboard-20240919_102440-Meeting Recording.mp4
# [WARN] Skipped unsupported file type: Engineering dashboard-20240919_102440-Meeting Recording.mp4
# [INFO] Processing file: As Built Logs_Commercial & Residential BU.xlsx
# [WARN] No text extracted from: As Built Logs_Commercial & Residential BU.xlsx (no text extracted (Excel))
# [INFO] Processing file: E1 Logs_Commercial & Residential BU.xlsx
# [WARN] No text extracted from: E1 Logs_Commercial & Residential BU.xlsx (no text extracted (Excel))
# [INFO] Processing file: E2 Logs_Commercial & Residential BU.xlsx
# [WARN] No text extracted from: E2 Logs_Commercial & Residential BU.xlsx (no text extracted (Excel))
# [INFO] Processing file: Raw Files.rar
# [WARN] Skipped unsupported file type: Raw Files.rar
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: Self Exec. Power Bi Report Ver-05.pbix
# [WARN] Skipped unsupported file type: Self Exec. Power Bi Report Ver-05.pbix
# [INFO] Processing file: Self Exec. Power Bi Report Ver-05.pbix
# [WARN] Skipped unsupported file type: Self Exec. Power Bi Report Ver-05.pbix
# [INFO] Processing file: Self Exec. Power Bi Report Ver-06.pbix
# [WARN] Skipped unsupported file type: Self Exec. Power Bi Report Ver-06.pbix
# [INFO] Processing file: Self Exec. Power Bi Report Ver-05-Hossam-Hatem.pbix
# [WARN] Skipped unsupported file type: Self Exec. Power Bi Report Ver-05-Hossam-Hatem.pbix
# [INFO] Processing file: General Milestones.pdf
# Processed 29 documents. Output saved to C:/Users/Omar Essam2/OneDrive - Rowad Modern Engineering/x004 Data Science/03.rme.db/05.llm/extracted_json\01 Dash Boards_extracted.json

# %%
import os
import json
import openai
import chromadb
from chromadb.config import Settings
from dotenv import load_dotenv
from tqdm import tqdm

# Load OpenAI API key from .env
load_dotenv()
openai.api_key = os.getenv('OPENAI_API_KEY')

# New paths outside the repo
EXTRACTED_DIR = r'C:/Users/Omar Essam2/OneDrive - Rowad Modern Engineering/x004 Data Science/03.rme.db/05.llm/extracted_json'
CHROMA_DB_DIR = r'C:/Users/Omar Essam2/OneDrive - Rowad Modern Engineering/x004 Data Science/03.rme.db/05.llm/chroma_db'
COLLECTION_NAME = 'company_docs'
CHUNK_SIZE = 1000  # characters per chunk
CHUNK_OVERLAP = 200
ID_TRACK_FILE = os.path.join(CHROMA_DB_DIR, 'embedded_chunk_ids.txt')

# Helper: chunk text
def chunk_text(text, chunk_size=CHUNK_SIZE, overlap=CHUNK_OVERLAP):
    chunks = []
    start = 0
    while start < len(text):
        end = min(start + chunk_size, len(text))
        chunks.append(text[start:end])
        start += chunk_size - overlap
    return chunks

# Helper: get OpenAI embeddings
def get_embedding(text):
    resp = openai.embeddings.create(
        input=[text],
        model="text-embedding-ada-002"
    )
    return resp.data[0].embedding

# Initialize Chroma DB
client = chromadb.PersistentClient(path=CHROMA_DB_DIR, settings=Settings(allow_reset=True))
if COLLECTION_NAME in [c.name for c in client.list_collections()]:
    collection = client.get_collection(COLLECTION_NAME)
else:
    collection = client.create_collection(COLLECTION_NAME)

def load_embedded_ids():
    if not os.path.exists(ID_TRACK_FILE):
        return set()
    with open(ID_TRACK_FILE, 'r', encoding='utf-8') as f:
        return set(line.strip() for line in f if line.strip())

def save_embedded_id(chunk_id):
    with open(ID_TRACK_FILE, 'a', encoding='utf-8') as f:
        f.write(chunk_id + '\n')

def process_json_files():
    files = [f for f in os.listdir(EXTRACTED_DIR) if f.endswith('.json')]
    doc_count = 0
    embedded_ids = load_embedded_ids()
    for file in files:
        with open(os.path.join(EXTRACTED_DIR, file), 'r', encoding='utf-8') as f:
            docs = json.load(f)
        for doc in tqdm(docs, desc=f"Processing {file}"):
            text = doc['text']
            if not text.strip():
                continue
            chunks = chunk_text(text)
            for i, chunk in enumerate(chunks):
                chunk_id = f"{doc['file_name']}_{i}"
                if chunk_id in embedded_ids:
                    continue  # Skip already embedded chunk
                meta = {
                    'file_name': doc['file_name'],
                    'file_path': doc['file_path'],
                    'type': doc['type'],
                    'extracted_at': doc['extracted_at'],
                    'chunk': i
                }
                try:
                    emb = get_embedding(chunk)
                    collection.add(
                        documents=[chunk],
                        embeddings=[emb],
                        metadatas=[meta],
                        ids=[chunk_id]
                    )
                    save_embedded_id(chunk_id)
                    doc_count += 1
                except Exception as e:
                    print(f"Error embedding chunk: {e}")
    print(f"Finished! {doc_count} new chunks embedded and stored in Chroma DB.")

if __name__ == "__main__":
    process_json_files()
# Out:
# Processing 01 Dash Boards_extracted.json: 100%|██████████| 29/29 [00:00<00:00, 71048.37it/s]
# Processing 02 artical_extracted.json: 100%|██████████| 21/21 [00:00<00:00, 25990.08it/s]
# Processing 02 Monthly Progress Presentation_extracted.json: 100%|██████████| 514/514 [00:00<00:00, 116836.78it/s]
# Processing 0207 Qasr Rashwan Lot A_extracted.json: 100%|██████████| 5/5 [00:00<00:00, 18001.30it/s]
# Processing 0208 Qasr Rashwan Lot B_extracted.json: 100%|██████████| 3/3 [00:00<00:00, 17003.94it/s]
# Finished! 0 new chunks embedded and stored in Chroma DB.
