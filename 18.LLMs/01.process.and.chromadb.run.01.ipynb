# %%
import os
import json
import pdfplumber
import pytesseract
from PIL import Image
import pandas as pd
from datetime import datetime
from docx import Document
from pptx import Presentation
import warnings
import re

# Suppress specific CropBox warning from pdfplumber
import logging
logging.getLogger("pdfminer").setLevel(logging.ERROR)

class CropBoxFilter:
    def filter(self, record):
        return not (record.levelno == logging.WARNING and 'CropBox missing from /Page, defaulting to MediaBox' in record.getMessage())

logging.getLogger().addFilter(CropBoxFilter())

# Add tkinter for folder selection
def select_folder():
    import tkinter as tk
    from tkinter import filedialog
    root = tk.Tk()
    root.withdraw()
    folder_selected = filedialog.askdirectory(title='Select folder to process')
    root.destroy()
    return folder_selected

def extract_text_from_pdf(pdf_path):
    text = ""
    try:
        with pdfplumber.open(pdf_path) as pdf:
            for page in pdf.pages:
                page_text = page.extract_text()
                if page_text:
                    text += page_text + "\n"
    except Exception:
        pass
    return text.strip()

def ocr_pdf(pdf_path):
    text = ""
    try:
        with pdfplumber.open(pdf_path) as pdf:
            for page in pdf.pages:
                img = page.to_image(resolution=300).original
                pil_img = Image.fromarray(img)
                page_text = pytesseract.image_to_string(pil_img)
                if page_text:
                    text += page_text + "\n"
    except Exception:
        pass
    return text.strip()

def extract_text_from_excel(excel_path):
    text = ""
    try:
        xls = pd.ExcelFile(excel_path)
        for sheet_name in xls.sheet_names:
            df = pd.read_excel(xls, sheet_name=sheet_name, dtype=str)
            text += f"\n--- Sheet: {sheet_name} ---\n"
            text += df.fillna('').to_string(index=False, header=True)
    except Exception:
        pass
    return text.strip()

def extract_text_from_docx(docx_path):
    text = ""
    try:
        doc = Document(docx_path)
        for para in doc.paragraphs:
            text += para.text + "\n"
    except Exception:
        pass
    return text.strip()

def extract_text_from_pptx(pptx_path):
    text = ""
    try:
        prs = Presentation(pptx_path)
        for slide in prs.slides:
            for shape in slide.shapes:
                if hasattr(shape, "text"):
                    text += shape.text + "\n"
    except Exception:
        pass
    return text.strip()

def process_folder(folder_path, output_json_path):
    data = []
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            print(f"[INFO] Processing file: {file}")
            file_path = os.path.join(root, file)
            ext = file.lower().split('.')[-1]
            entry = {
                'file_name': file,
                'file_path': file_path,
                'type': ext,
                'extracted_at': datetime.now().isoformat(),
                'text': ''
            }
            reason = None
            if ext == 'pdf':
                text = extract_text_from_pdf(file_path)
                if not text:
                    text = ocr_pdf(file_path)
                    if text:
                        reason = 'extracted via OCR'
                    else:
                        reason = 'no text extracted (PDF and OCR failed)'
                else:
                    reason = 'extracted as text PDF'
                entry['text'] = text
            elif ext in ['xls', 'xlsx']:
                text = extract_text_from_excel(file_path)
                entry['text'] = text
                reason = 'extracted from Excel' if text else 'no text extracted (Excel)'
            elif ext == 'docx':
                text = extract_text_from_docx(file_path)
                entry['text'] = text
                reason = 'extracted from Word' if text else 'no text extracted (Word)'
            elif ext == 'pptx':
                text = extract_text_from_pptx(file_path)
                entry['text'] = text
                reason = 'extracted from PowerPoint' if text else 'no text extracted (PowerPoint)'
            else:
                print(f"[WARN] Skipped unsupported file type: {file}")
                continue
            if entry['text']:
                data.append(entry)
            else:
                print(f"[WARN] No text extracted from: {file} ({reason})")
    with open(output_json_path, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=2)
    print(f"Processed {len(data)} documents. Output saved to {output_json_path}")

if __name__ == "__main__":
    # New output directory outside the repo
    output_dir = r'C:/Users/Omar Essam2/OneDrive - Rowad Modern Engineering/x004 Data Science/03.rme.db/05.llm/extracted_json'
    os.makedirs(output_dir, exist_ok=True)
    folder = select_folder()
    if not folder:
        print("No folder selected. Exiting.")
    else:
        folder_name = os.path.basename(os.path.normpath(folder))
        output_json = os.path.join(output_dir, f"{folder_name}_extracted.json")
        process_folder(folder, output_json)
# Out:
# [INFO] Processing file: C&R sector peresentation (Milestones & Area of Concern) (Cut off 31.Jan.23).pptx
# [INFO] Processing file: C&R sector peresentation Over all (Cut off 31.Jan.23).rar
# [WARN] Skipped unsupported file type: C&R sector peresentation Over all (Cut off 31.Jan.23).rar
# [INFO] Processing file: New Giza Teaching Hospital Presentation #29 28-Jan-23.pdf
# [INFO] Processing file: New Giza Teaching Hospital Presentation #30 4-Feb-23.pdf
# [INFO] Processing file: Mivida PKG#189  Presentation   16-Jan-23.pptx
# [INFO] Processing file: Industrial Sector presentation.rar
# [WARN] Skipped unsupported file type: Industrial Sector presentation.rar
# [INFO] Processing file: EGAT - Weekly Report 77 till 24-Jan-23.pdf
# [INFO] Processing file: EGAT - Weekly Report 78 till 31-Jan-23.pdf
# [INFO] Processing file: RM - Weekly Report 77 till 24-Jan-23.pdf
# [INFO] Processing file: RM - Weekly Report 78 till 31-Jan-23.pdf
# [INFO] Processing file: Eipico 3 Monthly Presentation.pptx
# [INFO] Processing file: EIPICO Project Summary 29-01-2023.pptm
# [WARN] Skipped unsupported file type: EIPICO Project Summary 29-01-2023.pptm
# [INFO] Processing file: 02 - DPW January-2023 Monthly Report.pdf
# [INFO] Processing file: Eng. Adel's sector milestones 16 FEB. 2023.pptx
# [INFO] Processing file: R05 – Z04 – Presentation 05 Feb. 2023 @11.2.23.pptx
# [INFO] Processing file: Air Defense Project Presentation Jan-23.rar
# [WARN] Skipped unsupported file type: Air Defense Project Presentation Jan-23.rar
# [INFO] Processing file: Air Defense Project Presentation.pptx
# [INFO] Processing file: (The Open Channel) Presenstation.pptx
# [INFO] Processing file: Bridge Sector Some Balance Issues (2023.02.27).pdf
# [INFO] Processing file: Bridges Sector All Data (2023.01.30) Contracts.pdf
# [INFO] Processing file: Bridges Sector All Data (2023.01.30) Invoicing.pdf
# [INFO] Processing file: Bridges Sector All Data (2023.01.30) Target Q1-23.pdf
# [INFO] Processing file: Bridges Sector All Qty Reductions And Settlement Deductions (2023.02.27).pdf
# [INFO] Processing file: Bridges Sector Client Invoice And Cash In Status (2023.01.30).pdf
# [INFO] Processing file: 0122 Ring Road Maryotia Planning Report 2023.01.23.pdf
# [INFO] Processing file: 0122 Ring Road Maryotia Planning Report 2023.01.30.pdf
# [INFO] Processing file: 0122 Ring Road Maryotia Planning Report 2023.02.27.pdf
# [INFO] Processing file: 0122 Ring Road Planning Report 2023.01.02.pdf
# [INFO] Processing file: 0122 Ring Road Planning Report 2023.01.09.pdf
# [INFO] Processing file: 0122 Ring Road Planning Report 2023.01.16.pdf
# [INFO] Processing file: 0130 Kafr Shokr Planning Report 2023.01.02.pdf
# [INFO] Processing file: 0130 Kafr Shokr Planning Report 2023.01.09.pdf
# [INFO] Processing file: 0130 Kafr Shokr Planning Report 2023.01.16.pdf
# [INFO] Processing file: 0130 Kafr Shokr Planning Report 2023.01.23.pdf
# [INFO] Processing file: 0130 Kafr Shokr Planning Report 2023.01.30.pdf
# [INFO] Processing file: 0130 Kafr Shokr Planning Report 2023.02.27.pdf
# [INFO] Processing file: 0143 El Khtatba Planning Report 2023.01.02.pdf
# [INFO] Processing file: 0143 El Khtatba Planning Report 2023.01.09.pdf
# [INFO] Processing file: 0143 El Khtatba Planning Report 2023.01.16.pdf
# [INFO] Processing file: 0143 El Khtatba Planning Report 2023.01.23.pdf
# [INFO] Processing file: 0143 El Khtatba Planning Report 2023.01.30.pdf
# [INFO] Processing file: 0143 El Khtatba Planning Report 2023.02.27.pdf
# [INFO] Processing file: 0152 HST El Sokhna Planning Report 2023.01.02.pdf
# [INFO] Processing file: 0152 HST El Sokhna Planning Report 2023.01.09.pdf
# [INFO] Processing file: 0152 HST El Sokhna Planning Report 2023.01.16.pdf
# [INFO] Processing file: 0152 HST El Sokhna Planning Report 2023.01.23.pdf
# [INFO] Processing file: 0152 HST El Sokhna Planning Report 2023.01.30.pdf
# [INFO] Processing file: 0152 HST El Sokhna Planning Report 2023.02.27.pdf
# [INFO] Processing file: 0157 Abu Ghaleb Planning Report 2023.01.02.pdf
# [INFO] Processing file: 0157 Abu Ghaleb Planning Report 2023.01.09.pdf
# [INFO] Processing file: 0157 Abu Ghaleb Planning Report 2023.01.16.pdf
# [INFO] Processing file: 0157 Abu Ghaleb Planning Report 2023.01.23.pdf
# [INFO] Processing file: 0157 Abu Ghaleb Planning Report 2023.01.30.pdf
# [INFO] Processing file: 0157 Abu Ghaleb Planning Report 2023.02.27.pdf
# [INFO] Processing file: 0166 Alamein bridge Planning Report 2023.01.02.pdf
# [INFO] Processing file: 0166 Alamein bridge Planning Report 2023.01.09.pdf
# [INFO] Processing file: 0166 Alamein bridge Planning Report 2023.01.16.pdf
# [INFO] Processing file: 0166 Alamein bridge Planning Report 2023.01.23.pdf
# [INFO] Processing file: 0166 Alamein bridge Planning Report 2023.01.30.pdf
# [INFO] Processing file: 0166 Alamein bridge Planning Report 2023.02.27.pdf
# [INFO] Processing file: 0167 Wadi El Natron Planning Report 2023.01.02.pdf
# [INFO] Processing file: 0167 Wadi El Natron Planning Report 2023.01.09.pdf
# [INFO] Processing file: 0167 Wadi El Natron Planning Report 2023.01.16.pdf
# [INFO] Processing file: 0167 Wadi El Natron Planning Report 2023.01.23.pdf
# [INFO] Processing file: 0167 Wadi El Natron Planning Report 2023.01.30.pdf
# [INFO] Processing file: 0167 Wadi El Natron Planning Report 2023.02.27.pdf
# [INFO] Processing file: 0168 HST Mahager Planning Report 2023.01.02.pdf
# [INFO] Processing file: 0168 HST Mahager Planning Report 2023.01.09.pdf
# [INFO] Processing file: 0168 HST Mahager Planning Report 2023.01.16.pdf
# [INFO] Processing file: 0168 HST Mahager Planning Report 2023.01.23.pdf
# [INFO] Processing file: 0168 HST Mahager Planning Report 2023.01.30.pdf
# [INFO] Processing file: 0168 HST Mahager Planning Report 2023.02.27.pdf
# [INFO] Processing file: 0169 HST Culverts Planning Report 2023.01.02.pdf
# [INFO] Processing file: 0169 HST Culverts Planning Report 2023.01.09.pdf
# [INFO] Processing file: 0169 HST Culverts Planning Report 2023.01.16.pdf
# [INFO] Processing file: 0169 HST Culverts Planning Report 2023.01.23.pdf
# [INFO] Processing file: 0169 HST Culverts Planning Report 2023.01.30.pdf
# [INFO] Processing file: 0169 HST Culverts Planning Report 2023.02.27.pdf
# [INFO] Processing file: F-P-PC-01-11 Weekly Progress Presentation - GOV-02 District 16-Jan-23.pptx
# [INFO] Processing file: F-P-PC-01-11 Weekly Progress Presentation - GOV-02 District 23-Jan-23.pptx
# [INFO] Processing file: F-P-PC-01-11 Weekly Progress Presentation - GOV-02 District 30-Jan-23.pptx
# [INFO] Processing file: F-P-PC-01-11 Weekly Progress Presentation 18-01-2023.pdf
# [INFO] Processing file: F-P-PC-01-11 Weekly Progress Presentation 25-01-2023.pdf
# [INFO] Processing file: F-P-PC-01-11 Weekly Progress Presentation - Diplomatic District 12-Jan-23.pptx
# [INFO] Processing file: F-P-PC-01-11 Weekly Progress Presentation - Diplomatic District 30-Jan-23.pptx
# [INFO] Processing file: Exchange Building Presentation 01-02-2023.pptx
# [INFO] Processing file: Radamis City Weekly Report 22-01-2023.pdf
# [INFO] Processing file: C&R sector Milestones & Area of Concerns peresentation Over all (Cut off 28Feb.23).pptx
# [INFO] Processing file: C&R sector peresentation Over all (Cut off 28Feb.23).rar
# [WARN] Skipped unsupported file type: C&R sector peresentation Over all (Cut off 28Feb.23).rar
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: Sector Progress Presentation #04 - NGUH.pptx
# [INFO] Processing file: Sector Progress Presentation Feb.23- ZED Project PH 1B.pptx
# [INFO] Processing file: Sector Progress Presentation - Kattameya Creeks Feb23.pptx
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: Sector Progress Presentation Feb.23- ZED Project PH 2.pptx
# [INFO] Processing file: MIVIDA PKG#189 - Feb.23 Sector Presentation.rar
# [WARN] Skipped unsupported file type: MIVIDA PKG#189 - Feb.23 Sector Presentation.rar
# [INFO] Processing file: Sector Progress Presentation Feb.23- ZED Project Landscape.pptx
# [INFO] Processing file: Sector Progress Presentation - Urban K  Feb23.pptx
# [INFO] Processing file: Industrial Sector Dates 26-2-2023.pptx
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: EGAT - Weekly Report 79 till 07-Feb-23.pdf
# [INFO] Processing file: EGAT - Weekly Report 80 till 14-Feb-23.pdf
# [INFO] Processing file: Sokhna Port Expansion - Monthly Presentation + Calculation Sheets.rar
# [WARN] Skipped unsupported file type: Sokhna Port Expansion - Monthly Presentation + Calculation Sheets.rar
# [INFO] Processing file: SPX - Presentation March.pptx
# [INFO] Processing file: 1- Sokhna Port Expansion - Weekly Progress Report - Feb23- Week 1.pptx
# [INFO] Processing file: 2- SPX Project Summary 08.pptm
# [WARN] Skipped unsupported file type: 2- SPX Project Summary 08.pptm
# [INFO] Processing file: SPX-REV3.20230205.xer
# [WARN] Skipped unsupported file type: SPX-REV3.20230205.xer
# [INFO] Processing file: VOW - Feb-23.pdf
# [INFO] Processing file: Portsaid Grain Silos 05.03.2023 - rev00.pptx
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: EGAT Projects.pptx
# [INFO] Processing file: RM - Weekly Report 79 till 07-Feb-23.pdf
# [INFO] Processing file: RM - Weekly Report 80 till 14-Feb-23.pdf
# [INFO] Processing file: Eipico 3 Monthly Presentation - Feb-23.pptx
# [INFO] Processing file: EIPICO Project Summary 05-02-2023.pptm
# [WARN] Skipped unsupported file type: EIPICO Project Summary 05-02-2023.pptm
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: DPW Presentation March.pptx
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: Eng. Adel sector presentation FEB. 2023.pptx
# [INFO] Processing file: Sector Adel's milestones 18 MAR. 2023.pptx
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: R05 – Z04 – Presentation 05 Feb. 2023 @11.2.23.pptx
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: Weekly Progress Report (The Open Channel) 04-Feb-2023.pptx
# [INFO] Processing file: 0000 Bridges Sector Planning Report 2023.03.13.pdf
# [INFO] Processing file: 0122 Ring Road Maryotia Planning Report 2023.02.06.pdf
# [INFO] Processing file: 0122 Ring Road Maryotia Planning Report 2023.02.13.pdf
# [INFO] Processing file: 0122 Ring Road Maryotia Planning Report 2023.03.13.pdf
# [INFO] Processing file: 0130 Kafr Shokr Planning Report 2023.02.06.pdf
# [INFO] Processing file: 0130 Kafr Shokr Planning Report 2023.02.13.pdf
# [INFO] Processing file: 0130 Kafr Shokr Planning Report 2023.03.13.pdf
# [INFO] Processing file: 0143 El Khtatba Planning Report 2023.01.02.pdf
# [INFO] Processing file: 0143 El Khtatba Planning Report 2023.02.06.pdf
# [INFO] Processing file: 0143 El Khtatba Planning Report 2023.02.13.pdf
# [INFO] Processing file: 0143 El Khtatba Planning Report 2023.03.13.pdf
# [INFO] Processing file: 0152 HST El Sokhna Planning Report 2023.02.06.pdf
# [INFO] Processing file: 0152 HST El Sokhna Planning Report 2023.02.13.pdf
# [INFO] Processing file: 0152 HST El Sokhna Planning Report 2023.03.13.pdf
# [INFO] Processing file: 0157 Abu Ghaleb Planning Report 2023.02.06.pdf
# [INFO] Processing file: 0157 Abu Ghaleb Planning Report 2023.02.13.pdf
# [INFO] Processing file: 0157 Abu Ghaleb Planning Report 2023.03.13.pdf
# [INFO] Processing file: 0166 Alamein bridge Planning Report 2023.02.06.pdf
# [INFO] Processing file: 0166 Alamein bridge Planning Report 2023.02.13.pdf
# [INFO] Processing file: 0166 Alamein bridge Planning Report 2023.03.13.pdf
# [INFO] Processing file: 0167 Wadi El Natron Planning Report 2023.02.06.pdf
# [INFO] Processing file: 0167 Wadi El Natron Planning Report 2023.02.13.pdf
# [INFO] Processing file: 0167 Wadi El Natron Planning Report 2023.03.13.pdf
# [INFO] Processing file: 0168 HST Mahager Planning Report 2023.02.06.pdf
# [INFO] Processing file: 0168 HST Mahager Planning Report 2023.02.13.pdf
# [INFO] Processing file: 0168 HST Mahager Planning Report 2023.03.13.pdf
# [INFO] Processing file: 0169 HST Culverts Planning Report 2023.02.06.pdf
# [INFO] Processing file: 0169 HST Culverts Planning Report 2023.03.13.pdf
# [INFO] Processing file: Bridges Sector All Data (2022.12.30) Contracts.pdf
# [INFO] Processing file: Bridges Sector All Data (2022.12.30) Invoicing.pdf
# [INFO] Processing file: Bridges Sector All Data (2022.12.30) Revised BOQs.pdf
# [INFO] Processing file: Bridges Sector All Data (2022.12.30) Target Q1-23 Invoicing.pdf
# [INFO] Processing file: Bridges Sector All Data (2022.12.30) Target Q1-23.pdf
# [INFO] Processing file: Bridges Sector All Data (2023.01.30) Cash In.pdf
# [INFO] Processing file: Bridges Sector All Data (2023.01.30) Cash Out.pdf
# [INFO] Processing file: Bridges Sector All Data (2023.01.30) Contracts.pdf
# [INFO] Processing file: Bridges Sector All Data (2023.01.30) Indirect.pdf
# [INFO] Processing file: Bridges Sector All Data (2023.01.30) Invoicing.pdf
# [INFO] Processing file: Bridges Sector All Data (2023.01.30) Target.pdf
# [INFO] Processing file: Bridges Sector All Qty Reductions And Settlement Deductions (All).pdf
# [INFO] Processing file: Bridges Sector All Qty Reductions And Settlement Deductions (Unresolved).pdf
# [INFO] Processing file: Bridges Sector Client Invoice And Cash In Status (2023.01.30).pdf
# [INFO] Processing file: Bridges Sector Planning Report 2023.02.06.pdf
# [INFO] Processing file: GOVERNMENTAL SECTOR PRESENTATION_FEB_2023.pptx
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: F-P-PC-01-11 Weekly Progress Presentation - GOV-02 District 1-Mar-23.pptx
# [INFO] Processing file: F-P-PC-01-11 Weekly Progress Presentation - GOV-02 District 14-Feb-23.pptx
# [INFO] Processing file: F-P-PC-01-11 Weekly Progress Presentation - GOV-02 District 21-Feb-23.pptx
# [INFO] Processing file: F-P-PC-01-11 Weekly Progress Presentation - GOV-02 District 6-Feb-23.pptx
# [INFO] Processing file: GOV-02 Area of Concern  Rev 00 @ 21-3-2023.xlsx
# [WARN] No text extracted from: GOV-02 Area of Concern  Rev 00 @ 21-3-2023.xlsx (no text extracted (Excel))
# [INFO] Processing file: GOV02 Project - FEB.23_Sector Presentation (002).pptx
# [INFO] Processing file: Area of Concern  Rev 00 @ 28-2-2023.pdf
# [INFO] Processing file: Area of Concern  Rev 00 @ 28-2-2023.xlsx
# [WARN] No text extracted from: Area of Concern  Rev 00 @ 28-2-2023.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-PC-01-11 Weekly Progress Presentation 01-03-2023.pdf
# [INFO] Processing file: F-P-PC-01-11 Weekly Progress Presentation 01-03-2023.pptx
# [INFO] Processing file: F-P-PC-01-11 Weekly Progress Presentation 22-02-2023.pdf
# [INFO] Processing file: F-P-PC-01-11 Weekly Progress Presentation 22-02-2023.pptx
# [INFO] Processing file: NMU Project - Feb.23_Sector Presentation.pptx
# [INFO] Processing file: Diplo Area of Concern  Rev 00 @ 21-3-2023.xlsx
# [WARN] No text extracted from: Diplo Area of Concern  Rev 00 @ 21-3-2023.xlsx (no text extracted (Excel))
# [INFO] Processing file: DIPLOMATIC DISTRICT Project - FEB.23_Sector Presentation.pptx
# [INFO] Processing file: F-P-PC-01-11 Weekly Progress Presentation - Diplomatic District 1-Mar-23.pptx
# [INFO] Processing file: F-P-PC-01-11 Weekly Progress Presentation - Diplomatic District 14-Feb-23.pptx
# [INFO] Processing file: F-P-PC-01-11 Weekly Progress Presentation - Diplomatic District 21-Feb-23.pptx
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: Under Railway Tunnel.pptx
# [INFO] Processing file: RME Presentation.pdf
# [INFO] Processing file: C&R sector Milestones & Area of Concerns peresentation Over all (Cut off 31.Mar.23).pptx
# [INFO] Processing file: C&R sector peresentation Over all (Cut off Mar.23).pptx
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: NGUH -Sector Progress Presentation #05 - Rev.00.pptx
# [INFO] Processing file: Sector Progress Presentation Mar.23- ZED Project PH 1B.pptx
# [INFO] Processing file: Sector Progress Presentation Mar.23- ZED Project PH 2.pptx
# [INFO] Processing file: MIVIDA PKG#189 - MAR.23 Sector Presentation - final.pptx
# [INFO] Processing file: Sector Progress Presentation Mar.23- ZED Project Landscape.pptx
# [INFO] Processing file: Sector Progress Presentation - Urban K  Mar-23.pptx
# [INFO] Processing file: Eipico 3 Monthly Presentation - Apr.23.pptx
# [INFO] Processing file: Eng. Adel sector presentation Mar. 2023.pptx
# [INFO] Processing file: GOVERNMENTAL SECTOR PRESENTATION_MARCH_2023.pptx
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: C&R sector peresentation Over all (Cut off April.23).pptx
# [INFO] Processing file: NGUH -Sector Progress Presentation #06 - Rev.00.pptx
# [INFO] Processing file: Sector Progress Presentation Apr.23- ZED Project PH 1B.pptx
# [INFO] Processing file: Sector Progress Presentation - Kattameya Creeks April.23.pptx
# [INFO] Processing file: Sector Progress Presentation Apr.23- ZED Project PH 2.pptx
# [INFO] Processing file: MIVIDA PKG#189 - Apr.23 Sector Presentation - final.pptx
# [INFO] Processing file: Sector Progress Presentation - Urban K  Apr-23.pptx
# [INFO] Processing file: Eipico 3 Monthly Presentation - May.23.pptx
# [INFO] Processing file: Eng. Adel sector presentation Apr. 2023.pptx
# [INFO] Processing file: Eng. Adel sector presentation Apr. 2023.xlsx
# [WARN] No text extracted from: Eng. Adel sector presentation Apr. 2023.xlsx (no text extracted (Excel))
# [INFO] Processing file: R05 @5-7-23.pptx
# [INFO] Processing file: 04 - GOVERNMENTAL SECTOR PRESENTATION_APRIL_2023 (002).pptx
# [INFO] Processing file: C&R sector Dashboard Over all (Cut off May.23).pdf
# [INFO] Processing file: NGUH -Sector Progress Presentation #07 - Rev.00.pptx
# [INFO] Processing file: Sector Progress Presentation May.23- ZED Project PH 1B.pptx
# [INFO] Processing file: Creek project sector peresentation Over all (Cut off May.23).pptx
# [INFO] Processing file: Sector Progress Presentation May.23- ZED Project PH 2.pptx
# [INFO] Processing file: MIVIDA PKG#189 - May.23 Sector Presentation - final.pptx
# [INFO] Processing file: Sector Progress Presentation May.23- ZED Project Landscape.pptx
# [INFO] Processing file: Sector Progress Presentation - Urban K  May-23.pptx
# [INFO] Processing file: Eng. Adel sector presentation May 2023.pptx
# [INFO] Processing file: C&R sector Dashboard Over all (Cut off Jun.23).pdf
# [INFO] Processing file: NGUH -Sector Progress Presentation #08 - Rev.03.pptx
# [INFO] Processing file: Sector Progress Presentation June.23- ZED Project PH 1B.pptx
# [INFO] Processing file: Creek project sector peresentation Over all (Cut off Jun.23).pptx
# [INFO] Processing file: Sector Progress Presentation June.23- ZED Project PH 2.pptx
# [INFO] Processing file: MIVIDA PKG#189 - June.23 Sector Presentation - final.pptx
# [INFO] Processing file: Sector Progress Presentation June.23- ZED Project Landscape.pptx
# [INFO] Processing file: Sector Progress Presentation - Urban K  June-23.pptx
# [INFO] Processing file: NGUH -Sector Progress Presentation #09 - Rev.00.pptx
# [INFO] Processing file: Sector Progress Presentation July.23- ZED Project PH 1B.pptx
# [INFO] Processing file: Creek project sector peresentation Over all (Cut off Jul.23).pptx
# [INFO] Processing file: Sector Progress Presentation July.23- ZED Project PH 2.pptx
# [INFO] Processing file: MIVIDA PKG#189 - July.23 Sector Presentation - final-Rev.02.pptx
# [INFO] Processing file: Sector Progress Presentation July.23- ZED Project Landscape.pptx
# [INFO] Processing file: Sector Progress Presentation - Urban K  July-23.pptx
# [INFO] Processing file: 07 - INFRASTRUCTURE SECTOR PRESENTATION_JULY_2023.pptx
# [INFO] Processing file: C&R sector Peresntation Over all (Cut off Aug.23).rar
# [WARN] Skipped unsupported file type: C&R sector Peresntation Over all (Cut off Aug.23).rar
# [INFO] Processing file: NGUH -Sector Progress Presentation #10 -Aug.23- Rev.00.pptx
# [INFO] Processing file: Sector Progress Presentation Aug.23- ZED Project PH 1B.pptx
# [INFO] Processing file: Creek project sector peresentation Over all (Cut off Aug23).pptx
# [INFO] Processing file: Sector Progress Presentation Aug.23- ZED Project PH 2.pptx
# [INFO] Processing file: MIVIDA PKG#189 - Aug.23 Sector Presentation - final-Rev.02.pptx
# [INFO] Processing file: Sector Progress Presentation Aug23- ZED Project Landscape.pptx
# [INFO] Processing file: Sector Progress Presentation - Urban K  Aug-23.pptx
# [INFO] Processing file: SPX - Presentation Aug2023.pptx
# [INFO] Processing file: MDF Monthly Presentation - August.23.pptx
# [INFO] Processing file: Portsaid Grain Silos 07.09.2023 - rev00.pptx
# [INFO] Processing file: Eipico 3 Monthly Presentation - August.23.pptx
# [INFO] Processing file: DPW - Aug Presentation.pptx
# [INFO] Processing file: Eng. Adel sector presentation AUG-23.pptx
# [INFO] Processing file: 08 - INFRASTRUCTURE SECTOR PRESENTATION_AUG_2023.pptx
# [INFO] Processing file: 04 - GOVERNMENTAL SECTOR PRESENTATION_August_2023 (001).pptx
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: NGUH -Sector Progress Presentation #11 - Rev.01.pptx
# [INFO] Processing file: Sector Progress Presentation Sep.23- ZED Project PH 1B.pptx
# [INFO] Processing file: Creek project sector peresentation Over all (Cut off Sep23).pptx
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: MIVIDA PKG#189 - Sep.23 Sector Presentation - final-Rev.02.pptx
# [INFO] Processing file: Sector Progress Presentation - Urban K  Sep-23.pptx
# [INFO] Processing file: R05 Sep.pptx
# [INFO] Processing file: 04 - GOVERNMENTAL SECTOR PRESENTATION_Sep_2023 Rev 00.pptx
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: NGUH -Sector Progress Presentation #12 - Rev.00.pptx
# [INFO] Processing file: Sector Progress Presentation Oct.23- ZED Project PH 1B.pptx
# [INFO] Processing file: Creek project sector peresentation Over all (Cut off Oct23).pptx
# [INFO] Processing file: Sector Progress Presentation Oct.23- ZED Project PH 2.pptx
# [INFO] Processing file: MIVIDA PKG#189 - Oct.23 Sector Presentation - final-Rev.02.pptx
# [INFO] Processing file: Sector Progress Presentation - Urban K  Oct-23.pptx
# [INFO] Processing file: INFRASTRUCTURE SECTOR PRESENTATION_OCT_2023 - GOV02 & Diplomatic District.pptx
# [INFO] Processing file: GOVERNMENTAL SECTOR PRESENTATION_Oct_2023.pptx
# [INFO] Processing file: NGUH -Sector Progress Presentation #13 - Rev.00.pptx
# [INFO] Processing file: Sector Progress Presentation Dec.23- ZED Project PH 1B.pptx
# [INFO] Processing file: Creek project sector peresentation Over all (Cut off Nov23).pptx
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: Sector Progress Presentation Dec.23- ZED Project PH 2.pptx
# [INFO] Processing file: MIVIDA PKG#189 - Nov.23 Sector Presentation - final-Rev.02.pptx
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: Sector Progress Presentation Dec.23- ZED Project Landscape.pptx
# [INFO] Processing file: Sector Progress Presentation - Urban K  Nov-23.pptx
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: GOVERNMENTAL SECTOR PRESENTATION_Nov_2023.pptx
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: Fayoum Infra Sector Monthly Presnetation.pptx
# [INFO] Processing file: SPX - Presentation December 2023.pptx
# [INFO] Processing file: Portsaid Grain Silos 14.12.2023 - rev00.ppt
# [WARN] Skipped unsupported file type: Portsaid Grain Silos 14.12.2023 - rev00.ppt
# [INFO] Processing file: 3-Peresntation 12-12-2023.ppt
# [WARN] Skipped unsupported file type: 3-Peresntation 12-12-2023.ppt
# [INFO] Processing file: 4-EGAT Projects  12-12-2023.pptx
# [INFO] Processing file: Eipico 3 Monthly Presentation - Nov.23.pptx
# [INFO] Processing file: DPW Presentation December.pptx
# [INFO] Processing file: Monthly Presentation.pptx
# [INFO] Processing file: EGCK_Presentation#01_231031_R00.pptx
# [INFO] Processing file: EGCK_Presentation#02_231115_R00.pptx
# [INFO] Processing file: EGCK_Presentation#03_231130_R00.pptx
# [INFO] Processing file: EGCK_Presentation#06_311223_R00.pptx
# [INFO] Processing file: Port Said Silos Presentation عربي.pptx
# [INFO] Processing file: Infra Sector Monthly Presentation.pptx
# [INFO] Processing file: GOVERNMENTAL SECTOR PRESENTATION_Dec_2023.pptx
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: GOVERNMENTAL SECTOR PRESENTATION_Dec_2023.pptx
# [INFO] Processing file: Air Defense College Monthly Presentation Nov 23.rar
# [WARN] Skipped unsupported file type: Air Defense College Monthly Presentation Nov 23.rar
# [INFO] Processing file: Open Cannel Progress Presentation-(DEC-23).pptx
# [INFO] Processing file: NGUH -Sector Progress Presentation #14 - Rev.00.pptx
# [INFO] Processing file: Sector Progress Presentation Jan.24- ZED Project PH 1B.pptx
# [INFO] Processing file: Creek project sector peresentation Over all (Cut off Dec-23).pptx
# [INFO] Processing file: Sector Progress Presentation Jan.24- ZED Project PH 2.pptx
# [INFO] Processing file: MIVIDA PKG#189 - Dec.23 Sector Presentation.pptx
# [INFO] Processing file: Sector Progress Presentation Jan.24- ZED Project Landscape.pptx
# [INFO] Processing file: Sector Progress Presentation - Urban K Dec-23.pptx
# [INFO] Processing file: Sector Progress Presentation - Hosh Eissa Hospital  Jan-24.pptx
# [INFO] Processing file: SPX - Presentation January 2024.pptx
# [INFO] Processing file: MDF Monthly Presentation - December 23.pptx
# [INFO] Processing file: Portsaid Grain Silos 08.01.2024 - rev00.pdf
# [INFO] Processing file: 5-Suez Peresntation 10-1-2024.pdf
# [INFO] Processing file: Eipico 3 Monthly Presentation - Dec.23.pptx
# [INFO] Processing file: DPW Presentation January.pptx
# [INFO] Processing file: EGCK_Presentation#04_231214_R00.pptx
# [INFO] Processing file: EGCK_Presentation#05_231223_R00.pptx
# [INFO] Processing file: EGCK_Presentation#06_311223_R00.pptx
# [INFO] Processing file: Radamis Monthly Report 13-Feb.-24 - rev0.pdf
# [INFO] Processing file: Jawhara Palace Progress Presentation Cut Date 31-Jan-2024.pptx
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: Air Defense College Monthly Presentation Jan 24.rar
# [WARN] Skipped unsupported file type: Air Defense College Monthly Presentation Jan 24.rar
# [INFO] Processing file: Open Cannel Progress Presentation-(JAN-24).pptx
# [INFO] Processing file: R05 Feb 2024.pptx
# [INFO] Processing file: Bridges Sector Control Dashboard (2024.01.29).pbix
# [WARN] Skipped unsupported file type: Bridges Sector Control Dashboard (2024.01.29).pbix
# [INFO] Processing file: Bridges Sector Control Dashboard (2024.01.29).pdf
# [INFO] Processing file: Bridges Sector Control Presentation (2024.02.05).pbix
# [WARN] Skipped unsupported file type: Bridges Sector Control Presentation (2024.02.05).pbix
# [INFO] Processing file: Bridges Sector Control Presentation (2024.02.05).pdf
# [INFO] Processing file: Sohag Station HSR Project Progress Presentation Jan-2024.pptx
# [INFO] Processing file: Infra Sector Monthly Presentation Finaal- Jan 2024.pptx
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: GOVERNMENTAL SECTOR PRESENTATION_Jan_2024 REV01.pptx
# [INFO] Processing file: MDF Monthly Presentation - Jan 24.pptx
# [INFO] Processing file: Portsaid Grain Silos 08.02.2024 - rev000.pptx
# [INFO] Processing file: Eipico 3 Monthly Presentation - jan.2024.pptx
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: 6-Peresntation 8-2-2024.pdf
# [INFO] Processing file: NGUH -Sector Progress Presentation #15 - Rev.00.pptx
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: Sector Progress Presentation Feb.24- ZED Project PH 1B.pptx
# [INFO] Processing file: Creek project sector peresentation Over all (Cut off Jan-24).pptx
# [INFO] Processing file: Sector Progress Presentation Feb.24- ZED Project PH 2.pptx
# [INFO] Processing file: MIVIDA PKG#189 - jan24 Sector Presentation.pptx
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: Sector Progress Presentation Feb.24- ZED Project Landscape.pptx
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: Sector Progress Presentation - Urban K Jan-24.pptx
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: Sector Progress Presentation - Hosh Eissa Hospital 06-Feb-24.pptx
# [INFO] Processing file: Jawhara Palace Progress Presentation Cut Date 29-2-2024.pptx
# [INFO] Processing file: Open Cannel Progress Presentation-([FEB-24).pptx
# [INFO] Processing file: 1. project progress DB Bridges Sector.pbix
# [WARN] Skipped unsupported file type: 1. project progress DB Bridges Sector.pbix
# [INFO] Processing file: 1. project progress DB Bridges Sector.pdf
# [INFO] Processing file: Bridges Sector Control Presentation (2024.02.05).pbix
# [WARN] Skipped unsupported file type: Bridges Sector Control Presentation (2024.02.05).pbix
# [INFO] Processing file: Bridges Sector Control Presentation (2024.02.05).pdf
# [INFO] Processing file: Sohag Station HSR Project Progress Presentation Feb - 2024.pptx
# [INFO] Processing file: Infra Sector Monthly Presentation Feb-2024.pptx
# [INFO] Processing file: GOVERNMENTAL SECTOR PRESENTATION_feb_2024 REV00.pptx
# [INFO] Processing file: DPW Presentation March.pptx
# [INFO] Processing file: Eipico 3 Monthly Presentation - Feb.2024.pptx
# [INFO] Processing file: SPX - Presentation March 2024.pptx
# [INFO] Processing file: Suez-Presentation 8-3-2024.pdf
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: Portsaid Grain Silos 10.03.2024 Rev00.pptx
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: NGUH -Sector Progress Presentation #16 - Rev.00.pptx
# [INFO] Processing file: Sector Progress Presentation Feb.24- ZED Project PH 1B.pptx
# [INFO] Processing file: Creek project sector peresentation Over all (Cut off Feb-24).pptx
# [INFO] Processing file: Sector Progress Presentation Feb.24- ZED Project PH 2.pptx
# [INFO] Processing file: MIVIDA PKG#189 - Feb.24 Sector Presentation.pptx
# [INFO] Processing file: Sector Progress Presentation Feb.24- ZED Project Landscape.pptx
# [INFO] Processing file: Sector Progress Presentation - Urban K Feb-24 (002).pptx
# [INFO] Processing file: 2024-03-Sector Progress Presentation - Hosh Eissa Hospital.pptx
# [INFO] Processing file: Air Defense College Monthly Presentation Mar 24.rar
# [WARN] Skipped unsupported file type: Air Defense College Monthly Presentation Mar 24.rar
# [INFO] Processing file: Open Cannel Progress Presentation-(MAR-24).pptx
# [INFO] Processing file: R-05 April 2024 Presentation.pptx
# [INFO] Processing file: Sohag Station HSR Project Progress Presentation Mar- 2024.pptx
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: 01- Jawhara Palace Progress Presentation Cut Date 31-3-2024.pptx
# [INFO] Processing file: Engineering Status.pbix
# [WARN] Skipped unsupported file type: Engineering Status.pbix
# [INFO] Processing file: Procurment Follow up Dashboard-Cut Date 27-Mar-2024.pbix
# [WARN] Skipped unsupported file type: Procurment Follow up Dashboard-Cut Date 27-Mar-2024.pbix
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: Infra Sector Monthly Presentation Mar-2024.pptx
# [INFO] Processing file: GOVERNMENTAL SECTOR PRESENTATION_Mar_2024 REV00.pptx
# [INFO] Processing file: DPW Presentation March.pptx
# [INFO] Processing file: Eipico 3 Monthly Presentation - mar.2024.pptx
# [INFO] Processing file: Port Said Grain Silos 04.04.2024 Meeting Presentation .pdf
# [INFO] Processing file: SPX - Presentation March 2024.pptx
# [INFO] Processing file: Suez Peresntation Mar-2024.pdf
# [INFO] Processing file: NGUH -Sector Progress Presentation #17 - Rev.00.pptx
# [INFO] Processing file: Sector Progress Presentation Mar.24- ZED Project PH 1B.pptx
# [INFO] Processing file: Creek project sector peresentation Over all (Cut off Mar-24).pptx
# [INFO] Processing file: Sector Progress Presentation Mar.24- ZED Project PH 2.pptx
# [INFO] Processing file: MIVIDA PKG#189 - Mar.24 Sector Presentation.pptx
# [INFO] Processing file: Sector Progress Presentation Mar.24- ZED Project Landscape.pptx
# [INFO] Processing file: Hosh Eissa Sector Progress Presentation - March-24.pptx
# [INFO] Processing file: Air Defense College Monthly Presentation Apr 24.pptx
# [INFO] Processing file: Open Cannel Progress Presentation-(APR-24).pptx
# [INFO] Processing file: Sohag Station HSR Project Progress Presentation May- 2024.pptx
# [INFO] Processing file: 01- Engineering Status.pbix
# [WARN] Skipped unsupported file type: 01- Engineering Status.pbix
# [INFO] Processing file: 02- Jawhara Palace Progress Presentation Cut Date 30-4-2024.pptx
# [INFO] Processing file: Procurment Follow up Dashboard.pbix
# [WARN] Skipped unsupported file type: Procurment Follow up Dashboard.pbix
# [INFO] Processing file: Infra Sector Monthly Presentation Apr-2024.pptx
# [INFO] Processing file: GOVERNMENTAL SECTOR PRESENTATION_Apr_2024 REV00.pptx
# [INFO] Processing file: 9- Suez Projects Peresntation.pdf
# [INFO] Processing file: Eipico 3 Monthly Presentation - Apr .2024.pptx
# [INFO] Processing file: MDF Monthly Presentation - Apr 2024.pdf
# [INFO] Processing file: Portsaid Grain Silos 11.05.2024 Rev00.ppt
# [WARN] Skipped unsupported file type: Portsaid Grain Silos 11.05.2024 Rev00.ppt
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: 2024-05-Sector Progress Presentation - Hosh Eissa Hospital.pptx
# [INFO] Processing file: Creek project sector peresentation Over all (Cut off Apr-24).pptx
# [INFO] Processing file: MIVIDA PKG#189 - Apr.24 Sector Presentation.pptx
# [INFO] Processing file: NGUH -Sector Progress Presentation #18 - Rev.00.pptx
# [INFO] Processing file: Sector Progress Presentation April.24- ZED Project Landscape.pptx
# [INFO] Processing file: Sector Progress Presentation April.24- ZED Project PH 1B.pptx
# [INFO] Processing file: Sector Progress Presentation April.24- ZED Project PH 2.pptx
# [INFO] Processing file: Urbn K project-Sector Progress Presentation - April.24.pptx
# [INFO] Processing file: Open Cannel Progress Presentation-(MAY-24).pptx
# [INFO] Processing file: R-05 June 2024 Presentation.pptx
# [INFO] Processing file: Infra Sector Monthly Presentation May-2024.pptx
# [INFO] Processing file: GOVERNMENTAL SECTOR PRESENTATION_May_2024 REV00.pptx
# [INFO] Processing file: Eipico 3 Monthly Presentation - May.2024.pptx
# [INFO] Processing file: MDF Monthly Presentation - May 2024.pdf
# [INFO] Processing file: Portsaid Grain Silos 08.06.2024 Rev00.pdf
# [INFO] Processing file: Portsaid Grain Silos 08.06.2024 Rev00.ppt
# [WARN] Skipped unsupported file type: Portsaid Grain Silos 08.06.2024 Rev00.ppt
# [INFO] Processing file: Suez Projects Peresntation 8-Jun-2024.pdf
# [INFO] Processing file: 2024-06-Sector Progress Presentation - Hosh Eissa Hospital-01.pptx
# [INFO] Processing file: MIVIDA PKG#189 - May.24 Sector Presentation.pptx
# [INFO] Processing file: NGUH -Sector Progress Presentation #19 - Rev.00.pptx
# [INFO] Processing file: Sector Progress Presentation May.24- ZED Project PH 2.pptx
# [INFO] Processing file: Open Cannel Progress Presentation-(JUN-24).pptx
# [INFO] Processing file: R-05 Jul 2024 Presentation.pptx
# [INFO] Processing file: 02- Jawhara Palace Progress Presentation Cut Date 30-6-2024.pptx
# [INFO] Processing file: ABOSHANAB-PROGRESS PRESENTATION 14-7-2024 - ....pptm
# [WARN] Skipped unsupported file type: ABOSHANAB-PROGRESS PRESENTATION 14-7-2024 - ....pptm
# [INFO] Processing file: Infra Sector Monthly Presentation June-2024.pptx
# [INFO] Processing file: Lot-A Internal Weekly Progress Presentation (2) (002).pptm
# [WARN] Skipped unsupported file type: Lot-A Internal Weekly Progress Presentation (2) (002).pptm
# [INFO] Processing file: Lot-B Internal Weekly Progress Presentation 14-07-2024.pptm
# [WARN] Skipped unsupported file type: Lot-B Internal Weekly Progress Presentation 14-07-2024.pptm
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: 11-Suez Presentation 7 Jul 24.pdf
# [INFO] Processing file: Damietta Monthly Progress Presentation - 10072024.pptx
# [INFO] Processing file: Eipico 3 Monthly Presentation - Jun.2024.pptx
# [INFO] Processing file: MDF Monthly Pressentation June 2024.pdf
# [INFO] Processing file: Portsaid Grain Silos 09.07.2024 Rev00.pdf
# [INFO] Processing file: 2024-07-Sector Progress Presentation - Hosh Eissa Hospital-01.pptx
# [INFO] Processing file: Creek project sector peresentation Over all (Cut off Jun-24).pptx
# [INFO] Processing file: MIVIDA PKG#189 - Jun.24 Sector Presentation2.pptx
# [INFO] Processing file: NGUH -Sector Progress Presentation #20 - Rev.00.pptx
# [INFO] Processing file: Sector Progress Presentation - Urban K Jun-24.pptx
# [INFO] Processing file: Sector Progress Presentation Jun.24- ZED Project PH 2.pptx
# [INFO] Processing file: Open Cannel Progress Presentation-(JUL-24).pptx
# [INFO] Processing file: R-05 August 2024 Presentation.pptx
# [INFO] Processing file: 2024-08-Sector Progress Presentation - Hosh Eissa Hospital-01.pptx
# [INFO] Processing file: Creek project sector peresentation Over all (Cut off Jul-24).pptx
# [INFO] Processing file: MIVIDA PKG#189 - Jul.24 Sector Presentation.pptx
# [INFO] Processing file: NGUH -Sector Progress Presentation #21 - Rev.00.pptx
# [INFO] Processing file: Sector Progress Presentation - Urban K Jul-24.pptx
# [INFO] Processing file: Sector Progress Presentation July.24- ZED Project PH 2.pptx
# [INFO] Processing file: Sohag HSR Progress Presentation Jul 2024.pptx
# [INFO] Processing file: wady elnatroon monthly progress presentation (2024.07).pdf
# [INFO] Processing file: wady elnatroon monthly progress presentation (2024.07).pptx
# [INFO] Processing file: Infra Sector Monthly Presentation July-2024.pptx
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: GOVERNMENTAL SECTOR PRESENTATION_July_2024 REV00.pptx
# [INFO] Processing file: 01 -DCT Monthly Progress Presentation -Aug 24 internal.pptx
# [INFO] Processing file: Epico  presentation 5-Aug-24.pdf
# [INFO] Processing file: MDF Factory - Industrial Sector - Monthly Presentation July 2024.pdf
# [INFO] Processing file: Portsaid Grain Silos 07.08.2024 Rev00.pdf
# [INFO] Processing file: Portsaid Grain Silos 07.08.2024 Rev00.ppt
# [WARN] Skipped unsupported file type: Portsaid Grain Silos 07.08.2024 Rev00.ppt
# [INFO] Processing file: Suez 13- Presentation 7-Aug-2024.pdf
# [INFO] Processing file: Open Cannel Progress Presentation-(AUG-24).pptx
# [INFO] Processing file: Sohag HSR Progress Presentation Aug 2024.pptx
# [INFO] Processing file: Infra Sector Monthly Presentation Aug-2024 (002) (1).pptx
# [INFO] Processing file: GOVERNMENTAL SECTOR PRESENTATION_August_2024 REV00.pptx
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: 14- Suez Presentation End of Aug-2024.pptx
# [INFO] Processing file: Damietta Monthly Progress Presentation -Aug 24 internal (002).pptx
# [INFO] Processing file: MDF Factory - Industrial Sector - Monthly Presentation Aug.2024...pdf
# [INFO] Processing file: Port_Said_Grain_Silos_Remaining_Activity_Presentation_.pdf
# [INFO] Processing file: Port_Said_Grain_Silos_Remaining_Activity_Presentation_.pptx
# [INFO] Processing file: Silos_Remaining_Activity.xlsx
# [WARN] No text extracted from: Silos_Remaining_Activity.xlsx (no text extracted (Excel))
# [INFO] Processing file: 2024-09-Sector Progress Presentation - Hosh Eissa Hospital-00.pptx
# [INFO] Processing file: Creek project sector peresentation Over all (Cut off Aug-24).pptx
# [INFO] Processing file: MIVIDA PKG#189 - Aug.24 Sector Presentation.pptx
# [INFO] Processing file: Sector Progress Presentation - Urban K Aug-24.pptx
# [INFO] Processing file: Sector Progress Presentation Aug.24- ZED Project PH 2.pptx
# [INFO] Processing file: R-05 October 2024 Presentation.pptx
# [INFO] Processing file: Sohag HSR Progress Presentation Sep-2024.pptx
# [INFO] Processing file: Sohag Presentation rev 2.pdf
# [INFO] Processing file: Infra Sector Monthly Presentation Sep-2024.pptx
# [INFO] Processing file: Damietta Presentation Sep 24.pdf
# [INFO] Processing file: MDF Factory - Industrial Sector - Monthly Presentation Sep.2024.pdf
# [INFO] Processing file: Suez Presentation Sep 24.pdf
# [INFO] Processing file: C&R Sector Sep.24 .rar
# [WARN] Skipped unsupported file type: C&R Sector Sep.24 .rar
# [INFO] Processing file: Open Cannel Progress Presentation-(OCT-24).pptx
# [INFO] Processing file: R-05 November 2024 Presentation.pptx
# [INFO] Processing file: Bridges Sector Control Presentation (2024.11.17).pdf
# [INFO] Processing file: Bridges Sector Control Presentation.pbix
# [WARN] Skipped unsupported file type: Bridges Sector Control Presentation.pbix
# [INFO] Processing file: F-P-PC-01-17 wady elnatroon monthly progress presentation(2024.11.30) .pptx
# [INFO] Processing file: Infra Sector Monthly Presentation Oct-2024.pptx
# [INFO] Processing file: Creek project sector peresentation Over all (Cut off Oct-24).pptx
# [INFO] Processing file: Hosh Eissa Hospital - Monthly Report - Oct 2024.pdf
# [INFO] Processing file: MIVIDA PKG#189 - Oct.24 Sector Presentation.pptx
# [INFO] Processing file: Sector Progress Presentation - Urban K Oct-24.pptx
# [INFO] Processing file: Sector Progress Presentation Oct.24- ZED Project PH 2.pptx
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: R-05 December 2024 Presentation.pptx
# [INFO] Processing file: F-P-PC-01-17 wady elnatroon monthly progress presentation(2024.11.30) .pptx
# [INFO] Processing file: F-P-PC-01-17 ABO GHALEB monthly progress presentation (2024.12).pdf
# [INFO] Processing file: F-P-PC-01-17 wady elnatroon monthly progress presentation(12.2024) .pdf
# [INFO] Processing file: ABOSHANAB-PROGRESS PRESENTATION Jan-2025.pptm
# [WARN] Skipped unsupported file type: ABOSHANAB-PROGRESS PRESENTATION Jan-2025.pptm
# [INFO] Processing file: Lot-A Internal Weekly Progress Presentation (2).pptm
# [WARN] Skipped unsupported file type: Lot-A Internal Weekly Progress Presentation (2).pptm
# [INFO] Processing file: Lot-B Internal Weekly Progress Presentation.pptm
# [WARN] Skipped unsupported file type: Lot-B Internal Weekly Progress Presentation.pptm
# [INFO] Processing file: - Sector Progress Presentation - Creek - Cut off Dec-24.pptx
# [INFO] Processing file: - Sector Progress Presentation - MIVIDA PKG#189 - Cut off Dec-24.pptx
# [INFO] Processing file: - Sector Progress Presentation - ZED Project PH02 - Cut off Dec-24.pptx
# [INFO] Processing file: Sector Progress Presentation - Urban K Dec-24.pptx
# [INFO] Processing file: ABO GHALEB monthly progress presentation (2025.01).pdf
# [INFO] Processing file: Sohag HSR Progress Presentation Jan 2025.pptx
# [INFO] Processing file: Wady elnatroon monthly progress presentation(01.2025).pdf
# [INFO] Processing file: EUA Progress Presentation-(JAN-25).pptx
# [INFO] Processing file: Mivida Sector Presentation Jan-25.rar
# [WARN] Skipped unsupported file type: Mivida Sector Presentation Jan-25.rar
# [INFO] Processing file: OC Progress Presentation-(JAN-25).pptx
# [INFO] Processing file: R05 Jan 2025 Presentation.pptx
# [INFO] Processing file: ZED Project PH02 Sector Progress Presentation Jan.25 -.pptx
# [INFO] Processing file: Damietta Monthly Progress Presentation  - Jan 25.pptx
# [INFO] Processing file: Saint Gobain Progress Report Jan-2025 - Updated.pptx
# [INFO] Processing file: Suez Monthly Progress  Presentation  End of Jan-2025.pptx
# [INFO] Processing file: Thumbs.db
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: Abo-Shanab Internal Weekly Progress Presentation .._ Final.pptm
# [WARN] Skipped unsupported file type: Abo-Shanab Internal Weekly Progress Presentation .._ Final.pptm
# [INFO] Processing file: Lot-A Internal Weekly Progress Presentation .._ Final.pptm
# [WARN] Skipped unsupported file type: Lot-A Internal Weekly Progress Presentation .._ Final.pptm
# [INFO] Processing file: Lot-B Internal Weekly Progress Presentation ....pptm
# [WARN] Skipped unsupported file type: Lot-B Internal Weekly Progress Presentation ....pptm
# [INFO] Processing file: F-P-PC-01-17 ABO GHALEB monthly progress presentation (2025.02).pdf
# [INFO] Processing file: F-P-PC-01-17 wady elnatroon monthly progress presentation(02.2025) .pdf
# [INFO] Processing file: Sohag HSR Project - Bridge Sector - Presentation.pptx
# [INFO] Processing file: Damietta Container Monthly Progress Presentation Feb-25.rar
# [WARN] Skipped unsupported file type: Damietta Container Monthly Progress Presentation Feb-25.rar
# [INFO] Processing file: Roots Monthly Presentation Feb.2025 Status REV.01.pptx
# [INFO] Processing file: Saint Gobain Progress Report Mar-2025 - Updated.pptx
# [INFO] Processing file: Suez Monthly Presentation  End of Feb-2025.pptx
# [INFO] Processing file: ABOSHANAB-PROGRESS PRESENTATION Mar-W1-2025.pptm
# [WARN] Skipped unsupported file type: ABOSHANAB-PROGRESS PRESENTATION Mar-W1-2025.pptm
# [INFO] Processing file: Lot-A Internal Weekly Progress Presentation (2).pptm
# [WARN] Skipped unsupported file type: Lot-A Internal Weekly Progress Presentation (2).pptm
# [INFO] Processing file: Lot-B Internal Weekly Progress Presentation.pptm
# [WARN] Skipped unsupported file type: Lot-B Internal Weekly Progress Presentation.pptm
# [INFO] Processing file: Presentation Cut off May-2025.pptx
# [INFO] Processing file: F-P-TN-02-06-Project-Execution-Plan-Hosh Eissa Rev 00.docx
# [INFO] Processing file: Hosh Eissa Central Hospital Presentation @12-Nov-23.pptx
# [INFO] Processing file: Project-Execution-Plan - Attachment.rar
# [WARN] Skipped unsupported file type: Project-Execution-Plan - Attachment.rar
# [INFO] Processing file: RME-RSM-Progress Presentation - 12.02.2024.pptx
# [INFO] Processing file: EGCK_Presentation#07_130124_R00.pptx
# [INFO] Processing file: EGCK_Presentation#08_310124_R00.pptx
# [INFO] Processing file: EGCK_Presentation#09_050224_R00.pptx
# [INFO] Processing file: Progress Status - Galawa Hotel Complex Jan 24.pdf
# [INFO] Processing file: RME - RSM - Progress Presentation - 26.02.2024.pdf
# [INFO] Processing file: RME - RSM - Progress Presentation - 26.02.2024.pdf
# [INFO] Processing file: EGCK_Presentation#09_050224_R00.pptx
# [INFO] Processing file: EGCK_Presentation#10_290224_R00.pptx
# [INFO] Processing file: RED SEA MUSEUM PROJECT STATUS 1-04-2024.pptx
# [INFO] Processing file: EGCK_Presentation#11_310324_R00.pptx
# [INFO] Processing file: RED SEA MUSEUM PROJECT STATUS 29-04-2024.pptx
# [INFO] Processing file: EGCK_Presentation#13_110524_R00.pptx
# [INFO] Processing file: MOC HQ IN DGDA Progress Presentation 270524.pptx
# [INFO] Processing file: RED SEA MUSEUM PROJECT STATUS 20-05-2024.pptx
# [INFO] Processing file: RABIGH Power Plant-1.2GW-Piles and Civil Package-Progress Report NO.02.pdf
# [INFO] Processing file: MOC HQ IN DGDA Progress Presentation 15-Aug-2024.pptx
# [INFO] Processing file: RABIGH POWER PLANT - Aug.24 Monthly Presentation.pptx
# [INFO] Processing file: 01- RSM -  Monthly Presentation 31072024.pptx
# [INFO] Processing file: EGCK_Presentation#15_310724_R00.pptx
# [INFO] Processing file: Ubari - Ghat Asphalt Plant 2024.08.pptx
# [INFO] Processing file: MOC HQ IN DGDA Progress Presentation 31-Aug-2024 - Monthly Presentation.pptx
# [INFO] Processing file: RBG - Internal Monthly Presentation - Sep.2024.pptx
# [INFO] Processing file: EGCK_Presentation#16_310824_R00.pptx
# [INFO] Processing file: MOC HQ IN DGDA Progress Presentation 29-Sep-24.pptx
# [INFO] Processing file: RBG - Internal Monthly Presentation - Oct.2024.pptx
# [INFO] Processing file: 01- RSM -  Monthly Presentation 05102024.pptx
# [INFO] Processing file: EGCK_Presentation#18_270924_R00.pptx
# [INFO] Processing file: MOC HQ IN DGDA Progress Presentation 11-Nov-24 Rev00.pptx
# [INFO] Processing file: RBG - Internal Monthly Presentation - Nov.2024.pptx
# [INFO] Processing file: 01- RSM -  Monthly Presentation 01112024.pptx
# [INFO] Processing file: RBG - Internal Monthly Presentation - Dec.2024.pptx
# [INFO] Processing file: 01- RSM -  Monthly Presentation 09122024.pptx
# [INFO] Processing file: EGCK_Presentation#20_130924_R00.pptx
# [INFO] Processing file: EGCK_Presentation#21_130924_R00.pptx
# [INFO] Processing file: RBG - Internal Monthly Presentation - Jan.25.pptx
# [INFO] Processing file: 01- RSM -  Monthly Presentation 10-01-2025.pptx
# [INFO] Processing file: EGCK_Presentation#22_130924_R00.pptx
# [INFO] Processing file: EGCK_Presentation#23_130924_R00.pptx
# [INFO] Processing file: EGCK_Presentation#25_130924_R00.pptx
# [INFO] Processing file: EGCK_Presentation#26_130924_R00.pptx
# [INFO] Processing file: MOC HQ IN DGDA Progress Presentation 31-Jan-25.pptx
# [INFO] Processing file: RBG - Internal Monthly Presentation - feb.2025.pptx
# [INFO] Processing file: RSM -  Monthly Presentation 03-02-2025.pptx
# [INFO] Processing file: MOC HQ IN DGDA Progress Presentation 28-Feb-25.pptx
# [INFO] Processing file: RBG - Internal Monthly Presentation - Mar.25.pptx
# [INFO] Processing file: RSM -  Monthly Presentation 09-03-2025.pptx
# [INFO] Processing file: OneDrive_2025-02-09.zip
# [WARN] Skipped unsupported file type: OneDrive_2025-02-09.zip
# [INFO] Processing file: Ubari-Ghat Monthly Planning Dashboard 2025.02.28.pdf
# [INFO] Processing file: Ubari-Ghat Planning Monthly Target Vs. Actuals 2025.02.28.pdf
# [INFO] Processing file: Ubari-Ghat Planning Report-Cut Date-2025.02.28.pdf
# [INFO] Processing file: Ubari-Ghat progress report -Stations.pdf
# Processed 514 documents. Output saved to C:/Users/Omar Essam2/OneDrive - Rowad Modern Engineering/x004 Data Science/03.rme.db/05.llm/extracted_json\02 Monthly Progress Presentation_extracted.json

# %%
import os
import json
import openai
import chromadb
from chromadb.config import Settings
from dotenv import load_dotenv
from tqdm import tqdm

# Load OpenAI API key from .env
load_dotenv()
openai.api_key = os.getenv('OPENAI_API_KEY')

# New paths outside the repo
EXTRACTED_DIR = r'C:/Users/Omar Essam2/OneDrive - Rowad Modern Engineering/x004 Data Science/03.rme.db/05.llm/extracted_json'
CHROMA_DB_DIR = r'C:/Users/Omar Essam2/OneDrive - Rowad Modern Engineering/x004 Data Science/03.rme.db/05.llm/chroma_db'
COLLECTION_NAME = 'company_docs'
CHUNK_SIZE = 1000  # characters per chunk
CHUNK_OVERLAP = 200
ID_TRACK_FILE = os.path.join(CHROMA_DB_DIR, 'embedded_chunk_ids.txt')

# Helper: chunk text
def chunk_text(text, chunk_size=CHUNK_SIZE, overlap=CHUNK_OVERLAP):
    chunks = []
    start = 0
    while start < len(text):
        end = min(start + chunk_size, len(text))
        chunks.append(text[start:end])
        start += chunk_size - overlap
    return chunks

# Helper: get OpenAI embeddings
def get_embedding(text):
    resp = openai.embeddings.create(
        input=[text],
        model="text-embedding-ada-002"
    )
    return resp.data[0].embedding

# Initialize Chroma DB
client = chromadb.PersistentClient(path=CHROMA_DB_DIR, settings=Settings(allow_reset=True))
if COLLECTION_NAME in [c.name for c in client.list_collections()]:
    collection = client.get_collection(COLLECTION_NAME)
else:
    collection = client.create_collection(COLLECTION_NAME)

def load_embedded_ids():
    if not os.path.exists(ID_TRACK_FILE):
        return set()
    with open(ID_TRACK_FILE, 'r', encoding='utf-8') as f:
        return set(line.strip() for line in f if line.strip())

def save_embedded_id(chunk_id):
    with open(ID_TRACK_FILE, 'a', encoding='utf-8') as f:
        f.write(chunk_id + '\n')

def process_json_files():
    files = [f for f in os.listdir(EXTRACTED_DIR) if f.endswith('.json')]
    doc_count = 0
    embedded_ids = load_embedded_ids()
    for file in files:
        with open(os.path.join(EXTRACTED_DIR, file), 'r', encoding='utf-8') as f:
            docs = json.load(f)
        for doc in tqdm(docs, desc=f"Processing {file}"):
            text = doc['text']
            if not text.strip():
                continue
            chunks = chunk_text(text)
            for i, chunk in enumerate(chunks):
                chunk_id = f"{doc['file_name']}_{i}"
                if chunk_id in embedded_ids:
                    continue  # Skip already embedded chunk
                meta = {
                    'file_name': doc['file_name'],
                    'file_path': doc['file_path'],
                    'type': doc['type'],
                    'extracted_at': doc['extracted_at'],
                    'chunk': i
                }
                try:
                    emb = get_embedding(chunk)
                    collection.add(
                        documents=[chunk],
                        embeddings=[emb],
                        metadatas=[meta],
                        ids=[chunk_id]
                    )
                    save_embedded_id(chunk_id)
                    doc_count += 1
                except Exception as e:
                    print(f"Error embedding chunk: {e}")
    print(f"Finished! {doc_count} new chunks embedded and stored in Chroma DB.")

if __name__ == "__main__":
    process_json_files()
# Out:
# Processing 02 artical_extracted.json: 100%|██████████| 21/21 [00:00<00:00, 29646.71it/s]
# Processing 02 Monthly Progress Presentation_extracted.json: 100%|██████████| 514/514 [54:02<00:00,  6.31s/it]
# Processing 0207 Qasr Rashwan Lot A_extracted.json: 100%|██████████| 5/5 [00:00<00:00, 25858.84it/s]
# Processing 0208 Qasr Rashwan Lot B_extracted.json: 100%|██████████| 3/3 [00:00<00:00, 11926.93it/s]
# Finished! 4257 new chunks embedded and stored in Chroma DB.
