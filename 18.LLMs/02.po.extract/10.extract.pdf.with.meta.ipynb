# %%
import os
import sys
import time
import logging
import tkinter as tk
from tkinter import filedialog
import mysql.connector
from mysql.connector import Error
import pytesseract
from pdf2image import convert_from_path
import hashlib

# Configure logging with UTF-8 encoding
class UTF8FileHandler(logging.FileHandler):
    def __init__(self, filename, mode='a', encoding='utf-8', delay=False):
        logging.FileHandler.__init__(self, filename, mode, encoding, delay)

# Configure logging to handle Unicode characters
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        UTF8FileHandler('pdf_extraction.log'),
        logging.StreamHandler(sys.stdout)
    ]
)

# Set the path to Poppler binaries
poppler_path = r'C:\poppler\Library\bin'

# Database configuration
DB_CONFIG = {
    'host': '10.10.11.242',
    'user': 'omar2',
    'password': 'Omar_54321',
    'database': 'RME_TEST'
}

class PDFExtractor:
    def __init__(self):
        self.folder_path = ""
        self.db_connection = None
        self.cursor = None
        self.processed_files = set()
    
    def connect_to_database(self):
        """Establish connection to MySQL database"""
        try:
            self.db_connection = mysql.connector.connect(**DB_CONFIG)
            self.cursor = self.db_connection.cursor()
            logging.info("Connected to MySQL database")
            
            # Create table if it doesn't exist
            self.create_table()
            
            # Load already processed files
            self.load_processed_files()
            
            return True
        except Error as e:
            logging.error(f"Error connecting to MySQL database: {e}")
            return False
    
    def create_table(self):
        """Create the po.pdfs table if it doesn't exist"""
        create_table_query = """
        CREATE TABLE IF NOT EXISTS `po.pdfs` (
            id INT AUTO_INCREMENT PRIMARY KEY,
            pdf_path VARCHAR(1000) NOT NULL,
            pdf_filename VARCHAR(255) NOT NULL,
            pdf_hash VARCHAR(64) NOT NULL,
            extracted_text LONGTEXT,
            processed_timestamp TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
            INDEX (pdf_hash)
        )
        """
        
        # Create chunks table
        create_chunks_table_query = """
        CREATE TABLE IF NOT EXISTS `po.pdf_chunks` (
            id INT AUTO_INCREMENT PRIMARY KEY,
            pdf_id INT NOT NULL,
            chunk_number INT NOT NULL,
            chunk_text LONGTEXT,
            FOREIGN KEY (pdf_id) REFERENCES `po.pdfs`(id) ON DELETE CASCADE,
            INDEX (pdf_id, chunk_number)
        )
        """
        
        try:
            self.cursor.execute(create_table_query)
            self.cursor.execute(create_chunks_table_query)
            self.db_connection.commit()
            logging.info("Database tables created or already exist")
        except Error as e:
            logging.error(f"Error creating tables: {e}")
    
    def load_processed_files(self):
        """Load already processed files from the database"""
        query = "SELECT pdf_hash FROM `po.pdfs`"
        try:
            self.cursor.execute(query)
            results = self.cursor.fetchall()
            self.processed_files = set([result[0] for result in results])
            logging.info(f"Loaded {len(self.processed_files)} already processed files")
        except Error as e:
            logging.error(f"Error loading processed files: {e}")
    
    def calculate_file_hash(self, file_path):
        """Calculate SHA-256 hash of a file"""
        sha256_hash = hashlib.sha256()
        with open(file_path, "rb") as f:
            # Read and update hash in chunks of 4K
            for byte_block in iter(lambda: f.read(4096), b""):
                sha256_hash.update(byte_block)
        return sha256_hash.hexdigest()
    
    def browse_folder(self):
        """Open a file dialog to browse for a folder"""
        root = tk.Tk()
        root.withdraw()  # Hide the main window
        
        folder_path = filedialog.askdirectory(title="Select Folder Containing PDF Files")
        
        if not folder_path:
            logging.warning("No folder selected. Exiting.")
            return False
        
        self.folder_path = folder_path
        logging.info(f"Selected folder: {folder_path}")
        return True
    
    def scan_pdfs(self, folder_path):
        """Scan a folder and all its subfolders for PDF files"""
        pdf_files = []
        
        # Walk through all subdirectories
        for root, dirs, files in os.walk(folder_path):
            # Find all PDF files in the current directory
            for file in files:
                if file.lower().endswith('.pdf'):
                    # Get the full path to the PDF file
                    full_path = os.path.join(root, file)
                    pdf_files.append(full_path)
        
        logging.info(f"Found {len(pdf_files)} PDF files in {folder_path}")
        return pdf_files
    
    def split_text_into_chunks(self, text):
        """
        Split the extracted text into meaningful chunks (paragraphs).
        Skip single lines and merge them with adjacent paragraphs.
        """
        # Split text by double newlines (paragraph breaks)
        paragraphs = [p.strip() for p in text.split('\n\n') if p.strip()]
        
        # Process paragraphs to handle single lines
        chunks = []
        current_chunk = ""
        
        for p in paragraphs:
            # If it's a single line (no newlines) and current_chunk is not empty
            if '\n' not in p and current_chunk:
                current_chunk += "\n" + p
            # If it's a single line and current_chunk is empty, start a new chunk
            elif '\n' not in p and not current_chunk:
                current_chunk = p
            # If it's a multi-line paragraph and current_chunk is not empty
            elif current_chunk:
                current_chunk += "\n" + p
                chunks.append(current_chunk)
                current_chunk = ""
            # If it's a multi-line paragraph and current_chunk is empty
            else:
                chunks.append(p)
        
        # Add the last chunk if not empty
        if current_chunk:
            chunks.append(current_chunk)
        
        return chunks
    
    def extract_text_from_pdf(self, pdf_path):
        """Extract text from a PDF file using Tesseract OCR with support for Arabic and English"""
        try:
            # Convert PDF to images using the specified poppler path
            images = convert_from_path(pdf_path, poppler_path=poppler_path)
            
            # Extract text from each image with Arabic + English language support
            text = ""
            for image in images:
                # Use Arabic + English language configuration
                text += pytesseract.image_to_string(image, lang='ara+eng')
                text += "\n\n"
            
            return text
        except Exception as e:
            logging.error(f"Error in OCR processing: {str(e)}")
            raise
    
    def save_to_database(self, pdf_path, text, chunks):
        """Save extracted text and chunks to the database"""
        try:
            # Calculate file hash
            file_hash = self.calculate_file_hash(pdf_path)
            
            # Check if this file has already been processed
            if file_hash in self.processed_files:
                logging.info(f"Skipping already processed file: {pdf_path}")
                return
            
            # Insert main PDF record
            insert_pdf_query = """
            INSERT INTO `po.pdfs` (pdf_path, pdf_filename, pdf_hash, extracted_text)
            VALUES (%s, %s, %s, %s)
            """
            
            filename = os.path.basename(pdf_path)
            self.cursor.execute(insert_pdf_query, (pdf_path, filename, file_hash, text))
            pdf_id = self.cursor.lastrowid
            
            # Insert chunks
            insert_chunk_query = """
            INSERT INTO `po.pdf_chunks` (pdf_id, chunk_number, chunk_text)
            VALUES (%s, %s, %s)
            """
            
            for i, chunk in enumerate(chunks, 1):
                self.cursor.execute(insert_chunk_query, (pdf_id, i, chunk))
            
            # Commit the transaction
            self.db_connection.commit()
            
            # Add to processed files set
            self.processed_files.add(file_hash)
            
            logging.info(f"Saved PDF {filename} with {len(chunks)} chunks to database")
            
        except Error as e:
            logging.error(f"Database error: {e}")
            self.db_connection.rollback()
    
    def process_pdfs(self):
        """Process all PDF files in the selected folder"""
        if not self.connect_to_database():
            return
        
        if not self.browse_folder():
            return
        
        pdf_files = self.scan_pdfs(self.folder_path)
        
        if not pdf_files:
            logging.warning("No PDF files found in the selected directory.")
            return
        
        total_pdfs = len(pdf_files)
        processed = 0
        skipped = 0
        errors = 0
        
        for i, pdf_path in enumerate(pdf_files):
            try:
                # Calculate file hash
                file_hash = self.calculate_file_hash(pdf_path)
                
                # Skip if already processed
                if file_hash in self.processed_files:
                    safe_path = repr(pdf_path)
                    logging.info(f"Skipping already processed file ({i+1}/{total_pdfs}): {safe_path}")
                    skipped += 1
                    continue
                
                safe_path = repr(pdf_path)
                logging.info(f"Processing ({i+1}/{total_pdfs}): {safe_path}")
                
                # Extract text
                text = self.extract_text_from_pdf(pdf_path)
                
                # Split into chunks
                chunks = self.split_text_into_chunks(text)
                
                # Save to database
                self.save_to_database(pdf_path, text, chunks)
                
                processed += 1
                
                # Log progress
                if (i+1) % 5 == 0 or (i+1) == total_pdfs:
                    logging.info(f"Progress: {i+1}/{total_pdfs} PDFs processed")
                
            except Exception as e:
                safe_path = repr(pdf_path)
                logging.error(f"Error processing {safe_path}: {str(e)}")
                errors += 1
        
        # Close database connection
        if self.db_connection and self.db_connection.is_connected():
            self.cursor.close()
            self.db_connection.close()
            logging.info("Database connection closed")
        
        # Final summary
        logging.info(f"Processing complete: {processed} processed, {skipped} skipped, {errors} errors")

def main():
    extractor = PDFExtractor()
    extractor.process_pdfs()

if __name__ == "__main__":
    main()
# Out:
# 2025-05-18 18:36:45,703 - INFO - Connected to MySQL database
# 2025-05-18 18:36:45,710 - INFO - Database tables created or already exist
# 2025-05-18 18:36:45,713 - INFO - Loaded 223 already processed files
# 2025-05-18 18:37:43,406 - INFO - Selected folder: //fileserver2/Head Office Server/Procurement (PR)/02 Projects Document
# 2025-05-18 18:38:02,761 - INFO - Found 16275 PDF files in //fileserver2/Head Office Server/Procurement (PR)/02 Projects Document
# 2025-05-18 18:38:02,866 - INFO - Skipping already processed file (1/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\10th Of Ramadan Bridge\\Comparison\\Concrete Supply Works\\Comparison for Concrete Supply Works - 10th Of Ramadan Bridge.pdf'
# 2025-05-18 18:38:02,938 - INFO - Skipping already processed file (2/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\10th Of Ramadan Bridge\\Comparison\\Expansion Joints Works\\Comparison for Expansion Joints Works - 10th Of Ramadan Bridge.pdf'
# 2025-05-18 18:38:03,049 - INFO - Skipping already processed file (3/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\10th Of Ramadan Bridge\\Comparison\\Strands Works\\Comparison for Strands Works - 10th Of Ramadan Bridge.pdf'
# 2025-05-18 18:38:03,222 - INFO - Skipping already processed file (4/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\10th Of Ramadan Bridge\\Contracts\\Egy Drill Company\\Contract Egy Drill Company - 10th Of Ramadan Bridge.pdf'
# 2025-05-18 18:38:03,403 - INFO - Skipping already processed file (5/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\10th Of Ramadan Bridge\\Contracts\\شركة الطحاوية للانشاء والتعمير\\Contract El Tahwia company - 10th Of Ramadan Bridge.pdf'
# 2025-05-18 18:38:03,610 - INFO - Skipping already processed file (6/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\10th Of Ramadan Bridge\\Contracts\\شركة العلا للمقاولات العمومية\\Contract El Olaa company - 10th Of Ramadan Bridge.pdf'
# 2025-05-18 18:38:03,775 - INFO - Skipping already processed file (7/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\10th Of Ramadan Bridge\\Contracts\\شركة الهنا للمقاولات العمومية\\Contract El Hana company - 10th Of Ramadan Bridge.pdf'
# 2025-05-18 18:38:03,953 - INFO - Skipping already processed file (8/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\10th Of Ramadan Bridge\\Contracts\\شركة ايه بلس للحلول الانشائية المتكامله\\Contract A plus company - 10th Of Ramadan Bridge.pdf'
# 2025-05-18 18:38:04,088 - INFO - Skipping already processed file (9/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\10th Of Ramadan Bridge\\Contracts\\شركة مشهور غنيم احمد\\Contract Mashour Company - El Asher Mn Ramadan Bridge.pdf'
# 2025-05-18 18:38:04,307 - INFO - Skipping already processed file (10/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\10th Of Ramadan Bridge\\Contracts\\عطايا للمقاولات العمومية و التوريدات\\Contract Ataya company - 10th Of Ramadan Bridge.pdf'
# 2025-05-18 18:38:04,424 - INFO - Skipping already processed file (11/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\10th Of Ramadan Bridge\\LPO\\P.O 001 Sammix company - 10th Of Ramadan Bridge.pdf'
# 2025-05-18 18:38:04,636 - INFO - Skipping already processed file (12/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\10th Of Ramadan Bridge\\LPO\\P.O 002 Nile Mix company - 10th Of Ramadan Bridge.pdf'
# 2025-05-18 18:38:04,695 - INFO - Skipping already processed file (13/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\10th Of Ramadan Bridge\\LPO\\P.O 003 Elsewedy company - 10th Of Ramadan Bridge.pdf'
# 2025-05-18 18:38:04,775 - INFO - Skipping already processed file (14/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\10th Of Ramadan Bridge\\LPO\\P.O 004 Dar Ready Mix company - 10th Of Ramadan Bridge.pdf'
# 2025-05-18 18:38:04,879 - INFO - Skipping already processed file (15/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\10th Of Ramadan Bridge\\LPO\\P.O 005 Nile Mix company - 10th Of Ramadan Bridge.pdf'
# 2025-05-18 18:38:04,963 - INFO - Skipping already processed file (16/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\15 May Concrete Fence\\Comparison\\Aluminum Window\\Comparison for Aluminum Windows - 15 May Store.pdf'
# 2025-05-18 18:38:04,998 - INFO - Skipping already processed file (17/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\15 May Concrete Fence\\Comparison\\Steel Structure\\Steel Structure - 15 May Store.PDF'
# 2025-05-18 18:38:05,069 - INFO - Skipping already processed file (18/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\15 May Concrete Fence\\Contract\\Abo Abd Allah Company add 01 - 15 May Fence Project.PDF'
# 2025-05-18 18:38:05,151 - INFO - Skipping already processed file (19/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\15 May Concrete Fence\\Contract\\Abo Abd Allah Company Contract - 15 May Fence Project.PDF'
# 2025-05-18 18:38:05,320 - INFO - Skipping already processed file (20/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\15 May Concrete Fence\\Contract\\Al Arabi Company - 15 May Store.PDF'
# 2025-05-18 18:38:05,433 - INFO - Skipping already processed file (21/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\15 May Concrete Fence\\Contract\\Contract 03 El Baraka Company - 15 May Store.pdf'
# 2025-05-18 18:38:05,587 - INFO - Skipping already processed file (22/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\15 May Concrete Fence\\Contract\\Contract Add 01El Baraka Company - 15 May Store.pdf'
# 2025-05-18 18:38:05,741 - INFO - Skipping already processed file (23/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\15 May Concrete Fence\\Contract\\Contract El Baraka Company - 15 May Store.pdf'
# 2025-05-18 18:38:05,819 - INFO - Skipping already processed file (24/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\6 October Tunnel\\LPO\\P.O 001 Better mix Company - 6 October Tunnel.pdf'
# 2025-05-18 18:38:05,950 - INFO - Skipping already processed file (25/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\6 October Tunnel\\LPO\\P.O 002 Concord Readymix Company - 6 October Tunnel.pdf'
# 2025-05-18 18:38:06,014 - INFO - Skipping already processed file (26/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\6 October Tunnel\\LPO\\P.O 003 Better mix Company - 6 October Tunnel.pdf'
# 2025-05-18 18:38:06,069 - INFO - Skipping already processed file (27/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\6 October Tunnel\\LPO\\P.O 004  Better Mix Company - 6 October Tunnel.pdf'
# 2025-05-18 18:38:06,167 - INFO - Skipping already processed file (28/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\6 October Tunnel\\LPO\\P.O 005 Better Mix Company - 6 October Tunnel.pdf'
# 2025-05-18 18:38:06,259 - INFO - Skipping already processed file (29/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\6 October Tunnel\\LPO\\P.O 006 Better Mix Company - 6 October Tunnel.pdf'
# 2025-05-18 18:38:06,351 - INFO - Skipping already processed file (30/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abbas El Akkad Bridge\\Comparison\\Concrete Supply\\Comparison for Concrete Supply - Nasr City Bridge.pdf'
# 2025-05-18 18:38:06,432 - INFO - Skipping already processed file (31/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abbas El Akkad Bridge\\Comparison\\Thermal Joints Works\\Comparison for Thermal Joints Works - Abbas El Akkad Bridge.pdf'
# 2025-05-18 18:38:06,511 - INFO - Skipping already processed file (32/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abbas El Akkad Bridge\\Contracts\\Capital Company\\Contract Add 01 Capital Company - Abbas El Akkad Bridge.pdf'
# 2025-05-18 18:38:06,693 - INFO - Skipping already processed file (33/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abbas El Akkad Bridge\\Contracts\\Capital Company\\Contract Capital Company - Abbas El Akkad Bridge.pdf'
# 2025-05-18 18:38:06,770 - INFO - Skipping already processed file (34/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abbas El Akkad Bridge\\Contracts\\Egydrill Company\\Contract Add 001 EgyDrill Company - Abbas El Akkad Bridge.pdf'
# 2025-05-18 18:38:06,961 - INFO - Skipping already processed file (35/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abbas El Akkad Bridge\\Contracts\\Egydrill Company\\Contract Egydrill Company - Abbas El Akkad Bridge.pdf'
# 2025-05-18 18:38:07,234 - INFO - Skipping already processed file (36/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abbas El Akkad Bridge\\Contracts\\Sarens Heavy Lift Company\\Contract Sarens Heavy Lift Company - Abbas El Akkad Bridge.pdf'
# 2025-05-18 18:38:07,384 - INFO - Skipping already processed file (37/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abbas El Akkad Bridge\\Contracts\\Tetra Company\\Contract Tetra Company - Abbas El Akkad Bridge.pdf'
# 2025-05-18 18:38:07,529 - INFO - Skipping already processed file (38/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abbas El Akkad Bridge\\Contracts\\شركة بينتا للاستشارات الهندسية\\Contract Penta Consultancy Company  - Abass El Akad Bridge.pdf'
# 2025-05-18 18:38:07,678 - INFO - Skipping already processed file (39/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abbas El Akkad Bridge\\Contracts\\شركة تكنولوجيا الاساسات للانشاءات\\Contract Driller Company - Abbas El Akkad Bridge.pdf'
# 2025-05-18 18:38:07,851 - INFO - Skipping already processed file (40/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abbas El Akkad Bridge\\Contracts\\شركة ريفر للمقاولات و التوريدات العمومية\\Contract River Company - Abbas El Akkad Bridge.pdf'
# 2025-05-18 18:38:08,004 - INFO - Skipping already processed file (41/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abbas El Akkad Bridge\\Contracts\\شركة زيدانكو للمقاولات العامة و الانشاءات\\Contract Zidanco Company - Abbas El Akkad Bridge.pdf'
# 2025-05-18 18:38:08,084 - INFO - Skipping already processed file (42/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abbas El Akkad Bridge\\LPO\\P.O 001 Semmix Ready Mix - Abbas El Akkad Bridge.pdf'
# 2025-05-18 18:38:08,180 - INFO - Skipping already processed file (43/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abbas El Akkad Bridge\\LPO\\P.O 002 Dar Ready Mix - Abbas El Akkad Bridge.pdf'
# 2025-05-18 18:38:08,304 - INFO - Skipping already processed file (44/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abbas El Akkad Bridge\\LPO\\P.O 003 Beter Mix Company  - Abass El Akad Bridge.pdf'
# 2025-05-18 18:38:08,512 - INFO - Skipping already processed file (45/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abbas El Akkad Bridge\\LPO\\P.O 005 Nile Mix Company - Abass El Akad Bridge.pdf'
# 2025-05-18 18:38:08,622 - INFO - Skipping already processed file (46/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abbas El Akkad Bridge\\LPO\\P.O 007 El Motaheda elsewedy - Abbas El Akkad Bridge.pdf'
# 2025-05-18 18:38:08,686 - INFO - Skipping already processed file (47/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abbas El Akkad Bridge\\LPO\\P.O 008 Dar Ready Mix - Abbas El Akkad Bridge.pdf'
# 2025-05-18 18:38:08,770 - INFO - Skipping already processed file (48/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abbas El Akkad Bridge\\LPO\\P.O 009 Sammix Ready Mix - Abbas El Akkad Bridge.pdf'
# 2025-05-18 18:38:08,873 - INFO - Skipping already processed file (49/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abbas El Akkad Bridge\\LPO\\P.O 010 Nile Ready Mix Company - Abbas El Akkad Bridge.pdf'
# 2025-05-18 18:38:08,961 - INFO - Skipping already processed file (50/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abo Sultan Bridge\\Comparison\\Concrete Supply\\Comparison for Concrete Supply  R 01 Signed - Abo Sultan Bridge.pdf'
# 2025-05-18 18:38:09,009 - INFO - Skipping already processed file (51/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abo Sultan Bridge\\Comparison\\Concrete Supply\\Comparison for Concrete Supply  R02 Signed - Abo Sultan Bridge.pdf'
# 2025-05-18 18:38:09,044 - INFO - Skipping already processed file (52/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abo Sultan Bridge\\Comparison\\Concrete Supply\\Comparison for Concrete Supply R03 - Abo Sultan Bridge.pdf'
# 2025-05-18 18:38:09,132 - INFO - Skipping already processed file (53/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abo Sultan Bridge\\Comparison\\Concrete Supply\\Concreta Supply  R- Abo Sultan Bridge.PDF'
# 2025-05-18 18:38:09,212 - INFO - Skipping already processed file (54/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abo Sultan Bridge\\Comparison\\Concrete Supply\\Concrete Supply  - Abo Sultan Bridge.PDF'
# 2025-05-18 18:38:09,500 - INFO - Skipping already processed file (55/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abo Sultan Bridge\\Contracts\\شركة فيبرو\\Contract Vibro Company Signed - Abo Sultan Bridge.PDF'
# 2025-05-18 18:38:09,647 - INFO - Skipping already processed file (56/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abo Sultan Bridge\\Contracts\\شركة محرم باخوم\\Contract Moharam Bakhom Company - Abo Sultan Bridge.pdf'
# 2025-05-18 18:38:09,808 - INFO - Skipping already processed file (57/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abo Sultan Bridge\\LPO\\P.O 01 Reliance Company.pdf'
# 2025-05-18 18:38:09,912 - INFO - Skipping already processed file (58/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abo Sultan Bridge\\LPO\\P.O 02 Reliance Company.pdf'
# 2025-05-18 18:38:10,284 - INFO - Skipping already processed file (59/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abo Sultan Bridge\\LPO\\P.O 03 Unimix Company - Abo Sultan Bridge.pdf'
# 2025-05-18 18:38:10,371 - INFO - Skipping already processed file (60/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abo Sultan Bridge\\LPO\\P.O 04 Unimix Company.pdf'
# 2025-05-18 18:38:10,448 - INFO - Skipping already processed file (61/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abo Sultan Bridge\\LPO\\P.O 05  Unimix Company -Abo Sultan Bridge.pdf'
# 2025-05-18 18:38:10,521 - INFO - Skipping already processed file (62/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abo Sultan Bridge\\LPO\\P.O 06 Unimix Company - Abo Sultan Bridge.pdf'
# 2025-05-18 18:38:10,768 - INFO - Skipping already processed file (63/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abo Sultan Bridge\\LPO\\P.O 07 Nile Mix Company - Abo Sultan Bridge.pdf'
# 2025-05-18 18:38:10,813 - INFO - Skipping already processed file (64/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abo Sultan Bridge 2\\Comparison\\Concrete Supply\\Comparison for Concrete Supply - Abo Sultan 2 Brigde.pdf'
# 2025-05-18 18:38:10,897 - INFO - Skipping already processed file (65/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abo Sultan Bridge 2\\Comparison\\Insulation Work\\Comparison for Insulation Work - Abo Sultan Bridge 2.pdf'
# 2025-05-18 18:38:10,940 - INFO - Skipping already processed file (66/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abo Sultan Bridge 2\\Comparison\\Neoprene Pads\\Comparison for Neoprene Pads - Abo Sultan Bridge 2.pdf'
# 2025-05-18 18:38:11,170 - INFO - Skipping already processed file (67/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abo Sultan Bridge 2\\Contracts\\Future Proof Company\\Contract Future Proof Company - Abo Sultan Bridge 2.pdf'
# 2025-05-18 18:38:11,273 - INFO - Skipping already processed file (68/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abo Sultan Bridge 2\\Contracts\\شركة الرائد\\Contract El Raed Company - Abo Sultan Bridge 2.pdf'
# 2025-05-18 18:38:11,413 - INFO - Skipping already processed file (69/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abo Sultan Bridge 2\\Contracts\\شركة تكنولوجيا الاساسات للانشاءات\\Contract Driller Company - Abo Sultan Bridge 2.pdf'
# 2025-05-18 18:38:11,620 - INFO - Skipping already processed file (70/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abo Sultan Bridge 2\\Contracts\\مكتب اوبك\\Contract Obek Company - Abo Sultan Bridge 2.pdf'
# 2025-05-18 18:38:11,737 - INFO - Skipping already processed file (71/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abo Sultan Bridge 2\\LPO\\P.O 01 Nile Mix Concrete Company - Abo Sultan Bridge 2.pdf'
# 2025-05-18 18:38:11,818 - INFO - Skipping already processed file (72/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abo Sultan Bridge 2\\LPO\\P.O 02 Unimix Company - Abo Sultan Bridge 2.pdf'
# 2025-05-18 18:38:11,923 - INFO - Skipping already processed file (73/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abo Sultan Bridge 2\\LPO\\P.O 03 3S Ready Mix Company - Abo Sultan Bridge 2.pdf'
# 2025-05-18 18:38:11,982 - INFO - Skipping already processed file (74/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abo Sultan Bridge 2\\LPO\\P.O 04 El Nada Company - Abo Sultan Bridge 2.pdf'
# 2025-05-18 18:38:12,110 - INFO - Skipping already processed file (75/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Abo Sultan Bridge 2\\LPO\\P.O 05 Nile Mix Company - Abo Sultan Bridge 2.pdf'
# 2025-05-18 18:38:12,188 - INFO - Skipping already processed file (76/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Administration\\Contracts\\Egress international Company\\عقد شحن ماكينات الخوازيق.PDF'
# 2025-05-18 18:38:12,245 - INFO - Skipping already processed file (77/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Administration\\Contracts\\filomix company\\Felomix  contract.PDF'
# 2025-05-18 18:38:12,279 - INFO - Skipping already processed file (78/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Administration\\Contracts\\UNI MIX Company\\uni mex  contract signd.pdf'
# 2025-05-18 18:38:12,313 - INFO - Skipping already processed file (79/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Administration\\Contracts\\شركة الالفى\\عقد مقاولة اعمال من الباطن.PDF'
# 2025-05-18 18:38:12,347 - INFO - Skipping already processed file (80/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Administration\\Contracts\\شركة اليكس تريدرز جروب\\اعمال تشطيبات الدور الخامس.PDF'
# 2025-05-18 18:38:12,417 - INFO - Skipping already processed file (81/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Administration\\Contracts\\شركة تراست\\عقد اعمال تشطيبات الدور السابع----تراست-----الادارة.PDF'
# 2025-05-18 18:38:12,467 - INFO - Skipping already processed file (82/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Administration\\Contracts\\شركة سامكريت مصر\\عقد توريد وتركيب - الادارة.PDF'
# 2025-05-18 18:38:12,539 - INFO - Skipping already processed file (83/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Administration\\Contracts\\شركة على محمود محمد\\عقد اعمال توريد وتركيب الدهانات---على محمود محمد-----الادارة الدور الثالث.PDF'
# 2025-05-18 18:38:12,695 - INFO - Skipping already processed file (84/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Administration\\Contracts\\شركة محمد علام عباس\\ملحق اعمال تشطيبات الدور الخامس----محمد علام عباس----الادارة.PDF'
# 2025-05-18 18:38:12,730 - INFO - Skipping already processed file (85/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Administration\\Request For Down Payment LPO\\قيمة امر توريد - شركة البركة.PDF'
# 2025-05-18 18:38:12,850 - INFO - Skipping already processed file (86/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Administration\\TPD Purchasing order\\قاطوع سيكوريت - شركة البركة.PDF'
# 2025-05-18 18:38:12,953 - INFO - Skipping already processed file (87/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ahmed Elzomr Bridge\\Comparisons\\Ahmed Elzomr Bridge\\Concrete Supply\\Comparison for Concrete Supply Works - Ahmed Elzomr Bridge.pdf'
# 2025-05-18 18:38:13,064 - INFO - Processing (88/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ahmed Elzomr Bridge\\Comparisons\\Ahmed Elzomr Bridge\\Supply and Erection Steel Structure Works\\Comparison for Supply and Erection Steel Structure Works - Ahmed Elzomr Bridge.pdf'
# 2025-05-18 18:38:13,106 - ERROR - Error in OCR processing: Unable to get page count.
# I/O Error: Couldn't open file '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\02-01 Finish\Ahmed Elzomr Bridge\Comparisons\Ahmed Elzomr Bridge\Supply and Erection Steel Structure Works\Comparison for Supply and Erection Steel Structure Works - Ahmed Elzomr Bridge.pdf': No error.
#
# 2025-05-18 18:38:13,107 - ERROR - Error processing '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ahmed Elzomr Bridge\\Comparisons\\Ahmed Elzomr Bridge\\Supply and Erection Steel Structure Works\\Comparison for Supply and Erection Steel Structure Works - Ahmed Elzomr Bridge.pdf': Unable to get page count.
# I/O Error: Couldn't open file '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\02-01 Finish\Ahmed Elzomr Bridge\Comparisons\Ahmed Elzomr Bridge\Supply and Erection Steel Structure Works\Comparison for Supply and Erection Steel Structure Works - Ahmed Elzomr Bridge.pdf': No error.
#
# 2025-05-18 18:38:13,161 - INFO - Skipping already processed file (89/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ahmed Elzomr Bridge\\Comparisons\\Ahmed Elzomr Bridge\\Thermal Joints Works\\Comparison for Thermal Joints Works - Ahmed Elzomr Bridge.pdf'
# 2025-05-18 18:38:13,334 - INFO - Skipping already processed file (90/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ahmed Elzomr Bridge\\Contracts\\Egy Drill Company\\Contract Egy Drill Company - Ahmed Elzomr Bridge.pdf'
# 2025-05-18 18:38:13,630 - INFO - Skipping already processed file (91/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ahmed Elzomr Bridge\\Contracts\\El Resala Company\\Contract El Resala Company - Ahmed Elzomr Bridge.pdf'
# 2025-05-18 18:38:13,800 - INFO - Skipping already processed file (92/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ahmed Elzomr Bridge\\Contracts\\El Tahawia Company\\Contract El Tahawia Company - Ahmed Elzomr Bridge.pdf'
# 2025-05-18 18:38:13,965 - INFO - Skipping already processed file (93/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ahmed Elzomr Bridge\\Contracts\\El-Farouk Company\\Contract El-Farouk Company - Ahmed Elzomr Bridge.pdf'
# 2025-05-18 18:38:14,064 - INFO - Skipping already processed file (94/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ahmed Elzomr Bridge\\Contracts\\Osama Okail Company\\Contract Osama Okail Company - Ahmed Elzomr Bridge.pdf'
# 2025-05-18 18:38:14,249 - INFO - Skipping already processed file (95/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ahmed Elzomr Bridge\\Contracts\\Vibro Company\\Contract Vibro Company - Ahmed Elzomr Bridge.pdf'
# 2025-05-18 18:38:14,574 - INFO - Skipping already processed file (96/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ahmed Elzomr Bridge\\Contracts\\عطايا للمقاولات العمومية و التوريدات\\Contract Ataya Company - Ahmed Elzomr Bridge.pdf'
# 2025-05-18 18:38:14,639 - INFO - Skipping already processed file (97/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ahmed Elzomr Bridge\\LPO\\P.O 001 El-Motaheda Company - Ahmed Elzomr Bridge.pdf'
# 2025-05-18 18:38:14,721 - INFO - Skipping already processed file (98/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ahmed Elzomr Bridge\\LPO\\P.O 002 Beter Mix Ready Mix Company - Ahmed Elzomr Bridge.pdf'
# 2025-05-18 18:38:14,802 - INFO - Skipping already processed file (99/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ahmed Elzomr Bridge\\LPO\\P.O 003 Sammix Ready Mix Company - Ahmed Elzomr Bridge.pdf'
# 2025-05-18 18:38:14,911 - INFO - Skipping already processed file (100/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ahmed Elzomr Bridge\\LPO\\P.O 004 Dar Ready Mix Company - Ahmed Elzomr Bridge.pdf'
# 2025-05-18 18:38:14,977 - INFO - Skipping already processed file (101/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ahmed Elzomr Bridge\\LPO\\P.O 005 El-Ola Company - Ahmed Elzomr Bridge.pdf'
# 2025-05-18 18:38:15,083 - INFO - Skipping already processed file (102/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ahmed Elzomr Bridge\\LPO\\P.O 006 Nile Mix Company - Ahmed Elzomr Bridge.pdf'
# 2025-05-18 18:38:15,147 - INFO - Skipping already processed file (103/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ahmed Elzomr Bridge\\LPO\\P.O 007 Steel Com Company - Ahmed Elzomr Bridge.pdf'
# 2025-05-18 18:38:15,328 - INFO - Skipping already processed file (104/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ahmed Elzomr Bridge\\LPO\\P.O 008 Dar Ready Mix Company - Ahmed Elzomr Bridge.pdf'
# 2025-05-18 18:38:15,421 - INFO - Skipping already processed file (105/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ahmed Elzomr Bridge\\LPO\\P.O 009 Beter Mix Ready Mix Company - Ahmed Elzomr Bridge.pdf'
# 2025-05-18 18:38:15,553 - INFO - Skipping already processed file (106/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ain Shams Bridge\\LPO\\P.O 001 Nile Ready Mix Company - Ain Shams Bridge.pdf'
# 2025-05-18 18:38:15,634 - INFO - Skipping already processed file (107/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ain Sokhna Tunnel\\Comparison\\Concrete\\Comparison for Concrete Supply R 03 Signed - Ain Sokhna Tunnel.pdf'
# 2025-05-18 18:38:15,760 - INFO - Skipping already processed file (108/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ain Sokhna Tunnel\\Comparison\\Concrete\\Comparison for Concrete Supply Signed - Ain Sokhna Tunnel.pdf'
# 2025-05-18 18:38:15,846 - INFO - Skipping already processed file (109/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ain Sokhna Tunnel\\Comparison\\Concrete\\Comparison for Concrete Supply Without Cement - Ain Sokhna Tunnel.pdf'
# 2025-05-18 18:38:15,930 - INFO - Skipping already processed file (110/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ain Sokhna Tunnel\\Comparison\\Concrete\\Concreta Supply R00- Ain Sokhna Tunnel.PDF'
# 2025-05-18 18:38:15,994 - INFO - Skipping already processed file (111/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ain Sokhna Tunnel\\Comparison\\Concrete\\Concrete Supply Without Cement- Ain Sokhna Tunnel.PDF'
# 2025-05-18 18:38:16,029 - INFO - Skipping already processed file (112/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ain Sokhna Tunnel\\Comparison\\Insulation Work\\Comparison for Insulation Work Signed - Ain Sokhna Tunnel.pdf'
# 2025-05-18 18:38:16,057 - INFO - Skipping already processed file (113/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ain Sokhna Tunnel\\Comparison\\Neoprene Pads\\Comparison for Neoprene Pads Signed - Ain Sokhna Tunnel.pdf'
# 2025-05-18 18:38:16,181 - INFO - Skipping already processed file (114/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ain Sokhna Tunnel\\Contracts\\الاخوة للمقاولات\\Contract El Ekhwa Company Signed - Ain Sokhna Tunnel.PDF'
# 2025-05-18 18:38:16,425 - INFO - Skipping already processed file (115/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ain Sokhna Tunnel\\Contracts\\الخولي للشحن والتفريغ\\Contract El Kholy Company Signed - Ain Sokhna Tunnel.PDF'
# 2025-05-18 18:38:16,602 - INFO - Skipping already processed file (116/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ain Sokhna Tunnel\\Contracts\\الياسمين للمقاولات والتوريدات\\Contract El Yasmin Company Signed - Ain Sokhna Tunnel.PDF'
# 2025-05-18 18:38:16,966 - INFO - Skipping already processed file (117/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ain Sokhna Tunnel\\Contracts\\سومي مصر\\Contract Somie Masr Company - Ain Sokhna Tunnel.pdf'
# 2025-05-18 18:38:17,212 - INFO - Skipping already processed file (118/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ain Sokhna Tunnel\\Contracts\\عبد الوارث تراك\\Contract Abdelwareth Terak Company Signed - Ain Sokhna Tunnel.PDF'
# 2025-05-18 18:38:17,434 - INFO - Skipping already processed file (119/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ain Sokhna Tunnel\\Contracts\\مكتب بنتا\\Contract Penta Company Signed - Ain Sokhna Tunnel.PDF'
# 2025-05-18 18:38:17,541 - INFO - Skipping already processed file (120/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ain Sokhna Tunnel\\LPO\\P.O 01 El Sweedy Concrete Company Signed - Ain Sokhna Tunnel.pdf'
# 2025-05-18 18:38:17,619 - INFO - Skipping already processed file (121/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ain Sokhna Tunnel\\LPO\\P.O 02 El Sweedy Concrete Company - Ain Sokhna Tunnel.pdf'
# 2025-05-18 18:38:17,820 - INFO - Skipping already processed file (122/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ain Sokhna Tunnel\\LPO\\P.O 03 Lafarge Ready Mix Company - Ain Sokhna Tunnel.pdf'
# 2025-05-18 18:38:17,891 - INFO - Skipping already processed file (123/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ain Sokhna Tunnel\\LPO\\P.O 04 Samco Company.pdf'
# 2025-05-18 18:38:18,106 - INFO - Skipping already processed file (124/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ain Sokhna Tunnel\\LPO\\P.O 05 Unimix Company - Ain Sokhna Tunnel.pdf'
# 2025-05-18 18:38:18,194 - INFO - Skipping already processed file (125/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ain Sokhna Tunnel\\LPO\\P.O 06 Unimix Company - Ain Sokhna Tunnel.pdf'
# 2025-05-18 18:38:18,281 - INFO - Skipping already processed file (126/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ain Sokhna Tunnel\\LPO\\P.O 07 Unimix Company - Ain Sokhna Tunnel.pdf'
# 2025-05-18 18:38:18,363 - INFO - Skipping already processed file (127/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ain Sokhna Tunnel\\LPO\\P.O 08 Unimix Company - Ain Sokhna Tunnel.pdf'
# 2025-05-18 18:38:18,441 - INFO - Skipping already processed file (128/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ain Sokhna Tunnel\\LPO\\P.O 09 El Sweedy Concrete Company - Ain Sokhna Tunnel.pdf'
# 2025-05-18 18:38:18,516 - INFO - Skipping already processed file (129/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ain Sokhna Tunnel 2\\Comparison\\Concrete Supply\\Comparison for Concrete Supply Without Cement - Ain Sokhna Tunnel 2.pdf'
# 2025-05-18 18:38:18,588 - INFO - Skipping already processed file (130/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ain Sokhna Tunnel 2\\Comparison\\Insulation Work\\Comparison for Insulation Work - Ain Sokhna Tunnel 2.pdf'
# 2025-05-18 18:38:18,758 - INFO - Skipping already processed file (131/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ain Sokhna Tunnel 2\\LPO\\P.O 01 Lafarge Ready Mix Company - Ain Sokhna Tunnel 2.pdf'
# 2025-05-18 18:38:18,971 - INFO - Skipping already processed file (132/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Ain Sokhna Tunnel 2\\URSC\\شركة سومي مصر\\Contract Somie Misr Company - Ain Sokhna Tunnel 2.pdf'
# 2025-05-18 18:38:19,006 - INFO - Skipping already processed file (133/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al amal Bridge\\Comparison\\Pedestal\\Pedestal -AL-amal bridge.PDF'
# 2025-05-18 18:38:19,050 - INFO - Skipping already processed file (134/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al amal Bridge\\Comparison\\Piles\\Piles -EL-Amal Bridge.PDF'
# 2025-05-18 18:38:19,137 - INFO - Skipping already processed file (135/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al amal Bridge\\Comparison\\Road & Pavement\\Road & Pavement -El Amal Bridge.PDF'
# 2025-05-18 18:38:19,273 - INFO - Skipping already processed file (136/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al amal Bridge\\Comparison\\Thermal Joints\\Thermal Joints - AL Amal Bridge.PDF'
# 2025-05-18 18:38:19,446 - INFO - Skipping already processed file (137/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al amal Bridge\\Contracts\\الشركة العربية للاساسات  فيبرو\\al amal bridge vibro signd.PDF'
# 2025-05-18 18:38:19,520 - INFO - Skipping already processed file (138/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al amal Bridge\\Contracts\\شركة الاخوة للمقاولات  عرفه محمود عطيه الله حسين وشركاه\\عقد الاخوه - كوبرى الامل - عرفه محمود عطيه.PDF'
# 2025-05-18 18:38:19,688 - INFO - Skipping already processed file (139/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al amal Bridge\\Contracts\\شركة جمال الدين ممدوح بسطويسى\\Al amal bridge  gamal el den  signd.PDF'
# 2025-05-18 18:38:19,791 - INFO - Skipping already processed file (140/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al amal Bridge\\Contracts\\شركة كام للمقاولات\\عقد مقاول توريد سن ورمل---كام للمقاولات--كوبرى الامل.pdf'
# 2025-05-18 18:38:19,856 - INFO - Skipping already processed file (141/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al amal Bridge\\Contracts\\شركة مدحت صالح عبدالونيس\\عقد توريد مياه ----مدحت صالح عبدالونيس----كوبرى الامل.PDF'
# 2025-05-18 18:38:19,951 - INFO - Skipping already processed file (142/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al amal Bridge\\Contracts\\مكتب الرائد للاستشارات الهندسيه\\عقد مكتب الرائد للاستشارات الهندسية1.pdf'
# 2025-05-18 18:38:20,026 - INFO - Skipping already processed file (143/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al amal Bridge\\TPD Purchasing order\\Al amal bridge  attaya p.o 02 signd.PDF'
# 2025-05-18 18:38:20,197 - INFO - Skipping already processed file (144/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al amal Bridge\\TPD Purchasing order\\Dar Ready Mix company 03 - Al Amal Bridge (Lock&Load).PDF'
# 2025-05-18 18:38:20,287 - INFO - Skipping already processed file (145/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al Jazzi Mall\\Comparison\\Membrane\\Comparison for Membrane - Al Jazzi Egypt Mall.pdf'
# 2025-05-18 18:38:20,370 - INFO - Skipping already processed file (146/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al Jazzi Mall\\Comparison\\Membrane\\Comparison for Vertical Protection Board for Membrane Water Proofing R 01 - Al Jazzi Egypt Mall.pdf'
# 2025-05-18 18:38:20,418 - INFO - Skipping already processed file (147/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al Jazzi Mall\\Comparison\\Post Tension Package\\Comparison for Post Tension Package - Al Jazzi Mall.pdf'
# 2025-05-18 18:38:20,509 - INFO - Skipping already processed file (148/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al Jazzi Mall\\Comparison\\Retaining Walls Insulation\\Comparison for Retaining Walls Insulation - Al Jazzi Egypt Mall.pdf'
# 2025-05-18 18:38:20,565 - INFO - Skipping already processed file (149/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al Jazzi Mall\\Comparison\\Supply Concrete\\Comparison for Supply Concrete R 01 - Al Jazzi Egypt Mall.pdf'
# 2025-05-18 18:38:20,623 - INFO - Skipping already processed file (150/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al Jazzi Mall\\Comparison\\Supply Concrete\\Comparison for Supply Concrete Signed - Al Jazzi Egypt Mall.pdf'
# 2025-05-18 18:38:20,710 - INFO - Skipping already processed file (151/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al Jazzi Mall\\Comparison\\Water Tank Insulation & Water Proofing\\Comparison for Water Tank Insulation & Water Proofing - Al Jazzi Egypt Mall.pdf'
# 2025-05-18 18:38:20,783 - INFO - Skipping already processed file (152/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al Jazzi Mall\\Contracts\\A&A Company\\Contract A&A Company - Al Jazzi Egypt Mall.pdf'
# 2025-05-18 18:38:20,833 - INFO - Skipping already processed file (153/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al Jazzi Mall\\Contracts\\CEL\\Contract Add 01 CEL Office - Al Jazzi Egypt Mall.pdf'
# 2025-05-18 18:38:20,894 - INFO - Skipping already processed file (154/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al Jazzi Mall\\Contracts\\شركة احمد خالد\\Contract Ahmed Khaled Company - Al Jazzi Egypt Mall.pdf'
# 2025-05-18 18:38:21,026 - INFO - Skipping already processed file (155/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al Jazzi Mall\\Contracts\\شركة الاهرام للمعدات\\Contract El Ahram Company - Al Jazzi Egypt Mall.pdf'
# 2025-05-18 18:38:21,075 - INFO - Skipping already processed file (156/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al Jazzi Mall\\Contracts\\شركة العزيزية\\Contract Add 01 El Azezya Company - Al Jazzi Egypt Mall.pdf'
# 2025-05-18 18:38:21,198 - INFO - Skipping already processed file (157/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al Jazzi Mall\\Contracts\\شركة العزيزية\\Contract El Azezeya Company - Al Jazzi Egypt Mall.pdf'
# 2025-05-18 18:38:21,269 - INFO - Skipping already processed file (158/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al Jazzi Mall\\Contracts\\شركة اي تي سي\\Contract Add 01 ITC Company - Al Jazzi Egypt Mall.pdf'
# 2025-05-18 18:38:21,494 - INFO - Skipping already processed file (159/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al Jazzi Mall\\Contracts\\شركة اي تي سي\\Contract Add 02 ITC Company - Al Jazzi Egypt Mall.pdf'
# 2025-05-18 18:38:21,874 - INFO - Skipping already processed file (160/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al Jazzi Mall\\Contracts\\شركة اي تي سي\\Contract Add 03 ITC Company - Al Jazzi Egypt Mall.pdf'
# 2025-05-18 18:38:22,023 - INFO - Skipping already processed file (161/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al Jazzi Mall\\Contracts\\شركة اي تي سي\\Contract Add 04 ITC Company - Al Jazzi Mall.pdf'
# 2025-05-18 18:38:22,267 - INFO - Skipping already processed file (162/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al Jazzi Mall\\Contracts\\شركة اي تي سي\\Contract ITC Company - Al Jazzi Egypt Mall.pdf'
# 2025-05-18 18:38:22,299 - INFO - Skipping already processed file (163/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al Jazzi Mall\\Contracts\\شركة عرفة محمد قرني\\Contract Add 02 Arafa Qurani Company - AL Jazzi Egypt Mall.pdf'
# 2025-05-18 18:38:22,439 - INFO - Skipping already processed file (164/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al Jazzi Mall\\Contracts\\شركة عرفة محمد قرني\\Contract Arafa Mohamed Qurani Company - Al Jazzi Egypt Mall.pdf'
# 2025-05-18 18:38:22,609 - INFO - Skipping already processed file (165/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al Jazzi Mall\\Contracts\\شركة فلورتك\\Contract Add 01 Floortec Company - Al Jazzi Egypt Mall.pdf'
# 2025-05-18 18:38:22,855 - INFO - Skipping already processed file (166/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al Jazzi Mall\\Contracts\\شركة فلورتك\\Contract Floortec Company Signed - Al Jazzi Egypt Mall.pdf'
# 2025-05-18 18:38:23,024 - INFO - Skipping already processed file (167/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al Jazzi Mall\\Contracts\\شركة محمد عبد الحليم\\Contract Mohamed Abdelhalim Company Signed - Al Jazzi Egypt Mall.PDF'
# 2025-05-18 18:38:23,228 - INFO - Skipping already processed file (168/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al Jazzi Mall\\Contracts\\شركة مصر ديفيداج\\Contract Add 01 Misr Dywidag Company - Al Jazzi Egypt Mall.pdf'
# 2025-05-18 18:38:23,511 - INFO - Skipping already processed file (169/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al Jazzi Mall\\Contracts\\شركة مصر ديفيداج\\Contract Misr Dywidag Company Signed - Al Jazzi Egypt Mall.pdf'
# 2025-05-18 18:38:23,582 - INFO - Skipping already processed file (170/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al Jazzi Mall\\Contracts\\مكتب العربي\\Contract El Araby Office - Al Jazzi Egypt Mall.pdf'
# 2025-05-18 18:38:23,767 - INFO - Skipping already processed file (171/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al Jazzi Mall\\Contracts\\مكتب نور الدين\\Contract Add 01 Nour El Deen Office - Al Jazzi Egypt Mall.pdf'
# 2025-05-18 18:38:23,857 - INFO - Skipping already processed file (172/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al Jazzi Mall\\Contracts\\مكتب نور الدين\\Contract Nour Eldin Office - Al Jazzi Egypt Mall.pdf'
# 2025-05-18 18:38:23,943 - INFO - Skipping already processed file (173/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al Jazzi Mall\\I.P.O\\I.P.O 01 Dywidag Company - Al Jazzi Egypt Mall.pdf'
# 2025-05-18 18:38:24,014 - INFO - Skipping already processed file (174/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al Jazzi Mall\\I.P.O\\I.P.O 02 Honestever Company - Al Jazzi Egypt Mall.pdf'
# 2025-05-18 18:38:24,262 - INFO - Skipping already processed file (175/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al Jazzi Mall\\LPO\\P.O 01 El Wali Company - Al Jazzi Egypt Mall.pdf'
# 2025-05-18 18:38:24,369 - INFO - Skipping already processed file (176/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al Jazzi Mall\\LPO\\P.O 010 Sermix Company - Al Jazzi Egypt Mall.pdf'
# 2025-05-18 18:38:24,485 - INFO - Skipping already processed file (177/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al Jazzi Mall\\LPO\\P.O 011 Unimix Company - Al Jazzi Egypt Mall.pdf'
# 2025-05-18 18:38:24,607 - INFO - Skipping already processed file (178/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al Jazzi Mall\\LPO\\P.O 012 El Sweedy Ready mix Company - Al Jazzi Mall.pdf'
# 2025-05-18 18:38:24,789 - INFO - Skipping already processed file (179/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Al Jazzi Mall\\LPO\\P.O 013 Al Motaheda Company - Al Jazzi Mall.pdf'
# ...
# 2025-05-19 08:32:25,687 - INFO - Saved PDF Civic gomaa fathy add 01 signd.PDF with 24 chunks to database
# 2025-05-19 08:32:25,689 - INFO - Progress: 1790/16275 PDFs processed
# 2025-05-19 08:32:25,846 - INFO - Processing (1791/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\LOGIEN INTERNATIONAL------1\\توريد وتركيب الاعمال المعدنيه-سيفك.pdf'
# 2025-05-19 08:32:55,380 - INFO - Saved PDF توريد وتركيب الاعمال المعدنيه-سيفك.pdf with 70 chunks to database
# 2025-05-19 08:32:55,429 - INFO - Processing (1792/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\Metal wood---2\\Civic metal wood concept add 01 signd.PDF'
# 2025-05-19 08:33:01,019 - INFO - Saved PDF Civic metal wood concept add 01 signd.PDF with 12 chunks to database
# 2025-05-19 08:33:01,243 - INFO - Processing (1793/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\Metal wood---2\\metal wood signd.PDF'
# 2025-05-19 08:34:36,636 - INFO - Saved PDF metal wood signd.PDF with 187 chunks to database
# 2025-05-19 08:34:36,844 - INFO - Processing (1794/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\Mido--------------1\\Civic mido signd.PDF'
# 2025-05-19 08:35:34,719 - INFO - Saved PDF Civic mido signd.PDF with 113 chunks to database
# 2025-05-19 08:35:35,205 - INFO - Processing (1795/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\MOROOJ---------2\\اعمال كهرباء.pdf'
# 2025-05-19 09:03:51,931 - INFO - Saved PDF اعمال كهرباء.pdf with 479 chunks to database
# 2025-05-19 09:03:51,934 - INFO - Progress: 1795/16275 PDFs processed
# 2025-05-19 09:03:51,997 - INFO - Processing (1796/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\MOROOJ---------2\\ملجق عقد1   توريد وتركيب  الاعمال الميكانيكيه والكهربائيه------مروج-----سيفك.PDF'
# 2025-05-19 09:04:19,186 - INFO - Saved PDF ملجق عقد1   توريد وتركيب  الاعمال الميكانيكيه والكهربائيه------مروج-----سيفك.PDF with 85 chunks to database
# 2025-05-19 09:04:19,345 - INFO - Processing (1797/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\WOOD AND MORE----------2\\اعمال مصنعيات توريد وتركيب اعمال WPC والبرجولات.pdf'
# 2025-05-19 09:11:04,363 - INFO - Saved PDF اعمال مصنعيات توريد وتركيب اعمال WPC والبرجولات.pdf with 121 chunks to database
# 2025-05-19 09:11:04,604 - INFO - Processing (1798/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\WOOD AND MORE----------2\\توريد وتركيب glass reinforced concrete  GRC.pdf'
# 2025-05-19 09:13:39,689 - INFO - Saved PDF توريد وتركيب glass reinforced concrete  GRC.pdf with 38 chunks to database
# 2025-05-19 09:13:39,839 - INFO - Processing (1799/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\ابراهيم رجب السيد----1\\توريد وتركيب الحجر الطبيعى الهاشما.pdf'
# 2025-05-19 09:14:01,228 - INFO - Saved PDF توريد وتركيب الحجر الطبيعى الهاشما.pdf with 39 chunks to database
# 2025-05-19 09:14:01,441 - INFO - Processing (1800/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\ابناء رشيد للانشاءات والتوريدات والمقاولات العمومية --------2\\ابناء رشيد--- ايجار معدات وتوريد خامات.pdf'
# 2025-05-19 09:16:10,545 - INFO - Saved PDF ابناء رشيد--- ايجار معدات وتوريد خامات.pdf with 39 chunks to database
# 2025-05-19 09:16:10,547 - INFO - Progress: 1800/16275 PDFs processed
# 2025-05-19 09:16:10,594 - INFO - Processing (1801/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\ابناء رشيد للانشاءات والتوريدات والمقاولات العمومية --------2\\ملحق عقد علاوة على ايجار معدات وتوريد خامات--ابنا رشيد--السفك.pdf'
# 2025-05-19 09:16:14,355 - INFO - Saved PDF ملحق عقد علاوة على ايجار معدات وتوريد خامات--ابنا رشيد--السفك.pdf with 6 chunks to database
# 2025-05-19 09:16:14,425 - INFO - Processing (1802/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\احمد مصطفى عبد الرازق محفوظ----2\\عقد اعمال توريد وتنفيذ اعمال الدهانات والالواح جبسية واعمال تركيب السيراميك والبورسلين - سيفك سنتر.PDF'
# 2025-05-19 09:16:38,510 - INFO - Saved PDF عقد اعمال توريد وتنفيذ اعمال الدهانات والالواح جبسية واعمال تركيب السيراميك والبورسلين - سيفك سنتر.PDF with 43 chunks to database
# 2025-05-19 09:16:38,540 - INFO - Processing (1803/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\احمد مصطفى عبد الرازق محفوظ----2\\ملحق اعمال توريد وتنفيذ بئر جوفى-----احمد مصطفى-------سيفك.PDF'
# 2025-05-19 09:16:41,020 - INFO - Saved PDF ملحق اعمال توريد وتنفيذ بئر جوفى-----احمد مصطفى-------سيفك.PDF with 5 chunks to database
# 2025-05-19 09:16:41,110 - INFO - Processing (1804/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\اف ام ام اس-----------2\\توريد وتنفيذ اعمال محارة.pdf'
# 2025-05-19 09:17:03,028 - INFO - Saved PDF توريد وتنفيذ اعمال محارة.pdf with 41 chunks to database
# 2025-05-19 09:17:03,179 - INFO - Processing (1805/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\اف ام ام اس-----------2\\عقد مصنعيات اعمال محارة-سيفك.pdf'
# 2025-05-19 09:17:19,628 - INFO - Saved PDF عقد مصنعيات اعمال محارة-سيفك.pdf with 19 chunks to database
# 2025-05-19 09:17:19,631 - INFO - Progress: 1805/16275 PDFs processed
# 2025-05-19 09:17:19,839 - INFO - Processing (1806/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\الحديثة للاسقف المعلقة--------1\\توريد وتركيب البلاطات الجبسية واسقف جبسية وقواطيع.pdf'
# 2025-05-19 09:19:49,424 - INFO - Saved PDF توريد وتركيب البلاطات الجبسية واسقف جبسية وقواطيع.pdf with 32 chunks to database
# 2025-05-19 09:19:49,454 - INFO - Processing (1807/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\الدخيلى للمقاولات والتوريدات-----2\\عقد مقاول باطن ايجار معدات -سيفك سنتر.PDF'
# 2025-05-19 09:20:07,152 - INFO - Saved PDF عقد مقاول باطن ايجار معدات -سيفك سنتر.PDF with 43 chunks to database
# 2025-05-19 09:20:07,192 - INFO - Processing (1808/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\الدخيلى للمقاولات والتوريدات-----2\\ملحق ايجار معدات -سيفك.PDF'
# 2025-05-19 09:20:09,039 - INFO - Saved PDF ملحق ايجار معدات -سيفك.PDF with 5 chunks to database
# 2025-05-19 09:20:09,266 - INFO - Processing (1809/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\الشرباصى جى يو تك----2\\اعمال توريد وتنفيذ بئر جوفى.pdf'
# 2025-05-19 09:22:15,950 - INFO - Saved PDF اعمال توريد وتنفيذ بئر جوفى.pdf with 31 chunks to database
# 2025-05-19 09:22:16,057 - INFO - Processing (1810/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\الشرباصى جى يو تك----2\\ملحق اعمال توريد وتنفيذ بئر جوفى.pdf'
# 2025-05-19 09:22:33,440 - INFO - Saved PDF ملحق اعمال توريد وتنفيذ بئر جوفى.pdf with 3 chunks to database
# 2025-05-19 09:22:33,442 - INFO - Progress: 1810/16275 PDFs processed
# 2025-05-19 09:22:33,608 - INFO - Processing (1811/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\العربية للمقاولات التخصصية------3\\اعمال الحدادة للخرسانة المسلحة.pdf'
# 2025-05-19 09:25:07,712 - INFO - Saved PDF اعمال الحدادة للخرسانة المسلحة.pdf with 47 chunks to database
# 2025-05-19 09:25:07,741 - INFO - Processing (1812/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\العربية للمقاولات التخصصية------3\\ملحق اعمال مصنعيات الحداده للارضيات-سيفك سنتر.PDF'
# 2025-05-19 09:25:09,715 - INFO - Saved PDF ملحق اعمال مصنعيات الحداده للارضيات-سيفك سنتر.PDF with 5 chunks to database
# 2025-05-19 09:25:09,767 - INFO - Processing (1813/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\العربية للمقاولات التخصصية------3\\ملحق عقد اعمال الحدادة للخرسانة المسلحة -سيفك سنتر.PDF'
# 2025-05-19 09:25:12,490 - INFO - Saved PDF ملحق عقد اعمال الحدادة للخرسانة المسلحة -سيفك سنتر.PDF with 6 chunks to database
# 2025-05-19 09:25:12,589 - INFO - Processing (1814/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\العربيه للخدات الهندسيه-------2\\اعمال توريد بالتات حديد.pdf'
# 2025-05-19 09:25:31,191 - INFO - Saved PDF اعمال توريد بالتات حديد.pdf with 34 chunks to database
# 2025-05-19 09:25:31,241 - INFO - Processing (1815/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\العربيه للخدات الهندسيه-------2\\اعمال توريد بلتات حديد مجلفنه.pdf'
# 2025-05-19 09:25:33,535 - INFO - Saved PDF اعمال توريد بلتات حديد مجلفنه.pdf with 4 chunks to database
# 2025-05-19 09:25:33,536 - INFO - Progress: 1815/16275 PDFs processed
# 2025-05-19 09:25:33,641 - INFO - Processing (1816/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\الفرج للمقاولات المتكاملة وتوريد مواد البناء----1\\عقد تركيب انترلوك -سيفك سنتر.pdf'
# 2025-05-19 09:25:53,387 - INFO - Saved PDF عقد تركيب انترلوك -سيفك سنتر.pdf with 35 chunks to database
# 2025-05-19 09:25:53,564 - INFO - Processing (1817/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\الفهد للمقاولات والتوريدات العامة-----2\\ايجار معدات وتوريد خامات.pdf'
# 2025-05-19 09:27:59,014 - INFO - Saved PDF ايجار معدات وتوريد خامات.pdf with 32 chunks to database
# 2025-05-19 09:27:59,090 - INFO - Processing (1818/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\الفهد للمقاولات والتوريدات العامة-----2\\ملحق عقد على ايجار معدات وتوريد خامات--الفهد للمقاولات والتوريدات العامة--السفك سنتر.pdf'
# 2025-05-19 09:28:01,899 - INFO - Saved PDF ملحق عقد على ايجار معدات وتوريد خامات--الفهد للمقاولات والتوريدات العامة--السفك سنتر.pdf with 3 chunks to database
# 2025-05-19 09:28:01,975 - INFO - Processing (1819/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\القدس ستيل--------1\\اعمال وتركيب شاسيه معدنى.PDF'
# 2025-05-19 09:28:23,650 - INFO - Saved PDF اعمال وتركيب شاسيه معدنى.PDF with 44 chunks to database
# 2025-05-19 09:28:23,774 - INFO - Processing (1820/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\المستقبل للتوريدات والمقاولات المتخصصه------1\\عقد توريد وتركيب اعمال مجارى الهواء ----المستقبل----سيفك.PDF'
# 2025-05-19 09:28:54,479 - INFO - Saved PDF عقد توريد وتركيب اعمال مجارى الهواء ----المستقبل----سيفك.PDF with 55 chunks to database
# 2025-05-19 09:28:54,481 - INFO - Progress: 1820/16275 PDFs processed
# 2025-05-19 09:28:54,563 - INFO - Processing (1821/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\المصرية لتكنولجيا الزجاج(د جريش )-------1\\عقد أعمال الزجاج والمرايات شامل الاكسسوارات-السيفك سنتر.PDF'
# 2025-05-19 09:29:36,183 - INFO - Saved PDF عقد أعمال الزجاج والمرايات شامل الاكسسوارات-السيفك سنتر.PDF with 85 chunks to database
# 2025-05-19 09:29:36,358 - INFO - Processing (1822/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\المصطفى للمقاولات العامة والتوريدات----4\\عقد اعمال توريد وتركيب رخام وجرانيت - السيفك.pdf'
# 2025-05-19 09:30:01,176 - INFO - Saved PDF عقد اعمال توريد وتركيب رخام وجرانيت - السيفك.pdf with 49 chunks to database
# 2025-05-19 09:30:01,314 - INFO - Processing (1823/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\المصطفى للمقاولات العامة والتوريدات----4\\عقد اعمال توريد وتركيب رخام وجرانيت ----المصطفى----سيفك سنتر.PDF'
# 2025-05-19 09:31:11,665 - INFO - Saved PDF عقد اعمال توريد وتركيب رخام وجرانيت ----المصطفى----سيفك سنتر.PDF with 216 chunks to database
# 2025-05-19 09:31:11,722 - INFO - Processing (1824/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\المصطفى للمقاولات العامة والتوريدات----4\\ملحق 2 اعمال توريد وتركيب رخام وجرانيت ----المصطفى-----سيفك.PDF'
# 2025-05-19 09:31:13,919 - INFO - Saved PDF ملحق 2 اعمال توريد وتركيب رخام وجرانيت ----المصطفى-----سيفك.PDF with 6 chunks to database
# 2025-05-19 09:31:13,980 - INFO - Processing (1825/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\المصطفى للمقاولات العامة والتوريدات----4\\ملحق توريد وتركيب رخام وجرانيت.PDF'
# 2025-05-19 09:31:20,459 - INFO - Saved PDF ملحق توريد وتركيب رخام وجرانيت.PDF with 17 chunks to database
# 2025-05-19 09:31:20,461 - INFO - Progress: 1825/16275 PDFs processed
# 2025-05-19 09:31:20,554 - INFO - Processing (1826/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\الهدى ميتال دورز------3\\توريد وتركيب ودهان الابواب المعدنيه والخردوات.pdf'
# 2025-05-19 09:31:47,114 - INFO - Saved PDF توريد وتركيب ودهان الابواب المعدنيه والخردوات.pdf with 58 chunks to database
# 2025-05-19 09:31:47,181 - INFO - Processing (1827/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\الهدى ميتال دورز------3\\عقد اعمال توريد وتركيب الابواب المعدنيه----الهدى ميتال دورز-----سيفك.pdf'
# 2025-05-19 09:32:13,763 - INFO - Saved PDF عقد اعمال توريد وتركيب الابواب المعدنيه----الهدى ميتال دورز-----سيفك.pdf with 54 chunks to database
# 2025-05-19 09:32:13,863 - INFO - Processing (1828/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\الهدى ميتال دورز------3\\عقد توريد وتركيب ودهان الابواب المعدنيه----الهدى-----سيفك.PDF'
# 2025-05-19 09:32:35,764 - INFO - Saved PDF عقد توريد وتركيب ودهان الابواب المعدنيه----الهدى-----سيفك.PDF with 47 chunks to database
# 2025-05-19 09:32:35,911 - INFO - Processing (1829/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\ايه -بيلد ايجبت للمقاولات--------1\\توريد وتركيب اعمال العزل.pdf'
# 2025-05-19 09:35:30,157 - INFO - Saved PDF توريد وتركيب اعمال العزل.pdf with 51 chunks to database
# 2025-05-19 09:35:30,334 - INFO - Processing (1830/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\بايلا للاعمال البحرية---------1\\توريد وتركيب اعمال دهانات داخلية وخارجية.pdf'
# 2025-05-19 09:37:42,473 - INFO - Saved PDF توريد وتركيب اعمال دهانات داخلية وخارجية.pdf with 36 chunks to database
# 2025-05-19 09:37:42,475 - INFO - Progress: 1830/16275 PDFs processed
# 2025-05-19 09:37:42,630 - INFO - Processing (1831/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\توب للخدمات الهندسية-----------1\\اعداد الرسومات التنفيذية.pdf'
# 2025-05-19 09:39:25,523 - INFO - Saved PDF اعداد الرسومات التنفيذية.pdf with 30 chunks to database
# 2025-05-19 09:39:25,706 - INFO - Processing (1832/16275): '//fileserver2/Head Office Server/Procurement (PR)/02 Projects Document\\02-01 Finish\\Civic center\\CONTRACTS\\ثروت توفيق محمد عبد المولى----------2\\اعمال النجارة للخرسانة المسلحة والعادية.pdf'
