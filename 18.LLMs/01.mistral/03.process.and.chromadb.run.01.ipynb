# %%
import os
import json
import pdfplumber
import pytesseract
from PIL import Image
import pandas as pd
from datetime import datetime
from docx import Document
from pptx import Presentation
import warnings
import re
import zipfile
import rarfile
import tempfile
import shutil

# Suppress specific CropBox warning from pdfplumber
import logging
logging.getLogger("pdfminer").setLevel(logging.ERROR)

class CropBoxFilter:
    def filter(self, record):
        return not (record.levelno == logging.WARNING and 'CropBox missing from /Page, defaulting to MediaBox' in record.getMessage())

logging.getLogger().addFilter(CropBoxFilter())

# Add tkinter for folder selection
def select_folder():
    import tkinter as tk
    from tkinter import filedialog
    root = tk.Tk()
    root.withdraw()
    folder_selected = filedialog.askdirectory(title='Select folder to process')
    root.destroy()
    return folder_selected

def extract_text_from_pdf(pdf_path):
    text = ""
    try:
        with pdfplumber.open(pdf_path) as pdf:
            for page in pdf.pages:
                page_text = page.extract_text()
                if page_text:
                    text += page_text + "\n"
    except Exception:
        pass
    return text.strip()

def ocr_pdf(pdf_path):
    text = ""
    try:
        with pdfplumber.open(pdf_path) as pdf:
            for page in pdf.pages:
                img = page.to_image(resolution=300).original
                pil_img = Image.fromarray(img)
                page_text = pytesseract.image_to_string(pil_img)
                if page_text:
                    text += page_text + "\n"
    except Exception:
        pass
    return text.strip()

def extract_project_name(file_path):
    # Try to extract project name from folder path or filename
    path_parts = os.path.normpath(file_path).split(os.sep)
    # Remove common non-project folders
    ignore = set(['', '2024', '2025', '2023', '2022', '2021', '2020', 'Mar. 2024', 'Jan-25', '3-Mar-2025', '01 Jan-25'])
    # Look for a likely project name in the path
    for part in reversed(path_parts[:-1]):
        if part not in ignore and not re.match(r'\d{4}', part):
            return part
    # Try to extract from filename
    fname = os.path.basename(file_path)
    match = re.search(r'([A-Za-z0-9\- ]+Project|[A-Za-z0-9\- ]+Dashboard|[A-Za-z0-9\- ]+Lot|[A-Za-z0-9\- ]+Port|[A-Za-z0-9\- ]+Sector)', fname)
    if match:
        return match.group(0)
    # If nothing found, label as GLOBAL
    return 'GLOBAL'

def extract_text_from_excel(excel_path):
    text = ""
    try:
        ext = excel_path.lower().split('.')[-1]
        if ext == 'xlsb':
            xls = pd.ExcelFile(excel_path, engine='pyxlsb')
        else:
            xls = pd.ExcelFile(excel_path)
        for sheet_name in xls.sheet_names:
            df = pd.read_excel(xls, sheet_name=sheet_name, dtype=str)
            # Only extract if <1000 rows and <30 columns and has headers
            if df.shape[0] < 1000 and df.shape[1] < 30 and all(df.columns.str.strip() != ''):
                text += f"\n--- Sheet: {sheet_name} ---\n"
                text += df.fillna('').to_csv(index=False)
    except Exception:
        pass
    return text.strip()

def extract_text_from_docx(docx_path):
    text = ""
    try:
        doc = Document(docx_path)
        for para in doc.paragraphs:
            text += para.text + "\n"
    except Exception:
        pass
    return text.strip()

def extract_text_from_pptx(pptx_path):
    text = ""
    try:
        prs = Presentation(pptx_path)
        for slide in prs.slides:
            for shape in slide.shapes:
                if hasattr(shape, "text"):
                    text += shape.text + "\n"
    except Exception:
        pass
    return text.strip()

def extract_text_from_ppt(file_path):
    """Attempt to convert .ppt to .pptx using unoconv, then extract text."""
    import subprocess
    import tempfile
    text = ""
    try:
        with tempfile.TemporaryDirectory() as tmpdir:
            pptx_path = os.path.join(tmpdir, os.path.basename(file_path) + '.pptx')
            # Try to convert .ppt to .pptx using unoconv
            result = subprocess.run([
                'unoconv', '-f', 'pptx', '-o', pptx_path, file_path
            ], capture_output=True)
            if result.returncode == 0 and os.path.exists(pptx_path):
                text = extract_text_from_pptx(pptx_path)
            else:
                print(f"[WARN] Failed to convert .ppt to .pptx: {file_path}")
    except Exception as e:
        print(f"[WARN] Exception during .ppt conversion: {file_path} | {e}")
    return text.strip()

def extract_text_from_pbix(pbix_path):
    """Try to extract text from .pbix by unzipping and reading .json/.xml files inside."""
    import zipfile
    import tempfile
    text = ""
    try:
        with zipfile.ZipFile(pbix_path, 'r') as z:
            with tempfile.TemporaryDirectory() as tmpdir:
                z.extractall(tmpdir)
                for root, _, files in os.walk(tmpdir):
                    for file in files:
                        if file.endswith('.json') or file.endswith('.xml'):
                            try:
                                with open(os.path.join(root, file), 'r', encoding='utf-8', errors='ignore') as f:
                                    content = f.read()
                                    # Only keep text if it's not too large
                                    if len(content) < 500_000:
                                        text += f"\n--- {file} ---\n" + content
                            except Exception:
                                continue
    except Exception as e:
        print(f"[WARN] Failed to extract .pbix: {pbix_path} | {e}")
    return text.strip()

def extract_text_from_doc(doc_path):
    """Convert .doc to .docx using unoconv, then extract text."""
    import subprocess
    import tempfile
    import os
    text = ""
    try:
        with tempfile.TemporaryDirectory() as tmpdir:
            docx_path = os.path.join(tmpdir, os.path.basename(doc_path) + '.docx')
            result = subprocess.run([
                'unoconv', '-f', 'docx', '-o', docx_path, doc_path
            ], capture_output=True)
            if result.returncode == 0 and os.path.exists(docx_path):
                text = extract_text_from_docx(docx_path)
            else:
                print(f"[WARN] Failed to convert .doc to .docx: {doc_path}")
    except Exception as e:
        print(f"[WARN] Exception during .doc conversion: {doc_path} | {e}")
    return text.strip()

def process_file(file_path, data):
    ext = file_path.lower().split('.')[-1]
    project = extract_project_name(file_path)
    print(f"[INFO] Processing file: {os.path.basename(file_path)} | Project: {project}")
    entry = {
        'file_name': os.path.basename(file_path),
        'file_path': file_path,
        'type': ext,
        'project': project,
        'extracted_at': datetime.now().isoformat(),
        'text': ''
    }
    reason = None
    if ext == 'pdf':
        text = extract_text_from_pdf(file_path)
        if not text:
            text = ocr_pdf(file_path)
            if text:
                reason = 'extracted via OCR'
            else:
                reason = 'no text extracted (PDF and OCR failed)'
        else:
            reason = 'extracted as text PDF'
        entry['text'] = text
    elif ext in ['xls', 'xlsx', 'xlsb']:
        text = extract_text_from_excel(file_path)
        entry['text'] = text
        reason = 'extracted from Excel' if text else 'no text extracted (Excel)'
    elif ext == 'docx':
        text = extract_text_from_docx(file_path)
        entry['text'] = text
        reason = 'extracted from Word' if text else 'no text extracted (Word)'
    elif ext in ['pptx', 'pptm']:
        text = extract_text_from_pptx(file_path)
        entry['text'] = text
        reason = 'extracted from PowerPoint' if text else 'no text extracted (PowerPoint)'
    elif ext == 'ppt':
        text = extract_text_from_ppt(file_path)
        entry['text'] = text
        reason = 'extracted from PPT (via conversion)' if text else 'no text extracted (PPT)'
    elif ext == 'pbix':
        text = extract_text_from_pbix(file_path)
        entry['text'] = text
        reason = 'extracted from PBIX' if text else 'no text extracted (PBIX)'
    elif ext == 'doc':
        text = extract_text_from_doc(file_path)
        entry['text'] = text
        reason = 'extracted from DOC (via conversion)' if text else 'no text extracted (DOC)'
    else:
        print(f"[WARN] Skipped unsupported file type: {os.path.basename(file_path)}")
        return
    if entry['text']:
        data.append(entry)
    else:
        print(f"[WARN] No text extracted from: {os.path.basename(file_path)} ({reason})")

def process_folder(folder_path, output_json_path):
    data = []
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            file_path = os.path.join(root, file)
            ext = file.lower().split('.')[-1]
            if ext in ['zip', 'rar']:
                print(f"[INFO] Extracting archive: {file}")
                with tempfile.TemporaryDirectory() as tmpdir:
                    try:
                        if ext == 'zip':
                            with zipfile.ZipFile(file_path, 'r') as z:
                                z.extractall(tmpdir)
                        elif ext == 'rar':
                            with rarfile.RarFile(file_path, 'r') as r:
                                r.extractall(tmpdir)
                        # Recursively process extracted files
                        for subroot, _, subfiles in os.walk(tmpdir):
                            for subfile in subfiles:
                                subfile_path = os.path.join(subroot, subfile)
                                process_file(subfile_path, data)
                    except Exception as e:
                        print(f"[WARN] Failed to extract {file}: {e}")
            else:
                process_file(file_path, data)
    with open(output_json_path, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=2)
    print(f"Processed {len(data)} documents. Output saved to {output_json_path}")

if __name__ == "__main__":
    # New output directory outside the repo
    output_dir = r'C:/Users/Omar Essam2/OneDrive - Rowad Modern Engineering/x004 Data Science/03.rme.db/05.llm/extracted_json'
    os.makedirs(output_dir, exist_ok=True)
    folder = select_folder()
    if not folder:
        print("No folder selected. Exiting.")
    else:
        folder_name = os.path.basename(os.path.normpath(folder))
        output_json = os.path.join(output_dir, f"{folder_name}_extracted.json")
        process_folder(folder, output_json)
# Out:
# [INFO] Processing file: 0. July Commercial & Residential Sector .xlsx | Project: Residential & Commercial (LOAI)
# [WARN] No text extracted from: 0. July Commercial & Residential Sector .xlsx (no text extracted (Excel))
# [INFO] Processing file: 0. July Commercial & Residential sector.pbix | Project: Residential & Commercial (LOAI)
# [INFO] Processing file: 0. August Army Sector.xlsx | Project: Army Sector (Amr Zaki)
# [WARN] No text extracted from: 0. August Army Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. August Army sector.pbix | Project: Army Sector (Amr Zaki)
# [INFO] Processing file: Bridges Sector All Data (2023.08.30).xlsx | Project: Bridges Sector (Omar Essam)
# [WARN] No text extracted from: Bridges Sector All Data (2023.08.30).xlsx (no text extracted (Excel))
# [INFO] Processing file: Bridges Sector Cash Position (2023.08.30).pdf | Project: Bridges Sector (Omar Essam)
# [INFO] Processing file: Bridges Sector Cash Position Justification.pdf | Project: Bridges Sector (Omar Essam)
# [INFO] Processing file: Bridges Sector Planning Status 2023.09.04.pbix | Project: Bridges Sector (Omar Essam)
# [INFO] Processing file: 0. August Industrial Sector .xlsx | Project: Industrial Sector (Amr Zaki)
# [WARN] No text extracted from: 0. August Industrial Sector .xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. August Industrial sector.pbix | Project: Industrial Sector (Amr Zaki)
# [INFO] Processing file: 0. August Infrastructure & Governmental Sector.xlsx | Project: Infrastructure & Governmental Sector (Ghonemi)
# [WARN] No text extracted from: 0. August Infrastructure & Governmental Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. August Infrastructure & Governmental sector.pbix | Project: Infrastructure & Governmental Sector (Ghonemi)
# [INFO] Processing file: 0. August Commercial & Residential Sector.xlsx | Project: Residential & Commercial (LOAI)
# [WARN] No text extracted from: 0. August Commercial & Residential Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. August Commercial & Residential sector.pbix | Project: Residential & Commercial (LOAI)
# [INFO] Processing file: Bridges Sector Control Dashboard (2023.09.30).pbix | Project: Bridges Sector (Omar Essam)
# [INFO] Processing file: 0. September Infrastructure & Governmental Sector.xlsx | Project: Infrastructure & Governmental Sector (Ghonemi)
# [WARN] No text extracted from: 0. September Infrastructure & Governmental Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. September Infrastructure & Governmental sector.pbix | Project: Infrastructure & Governmental Sector (Ghonemi)
# [INFO] Processing file: 0. September Commercial & Residential Sector.xlsx | Project: Residential & Commercial (LOAI)
# [WARN] No text extracted from: 0. September Commercial & Residential Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. September Commercial & Residential sector.pbix | Project: Residential & Commercial (LOAI)
# [INFO] Processing file: 0. October Army Sector.xlsx | Project: Army Sector (Amr Zaki)
# [WARN] No text extracted from: 0. October Army Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. October Army sector.pbix | Project: Army Sector (Amr Zaki)
# [INFO] Processing file: 0. October Industrial Sector.xlsx | Project: Industrial Sector (Amr Zaki)
# [WARN] No text extracted from: 0. October Industrial Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. October Industrial sector.pbix | Project: Industrial Sector (Amr Zaki)
# [INFO] Processing file: 0. October Infrastructure & Governmental Sector.xlsx | Project: Infrastructure & Governmental Sector (Ghonemi)
# [WARN] No text extracted from: 0. October Infrastructure & Governmental Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. October Infrastructure & Governmental sector.pbix | Project: Infrastructure & Governmental Sector (Ghonemi)
# [INFO] Processing file: 0. October Commercial & Residential Sector.xlsx | Project: Residential & Commercial (LOAI)
# [WARN] No text extracted from: 0. October Commercial & Residential Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. October Commercial & Residential sector.pbix | Project: Residential & Commercial (LOAI)
# [INFO] Processing file: 0. October Army Sector.xlsx | Project: Army Sector (Amr Zaki)
# [WARN] No text extracted from: 0. October Army Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. October Army sector.pbix | Project: Army Sector (Amr Zaki)
# [INFO] Processing file: 0. October Industrial Sector.xlsx | Project: Industrial Sector (Amr Zaki)
# [WARN] No text extracted from: 0. October Industrial Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. October Industrial sector.pbix | Project: Industrial Sector (Amr Zaki)
# [INFO] Processing file: 0. October Infrastructure & Governmental Sector.xlsx | Project: Infrastructure & Governmental Sector (Ghonemi)
# [WARN] No text extracted from: 0. October Infrastructure & Governmental Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. October Infrastructure & Governmental sector.pbix | Project: Infrastructure & Governmental Sector (Ghonemi)
# [INFO] Processing file: 0. October Commercial & Residential Sector.xlsx | Project: Residential & Commercial (LOAI)
# [WARN] No text extracted from: 0. October Commercial & Residential Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. October Commercial & Residential sector.pbix | Project: Residential & Commercial (LOAI)
# [INFO] Processing file: Google Sheets Update.xlsx | Project: 12. December-2023
# [WARN] No text extracted from: Google Sheets Update.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Army Sector - .pbix | Project: Army Sector (Amr Zaki)
# [INFO] Processing file: Army Sector .xlsx | Project: Army Sector (Amr Zaki)
# [WARN] No text extracted from: Army Sector .xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB C&R Sector.pbix | Project: C&R Sector (Loay)
# [INFO] Processing file: Commercial & Residential Sector .xlsx | Project: C&R Sector (Loay)
# [WARN] No text extracted from: Commercial & Residential Sector .xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB LE Galawa.pbix | Project: Comoros Le Galawa (Mahmoud)
# [INFO] Processing file: Comros Le Galawa.xlsx | Project: Comoros Le Galawa (Mahmoud)
# [WARN] No text extracted from: Comros Le Galawa.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Governmental Sector.pbix | Project: Governmental Sector (Ahmed El Ghoneimy)
# [INFO] Processing file: Governmental Sector.xlsx | Project: Governmental Sector (Ahmed El Ghoneimy)
# [WARN] No text extracted from: Governmental Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Industrial Sector.pbix | Project: Industrial Sector (Amr Zaki)
# [INFO] Processing file: Industrial Sector.xlsx | Project: Industrial Sector (Amr Zaki)
# [WARN] No text extracted from: Industrial Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Infra Structure.pbix | Project: Infrastructure Sector (Ahmed El Ghoneimy)
# [INFO] Processing file: Infrastructure Sector.xlsx | Project: Infrastructure Sector (Ahmed El Ghoneimy)
# [WARN] No text extracted from: Infrastructure Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Radamis.pbix | Project: Radamis (Amr Zaki)
# [INFO] Processing file: Radamis.xlsx | Project: Radamis (Amr Zaki)
# [WARN] No text extracted from: Radamis.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Jawhara.pbix | Project: Restoration Sector (Heba Mahmoud)
# [INFO] Processing file: Jawhara.xlsx | Project: Restoration Sector (Heba Mahmoud)
# [WARN] No text extracted from: Jawhara.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Army Sector - .pbix | Project: Army Sector (Amr Zaki)
# [INFO] Processing file: Army Sector .xlsx | Project: Army Sector (Amr Zaki)
# [WARN] No text extracted from: Army Sector .xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Bridges Sector.pbix | Project: Bridges Sector
# [INFO] Processing file: Bridges Sector.xlsx | Project: Bridges Sector
# [WARN] No text extracted from: Bridges Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB C&R Sector.pbix | Project: C&R Sector (Loay)
# [INFO] Processing file: Commercial & Residential Sector .xlsx | Project: C&R Sector (Loay)
# [WARN] No text extracted from: Commercial & Residential Sector .xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB LE Galawa.pbix | Project: Comoros Le Galawa (Mahmoud)
# [INFO] Processing file: Comros Le Galawa.xlsx | Project: Comoros Le Galawa (Mahmoud)
# [WARN] No text extracted from: Comros Le Galawa.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Governmental Sector.pbix | Project: Governmental Sector (Ahmed El Ghoneimy)
# [INFO] Processing file: Governmental Sector.xlsx | Project: Governmental Sector (Ahmed El Ghoneimy)
# [WARN] No text extracted from: Governmental Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Industrial Sector.pbix | Project: Industrial Sector (Hany arafat)
# [INFO] Processing file: Industrial Sector.xlsx | Project: Industrial Sector (Hany arafat)
# [WARN] No text extracted from: Industrial Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Infra Structure.pbix | Project: Infrastructure Sector (Ahmed El Ghoneimy)
# [INFO] Processing file: Infrastructure Sector.xlsx | Project: Infrastructure Sector (Ahmed El Ghoneimy)
# [WARN] No text extracted from: Infrastructure Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Koumassi.pbix | Project: Koumassi
# [INFO] Processing file: Côte d'Ivoire Koumassi .xlsx | Project: Koumassi
# [WARN] No text extracted from: Côte d'Ivoire Koumassi .xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Radamis.pbix | Project: Radamis (Amr Zaki)
# [INFO] Processing file: Radamis.xlsx | Project: Radamis (Amr Zaki)
# [WARN] No text extracted from: Radamis.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Jawhara.pbix | Project: Restoration Sector (Heba Mahmoud)
# [INFO] Processing file: Jawhara.xlsx | Project: Restoration Sector (Heba Mahmoud)
# [WARN] No text extracted from: Jawhara.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Army Sector .pbix | Project: Army Sector (Amr Zaki)
# [INFO] Processing file: Army Sector.xlsx | Project: Army Sector (Amr Zaki)
# [WARN] No text extracted from: Army Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Bridges Sector.pbix | Project: Bridges Sector
# [INFO] Processing file: Bridges Sector.xlsx | Project: Bridges Sector
# [WARN] No text extracted from: Bridges Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB C&R Sector.pbix | Project: C&R Sector (Loay)
# [INFO] Processing file: Commercial & Residential Sector .xlsx | Project: C&R Sector (Loay)
# [WARN] No text extracted from: Commercial & Residential Sector .xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Governmental Sector.pbix | Project: Governmental Sector (Ahmed El Ghoneimy)
# [INFO] Processing file: Governmental Sector.xlsx | Project: Governmental Sector (Ahmed El Ghoneimy)
# [WARN] No text extracted from: Governmental Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Industrial Sector.pbix | Project: Industrial Sector (Hany arafat)
# [INFO] Processing file: Industrial Sector  (1).xlsx | Project: Industrial Sector (Hany arafat)
# [WARN] No text extracted from: Industrial Sector  (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Infra Structure.pbix | Project: Infrastructure Sector (Ahmed El Ghoneimy)
# [INFO] Processing file: Infrastructure Sector.xlsx | Project: Infrastructure Sector (Ahmed El Ghoneimy)
# [WARN] No text extracted from: Infrastructure Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Koumassi.pbix | Project: Koumassi
# [INFO] Processing file: Côte d'Ivoire Koumassi.xlsx | Project: Koumassi
# [WARN] No text extracted from: Côte d'Ivoire Koumassi.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Radamis.pbix | Project: Radamis (Amr Zaki)
# [INFO] Processing file: Radamis.xlsx | Project: Radamis (Amr Zaki)
# [WARN] No text extracted from: Radamis.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Jawhara.pbix | Project: Restoration Sector (Heba Mahmoud)
# [INFO] Processing file: Jawhara.xlsx | Project: Restoration Sector (Heba Mahmoud)
# [WARN] No text extracted from: Jawhara.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Army Sector - .pbix | Project: Army Sector (Hossam Wefki)
# [INFO] Processing file: Army Sector  (2).xlsx | Project: Army Sector (Hossam Wefki)
# [WARN] No text extracted from: Army Sector  (2).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Bridges Sector.pbix | Project: Bridges Sector
# [INFO] Processing file: Bridges Sector.xlsx | Project: Bridges Sector
# [WARN] No text extracted from: Bridges Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB C&R Sector.pbix | Project: C&R Sector (Loay)
# [INFO] Processing file: Commercial & Residential Sector  (1).xlsx | Project: C&R Sector (Loay)
# [WARN] No text extracted from: Commercial & Residential Sector  (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Governmental Sector.pbix | Project: Governmental Sector (Ahmed El Ghoneimy)
# [INFO] Processing file: Governmental Sector.xlsx | Project: Governmental Sector (Ahmed El Ghoneimy)
# [WARN] No text extracted from: Governmental Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Industrial Sector.pbix | Project: Industrial Sector (Hany arafat)
# [INFO] Processing file: Industrial Sector  (1).xlsx | Project: Industrial Sector (Hany arafat)
# [WARN] No text extracted from: Industrial Sector  (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Infra Structure.pbix | Project: Infrastructure Sector (Ahmed El Ghoneimy)
# [INFO] Processing file: Infrastructure Sector.xlsx | Project: Infrastructure Sector (Ahmed El Ghoneimy)
# [WARN] No text extracted from: Infrastructure Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Koumassi.pbix | Project: Koumassi
# [INFO] Processing file: Côte d'Ivoire Koumassi (1).xlsx | Project: Koumassi
# [WARN] No text extracted from: Côte d'Ivoire Koumassi (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Jawhara.pbix | Project: Restoration Sector (Mahmoud)
# [INFO] Processing file: Jawhara.xlsx | Project: Restoration Sector (Mahmoud)
# [WARN] No text extracted from: Jawhara.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Army Sector - .pbix | Project: Army Sector (Hossam Wefki)
# [INFO] Processing file: 1. project progress DB Army Sector Rev01.pbix | Project: Army Sector (Hossam Wefki)
# [INFO] Processing file: Army Sector  (3).xlsx | Project: Army Sector (Hossam Wefki)
# [WARN] No text extracted from: Army Sector  (3).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Bridges Sector Rev01.pbix | Project: Bridges Sector (Omar Essam)
# [INFO] Processing file: 1. project progress DB Bridges Sector.pbix | Project: Bridges Sector (Omar Essam)
# [INFO] Processing file: Bridges Sector (1).xlsx | Project: Bridges Sector (Omar Essam)
# [WARN] No text extracted from: Bridges Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB C&R Sector Rev01.pbix | Project: C&R Sector (Loay)
# [INFO] Processing file: 1. project progress DB C&R Sector.pbix | Project: C&R Sector (Loay)
# [INFO] Processing file: Commercial & Residential Sector  (2).xlsx | Project: C&R Sector (Loay)
# [WARN] No text extracted from: Commercial & Residential Sector  (2).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Governmental Sector.pbix | Project: Governmental Sector (Ahmed El Ghoneimy)
# [INFO] Processing file: Governmental Sector.xlsx | Project: Governmental Sector (Ahmed El Ghoneimy)
# [WARN] No text extracted from: Governmental Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Industrial Sector Rev01.pbix | Project: Industrial Sector (Hany arafat)
# [INFO] Processing file: 1. project progress DB Industrial Sector.pbix | Project: Industrial Sector (Hany arafat)
# [INFO] Processing file: Industrial Sector  (2).xlsx | Project: Industrial Sector (Hany arafat)
# [WARN] No text extracted from: Industrial Sector  (2).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Infra Structure Rev01.pbix | Project: Infrastructure Sector (Ahmed El Ghoneimy)
# [INFO] Processing file: 1. project progress DB Infra Structure.pbix | Project: Infrastructure Sector (Ahmed El Ghoneimy)
# [INFO] Processing file: Infrastructure Sector.xlsx | Project: Infrastructure Sector (Ahmed El Ghoneimy)
# [WARN] No text extracted from: Infrastructure Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Radamis.pbix | Project: Radamis (Amr Zaki)
# [INFO] Processing file: Radamis.xlsx | Project: Radamis (Amr Zaki)
# [WARN] No text extracted from: Radamis.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Jawhara.pbix | Project: Restoration Sector (Mahmoud)
# [INFO] Processing file: Jawhara (1).xlsx | Project: Restoration Sector (Mahmoud)
# [WARN] No text extracted from: Jawhara (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Army Sector - .pbix | Project: Army Sector (Hossam Wefki)
# [INFO] Processing file: Army Sector  (3).xlsx | Project: Army Sector (Hossam Wefki)
# [WARN] No text extracted from: Army Sector  (3).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Bridges Sector.pbix | Project: Bridges Sector (Omar Essam)
# [INFO] Processing file: Bridges Sector (1).xlsx | Project: Bridges Sector (Omar Essam)
# [WARN] No text extracted from: Bridges Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB C&R Sector.pbix | Project: C&R Sector (Loay)
# [INFO] Processing file: Commercial & Residential Sector  (2).xlsx | Project: C&R Sector (Loay)
# [WARN] No text extracted from: Commercial & Residential Sector  (2).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Governmental Sector.pbix | Project: Governmental Sector (Ahmed El Ghoneimy)
# [INFO] Processing file: Governmental Sector.xlsx | Project: Governmental Sector (Ahmed El Ghoneimy)
# [WARN] No text extracted from: Governmental Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Industrial Sector.pbix | Project: Industrial Sector (Hany arafat)
# [INFO] Processing file: Industrial Sector  (2).xlsx | Project: Industrial Sector (Hany arafat)
# [WARN] No text extracted from: Industrial Sector  (2).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Infra Structure.pbix | Project: Infrastructure Sector (Ahmed El Ghoneimy)
# [INFO] Processing file: Infrastructure Sector.xlsx | Project: Infrastructure Sector (Ahmed El Ghoneimy)
# [WARN] No text extracted from: Infrastructure Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Jawhara.pbix | Project: Restoration Sector (Mahmoud)
# [INFO] Processing file: Jawhara (1).xlsx | Project: Restoration Sector (Mahmoud)
# [WARN] No text extracted from: Jawhara (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Army Sector - .pbix | Project: Army Sector (Hossam Wefki)
# [INFO] Processing file: 1. project progress DB Bridges Sector.pbix | Project: Bridges Sector (Omar Essam)
# [INFO] Processing file: 1. project progress DB C&R Sector.pbix | Project: C&R Sector (Loay)
# [INFO] Processing file: Commercial & Residential Sector  (2).xlsx | Project: C&R Sector (Loay)
# [WARN] No text extracted from: Commercial & Residential Sector  (2).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Governmental Sector.pbix | Project: Governmental Sector (Ahmed El Ghoneimy)
# [INFO] Processing file: 1. project progress DB Industrial Sector.pbix | Project: Industrial Sector (Hany arafat)
# [INFO] Processing file: 1. project progress DB Infra Structure.pbix | Project: Infrastructure Sector (Ahmed El Ghoneimy)
# [INFO] Processing file: 1. project progress DB Jawhara.pbix | Project: Restoration Sector (Mahmoud)
# [INFO] Processing file: Jawhara (1).xlsx | Project: Restoration Sector (Mahmoud)
# [WARN] No text extracted from: Jawhara (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Army Sector - .pbix | Project: Army Sector (Hossam Wefki)
# [INFO] Processing file: 1. project progress DB Bridges Sector.pbix | Project: Bridges Sector (Omar Essam)
# [INFO] Processing file: 1. project progress DB C&R Sector.pbix | Project: C&R Sector (Loay)
# [INFO] Processing file: 1. project progress DB Governmental Sector.pbix | Project: Governmental Sector (Ahmed El Ghoneimy)
# [INFO] Processing file: 1. project progress DB Industrial Sector.pbix | Project: Industrial Sector (Hany arafat)
# [INFO] Processing file: 1. project progress DB Infra Structure.pbix | Project: Infrastructure Sector (Ahmed El Ghoneimy)
# [INFO] Processing file: 1. project progress DB Koumassi.pbix | Project: Koumassi (Aly Maher)
# [INFO] Processing file: 1. project progress DB Jawhara.pbix | Project: Restoration Sector (Mahmoud)
# [INFO] Processing file: 1. project progress DB Army Sector - .pbix | Project: Army Sector (Hossam Wefki)
# [INFO] Processing file: Army Sector  (3).xlsx | Project: Army Sector (Hossam Wefki)
# [WARN] No text extracted from: Army Sector  (3).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Bridges Sector.pbix | Project: Bridges Sector (Omar Essam)
# [INFO] Processing file: Bridges Sector (1).xlsx | Project: Bridges Sector (Omar Essam)
# [WARN] No text extracted from: Bridges Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB C&R Sector.pbix | Project: C&R Sector (Loay)
# [INFO] Processing file: Commercial & Residential Sector  (2).xlsx | Project: C&R Sector (Loay)
# [WARN] No text extracted from: Commercial & Residential Sector  (2).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Governmental Sector.pbix | Project: Governmental Sector (Ahmed El Ghoneimy)
# [INFO] Processing file: Governmental Sector.xlsx | Project: Governmental Sector (Ahmed El Ghoneimy)
# [WARN] No text extracted from: Governmental Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Industrial Sector.pbix | Project: Industrial Sector (Hany arafat)
# [INFO] Processing file: Industrial Sector.xlsx | Project: Industrial Sector (Hany arafat)
# [WARN] No text extracted from: Industrial Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Infra Structure.pbix | Project: Infrastructure Sector (Ahmed El Ghoneimy)
# [INFO] Processing file: Infrastructure Sector.xlsx | Project: Infrastructure Sector (Ahmed El Ghoneimy)
# [WARN] No text extracted from: Infrastructure Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Koumassi.pbix | Project: Koumassi (Aly Maher)
# [INFO] Processing file: Côte d'Ivoire Koumassi (1).xlsx | Project: Koumassi (Aly Maher)
# [WARN] No text extracted from: Côte d'Ivoire Koumassi (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB KSA.pbix | Project: KSA
# [INFO] Processing file: KSA Sector.xlsx | Project: KSA
# [WARN] No text extracted from: KSA Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Jawhara.pbix | Project: Restoration Sector (Mahmoud)
# [INFO] Processing file: Jawhara (1).xlsx | Project: Restoration Sector (Mahmoud)
# [WARN] No text extracted from: Jawhara (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Army Sector - .pbix | Project: Army Sector (Hossam Wefki)
# [INFO] Processing file: Army Sector  (3).xlsx | Project: Army Sector (Hossam Wefki)
# [WARN] No text extracted from: Army Sector  (3).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Bridges Sector.pbix | Project: Bridges Sector (Omar Essam)
# [INFO] Processing file: Bridges Sector (2).xlsx | Project: Bridges Sector (Omar Essam)
# [WARN] No text extracted from: Bridges Sector (2).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB C&R Sector.pbix | Project: C&R Sector (Hossam Wefki)
# [INFO] Processing file: Commercial & Residential Sector  (3).xlsx | Project: C&R Sector (Hossam Wefki)
# [WARN] No text extracted from: Commercial & Residential Sector  (3).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Damietta Port.pbix | Project: Damietta (Hany Arafat)
# [INFO] Processing file: Damietta Port.xlsx | Project: Damietta (Hany Arafat)
# [WARN] No text extracted from: Damietta Port.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Governmental Sector.pbix | Project: Governmental Sector (Ahmed El Ghoneimy)
# [INFO] Processing file: Governmental Sector (1).xlsx | Project: Governmental Sector (Ahmed El Ghoneimy)
# [WARN] No text extracted from: Governmental Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Industrial Sector.pbix | Project: Industrial Sector (Hany arafat)
# [INFO] Processing file: Industrial Sector  (3).xlsx | Project: Industrial Sector (Hany arafat)
# [WARN] No text extracted from: Industrial Sector  (3).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Infra Structure.pbix | Project: Infrastructure Sector (Mohamed Ragab Barakat)
# [INFO] Processing file: Infrastructure Sector (1).xlsx | Project: Infrastructure Sector (Mohamed Ragab Barakat)
# [WARN] No text extracted from: Infrastructure Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Koumassi.pbix | Project: Koumassi (Aly Maher)
# [INFO] Processing file: Côte d'Ivoire Koumassi (1).xlsx | Project: Koumassi (Aly Maher)
# [WARN] No text extracted from: Côte d'Ivoire Koumassi (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB KSA.pbix | Project: KSA (Loai)
# [INFO] Processing file: KSA Sector (1).xlsx | Project: KSA (Loai)
# [WARN] No text extracted from: KSA Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Jawhara.pbix | Project: Restoration Sector (Menna)
# [INFO] Processing file: Jawhara (1).xlsx | Project: Restoration Sector (Menna)
# [WARN] No text extracted from: Jawhara (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Army Sector - .pbix | Project: Army Sector (Hossam Wefki)
# [INFO] Processing file: Army Sector  (3).xlsx | Project: Army Sector (Hossam Wefki)
# [WARN] No text extracted from: Army Sector  (3).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Bridges Sector.pbix | Project: Bridges Sector (Omar Essam)
# [INFO] Processing file: Bridges Sector (2).xlsx | Project: Bridges Sector (Omar Essam)
# [WARN] No text extracted from: Bridges Sector (2).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB C&R Sector.pbix | Project: C&R Sector (Hossam Wefki)
# [INFO] Processing file: Commercial & Residential Sector  (3).xlsx | Project: C&R Sector (Hossam Wefki)
# [WARN] No text extracted from: Commercial & Residential Sector  (3).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Governmental Sector.pbix | Project: Governmental Sector (Ahmed El Ghoneimy)
# [INFO] Processing file: Governmental Sector (1).xlsx | Project: Governmental Sector (Ahmed El Ghoneimy)
# [WARN] No text extracted from: Governmental Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Industrial Sector.pbix | Project: Industrial Sector (Hany arafat)
# [INFO] Processing file: Industrial Sector  (3).xlsx | Project: Industrial Sector (Hany arafat)
# [WARN] No text extracted from: Industrial Sector  (3).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Infra Structure.pbix | Project: Infrastructure Sector (Mohamed Ragab Barakat)
# [INFO] Processing file: Infrastructure Sector (1).xlsx | Project: Infrastructure Sector (Mohamed Ragab Barakat)
# [WARN] No text extracted from: Infrastructure Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB KSA.pbix | Project: KSA (Loai)
# [INFO] Processing file: KSA Sector (1).xlsx | Project: KSA (Loai)
# [WARN] No text extracted from: KSA Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Jawhara.pbix | Project: Restoration Sector (Menna)
# [INFO] Processing file: Jawhara (1).xlsx | Project: Restoration Sector (Menna)
# [WARN] No text extracted from: Jawhara (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Army Sector - .pbix | Project: Army Sector (Hossam Wefki)
# [INFO] Processing file: Army Sector  (3).xlsx | Project: Army Sector (Hossam Wefki)
# [WARN] No text extracted from: Army Sector  (3).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Bridges Sector.pbix | Project: Bridges Sector (Omar Essam)
# [INFO] Processing file: Bridges Sector (2).xlsx | Project: Bridges Sector (Omar Essam)
# [WARN] No text extracted from: Bridges Sector (2).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB C&R Sector.pbix | Project: C&R Sector (Hossam Wefki)
# [INFO] Processing file: Commercial & Residential Sector  (3).xlsx | Project: C&R Sector (Hossam Wefki)
# [WARN] No text extracted from: Commercial & Residential Sector  (3).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Damietta Port.pbix | Project: Damietta (Ahmed El Ghonemy)
# [INFO] Processing file: Damietta Port.xlsx | Project: Damietta (Ahmed El Ghonemy)
# [WARN] No text extracted from: Damietta Port.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Governmental Sector.pbix | Project: Governmental Sector (Ahmed El Ghoneimy)
# [INFO] Processing file: Governmental Sector (1).xlsx | Project: Governmental Sector (Ahmed El Ghoneimy)
# [WARN] No text extracted from: Governmental Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Industrial Sector.pbix | Project: Industrial Sector (Ahmed El Ghoneimy)
# [INFO] Processing file: Industrial Sector  (3).xlsx | Project: Industrial Sector (Ahmed El Ghoneimy)
# [WARN] No text extracted from: Industrial Sector  (3).xlsx (no text extracted (Excel))
# [INFO] Processing file: Infrastructure Sector (1).xlsx | Project: Infrastructure Sector (Aly Maher)
# [WARN] No text extracted from: Infrastructure Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Koumassi.pbix | Project: Koumassi (Aly Maher)
# [INFO] Processing file: Côte d'Ivoire Koumassi (1).xlsx | Project: Koumassi (Aly Maher)
# [WARN] No text extracted from: Côte d'Ivoire Koumassi (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB KSA.pbix | Project: KSA (Loai)
# [INFO] Processing file: KSA Sector (1).xlsx | Project: KSA (Loai)
# [WARN] No text extracted from: KSA Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Army Sector - .pbix | Project: Army Sector (Hossam Wefki)
# [INFO] Processing file: Army Sector  (3).xlsx | Project: Army Sector (Hossam Wefki)
# [WARN] No text extracted from: Army Sector  (3).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Bridges Sector.pbix | Project: Bridges Sector (Omar Essam)
# [INFO] Processing file: Bridges Sector (2).xlsx | Project: Bridges Sector (Omar Essam)
# [WARN] No text extracted from: Bridges Sector (2).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB C&R Sector.pbix | Project: C&R Sector (Hossam Wefki)
# [INFO] Processing file: Commercial & Residential Sector  (3).xlsx | Project: C&R Sector (Hossam Wefki)
# [WARN] No text extracted from: Commercial & Residential Sector  (3).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Damietta Port.pbix | Project: Damietta (Ahmed El Ghonemy)
# [INFO] Processing file: Damietta Port.xlsx | Project: Damietta (Ahmed El Ghonemy)
# [WARN] No text extracted from: Damietta Port.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Governmental Sector.pbix | Project: Governmental Sector (Ahmed El Ghoneimy)
# [INFO] Processing file: Governmental Sector (1).xlsx | Project: Governmental Sector (Ahmed El Ghoneimy)
# [WARN] No text extracted from: Governmental Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Industrial Sector.pbix | Project: Industrial (Ahmed El Ghonemy)
# [INFO] Processing file: 1. project progress DB Infra Structure.pbix | Project: Infrastructure Sector (Aly Maher)
# [INFO] Processing file: Infrastructure Sector (1).xlsx | Project: Infrastructure Sector (Aly Maher)
# [WARN] No text extracted from: Infrastructure Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Koumassi.pbix | Project: Koumassi (Aly Maher)
# [INFO] Processing file: Côte d'Ivoire Koumassi (1).xlsx | Project: Koumassi (Aly Maher)
# [WARN] No text extracted from: Côte d'Ivoire Koumassi (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB KSA.pbix | Project: KSA (Loai)
# [INFO] Processing file: KSA Sector (1).xlsx | Project: KSA (Loai)
# [WARN] No text extracted from: KSA Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: 1. project progress DB Jawhara.pbix | Project: Restoration Sector (Heba)
# [INFO] Processing file: Jawhara (1).xlsx | Project: Restoration Sector (Heba)
# [WARN] No text extracted from: Jawhara (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: Commercial & Residential BU (National) 2025.xlsx | Project: 1-Commercial & Residential BU (National) (Hossam Wefki & Heba Nagy)
# [WARN] No text extracted from: Commercial & Residential BU (National) 2025.xlsx (no text extracted (Excel))
# [INFO] Processing file: Dashboard Commercial & Residential BU (National) 2025.pbix | Project: 1-Commercial & Residential BU (National) (Hossam Wefki & Heba Nagy)
# [INFO] Processing file: Damietta Port.xlsx | Project: Damietta Dashboard
# [WARN] No text extracted from: Damietta Port.xlsx (no text extracted (Excel))
# [INFO] Processing file: DB Damietta Port 2025.pbix | Project: Damietta Dashboard
# [INFO] Processing file: DB Industrial 2025.pbix | Project: Industrial Dashboard
# [INFO] Processing file: Dash Board Infrastructure BU National (2025).pbix | Project: 3-Infrastructure BU (National) (Aly Maher)
# [INFO] Processing file: Dash Board Infrastructure BU National (2025).xlsx | Project: 3-Infrastructure BU (National) (Aly Maher)
# [WARN] No text extracted from: Dash Board Infrastructure BU National (2025).xlsx (no text extracted (Excel))
# [INFO] Processing file: Dashboard Bridges BU National (2025).pbix | Project: 4-Bridges BU (National) (Ahmed Salah)
# [INFO] Processing file: Dashboard Bridges BU National (2025).xlsx | Project: 4-Bridges BU (National) (Ahmed Salah)
# [WARN] No text extracted from: Dashboard Bridges BU National (2025).xlsx (no text extracted (Excel))
# [INFO] Processing file: DB Governmental 2025.pbix | Project: 5-Governmental Sector (Ahmed El Ghoneimy)
# [INFO] Processing file: DB Governmental 2025.xlsx | Project: 5-Governmental Sector (Ahmed El Ghoneimy)
# [WARN] No text extracted from: DB Governmental 2025.xlsx (no text extracted (Excel))
# [INFO] Processing file: Dashboard Restoration BU National (2025).pbix | Project: 6-Restoration BU (National) (Heba)
# [INFO] Processing file: Dashboard Restoration BU National (2025).xlsx | Project: 6-Restoration BU (National) (Heba)
# [WARN] No text extracted from: Dashboard Restoration BU National (2025).xlsx (no text extracted (Excel))
# [INFO] Processing file: Dashboard Cote d'ivoire Branch (International) (2025).pbix | Project: 7-Cote d'ivoire Branch (International) (Aly Maher)
# [INFO] Processing file: Dashboard Cote d'ivoire Branch (International) (2025).xlsx | Project: 7-Cote d'ivoire Branch (International) (Aly Maher)
# [WARN] No text extracted from: Dashboard Cote d'ivoire Branch (International) (2025).xlsx (no text extracted (Excel))
# [INFO] Processing file: Dashboard KSA Branch International (2025).pbix | Project: 8-KSA Branch (International) (Loai)
# [INFO] Processing file: Dashboard KSA Branch International (2025).xlsx | Project: 8-KSA Branch (International) (Loai)
# [WARN] No text extracted from: Dashboard KSA Branch International (2025).xlsx (no text extracted (Excel))
# [INFO] Processing file: Monthly dash board 31-1-2025.pdf | Project: TTRR Project
# [INFO] Processing file: UGR - Monthly dash board No.10 cut-off date Jan-2025.pdf | Project: Ubari-Gaat Project
# [INFO] Processing file: Commercial & Residential BU (National) 2025.xlsx | Project: 1-Commercial & Residential BU (National) (Hossam Wefki & Heba Nagy)
# [WARN] No text extracted from: Commercial & Residential BU (National) 2025.xlsx (no text extracted (Excel))
# [INFO] Processing file: Dashboard Commercial & Residential BU (National) 2025.pbix | Project: 1-Commercial & Residential BU (National) (Hossam Wefki & Heba Nagy)
# [INFO] Processing file: DB Damietta Port 2025.pbix | Project: Damietta Dashboard
# [INFO] Processing file: DB Damietta Port 2025.xlsx | Project: Damietta Dashboard
# [WARN] No text extracted from: DB Damietta Port 2025.xlsx (no text extracted (Excel))
# [INFO] Processing file: DB Industrial 2025.pbix | Project: Industrial Dashboard
# [INFO] Processing file: DB Industrial 2025.xlsx | Project: Industrial Dashboard
# [WARN] No text extracted from: DB Industrial 2025.xlsx (no text extracted (Excel))
# [INFO] Processing file: Dash Board Infrastructure BU National (2025).pbix | Project: 3-Infrastructure BU (National) (Aly Maher)
# [INFO] Processing file: Dash Board Infrastructure BU National (2025).xlsx | Project: 3-Infrastructure BU (National) (Aly Maher)
# [WARN] No text extracted from: Dash Board Infrastructure BU National (2025).xlsx (no text extracted (Excel))
# [INFO] Processing file: Dashboard Bridges BU National (2025).pbix | Project: 4-Bridges BU (National) (Ahmed Salah)
# [INFO] Processing file: Dashboard Bridges BU National (2025).xlsx | Project: 4-Bridges BU (National) (Ahmed Salah)
# [WARN] No text extracted from: Dashboard Bridges BU National (2025).xlsx (no text extracted (Excel))
# [INFO] Processing file: DB Governmental 2025.pbix | Project: 5-Governmental Sector (Ahmed El Ghoneimy)
# [INFO] Processing file: DB Governmental 2025.xlsx | Project: 5-Governmental Sector (Ahmed El Ghoneimy)
# [WARN] No text extracted from: DB Governmental 2025.xlsx (no text extracted (Excel))
# [INFO] Processing file: Dashboard Restoration BU National (2025).pbix | Project: 6-Restoration BU (National) (Heba)
# [INFO] Processing file: Dashboard Restoration BU National (2025).xlsx | Project: 6-Restoration BU (National) (Heba)
# [WARN] No text extracted from: Dashboard Restoration BU National (2025).xlsx (no text extracted (Excel))
# [INFO] Processing file: Dashboard Cote d'ivoire Branch (International) (2025).pbix | Project: 7-Cote d'ivoire Branch (International) (Aly Maher)
# [INFO] Processing file: Dashboard Cote d'ivoire Branch (International) (2025).xlsx | Project: 7-Cote d'ivoire Branch (International) (Aly Maher)
# [WARN] No text extracted from: Dashboard Cote d'ivoire Branch (International) (2025).xlsx (no text extracted (Excel))
# [INFO] Processing file: Dashboard KSA Branch International (2025).pbix | Project: 8-KSA Branch (International) (Loai)
# [INFO] Processing file: Dashboard KSA Branch International (2025).xlsx | Project: 8-KSA Branch (International) (Loai)
# [WARN] No text extracted from: Dashboard KSA Branch International (2025).xlsx (no text extracted (Excel))
# [INFO] Processing file: Commercial & Residential Sector .xlsx | Project: 1-Commercial & Residential BU (National) (Hossam Wefki & Heba Nagy)
# [WARN] No text extracted from: Commercial & Residential Sector .xlsx (no text extracted (Excel))
# [INFO] Processing file: Dashboard Commercial & Residential BU (National) 2025.pbix | Project: 1-Commercial & Residential BU (National) (Hossam Wefki & Heba Nagy)
# [INFO] Processing file: Damietta Port.xlsx | Project: Damietta Dashboard
# [WARN] No text extracted from: Damietta Port.xlsx (no text extracted (Excel))
# [INFO] Processing file: DB Damietta Port 2025.pbix | Project: Damietta Dashboard
# [INFO] Processing file: DB Industrial 2025.pbix | Project: Industrial Dashboard
# [INFO] Processing file: Industrial Sector  (3).xlsx | Project: Industrial Dashboard
# [WARN] No text extracted from: Industrial Sector  (3).xlsx (no text extracted (Excel))
# [INFO] Processing file: Dash Board Infrastructure BU National (2025).pbix | Project: 3-Infrastructure BU (National) (Aly Maher)
# [INFO] Processing file: Infrastructure Sector (1).xlsx | Project: 3-Infrastructure BU (National) (Aly Maher)
# [WARN] No text extracted from: Infrastructure Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: Bridges Sector (2).xlsx | Project: 4-Bridges BU (National) (Ahmed Salah)
# [WARN] No text extracted from: Bridges Sector (2).xlsx (no text extracted (Excel))
# [INFO] Processing file: Dashboard Bridges BU National (2025).pbix | Project: 4-Bridges BU (National) (Ahmed Salah)
# [INFO] Processing file: DB Governmental 2025.pbix | Project: 5-Governmental Sector (Ahmed El Ghoneimy)
# [INFO] Processing file: Governmental Sector (1).xlsx | Project: 5-Governmental Sector (Ahmed El Ghoneimy)
# [WARN] No text extracted from: Governmental Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: Dashboard Restoration BU National (2025).pbix | Project: 6-Restoration BU (National) (Heba)
# [INFO] Processing file: Jawhara (1).xlsx | Project: 6-Restoration BU (National) (Heba)
# [WARN] No text extracted from: Jawhara (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: Dashboard Cote d'ivoire Branch (International) (2025).pbix | Project: 7-Cote d'ivoire Branch (International) (Aly Maher)
# [INFO] Processing file: Dashboard KSA Branch International (2025).pbix | Project: 8-KSA Branch (International) (Loai)
# [INFO] Processing file: KSA Sector (1).xlsx | Project: 8-KSA Branch (International) (Loai)
# [WARN] No text extracted from: KSA Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: Commercial & Residential Sector  (3).xlsx | Project: 1-Commercial & Residential BU (National) (Hossam Wefki & Heba Nagy)
# [WARN] No text extracted from: Commercial & Residential Sector  (3).xlsx (no text extracted (Excel))
# [INFO] Processing file: Dashboard Commercial & Residential BU (National) 2025.pbix | Project: 1-Commercial & Residential BU (National) (Hossam Wefki & Heba Nagy)
# [INFO] Processing file: Damietta Port.xlsx | Project: Damietta Dashboard
# [WARN] No text extracted from: Damietta Port.xlsx (no text extracted (Excel))
# [INFO] Processing file: DB Damietta Port 2025.pbix | Project: Damietta Dashboard
# [INFO] Processing file: DB Industrial 2025.pbix | Project: Industrial Dashboard
# [INFO] Processing file: Industrial Sector  (3).xlsx | Project: Industrial Dashboard
# [WARN] No text extracted from: Industrial Sector  (3).xlsx (no text extracted (Excel))
# [INFO] Processing file: Dash Board Infrastructure BU National (2025).pbix | Project: 3-Infrastructure BU (National) (Aly Maher)
# [INFO] Processing file: Infrastructure Sector (1).xlsx | Project: 3-Infrastructure BU (National) (Aly Maher)
# [WARN] No text extracted from: Infrastructure Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: Bridges Sector (2).xlsx | Project: 4-Bridges BU (National) (Ahmed Salah)
# [WARN] No text extracted from: Bridges Sector (2).xlsx (no text extracted (Excel))
# [INFO] Processing file: Dashboard Bridges BU National (2025).pbix | Project: 4-Bridges BU (National) (Ahmed Salah)
# [INFO] Processing file: DB Governmental 2025.pbix | Project: 5-Governmental Sector (Ahmed El Ghoneimy)
# [INFO] Processing file: Governmental Sector (1).xlsx | Project: 5-Governmental Sector (Ahmed El Ghoneimy)
# [WARN] No text extracted from: Governmental Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: Dashboard Restoration BU National (2025).pbix | Project: 6-Restoration BU (National) (Heba)
# [INFO] Processing file: Jawhara (1).xlsx | Project: 6-Restoration BU (National) (Heba)
# [WARN] No text extracted from: Jawhara (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: Côte d'Ivoire Sector.xlsx | Project: 7-Cote d'ivoire Branch (International) (Aly Maher)
# [WARN] No text extracted from: Côte d'Ivoire Sector.xlsx (no text extracted (Excel))
# [INFO] Processing file: Dashboard Cote d'ivoire Branch (International) (2025).pbix | Project: 7-Cote d'ivoire Branch (International) (Aly Maher)
# [INFO] Processing file: Dashboard KSA Branch International (2025).pbix | Project: 8-KSA Branch (International) (Loai)
# [INFO] Processing file: KSA Sector (1).xlsx | Project: 8-KSA Branch (International) (Loai)
# [WARN] No text extracted from: KSA Sector (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: Baseline-EOT-Milestones-Projects Status Log - Final Apr-25.xlsx | Project: Enhancements on the Dashboards
# [WARN] No text extracted from: Baseline-EOT-Milestones-Projects Status Log - Final Apr-25.xlsx (no text extracted (Excel))
# [INFO] Processing file: CR 24,25 Planned Vs Actual.xlsx | Project: Enhancements on the Dashboards
# [WARN] No text extracted from: CR 24,25 Planned Vs Actual.xlsx (no text extracted (Excel))
# [INFO] Processing file: Baseline-EOT-Milestones-Projects Status Log - Final Jan.25.xlsx | Project: 1-Jan.25
# [WARN] No text extracted from: Baseline-EOT-Milestones-Projects Status Log - Final Jan.25.xlsx (no text extracted (Excel))
# [INFO] Processing file: General Milestones.pdf | Project: Files
# [INFO] Processing file: International Projects Intermediate milestones.pdf | Project: Files
# [INFO] Processing file: International Projects.pdf | Project: Files
# [INFO] Processing file: National Projects Intermediate Milestones ( Bridges, Infra, Industrial).pdf | Project: Files
# [INFO] Processing file: National Projects Intermediate Milestones ( Commercial, Restoration & GOV).pdf | Project: Files
# [INFO] Processing file: National Projects.pdf | Project: Files
# [INFO] Processing file: Project Control Department Report.pdf | Project: Final presentation & Pdf
# [INFO] Processing file: Project Control Department Report.pptx | Project: Final presentation & Pdf
# [INFO] Processing file: Thumbs.db | Project: Final presentation & Pdf
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: Bridges Sector (2).xlsx | Project: Jan.25 File
# [WARN] No text extracted from: Bridges Sector (2).xlsx (no text extracted (Excel))
# [INFO] Processing file: Commercial & Residential Sector  (3).xlsx | Project: Jan.25 File
# [WARN] No text extracted from: Commercial & Residential Sector  (3).xlsx (no text extracted (Excel))
# [INFO] Processing file: Côte d'Ivoire Koumassi (1).xlsx | Project: Jan.25 File
# [WARN] No text extracted from: Côte d'Ivoire Koumassi (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: Damietta Port.xlsx | Project: Jan.25 File
# [WARN] No text extracted from: Damietta Port.xlsx (no text extracted (Excel))
# [INFO] Processing file: Governmental Sector (1).xlsx | Project: Jan.25 File
# ...
# [INFO] Processing file: Engineering Follow up Dashboard (30-June-2024).pbix | Project: 4-June.2024
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Sohag HSR Station-1-7-2024.xlsx | Project: Sohag HSR Station
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Sohag HSR Station-1-7-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 log - Damietta Container Terminal.xlsx | Project: Damietta
# [WARN] No text extracted from: F-P-EN-01-01 E1 log - Damietta Container Terminal.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log -EIPICO 3 - CIVIL-ARC -08-07-2024.xlsx | Project: Eipico
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log -EIPICO 3 - CIVIL-ARC -08-07-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log Rabigh-1-7-2024..xlsx | Project: Rabigh
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log Rabigh-1-7-2024..xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Silos..xlsx | Project: Silos
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Silos..xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-MEP Suez 30-06-2024.xlsx | Project: Suez
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-MEP Suez 30-06-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Suez - 30-06-2024.xlsx | Project: Suez
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Suez - 30-06-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log Abo Shanab Update 1-7-2024.xlsx | Project: Abo Shanab
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log Abo Shanab Update 1-7-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log Qasr Rashwan Lot A 1-7-2024.xlsx | Project: Qasr Rshwan lot (A)
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log Qasr Rashwan Lot A 1-7-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 log Qasr Rshwan Lot B 1-7-2024.xlsx | Project: Qasr Rshwan lot (B)
# [WARN] No text extracted from: F-P-EN-01-01 E1 log Qasr Rshwan Lot B 1-7-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log- hosh issa..xlsx | Project: Hosh Eissa
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log- hosh issa..xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-CREEKSLANDSCAPE 08-07-2024.xlsx | Project: Kattmya Creek
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-CREEKSLANDSCAPE 08-07-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Mivida-09-07-2024.xlsx | Project: Mivida
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Mivida-09-07-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Ora Zed. 09-07-2024.xlsx | Project: Ora Zed Phase 02
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Ora Zed. 09-07-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Urban-K 08-07-2024.xlsx | Project: UrbanK
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Urban-K 08-07-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log Jawhara Palace-01-07-2024.xlsx | Project: Jawhara Palace
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log Jawhara Palace-01-07-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log Red Sea 1-7-2024.xlsx | Project: Red Sea Musuem
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log Red Sea 1-7-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: Engineering Follow up Dashboard (30-june-2024)..pbix | Project: 5-July.2024
# [INFO] Extracting archive: July.2024.rar
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Sohag HSR Station 30-7-2024.xlsx | Project: Sohag HSR Station
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Sohag HSR Station 30-7-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log -EIPICO 3 - CIVIL-ARC -30-07-2024.xlsx | Project: Eipico
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log -EIPICO 3 - CIVIL-ARC -30-07-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log Rabigh-30-7-2024..xlsx | Project: Rabigh
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log Rabigh-30-7-2024..xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Silos..xlsx | Project: Silos
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Silos..xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-MEP Suez 30-07-2024.xlsx | Project: Suez
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-MEP Suez 30-07-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Suez - 30-07-2024.xlsx | Project: Suez
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Suez - 30-07-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log Abo Shanab 30-7-2024.xlsx | Project: Abo Shanab
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log Abo Shanab 30-7-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log Qasr Rashwan Lot A 30-7-2024.xlsx | Project: Qasr Rshwan lot (A)
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log Qasr Rashwan Lot A 30-7-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 log Qasr Rshwan Lot B 30-7-2024.xlsx | Project: Qasr Rshwan lot (B)
# [WARN] No text extracted from: F-P-EN-01-01 E1 log Qasr Rshwan Lot B 30-7-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log- hosh issa 30-7-2024.xlsx | Project: Hosh Eissa
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log- hosh issa 30-7-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-CREEKSLANDSCAPE 30-07-2024.xlsx | Project: Kattmya Creek
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-CREEKSLANDSCAPE 30-07-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Mivida-30-07-2024.xlsx | Project: Mivida
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Mivida-30-07-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Ora Zed. 30-07-2024.xlsx | Project: Ora Zed Phase 02
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Ora Zed. 30-07-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Urban-K 30-07-2024.xlsx | Project: UrbanK
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Urban-K 30-07-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log Jawhara Palace 1-8-2024.xlsx | Project: Jawhara Palace
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log Jawhara Palace 1-8-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: 00- 05- F-P-EN-01-01 E1 Log Red Sea.xlsx | Project: Red Sea Musuem
# [WARN] No text extracted from: 00- 05- F-P-EN-01-01 E1 Log Red Sea.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Sohag HSR Station 30-7-2024.xlsx | Project: Sohag HSR Station
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Sohag HSR Station 30-7-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log -EIPICO 3 - CIVIL-ARC -30-07-2024.xlsx | Project: Eipico
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log -EIPICO 3 - CIVIL-ARC -30-07-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log Rabigh-30-7-2024..xlsx | Project: Rabigh
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log Rabigh-30-7-2024..xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Silos..xlsx | Project: Silos
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Silos..xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-MEP Suez 30-07-2024.xlsx | Project: Suez
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-MEP Suez 30-07-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Suez - 30-07-2024.xlsx | Project: Suez
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Suez - 30-07-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log Abo Shanab 30-7-2024.xlsx | Project: Abo Shanab
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log Abo Shanab 30-7-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log Qasr Rashwan Lot A 30-7-2024.xlsx | Project: Qasr Rshwan lot (A)
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log Qasr Rashwan Lot A 30-7-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 log Qasr Rshwan Lot B 30-7-2024.xlsx | Project: Qasr Rshwan lot (B)
# [WARN] No text extracted from: F-P-EN-01-01 E1 log Qasr Rshwan Lot B 30-7-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log- hosh issa 30-7-2024.xlsx | Project: Hosh Eissa
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log- hosh issa 30-7-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-CREEKSLANDSCAPE 30-07-2024.xlsx | Project: Kattmya Creek
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-CREEKSLANDSCAPE 30-07-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Mivida-30-07-2024.xlsx | Project: Mivida
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Mivida-30-07-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Ora Zed. 30-07-2024.xlsx | Project: Ora Zed Phase 02
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Ora Zed. 30-07-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Urban-K 30-07-2024.xlsx | Project: UrbanK
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Urban-K 30-07-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log Jawhara Palace 1-8-2024.xlsx | Project: Jawhara Palace
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log Jawhara Palace 1-8-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: 00- 05- F-P-EN-01-01 E1 Log Red Sea.xlsx | Project: Red Sea Musuem
# [WARN] No text extracted from: 00- 05- F-P-EN-01-01 E1 Log Red Sea.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-CREEKSLANDSCAPE(Sep2024-).xlsx | Project: Kattmya Creek
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-CREEKSLANDSCAPE(Sep2024-).xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Mivida-30-08-2024.xlsx | Project: Mivida
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Mivida-30-08-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log Update-Abo Shanab- 30-09-2024.xlsx | Project: Abo Shanab
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log Update-Abo Shanab- 30-09-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log Qasr Rashwan Lot A 30-09-2024.xlsx | Project: Qasr Rshwan lot (A)
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log Qasr Rashwan Lot A 30-09-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log Qasr Rashwan Lot B 30-09-2024.xlsx | Project: Qasr Rshwan lot (B)
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log Qasr Rashwan Lot B 30-09-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-CREEKSLANDSCAPE(Sep2024-).xlsx | Project: Kattmya Creek
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-CREEKSLANDSCAPE(Sep2024-).xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Mivida-30-08-2024.xlsx | Project: Mivida
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Mivida-30-08-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: ENG Query-Rev05.xlsx | Project: Engineering Quey and Dashboard
# [WARN] No text extracted from: ENG Query-Rev05.xlsx (no text extracted (Excel))
# [INFO] Processing file: Engineering Follow up Dashboard Rev.05.pbix | Project: Engineering Quey and Dashboard
# [INFO] Processing file: Shopdrawings-Rev.05.xlsx | Project: Engineering Quey and Dashboard
# [WARN] No text extracted from: Shopdrawings-Rev.05.xlsx (no text extracted (Excel))
# [INFO] Processing file: Engineering dashboard-20240919_102440-Meeting Recording.mp4 | Project: Orintation Record
# [WARN] Skipped unsupported file type: Engineering dashboard-20240919_102440-Meeting Recording.mp4
# [INFO] Processing file: As Built Logs_Commercial & Residential BU.xlsx | Project: 1-Commercial & Residential BU
# [WARN] No text extracted from: As Built Logs_Commercial & Residential BU.xlsx (no text extracted (Excel))
# [INFO] Processing file: E1 Logs_Commercial & Residential BU.xlsx | Project: 1-Commercial & Residential BU
# [WARN] No text extracted from: E1 Logs_Commercial & Residential BU.xlsx (no text extracted (Excel))
# [INFO] Processing file: E2 Logs_Commercial & Residential BU.xlsx | Project: 1-Commercial & Residential BU
# [WARN] No text extracted from: E2 Logs_Commercial & Residential BU.xlsx (no text extracted (Excel))
# [INFO] Extracting archive: Raw Files.rar
# [INFO] Processing file: E1 & E2 - Creeks.rar | Project: 0-Received Files
# [WARN] Skipped unsupported file type: E1 & E2 - Creeks.rar
# [INFO] Processing file: E1 & E2 -MAFI.rar | Project: 0-Received Files
# [WARN] Skipped unsupported file type: E1 & E2 -MAFI.rar
# [INFO] Processing file: 00__AS_BUILT_CREEKS.xlsx | Project: As Built
# [WARN] No text extracted from: 00__AS_BUILT_CREEKS.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-CREEKSLANDSCAPE.xlsx | Project: E1
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-CREEKSLANDSCAPE.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-TN-02-07 C,H&R Sector Sourcing Plan - 31-Jan-24 -Kattamya Creeks .xlsx | Project: E2
# [WARN] No text extracted from: F-P-TN-02-07 C,H&R Sector Sourcing Plan - 31-Jan-24 -Kattamya Creeks .xlsx (no text extracted (Excel))
# [INFO] Processing file: MAFI - F-P-EN-01-01 E1 log Update.xlsx | Project: E1
# [WARN] No text extracted from: MAFI - F-P-EN-01-01 E1 log Update.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-TN-02-07 Procurement (Sourcing) Plan (18-02-2025).xlsx | Project: E2
# [WARN] No text extracted from: F-P-TN-02-07 Procurement (Sourcing) Plan (18-02-2025).xlsx (no text extracted (Excel))
# [INFO] Processing file: AS-BUILT-Log-Mivida-2-1-2025.xlsx | Project: E1
# [WARN] No text extracted from: AS-BUILT-Log-Mivida-2-1-2025.xlsx (no text extracted (Excel))
# [INFO] Processing file: E1 Shop Drawing LOG -Mivida-16-2-2025.xlsx | Project: E1
# [WARN] No text extracted from: E1 Shop Drawing LOG -Mivida-16-2-2025.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-TN-02-07 mivida  R Sector Sourcing Plan - 2025-02-16 - Rev01.xlsx | Project: E2
# [WARN] No text extracted from: F-P-TN-02-07 mivida  R Sector Sourcing Plan - 2025-02-16 - Rev01.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-TN-02-07 mivida  R Sector Sourcing Plan - 2025-02-16.xlsx | Project: E2
# [WARN] No text extracted from: F-P-TN-02-07 mivida  R Sector Sourcing Plan - 2025-02-16.xlsx (no text extracted (Excel))
# [INFO] Processing file: AS BUILT- URBN K-12-02-2025.xlsx | Project: E1
# [WARN] No text extracted from: AS BUILT- URBN K-12-02-2025.xlsx (no text extracted (Excel))
# [INFO] Processing file: F-P-EN-01-01 E1 Log-Urban-K (1).xlsx | Project: E1
# [WARN] No text extracted from: F-P-EN-01-01 E1 Log-Urban-K (1).xlsx (no text extracted (Excel))
# [INFO] Processing file: Thumbs.db | Project: 1-Commercial & Residential BU
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: Self Exec. Power Bi Report Ver-05.pbix | Project: 07 Self-Execution
# [INFO] Processing file: Self Exec. Power Bi Report Ver-05.pbix | Project: 07 Self-Execution
# [INFO] Processing file: Self Exec. Power Bi Report Ver-06.pbix | Project: 07 Self-Execution
# [INFO] Processing file: Self Exec. Power Bi Report Ver-05-Hossam-Hatem.pbix | Project: 07 Self-Execution
# [INFO] Processing file: General Milestones.pdf | Project: 03-Completion Dates Status for the ongoing projects
# Processed 264 documents. Output saved to C:/Users/Omar Essam2/OneDrive - Rowad Modern Engineering/x004 Data Science/03.rme.db/05.llm/extracted_json\01 Dash Boards_extracted.json

# %%
# Requirements: pip install sentence-transformers torch chromadb tqdm python-dotenv
import os
import json
from sentence_transformers import SentenceTransformer
import chromadb
from chromadb.config import Settings
from dotenv import load_dotenv
from tqdm import tqdm

# Load environment variables (if needed for paths)
load_dotenv()

# New paths outside the repo
EXTRACTED_DIR = r'C:/Users/Omar Essam2/OneDrive - Rowad Modern Engineering/x004 Data Science/03.rme.db/05.llm/extracted_json'
CHROMA_DB_DIR = r'C:/Users/Omar Essam2/OneDrive - Rowad Modern Engineering/x004 Data Science/03.rme.db/05.llm/chroma_db_local'
COLLECTION_NAME = 'company_docs_local'
CHUNK_SIZE = 500  # characters per chunk (reduced for more precise retrieval)
CHUNK_OVERLAP = 200
ID_TRACK_FILE = os.path.join(CHROMA_DB_DIR, 'embedded_chunk_ids.txt')
BATCH_SIZE = 32  # Number of chunks to embed in one call

# Helper: chunk text
def chunk_text(text, chunk_size=CHUNK_SIZE, overlap=CHUNK_OVERLAP):
    chunks = []
    start = 0
    while start < len(text):
        end = min(start + chunk_size, len(text))
        chunks.append(text[start:end])
        start += chunk_size - overlap
    return chunks

# Helper: get local embeddings
model = SentenceTransformer('all-MiniLM-L6-v2')  # You can change to another local model if needed
def get_embeddings(texts):
    return model.encode(texts, show_progress_bar=False, convert_to_numpy=True).tolist()

# Initialize Chroma DB
client = chromadb.PersistentClient(path=CHROMA_DB_DIR, settings=Settings(allow_reset=True))
if COLLECTION_NAME in [c.name for c in client.list_collections()]:
    collection = client.get_collection(COLLECTION_NAME)
else:
    collection = client.create_collection(COLLECTION_NAME)

def load_embedded_ids():
    if not os.path.exists(ID_TRACK_FILE):
        return set()
    with open(ID_TRACK_FILE, 'r', encoding='utf-8') as f:
        return set(line.strip() for line in f if line.strip())

def save_embedded_id(chunk_id):
    with open(ID_TRACK_FILE, 'a', encoding='utf-8') as f:
        f.write(chunk_id + '\n')

def process_json_files():
    files = [f for f in os.listdir(EXTRACTED_DIR) if f.endswith('.json')]
    doc_count = 0
    embedded_ids = load_embedded_ids()
    for file in files:
        with open(os.path.join(EXTRACTED_DIR, file), 'r', encoding='utf-8') as f:
            docs = json.load(f)
        for doc in tqdm(docs, desc=f"Processing {file}"):
            text = doc['text']
            if not text.strip():
                continue
            chunks = chunk_text(text)
            batch_chunks = []
            batch_metas = []
            batch_ids = []
            for i, chunk in enumerate(chunks):
                chunk_id = f"{doc['file_name']}_{i}"
                if chunk_id in embedded_ids:
                    continue  # Skip already embedded chunk
                meta = {
                    'file_name': doc['file_name'],
                    'file_path': doc['file_path'],
                    'type': doc['type'],
                    'project': doc.get('project', 'GLOBAL'),
                    'extracted_at': doc['extracted_at'],
                    'chunk': i
                }
                batch_chunks.append(chunk)
                batch_metas.append(meta)
                batch_ids.append(chunk_id)
                if len(batch_chunks) == BATCH_SIZE:
                    try:
                        embs = get_embeddings(batch_chunks)
                        collection.add(
                            documents=batch_chunks,
                            embeddings=embs,
                            metadatas=batch_metas,
                            ids=batch_ids
                        )
                        for cid in batch_ids:
                            save_embedded_id(cid)
                        doc_count += len(batch_chunks)
                    except Exception as e:
                        print(f"Error embedding batch: {e}")
                    batch_chunks, batch_metas, batch_ids = [], [], []
            # Process any remaining chunks in the batch
            if batch_chunks:
                try:
                    embs = get_embeddings(batch_chunks)
                    collection.add(
                        documents=batch_chunks,
                        embeddings=embs,
                        metadatas=batch_metas,
                        ids=batch_ids
                    )
                    for cid in batch_ids:
                        save_embedded_id(cid)
                    doc_count += len(batch_chunks)
                except Exception as e:
                    print(f"Error embedding batch: {e}")
    print(f"Finished! {doc_count} new chunks embedded and stored in Chroma DB.")

if __name__ == "__main__":
    process_json_files()
# Out:
# Processing 01 Dash Boards_extracted.json: 100%|██████████| 264/264 [1:57:17<00:00, 26.66s/it]
# Finished! 365771 new chunks embedded and stored in Chroma DB.
