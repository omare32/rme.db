# %%
import os
import json
import pdfplumber
import pytesseract
from PIL import Image
import pandas as pd
from datetime import datetime
from docx import Document
from pptx import Presentation
import warnings
import re
import zipfile
import rarfile
import tempfile
import shutil

# Suppress specific CropBox warning from pdfplumber
import logging
logging.getLogger("pdfminer").setLevel(logging.ERROR)

class CropBoxFilter:
    def filter(self, record):
        return not (record.levelno == logging.WARNING and 'CropBox missing from /Page, defaulting to MediaBox' in record.getMessage())

logging.getLogger().addFilter(CropBoxFilter())

# Add tkinter for folder selection
def select_folder():
    import tkinter as tk
    from tkinter import filedialog
    root = tk.Tk()
    root.withdraw()
    folder_selected = filedialog.askdirectory(title='Select folder to process')
    root.destroy()
    return folder_selected

def extract_text_from_pdf(pdf_path):
    text = ""
    try:
        with pdfplumber.open(pdf_path) as pdf:
            for page in pdf.pages:
                page_text = page.extract_text()
                if page_text:
                    text += page_text + "\n"
    except Exception:
        pass
    return text.strip()

def ocr_pdf(pdf_path):
    text = ""
    try:
        with pdfplumber.open(pdf_path) as pdf:
            for page in pdf.pages:
                img = page.to_image(resolution=300).original
                pil_img = Image.fromarray(img)
                page_text = pytesseract.image_to_string(pil_img)
                if page_text:
                    text += page_text + "\n"
    except Exception:
        pass
    return text.strip()

def extract_project_name(file_path):
    # Try to extract project name from folder path or filename
    path_parts = os.path.normpath(file_path).split(os.sep)
    # Remove common non-project folders
    ignore = set(['', '2024', '2025', '2023', '2022', '2021', '2020', 'Mar. 2024', 'Jan-25', '3-Mar-2025', '01 Jan-25'])
    # Look for a likely project name in the path
    for part in reversed(path_parts[:-1]):
        if part not in ignore and not re.match(r'\d{4}', part):
            return part
    # Try to extract from filename
    fname = os.path.basename(file_path)
    match = re.search(r'([A-Za-z0-9\- ]+Project|[A-Za-z0-9\- ]+Dashboard|[A-Za-z0-9\- ]+Lot|[A-Za-z0-9\- ]+Port|[A-Za-z0-9\- ]+Sector)', fname)
    if match:
        return match.group(0)
    # If nothing found, label as GLOBAL
    return 'GLOBAL'

def extract_text_from_excel(excel_path):
    text = ""
    try:
        ext = excel_path.lower().split('.')[-1]
        if ext == 'xlsb':
            xls = pd.ExcelFile(excel_path, engine='pyxlsb')
        else:
            xls = pd.ExcelFile(excel_path)
        for sheet_name in xls.sheet_names:
            df = pd.read_excel(xls, sheet_name=sheet_name, dtype=str)
            # Only extract if <1000 rows and <30 columns and has headers
            if df.shape[0] < 1000 and df.shape[1] < 30 and all(df.columns.str.strip() != ''):
                text += f"\n--- Sheet: {sheet_name} ---\n"
                text += df.fillna('').to_csv(index=False)
    except Exception:
        pass
    return text.strip()

def extract_text_from_docx(docx_path):
    text = ""
    try:
        doc = Document(docx_path)
        for para in doc.paragraphs:
            text += para.text + "\n"
    except Exception:
        pass
    return text.strip()

def extract_text_from_pptx(pptx_path):
    text = ""
    try:
        prs = Presentation(pptx_path)
        for slide in prs.slides:
            for shape in slide.shapes:
                if hasattr(shape, "text"):
                    text += shape.text + "\n"
    except Exception:
        pass
    return text.strip()

def extract_text_from_ppt(file_path):
    """Attempt to convert .ppt to .pptx using unoconv, then extract text."""
    import subprocess
    import tempfile
    text = ""
    try:
        with tempfile.TemporaryDirectory() as tmpdir:
            pptx_path = os.path.join(tmpdir, os.path.basename(file_path) + '.pptx')
            # Try to convert .ppt to .pptx using unoconv
            result = subprocess.run([
                'unoconv', '-f', 'pptx', '-o', pptx_path, file_path
            ], capture_output=True)
            if result.returncode == 0 and os.path.exists(pptx_path):
                text = extract_text_from_pptx(pptx_path)
            else:
                print(f"[WARN] Failed to convert .ppt to .pptx: {file_path}")
    except Exception as e:
        print(f"[WARN] Exception during .ppt conversion: {file_path} | {e}")
    return text.strip()

def extract_text_from_pbix(pbix_path):
    """Try to extract text from .pbix by unzipping and reading .json/.xml files inside."""
    import zipfile
    import tempfile
    text = ""
    try:
        with zipfile.ZipFile(pbix_path, 'r') as z:
            with tempfile.TemporaryDirectory() as tmpdir:
                z.extractall(tmpdir)
                for root, _, files in os.walk(tmpdir):
                    for file in files:
                        if file.endswith('.json') or file.endswith('.xml'):
                            try:
                                with open(os.path.join(root, file), 'r', encoding='utf-8', errors='ignore') as f:
                                    content = f.read()
                                    # Only keep text if it's not too large
                                    if len(content) < 500_000:
                                        text += f"\n--- {file} ---\n" + content
                            except Exception:
                                continue
    except Exception as e:
        print(f"[WARN] Failed to extract .pbix: {pbix_path} | {e}")
    return text.strip()

def extract_text_from_doc(doc_path):
    """Convert .doc to .docx using unoconv, then extract text."""
    import subprocess
    import tempfile
    import os
    text = ""
    try:
        with tempfile.TemporaryDirectory() as tmpdir:
            docx_path = os.path.join(tmpdir, os.path.basename(doc_path) + '.docx')
            result = subprocess.run([
                'unoconv', '-f', 'docx', '-o', docx_path, doc_path
            ], capture_output=True)
            if result.returncode == 0 and os.path.exists(docx_path):
                text = extract_text_from_docx(docx_path)
            else:
                print(f"[WARN] Failed to convert .doc to .docx: {doc_path}")
    except Exception as e:
        print(f"[WARN] Exception during .doc conversion: {doc_path} | {e}")
    return text.strip()

def process_file(file_path, data):
    ext = file_path.lower().split('.')[-1]
    project = extract_project_name(file_path)
    print(f"[INFO] Processing file: {os.path.basename(file_path)} | Project: {project}")
    entry = {
        'file_name': os.path.basename(file_path),
        'file_path': file_path,
        'type': ext,
        'project': project,
        'extracted_at': datetime.now().isoformat(),
        'text': ''
    }
    reason = None
    if ext == 'pdf':
        text = extract_text_from_pdf(file_path)
        if not text:
            text = ocr_pdf(file_path)
            if text:
                reason = 'extracted via OCR'
            else:
                reason = 'no text extracted (PDF and OCR failed)'
        else:
            reason = 'extracted as text PDF'
        entry['text'] = text
    elif ext in ['xls', 'xlsx', 'xlsb']:
        text = extract_text_from_excel(file_path)
        entry['text'] = text
        reason = 'extracted from Excel' if text else 'no text extracted (Excel)'
    elif ext == 'docx':
        text = extract_text_from_docx(file_path)
        entry['text'] = text
        reason = 'extracted from Word' if text else 'no text extracted (Word)'
    elif ext in ['pptx', 'pptm']:
        text = extract_text_from_pptx(file_path)
        entry['text'] = text
        reason = 'extracted from PowerPoint' if text else 'no text extracted (PowerPoint)'
    elif ext == 'ppt':
        text = extract_text_from_ppt(file_path)
        entry['text'] = text
        reason = 'extracted from PPT (via conversion)' if text else 'no text extracted (PPT)'
    elif ext == 'pbix':
        text = extract_text_from_pbix(file_path)
        entry['text'] = text
        reason = 'extracted from PBIX' if text else 'no text extracted (PBIX)'
    elif ext == 'doc':
        text = extract_text_from_doc(file_path)
        entry['text'] = text
        reason = 'extracted from DOC (via conversion)' if text else 'no text extracted (DOC)'
    else:
        print(f"[WARN] Skipped unsupported file type: {os.path.basename(file_path)}")
        return
    if entry['text']:
        data.append(entry)
    else:
        print(f"[WARN] No text extracted from: {os.path.basename(file_path)} ({reason})")

def process_folder(folder_path, output_json_path):
    data = []
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            file_path = os.path.join(root, file)
            ext = file.lower().split('.')[-1]
            if ext in ['zip', 'rar']:
                print(f"[INFO] Extracting archive: {file}")
                with tempfile.TemporaryDirectory() as tmpdir:
                    try:
                        if ext == 'zip':
                            with zipfile.ZipFile(file_path, 'r') as z:
                                z.extractall(tmpdir)
                        elif ext == 'rar':
                            with rarfile.RarFile(file_path, 'r') as r:
                                r.extractall(tmpdir)
                        # Recursively process extracted files
                        for subroot, _, subfiles in os.walk(tmpdir):
                            for subfile in subfiles:
                                subfile_path = os.path.join(subroot, subfile)
                                process_file(subfile_path, data)
                    except Exception as e:
                        print(f"[WARN] Failed to extract {file}: {e}")
            else:
                process_file(file_path, data)
    with open(output_json_path, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=2)
    print(f"Processed {len(data)} documents. Output saved to {output_json_path}")

if __name__ == "__main__":
    # New output directory outside the repo
    output_dir = r'C:/Users/Omar Essam2/OneDrive - Rowad Modern Engineering/x004 Data Science/03.rme.db/05.llm/extracted_json'
    os.makedirs(output_dir, exist_ok=True)
    folder = select_folder()
    if not folder:
        print("No folder selected. Exiting.")
    else:
        folder_name = os.path.basename(os.path.normpath(folder))
        output_json = os.path.join(output_dir, f"{folder_name}_extracted.json")
        process_folder(folder, output_json)
# Out:
# [INFO] Processing file: Invoices Follow Up Log @29.12.24.xlsx | Project: 05 Client Invoices
# [WARN] No text extracted from: Invoices Follow Up Log @29.12.24.xlsx (no text extracted (Excel))
# [INFO] Processing file: Invoices Log.xlsx | Project: 01 Client Invoices
# [WARN] No text extracted from: Invoices Log.xlsx (no text extracted (Excel))
# [INFO] Processing file: IP.C.17.pdf | Project: 17
# [WARN] No text extracted from: IP.C.17.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: Invoice No 18.xlsx | Project: 18
# [WARN] No text extracted from: Invoice No 18.xlsx (no text extracted (Excel))
# [INFO] Processing file: SODIC- CS- IPC # 019.xlsx | Project: 19
# [WARN] No text extracted from: SODIC- CS- IPC # 019.xlsx (no text extracted (Excel))
# [INFO] Processing file: SODIC- ID- IPC # 019-01.xlsx | Project: 19
# [WARN] No text extracted from: SODIC- ID- IPC # 019-01.xlsx (no text extracted (Excel))
# [INFO] Processing file: SW1523.PDF | Project: 19
# [WARN] No text extracted from: SW1523.PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: SODIC- CS- IPC # 020 Rev-00.xlsx | Project: 20
# [WARN] No text extracted from: SODIC- CS- IPC # 020 Rev-00.xlsx (no text extracted (Excel))
# [INFO] Processing file: SODIC- ID- IPC # 020 Rev-00.xlsx | Project: 20
# [WARN] No text extracted from: SODIC- ID- IPC # 020 Rev-00.xlsx (no text extracted (Excel))
# [INFO] Processing file: Pages from SW1808.pdf | Project: 21
# [WARN] No text extracted from: Pages from SW1808.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: SODIC- CS- IPC # 024 Rev-00.xlsx | Project: 24
# [WARN] No text extracted from: SODIC- CS- IPC # 024 Rev-00.xlsx (no text extracted (Excel))
# [INFO] Processing file: 001- SODIC- CS- IPC # 025 Rev-00.xlsx | Project: 25
# [WARN] No text extracted from: 001- SODIC- CS- IPC # 025 Rev-00.xlsx (no text extracted (Excel))
# [INFO] Processing file: 002- SODIC- ID- IPC # 025 Rev-00.xlsx | Project: 25
# [WARN] No text extracted from: 002- SODIC- ID- IPC # 025 Rev-00.xlsx (no text extracted (Excel))
# [INFO] Processing file: 001- SODIC- CS- IPC # 026 Rev-00.xlsx | Project: 26
# [WARN] No text extracted from: 001- SODIC- CS- IPC # 026 Rev-00.xlsx (no text extracted (Excel))
# [INFO] Processing file: 002- SODIC- ID- IPC # 026 Rev-00.xlsx | Project: 26
# [WARN] No text extracted from: 002- SODIC- ID- IPC # 026 Rev-00.xlsx (no text extracted (Excel))
# [INFO] Processing file: INVOICE 26.PDF | Project: 26
# [WARN] No text extracted from: INVOICE 26.PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 001- SODIC- CS- IPC # 027 Rev-00.xlsx | Project: 27
# [WARN] No text extracted from: 001- SODIC- CS- IPC # 027 Rev-00.xlsx (no text extracted (Excel))
# [INFO] Processing file: 002- SODIC- ID- IPC # 027 Rev-00.xlsx | Project: 27
# [WARN] No text extracted from: 002- SODIC- ID- IPC # 027 Rev-00.xlsx (no text extracted (Excel))
# [INFO] Processing file: 004- France Metal - 01 Rev-00.xlsx | Project: 27
# [WARN] No text extracted from: 004- France Metal - 01 Rev-00.xlsx (no text extracted (Excel))
# [INFO] Processing file: INVOICE - 05 (SYSTEM).xlsx | Project: 27
# [WARN] No text extracted from: INVOICE - 05 (SYSTEM).xlsx (no text extracted (Excel))
# [INFO] Processing file: 001- SODIC- CS- IPC # 028 Rev-00.xlsx | Project: 28
# [WARN] No text extracted from: 001- SODIC- CS- IPC # 028 Rev-00.xlsx (no text extracted (Excel))
# [INFO] Processing file: 002- SODIC- ID- IPC # 028 Rev-00.xlsx | Project: 28
# [WARN] No text extracted from: 002- SODIC- ID- IPC # 028 Rev-00.xlsx (no text extracted (Excel))
# [INFO] Processing file: 004- France Metal - 02 Rev-00.xlsx | Project: 28
# [WARN] No text extracted from: 004- France Metal - 02 Rev-00.xlsx (no text extracted (Excel))
# [INFO] Processing file: invoice 28.pdf | Project: 28
# [WARN] No text extracted from: invoice 28.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: INVOICE 6 Rev-0 (Final).xlsx | Project: 28
# [WARN] No text extracted from: INVOICE 6 Rev-0 (Final).xlsx (no text extracted (Excel))
# [INFO] Processing file: 001- SODIC- CS- IPC # 029 Rev-00.xlsx | Project: 29
# [WARN] No text extracted from: 001- SODIC- CS- IPC # 029 Rev-00.xlsx (no text extracted (Excel))
# [INFO] Processing file: 002- SODIC- ID- IPC # 029 Rev-00.xlsx | Project: 29
# [WARN] No text extracted from: 002- SODIC- ID- IPC # 029 Rev-00.xlsx (no text extracted (Excel))
# [INFO] Processing file: 003- INVOICE 7Rev-0.xlsx | Project: 29
# [WARN] No text extracted from: 003- INVOICE 7Rev-0.xlsx (no text extracted (Excel))
# [INFO] Processing file: 004- France Metal - 03 Rev-00.xlsx | Project: 29
# [WARN] No text extracted from: 004- France Metal - 03 Rev-00.xlsx (no text extracted (Excel))
# [INFO] Processing file: 001- SODIC- CS- IPC # 030 Rev-00.xlsx | Project: 30
# [WARN] No text extracted from: 001- SODIC- CS- IPC # 030 Rev-00.xlsx (no text extracted (Excel))
# [INFO] Processing file: 002- SODIC- ID- IPC # 030 Rev-00 (2).xlsx | Project: 30
# [WARN] No text extracted from: 002- SODIC- ID- IPC # 030 Rev-00 (2).xlsx (no text extracted (Excel))
# [INFO] Processing file: 003- System -INVOICE 8 Rev-00.xlsx | Project: 30
# [WARN] No text extracted from: 003- System -INVOICE 8 Rev-00.xlsx (no text extracted (Excel))
# [INFO] Processing file: 004- France Metal - 04 Rev-00.xlsx | Project: 30
# [WARN] No text extracted from: 004- France Metal - 04 Rev-00.xlsx (no text extracted (Excel))
# [INFO] Processing file: Invoice 30.pdf | Project: 30
# [WARN] No text extracted from: Invoice 30.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 001- SODIC- CS- IPC # 031 Rev-00 (After 100% concrete).xlsx | Project: 31
# [WARN] No text extracted from: 001- SODIC- CS- IPC # 031 Rev-00 (After 100% concrete).xlsx (no text extracted (Excel))
# [INFO] Processing file: 002- SODIC- ID- IPC # 031 Rev-00.xlsx | Project: 31
# [WARN] No text extracted from: 002- SODIC- ID- IPC # 031 Rev-00.xlsx (no text extracted (Excel))
# [INFO] Processing file: 003- System INVOICE 9.xlsx | Project: 31
# [WARN] No text extracted from: 003- System INVOICE 9.xlsx (no text extracted (Excel))
# [INFO] Processing file: 004- France Metal - 05 Rev-000.xlsx | Project: 31
# [WARN] No text extracted from: 004- France Metal - 05 Rev-000.xlsx (no text extracted (Excel))
# [INFO] Processing file: INVOICE 31.pdf | Project: 31
# [WARN] No text extracted from: INVOICE 31.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 001- SODIC- CS- IPC # 032 Rev-00.xlsx | Project: 32
# [WARN] No text extracted from: 001- SODIC- CS- IPC # 032 Rev-00.xlsx (no text extracted (Excel))
# [INFO] Processing file: 002- SODIC- ID- IPC # 032 Rev-0000.xlsx | Project: 32
# [WARN] No text extracted from: 002- SODIC- ID- IPC # 032 Rev-0000.xlsx (no text extracted (Excel))
# [INFO] Processing file: 003- System INVOICE 10.xlsx | Project: 32
# [WARN] No text extracted from: 003- System INVOICE 10.xlsx (no text extracted (Excel))
# [INFO] Processing file: 004- France Metal - 06 Rev-000.xlsx | Project: 32
# [WARN] No text extracted from: 004- France Metal - 06 Rev-000.xlsx (no text extracted (Excel))
# [INFO] Processing file: 169.PDF | Project: 32
# [WARN] No text extracted from: 169.PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: Allegria- IPC # 29 - Rev 0.xls | Project: 32
# [WARN] No text extracted from: Allegria- IPC # 29 - Rev 0.xls (no text extracted (Excel))
# [INFO] Processing file: 001- SODIC- CS- IPC # 033 Rev-00.xlsx | Project: 33
# [WARN] No text extracted from: 001- SODIC- CS- IPC # 033 Rev-00.xlsx (no text extracted (Excel))
# [INFO] Processing file: 002- SODIC- ID- IPC # 033 Rev-00.xlsx | Project: 33
# [WARN] No text extracted from: 002- SODIC- ID- IPC # 033 Rev-00.xlsx (no text extracted (Excel))
# [INFO] Processing file: 003- SYSTEM INVOICE 11 Rev-00.xlsx | Project: 33
# [WARN] No text extracted from: 003- SYSTEM INVOICE 11 Rev-00.xlsx (no text extracted (Excel))
# [INFO] Processing file: 004- France Metal - 07 Rev-00.xlsx | Project: 33
# [WARN] No text extracted from: 004- France Metal - 07 Rev-00.xlsx (no text extracted (Excel))
# [INFO] Processing file: RME-EHAF-ALG-173.pdf | Project: 33
# [WARN] No text extracted from: RME-EHAF-ALG-173.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 001- SODIC- CS- IPC # 034 Rev-00.xlsx | Project: 34
# [WARN] No text extracted from: 001- SODIC- CS- IPC # 034 Rev-00.xlsx (no text extracted (Excel))
# [INFO] Processing file: 002- SODIC- ID- IPC # 034 Rev-00a.xlsx | Project: 34
# [WARN] No text extracted from: 002- SODIC- ID- IPC # 034 Rev-00a.xlsx (no text extracted (Excel))
# [INFO] Processing file: 004- France Metal - 08 Rev-00.xlsx | Project: 34
# [WARN] No text extracted from: 004- France Metal - 08 Rev-00.xlsx (no text extracted (Excel))
# [INFO] Processing file: Invoice #341.pdf | Project: 34
# [WARN] No text extracted from: Invoice #341.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 001- SODIC- CS- IPC # 035 Rev-000.xlsx | Project: 35
# [WARN] No text extracted from: 001- SODIC- CS- IPC # 035 Rev-000.xlsx (no text extracted (Excel))
# [INFO] Processing file: 002- SODIC- ID- IPC # 035 Rev-00.xlsx | Project: 35
# [WARN] No text extracted from: 002- SODIC- ID- IPC # 035 Rev-00.xlsx (no text extracted (Excel))
# [INFO] Processing file: 003- System INVOICE 13 REV00.xlsx | Project: 35
# [WARN] No text extracted from: 003- System INVOICE 13 REV00.xlsx (no text extracted (Excel))
# [INFO] Processing file: 004- France Metal - 09 Rev-00.xlsx | Project: 35
# [WARN] No text extracted from: 004- France Metal - 09 Rev-00.xlsx (no text extracted (Excel))
# [INFO] Processing file: 001- SODIC- CS- IPC # 036Rev-000.xlsx | Project: From Hussein
# [WARN] No text extracted from: 001- SODIC- CS- IPC # 036Rev-000.xlsx (no text extracted (Excel))
# [INFO] Processing file: 002- SODIC- ID- IPC # 036 Rev-000..xlsx | Project: From Hussein
# [WARN] No text extracted from: 002- SODIC- ID- IPC # 036 Rev-000..xlsx (no text extracted (Excel))
# [INFO] Processing file: 003- System -INVOICE 14-Rev-00.xlsx | Project: From Hussein
# [WARN] No text extracted from: 003- System -INVOICE 14-Rev-00.xlsx (no text extracted (Excel))
# [INFO] Processing file: 004- France Metal - 10 Rev-00.xlsx | Project: From Hussein
# [WARN] No text extracted from: 004- France Metal - 10 Rev-00.xlsx (no text extracted (Excel))
# [INFO] Processing file: FW  Sodic Allegria-IPC#36-00.msg | Project: From Hussein
# [WARN] Skipped unsupported file type: FW  Sodic Allegria-IPC#36-00.msg
# [INFO] Processing file: MEP.xls | Project: From Hussein
# [WARN] No text extracted from: MEP.xls (no text extracted (Excel))
# [INFO] Processing file: Receiving IPC #36.pdf | Project: From Hussein
# [WARN] No text extracted from: Receiving IPC #36.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 001- SODIC- CS- IPC # 036Rev-000.xlsx | Project: From Mahmoud
# [WARN] No text extracted from: 001- SODIC- CS- IPC # 036Rev-000.xlsx (no text extracted (Excel))
# [INFO] Processing file: Receiving IPC #36.pdf | Project: From Mahmoud
# [WARN] No text extracted from: Receiving IPC #36.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: RME-EHAF-ALG-2020-185- Final Invoice 37.pdf | Project: 37
# [WARN] No text extracted from: RME-EHAF-ALG-2020-185- Final Invoice 37.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: IP.C.17.pdf | Project: 17
# [WARN] No text extracted from: IP.C.17.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: IPC#18 Sodic club house (approved).pdf | Project: 18
# [WARN] No text extracted from: IPC#18 Sodic club house (approved).pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: Pages from SW1808.pdf | Project: 21
# [WARN] No text extracted from: Pages from SW1808.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: AH-1962.PDF | Project: 23
# [WARN] No text extracted from: AH-1962.PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: SODIC- CS- IPC # 023 Rev-01.xlsx | Project: 23
# [WARN] No text extracted from: SODIC- CS- IPC # 023 Rev-01.xlsx (no text extracted (Excel))
# [INFO] Processing file: SODIC- CS- IPC # 024 Rev-01.xlsx | Project: Clean copy after consultant approval
# [WARN] No text extracted from: SODIC- CS- IPC # 024 Rev-01.xlsx (no text extracted (Excel))
# [INFO] Processing file: SODIC- ID- IPC # 024 Rev-01.xlsx | Project: Clean copy after consultant approval
# [WARN] No text extracted from: SODIC- ID- IPC # 024 Rev-01.xlsx (no text extracted (Excel))
# [INFO] Processing file: Inv. 24.pdf | Project: Client
# [WARN] No text extracted from: Inv. 24.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 001- SODIC- CS- IPC # 025 Rev-01.xlsx | Project: Clean copy
# [WARN] No text extracted from: 001- SODIC- CS- IPC # 025 Rev-01.xlsx (no text extracted (Excel))
# [INFO] Processing file: 002- SODIC- ID- IPC # 025 Rev-01.xlsx | Project: Clean copy
# [WARN] No text extracted from: 002- SODIC- ID- IPC # 025 Rev-01.xlsx (no text extracted (Excel))
# [INFO] Processing file: Allegria Counrty club - Payment 25.xlsx | Project: Client approval
# [WARN] No text extracted from: Allegria Counrty club - Payment 25.xlsx (no text extracted (Excel))
# [INFO] Processing file: SM-2213.pdf | Project: Client approval
# [WARN] No text extracted from: SM-2213.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 001- SODIC- CS- IPC # 026 Rev-01.xlsx | Project: Approved by consultant
# [WARN] No text extracted from: 001- SODIC- CS- IPC # 026 Rev-01.xlsx (no text extracted (Excel))
# [INFO] Processing file: 002- SODIC- ID- IPC # 026 Rev-01.xlsx | Project: Approved by consultant
# [WARN] No text extracted from: 002- SODIC- ID- IPC # 026 Rev-01.xlsx (no text extracted (Excel))
# [INFO] Processing file: 148.PDF | Project: Approved by consultant
# [WARN] No text extracted from: 148.PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: IPC23 - Clean Copy.xlsx | Project: Approved by consultant
# [WARN] No text extracted from: IPC23 - Clean Copy.xlsx (no text extracted (Excel))
# [INFO] Processing file: System INVOICE04 Rev-01.xlsx | Project: Approved by consultant
# [WARN] No text extracted from: System INVOICE04 Rev-01.xlsx (no text extracted (Excel))
# [INFO] Processing file: Allegria Counrty club - Payment 26.pdf | Project: Client approval
# [WARN] No text extracted from: Allegria Counrty club - Payment 26.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: Allegria Counrty club - Payment 26.xlsx | Project: Client approval
# [WARN] No text extracted from: Allegria Counrty club - Payment 26.xlsx (no text extracted (Excel))
# [INFO] Processing file: Pages from SW-2359-ALG Clubhouse-.pdf | Project: Client Approval
# [WARN] No text extracted from: Pages from SW-2359-ALG Clubhouse-.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 001- SODIC- CS- IPC # 027 Rev-01.xlsx | Project: Consultant approval
# [WARN] No text extracted from: 001- SODIC- CS- IPC # 027 Rev-01.xlsx (no text extracted (Excel))
# [INFO] Processing file: 002- SODIC- ID- IPC # 027 Rev-01.xlsx | Project: Consultant approval
# [WARN] No text extracted from: 002- SODIC- ID- IPC # 027 Rev-01.xlsx (no text extracted (Excel))
# [INFO] Processing file: 004- France Metal - 01 Rev-01.xlsx | Project: Consultant approval
# [WARN] No text extracted from: 004- France Metal - 01 Rev-01.xlsx (no text extracted (Excel))
# [INFO] Processing file: Invoice 27- celan copy - Received.pdf | Project: Consultant approval
# [WARN] No text extracted from: Invoice 27- celan copy - Received.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: INVOICE 5 Rev-01.xlsx | Project: Consultant approval
# [WARN] No text extracted from: INVOICE 5 Rev-01.xlsx (no text extracted (Excel))
# [INFO] Processing file: Allegria Counrty club - Payment 28.pdf | Project: Client Approval
# [WARN] No text extracted from: Allegria Counrty club - Payment 28.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: Allegria Counrty club - Payment 28.xlsx | Project: Client Approval
# [WARN] No text extracted from: Allegria Counrty club - Payment 28.xlsx (no text extracted (Excel))
# [INFO] Processing file: 001- SODIC- CS- IPC # 028 Rev-01.xlsx | Project: Consultant approval
# [WARN] No text extracted from: 001- SODIC- CS- IPC # 028 Rev-01.xlsx (no text extracted (Excel))
# [INFO] Processing file: 002- SODIC- ID- IPC # 028 Rev-01.xlsx | Project: Consultant approval
# [WARN] No text extracted from: 002- SODIC- ID- IPC # 028 Rev-01.xlsx (no text extracted (Excel))
# [INFO] Processing file: 004- France Metal - 02 Rev-01.xlsx | Project: Consultant approval
# [WARN] No text extracted from: 004- France Metal - 02 Rev-01.xlsx (no text extracted (Excel))
# [INFO] Processing file: Invoice 28 - Clean Copy.pdf | Project: Consultant approval
# [WARN] No text extracted from: Invoice 28 - Clean Copy.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: INVOICE 6 Rev-01.xlsx | Project: Consultant approval
# [WARN] No text extracted from: INVOICE 6 Rev-01.xlsx (no text extracted (Excel))
# [INFO] Processing file: Client approval.pdf | Project: 29
# [WARN] No text extracted from: Client approval.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: Allegria Counrty club - Payment 30.pdf | Project: 30
# [WARN] No text extracted from: Allegria Counrty club - Payment 30.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: Allegria Counrty club - Payment 30.xlsx | Project: 30
# [WARN] No text extracted from: Allegria Counrty club - Payment 30.xlsx (no text extracted (Excel))
# [INFO] Processing file: Allegria Counrty club - Payment 31-1.xlsx | Project: Client
# [WARN] No text extracted from: Allegria Counrty club - Payment 31-1.xlsx (no text extracted (Excel))
# [INFO] Processing file: Allegria Counrty club - Payment 31.xlsx | Project: Client
# [WARN] No text extracted from: Allegria Counrty club - Payment 31.xlsx (no text extracted (Excel))
# [INFO] Processing file: IPC#31-1.pdf | Project: Client
# [WARN] No text extracted from: IPC#31-1.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: IPC#31.pdf | Project: Client
# [WARN] No text extracted from: IPC#31.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 001- SODIC- CS- IPC # 031 Rev-01.xlsx | Project: Consultant
# [WARN] No text extracted from: 001- SODIC- CS- IPC # 031 Rev-01.xlsx (no text extracted (Excel))
# [INFO] Processing file: 002- SODIC- ID- IPC # 031 Rev-01.xlsx | Project: Consultant
# [WARN] No text extracted from: 002- SODIC- ID- IPC # 031 Rev-01.xlsx (no text extracted (Excel))
# [INFO] Processing file: 003- System INVOICE 9 (HF).xlsx | Project: Consultant
# [WARN] No text extracted from: 003- System INVOICE 9 (HF).xlsx (no text extracted (Excel))
# [INFO] Processing file: 004- France Metal - 05 Rev-01.xlsx | Project: Consultant
# [WARN] No text extracted from: 004- France Metal - 05 Rev-01.xlsx (no text extracted (Excel))
# [INFO] Processing file: 005- MEP- IPC2#28 - Rev 1- (Clean Copy).xls | Project: Consultant
# [WARN] No text extracted from: 005- MEP- IPC2#28 - Rev 1- (Clean Copy).xls (no text extracted (Excel))
# [INFO] Processing file: 168,,.PDF | Project: Consultant
# [WARN] No text extracted from: 168,,.PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 001- SODIC- CS- IPC # 032 Rev-01.xlsx | Project: Clean Copy
# [WARN] No text extracted from: 001- SODIC- CS- IPC # 032 Rev-01.xlsx (no text extracted (Excel))
# [INFO] Processing file: 002- SODIC- ID- IPC # 032 Rev-01.xlsx | Project: Clean Copy
# [WARN] No text extracted from: 002- SODIC- ID- IPC # 032 Rev-01.xlsx (no text extracted (Excel))
# [INFO] Processing file: 003- INVOICE 10 REV01.xlsx | Project: Clean Copy
# [WARN] No text extracted from: 003- INVOICE 10 REV01.xlsx (no text extracted (Excel))
# [INFO] Processing file: 004- France Metal - 06 Rev-01.xlsx | Project: Clean Copy
# [WARN] No text extracted from: 004- France Metal - 06 Rev-01.xlsx (no text extracted (Excel))
# [INFO] Processing file: Invoic (32) - Clean Copy.pdf | Project: Clean Copy
# [WARN] No text extracted from: Invoic (32) - Clean Copy.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: Allegria Counrty club - Payment 32.pdf | Project: Client
# [WARN] No text extracted from: Allegria Counrty club - Payment 32.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: Allegria Counrty club - Payment 32.xlsx | Project: Client
# [WARN] No text extracted from: Allegria Counrty club - Payment 32.xlsx (no text extracted (Excel))
# [INFO] Processing file: 001- SODIC- CS- IPC # 032 Rev-00.xlsx | Project: Consultant
# [WARN] No text extracted from: 001- SODIC- CS- IPC # 032 Rev-00.xlsx (no text extracted (Excel))
# [INFO] Processing file: 002- SODIC- ID- IPC # 032 Rev-0000.xlsx | Project: Consultant
# [WARN] No text extracted from: 002- SODIC- ID- IPC # 032 Rev-0000.xlsx (no text extracted (Excel))
# [INFO] Processing file: 003- System INVOICE 10.xlsx | Project: Consultant
# [WARN] No text extracted from: 003- System INVOICE 10.xlsx (no text extracted (Excel))
# [INFO] Processing file: 001- SODIC- CS- IPC # 033 Rev-01.xlsx | Project: Clean Copy
# [WARN] No text extracted from: 001- SODIC- CS- IPC # 033 Rev-01.xlsx (no text extracted (Excel))
# [INFO] Processing file: 002- SODIC- ID- IPC # 033 Rev-001.xlsx | Project: Clean Copy
# [WARN] No text extracted from: 002- SODIC- ID- IPC # 033 Rev-001.xlsx (no text extracted (Excel))
# [INFO] Processing file: 003- SYSTEM INVOICE 11 rev01.xlsx | Project: Clean Copy
# [WARN] No text extracted from: 003- SYSTEM INVOICE 11 rev01.xlsx (no text extracted (Excel))
# [INFO] Processing file: 004- France Metal - 07 Rev-01.xlsx | Project: Clean Copy
# [WARN] No text extracted from: 004- France Metal - 07 Rev-01.xlsx (no text extracted (Excel))
# [INFO] Processing file: RME-EHAF-ALG-175.PDF | Project: Clean Copy
# [WARN] No text extracted from: RME-EHAF-ALG-175.PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 1.pdf | Project: Client
# [WARN] No text extracted from: 1.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: Allegria Counrty club - Payment 33.xlsx | Project: Client
# [WARN] No text extracted from: Allegria Counrty club - Payment 33.xlsx (no text extracted (Excel))
# [INFO] Processing file: 001- SODIC- CS- IPC # 034 Rev-01.xlsx | Project: Clean copy
# [WARN] No text extracted from: 001- SODIC- CS- IPC # 034 Rev-01.xlsx (no text extracted (Excel))
# [INFO] Processing file: 002- SODIC- ID- IPC # 034 Rev-01.xlsx | Project: Clean copy
# [WARN] No text extracted from: 002- SODIC- ID- IPC # 034 Rev-01.xlsx (no text extracted (Excel))
# [INFO] Processing file: receiving invoice 34-clean copy.PDF | Project: Clean copy
# [WARN] No text extracted from: receiving invoice 34-clean copy.PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: Allegria Counrty club - Payment 34.xlsx | Project: Client
# [WARN] No text extracted from: Allegria Counrty club - Payment 34.xlsx (no text extracted (Excel))
# [INFO] Processing file: pay 34.pdf | Project: Client
# [WARN] No text extracted from: pay 34.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 001- SODIC- CS- IPC # 035 Rev-001.xlsx | Project: 35
# [WARN] No text extracted from: 001- SODIC- CS- IPC # 035 Rev-001.xlsx (no text extracted (Excel))
# [INFO] Processing file: 002- SODIC- ID- IPC # 035 Rev-001.xlsx | Project: 35
# [WARN] No text extracted from: 002- SODIC- ID- IPC # 035 Rev-001.xlsx (no text extracted (Excel))
# [INFO] Processing file: 003- System INVOICE 13 REV01.xlsx | Project: 35
# [WARN] No text extracted from: 003- System INVOICE 13 REV01.xlsx (no text extracted (Excel))
# [INFO] Processing file: 004- France Metal - 09 Rev-01.xlsx | Project: 35
# [WARN] No text extracted from: 004- France Metal - 09 Rev-01.xlsx (no text extracted (Excel))
# [INFO] Processing file: Allegria Counrty club - Payment 35.xlsx | Project: Client
# [WARN] No text extracted from: Allegria Counrty club - Payment 35.xlsx (no text extracted (Excel))
# [INFO] Processing file: Pages from SW3121.pdf | Project: Client
# [WARN] No text extracted from: Pages from SW3121.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: 001- SODIC- CS- IPC # 036Rev-01.xlsx | Project: CS
# [WARN] No text extracted from: 001- SODIC- CS- IPC # 036Rev-01.xlsx (no text extracted (Excel))
# [INFO] Processing file: 002- SODIC- ID- IPC # 036 Rev-01.xlsx | Project: CS
# [WARN] No text extracted from: 002- SODIC- ID- IPC # 036 Rev-01.xlsx (no text extracted (Excel))
# [INFO] Processing file: 003- System -INVOICE 14-Rev-01.xlsx | Project: CS
# [WARN] No text extracted from: 003- System -INVOICE 14-Rev-01.xlsx (no text extracted (Excel))
# [INFO] Processing file: 004- France Metal - 10 Rev-01.xlsx | Project: CS
# [WARN] No text extracted from: 004- France Metal - 10 Rev-01.xlsx (no text extracted (Excel))
# [INFO] Processing file: Allegria- IPC # 33 - (Clean Copy)-Rev.01.xls | Project: CS
# [WARN] No text extracted from: Allegria- IPC # 33 - (Clean Copy)-Rev.01.xls (no text extracted (Excel))
# [INFO] Processing file: RME-EHAF-ALG-182.pdf | Project: CS
# [WARN] No text extracted from: RME-EHAF-ALG-182.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: IPC no.24 approved by turner.pdf | Project: 24
# [WARN] No text extracted from: IPC no.24 approved by turner.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: IPC no.24 approved by turner.xlsm | Project: 24
# [WARN] Skipped unsupported file type: IPC no.24 approved by turner.xlsm
# [INFO] Processing file: PC24  finaaaaal.xlsm | Project: 24
# [WARN] Skipped unsupported file type: PC24  finaaaaal.xlsm
# [INFO] Processing file: PKG#53-PC26 A.C.E. Rev.1-Scenario 2.xlsm | Project: 26
# [WARN] Skipped unsupported file type: PKG#53-PC26 A.C.E. Rev.1-Scenario 2.xlsm
# [INFO] Processing file: Transmittal no.2942 Rev.00 - IPC no.26.pdf | Project: 26
# [WARN] No text extracted from: Transmittal no.2942 Rev.00 - IPC no.26.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: PKG#53-IPC no.27.xlsm | Project: 27
# [WARN] Skipped unsupported file type: PKG#53-IPC no.27.xlsm
# [INFO] Processing file: PKG#53-IPC 28 R.M.E Rev.0.xlsm | Project: 28
# [WARN] Skipped unsupported file type: PKG#53-IPC 28 R.M.E Rev.0.xlsm
# [INFO] Processing file: Transmittal no.2966 Rev.00 - IPC no.28-Uptown cairo-PKG#53.pdf | Project: 28
# [WARN] No text extracted from: Transmittal no.2966 Rev.00 - IPC no.28-Uptown cairo-PKG#53.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: PKG#53-IPC 29 R.M.E Rev.0.xlsm | Project: 29
# [WARN] Skipped unsupported file type: PKG#53-IPC 29 R.M.E Rev.0.xlsm
# [INFO] Processing file: Transmittal no.2983 Rev.00 - IPC no.29-Uptown cairo-PKG#53.pdf | Project: 29
# [WARN] No text extracted from: Transmittal no.2983 Rev.00 - IPC no.29-Uptown cairo-PKG#53.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: PKG#53-IPC 30 RME-REV 01-Scenario 1.xlsm | Project: 30
# [WARN] Skipped unsupported file type: PKG#53-IPC 30 RME-REV 01-Scenario 1.xlsm
# [INFO] Processing file: Transmittal Out No.3010 Interim Payment Certificate # 31.PDF | Project: 31
# [WARN] No text extracted from: Transmittal Out No.3010 Interim Payment Certificate # 31.PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: IPC#32 - April 2018 RME.xlsm | Project: 32
# [WARN] Skipped unsupported file type: IPC#32 - April 2018 RME.xlsm
# [INFO] Processing file: Transmittal Out No.3021 Interim Payment Certificate No.32.PDF | Project: 32
# [WARN] No text extracted from: Transmittal Out No.3021 Interim Payment Certificate No.32.PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: IPC#33 - May 2018 - RME.xlsm | Project: 33
# [WARN] Skipped unsupported file type: IPC#33 - May 2018 - RME.xlsm
# [INFO] Processing file: Transmittal no.3029 Rev.0 - IPC no.33.pdf | Project: 33
# [WARN] No text extracted from: Transmittal no.3029 Rev.0 - IPC no.33.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: IPC#34-June 2018 RME - Scenario 1.xlsm | Project: 34
# [WARN] Skipped unsupported file type: IPC#34-June 2018 RME - Scenario 1.xlsm
# [INFO] Processing file: Transmittal Out No.3035 Interim Payment Certificate # 34.PDF | Project: 34
# [WARN] No text extracted from: Transmittal Out No.3035 Interim Payment Certificate # 34.PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: IPC#35 - July 2018 - RME-Last.xlsm | Project: 35
# [WARN] Skipped unsupported file type: IPC#35 - July 2018 - RME-Last.xlsm
# [INFO] Processing file: Submitted IPC no.35.pdf | Project: 35
# [WARN] No text extracted from: Submitted IPC no.35.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: IPC#36 - August 2018 - Rowad.xlsm | Project: 36
# [WARN] Skipped unsupported file type: IPC#36 - August 2018 - Rowad.xlsm
# [INFO] Processing file: Transmittal Out No.3060 Interim Payment Certificate No.36.PDF | Project: 36
# [WARN] No text extracted from: Transmittal Out No.3060 Interim Payment Certificate No.36.PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: IPC#37 - September 2018 - RME.xlsm | Project: 37
# [WARN] Skipped unsupported file type: IPC#37 - September 2018 - RME.xlsm
# [INFO] Processing file: Transmittal Out No.3069 IPC no.37 - September 2018 - RME.PDF | Project: 37
# [WARN] No text extracted from: Transmittal Out No.3069 IPC no.37 - September 2018 - RME.PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: IPC#38 - January 2019 - RME.xlsm | Project: Rev.00
# [WARN] Skipped unsupported file type: IPC#38 - January 2019 - RME.xlsm
# [INFO] Processing file: IPC#38 - January 2019 - RME.xlsm | Project: Rev.01
# [WARN] Skipped unsupported file type: IPC#38 - January 2019 - RME.xlsm
# [INFO] Processing file: Transmittal Out No.3078 Transmittal Out No.3078 Interim Payment Certificate No.38.PDF | Project: Rev.01
# [WARN] No text extracted from: Transmittal Out No.3078 Transmittal Out No.3078 Interim Payment Certificate No.38.PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: IPC#38 - January 2019 - RME.xlsm | Project: Rev.02
# [WARN] Skipped unsupported file type: IPC#38 - January 2019 - RME.xlsm
# [INFO] Processing file: 3079  ipc 39.PDF | Project: 39
# [WARN] No text extracted from: 3079  ipc 39.PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: IPC no  39 pkg 53 - Submitted.msg | Project: 39
# [WARN] Skipped unsupported file type: IPC no  39 pkg 53 - Submitted.msg
# [INFO] Processing file: IPC#39 - April 2019 - RME.xlsm | Project: 39
# [WARN] Skipped unsupported file type: IPC#39 - April 2019 - RME.xlsm
# [INFO] Processing file: IPC#40.PDF | Project: 40
# [WARN] No text extracted from: IPC#40.PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: Interim payment Certificate no.42 rev.1.PDF | Project: 42
# [WARN] No text extracted from: Interim payment Certificate no.42 rev.1.PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: Final Interim Payment no.43.pdf | Project: 43
# [WARN] No text extracted from: Final Interim Payment no.43.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: Approved IPC no.25 by Turner.pdf | Project: Client Approval
# [WARN] No text extracted from: Approved IPC no.25 by Turner.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: IPC no.25 - Approved by turner.xlsm | Project: Client Approval
# [WARN] Skipped unsupported file type: IPC no.25 - Approved by turner.xlsm
# [INFO] Processing file: PKG#53-PC25 A.C.E. Rev.0.xlsm | Project: Consultant approval
# [WARN] Skipped unsupported file type: PKG#53-PC25 A.C.E. Rev.0.xlsm
# [INFO] Processing file: Transmittal no.2912 - IPC no.25.pdf | Project: Consultant approval
# [WARN] No text extracted from: Transmittal no.2912 - IPC no.25.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: Approved IPC no.26 by Turner.pdf | Project: Client Approval
# [WARN] No text extracted from: Approved IPC no.26 by Turner.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: PKG#53-PC26 finaaaaal.xlsm | Project: Client Approval
# [WARN] Skipped unsupported file type: PKG#53-PC26 finaaaaal.xlsm
# [INFO] Processing file: PKG#53-PC26 A.C.E. Rev.0.xlsm | Project: Consultant approval
# [WARN] Skipped unsupported file type: PKG#53-PC26 A.C.E. Rev.0.xlsm
# [INFO] Processing file: Transmittal In No.2942 Interim Payment Certificate # 26.PDF | Project: Consultant approval
# [WARN] No text extracted from: Transmittal In No.2942 Interim Payment Certificate # 26.PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: IPC no.27 - November 2017-Approved by urner.pdf | Project: Approved by client
# [WARN] No text extracted from: IPC no.27 - November 2017-Approved by urner.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: PKG#53-PC27 finaaaal.xlsm | Project: Approved by client
# [WARN] Skipped unsupported file type: PKG#53-PC27 finaaaal.xlsm
# [INFO] Processing file: PKG#53-PC27 A.C.E. Rev.0.xlsm | Project: Approved by consultant
# [WARN] Skipped unsupported file type: PKG#53-PC27 A.C.E. Rev.0.xlsm
# [INFO] Processing file: Transmittal no.2957-IPC no.27-approved by consultant.pdf | Project: Approved by consultant
# [WARN] No text extracted from: Transmittal no.2957-IPC no.27-approved by consultant.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: Approved IPC no.28 by turner 15-2-2018.pdf | Project: Client approval
# [WARN] No text extracted from: Approved IPC no.28 by turner 15-2-2018.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file
DF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: Interim Payment Certificate No.36.PDF | Project: Rev.02
# [WARN] No text extracted from: Interim Payment Certificate No.36.PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: IPC#36 - finaaaal.xlsm | Project: Rev.02
# [WARN] Skipped unsupported file type: IPC#36 - finaaaal.xlsm
# [INFO] Processing file: IPC#37 - September 2018 -ACE-After check-5-11-2018+++++.xlsm | Project: Clean copy
# [WARN] Skipped unsupported file type: IPC#37 - September 2018 -ACE-After check-5-11-2018+++++.xlsm
# [INFO] Processing file: IPC#37 - September 2018 -ACE-After check-5-11-2018.xlsm | Project: Rev.01
# [WARN] Skipped unsupported file type: IPC#37 - September 2018 -ACE-After check-5-11-2018.xlsm
# [INFO] Processing file: Transmittal In No.3069.Rev 00 Interim Payment Certificate No.37 (Sep 2018).PDF | Project: Rev.01
# [WARN] No text extracted from: Transmittal In No.3069.Rev 00 Interim Payment Certificate No.37 (Sep 2018).PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: Approved IPC no.37 by Consultant - Uptown cairo-PKG#53 (14.9 MB).msg | Project: Rev.02
# [WARN] Skipped unsupported file type: Approved IPC no.37 by Consultant - Uptown cairo-PKG#53 (14.9 MB).msg
# [INFO] Processing file: IPC#37 - September 2018 -ACE-After check-17-11-2018.xlsm | Project: Rev.02
# [WARN] Skipped unsupported file type: IPC#37 - September 2018 -ACE-After check-17-11-2018.xlsm
# [INFO] Processing file: Transmittal In No.3069.Rev 00 Interim Payment Certificate No.37 (Sep 2018).PDF | Project: Rev.02
# [WARN] No text extracted from: Transmittal In No.3069.Rev 00 Interim Payment Certificate No.37 (Sep 2018).PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: IPC no.37 - Approved by TiME.PDF | Project: Rev.03
# [WARN] No text extracted from: IPC no.37 - Approved by TiME.PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: IPC#37 - September 2018 -TIME.xlsm | Project: Rev.03
# [WARN] Skipped unsupported file type: IPC#37 - September 2018 -TIME.xlsm
# [INFO] Processing file: Interim Payment Certificate # 37 - Rev.01.PDF | Project: Rev.04
# [WARN] No text extracted from: Interim Payment Certificate # 37 - Rev.01.PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: IPC#37 - September 2018 -TIME-REV01.xlsm | Project: Rev.04
# [WARN] Skipped unsupported file type: IPC#37 - September 2018 -TIME-REV01.xlsm
# [INFO] Processing file: Approved IPC no.37 by Consultant - Uptown cairo-PKG#53 (14.9 MB).msg | Project: New folder
# [WARN] Skipped unsupported file type: Approved IPC no.37 by Consultant - Uptown cairo-PKG#53 (14.9 MB).msg
# [INFO] Processing file: deduction of 2nd coat in Punch list from B9 till B15 - Uptown cairo-PKG#53.xlsx | Project: New folder
# [WARN] No text extracted from: deduction of 2nd coat in Punch list from B9 till B15 - Uptown cairo-PKG#53.xlsx (no text extracted (Excel))
# [INFO] Extracting archive: IPC#37 - September 2018 -ACE-After check-17-11-2018.rar
# [INFO] Processing file: IPC#37 - September 2018 -ACE-After check-17-11-2018.xlsm | Project: tmpymx59j7q
# [WARN] Skipped unsupported file type: IPC#37 - September 2018 -ACE-After check-17-11-2018.xlsm
# [INFO] Extracting archive: IPC#37 - September 2018 -ACE-After check-5-11-2018.rar
# [INFO] Processing file: IPC#37 - September 2018 -ACE-After check-5-11-2018.xlsm | Project: tmp6tir8nxu
# [WARN] Skipped unsupported file type: IPC#37 - September 2018 -ACE-After check-5-11-2018.xlsm
# [INFO] Processing file: Transmittal In No.3069.Rev 00 Interim Payment Certificate No.37 (Sep 2018).PDF | Project: New folder
# [WARN] No text extracted from: Transmittal In No.3069.Rev 00 Interim Payment Certificate No.37 (Sep 2018).PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: IPC#37 - September 2018 -ACE-After check-17-11-2018.xlsm | Project: IPC#37 - September 2018 -ACE-After check-17-11-2018
# [WARN] Skipped unsupported file type: IPC#37 - September 2018 -ACE-After check-17-11-2018.xlsm
# [INFO] Processing file: IPC#37 - September 2018 -ACE-After check-5-11-2018.xlsm | Project: IPC#37 - September 2018 -ACE-After check-5-11-2018
# [WARN] Skipped unsupported file type: IPC#37 - September 2018 -ACE-After check-5-11-2018.xlsm
# [INFO] Processing file: interm payment 38.pdf | Project: CS
# [WARN] No text extracted from: interm payment 38.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: IPC#38 -after check - TIME.xlsm | Project: CS
# [WARN] Skipped unsupported file type: IPC#38 -after check - TIME.xlsm
# [INFO] Processing file: RE  PKG#53- IPC#38.msg | Project: CS
# [WARN] Skipped unsupported file type: RE  PKG#53- IPC#38.msg
# [INFO] Processing file: 3079  ipc 39.PDF | Project: Rev.01
# [WARN] No text extracted from: 3079  ipc 39.PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: Differenece between Submit & revised from Consultant in IPC no.39.xlsx | Project: Rev.01
# [WARN] No text extracted from: Differenece between Submit & revised from Consultant in IPC no.39.xlsx (no text extracted (Excel))
# [INFO] Processing file: Interim payment certificate 39.PDF | Project: Rev.01
# [WARN] No text extracted from: Interim payment certificate 39.PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: IPC no 39 - Uptown cairo - PKG#53- revised by consultant (ACE).msg | Project: Rev.01
# [WARN] Skipped unsupported file type: IPC no 39 - Uptown cairo - PKG#53- revised by consultant (ACE).msg
# [INFO] Processing file: IPC#39 - April 2019 - RME -After Check.xlsm | Project: Rev.01
# [WARN] Skipped unsupported file type: IPC#39 - April 2019 - RME -After Check.xlsm
# [INFO] Processing file: Request for the issuance of the final certificate (Reminder)7.8.PDF | Project: Rev.01
# [WARN] No text extracted from: Request for the issuance of the final certificate (Reminder)7.8.PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: Request for the issuance of the final certificate 11,12.pdf | Project: Rev.01
# [WARN] No text extracted from: Request for the issuance of the final certificate 11,12.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: Request for the issuance of the final certificate 13,14.PDF | Project: Rev.01
# [WARN] No text extracted from: Request for the issuance of the final certificate 13,14.PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: Request for the issuance of the final certificate 7,8,9,10 (Reminder).pdf | Project: Rev.01
# [WARN] No text extracted from: Request for the issuance of the final certificate 7,8,9,10 (Reminder).pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: Approved IPC no.41.jpg | Project: 41
# [WARN] Skipped unsupported file type: Approved IPC no.41.jpg
# [INFO] Processing file: Interim payment Certificate no.42 rev.1.PDF | Project: 42
# [WARN] No text extracted from: Interim payment Certificate no.42 rev.1.PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file
2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: 4 Collection April 2024.xlsx | Project: 04
# [WARN] No text extracted from: 4 Collection April 2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: Collection April 2024.xlsx | Project: 04
# [WARN] No text extracted from: Collection April 2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: 1 Collection May 2024.xlsx | Project: 01
# [WARN] No text extracted from: 1 Collection May 2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: 16.05.2024.xlsx | Project: 01
# [WARN] No text extracted from: 16.05.2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: Collection status 21-05-2024.xlsx | Project: 01
# [WARN] No text extracted from: Collection status 21-05-2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: 2 Collection May 2024.xlsx | Project: 02
# [WARN] No text extracted from: 2 Collection May 2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: 3 Collection May 2024.xlsx | Project: 03
# [WARN] No text extracted from: 3 Collection May 2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: 4 Collection May 2024.xlsx | Project: 04
# [WARN] No text extracted from: 4 Collection May 2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: Book1.xlsx | Project: 04
# [WARN] No text extracted from: Book1.xlsx (no text extracted (Excel))
# [INFO] Processing file: Book1.xlsx | Project: 01
# [WARN] No text extracted from: Book1.xlsx (no text extracted (Excel))
# [INFO] Processing file: collection June 2024.xlsx | Project: 01
# [WARN] No text extracted from: collection June 2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: 03.07.2024.xlsx | Project: 02
# [WARN] No text extracted from: 03.07.2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: Book1.xlsx | Project: 02
# [WARN] No text extracted from: Book1.xlsx (no text extracted (Excel))
# [INFO] Processing file: collection June 2024.xlsx | Project: 02
# [WARN] No text extracted from: collection June 2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: Collection july 2024.xlsx | Project: 01
# [WARN] No text extracted from: Collection july 2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: collection August 2024 - Copy.xlsx | Project: 01
# [WARN] No text extracted from: collection August 2024 - Copy.xlsx (no text extracted (Excel))
# [INFO] Processing file: 10.10.2024.xlsx | Project: 09 Sep-24
# [WARN] No text extracted from: 10.10.2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: Book1.xlsx | Project: 09 Sep-24
# [WARN] No text extracted from: Book1.xlsx (no text extracted (Excel))
# [INFO] Processing file: collection September  2024 -.xlsx | Project: 09 Sep-24
# [WARN] No text extracted from: collection September  2024 -.xlsx (no text extracted (Excel))
# [INFO] Processing file: collection October 2024.xlsx | Project: 10 Oct-24
# [WARN] No text extracted from: collection October 2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: 26.12.2024.xlsx | Project: 11 Nov-24
# [WARN] No text extracted from: 26.12.2024.xlsx (no text extracted (Excel))
# [INFO] Processing file: Book1.xlsx | Project: 11 Nov-24
# [WARN] No text extracted from: Book1.xlsx (no text extracted (Excel))
# [INFO] Processing file: collection November  2024 -.xlsx | Project: 11 Nov-24
# [WARN] No text extracted from: collection November  2024 -.xlsx (no text extracted (Excel))
# [INFO] Processing file: collection December 2024 -.xlsx | Project: 12 Dec-24
# [WARN] No text extracted from: collection December 2024 -.xlsx (no text extracted (Excel))
# Processed 1617 documents. Output saved to C:/Users/Omar Essam2/OneDrive - Rowad Modern Engineering/x004 Data Science/03.rme.db/05.llm/extracted_json\05 Client Invoices_extracted.json

# %%
# Requirements: pip install sentence-transformers torch chromadb tqdm python-dotenv
import os
import json
from sentence_transformers import SentenceTransformer
import chromadb
from chromadb.config import Settings
from dotenv import load_dotenv
from tqdm import tqdm

# Load environment variables (if needed for paths)
load_dotenv()

# New paths outside the repo
EXTRACTED_DIR = r'C:/Users/Omar Essam2/OneDrive - Rowad Modern Engineering/x004 Data Science/03.rme.db/05.llm/extracted_json'
CHROMA_DB_DIR = r'C:/Users/Omar Essam2/OneDrive - Rowad Modern Engineering/x004 Data Science/03.rme.db/05.llm/chroma_db_local'
COLLECTION_NAME = 'company_docs_local'
CHUNK_SIZE = 500  # characters per chunk (reduced for more precise retrieval)
CHUNK_OVERLAP = 200
ID_TRACK_FILE = os.path.join(CHROMA_DB_DIR, 'embedded_chunk_ids.txt')
BATCH_SIZE = 32  # Number of chunks to embed in one call

# Helper: chunk text
def chunk_text(text, chunk_size=CHUNK_SIZE, overlap=CHUNK_OVERLAP):
    chunks = []
    start = 0
    while start < len(text):
        end = min(start + chunk_size, len(text))
        chunks.append(text[start:end])
        start += chunk_size - overlap
    return chunks

# Helper: get local embeddings
model = SentenceTransformer('all-MiniLM-L6-v2')  # You can change to another local model if needed
def get_embeddings(texts):
    return model.encode(texts, show_progress_bar=False, convert_to_numpy=True).tolist()

# Initialize Chroma DB
client = chromadb.PersistentClient(path=CHROMA_DB_DIR, settings=Settings(allow_reset=True))
if COLLECTION_NAME in [c.name for c in client.list_collections()]:
    collection = client.get_collection(COLLECTION_NAME)
else:
    collection = client.create_collection(COLLECTION_NAME)

def load_embedded_ids():
    if not os.path.exists(ID_TRACK_FILE):
        return set()
    with open(ID_TRACK_FILE, 'r', encoding='utf-8') as f:
        return set(line.strip() for line in f if line.strip())

def save_embedded_id(chunk_id):
    with open(ID_TRACK_FILE, 'a', encoding='utf-8') as f:
        f.write(chunk_id + '\n')

def process_json_files():
    files = [f for f in os.listdir(EXTRACTED_DIR) if f.endswith('.json')]
    doc_count = 0
    embedded_ids = load_embedded_ids()
    for file in files:
        with open(os.path.join(EXTRACTED_DIR, file), 'r', encoding='utf-8') as f:
            docs = json.load(f)
        for doc in tqdm(docs, desc=f"Processing {file}"):
            text = doc['text']
            if not text.strip():
                continue
            chunks = chunk_text(text)
            batch_chunks = []
            batch_metas = []
            batch_ids = []
            for i, chunk in enumerate(chunks):
                chunk_id = f"{doc['file_name']}_{i}"
                if chunk_id in embedded_ids:
                    continue  # Skip already embedded chunk
                meta = {
                    'file_name': doc['file_name'],
                    'file_path': doc['file_path'],
                    'type': doc['type'],
                    'project': doc.get('project', 'GLOBAL'),
                    'extracted_at': doc['extracted_at'],
                    'chunk': i
                }
                batch_chunks.append(chunk)
                batch_metas.append(meta)
                batch_ids.append(chunk_id)
                if len(batch_chunks) == BATCH_SIZE:
                    try:
                        embs = get_embeddings(batch_chunks)
                        collection.add(
                            documents=batch_chunks,
                            embeddings=embs,
                            metadatas=batch_metas,
                            ids=batch_ids
                        )
                        for cid in batch_ids:
                            save_embedded_id(cid)
                        doc_count += len(batch_chunks)
                    except Exception as e:
                        print(f"Error embedding batch: {e}")
                    batch_chunks, batch_metas, batch_ids = [], [], []
            # Process any remaining chunks in the batch
            if batch_chunks:
                try:
                    embs = get_embeddings(batch_chunks)
                    collection.add(
                        documents=batch_chunks,
                        embeddings=embs,
                        metadatas=batch_metas,
                        ids=batch_ids
                    )
                    for cid in batch_ids:
                        save_embedded_id(cid)
                    doc_count += len(batch_chunks)
                except Exception as e:
                    print(f"Error embedding batch: {e}")
    print(f"Finished! {doc_count} new chunks embedded and stored in Chroma DB.")

if __name__ == "__main__":
    process_json_files()
# Out:
# Processing 01 Dash Boards_extracted.json: 100%|██████████| 264/264 [00:00<00:00, 857.86it/s]
# Processing 02 Monthly Progress Presentation_extracted.json: 100%|██████████| 574/574 [00:00<00:00, 40127.51it/s]
# Processing 03 Procurement Follow Up Reports_extracted.json: 100%|██████████| 22/22 [00:00<00:00, 56059.96it/s]
# Processing 04 Engineering Follow Up_extracted.json: 0it [00:00, ?it/s]
# Processing 05 Client Invoices_extracted.json: 100%|██████████| 1617/1617 [1:51:34<00:00,  4.14s/it]
# Finished! 458008 new chunks embedded and stored in Chroma DB.
