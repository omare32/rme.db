# %%
import os
import json
import pdfplumber
import pytesseract
from PIL import Image
import pandas as pd
from datetime import datetime
from docx import Document
from pptx import Presentation
import warnings
import re
import zipfile
import rarfile
import tempfile
import shutil

# Suppress specific CropBox warning from pdfplumber
import logging
logging.getLogger("pdfminer").setLevel(logging.ERROR)

class CropBoxFilter:
    def filter(self, record):
        return not (record.levelno == logging.WARNING and 'CropBox missing from /Page, defaulting to MediaBox' in record.getMessage())

logging.getLogger().addFilter(CropBoxFilter())

# Add tkinter for folder selection
def select_folder():
    import tkinter as tk
    from tkinter import filedialog
    root = tk.Tk()
    root.withdraw()
    folder_selected = filedialog.askdirectory(title='Select folder to process')
    root.destroy()
    return folder_selected

def extract_text_from_pdf(pdf_path):
    text = ""
    try:
        with pdfplumber.open(pdf_path) as pdf:
            for page in pdf.pages:
                page_text = page.extract_text()
                if page_text:
                    text += page_text + "\n"
    except Exception:
        pass
    return text.strip()

def ocr_pdf(pdf_path):
    text = ""
    try:
        with pdfplumber.open(pdf_path) as pdf:
            for page in pdf.pages:
                img = page.to_image(resolution=300).original
                pil_img = Image.fromarray(img)
                page_text = pytesseract.image_to_string(pil_img)
                if page_text:
                    text += page_text + "\n"
    except Exception:
        pass
    return text.strip()

def extract_project_name(file_path):
    # Try to extract project name from folder path or filename
    path_parts = os.path.normpath(file_path).split(os.sep)
    # Remove common non-project folders
    ignore = set(['', '2024', '2025', '2023', '2022', '2021', '2020', 'Mar. 2024', 'Jan-25', '3-Mar-2025', '01 Jan-25'])
    # Look for a likely project name in the path
    for part in reversed(path_parts[:-1]):
        if part not in ignore and not re.match(r'\d{4}', part):
            return part
    # Try to extract from filename
    fname = os.path.basename(file_path)
    match = re.search(r'([A-Za-z0-9\- ]+Project|[A-Za-z0-9\- ]+Dashboard|[A-Za-z0-9\- ]+Lot|[A-Za-z0-9\- ]+Port|[A-Za-z0-9\- ]+Sector)', fname)
    if match:
        return match.group(0)
    # If nothing found, label as GLOBAL
    return 'GLOBAL'

def extract_text_from_excel(excel_path):
    text = ""
    try:
        ext = excel_path.lower().split('.')[-1]
        if ext == 'xlsb':
            xls = pd.ExcelFile(excel_path, engine='pyxlsb')
        else:
            xls = pd.ExcelFile(excel_path)
        for sheet_name in xls.sheet_names:
            df = pd.read_excel(xls, sheet_name=sheet_name, dtype=str)
            # Only extract if <1000 rows and <30 columns and has headers
            if df.shape[0] < 1000 and df.shape[1] < 30 and all(df.columns.str.strip() != ''):
                text += f"\n--- Sheet: {sheet_name} ---\n"
                text += df.fillna('').to_csv(index=False)
    except Exception:
        pass
    return text.strip()

def extract_text_from_docx(docx_path):
    text = ""
    try:
        doc = Document(docx_path)
        for para in doc.paragraphs:
            text += para.text + "\n"
    except Exception:
        pass
    return text.strip()

def extract_text_from_pptx(pptx_path):
    text = ""
    try:
        prs = Presentation(pptx_path)
        for slide in prs.slides:
            for shape in slide.shapes:
                if hasattr(shape, "text"):
                    text += shape.text + "\n"
    except Exception:
        pass
    return text.strip()

def extract_text_from_ppt(file_path):
    """Attempt to convert .ppt to .pptx using unoconv, then extract text."""
    import subprocess
    import tempfile
    text = ""
    try:
        with tempfile.TemporaryDirectory() as tmpdir:
            pptx_path = os.path.join(tmpdir, os.path.basename(file_path) + '.pptx')
            # Try to convert .ppt to .pptx using unoconv
            result = subprocess.run([
                'unoconv', '-f', 'pptx', '-o', pptx_path, file_path
            ], capture_output=True)
            if result.returncode == 0 and os.path.exists(pptx_path):
                text = extract_text_from_pptx(pptx_path)
            else:
                print(f"[WARN] Failed to convert .ppt to .pptx: {file_path}")
    except Exception as e:
        print(f"[WARN] Exception during .ppt conversion: {file_path} | {e}")
    return text.strip()

def extract_text_from_pbix(pbix_path):
    """Try to extract text from .pbix by unzipping and reading .json/.xml files inside."""
    import zipfile
    import tempfile
    text = ""
    try:
        with zipfile.ZipFile(pbix_path, 'r') as z:
            with tempfile.TemporaryDirectory() as tmpdir:
                z.extractall(tmpdir)
                for root, _, files in os.walk(tmpdir):
                    for file in files:
                        if file.endswith('.json') or file.endswith('.xml'):
                            try:
                                with open(os.path.join(root, file), 'r', encoding='utf-8', errors='ignore') as f:
                                    content = f.read()
                                    # Only keep text if it's not too large
                                    if len(content) < 500_000:
                                        text += f"\n--- {file} ---\n" + content
                            except Exception:
                                continue
    except Exception as e:
        print(f"[WARN] Failed to extract .pbix: {pbix_path} | {e}")
    return text.strip()

def extract_text_from_doc(doc_path):
    """Convert .doc to .docx using unoconv, then extract text."""
    import subprocess
    import tempfile
    import os
    text = ""
    try:
        with tempfile.TemporaryDirectory() as tmpdir:
            docx_path = os.path.join(tmpdir, os.path.basename(doc_path) + '.docx')
            result = subprocess.run([
                'unoconv', '-f', 'docx', '-o', docx_path, doc_path
            ], capture_output=True)
            if result.returncode == 0 and os.path.exists(docx_path):
                text = extract_text_from_docx(docx_path)
            else:
                print(f"[WARN] Failed to convert .doc to .docx: {doc_path}")
    except Exception as e:
        print(f"[WARN] Exception during .doc conversion: {doc_path} | {e}")
    return text.strip()

def process_file(file_path, data):
    ext = file_path.lower().split('.')[-1]
    project = extract_project_name(file_path)
    print(f"[INFO] Processing file: {os.path.basename(file_path)} | Project: {project}")
    entry = {
        'file_name': os.path.basename(file_path),
        'file_path': file_path,
        'type': ext,
        'project': project,
        'extracted_at': datetime.now().isoformat(),
        'text': ''
    }
    reason = None
    if ext == 'pdf':
        text = extract_text_from_pdf(file_path)
        if not text:
            text = ocr_pdf(file_path)
            if text:
                reason = 'extracted via OCR'
            else:
                reason = 'no text extracted (PDF and OCR failed)'
        else:
            reason = 'extracted as text PDF'
        entry['text'] = text
    elif ext in ['xls', 'xlsx', 'xlsb']:
        text = extract_text_from_excel(file_path)
        entry['text'] = text
        reason = 'extracted from Excel' if text else 'no text extracted (Excel)'
    elif ext == 'docx':
        text = extract_text_from_docx(file_path)
        entry['text'] = text
        reason = 'extracted from Word' if text else 'no text extracted (Word)'
    elif ext in ['pptx', 'pptm']:
        text = extract_text_from_pptx(file_path)
        entry['text'] = text
        reason = 'extracted from PowerPoint' if text else 'no text extracted (PowerPoint)'
    elif ext == 'ppt':
        text = extract_text_from_ppt(file_path)
        entry['text'] = text
        reason = 'extracted from PPT (via conversion)' if text else 'no text extracted (PPT)'
    elif ext == 'pbix':
        text = extract_text_from_pbix(file_path)
        entry['text'] = text
        reason = 'extracted from PBIX' if text else 'no text extracted (PBIX)'
    elif ext == 'doc':
        text = extract_text_from_doc(file_path)
        entry['text'] = text
        reason = 'extracted from DOC (via conversion)' if text else 'no text extracted (DOC)'
    else:
        print(f"[WARN] Skipped unsupported file type: {os.path.basename(file_path)}")
        return
    if entry['text']:
        data.append(entry)
    else:
        print(f"[WARN] No text extracted from: {os.path.basename(file_path)} ({reason})")

def process_folder(folder_path, output_json_path):
    data = []
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            file_path = os.path.join(root, file)
            ext = file.lower().split('.')[-1]
            if ext in ['zip', 'rar']:
                print(f"[INFO] Extracting archive: {file}")
                with tempfile.TemporaryDirectory() as tmpdir:
                    try:
                        if ext == 'zip':
                            with zipfile.ZipFile(file_path, 'r') as z:
                                z.extractall(tmpdir)
                        elif ext == 'rar':
                            with rarfile.RarFile(file_path, 'r') as r:
                                r.extractall(tmpdir)
                        # Recursively process extracted files
                        for subroot, _, subfiles in os.walk(tmpdir):
                            for subfile in subfiles:
                                subfile_path = os.path.join(subroot, subfile)
                                process_file(subfile_path, data)
                    except Exception as e:
                        print(f"[WARN] Failed to extract {file}: {e}")
            else:
                process_file(file_path, data)
    with open(output_json_path, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=2)
    print(f"Processed {len(data)} documents. Output saved to {output_json_path}")

if __name__ == "__main__":
    # New output directory outside the repo
    output_dir = r'C:/Users/Omar Essam2/OneDrive - Rowad Modern Engineering/x004 Data Science/03.rme.db/05.llm/extracted_json'
    os.makedirs(output_dir, exist_ok=True)
    folder = select_folder()
    if not folder:
        print("No folder selected. Exiting.")
    else:
        folder_name = os.path.basename(os.path.normpath(folder))
        output_json = os.path.join(output_dir, f"{folder_name}_extracted.json")
        process_folder(folder, output_json)
# Out:
# [INFO] Processing file: Baseline & EOT Status.xlsx | Project: 00
# [WARN] No text extracted from: Baseline & EOT Status.xlsx (no text extracted (Excel))
# [INFO] Processing file: Book1.xlsx | Project: 00
# [WARN] No text extracted from: Book1.xlsx (no text extracted (Excel))
# [INFO] Processing file: Cost Reports LOG.xlsx | Project: 00
# [WARN] No text extracted from: Cost Reports LOG.xlsx (no text extracted (Excel))
# [INFO] Extracting archive: Cash in and out.rar
# [INFO] Processing file: CASH.XLSX | Project: Cash in and out
# [WARN] No text extracted from: CASH.XLSX (no text extracted (Excel))
# [INFO] Processing file: Mintra Project Cash flow S Curve - After IPC #3 REV01pdf.xlsx | Project: Cash in and out
# [WARN] No text extracted from: Mintra Project Cash flow S Curve - After IPC #3 REV01pdf.xlsx (no text extracted (Excel))
# [INFO] Processing file: Value of Work 25-09-2018 (4 month).xlsx | Project: Cash in and out
# [WARN] No text extracted from: Value of Work 25-09-2018 (4 month).xlsx (no text extracted (Excel))
# [INFO] Processing file: Beni-Suef - Cash In-Cash out.pdf | Project: Alstom Substation
# [INFO] Processing file: Beni-Suef - Cash In-Cash out.xlsx | Project: Alstom Substation
# [WARN] No text extracted from: Beni-Suef - Cash In-Cash out.xlsx (no text extracted (Excel))
# [INFO] Processing file: Ismailia Cash In-Cash out.pdf | Project: Alstom Substation
# [INFO] Processing file: Ismailia Cash In-Cash out.xlsx | Project: Alstom Substation
# [WARN] No text extracted from: Ismailia Cash In-Cash out.xlsx (no text extracted (Excel))
# [INFO] Processing file: TAMEY - Cash In-Cash out.pdf | Project: Alstom Substation
# [INFO] Processing file: TAMEY - Cash In-Cash out.xlsx | Project: Alstom Substation
# [WARN] No text extracted from: TAMEY - Cash In-Cash out.xlsx (no text extracted (Excel))
# [INFO] Processing file: Cash In AL JAzi .xlsx | Project: Jazi
# [WARN] No text extracted from: Cash In AL JAzi .xlsx (no text extracted (Excel))
# [INFO] Processing file: Cash out - 30-8-2018.pdf | Project: Kayan
# [INFO] Processing file: Value Of Work (Cash In)  (30-8-2018).pdf | Project: Kayan
# [INFO] Processing file: Cash-in&out 22-09-18.xlsx | Project: Rolling Mill
# [WARN] No text extracted from: Cash-in&out 22-09-18.xlsx (no text extracted (Excel))
# [INFO] Processing file: RCM#CASH FLOW  till DEC.2018.xlsx | Project: Royal City
# [WARN] No text extracted from: RCM#CASH FLOW  till DEC.2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: RCM#CASHFLOW.pdf | Project: Royal City
# [INFO] Processing file: cash out & cash in.xlsx | Project: 7 OT
# [WARN] No text extracted from: cash out & cash in.xlsx (no text extracted (Excel))
# [INFO] Processing file: CASH.XLSX | Project: Cash in and out
# [WARN] No text extracted from: CASH.XLSX (no text extracted (Excel))
# [INFO] Processing file: Mintra Project Cash flow S Curve - After IPC #3 REV01pdf.xlsx | Project: Cash in and out
# [WARN] No text extracted from: Mintra Project Cash flow S Curve - After IPC #3 REV01pdf.xlsx (no text extracted (Excel))
# [INFO] Processing file: Reports log.xlsx | Project: Cash in and out
# [WARN] No text extracted from: Reports log.xlsx (no text extracted (Excel))
# [INFO] Processing file: Value of Work 25-09-2018 (4 month).xlsx | Project: Cash in and out
# [WARN] No text extracted from: Value of Work 25-09-2018 (4 month).xlsx (no text extracted (Excel))
# [INFO] Processing file: Beni-Suef - Cash In-Cash out.pdf | Project: Alstom Substation
# [INFO] Processing file: Beni-Suef - Cash In-Cash out.xlsx | Project: Alstom Substation
# [WARN] No text extracted from: Beni-Suef - Cash In-Cash out.xlsx (no text extracted (Excel))
# [INFO] Processing file: Ismailia Cash In-Cash out.pdf | Project: Alstom Substation
# [INFO] Processing file: Ismailia Cash In-Cash out.xlsx | Project: Alstom Substation
# [WARN] No text extracted from: Ismailia Cash In-Cash out.xlsx (no text extracted (Excel))
# [INFO] Processing file: TAMEY - Cash In-Cash out.pdf | Project: Alstom Substation
# [INFO] Processing file: TAMEY - Cash In-Cash out.xlsx | Project: Alstom Substation
# [WARN] No text extracted from: TAMEY - Cash In-Cash out.xlsx (no text extracted (Excel))
# [INFO] Processing file: Cash In AL JAzi .xlsx | Project: Jazi
# [WARN] No text extracted from: Cash In AL JAzi .xlsx (no text extracted (Excel))
# [INFO] Processing file: Cash out - 30-8-2018.pdf | Project: Kayan
# [INFO] Processing file: Value Of Work (Cash In)  (30-8-2018).pdf | Project: Kayan
# [INFO] Processing file: Cash-in&out 22-09-18.xlsx | Project: Rolling Mill
# [WARN] No text extracted from: Cash-in&out 22-09-18.xlsx (no text extracted (Excel))
# [INFO] Processing file: RCM#CASH FLOW  till DEC.2018.xlsx | Project: Royal City
# [WARN] No text extracted from: RCM#CASH FLOW  till DEC.2018.xlsx (no text extracted (Excel))
# [INFO] Processing file: RCM#CASHFLOW.pdf | Project: Royal City
# [INFO] Processing file: Beni Suef CCPP.PDF | Project: 1 Cost Control report
# [WARN] No text extracted from: Beni Suef CCPP.PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: Cost Control Report LOG.xlsx | Project: 1 Cost Control report
# [WARN] No text extracted from: Cost Control Report LOG.xlsx (no text extracted (Excel))
# [INFO] Processing file: Cost Report Summary.xlsx | Project: 1 Cost Control report
# [WARN] No text extracted from: Cost Report Summary.xlsx (no text extracted (Excel))
# [INFO] Processing file: Cost Reports progress 01.pdf | Project: 1 Cost Control report
# [INFO] Processing file: Cost Reports progress 02.pdf | Project: 1 Cost Control report
# [INFO] Processing file: Indirect Cost Summary.xlsx | Project: 1 Cost Control report
# [WARN] No text extracted from: Indirect Cost Summary.xlsx (no text extracted (Excel))
# [INFO] Processing file: Start & Finish Date for Projects Log.xlsx | Project: 1 Cost Control report
# [WARN] No text extracted from: Start & Finish Date for Projects Log.xlsx (no text extracted (Excel))
# [INFO] Extracting archive: JICA Wind Farm El Zayt (220MW) (Jan. & May).rar
# [INFO] Processing file: JICA Project - Cost Control Report till 31-05-2017.xlsx | Project: tmpl7e_tg37
# [WARN] No text extracted from: JICA Project - Cost Control Report till 31-05-2017.xlsx (no text extracted (Excel))
# [INFO] Processing file: JICA Project - Cost Control Report till 31.Jan.2017.pdf | Project: tmpl7e_tg37
# [INFO] Processing file: NGU Project Cost Control Report Till 30-07-2015(CHECK.xlsx | Project: 46 NGU 1 30-7-2015
# [WARN] No text extracted from: NGU Project Cost Control Report Till 30-07-2015(CHECK.xlsx (no text extracted (Excel))
# [INFO] Processing file: NGU Project Cost Control Report Till 31-07-2015.pdf | Project: 46 NGU 1 30-7-2015
# [INFO] Processing file: NGU Project Cost Control Report Till final 2.xlsx | Project: 46 NGU 1 30-7-2015
# [WARN] No text extracted from: NGU Project Cost Control Report Till final 2.xlsx (no text extracted (Excel))
# [INFO] Processing file: 01 Abu Sultan Bridge Cost Report 03 Sep 2018 (30-09-2018).pdf | Project: Abu Sultan Bridge
# [INFO] Processing file: 02 Abu Sultan Bridge Cost Report 04 Sep 2018 (30-09-2018) Rev.05.xlsb | Project: Abu Sultan Bridge
# [INFO] Processing file: 02 Abu Sultan Bridge Cost Report 04 Sep 2018 (30-09-2018).pdf | Project: Abu Sultan Bridge
# [INFO] Processing file: 03 Abu Sultan Bridge 01 Cost Report (30-11-2018).pdf | Project: Abu Sultan Bridge
# [INFO] Processing file: 03 Abu Sultan Bridge Cost Report 05 Nov 2018 (30-11-2018).xlsb | Project: Abu Sultan Bridge
# [INFO] Processing file: 01 Abu Sultan Bridge 02 Cost Report No 02 (30-10-2018).pdf | Project: Abu Sultan Bridge 2
# [INFO] Processing file: 01 Abu Sultan Bridge 2 Cost Report No 02 Oct 2018 Rev00 (30-10-2018).xlsb | Project: Abu Sultan Bridge 2
# [INFO] Processing file: 02 Abu Sultan 02 Green House Cost Report (30-11-2018).pdf | Project: Abu Sultan Bridge 2
# [INFO] Processing file: 02 Abu Sultan 2 + El Sewab Cost Report No 02 Nov 2018 (30-11-2018).xlsb | Project: Abu Sultan Bridge 2
# [INFO] Processing file: 01 Al Jazi Mall May 2018-Final Cost Report.pdf | Project: AL Jazi
# [INFO] Processing file: 02 Al Jazi Mall August 2018-Cost.pdf | Project: AL Jazi
# [INFO] Processing file: 03 October Final Cost Report 4 Final.pdf | Project: AL Jazi
# [INFO] Processing file: ATTAQA power plant Cost Report 31-1-2016 .xlsx | Project: Ataqqa Power Plant
# [WARN] No text extracted from: ATTAQA power plant Cost Report 31-1-2016 .xlsx (no text extracted (Excel))
# [INFO] Processing file: 01 Cement Plant_Cost Report 1_till 30-9-2016.pdf | Project: Bani Suif (Cement Plant)
# [INFO] Processing file: 02 Cement Plant Cost Report till 30-11-2016.pdf | Project: Bani Suif (Cement Plant)
# [INFO] Processing file: 03  Cost report Jan-2017.pdf | Project: Bani Suif (Cement Plant)
# [INFO] Processing file: 04 Beni Suif Cement Plant Cost Report till 28-Feb-2017.pdf | Project: Bani Suif (Cement Plant)
# [INFO] Processing file: 05 Cost Control Report till April,2017.pdf | Project: Bani Suif (Cement Plant)
# [INFO] Processing file: 08 Cost control report Sep.,2017.pdf | Project: Bani Suif (Cement Plant)
# [INFO] Processing file: Cement Plant Cost Report till 30-9-2017.xlsb | Project: Bani Suif (Cement Plant)
# [INFO] Processing file: Thumbs.db | Project: Bani Suif (Cement Plant)
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: 02 Bani Swef Cost Report March 2016.pdf | Project: Bani Suif (Power plant)
# [INFO] Processing file: 03 Bani Suef_Cost Reprt 3_April 2016.pdf | Project: Bani Suif (Power plant)
# [INFO] Processing file: 04 Bani Suef_Cost Reprt 4_June 2016.pdf | Project: Bani Suif (Power plant)
# [INFO] Processing file: 05 Bani Suef_Cost Reprt 5_July 2016.pdf | Project: Bani Suif (Power plant)
# [INFO] Processing file: 06 Bani Suef_Cost Reprt 6_September 2016.pdf | Project: Bani Suif (Power plant)
# [INFO] Processing file: 07 Bani Suef_Cost Reprt 7_October 2016.pdf | Project: Bani Suif (Power plant)
# [INFO] Processing file: 08 Bani Suef_Cost Reprt 8_December 2016.pdf | Project: Bani Suif (Power plant)
# [INFO] Processing file: 09 Cost Control Report till 31-04-2017.pdf | Project: Bani Suif (Power plant)
# [INFO] Processing file: Thumbs.db | Project: Bani Suif (Power plant)
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: 01 TSK Solar Benban August Cost Report.pdf | Project: Benban
# [INFO] Processing file: 02 Benban Nov.18 Cost Report.pdf | Project: Benban
# [INFO] Processing file: 01 Beni-Seuf SS 30 Aug.pdf | Project: BSF SS
# [INFO] Processing file: 02 Beni-Suef Substation Cost Report as of (30.12.2017).pdf | Project: BSF SS
# [INFO] Processing file: 03 Bani Suef Cost Report Jan-18.pdf | Project: BSF SS
# [INFO] Processing file: 04 March Cost Report.pdf | Project: BSF SS
# [INFO] Processing file: 05 BSF SS Cost Sheet May.18.pdf | Project: BSF SS
# [INFO] Processing file: 06 BSF Cost Report No.6 July-2018.pdf | Project: BSF SS
# [INFO] Extracting archive: BSF SS Cost Report Aug 2017.rar
# [INFO] Processing file: Beni-Seuf 30 Aug.xlsb | Project: New folder
# [INFO] Processing file: Report No.1.pdf | Project: New folder
# [INFO] Processing file: Copy of BSF SS Cost Sheet Jul 18.xlsb | Project: BSF SS
# [INFO] Processing file: Thumbs.db | Project: BSF SS
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: Beni-Seuf 30 Aug.xlsb | Project: New folder
# [INFO] Processing file: Beni-Seuf SS 30 Aug.pdf | Project: New folder
# [INFO] Processing file: Report No.1.pdf | Project: Report No.1 30-08-2017
# [INFO] Processing file: BSF Petty Cash Log.Aug.xlsx | Project: Data
# [WARN] No text extracted from: BSF Petty Cash Log.Aug.xlsx (no text extracted (Excel))
# [INFO] Processing file: BSF Wages Log.Aug.xlsx | Project: Data
# [WARN] No text extracted from: BSF Wages Log.Aug.xlsx (no text extracted (Excel))
# [INFO] Processing file: Casted Concrete Status 31-8.xlsx | Project: Data
# [WARN] No text extracted from: Casted Concrete Status 31-8.xlsx (no text extracted (Excel))
# [INFO] Processing file: Staff Salaries Aug.xlsx | Project: Data
# [WARN] No text extracted from: Staff Salaries Aug.xlsx (no text extracted (Excel))
# [INFO] Processing file: Storage Aug.xlsx | Project: Data
# [WARN] No text extracted from: Storage Aug.xlsx (no text extracted (Excel))
# [INFO] Processing file: Transportation For Material Aug.xlsx | Project: Data
# [WARN] No text extracted from: Transportation For Material Aug.xlsx (no text extracted (Excel))
# [INFO] Processing file: #Purchasing order #002  Al-Ahram Company Signed - Beni Suif Substation.PDF | Project: PO
# [WARN] No text extracted from: #Purchasing order #002  Al-Ahram Company Signed - Beni Suif Substation.PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: TPD-LPO-1405-1-C-001-2017.PDF | Project: PO
# [WARN] No text extracted from: TPD-LPO-1405-1-C-001-2017.PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: Abdel Hakeem -04.pdf | Project: Unsigned Drafts
# [INFO] Processing file: Abdel Hakiem-05.pdf | Project: Unsigned Drafts
# [INFO] Processing file: Abd El.Hakim Abu Galal Excavation Quantities Status.xlsx | Project: Status
# [WARN] No text extracted from: Abd El.Hakim Abu Galal Excavation Quantities Status.xlsx (no text extracted (Excel))
# [INFO] Processing file: RME-SUB-BSF-INV-ABZ-01.xls | Project: RME-SUB-BSF-INV-ABZ-01
# [WARN] No text extracted from: RME-SUB-BSF-INV-ABZ-01.xls (no text extracted (Excel))
# [INFO] Processing file: subcontractor.pdf | Project: RME-SUB-BSF-INV-ABZ-01
# [INFO] Processing file: Aly Noor El Dine- 009.docx | Project: Draft
# [INFO] Processing file: Ali Nour El.Din Excavation Quantities Status.xlsx | Project: Status
# [WARN] No text extracted from: Ali Nour El.Din Excavation Quantities Status.xlsx (no text extracted (Excel))
# [INFO] Processing file: #Contract Golden Metal Company Signed - Substaion 500-220KV of Beni suif.pdf | Project: False Ceiling
# [WARN] No text extracted from: #Contract Golden Metal Company Signed - Substaion 500-220KV of Beni suif.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: RME-SUB-BSF-INV-SOM-01.xls | Project: RME-SUB-BSF-INV-SOM-01
# [WARN] No text extracted from: RME-SUB-BSF-INV-SOM-01.xls (no text extracted (Excel))
# [INFO] Processing file: RME-SUB-BSF-INV-SOM-02.xls | Project: RME-SUB-BSF-INV-SOM-02
# [WARN] No text extracted from: RME-SUB-BSF-INV-SOM-02.xls (no text extracted (Excel))
# [INFO] Processing file: #Contract CEL Company Signed - Substaion 500-220KV of Beni suif.PDF | Project: Contract
# [WARN] No text extracted from: #Contract CEL Company Signed - Substaion 500-220KV of Beni suif.PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: RME-SUB-BSF-INV-CEL-01.xls | Project: Invoices
# [WARN] No text extracted from: RME-SUB-BSF-INV-CEL-01.xls (no text extracted (Excel))
# [INFO] Processing file: El Khier - 008 (masonry) 02-10-2017 FINAL.docx | Project: Contract
# [INFO] Processing file: RME-SUB-BSF-INV-MAP-01.xls | Project: RME-SUB-BSF-INV-MAP-01
# [WARN] No text extracted from: RME-SUB-BSF-INV-MAP-01.xls (no text extracted (Excel))
# [INFO] Processing file: RME-SUB-BSF-INV-MAP-02.xls | Project: RME-SUB-BSF-INV-MAP-02
# [WARN] No text extracted from: RME-SUB-BSF-INV-MAP-02.xls (no text extracted (Excel))
# [INFO] Processing file: Abdel Hakiem-05.pdf | Project: RME-SUB-BSF-INV-GLL5-01
# [INFO] Processing file: Rates Confirmation.msg | Project: RME-SUB-BSF-INV-GLL5-01
# [WARN] Skipped unsupported file type: Rates Confirmation.msg
# [INFO] Processing file: RME-SUB-BSF-INV-GLL5-01.xls | Project: RME-SUB-BSF-INV-GLL5-01
# [WARN] No text extracted from: RME-SUB-BSF-INV-GLL5-01.xls (no text extracted (Excel))
# [INFO] Processing file: Rental Equipment Status.xlsx | Project: RME-SUB-BSF-INV-GLL5-02
# [WARN] No text extracted from: Rental Equipment Status.xlsx (no text extracted (Excel))
# [INFO] Processing file: RME-SUB-BSF-INV-GLL5-02.xls | Project: RME-SUB-BSF-INV-GLL5-02
# [WARN] No text extracted from: RME-SUB-BSF-INV-GLL5-02.xls (no text extracted (Excel))
# [INFO] Processing file: Rental Equipment Status.xlsx | Project: RME-SUB-BSF-INV-GLL5-03
# [WARN] No text extracted from: Rental Equipment Status.xlsx (no text extracted (Excel))
# [INFO] Processing file: RME-SUB-BSF-INV-GLL5-03.xls | Project: RME-SUB-BSF-INV-GLL5-03
# [WARN] No text extracted from: RME-SUB-BSF-INV-GLL5-03.xls (no text extracted (Excel))
# [INFO] Processing file: #Contract ALhadaya Company Signed - Beni Suif Substation.PDF | Project: Contract
# [WARN] No text extracted from: #Contract ALhadaya Company Signed - Beni Suif Substation.PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: عرض سعر شركة الهدايا لودر باكت وشوكة.pdf | Project: Contract
# [WARN] No text extracted from: عرض سعر شركة الهدايا لودر باكت وشوكة.pdf (no text extracted (PDF and OCR failed))
# [INFO] Processing file: Rental Equipment Status.xlsx | Project: RME-SUB-BSF-INV-HDY-01
# [WARN] No text extracted from: Rental Equipment Status.xlsx (no text extracted (Excel))
# [INFO] Processing file: RME-SUB-BSF-INV-HDY-01.xls | Project: RME-SUB-BSF-INV-HDY-01
# [WARN] No text extracted from: RME-SUB-BSF-INV-HDY-01.xls (no text extracted (Excel))
# [INFO] Processing file: #Contract MEC Company Signed -Beni Suif Substation.PDF | Project: Contract
# [WARN] No text extracted from: #Contract MEC Company Signed -Beni Suif Substation.PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: #Contract Al Ahram Company Signed - Substaion 500-220KV of Beni suif.PDF | Project: Contract
# [WARN] No text extracted from: #Contract Al Ahram Company Signed - Substaion 500-220KV of Beni suif.PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: عقد حراسة مشروع محولات بنى سويف.PDF | Project: Security
# [WARN] No text extracted from: عقد حراسة مشروع محولات بنى سويف.PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: عقد توريد وتركيب أوناش - محطه توزيع كهرباء بنى سويف - ايجيبت اند ستريز.PDF | Project: Contract
# [WARN] No text extracted from: عقد توريد وتركيب أوناش - محطه توزيع كهرباء بنى سويف - ايجيبت اند ستريز.PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: #Contract  Al Amir Company Signed - Substaion 500-220KV of Beni suif.PDF | Project: Contract
# [WARN] No text extracted from: #Contract  Al Amir Company Signed - Substaion 500-220KV of Beni suif.PDF (no text extracted (PDF and OCR failed))
# [INFO] Processing file: Unsigned BOQ.pdf | Project: Contract
# [INFO] Processing file: RME-SUB-BSF-INV-AMR-01.xls | Project: RME-SUB-BSF-INV-AMR-01
# [WARN] No text extracted from: RME-SUB-BSF-INV-AMR-01.xls (no text extracted (Excel))
# [INFO] Processing file: Unsigned BOQ.pdf | Project: RME-SUB-BSF-INV-AMR-01
# [INFO] Processing file: RME-SUB-BSF-INV-AMR-02.xls | Project: RME-SUB-BSF-INV-AMR-02
# [WARN] No text extracted from: RME-SUB-BSF-INV-AMR-02.xls (no text extracted (Excel))
# [INFO] Processing file: Beni-Suef Substation Cost Report as of (30.12.2017).pdf | Project: Report No.2 30-12-2017
# [INFO] Processing file: QS.xlsx | Project: Data
# [WARN] No text extracted from: QS.xlsx (no text extracted (Excel))
# [INFO] Processing file: BSF SS - Steel Status 07-01-2018.pdf | Project: BSF SS - Steel Status
# [INFO] Processing file: BSF SS - Casted Concrete Status.xlsx | Project: Supporting
# [WARN] No text extracted from: BSF SS - Casted Concrete Status.xlsx (no text extracted (Excel))
# [INFO] Processing file: My Storage.xlsx | Project: Supporting
# [WARN] No text extracted from: My Storage.xlsx (no text extracted (Excel))
# [INFO] Processing file: Quantities Monitoring.xlsx | Project: Supporting
# [WARN] No text extracted from: Quantities Monitoring.xlsx (no text extracted (Excel))
# [INFO] Processing file: Sub-Contractors Sheet.xlsx | Project: Supporting
# [WARN] No text extracted from: Sub-Contractors Sheet.xlsx (no text extracted (Excel))
# [INFO] Processing file: Thumbs.db | Project: Supporting
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: Substations Planning Report Dec 2017.xlsx | Project: Salaries
# [WARN] No text extracted from: Substations Planning Report Dec 2017.xlsx (no text extracted (Excel))
# [INFO] Processing file: BSF Wages Log.xlsx | Project: Log
# [WARN] No text extracted from: BSF Wages Log.xlsx (no text extracted (Excel))
# [INFO] Processing file: Beni Suef Substion 01-12-2017 to 15-12-2017.xlsx | Project: Wages
# [WARN] No text extracted from: Beni Suef Substion 01-12-2017 to 15-12-2017.xlsx (no text extracted (Excel))
# [INFO] Processing file: Beni Suef Substion 16-12-2017 to 31-12-2017.xlsx | Project: Wages
# [WARN] No text extracted from: Beni Suef Substion 16-12-2017 to 31-12-2017.xlsx (no text extracted (Excel))
# [INFO] Processing file: بيان بالمرتبات خلال الفترات.xlsx | Project: Wages
# [WARN] No text extracted from: بيان بالمرتبات خلال الفترات.xlsx (no text extracted (Excel))
# [INFO] Processing file: Copy of MOBINIL FORM summary.xlsx | Project: Dec-17
# [WARN] No text extracted from: Copy of MOBINIL FORM summary.xlsx (no text extracted (Excel))
# [INFO] Processing file: Rentals Generators.pdf | Project: Nov-17
# [INFO] Processing file: Daily report2018  .xlsx | Project: Material
# [WARN] No text extracted from: Daily report2018  .xlsx (no text extracted (Excel))
# [INFO] Processing file: تسويـــــات ديسمبر 2017.xlsx | Project: Petty Cash
# [WARN] No text extracted from: تسويـــــات ديسمبر 2017.xlsx (no text extracted (Excel))
# [INFO] Processing file: BSF Petty Cash Log.sEP.xlsx | Project: Petty Cash Log
# [WARN] No text extracted from: BSF Petty Cash Log.sEP.xlsx (no text extracted (Excel))
# [INFO] Processing file: Bani Suef Cost Report Jan-18.pdf | Project: Report No.3 30-01-2018
# [INFO] Processing file: Thumbs.db | Project: Report No.3 30-01-2018
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: BSF-Trend-Analysis.xlsx | Project: Data
# [WARN] No text extracted from: BSF-Trend-Analysis.xlsx (no text extracted (Excel))
# [INFO] Processing file: January Cost Sheet - Shortcut.lnk | Project: Data
# [WARN] Skipped unsupported file type: January Cost Sheet - Shortcut.lnk
# [INFO] Processing file: January Cost Sheet.xlsb | Project: Data
# [INFO] Processing file: Quantities Monitoring - Shortcut (2).lnk | Project: Data
# [WARN] Skipped unsupported file type: Quantities Monitoring - Shortcut (2).lnk
# [INFO] Processing file: Quantities Monitoring - Shortcut.lnk | Project: Data
# [WARN] Skipped unsupported file type: Quantities Monitoring - Shortcut.lnk
# [INFO] Extracting archive: Quantities Monitoring.rar
# [INFO] Processing file: Quantities Monitoring.xlsx | Project: tmp06lbi9nq
# [WARN] No text extracted from: Quantities Monitoring.xlsx (no text extracted (Excel))
# [INFO] Processing file: Quantities Monitoring.xlsx | Project: Data
# [WARN] No text extracted from: Quantities Monitoring.xlsx (no text extracted (Excel))
# [INFO] Processing file: Thumbs.db | Project: Data
# [WARN] Skipped unsupported file type: Thumbs.db
# [INFO] Processing file: 01 Cost Control report for DP world Alegria 30-4-2017.pdf | Project: DP world Alegria
# [INFO] Processing file: STAFF histogram modified 15-6-2017.xlsx | Project: DP world Alegria
# [WARN] No text extracted from: STAFF histogram modified 15-6-2017.xlsx (no text extracted (Excel))
# [INFO] Processing file: 01 El Sokhna Tunnel Cost Report May 2018 Rev00 (30-04-2018).pdf | Project: El Sokhna Tunnel
# [INFO] Processing file: 02 El Sokhna Tunnel Cost Report No 03 Sep 2018 Rev04 (30-09-2018).xlsb | Project: El Sokhna Tunnel
# [INFO] Processing file: 02 El Sokhna Tunnel Cost Report Sep 2018 Rev04 (30-09-2018).pdf | Project: El Sokhna Tunnel
# [INFO] Processing file: 03 El Sokhna Tunnel Cost Report No 06 Oct 2018 (30-10-2018).pdf | Project: El Sokhna Tunnel
# [INFO] Processing file: 03 El Sokhna Tunnel Cost Report No 06 Oct 2018 (30-10-2018).xlsb | Project: El Sokhna Tunnel
# [INFO] Processing file: 04 El Sokhna Tunnel 01 Cost Report (30-11-2018).pdf | Project: El Sokhna Tunnel
# [INFO] Processing file: 04 El Sokhna Tunnel Cost Report No 07 Nov 2018 (30-11-2018).xlsb | Project: El Sokhna Tunnel
# [INFO] Processing file: 01 El Sokhna Tunnel 02 Cost Report (30-11-2018).pdf | Project: El Sokhna Tunnel 2
# [INFO] Processing file: 01 El Sokhna Tunnel 2 Cost Report No 02 Nov 2018 (30-11-2018) Rev.00.xlsb | Project: El Sokhna Tunnel 2
# [INFO] Processing file: 01 Cost Reports progress 02.pdf | Project: El sweedy Univeristy
# [INFO] Processing file: El Sewedy Cost Report Samir(Autosaved).xlsb | Project: El sweedy Univeristy
# [INFO] Processing file: 01- Cost control report Oct.,2017.pdf | Project: ELECO
# [INFO] Processing file: 02 Rolling Mill -Cost Report Nov.17- Revised Budget..xlsb | Project: ELECO
# [INFO] Processing file: 02 Rolling Mill Cost Report Nov.17.pdf | Project: ELECO
# [INFO] Processing file: 03 Rolling Mill -Cost Report -Dec.17.pdf | Project: ELECO
# [INFO] Processing file: 03 Rolling Mill -Cost Report -Dec.17.xlsb | Project: ELECO

# %%
# Requirements: pip install sentence-transformers torch chromadb tqdm python-dotenv
import os
import json
from sentence_transformers import SentenceTransformer
import chromadb
from chromadb.config import Settings
from dotenv import load_dotenv
from tqdm import tqdm

# Load environment variables (if needed for paths)
load_dotenv()

# New paths outside the repo
EXTRACTED_DIR = r'C:/Users/Omar Essam2/OneDrive - Rowad Modern Engineering/x004 Data Science/03.rme.db/05.llm/extracted_json'
CHROMA_DB_DIR = r'C:/Users/Omar Essam2/OneDrive - Rowad Modern Engineering/x004 Data Science/03.rme.db/05.llm/chroma_db_local'
COLLECTION_NAME = 'company_docs_local'
CHUNK_SIZE = 500  # characters per chunk (reduced for more precise retrieval)
CHUNK_OVERLAP = 200
ID_TRACK_FILE = os.path.join(CHROMA_DB_DIR, 'embedded_chunk_ids.txt')
BATCH_SIZE = 32  # Number of chunks to embed in one call

# Helper: chunk text
def chunk_text(text, chunk_size=CHUNK_SIZE, overlap=CHUNK_OVERLAP):
    chunks = []
    start = 0
    while start < len(text):
        end = min(start + chunk_size, len(text))
        chunks.append(text[start:end])
        start += chunk_size - overlap
    return chunks

# Helper: get local embeddings
model = SentenceTransformer('all-MiniLM-L6-v2')  # You can change to another local model if needed
def get_embeddings(texts):
    return model.encode(texts, show_progress_bar=False, convert_to_numpy=True).tolist()

# Initialize Chroma DB
client = chromadb.PersistentClient(path=CHROMA_DB_DIR, settings=Settings(allow_reset=True))
if COLLECTION_NAME in [c.name for c in client.list_collections()]:
    collection = client.get_collection(COLLECTION_NAME)
else:
    collection = client.create_collection(COLLECTION_NAME)

def load_embedded_ids():
    if not os.path.exists(ID_TRACK_FILE):
        return set()
    with open(ID_TRACK_FILE, 'r', encoding='utf-8') as f:
        return set(line.strip() for line in f if line.strip())

def save_embedded_id(chunk_id):
    with open(ID_TRACK_FILE, 'a', encoding='utf-8') as f:
        f.write(chunk_id + '\n')

def process_json_files():
    files = [f for f in os.listdir(EXTRACTED_DIR) if f.endswith('.json')]
    doc_count = 0
    embedded_ids = load_embedded_ids()
    for file in files:
        with open(os.path.join(EXTRACTED_DIR, file), 'r', encoding='utf-8') as f:
            docs = json.load(f)
        for doc in tqdm(docs, desc=f"Processing {file}"):
            text = doc['text']
            if not text.strip():
                continue
            chunks = chunk_text(text)
            batch_chunks = []
            batch_metas = []
            batch_ids = []
            for i, chunk in enumerate(chunks):
                chunk_id = f"{doc['file_name']}_{i}"
                if chunk_id in embedded_ids:
                    continue  # Skip already embedded chunk
                meta = {
                    'file_name': doc['file_name'],
                    'file_path': doc['file_path'],
                    'type': doc['type'],
                    'project': doc.get('project', 'GLOBAL'),
                    'extracted_at': doc['extracted_at'],
                    'chunk': i
                }
                batch_chunks.append(chunk)
                batch_metas.append(meta)
                batch_ids.append(chunk_id)
                if len(batch_chunks) == BATCH_SIZE:
                    try:
                        embs = get_embeddings(batch_chunks)
                        collection.add(
                            documents=batch_chunks,
                            embeddings=embs,
                            metadatas=batch_metas,
                            ids=batch_ids
                        )
                        for cid in batch_ids:
                            save_embedded_id(cid)
                        doc_count += len(batch_chunks)
                    except Exception as e:
                        print(f"Error embedding batch: {e}")
                    batch_chunks, batch_metas, batch_ids = [], [], []
            # Process any remaining chunks in the batch
            if batch_chunks:
                try:
                    embs = get_embeddings(batch_chunks)
                    collection.add(
                        documents=batch_chunks,
                        embeddings=embs,
                        metadatas=batch_metas,
                        ids=batch_ids
                    )
                    for cid in batch_ids:
                        save_embedded_id(cid)
                    doc_count += len(batch_chunks)
                except Exception as e:
                    print(f"Error embedding batch: {e}")
    print(f"Finished! {doc_count} new chunks embedded and stored in Chroma DB.")

if __name__ == "__main__":
    process_json_files()
# Out:
# Processing 01 Dash Boards_extracted.json: 100%|██████████| 264/264 [00:00<00:00, 878.70it/s]
# Processing 02 Monthly Progress Presentation_extracted.json: 100%|██████████| 574/574 [00:00<00:00, 30281.50it/s]
# Processing 03 Procurement Follow Up Reports_extracted.json: 100%|██████████| 22/22 [00:00<00:00, 47984.76it/s]
# Processing 04 Engineering Follow Up_extracted.json: 0it [00:00, ?it/s]
# Processing 05 Client Invoices_extracted.json: 100%|██████████| 1617/1617 [00:00<00:00, 4019.31it/s]
# Processing 06 Initial Budget_extracted.json: 0it [00:00, ?it/s]
# Processing 07 RME Global Reports_extracted.json: 100%|██████████| 1497/1497 [42:15<00:00,  1.69s/it]
# Finished! 139978 new chunks embedded and stored in Chroma DB.
