# %% [markdown]
# # Geospatial Features
# In this notebook we will learn about geographic data and how to work with them

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from datetime import datetime

# %matplotlib inline
sns.set(rc={'figure.figsize':(10, 10)}, font_scale=1.2)

# %% [markdown]
# ### 1) Work with Lat and Long
#
# we will use this library: https://pypi.org/project/geopy/

# %% [markdown]
# **1) Measuring Distance**

# %%
# import great_circle from geopy.distance
from geopy.distance import great_circle

# create 2 vars for home and cafe with lats and longs of (30.109919, 31.308797) & (30.120982, 31.322026)
my_home = (30.109919, 31.308797) # (lat, long)
my_cafe = (30.120982, 31.322026)

# calcaulate the distance   
great_circle(my_home, my_cafe).kilometers  # miles
# Out:
# 1.7698508016026915

# %% [markdown]
# ***So Lets use it with Our data***

# %%
# read sendy_logistics dataset
df = pd.read_csv('../dastasets/sendy_logistics.csv')
df.head()
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0   Order_No_4211   User_Id_633         Bike              3
# 1  Order_No_25375  User_Id_2285         Bike              3
# 2   Order_No_1899   User_Id_265         Bike              3
# 3   Order_No_9336  User_Id_1402         Bike              3
# 4  Order_No_27883  User_Id_1737         Bike              1
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                         9
# 1             Personal                        12
# 2             Business                        30
# 3             Business                        15
# 4             Personal                        13
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             5       9:35:46 AM                            9
# 1                             5      11:16:16 AM                           12
# 2                             2      12:39:25 PM                           30
# 3                             5       9:25:34 AM                           15
# 4                             1       9:55:18 AM                           13
#
#    Confirmation - Weekday (Mo = 1)  ... Arrival at Destination - Time  \
# 0                                5  ...                   10:39:55 AM
# 1                                5  ...                   12:17:22 PM
# 2                                2  ...                    1:00:38 PM
# 3                                5  ...                   10:05:27 AM
# 4                                1  ...                   10:25:37 AM
#
#    Distance (KM)  Temperature Precipitation in millimeters  Pickup Lat  \
# 0              4         20.4                          NaN   -1.317755
# 1             16         26.4                          NaN   -1.351453
# 2              3          NaN                          NaN   -1.308284
# 3              9         19.2                          NaN   -1.281301
# 4              9         15.4                          NaN   -1.266597
#
#    Pickup Long Destination Lat  Destination Long      Rider Id  \
# 0    36.830370       -1.300406         36.829741  Rider_Id_432
# 1    36.899315       -1.295004         36.814358  Rider_Id_856
# 2    36.843419       -1.300921         36.828195  Rider_Id_155
# 3    36.832396       -1.257147         36.795063  Rider_Id_855
# 4    36.792118       -1.295041         36.809817  Rider_Id_770
#
#   Time from Pickup to Arrival
# 0                         745
# 1                        1993
# 2                         455
# 3                        1341
# 4                        1214
#
# [5 rows x 29 columns]

# %%
# create a fn to extract the distance from lat & long in each row
def get_dist(x):
    loc_1 = (x['Pickup Lat'], x['Pickup Long'])
    loc_2 = (x['Destination Lat'], x['Destination Long'])
    return great_circle(loc_1, loc_2).kilometers

# apply the fn to df and create new column for distance
df['Dist_Pick_Dest'] = df.apply(get_dist, axis=1)
df.head()
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0   Order_No_4211   User_Id_633         Bike              3
# 1  Order_No_25375  User_Id_2285         Bike              3
# 2   Order_No_1899   User_Id_265         Bike              3
# 3   Order_No_9336  User_Id_1402         Bike              3
# 4  Order_No_27883  User_Id_1737         Bike              1
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                         9
# 1             Personal                        12
# 2             Business                        30
# 3             Business                        15
# 4             Personal                        13
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             5       9:35:46 AM                            9
# 1                             5      11:16:16 AM                           12
# 2                             2      12:39:25 PM                           30
# 3                             5       9:25:34 AM                           15
# 4                             1       9:55:18 AM                           13
#
#    Confirmation - Weekday (Mo = 1)  ... Distance (KM)  Temperature  \
# 0                                5  ...             4         20.4
# 1                                5  ...            16         26.4
# 2                                2  ...             3          NaN
# 3                                5  ...             9         19.2
# 4                                1  ...             9         15.4
#
#    Precipitation in millimeters Pickup Lat  Pickup Long  Destination Lat  \
# 0                           NaN  -1.317755    36.830370        -1.300406
# 1                           NaN  -1.351453    36.899315        -1.295004
# 2                           NaN  -1.308284    36.843419        -1.300921
# 3                           NaN  -1.281301    36.832396        -1.257147
# 4                           NaN  -1.266597    36.792118        -1.295041
#
#   Destination Long      Rider Id  Time from Pickup to Arrival Dist_Pick_Dest
# 0        36.829741  Rider_Id_432                          745       1.930336
# 1        36.814358  Rider_Id_856                         1993      11.339865
# 2        36.828195  Rider_Id_155                          455       1.880081
# 3        36.795063  Rider_Id_855                         1341       4.943465
# 4        36.809817  Rider_Id_770                         1214       3.724834
#
# [5 rows x 30 columns]

# %% [markdown]
# ### 2) Geocoding features to get the address from lat, long or reverse.
#
# we will use this library: https://pypi.org/project/geopy/

# %%
# import Nominatim from geopy.geocoders
from geopy.geocoders import Nominatim

# create an object from Nominatim with user_agent = Rowad
geolocator = Nominatim(user_agent="Data Science course")

# %%
# give a location to the object using .geocode method
location = geolocator.geocode("Cairo Festival, Cairo, Egypt")

# show the location information data using .raw method
location.raw
# Out:
# {'place_id': 43010744,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#  'osm_type': 'way',
#  'osm_id': 26753320,
#  'lat': '30.026992800000002',
#  'lon': '31.40906325945414',
#  'class': 'place',
#  'type': 'neighbourhood',
#  'place_rank': 20,
#  'importance': 0.25000999999999995,
#  'addresstype': 'neighbourhood',
#  'name': 'كايرو فستيفال سيتى',
#  'display_name': 'كايرو فستيفال سيتى, القاهرة, مصر',
#  'boundingbox': ['30.0164179', '30.0374523', '31.4019316', '31.4220303']}

# %%
# show lat & long
location.raw['lat'], location.raw['lon']
# Out:
# ('30.026992800000002', '31.40906325945414')

# %%
# show the location information using .reverse with lat & long
location = geolocator.reverse("29.981650417493046, 31.428900499194086")
location.raw
# Out:
# {'place_id': 42837656,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#  'osm_type': 'way',
#  'osm_id': 338687680,
#  'lat': '29.98171225560333',
#  'lon': '31.42896290016677',
#  'class': 'highway',
#  'type': 'residential',
#  'place_rank': 26,
#  'importance': 0.10000999999999993,
#  'addresstype': 'road',
#  'name': '',
#  'display_name': 'التجمع الثالث, القاهرة, 11936, مصر',
#  'address': {'neighbourhood': 'التجمع الثالث',
#   'village': 'التجمع الثالث',
#   'city': 'القاهرة',
#   'state': 'القاهرة',
#   'ISO3166-2-lvl4': 'EG-C',
#   'postcode': '11936',
#   'country': 'مصر',
#   'country_code': 'eg'},
#  'boundingbox': ['29.9785046', '29.9825297', '31.4280647', '31.4292666']}

# %%
# show country name from location information
location.raw['address']['country']
# Out:
# 'مصر'

# %%
# show city name from location information
location.raw['address']['city']
# Out:
# 'القاهرة'

# %% [markdown]
# ***So Lets use it with Our data***

# %%
# take a sample of size 200 from sendy_logistics dataset
df = pd.read_csv('../dastasets/sendy_logistics.csv').sample(200)
df.head()
# Out:
#              Order No       User Id Vehicle Type  Platform Type  \
# 8557   Order_No_24983    User_Id_60         Bike              3
# 11901  Order_No_27965   User_Id_393         Bike              3
# 18234  Order_No_26810  User_Id_1603         Bike              1
# 4352    Order_No_9984  User_Id_1363         Bike              3
# 6096   Order_No_24392  User_Id_2593         Bike              3
#
#       Personal or Business  Placement - Day of Month  \
# 8557              Business                        28
# 11901             Business                        11
# 18234             Personal                        28
# 4352              Business                         2
# 6096              Business                         7
#
#        Placement - Weekday (Mo = 1) Placement - Time  \
# 8557                              4       1:48:44 PM
# 11901                             1       1:24:39 PM
# 18234                             1       4:51:12 PM
# 4352                              5       9:00:32 AM
# 6096                              2      10:57:21 AM
#
#        Confirmation - Day of Month  Confirmation - Weekday (Mo = 1)  ...  \
# 8557                            28                                4  ...
# 11901                           11                                1  ...
# 18234                           28                                1  ...
# 4352                             2                                5  ...
# 6096                             7                                2  ...
#
#       Arrival at Destination - Time  Distance (KM)  Temperature  \
# 8557                     2:31:50 PM             15         27.2
# 11901                    1:59:29 PM             11         27.9
# 18234                    5:49:03 PM              7         22.5
# 4352                     9:18:32 AM              3         17.9
# 6096                    11:11:26 AM              1         23.3
#
#       Precipitation in millimeters  Pickup Lat  Pickup Long Destination Lat  \
# 8557                           NaN   -1.303596    36.778378       -1.229662
# 11901                          NaN   -1.316711    36.830156       -1.263818
# 18234                          NaN   -1.280677    36.837076       -1.322019
# 4352                          16.9   -1.300406    36.829741       -1.304713
# 6096                           NaN   -1.261589    36.792873       -1.255189
#
#        Destination Long      Rider Id Time from Pickup to Arrival
# 8557          36.843827  Rider_Id_484                        1757
# 11901         36.793006  Rider_Id_619                           2
# 18234         36.840017  Rider_Id_208                        1896
# 4352          36.808955   Rider_Id_69                         558
# 6096          36.782203  Rider_Id_449                         389
#
# [5 rows x 29 columns]

# %%
# create a fn to extract the city name from the data
def get_city(x):
    try:
        location = geolocator.reverse(f"{x['Pickup Lat']}, {x['Pickup Long']}")
        return location.raw['address']['city']
    except:
        return np.nan

# create a new column called city
df['City'] = df.apply(get_city, axis=1)
df.head()
# Out:
#              Order No       User Id Vehicle Type  Platform Type  \
# 8557   Order_No_24983    User_Id_60         Bike              3
# 11901  Order_No_27965   User_Id_393         Bike              3
# 18234  Order_No_26810  User_Id_1603         Bike              1
# 4352    Order_No_9984  User_Id_1363         Bike              3
# 6096   Order_No_24392  User_Id_2593         Bike              3
#
#       Personal or Business  Placement - Day of Month  \
# 8557              Business                        28
# 11901             Business                        11
# 18234             Personal                        28
# 4352              Business                         2
# 6096              Business                         7
#
#        Placement - Weekday (Mo = 1) Placement - Time  \
# 8557                              4       1:48:44 PM
# 11901                             1       1:24:39 PM
# 18234                             1       4:51:12 PM
# 4352                              5       9:00:32 AM
# 6096                              2      10:57:21 AM
#
#        Confirmation - Day of Month  Confirmation - Weekday (Mo = 1)  ...  \
# 8557                            28                                4  ...
# 11901                           11                                1  ...
# 18234                           28                                1  ...
# 4352                             2                                5  ...
# 6096                             7                                2  ...
#
#       Distance (KM)  Temperature  Precipitation in millimeters Pickup Lat  \
# 8557             15         27.2                           NaN  -1.303596
# 11901            11         27.9                           NaN  -1.316711
# 18234             7         22.5                           NaN  -1.280677
# 4352              3         17.9                          16.9  -1.300406
# 6096              1         23.3                           NaN  -1.261589
#
#        Pickup Long  Destination Lat Destination Long      Rider Id  \
# 8557     36.778378        -1.229662        36.843827  Rider_Id_484
# 11901    36.830156        -1.263818        36.793006  Rider_Id_619
# 18234    36.837076        -1.322019        36.840017  Rider_Id_208
# 4352     36.829741        -1.304713        36.808955   Rider_Id_69
# 6096     36.792873        -1.255189        36.782203  Rider_Id_449
#
#        Time from Pickup to Arrival     City
# 8557                          1757  Nairobi
# 11901                            2  Nairobi
# 18234                         1896  Nairobi
# 4352                           558  Nairobi
# 6096                           389  Nairobi
#
# [5 rows x 30 columns]

# %%
# show value counts
df['City'].value_counts()
# Out:
# City
# Nairobi                    192
# Syokimau-Mulolongo ward      5
# Roysambu ward                1
# Matathani ward               1
# Kiambu Township ward         1
# Name: count, dtype: int64

# %% [markdown]
# # Great Work!
