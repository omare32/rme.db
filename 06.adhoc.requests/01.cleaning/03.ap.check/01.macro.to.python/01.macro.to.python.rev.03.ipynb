# %%
import openpyxl
from openpyxl.styles import PatternFill, Font, Border, Side, Alignment
from openpyxl.utils import get_column_letter
import os
import logging

# Set up logging
logging.basicConfig(filename='excel_processing.log', level=logging.INFO)

def clean_excel_data(excel_file_path):
    try:
        wb = openpyxl.load_workbook(excel_file_path)
        ws = wb.active

        if ws.max_row == 1 and ws.max_column == 1 and ws.cell(row=1, column=1).value is None:
            print(f"Warning: Sheet is empty in {excel_file_path}. Skipping this file.")
            return

        # Insert a column at the beginning (column A)
        ws.insert_cols(1) 

        # Unmerge all cells within the sheet's dimensions
        merged_cells_copy = [
            rng for rng in ws.merged_cells.ranges 
            if rng.min_row <= ws.max_row and rng.max_col <= ws.max_column
        ]
        for merged_cell_range in merged_cells_copy:
            try:
                ws.unmerge_cells(str(merged_cell_range))
            except KeyError as e:
                print(f"Warning: KeyError encountered while unmerging cells (likely due to invalid range): {e}")
                print(f"Problematic merged cell range: {merged_cell_range}")  # Print details of the range

        # Copy row 24 and paste special to row 18
        for col_idx in range(1, ws.max_column + 1):
            ws.cell(row=18, column=col_idx).value = ws.cell(row=24, column=col_idx).value

        # Copying Project Names
        proj_name = None 
        for row_idx in range(18, ws.max_row + 1):
            crr_cell = ws.cell(row=row_idx, column=2)  # Adjusted column index due to insertion
            color_int = crr_cell.fill.start_color.index 
            if color_int == "00703084" and crr_cell.value == "Bank Account Name":
                proj_name = ws.cell(row=row_idx - 4, column=5).value  # Adjusted column index
                ws.cell(row=row_idx, column=1).value = proj_name
            elif color_int == "00FFFFFF" and crr_cell.value and ws.cell(row=row_idx, column=3).value:  # Adjusted column index
                ws.cell(row=row_idx, column=1).value = proj_name

        # Find the last row with data in column A, handle empty column case
        last_row = ws.max_row
        while last_row > 0 and ws.cell(row=last_row, column=1).value is None:
            last_row -= 1

        if last_row == 0:  # Handle empty column A
            print(f"Warning: Column A is empty in {excel_file_path}. Skipping this file.")
            return  # Skip further processing for this file

        # Set cell A18 
        cell_a18 = ws.cell(row=18, column=1)
        cell_a18.value = "Project"
        cell_a18.fill = PatternFill(start_color="00703084", end_color="00703084", fill_type="solid")
        cell_a18.font = Font(color="FFFFFF") 

        # Set cell in the next row to "END"
        ws.cell(row=last_row + 1, column=1).value = "END"

        # Deleting excess rows (iterate in reverse to avoid index issues)
        for row_idx in range(ws.max_row, 18, -1): 
            crr_cell = ws.cell(row=row_idx, column=1)
            if (
                crr_cell.value is None 
                or ws.cell(row=row_idx, column=2).value is None
                or ws.cell(row=row_idx, column=2).value == "Bank Account Name"
                or ws.cell(row=row_idx, column=2).value == "Owner Name "
            ):
                ws.delete_rows(row_idx)

        # Find the new last row after deletions
        last_row = ws.max_row
        while ws.cell(row=last_row, column=1).value is None:
            last_row -= 1

        # Delete 50 rows after the last row
        ws.delete_rows(last_row + 1, 50)

        # Find the final last row
        last_row = ws.max_row
        while ws.cell(row=last_row, column=1).value is None:
            last_row -= 1

        # Apply formatting
        range_to_format = ws["A18": get_column_letter(15) + str(last_row)]
        thin_border = Border(left=Side(style='thin'), 
                            right=Side(style='thin'), 
                            top=Side(style='thin'), 
                            bottom=Side(style='thin'))

        for row in range_to_format:
            for cell in row:
                cell.border = thin_border
                cell.alignment = Alignment(horizontal="center")

        # Autofit columns
        for col in ws.columns:
            max_length = 0
            column = col[0].column_letter 
            for cell in col:
                try:
                    if len(str(cell.value)) > max_length:
                        max_length = len(cell.value)
                except:
                    pass
            adjusted_width = (max_length + 2) * 1.2
            ws.column_dimensions[column].width = adjusted_width

        wb.save(excel_file_path)
    except Exception as e:
        logging.error(f"Error processing {excel_file_path}: {e}")
        print(f"Error processing {excel_file_path}. See log for details.")

# Get the directory where your Jupyter Notebook is located
notebook_directory = os.path.dirname(os.path.abspath("__file__"))

# Find all Excel files in the directory
excel_files = [f for f in os.listdir(notebook_directory) if f.endswith('.xlsx') or f.endswith('.xls')]

# Process each Excel file
for excel_file in excel_files:
    excel_file_path = os.path.join(notebook_directory, excel_file)
    clean_excel_data(excel_file_path)
    print(f"Processed: {excel_file}")
# Out:
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3988, 1)
# Problematic merged cell range: A3987:A3988
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4461, 1)
# Problematic merged cell range: A4460:A4461
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4761, 1)
# Problematic merged cell range: A4760:A4761
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (749, 1)
# Problematic merged cell range: A748:A749
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4815, 1)
# Problematic merged cell range: A4814:A4815
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (570, 1)
# Problematic merged cell range: A569:A570
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (797, 1)
# Problematic merged cell range: A796:A797
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3340, 1)
# Problematic merged cell range: A3339:A3340
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (841, 1)
# Problematic merged cell range: A840:A841
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4173, 1)
# Problematic merged cell range: A4172:A4173
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1952, 1)
# Problematic merged cell range: A1951:A1952
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1653, 1)
# Problematic merged cell range: A1652:A1653
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4825, 1)
# Problematic merged cell range: A4824:A4825
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4526, 1)
# Problematic merged cell range: A4525:A4526
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1663, 1)
# Problematic merged cell range: A1662:A1663
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (183, 1)
# Problematic merged cell range: A182:A183
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2780, 1)
# Problematic merged cell range: A2779:A2780
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (705, 1)
# Problematic merged cell range: A704:A705
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3770, 1)
# Problematic merged cell range: A3769:A3770
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3449, 1)
# Problematic merged cell range: A3448:A3449
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4134, 1)
# Problematic merged cell range: A4133:A4134
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1708, 1)
# Problematic merged cell range: A1707:A1708
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2393, 1)
# Problematic merged cell range: A2392:A2393
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (391, 1)
# Problematic merged cell range: A390:A391
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2555, 1)
# Problematic merged cell range: A2554:A2555
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2861, 1)
# Problematic merged cell range: A2860:A2861
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (745, 1)
# Problematic merged cell range: A744:A745
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (5000, 1)
# Problematic merged cell range: A4999:A5000
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1272, 1)
# Problematic merged cell range: A1271:A1272
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2899, 1)
# Problematic merged cell range: A2898:A2899
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3573, 1)
# Problematic merged cell range: A3572:A3573
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1419, 1)
# Problematic merged cell range: A1418:A1419
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2811, 1)
# Problematic merged cell range: A2810:A2811
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1414, 1)
# Problematic merged cell range: A1413:A1414
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (711, 1)
# Problematic merged cell range: A710:A711
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4042, 1)
# Problematic merged cell range: A4041:A4042
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1828, 1)
# Problematic merged cell range: A1827:A1828
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1838, 1)
# Problematic merged cell range: A1837:A1838
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2311, 1)
# Problematic merged cell range: A2310:A2311
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2561, 1)
# Problematic merged cell range: A2560:A2561
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3377, 1)
# Problematic merged cell range: A3376:A3377
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1681, 1)
# Problematic merged cell range: A1680:A1681
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3793, 1)
# Problematic merged cell range: A3792:A3793
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4909, 1)
# Problematic merged cell range: A4908:A4909
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2682, 1)
# Problematic merged cell range: A2681:A2682
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4504, 1)
# Problematic merged cell range: A4503:A4504
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2405, 1)
# Problematic merged cell range: A2404:A2405
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (462, 1)
# Problematic merged cell range: A461:A462
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (620, 1)
# Problematic merged cell range: A619:A620
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4973, 1)
# Problematic merged cell range: A4972:A4973
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3493, 1)
# Problematic merged cell range: A3492:A3493
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3837, 1)
# Problematic merged cell range: A3836:A3837
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (831, 1)
# Problematic merged cell range: A830:A831
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3733, 1)
# Problematic merged cell range: A3732:A3733
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1028, 1)
# Problematic merged cell range: A1027:A1028
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2867, 1)
# Problematic merged cell range: A2866:A2867
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (793, 1)
# Problematic merged cell range: A792:A793
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1398, 1)
# Problematic merged cell range: A1397:A1398
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4729, 1)
# Problematic merged cell range: A4728:A4729
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (386, 1)
# Problematic merged cell range: A385:A386
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4299, 1)
# Problematic merged cell range: A4298:A4299
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4010, 1)
# Problematic merged cell range: A4009:A4010
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (914, 1)
# Problematic merged cell range: A913:A914
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (451, 1)
# Problematic merged cell range: A450:A451
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1267, 1)
# Problematic merged cell range: A1266:A1267
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (321, 1)
# Problematic merged cell range: A320:A321
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (953, 1)
# Problematic merged cell range: A952:A953
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1006, 1)
# Problematic merged cell range: A1005:A1006
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3750, 1)
# Problematic merged cell range: A3749:A3750
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4735, 1)
# Problematic merged cell range: A4734:A4735
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2661, 1)
# Problematic merged cell range: A2660:A2661
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2329, 1)
# Problematic merged cell range: A2328:A2329
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (71, 1)
# Problematic merged cell range: A70:A71
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (283, 1)
# Problematic merged cell range: A282:A283
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4343, 1)
# Problematic merged cell range: A4342:A4343
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4643, 1)
# Problematic merged cell range: A4642:A4643
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4338, 1)
# Problematic merged cell range: A4337:A4338
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2542, 1)
# Problematic merged cell range: A2541:A2542
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (457, 1)
# Problematic merged cell range: A456:A457
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (821, 1)
# Problematic merged cell range: A820:A821
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (866, 1)
# Problematic merged cell range: A865:A866
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (860, 1)
# Problematic merged cell range: A859:A860
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3320, 1)
# Problematic merged cell range: A3319:A3320
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1851, 1)
# Problematic merged cell range: A1850:A1851
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4088, 1)
# Problematic merged cell range: A4087:A4088
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1546, 1)
# Problematic merged cell range: A1545:A1546
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2309, 1)
# Problematic merged cell range: A2308:A2309
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (892, 1)
# Problematic merged cell range: A891:A892
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (130, 1)
# Problematic merged cell range: A129:A130
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3006, 1)
# Problematic merged cell range: A3005:A3006
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (632, 1)
# Problematic merged cell range: A631:A632
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3690, 1)
# Problematic merged cell range: A3689:A3690
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (827, 1)
# Problematic merged cell range: A826:A827
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1285, 1)
# Problematic merged cell range: A1284:A1285
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1954, 1)
# Problematic merged cell range: A1953:A1954
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4197, 1)
# Problematic merged cell range: A4196:A4197
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4871, 1)
# Problematic merged cell range: A4870:A4871
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4960, 1)
# Problematic merged cell range: A4959:A4960
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4528, 1)
# Problematic merged cell range: A4527:A4528
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (343, 1)
# Problematic merged cell range: A342:A343
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (5013, 1)
# Problematic merged cell range: A5012:A5013
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2340, 1)
# Problematic merged cell range: A2339:A2340
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (735, 1)
# Problematic merged cell range: A734:A735
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1498, 1)
# Problematic merged cell range: A1497:A1498
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3908, 1)
# Problematic merged cell range: A3907:A3908
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4725, 1)
# Problematic merged cell range: A4724:A4725
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1868, 1)
# Problematic merged cell range: A1867:A1868
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3990, 1)
# Problematic merged cell range: A3989:A3990
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (747, 1)
# Problematic merged cell range: A746:A747
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (780, 1)
# Problematic merged cell range: A779:A780
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (894, 1)
# Problematic merged cell range: A893:A894
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3953, 1)
# Problematic merged cell range: A3952:A3953
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (845, 1)
# Problematic merged cell range: A844:A845
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4175, 1)
# Problematic merged cell range: A4174:A4175
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4775, 1)
# Problematic merged cell range: A4774:A4775
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4378, 1)
# Problematic merged cell range: A4377:A4378
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (871, 1)
# Problematic merged cell range: A870:A871
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3915, 1)
# Problematic merged cell range: A3914:A3915
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1677, 1)
# Problematic merged cell range: A1676:A1677
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1411, 1)
# Problematic merged cell range: A1410:A1411
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4584, 1)
# Problematic merged cell range: A4583:A4584
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2696, 1)
# Problematic merged cell range: A2695:A2696
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2538, 1)
# Problematic merged cell range: A2537:A2538
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (763, 1)
# Problematic merged cell range: A762:A763
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (306, 1)
# Problematic merged cell range: A305:A306
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3223, 1)
# Problematic merged cell range: A3222:A3223
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2760, 1)
# Problematic merged cell range: A2759:A2760
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1064, 1)
# Problematic merged cell range: A1063:A1064
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3823, 1)
# Problematic merged cell range: A3822:A3823
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (817, 1)
# Problematic merged cell range: A816:A817
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1477, 1)
# Problematic merged cell range: A1476:A1477
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4335, 1)
# Problematic merged cell range: A4334:A4335
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2569, 1)
# Problematic merged cell range: A2568:A2569
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1030, 1)
# Problematic merged cell range: A1029:A1030
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (795, 1)
# Problematic merged cell range: A794:A795
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4406, 1)
# Problematic merged cell range: A4405:A4406
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4012, 1)
# Problematic merged cell range: A4011:A4012
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2685, 1)
# Problematic merged cell range: A2684:A2685
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (584, 1)
# Problematic merged cell range: A583:A584
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (323, 1)
# Problematic merged cell range: A322:A323
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (535, 1)
# Problematic merged cell range: A534:A535
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3768, 1)
# Problematic merged cell range: A3767:A3768
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1134, 1)
# Problematic merged cell range: A1133:A1134
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1036, 1)
# Problematic merged cell range: A1035:A1036
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2794, 1)
# Problematic merged cell range: A2793:A2794
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (89, 1)
# Problematic merged cell range: A88:A89
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2817, 1)
# Problematic merged cell range: A2816:A2817
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (890, 1)
# Problematic merged cell range: A889:A890
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2887, 1)
# Problematic merged cell range: A2886:A2887
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3949, 1)
# Problematic merged cell range: A3948:A3949
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1401, 1)
# Problematic merged cell range: A1400:A1401
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4629, 1)
# Problematic merged cell range: A4628:A4629
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1140, 1)
# Problematic merged cell range: A1139:A1140
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4014, 1)
# Problematic merged cell range: A4013:A4014
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4771, 1)
# Problematic merged cell range: A4770:A4771
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2544, 1)
# Problematic merged cell range: A2543:A2544
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2702, 1)
# Problematic merged cell range: A2701:A2702
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (454, 1)
# Problematic merged cell range: A453:A454
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (787, 1)
# Problematic merged cell range: A786:A787
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3258, 1)
# Problematic merged cell range: A3257:A3258
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1325, 1)
# Problematic merged cell range: A1324:A1325
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4079, 1)
# Problematic merged cell range: A4078:A4079
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1994, 1)
# Problematic merged cell range: A1993:A1994
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1679, 1)
# Problematic merged cell range: A1678:A1679
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1979, 1)
# Problematic merged cell range: A1978:A1979
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4749, 1)
# Problematic merged cell range: A4748:A4749
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4891, 1)
# Problematic merged cell range: A4890:A4891
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2806, 1)
# Problematic merged cell range: A2805:A2806
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (607, 1)
# Problematic merged cell range: A606:A607
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1734, 1)
# Problematic merged cell range: A1733:A1734
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4194, 1)
# Problematic merged cell range: A4193:A4194
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3889, 1)
# Problematic merged cell range: A3888:A3889
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1729, 1)
# Problematic merged cell range: A1728:A1729
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (5016, 1)
# Problematic merged cell range: A5015:A5016
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (815, 1)
# Problematic merged cell range: A814:A815
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1026, 1)
# Problematic merged cell range: A1025:A1026
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (869, 1)
# Problematic merged cell range: A868:A869
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (863, 1)
# Problematic merged cell range: A862:A863
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1642, 1)
# Problematic merged cell range: A1641:A1642
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1396, 1)
# Problematic merged cell range: A1395:A1396
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4402, 1)
# Problematic merged cell range: A4401:A4402
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1696, 1)
# Problematic merged cell range: A1695:A1696
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3939, 1)
# Problematic merged cell range: A3938:A3939
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4727, 1)
# Problematic merged cell range: A4726:A4727
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2301, 1)
# Problematic merged cell range: A2300:A2301
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (580, 1)
# Problematic merged cell range: A579:A580
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3050, 1)
# Problematic merged cell range: A3049:A3050
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3073, 1)
# Problematic merged cell range: A3072:A3073
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3373, 1)
# Problematic merged cell range: A3372:A3373
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4063, 1)
# Problematic merged cell range: A4062:A4063
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1963, 1)
# Problematic merged cell range: A1962:A1963
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1957, 1)
# Problematic merged cell range: A1956:A1957
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4733, 1)
# Problematic merged cell range: A4732:A4733
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4864, 1)
# Problematic merged cell range: A4863:A4864
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2432, 1)
# Problematic merged cell range: A2431:A2432
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4859, 1)
# Problematic merged cell range: A4858:A4859
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1004, 1)
# Problematic merged cell range: A1003:A1004
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (896, 1)
# Problematic merged cell range: A895:A896
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1044, 1)
# Problematic merged cell range: A1043:A1044
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2148, 1)
# Problematic merged cell range: A2147:A2148
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4245, 1)
# Problematic merged cell range: A4244:A4245
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4930, 1)
# Problematic merged cell range: A4929:A4930
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2540, 1)
# Problematic merged cell range: A2539:A2540
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (819, 1)
# Problematic merged cell range: A818:A819
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (847, 1)
# Problematic merged cell range: A846:A847
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4353, 1)
# Problematic merged cell range: A4352:A4353
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4848, 1)
# Problematic merged cell range: A4847:A4848
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (200, 1)
# Problematic merged cell range: A199:A200
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (233, 1)
# Problematic merged cell range: A232:A233
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (858, 1)
# Problematic merged cell range: A857:A858
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3318, 1)
# Problematic merged cell range: A3317:A3318
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3004, 1)
# Problematic merged cell range: A3003:A3004
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1213, 1)
# Problematic merged cell range: A1212:A1213
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1991, 1)
# Problematic merged cell range: A1990:A1991
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1686, 1)
# Problematic merged cell range: A1685:A1686
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4484, 1)
# Problematic merged cell range: A4483:A4484
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (167, 1)
# Problematic merged cell range: A166:A167
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (767, 1)
# Problematic merged cell range: A766:A767
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1136, 1)
# Problematic merged cell range: A1135:A1136
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1033, 1)
# Problematic merged cell range: A1032:A1033
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4249, 1)
# Problematic merged cell range: A4248:A4249
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4240, 1)
# Problematic merged cell range: A4239:A4240
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3935, 1)
# Problematic merged cell range: A3934:A3935
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (75, 1)
# Problematic merged cell range: A74:A75
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (64, 1)
# Problematic merged cell range: A63:A64
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2819, 1)
# Problematic merged cell range: A2818:A2819
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (5062, 1)
# Problematic merged cell range: A5061:A5062
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1202, 1)
# Problematic merged cell range: A1201:A1202
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3951, 1)
# Problematic merged cell range: A3950:A3951
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1605, 1)
# Problematic merged cell range: A1604:A1605
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1600, 1)
# Problematic merged cell range: A1599:A1600
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (120, 1)
# Problematic merged cell range: A119:A120
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4773, 1)
# Problematic merged cell range: A4772:A4773
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4801, 1)
# Problematic merged cell range: A4800:A4801
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (789, 1)
# Problematic merged cell range: A788:A789
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (947, 1)
# Problematic merged cell range: A946:A947
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (843, 1)
# Problematic merged cell range: A842:A843
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (837, 1)
# Problematic merged cell range: A836:A837
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4582, 1)
# Problematic merged cell range: A4581:A4582
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4557, 1)
# Problematic merged cell range: A4556:A4557
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4926, 1)
# Problematic merged cell range: A4925:A4926
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2694, 1)
# Problematic merged cell range: A2693:A2694
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (293, 1)
# Problematic merged cell range: A292:A293
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3821, 1)
# Problematic merged cell range: A3820:A3821
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3963, 1)
# Problematic merged cell range: A3962:A3963
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1878, 1)
# Problematic merged cell range: A1877:A1878
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4180, 1)
# Problematic merged cell range: A4179:A4180
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4321, 1)
# Problematic merged cell range: A4320:A4321
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4316, 1)
# Problematic merged cell range: A4315:A4316
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4490, 1)
# Problematic merged cell range: A4489:A4490
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4676, 1)
# Problematic merged cell range: A4675:A4676
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3260, 1)
# Problematic merged cell range: A3259:A3260
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (801, 1)
# Problematic merged cell range: A800:A801
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3702, 1)
# Problematic merged cell range: A3701:A3702
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1160, 1)
# Problematic merged cell range: A1159:A1160
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1328, 1)
# Problematic merged cell range: A1327:A1328
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3772, 1)
# Problematic merged cell range: A3771:A3772
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4072, 1)
# Problematic merged cell range: A4071:A4072
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1987, 1)
# Problematic merged cell range: A1986:A1987
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (512, 1)
# Problematic merged cell range: A511:A512
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3114, 1)
# Problematic merged cell range: A3113:A3114
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2711, 1)
# Problematic merged cell range: A2710:A2711
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (882, 1)
# Problematic merged cell range: A881:A882
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4965, 1)
# Problematic merged cell range: A4964:A4965
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (316, 1)
# Problematic merged cell range: A315:A316
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2565, 1)
# Problematic merged cell range: A2564:A2565
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (60, 1)
# Problematic merged cell range: A59:A60
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3577, 1)
# Problematic merged cell range: A3576:A3577
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2815, 1)
# Problematic merged cell range: A2814:A2815
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3903, 1)
# Problematic merged cell range: A3902:A3903
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1503, 1)
# Problematic merged cell range: A1502:A1503
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3719, 1)
# Problematic merged cell range: A3718:A3719
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4932, 1)
# Problematic merged cell range: A4931:A4932
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4600, 1)
# Problematic merged cell range: A4599:A4600
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4627, 1)
# Problematic merged cell range: A4626:A4627
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4769, 1)
# Problematic merged cell range: A4768:A4769
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (126, 1)
# Problematic merged cell range: A125:A126
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (480, 1)
# Problematic merged cell range: A479:A480
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4416, 1)
# Problematic merged cell range: A4415:A4416
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1138, 1)
# Problematic merged cell range: A1137:A1138
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2070, 1)
# Problematic merged cell range: A2069:A2070
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1965, 1)
# Problematic merged cell range: A1964:A1965
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (269, 1)
# Problematic merged cell range: A268:A269
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2434, 1)
# Problematic merged cell range: A2433:A2434
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (235, 1)
# Problematic merged cell range: A234:A235
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3566, 1)
# Problematic merged cell range: A3565:A3566
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4422, 1)
# Problematic merged cell range: A4421:A4422
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4536, 1)
# Problematic merged cell range: A4535:A4536
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4905, 1)
# Problematic merged cell range: A4904:A4905
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1416, 1)
# Problematic merged cell range: A1415:A1416
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4889, 1)
# Problematic merged cell range: A4888:A4889
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4590, 1)
# Problematic merged cell range: A4589:A4590
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4949, 1)
# Problematic merged cell range: A4948:A4949
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4486, 1)
# Problematic merged cell range: A4485:A4486
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1455, 1)
# Problematic merged cell range: A1454:A1455
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1482, 1)
# Problematic merged cell range: A1481:A1482
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (813, 1)
# Problematic merged cell range: A812:A813
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3056, 1)
# Problematic merged cell range: A3055:A3056
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (105, 1)
# Problematic merged cell range: A104:A105
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (405, 1)
# Problematic merged cell range: A404:A405
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2979, 1)
# Problematic merged cell range: A2978:A2979
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1563, 1)
# Problematic merged cell range: A1562:A1563
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2665, 1)
# Problematic merged cell range: A2664:A2665
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2333, 1)
# Problematic merged cell range: A2332:A2333
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3323, 1)
# Problematic merged cell range: A3322:A3323
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4804, 1)
# Problematic merged cell range: A4803:A4804
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4520, 1)
# Problematic merged cell range: A4519:A4520
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4672, 1)
# Problematic merged cell range: A4671:A4672
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2430, 1)
# Problematic merged cell range: A2429:A2430
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4243, 1)
# Problematic merged cell range: A4242:A4243
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2458, 1)
# Problematic merged cell range: A2457:A2458
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2468, 1)
# Problematic merged cell range: A2467:A2468
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4296, 1)
# Problematic merged cell range: A4295:A4296
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4928, 1)
# Problematic merged cell range: A4927:A4928
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (279, 1)
# Problematic merged cell range: A278:A279
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (825, 1)
# Problematic merged cell range: A824:A825
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4428, 1)
# Problematic merged cell range: A4427:A4428
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3982, 1)
# Problematic merged cell range: A3981:A3982
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1880, 1)
# Problematic merged cell range: A1879:A1880
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1150, 1)
# Problematic merged cell range: A1149:A1150
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1450, 1)
# Problematic merged cell range: A1449:A1450
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4318, 1)
# Problematic merged cell range: A4317:A4318
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (434, 1)
# Problematic merged cell range: A433:A434
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (281, 1)
# Problematic merged cell range: A280:A281
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3035, 1)
# Problematic merged cell range: A3034:A3035
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (803, 1)
# Problematic merged cell range: A802:A803
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4874, 1)
# Problematic merged cell range: A4873:A4874
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1566, 1)
# Problematic merged cell range: A1565:A1566
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1172, 1)
# Problematic merged cell range: A1171:A1172
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (884, 1)
# Problematic merged cell range: A883:A884
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1516, 1)
# Problematic merged cell range: A1515:A1516
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1658, 1)
# Problematic merged cell range: A1657:A1658
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1989, 1)
# Problematic merged cell range: A1988:A1989
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4832, 1)
# Problematic merged cell range: A4831:A4832
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (243, 1)
# Problematic merged cell range: A242:A243
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1000, 1)
# Problematic merged cell range: A999:A1000
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (912, 1)
# Problematic merged cell range: A911:A912
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3966, 1)
# Problematic merged cell range: A3965:A3966
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4641, 1)
# Problematic merged cell range: A4640:A4641
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2447, 1)
# Problematic merged cell range: A2446:A2447
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (362, 1)
# Problematic merged cell range: A361:A362
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (662, 1)
# Problematic merged cell range: A661:A662
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (809, 1)
# Problematic merged cell range: A808:A809
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3579, 1)
# Problematic merged cell range: A3578:A3579
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1636, 1)
# Problematic merged cell range: A1635:A1636
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1479, 1)
# Problematic merged cell range: A1478:A1479
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (73, 1)
# Problematic merged cell range: A72:A73
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3986, 1)
# Problematic merged cell range: A3985:A3986
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (417, 1)
# Problematic merged cell range: A416:A417
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (254, 1)
# Problematic merged cell range: A253:A254
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2714, 1)
# Problematic merged cell range: A2713:A2714
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1376, 1)
# Problematic merged cell range: A1375:A1376
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3688, 1)
# Problematic merged cell range: A3687:A3688
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4069, 1)
# Problematic merged cell range: A4068:A4069
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4588, 1)
# Problematic merged cell range: A4587:A4588
# ...
# Problematic merged cell range: A2688:A2689
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (499, 1)
# Problematic merged cell range: A498:A499
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4739, 1)
# Problematic merged cell range: A4738:A4739
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (185, 1)
# Problematic merged cell range: A184:A185
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (510, 1)
# Problematic merged cell range: A509:A510
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2307, 1)
# Problematic merged cell range: A2306:A2307
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4425, 1)
# Problematic merged cell range: A4424:A4425
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2324, 1)
# Problematic merged cell range: A2323:A2324
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2498, 1)
# Problematic merged cell range: A2497:A2498
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (407, 1)
# Problematic merged cell range: A406:A407
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2709, 1)
# Problematic merged cell range: A2708:A2709
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (708, 1)
# Problematic merged cell range: A707:A708
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4631, 1)
# Problematic merged cell range: A4630:A4631
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3020, 1)
# Problematic merged cell range: A3019:A3020
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (805, 1)
# Problematic merged cell range: A804:A805
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3575, 1)
# Problematic merged cell range: A3574:A3575
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1632, 1)
# Problematic merged cell range: A1631:A1632
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1943, 1)
# Problematic merged cell range: A1942:A1943
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (349, 1)
# Problematic merged cell range: A348:A349
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (516, 1)
# Problematic merged cell range: A515:A516
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4844, 1)
# Problematic merged cell range: A4843:A4844
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2813, 1)
# Problematic merged cell range: A2812:A2813
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (713, 1)
# Problematic merged cell range: A712:A713
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (430, 1)
# Problematic merged cell range: A429:A430
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2667, 1)
# Problematic merged cell range: A2666:A2667
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2563, 1)
# Problematic merged cell range: A2562:A2563
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (189, 1)
# Problematic merged cell range: A188:A189
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (164, 1)
# Problematic merged cell range: A163:A164
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3495, 1)
# Problematic merged cell range: A3494:A3495
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3848, 1)
# Problematic merged cell range: A3847:A3848
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4060, 1)
# Problematic merged cell range: A4059:A4060
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2303, 1)
# Problematic merged cell range: A2302:A2303
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (691, 1)
# Problematic merged cell range: A690:A691
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (833, 1)
# Problematic merged cell range: A832:A833
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1002, 1)
# Problematic merged cell range: A1001:A1002
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3604, 1)
# Problematic merged cell range: A3603:A3604
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3668, 1)
# Problematic merged cell range: A3667:A3668
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4731, 1)
# Problematic merged cell range: A4730:A4731
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (441, 1)
# Problematic merged cell range: A440:A441
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4986, 1)
# Problematic merged cell range: A4985:A4986
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (5100, 1)
# Problematic merged cell range: A5099:A5100
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4687, 1)
# Problematic merged cell range: A4686:A4687
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2885, 1)
# Problematic merged cell range: A2884:A2885
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (811, 1)
# Problematic merged cell range: A810:A811
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1269, 1)
# Problematic merged cell range: A1268:A1269
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4028, 1)
# Problematic merged cell range: A4027:A4028
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3571, 1)
# Problematic merged cell range: A3570:A3571
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (839, 1)
# Problematic merged cell range: A838:A839
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1638, 1)
# Problematic merged cell range: A1637:A1638
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4382, 1)
# Problematic merged cell range: A4381:A4382
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4420, 1)
# Problematic merged cell range: A4419:A4420
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4840, 1)
# Problematic merged cell range: A4839:A4840
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4737, 1)
# Problematic merged cell range: A4736:A4737
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (545, 1)
# Problematic merged cell range: A544:A545
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1019, 1)
# Problematic merged cell range: A1018:A1019
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3375, 1)
# Problematic merged cell range: A3374:A3375
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3871, 1)
# Problematic merged cell range: A3870:A3871
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4171, 1)
# Problematic merged cell range: A4170:A4171
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1743, 1)
# Problematic merged cell range: A1742:A1743
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (159, 1)
# Problematic merged cell range: A158:A159
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2402, 1)
# Problematic merged cell range: A2401:A2402
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (273, 1)
# Problematic merged cell range: A272:A273
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2924, 1)
# Problematic merged cell range: A2923:A2924
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3860, 1)
# Problematic merged cell range: A3859:A3860
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (823, 1)
# Problematic merged cell range: A822:A823
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1009, 1)
# Problematic merged cell range: A1008:A1009
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2608, 1)
# Problematic merged cell range: A2607:A2608
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (420, 1)
# Problematic merged cell range: A419:A420
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2669, 1)
# Problematic merged cell range: A2668:A2669
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2663, 1)
# Problematic merged cell range: A2662:A2663
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (568, 1)
# Problematic merged cell range: A567:A568
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3338, 1)
# Problematic merged cell range: A3337:A3338
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1548, 1)
# Problematic merged cell range: A1547:A1548
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3692, 1)
# Problematic merged cell range: A3691:A3692
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4465, 1)
# Problematic merged cell range: A4464:A4465
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1759, 1)
# Problematic merged cell range: A1758:A1759
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4846, 1)
# Problematic merged cell range: A4845:A4846
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2314, 1)
# Problematic merged cell range: A2313:A2314
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (318, 1)
# Problematic merged cell range: A317:A318
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (829, 1)
# Problematic merged cell range: A828:A829
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (998, 1)
# Problematic merged cell range: A997:A998
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (594, 1)
# Problematic merged cell range: A593:A594
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1199, 1)
# Problematic merged cell range: A1198:A1199
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4230, 1)
# Problematic merged cell range: A4229:A4230
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1825, 1)
# Problematic merged cell range: A1824:A1825
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (345, 1)
# Problematic merged cell range: A344:A345
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (40, 1)
# Problematic merged cell range: A39:A40
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2483, 1)
# Problematic merged cell range: A2482:A2483
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (384, 1)
# Problematic merged cell range: A383:A384
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (252, 1)
# Problematic merged cell range: A251:A252
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2853, 1)
# Problematic merged cell range: A2852:A2853
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (737, 1)
# Problematic merged cell range: A736:A737
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (791, 1)
# Problematic merged cell range: A790:A791
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (807, 1)
# Problematic merged cell range: A806:A807
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2495, 1)
# Problematic merged cell range: A2494:A2495
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1492, 1)
# Problematic merged cell range: A1491:A1492
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1634, 1)
# Problematic merged cell range: A1633:A1634
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (765, 1)
# Problematic merged cell range: A764:A765
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3415, 1)
# Problematic merged cell range: A3414:A3415
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (557, 1)
# Problematic merged cell range: A556:A557
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4586, 1)
# Problematic merged cell range: A4585:A4586
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3786, 1)
# Problematic merged cell range: A3785:A3786
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (682, 1)
# Problematic merged cell range: A681:A682
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (677, 1)
# Problematic merged cell range: A676:A677
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1282, 1)
# Problematic merged cell range: A1281:A1282
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4178, 1)
# Problematic merged cell range: A4177:A4178
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (4553, 1)
# Problematic merged cell range: A4552:A4553
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (466, 1)
# Problematic merged cell range: A465:A466
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2305, 1)
# Problematic merged cell range: A2304:A2305
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (2463, 1)
# Problematic merged cell range: A2462:A2463
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (36, 1)
# Problematic merged cell range: A35:A36
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (388, 1)
# Problematic merged cell range: A387:A388
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (688, 1)
# Problematic merged cell range: A687:A688
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (835, 1)
# Problematic merged cell range: A834:A835
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (1021, 1)
# Problematic merged cell range: A1020:A1021
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3590, 1)
# Problematic merged cell range: A3589:A3590
# Warning: KeyError encountered while unmerging cells (likely due to invalid range): (3334, 1)
# Problematic merged cell range: A3333:A3334
# Warning: Column A is empty in d:\OneDrive\OneDrive - Rowad Modern Engineering\x004 Data Science\03.rme.db\00.repo\rme.db-1\06.cleaning\03.ap.check\01.macro.to.python\23.aug.only.RME_AP_Check_Payment_Grouping__130923.xlsx. Skipping this file.
# Processed: 23.aug.only.RME_AP_Check_Payment_Grouping__130923.xlsx
