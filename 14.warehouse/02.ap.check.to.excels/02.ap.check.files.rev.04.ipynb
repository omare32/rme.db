# %%
import pyodbc
import pandas as pd
import re

def connect_to_sql_server(server, database, user, password):
    """Connects to a SQL Server database and returns a connection object."""
    conn_str = (
        r'DRIVER={SQL Server};'
        r'SERVER=' + server + ';'
        r'DATABASE=' + database + ';'
        r'UID=' + user + ';'
        r'PWD=' + password + ';'
    )
    conn = pyodbc.connect(conn_str)
    return conn

def get_unique_projects(conn):
    """Gets a unique list of projects from the project_name column."""
    query = "SELECT DISTINCT project_name FROM [omar.rme1].[dbo].[ap_check]"
    cursor = conn.cursor()
    cursor.execute(query)
    projects = [row[0] for row in cursor.fetchall()]
    cursor.close()
    return projects

def sanitize_project_name(project_name):
    """Sanitizes the project name to make it suitable for a file name."""
    return re.sub(r'[\\/*?:"<>|]', "_", project_name)

def get_project_data(conn, project_name):
    """Gets all data related to a specific project."""
    query = f"""
        SELECT *
        FROM [omar.rme1].[dbo].[ap_check]
        WHERE project_name = ?
    """
    df = pd.read_sql(query, conn, params=[project_name])
    return df

def create_excel_files(conn, projects):
    """Creates an Excel file for each project with its related data."""
    for project in projects:
        sanitized_name = sanitize_project_name(project)
        df = get_project_data(conn, project)
        file_name = f"{sanitized_name}.xlsx"
        df.to_excel(file_name, index=False)
        print(f"Created {file_name}")

if __name__ == "__main__":
    server = '10.10.11.241'
    database = 'omar.rme1'
    user = 'yasser'
    password = 'yasser123'

    try:
        conn = connect_to_sql_server(server, database, user, password)
        projects = get_unique_projects(conn)
        create_excel_files(conn, projects)

    except Exception as e:
        print("Error:", e)
    finally:
        if conn:
            conn.close()
# Out:
# C:\Users\Omar Essam\AppData\Local\Temp\ipykernel_13604\3634977416.py:37: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn, params=[project_name])
# Created Ministries Buildings  0060.xlsx
# Created EMAAR-PKG117- MARASSI  0071.xlsx
# Created NREA Gulf El Zayt120 MW (FIEM)  GMSA_GZWF_1441.xlsx
# Created October Dry Port Railway  0153.xlsx
# Created MDF Factory  0147.xlsx
# Created ElSewedy HQ Internal Finishing  0141.xlsx
# Created EMAAR-PKG#85-UPTOWN  0073.xlsx
# Created October Under-Railway Tunnel  0175.xlsx
# Created SODIC Allegria Villa f100  0177.xlsx
# Created Alfa New Central Labs  0154.xlsx
# Created Abu Sultan Road Extension  0075.xlsx
# Created British International School  0203.xlsx
# Created ACWA POWER & NOMAC HQ  0213..xlsx
# Created ESPIKO Bridge L&L  0116.xlsx
# Created MR3 Bridge L&L  0118.xlsx
# Created Mostafa Kamel Bridge L&L  0114.xlsx
# Created CIP SODIC HEAD OFFICE  CIP SODIC HEAD OFFICE.xlsx
# Created Egat Rolling Mill no.4  0172.xlsx
# Created Tarek AbdelHakim Center  0197.xlsx
# Created Egyptian Exchange Building  0158.xlsx
# Created AbuSultan Rd Bridge2 Extension  0089.xlsx
# Created MAF HQ Renovation  0196.xlsx
# Created Kayan 3 New Cairo Capital City  ARMY_KYAN_1446.xlsx
# Created ESU Ph2-Enabling & Struc  0119.xlsx
# Created Ismalia Bridge  0019.xlsx
# Created CFC Podium 2  0113.xlsx
# Created Olympic City Lock&Load  0148.xlsx
# Created New Capital Tunnels  0059.xlsx
# Created EPICO 3 Facility  0187.xlsx
# Created Seashell Playa 5 Villas  0194.xlsx
# Created EDNC Hardscape Package  0171.xlsx
# Created Agric Greenhouses Tunnel  0097.xlsx
# Created EL-Hegaz Square Bridge  0121.xlsx
# Created El Amal Bridge  0046.xlsx
# Created Ras El Teen Hangar  0161.xlsx
# Created Tunnel of Sokhna Road  0074.xlsx
# Created Hyper El-Temsah  0070.xlsx
# Created Sherouk Bridge- LOCK&LOAD  0136.xlsx
# Created Mivida BP#189  0170.xlsx
# Created El Khatatba Bridge  0143.xlsx
# Created EGAT Mechanical Installations  0198.xlsx
# Created Mabarra for Girls Orphana  0202.xlsx
# Created L&L El-Awsaty Tunnel  0186.xlsx
# Created kayan wall lock & Load  0068.xlsx
# Created Pyramid tunnel  0101.xlsx
# Created ORA ZED - Ph 01B - Pkgs A&D  0137.xlsx
# Created Asmarat Roads L&L  0162.xlsx
# Created New bridge Ismailiya Nefisha  0079.xlsx
# Created Ora Zed Landscape Ph1  0185.xlsx
# Created Waldorf Astoria Mock-up Room  0146.xlsx
# Created Wady El Natroon Bridge  0167.xlsx
# Created Mohamed Ali Palace Restoration  0078.xlsx
# Created EMAAR-PKG#107-MARASSI  EMAR_IPWT_1459.xlsx
# Created Amal Bridge Lock & Load  0053.xlsx
# Created EMAAR-Pkg#162_163- Marassi  0123.xlsx
# Created HST El Mahager Bridge  0168.xlsx
# Created The Open Channel Project  0160.xlsx
# Created Gabal El-Zayt 40 MW KfW  GMSA_GZWF_1440.xlsx
# Created Damietta Container Termin  0216.xlsx
# Created Comoros La Galawa Resort  CMRS.xlsx
# Created Jawhara Palace Restoratio  0200.xlsx
# Created Cairo-Alex Railway  0134.xlsx
# Created BridgeNasr Rd w Abbas El-Akkad  0128.xlsx
# Created EDNC Retail & Offices Civil  0092.xlsx
# Created Waslet Om Amar Bridge  0156.xlsx
# Created Kemet Building  0149.xlsx
# Created ORA ZED-Ph 2-Pkgs A&D  0151.xlsx
# Created Bani Suef Old Substation  Bani Suef.xlsx
# Created Hosh Eissa Hospital  0201.xlsx
# Created Tarek Abdel-Hakim Center  0212.xlsx
# Created Astoria Sharm elSheikh  0182.xlsx
# Created El Moshier ( Abu Zaid Khedr)  0105.xlsx
# Created Joseph Tito Bridge L&L  0115.xlsx
# Created El Mostaqbal lock & load  0066.xlsx
# Created Ring Road - El Qawmiya  0188.xlsx
# Created DPW Onshore Port & Terminal  0094.xlsx
# Created Suez Steel Factory  0069.xlsx
# Created TSK Solar Benban  0083.xlsx
# Created EMAAR- Pkg 140-ITP-Mivida  0098.xlsx
# Created EMAAR-PKG# 101-UPTOWN  0095.xlsx
# Created Lekela 250MW Wind Farm  0125.xlsx
# Created Sokhna Port Expansion  0145.xlsx
# Created BKG#178-Lagoon Discharge  0142.xlsx
# Created Mohamed Aly Fahmy Lock&Load  0104.xlsx
# Created Sohag HSR Station  0210.xlsx
# Created NUCA R05 - Z02  0088.xlsx
# Created Kattameya Creeks  0138.xlsx
# Created GOE BENI SUEF 6X6000TPD  CDRI_BSCC_1445.xlsx
# Created Abu Qir Bridge  0214.xlsx
# Created Ring Road - Service Road  0189.xlsx
# Created Mehwar elsalam Lock & Load  0120.xlsx
# Created Tunnel of Sokhna Road (2)  0090.xlsx
# Created King Mariout  Bridge'  0165.xlsx
# Created Al Mostathmreen GIS Substation  0040.xlsx
# Created SSC Suez Steel Company Project  0184.xlsx
# Created Beymen Fit Out  0181.xlsx
# Created R06 Loack & Load  0155.xlsx
# Created Mall Of Egypt  0030.xlsx
# Created AL-JAZI EGYPT  0081.xlsx
# Created Haramein Columns Transfer  0199.xlsx
# Created Wadi Halfa Port  0183.xlsx
# Created Alamein Coastal Road Bridge  0166.xlsx
# Created DP World Basin 2 Ph2  0193.xlsx
# Created DoubleTree Mangroovy ElGouna  0107.xlsx
# Created New Giza Teaching Hospital  0126.xlsx
# Created EMAAR-PKG# 144, Marassi  0093.xlsx
# Created Darb Allabana Bldgs Ph1  0191.xlsx
# Created HSR - Fayoum Bridge  0211.xlsx
# Created King Farouk Resthouse Rest.  0077.xlsx
# Created Ismailiya East Substation  0052.xlsx
# Created HST Bridges-Sokhna & Mahager  0152.xlsx
# Created Air Defense College  0150.xlsx
# Created El Sewedy Stores Project  0065.xlsx
# Created Diplomatic District - Infra  0140.xlsx
# Created ORA Zed Park LOCK&LOAD  0106.xlsx
# Created Mohamed Nader Villa's  0204.xlsx
# Created Creeks URBN-K  0192.xlsx
# Created Emergency Bridge  0100.xlsx
# Created Hassan El Mamoun Bridge  0135.xlsx
# Created Gabal El-Zayt JICA 220 MW WF  GMSA_GBLZ_1301.xlsx
# Created Baron Fence  0108.xlsx
# Created New Giza 2  NGZA_UNVI_1369.xlsx
# Created Shubra-Banha lock&load  0064.xlsx
# Created Sodic Club House  0032.xlsx
# Created Middle Tunnel Lock Load  0091.xlsx
# Created 3A-L2M Building  0215.xlsx
# Created Alamein  0084.xlsx
# Created Abu Ghazala Lock & Load  0103.xlsx
# Created Siemens Power Station  0072.xlsx
# Created Qasr Rashwan - Lot B  0208.xlsx
# Created Qasr Rashwan Lot A  0207.xlsx
# Created Waldorf Astoria Cairo  0164.xlsx
# Created Asher Mn Ramadan Bridge No2  0129.xlsx
# Created EGP.xlsx
# Created Jawhar Al-Lala Mosque  0179.xlsx
# Created Kafr Shokr Bridge  0130.xlsx
# Created Suez Road Tunnel RES  0110.xlsx
# Created Royal City  0063.xlsx
# Created Abou Ghaleb Bridge  0157.xlsx
# Created Port Said Port Silos  0159.xlsx
# Created Faculty of Medicine  0139.xlsx
# Created RING ROAD MARYOTIA EXPANSION  0122.xlsx
# Created Elsewedy Univ - Enabling Works  0085.xlsx
# Created SOL Town PKG.220  0205.xlsx
# Created EMAAR-PKG#62-UPTOWN  Village E PKG#62.xlsx
# Created EGAT Pelletizing Plant  0144.xlsx
# Created El- Hussein Mosque  0178.xlsx
# Created Qani bay Al rammah Mosque  0174.xlsx
# Created Lock&Load-30June w Sokhna Rd  0086.xlsx
# Created Substation Elco Steel  0096.xlsx
# Created Endowments Building  0180.xlsx
# Created Olympic Multi – Sports Hall  0099.xlsx
# Created EMAAR-PKG#22-MARASSI  EMAR_ITPR_11226.xlsx
# Created EMAAR-PKG#53-UPTOWN  EMAR_SIER_1354.xlsx
# Created Egypt Mosque  8013.xlsx
# Created Abo Shanab El Agamien  0195.xlsx
# Created Sultana Malak Restoration  0124.xlsx
# Created Maxim Mall  MAXM_MXCM_1305.xlsx
# Created Tamey El-amdeed Substation  0051.xlsx
# Created EGAT Lock & Load  0173.xlsx
# Created GOV2 - Infra  0133.xlsx
# Created Kayan Landscape  0127.xlsx
# Created Safeer Square Bridge  0109.xlsx
# Created Beni Suef Substation R61  0061.xlsx
# Created HST Culverts  0169.xlsx
# Created Mintra New Factory  0076.xlsx
# Created Radamis City  0176.xlsx
