# %%
import os
import psycopg2
from google.cloud import sql

# %%
os.environ["rmedb-395804"] = "your-project-id"
project_id = os.environ["rmedb-395804"]
instance_name = "rme"
database = "rme"
username = "postgres"
password = "omar_321"

connection = psycopg2.connect(
    host="35.237.221.234",
    port=5432,
    database=database,
    user=username,
    password=password,
)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[6], line 8
#       5 username = "postgres"
#       6 password = "omar_321"
# ----> 8 connection = psycopg2.connect(
#       9     host="35.237.221.234",
#      10     port=5432,
#      11     database=database,
#      12     user=username,
#      13     password=password,
#      14 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\psycopg2\__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# OperationalError: connection to server at "35.237.221.234", port 5432 failed: Connection refused (0x0000274D/10061)
# 	Is the server running on that host and accepting TCP/IP connections?

# %%
try:
    connector.ping()
    print("Connection successful!")
except Exception as e:
    print("Connection failed:", e)
